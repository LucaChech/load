# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
#%pdb
mypath = ''
#mypath = 'C:/Users/KeK/OneDrive - University College London/Random_probes_last/Luca/'

# %%
# path = 'p7_1_r_dirty.csv'
# df = pd.DataFrame.from_csv(path, header = None)
# df.reset_index(inplace = True)
# df.columns = ['Image_Name','Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','space','RT_TO','keys','RT_VS','useless','Trial_N_Block','Block']

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
def fix_reaction_times(df):
#     df = pd.DataFrame.from_csv(path, header = None)
#     df.reset_index(inplace = True)
#     df.columns = ['Image_Name','Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','space','RT_TO','keys','RT_VS','useless','Trial_N_Block','Block']

    n = df.shape[0]
    for i in range(n):
        
        trial_type = df['trial_type'][i]
        rt_sound = df['RT_TO'][i]
        if 'Critical' in trial_type and 'No timing' in rt_sound:
            print 'DIRTY!',i
            go = True
            c = i+1
    #         set_trace()
            if c<n and 'Normal' in df['trial_type'][c] and  'No timing' not in df['RT_TO'][c]:

                print 'FOUND RT IN FIRST', c
                df.loc[i,'RT_TO'] = float(df.loc[c,'RT_TO']) + 1.3
                df.loc[i,'space'] = 'space'
                df.loc[c,'RT_TO'] = 'No timing'
                df.loc[c,'space'] = 'No space' 
                go = False
            c = i+2
            if go and c<n and 'Normal' in df['trial_type'][c] and  'No timing' not in df['RT_TO'][c]:
                print 'FOUND RT IN SECOND',c
                df.loc[i,'RT_TO'] = float(df.loc[c,'RT_TO']) + 2.6
                df.loc[i,'space'] = 'space'
                df.loc[c,'RT_TO'] = 'No timing'
                df.loc[c,'space'] = 'No space' 
    return df

# %%
# df = pd.DataFrame.from_csv(path, header = None)
# df.reset_index(inplace = True)
# df.columns = ['Image_Name','Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','space','RT_TO','keys','RT_VS','useless','Trial_N_Block','Block']

# fix_reaction_times(df)
# df.to_csv('clean_3.csv')

# %%
def clean_csv(path):
    df1 = pd.DataFrame.from_csv(path, header = None)

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
df1 = pd.DataFrame.from_csv(mypath+'p7_1_r_dirty.csv', header = None)
df1.reset_index(inplace = True)
df1.columns = ['Image_Name','Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','space','RT_TO','keys','RT_VS','useless','Trial_N_Block','Block']
df1.shape
df1
# Out:
#           Image_Name          Cat.1            Cat.2            Cat.3  \
# 0    2008_000189.jpg        person'           ' car'              nan
# 1    2010_004175.jpg           cat'              nan              nan
# 2    2010_001988.jpg          bird'              nan              nan
# 3    2009_000169.jpg        person'         ' horse'           ' car'
# 4    2008_001836.jpg           cat'              nan              nan
# 5    2009_004225.jpg           cat'              nan              nan
# 6    2009_000523.jpg           car'              nan              nan
# 7    2009_004888.jpg        person'          ' boat'              nan
# 8    2008_005123.jpg           dog'              nan              nan
# 9    2009_001723.jpg          boat'              nan              nan
# 10   2008_006954.jpg          bird'              nan              nan
# 11   2011_000481.jpg     aeroplane'              nan              nan
# 12   2009_002594.jpg        bottle'              nan              nan
# 13   2010_004145.jpg         horse'              nan              nan
# 14   2008_000115.jpg         chair'           ' cat'              nan
# 15   2011_002558.jpg        person'          ' boat'              nan
# 16   2010_003890.jpg         horse'              nan              nan
# 17   2010_005054.jpg     tvmonitor'          ' sofa'              nan
# 18   2008_007096.jpg     aeroplane'              nan              nan
# 19   2011_001005.jpg   pottedplant'          ' sofa'              nan
# 20   2009_001470.jpg          sofa'           ' dog'              nan
# 21   2009_004984.jpg       bicycle'        ' bottle'              nan
# 22   2009_002439.jpg        person'           ' cat'              nan
# 23   2010_003329.jpg        bottle'              nan              nan
# 24   2008_001205.jpg        person'              nan              nan
# 25   2008_000912.jpg         horse'              nan              nan
# 26   2008_000634.jpg        person'              nan              nan
# 27   2009_000189.jpg          sofa'           ' dog'              nan
# 28   2008_005903.jpg          bird'              nan              nan
# 29   2008_007274.jpg           dog'              nan              nan
# ..               ...            ...              ...              ...
# 450  2008_002084.jpg   pottedplant'        ' person'           ' dog'
# 451  2010_001856.jpg        person'         ' horse'              nan
# 452  2008_002774.jpg        person'     ' motorbike'              nan
# 453  2008_001576.jpg     tvmonitor'         ' chair'        ' person'
# 454  2010_004447.jpg        person'        ' bottle'          ' sofa'
# 455  2011_002641.jpg        person'         ' chair'        ' bottle'
# 456  2010_005542.jpg           car'       ' bicycle'        ' person'
# 457  2009_002414.jpg          bird'              nan              nan
# 458  2008_002789.jpg        person'         ' chair'   ' diningtable'
# 459  2008_000705.jpg        person'        ' bottle'              nan
# 460  2008_006121.jpg        person'          ' boat'              nan
# 461  2009_003351.jpg   pottedplant'        ' person'         ' chair'
# 462  2008_000270.jpg        person'           ' dog'          ' sofa'
# 463  2011_001991.jpg          boat'              nan              nan
# 464  2008_004487.jpg         chair'        ' bottle'              nan
# 465  2009_002306.jpg          boat'              nan              nan
# 466  2008_007108.jpg   pottedplant'           ' dog'              nan
# 467  2008_007250.jpg          bird'              nan              nan
# 468  2009_002750.jpg        person'         ' horse'              nan
# 469  2008_001210.jpg           cat'              nan              nan
# 470  2008_004459.jpg        person'          ' sofa'              nan
# 471  2010_002127.jpg        person'        ' bottle'           ' car'
# 472  2009_002001.jpg        person'     ' aeroplane'              nan
# 473  2008_000192.jpg          bird'              nan              nan
# 474  2008_002725.jpg        person'              nan              nan
# 475  2008_005750.jpg     aeroplane'              nan              nan
# 476  2008_000274.jpg   pottedplant'         ' chair'              nan
# 477  2008_003635.jpg        person'   ' diningtable'        ' bottle'
# 478  2008_003081.jpg        person'          ' boat'              nan
# 479  2011_000282.jpg        person'         ' chair'        ' bottle'
#
#                Cat.4     Cat.5         TS     Load         exemplar  \
# 0                nan       nan  18.390878    'low'           ' car'
# 1                nan       nan  10.236636    'low'           ' cat'
# 2                nan       nan  15.253871    'low'          ' bird'
# 3                nan       nan  20.934600    'low'         ' horse'
# 4                nan       nan  20.463884    'low'           ' cat'
# 5                nan       nan  12.729033    'low'           ' cat'
# 6                nan       nan  21.181011    'low'           ' car'
# 7                nan       nan  16.651242    'low'          ' boat'
# 8                nan       nan  19.570662    'low'           ' dog'
# 9                nan       nan  19.264338    'low'          ' boat'
# 10               nan       nan  11.957700    'low'          ' bird'
# 11               nan       nan  15.759492    'low'     ' aeroplane'
# 12               nan       nan  19.096237    'low'        ' bottle'
# 13               nan       nan  18.590456    'low'         ' horse'
# 14               nan       nan  17.570654    'low'         ' chair'
# 15               nan       nan  16.146155    'low'          ' boat'
# 16               nan       nan  19.803899    'low'         ' horse'
# 17               nan       nan  20.216264    'low'          ' sofa'
# 18               nan       nan  20.158044    'low'     ' aeroplane'
# 19               nan       nan  18.967723    'low'   ' pottedplant'
# 20               nan       nan  19.188834    'low'          ' sofa'
# 21               nan       nan  18.893798    'low'        ' bottle'
# 22               nan       nan  20.139878    'low'        ' person'
# 23               nan       nan  20.965775    'low'        ' bottle'
# 24               nan       nan  19.675827    'low'        ' person'
# 25               nan       nan  18.505883    'low'         ' horse'
# 26               nan       nan  21.235360    'low'        ' person'
# 27               nan       nan  20.934060    'low'          ' sofa'
# 28               nan       nan  18.015669    'low'          ' bird'
# 29               nan       nan  16.693373    'low'           ' dog'
# ..               ...       ...        ...      ...              ...
# 450              nan       nan  30.007374   'high'           ' dog'
# 451              nan       nan  35.669132   'high'         ' horse'
# 452              nan       nan  32.123307   'high'        ' person'
# 453              nan       nan  31.794729   'high'        ' person'
# 454              nan       nan  33.561186   'high'        ' bottle'
# 455              nan       nan  33.381115   'high'         ' chair'
# 456              nan       nan  28.874416   'high'        ' person'
# 457              nan       nan  29.742787   'high'          ' bird'
# 458        ' bottle'       nan  33.823550   'high'         ' chair'
# 459              nan       nan  30.958055   'high'        ' bottle'
# 460              nan       nan  30.384187   'high'          ' boat'
# 461     ' motorbike'   ' boat'  31.580490   'high'          ' boat'
# 462              nan       nan  29.935618   'high'           ' dog'
# 463              nan       nan  34.047147   'high'          ' boat'
# 464              nan       nan  35.925065   'high'         ' chair'
# 465              nan       nan  30.065266   'high'          ' boat'
# 466              nan       nan  29.851834   'high'           ' dog'
# 467              nan       nan  31.892126   'high'          ' bird'
# 468              nan       nan  30.141763   'high'         ' horse'
# 469              nan       nan  29.246976   'high'           ' cat'
# 470              nan       nan  31.124437   'high'          ' sofa'
# 471              nan       nan  34.313161   'high'           ' car'
# 472              nan       nan  34.544145   'high'     ' aeroplane'
# 473              nan       nan  29.176311   'high'          ' bird'
# 474              nan       nan  35.696632   'high'        ' person'
# 475              nan       nan  29.201869   'high'     ' aeroplane'
# 476              nan       nan  32.054270   'high'   ' pottedplant'
# 477              nan       nan  36.156013   'high'        ' bottle'
# 478              nan       nan  29.006457   'high'        ' person'
# 479   ' diningtable'       nan  35.134857   'high'        ' bottle'
#
#        question  ...     trial_type     tone_Hz tone_onset           space  \
# 0           nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 1     ' person'  ...       'Normal'   'No tone'       -999   'No spacebar'
# 2           nan  ...     'Critical'     'tone2'        481         'space'
# 3           nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 4           nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 5        ' cat'  ...       'Normal'   'No tone'       -999   'No spacebar'
# 6           nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 7       ' boat'  ...       'Normal'   'No tone'       -999   'No spacebar'
# 8     ' person'  ...       'Normal'   'No tone'       -999   'No spacebar'
# 9           nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 10          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 11          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 12          nan  ...     'Critical'     'tone2'        631   'No spacebar'
# 13          nan  ...       'Normal'   'No tone'       -999         'space'
# 14          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 15          nan  ...     'Critical'     'tone2'        305   'No spacebar'
# 16          nan  ...       'Normal'   'No tone'       -999         'space'
# 17          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 18          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 19          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 20          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 21          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 22          nan  ...     'Critical'     'tone1'         78         'space'
# 23          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 24          nan  ...     'Critical'     'tone2'        946   'No spacebar'
# 25          nan  ...       'Normal'   'No tone'       -999         'space'
# 26          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 27          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 28          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 29          nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# ..          ...  ...            ...         ...        ...             ...
# 450         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 451         nan  ...     'Critical'     'tone1'        659   'No spacebar'
# 452         nan  ...       'Normal'   'No tone'       -999         'space'
# 453         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 454         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 455     ' boat'  ...       'Normal'   'No tone'       -999   'No spacebar'
# 456         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 457         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 458         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 459         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 460     ' sofa'  ...       'Normal'   'No tone'       -999   'No spacebar'
# 461         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 462         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 463         nan  ...     'Critical'     'tone2'        107   'No spacebar'
# 464         nan  ...       'Normal'   'No tone'       -999         'space'
# 465         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 466         nan  ...     'Critical'     'tone1'        474         'space'
# 467         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 468         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 469      ' car'  ...       'Normal'   'No tone'       -999   'No spacebar'
# 470         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 471         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 472         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 473         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 474         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 475         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 476         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 477         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 478         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
# 479         nan  ...       'Normal'   'No tone'       -999   'No spacebar'
#
#             RT_TO   keys  RT_VS useless Trial_N_Block  Block
# 0     'No timing'   'Na'   'Na'    'Na'             0      1
# 1     'No timing'    'p'  2.527    -999             1      1
# 2      1.24632294   'Na'   'Na'    'Na'             2      1
# 3     'No timing'   'Na'   'Na'    'Na'             3      1
# 4     'No timing'   'Na'   'Na'    'Na'             4      1
# 5     'No timing'    'q'  2.283    -999             5      1
# 6     'No timing'   'Na'   'Na'    'Na'             6      1
# 7     'No timing'    'q'  2.621    -999             7      1
# 8     'No timing'    'p'  2.089    -999             8      1
# 9     'No timing'   'Na'   'Na'    'Na'             9      1
# 10    'No timing'   'Na'   'Na'    'Na'            10      1
# 11    'No timing'   'Na'   'Na'    'Na'            11      1
# 12    'No timing'   'Na'   'Na'    'Na'            12      1
# 13     0.07867753   'Na'   'Na'    'Na'            13      1
# 14    'No timing'   'Na'   'Na'    'Na'            14      1
# 15    'No timing'   'Na'   'Na'    'Na'            15      1
# 16     0.49433452   'Na'   'Na'    'Na'            16      1
# 17    'No timing'   'Na'   'Na'    'Na'            17      1
# 18    'No timing'   'Na'   'Na'    'Na'            18      1
# 19    'No timing'   'Na'   'Na'    'Na'            19      1
# 20    'No timing'   'Na'   'Na'    'Na'            20      1
# 21    'No timing'   'Na'   'Na'    'Na'            21      1
# 22    0.844541131   'Na'   'Na'    'Na'            22      1
# 23    'No timing'   'Na'   'Na'    'Na'            23      1
# 24    'No timing'   'Na'   'Na'    'Na'            24      1
# 25     0.22796829   'Na'   'Na'    'Na'            25      1
# 26    'No timing'   'Na'   'Na'    'Na'            26      1
# 27    'No timing'   'Na'   'Na'    'Na'            27      1
# 28    'No timing'   'Na'   'Na'    'Na'            28      1
# 29    'No timing'   'Na'   'Na'    'Na'            29      1
# ..            ...    ...    ...     ...           ...    ...
# 450   'No timing'   'Na'   'Na'    'Na'            30      8
# 451   'No timing'   'Na'   'Na'    'Na'            31      8
# 452   0.284179192   'Na'   'Na'    'Na'            32      8
# 453   'No timing'   'Na'   'Na'    'Na'            33      8
# 454   'No timing'   'Na'   'Na'    'Na'            34      8
# 455   'No timing'    'p'  2.518    -999            35      8
# 456   'No timing'   'Na'   'Na'    'Na'            36      8
# 457   'No timing'   'Na'   'Na'    'Na'            37      8
# 458   'No timing'   'Na'   'Na'    'Na'            38      8
# 459   'No timing'   'Na'   'Na'    'Na'            39      8
# 460   'No timing'    'p'  3.423    -999            40      8
# 461   'No timing'   'Na'   'Na'    'Na'            41      8
# 462   'No timing'   'Na'   'Na'    'Na'            42      8
# 463   'No timing'   'Na'   'Na'    'Na'            43      8
# 464   0.123970295   'Na'   'Na'    'Na'            44      8
# 465   'No timing'   'Na'   'Na'    'Na'            45      8
# 466   1.337986143   'Na'   'Na'    'Na'            46      8
# 467   'No timing'   'Na'   'Na'    'Na'            47      8
# 468   'No timing'   'Na'   'Na'    'Na'            48      8
# 469   'No timing'    'p'  3.278    -999            49      8
# 470   'No timing'   'Na'   'Na'    'Na'            50      8
# 471   'No timing'   'Na'   'Na'    'Na'            51      8
# 472   'No timing'   'Na'   'Na'    'Na'            52      8
# 473   'No timing'   'Na'   'Na'    'Na'            53      8
# 474   'No timing'   'Na'   'Na'    'Na'            54      8
# 475   'No timing'   'Na'   'Na'    'Na'            55      8
# 476   'No timing'   'Na'   'Na'    'Na'            56      8
# 477   'No timing'   'Na'   'Na'    'Na'            57      8
# 478   'No timing'   'Na'   'Na'    'Na'            58      8
# 479   'No timing'   'Na'   'Na'    'Na'            59      8
#
# [480 rows x 21 columns]

# %%
df2 = pd.DataFrame.from_csv(mypath+'p7_2_r_dirty.csv', header = None)
df2.reset_index(inplace = True)
df2.columns = ['Image_Name','Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','space','RT_TO','keys','RT_VS','useless','Trial_N_Block','Block']
df2.shape
#df2
# Out:
# (480, 21)

# %%
frames = [df1,df2]
df = pd.concat(frames)
df.reset_index(drop=True, inplace=True)
df.drop(['Image_Name','Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','exemplar','question','space','useless'], axis=1, inplace=True)
fix_reaction_times(df)
df
# Out:
# DIRTY! 12
# FOUND RT IN FIRST 13
# DIRTY! 15
# FOUND RT IN FIRST 16
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 36
# FOUND RT IN FIRST 37
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 107
# DIRTY! 125
# DIRTY! 160
# FOUND RT IN FIRST 161
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 175
# DIRTY! 190
# FOUND RT IN FIRST 191
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# DIRTY! 253
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 292
# FOUND RT IN FIRST 293
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 319
# FOUND RT IN FIRST 320
# DIRTY! 336
# FOUND RT IN FIRST 337
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 379
# FOUND RT IN FIRST 380
# DIRTY! 433
# FOUND RT IN FIRST 434
# DIRTY! 440
# DIRTY! 443
# FOUND RT IN FIRST 444
# DIRTY! 451
# FOUND RT IN FIRST 452
# DIRTY! 463
# FOUND RT IN FIRST 464
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 532
# FOUND RT IN FIRST 533
# DIRTY! 541
# FOUND RT IN FIRST 542
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 612
# FOUND RT IN FIRST 613
# DIRTY! 637
# FOUND RT IN FIRST 638
# DIRTY! 663
# DIRTY! 692
# DIRTY! 710
# DIRTY! 741
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 804
# DIRTY! 810
# FOUND RT IN FIRST 811
# DIRTY! 821
# FOUND RT IN FIRST 822
# DIRTY! 837
# DIRTY! 901
# FOUND RT IN FIRST 902
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# DIRTY! 929
# FOUND RT IN FIRST 930
#         Load     present_absent   trial_type     tone_Hz  tone_onset  \
# 0      'low'        'No Target'     'Normal'   'No tone'        -999
# 1      'low'    'Target Absent'     'Normal'   'No tone'        -999
# 2      'low'        'No Target'   'Critical'     'tone2'         481
# 3      'low'        'No Target'     'Normal'   'No tone'        -999
# 4      'low'        'No Target'     'Normal'   'No tone'        -999
# 5      'low'   'Target Present'     'Normal'   'No tone'        -999
# 6      'low'        'No Target'     'Normal'   'No tone'        -999
# 7      'low'   'Target Present'     'Normal'   'No tone'        -999
# 8      'low'    'Target Absent'     'Normal'   'No tone'        -999
# 9      'low'        'No Target'     'Normal'   'No tone'        -999
# 10     'low'        'No Target'     'Normal'   'No tone'        -999
# 11     'low'        'No Target'     'Normal'   'No tone'        -999
# 12     'low'        'No Target'   'Critical'     'tone2'         631
# 13     'low'        'No Target'     'Normal'   'No tone'        -999
# 14     'low'        'No Target'     'Normal'   'No tone'        -999
# 15     'low'        'No Target'   'Critical'     'tone2'         305
# 16     'low'        'No Target'     'Normal'   'No tone'        -999
# 17     'low'        'No Target'     'Normal'   'No tone'        -999
# 18     'low'        'No Target'     'Normal'   'No tone'        -999
# 19     'low'        'No Target'     'Normal'   'No tone'        -999
# 20     'low'        'No Target'     'Normal'   'No tone'        -999
# 21     'low'        'No Target'     'Normal'   'No tone'        -999
# 22     'low'        'No Target'   'Critical'     'tone1'          78
# 23     'low'        'No Target'     'Normal'   'No tone'        -999
# 24     'low'        'No Target'   'Critical'     'tone2'         946
# 25     'low'        'No Target'     'Normal'   'No tone'        -999
# 26     'low'        'No Target'     'Normal'   'No tone'        -999
# 27     'low'        'No Target'     'Normal'   'No tone'        -999
# 28     'low'        'No Target'     'Normal'   'No tone'        -999
# 29     'low'        'No Target'     'Normal'   'No tone'        -999
# ..       ...                ...          ...         ...         ...
# 930   'high'        'No Target'     'Normal'   'No tone'        -999
# 931   'high'        'No Target'     'Normal'   'No tone'        -999
# 932   'high'        'No Target'     'Normal'   'No tone'        -999
# 933   'high'        'No Target'     'Normal'   'No tone'        -999
# 934   'high'        'No Target'   'Critical'     'tone1'         385
# 935   'high'        'No Target'     'Normal'   'No tone'        -999
# 936   'high'        'No Target'     'Normal'   'No tone'        -999
# 937   'high'   'Target Present'     'Normal'   'No tone'        -999
# 938   'high'        'No Target'     'Normal'   'No tone'        -999
# 939   'high'        'No Target'     'Normal'   'No tone'        -999
# 940   'high'        'No Target'     'Normal'   'No tone'        -999
# 941   'high'        'No Target'     'Normal'   'No tone'        -999
# 942   'high'        'No Target'     'Normal'   'No tone'        -999
# 943   'high'        'No Target'     'Normal'   'No tone'        -999
# 944   'high'        'No Target'     'Normal'   'No tone'        -999
# 945   'high'        'No Target'     'Normal'   'No tone'        -999
# 946   'high'        'No Target'     'Normal'   'No tone'        -999
# 947   'high'        'No Target'     'Normal'   'No tone'        -999
# 948   'high'        'No Target'     'Normal'   'No tone'        -999
# 949   'high'   'Target Present'     'Normal'   'No tone'        -999
# 950   'high'        'No Target'     'Normal'   'No tone'        -999
# 951   'high'        'No Target'     'Normal'   'No tone'        -999
# 952   'high'        'No Target'     'Normal'   'No tone'        -999
# 953   'high'        'No Target'     'Normal'   'No tone'        -999
# 954   'high'        'No Target'     'Normal'   'No tone'        -999
# 955   'high'   'Target Present'     'Normal'   'No tone'        -999
# 956   'high'        'No Target'     'Normal'   'No tone'        -999
# 957   'high'        'No Target'     'Normal'   'No tone'        -999
# 958   'high'        'No Target'     'Normal'   'No tone'        -999
# 959   'high'        'No Target'     'Normal'   'No tone'        -999
#
#             RT_TO   keys  RT_VS  Trial_N_Block  Block     space
# 0     'No timing'   'Na'   'Na'              0      1       NaN
# 1     'No timing'    'p'  2.527              1      1       NaN
# 2      1.24632294   'Na'   'Na'              2      1       NaN
# 3     'No timing'   'Na'   'Na'              3      1       NaN
# 4     'No timing'   'Na'   'Na'              4      1       NaN
# 5     'No timing'    'q'  2.283              5      1       NaN
# 6     'No timing'   'Na'   'Na'              6      1       NaN
# 7     'No timing'    'q'  2.621              7      1       NaN
# 8     'No timing'    'p'  2.089              8      1       NaN
# 9     'No timing'   'Na'   'Na'              9      1       NaN
# 10    'No timing'   'Na'   'Na'             10      1       NaN
# 11    'No timing'   'Na'   'Na'             11      1       NaN
# 12        1.37868   'Na'   'Na'             12      1     space
# 13      No timing   'Na'   'Na'             13      1  No space
# 14    'No timing'   'Na'   'Na'             14      1       NaN
# 15        1.79433   'Na'   'Na'             15      1     space
# 16      No timing   'Na'   'Na'             16      1  No space
# 17    'No timing'   'Na'   'Na'             17      1       NaN
# 18    'No timing'   'Na'   'Na'             18      1       NaN
# 19    'No timing'   'Na'   'Na'             19      1       NaN
# 20    'No timing'   'Na'   'Na'             20      1       NaN
# 21    'No timing'   'Na'   'Na'             21      1       NaN
# 22    0.844541131   'Na'   'Na'             22      1       NaN
# 23    'No timing'   'Na'   'Na'             23      1       NaN
# 24        1.52797   'Na'   'Na'             24      1     space
# 25      No timing   'Na'   'Na'             25      1  No space
# 26    'No timing'   'Na'   'Na'             26      1       NaN
# 27    'No timing'   'Na'   'Na'             27      1       NaN
# 28    'No timing'   'Na'   'Na'             28      1       NaN
# 29    'No timing'   'Na'   'Na'             29      1       NaN
# ..            ...    ...    ...            ...    ...       ...
# 930     No timing   'Na'   'Na'             30     16  No space
# 931   'No timing'   'Na'   'Na'             31     16       NaN
# 932   'No timing'   'Na'   'Na'             32     16       NaN
# 933   'No timing'   'Na'   'Na'             33     16       NaN
# 934   1.147487511   'Na'   'Na'             34     16       NaN
# 935   'No timing'   'Na'   'Na'             35     16       NaN
# 936   'No timing'   'Na'   'Na'             36     16       NaN
# 937   'No timing'    'q'  2.201             37     16       NaN
# 938   'No timing'   'Na'   'Na'             38     16       NaN
# 939   'No timing'   'Na'   'Na'             39     16       NaN
# 940   'No timing'   'Na'   'Na'             40     16       NaN
# 941   'No timing'   'Na'   'Na'             41     16       NaN
# 942   'No timing'   'Na'   'Na'             42     16       NaN
# 943   'No timing'   'Na'   'Na'             43     16       NaN
# 944   'No timing'   'Na'   'Na'             44     16       NaN
# 945   'No timing'   'Na'   'Na'             45     16       NaN
# 946   'No timing'   'Na'   'Na'             46     16       NaN
# 947   'No timing'   'Na'   'Na'             47     16       NaN
# 948   'No timing'   'Na'   'Na'             48     16       NaN
# 949   'No timing'    'q'  2.587             49     16       NaN
# 950   'No timing'   'Na'   'Na'             50     16       NaN
# 951   'No timing'   'Na'   'Na'             51     16       NaN
# 952   'No timing'   'Na'   'Na'             52     16       NaN
# 953   'No timing'   'Na'   'Na'             53     16       NaN
# 954   'No timing'   'Na'   'Na'             54     16       NaN
# 955   'No timing'    'q'  2.055             55     16       NaN
# 956   'No timing'   'Na'   'Na'             56     16       NaN
# 957   'No timing'   'Na'   'Na'             57     16       NaN
# 958   'No timing'   'Na'   'Na'             58     16       NaN
# 959   'No timing'   'Na'   'Na'             59     16       NaN
#
# [960 rows x 11 columns]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#         Load     present_absent   trial_type     tone_Hz  tone_onset  \
# 0      'low'        'No Target'     'Normal'   'No tone'        -999
# 1      'low'    'Target Absent'     'Normal'   'No tone'        -999
# 2      'low'        'No Target'   'Critical'     'tone2'         481
# 3      'low'        'No Target'     'Normal'   'No tone'        -999
# 4      'low'        'No Target'     'Normal'   'No tone'        -999
# 5      'low'   'Target Present'     'Normal'   'No tone'        -999
# 6      'low'        'No Target'     'Normal'   'No tone'        -999
# 7      'low'   'Target Present'     'Normal'   'No tone'        -999
# 8      'low'    'Target Absent'     'Normal'   'No tone'        -999
# 9      'low'        'No Target'     'Normal'   'No tone'        -999
# 10     'low'        'No Target'     'Normal'   'No tone'        -999
# 11     'low'        'No Target'     'Normal'   'No tone'        -999
# 12     'low'        'No Target'   'Critical'     'tone2'         631
# 13     'low'        'No Target'     'Normal'   'No tone'        -999
# 14     'low'        'No Target'     'Normal'   'No tone'        -999
# 15     'low'        'No Target'   'Critical'     'tone2'         305
# 16     'low'        'No Target'     'Normal'   'No tone'        -999
# 17     'low'        'No Target'     'Normal'   'No tone'        -999
# 18     'low'        'No Target'     'Normal'   'No tone'        -999
# 19     'low'        'No Target'     'Normal'   'No tone'        -999
# 20     'low'        'No Target'     'Normal'   'No tone'        -999
# 21     'low'        'No Target'     'Normal'   'No tone'        -999
# 22     'low'        'No Target'   'Critical'     'tone1'          78
# 23     'low'        'No Target'     'Normal'   'No tone'        -999
# 24     'low'        'No Target'   'Critical'     'tone2'         946
# 25     'low'        'No Target'     'Normal'   'No tone'        -999
# 26     'low'        'No Target'     'Normal'   'No tone'        -999
# 27     'low'        'No Target'     'Normal'   'No tone'        -999
# 28     'low'        'No Target'     'Normal'   'No tone'        -999
# 29     'low'        'No Target'     'Normal'   'No tone'        -999
# ..       ...                ...          ...         ...         ...
# 930   'high'        'No Target'     'Normal'   'No tone'        -999
# 931   'high'        'No Target'     'Normal'   'No tone'        -999
# 932   'high'        'No Target'     'Normal'   'No tone'        -999
# 933   'high'        'No Target'     'Normal'   'No tone'        -999
# 934   'high'        'No Target'   'Critical'     'tone1'         385
# 935   'high'        'No Target'     'Normal'   'No tone'        -999
# 936   'high'        'No Target'     'Normal'   'No tone'        -999
# 937   'high'   'Target Present'     'Normal'   'No tone'        -999
# 938   'high'        'No Target'     'Normal'   'No tone'        -999
# 939   'high'        'No Target'     'Normal'   'No tone'        -999
# 940   'high'        'No Target'     'Normal'   'No tone'        -999
# 941   'high'        'No Target'     'Normal'   'No tone'        -999
# 942   'high'        'No Target'     'Normal'   'No tone'        -999
# 943   'high'        'No Target'     'Normal'   'No tone'        -999
# 944   'high'        'No Target'     'Normal'   'No tone'        -999
# 945   'high'        'No Target'     'Normal'   'No tone'        -999
# 946   'high'        'No Target'     'Normal'   'No tone'        -999
# 947   'high'        'No Target'     'Normal'   'No tone'        -999
# 948   'high'        'No Target'     'Normal'   'No tone'        -999
# 949   'high'   'Target Present'     'Normal'   'No tone'        -999
# 950   'high'        'No Target'     'Normal'   'No tone'        -999
# 951   'high'        'No Target'     'Normal'   'No tone'        -999
# 952   'high'        'No Target'     'Normal'   'No tone'        -999
# 953   'high'        'No Target'     'Normal'   'No tone'        -999
# 954   'high'        'No Target'     'Normal'   'No tone'        -999
# 955   'high'   'Target Present'     'Normal'   'No tone'        -999
# 956   'high'        'No Target'     'Normal'   'No tone'        -999
# 957   'high'        'No Target'     'Normal'   'No tone'        -999
# 958   'high'        'No Target'     'Normal'   'No tone'        -999
# 959   'high'        'No Target'     'Normal'   'No tone'        -999
#
#             RT_TO   keys  RT_VS  Trial_N_Block  Block
# 0     'No timing'   'Na'   'Na'              0      1
# 1     'No timing'    'p'  2.842              1      1
# 2     1.460890014   'Na'   'Na'              2      1
# 3     'No timing'   'Na'   'Na'              3      1
# 4     'No timing'   'Na'   'Na'              4      1
# 5     'No timing'    'q'  2.138              5      1
# 6     'No timing'   'Na'   'Na'              6      1
# 7     'No timing'    'q'  2.482              7      1
# 8     'No timing'    'p'  2.131              8      1
# 9     'No timing'   'Na'   'Na'              9      1
# 10    'No timing'   'Na'   'Na'             10      1
# 11    'No timing'   'Na'   'Na'             11      1
# 12    1.395144772   'Na'   'Na'             12      1
# 13    'No timing'   'Na'   'Na'             13      1
# 14    'No timing'   'Na'   'Na'             14      1
# 15    1.111763832   'Na'   'Na'             15      1
# 16    'No timing'   'Na'   'Na'             16      1
# 17    'No timing'   'Na'   'Na'             17      1
# 18    'No timing'   'Na'   'Na'             18      1
# 19    'No timing'   'Na'   'Na'             19      1
# 20    'No timing'   'Na'   'Na'             20      1
# 21    'No timing'   'Na'   'Na'             21      1
# 22    0.861891771   'Na'   'Na'             22      1
# 23    'No timing'   'Na'   'Na'             23      1
# 24    1.461830845   'Na'   'Na'             24      1
# 25    'No timing'   'Na'   'Na'             25      1
# 26    'No timing'   'Na'   'Na'             26      1
# 27    'No timing'   'Na'   'Na'             27      1
# 28    'No timing'   'Na'   'Na'             28      1
# 29    'No timing'   'Na'   'Na'             29      1
# ..            ...    ...    ...            ...    ...
# 930   'No timing'   'Na'   'Na'             30     16
# 931   'No timing'   'Na'   'Na'             31     16
# 932   'No timing'   'Na'   'Na'             32     16
# 933   'No timing'   'Na'   'Na'             33     16
# 934   'No timing'   'Na'   'Na'             34     16
# 935   'No timing'   'Na'   'Na'             35     16
# 936   'No timing'   'Na'   'Na'             36     16
# 937   'No timing'    'q'  2.139             37     16
# 938   'No timing'   'Na'   'Na'             38     16
# 939   'No timing'   'Na'   'Na'             39     16
# 940   'No timing'   'Na'   'Na'             40     16
# 941   'No timing'   'Na'   'Na'             41     16
# 942   'No timing'   'Na'   'Na'             42     16
# 943   'No timing'   'Na'   'Na'             43     16
# 944   'No timing'   'Na'   'Na'             44     16
# 945   'No timing'   'Na'   'Na'             45     16
# 946   'No timing'   'Na'   'Na'             46     16
# 947   'No timing'   'Na'   'Na'             47     16
# 948   'No timing'   'Na'   'Na'             48     16
# 949   'No timing'    'q'  2.902             49     16
# 950   'No timing'   'Na'   'Na'             50     16
# 951   'No timing'   'Na'   'Na'             51     16
# 952   'No timing'   'Na'   'Na'             52     16
# 953   'No timing'   'Na'   'Na'             53     16
# 954   'No timing'   'Na'   'Na'             54     16
# 955   'No timing'    'q'   2.05             55     16
# 956   'No timing'   'Na'   'Na'             56     16
# 957   'No timing'   'Na'   'Na'             57     16
# 958   'No timing'   'Na'   'Na'             58     16
# 959   'No timing'   'Na'   'Na'             59     16
#
# [960 rows x 10 columns]

# %%
RT_TO = df['RT_TO'].tolist()
RT_VS = df['RT_VS'].tolist()
Audio = df['trial_type'].tolist()
Present_absent = df['present_absent'].tolist()
Audio = df['trial_type'].tolist()
Keys = df['keys'].tolist()
Tone_onset = df['tone_onset'].tolist()

# %%
#RT_TO_floats = [n for n in RT_TO if 'NaN' not in n]
#sd_TO = np.std(RT_TO_floats)
#mean_TO = np.mean(RT_TO_floats)

# %%
RT_TO = [str('NaN') if 'No timing' in n else float(n[0:5]) for n in RT_TO]

# %%
RT_VS = [str('NaN') if 'Na' in n else float(n[0:5])-1.3 for n in RT_VS]

# %%
Keys = [str(n[2:-1]) for n in Keys]

# %%
RT_TO_floats = [n for n in RT_TO if type(n) == float]
sd_TO = np.std(RT_TO_floats)
mean_TO = np.mean(RT_TO_floats)

# %%
#Getting rid of outliers for TO RT (outliers are replaced with mean)
RT_TO_no_outliers = []
counter_TO = 0
RT_TO_outliers = []
for i in RT_TO:
    if type(i) != float:
        RT_TO_no_outliers.append(i)
    elif type(i) == float:
        if (mean_TO - 2.5 * sd_TO) < i < (mean_TO + 2.5 * sd_TO):
            RT_TO_no_outliers.append(i)
        else:
            counter_TO = counter_TO + 1
            #print 'Outlier ' + str(counter_TO) + ': ' + str(i) 
            RT_TO_no_outliers.append(mean_TO)
            RT_TO_outliers.append(i)
RT_TO = RT_TO_no_outliers

# %%
Tone_onset = [int(n) for n in Tone_onset]
for i in range(len(Tone_onset)):
    if Tone_onset[i] != -999:
        Tone_onset[i] = float(Tone_onset[i])/1000
        if type(RT_TO[i]) == float:
            #print RT_TO[i], '-', Tone_onset[i] 
            RT_TO[i] = RT_TO[i] - Tone_onset[i]
            #print RT_TO[i]

# %%
RT_VS_floats = [n for n in RT_VS if type(n) == float]
sd_VS = np.std(RT_VS_floats)
mean_VS = np.mean(RT_VS_floats)

# %%
#Getting rid of outliers for TO RT (outliers are replaced with mean)
RT_VS_no_outliers = []
counter_VS = 0
RT_VS_outliers = []
for i in RT_VS:
    if type(i) != float:
        RT_VS_no_outliers.append(i)
    elif type(i) == float:
        if (mean_VS - 2.5 * sd_VS) < i < (mean_VS + 2.5 * sd_VS):
            RT_VS_no_outliers.append(i)
        else:
            counter_VS = counter_VS + 1
            #print 'Outlier ' + str(counter_TO) + ': ' + str(i) 
            RT_VS_no_outliers.append(mean_VS)
            RT_VS_outliers.append(i)
RT_VS = RT_VS_no_outliers

# %%
print 'Take Over:'
print 'mean RT: ', mean_TO
print 'SD: ', sd_TO
print 'Outliers: ', len(RT_TO_outliers)
for i in RT_TO_outliers:
    print i

print 'Visual Search:'
print 'mean RT: ', mean_VS
print 'SD: ', sd_VS
print 'Outliers: ', len(RT_VS_outliers)
for i in RT_VS_outliers:
    print i

# %%
for i in RT_TO:
    print i, type(i)

# %%
#######
Acc_VS = []
for i in range(960):
    if 'Critical' in Audio[i]:
        #print i
        Acc_VS.append('999')
    elif 'Normal' in Audio[i] and RT_TO[i] != 'NaN':
        Acc_VS.append('666')
    elif 'Target Present' in Present_absent[i] and 'q' in Keys[i]:
        Acc_VS.append(1)
    elif 'Target Present' in Present_absent[i] and 'p' in Keys[i]:
        Acc_VS.append(0)
    elif 'Target Absent' in Present_absent[i] and 'p' in Keys[i]:
        Acc_VS.append(1)   
    elif 'Target Absent' in Present_absent[i] and 'q' in Keys[i]:
        Acc_VS.append(0)
    elif 'No Target' in Present_absent[i]:
        Acc_VS.append('999')

#print len(Acc_VS)
#######

# %%
#######
# CREATING Acc_DT (1 = included for analysis; 0 = excluded from analysis)
Acc_DT = []
for i in range(960):
    if 'Critical' in Audio[i] and type(RT_TO[i]) != str:
        if 'Target Present' in Present_absent[i] and 'q' in Keys[i]:
            Acc_DT.append(1)
        elif 'Target Absent' in Present_absent[i] and 'p' in Keys[i]:
            Acc_DT.append(1)
        elif 'Target Present' in Present_absent[i] and 'p' in Keys[i]:
            Acc_DT.append(999)
        elif 'Target Absent' in Present_absent[i] and 'q' in Keys[i]:
            Acc_DT.append(999)
        elif 'No Target' in Present_absent[i]:
            Acc_DT.append(1)
    elif 'Critical' in Audio[i] and type(RT_TO[i]) == str:
        Acc_DT.append(0)
    elif 'Normal' in Audio[i] and type(RT_TO[i]) != str:
        Acc_DT.append(666) # 666 are false alarms
    elif 'Normal' in Audio[i] and type(RT_TO[i]) == str:
        Acc_DT.append(999)
#print len(Acc_DT)

# %%
# Calculating D' :
# to calculate D' prime you need:
#1) hit rate
#2) false alarms rate
# the z-transformed of 1 and 2
# the formula is:....
# 1 and 2 cannot be equal to 1 or 0
correct_response_counter = len([n for n in Acc_DT if n == 1])
incorrect_response_counter = len([n for n in Acc_DT if n == 0])
incorrect_response_counter

# %%
# Converting lists into pandas.series...
RT_TO = pd.Series(data=RT_TO)
RT_VS = pd.Series(data=RT_VS)
Acc_VS = pd.Series(data=Acc_VS)
Acc_DT = pd.Series(data=Acc_DT)
#False_Alarms = pd.Series(data=False_Alarms)
# ...and combining them into a pandas dataframe

# %%
df.drop(['RT_TO','RT_VS'], inplace = True)
df['RT_TO'] = RT_TO.values
df['RT_VS'] = RT_VS.values
df['Acc_VS'] = Acc_VS.values
df['Acc_DT'] = Acc_DT.values

# %%
df[['RT_TO','RT_VS']] = df[['RT_TO','RT_VS']].astype('float')
df[['Acc_VS','Acc_DT']] = df[['Acc_VS','Acc_DT']].astype('int')
print df.dtypes

# %%
# Calculating D' :
# to calculate D' prime you need:
#1) hit rate
#2) false alarms rate
# the z-transformed of 1 and 2
# the formula is:....
# 1 and 2 cannot be equal to 1 or 0

# %%
#TABLE 1
#print df.groupby(['Load','Acc_VS']).RT_VS.mean()
#print df.groupby(['Load','Acc_VS']).RT_VS.count()

# TABLE 2
print df.groupby(['Load','Acc_VS','present_absent']).RT_VS.mean()
print df.groupby(['Load','Acc_VS','present_absent']).RT_VS.count()

#TABLE 3
#print df.groupby(['Load','trial_type','Acc_DT']).RT_TO.mean()
#print df.groupby(['Load','trial_type','Acc_DT']).Acc_DT.count()

#-----------------------------------------------------------------------
#TABLE 4
#print df.groupby(['Load','Audio']).Audio.count()
#print df.groupby(['Load','Audio','Acc_DT']).Acc_DT.count()
