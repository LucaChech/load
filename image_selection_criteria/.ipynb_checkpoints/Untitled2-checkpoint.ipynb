# %%
import pandas as pd
import numpy as np
import random
import csv

# %%
my_dict={}
with open('C:/Users/luca.chech.16/Desktop/Visual Search Exp/annotations.csv', 'r') as f:
    for line in f:
        items = line.split(',')
        key, values = items[0], items[1:]
        my_dict.setdefault(key, []).extend(values)
lista= my_dict.keys()

# %%
true_skill_dict = {}
with open('C:/Users/luca.chech.16/Desktop/Visual Search Exp/true_skill_2.csv', 'r') as f:
    for line in f:
        items = line.split(',')
        key, values = items[0], items[1:]
        true_skill_dict.setdefault(key, []).extend(values)
lista= true_skill_dict.keys()
len(lista)
# Out:
# 2000

# %%
true_skill_dict
# Out:
# {'2008_003545.jpg': ['27.33404946795403\n'],
#  '2011_001870.jpg': ['31.55697493659705\n'],
#  '2011_002831.jpg': ['22.789849733974634\n'],
#  '2010_003329.jpg': ['20.965775321926714\n'],
#  '2008_004008.jpg': ['22.895043347166332\n'],
#  '2011_001656.jpg': ['19.156547420300026\n'],
#  '2008_001688.jpg': ['30.844946015550335\n'],
#  '2011_000745.jpg': ['27.967249067888858\n'],
#  '2009_000906.jpg': ['29.05478148184519\n'],
#  '2009_001972.jpg': ['15.20975978276442\n'],
#  '2010_002469.jpg': ['26.594945661706998\n'],
#  '2009_001384.jpg': ['23.169020276881632\n'],
#  '2010_001754.jpg': ['21.836713940782506\n'],
#  '2008_002936.jpg': ['24.07292507206941\n'],
#  '2008_003280.jpg': ['26.76296406648404\n'],
#  '2008_006481.jpg': ['29.314233597971622\n'],
#  '2009_002286.jpg': ['23.731922310863247\n'],
#  '2011_001877.jpg': ['22.063249091593846\n'],
#  '2010_003248.jpg': ['29.396369433299476\n'],
#  '2008_003498.jpg': ['32.345816037704566\n'],
# ...

# %%
#Find a better way to do this
from itertools import chain
from collections import defaultdict
dict_merged = defaultdict(list)
for k, v in chain(my_dict.items(), true_skill_dict.items()):
    dict_merged[k].append(v)
 
for k, v in dict_merged.items():
    print(k, v)
# Out:
# ('2008_007434.jpg', [[' bird', '', '', '', '', '\n']])
# ('2010_005860.jpg', [[' pottedplant', ' car', ' bicycle', '', '', '\n']])
# ('2012_002235.jpg', [[' person', '', '', '', '', '\n']])
# ('2012_000051.jpg', [[' person', '', '', '', '', '\n']])
# ('2011_006008.jpg', [[' person', '', '', '', '', '\n']])
# ('2012_000044.jpg', [[' person', '', '', '', '', '\n']])
# ('2009_000063.jpg', [[' person', '', '', '', '', '\n']])
# ('2010_000307.jpg', [[' sheep', '', '', '', '', '\n']])
# ('2007_009901.jpg', [[' person', ' chair', ' diningtable', '', '', '\n']])
# ('2007_007447.jpg', [[' person', ' bicycle', ' car', '', '', '\n']])
# ('2011_005998.jpg', [[' person', '', '', '', '', '\n']])
# ('2012_002379.jpg', [[' person', '', '', '', '', '\n']])
# ('2011_004607.jpg', [[' person', '', '', '', '', '\n']])
# ('2008_007922.jpg', [[' chair', ' diningtable', '', '', '', '\n']])
# ('2009_001376.jpg', [[' person', ' sofa', '', '', '', '\n']])
# ...

# %%
for each in my_dict:
    if each in true_skill_dict.keys():
        my_dict[each].append(true_skill_dict[each][0])
len(my_dict)
# Out:
# 17125

# %%
my_dict
# Out:
# {'2010_004635.jpg': [' cow', '', '', '', '', '\n'],
#  '2008_007434.jpg': [' bird', '', '', '', '', '\n'],
#  '2010_005644.jpg': [' dog', '', '', '', '', '\n'],
#  '2010_006054.jpg': [' train', '', '', '', '', '\n'],
#  '2012_000051.jpg': [' person', '', '', '', '', '\n'],
#  '2011_006008.jpg': [' person', '', '', '', '', '\n'],
#  '2012_000044.jpg': [' person', '', '', '', '', '\n'],
#  '2009_000063.jpg': [' person', '', '', '', '', '\n'],
#  '2010_000307.jpg': [' sheep', '', '', '', '', '\n'],
#  '2007_009901.jpg': [' person', ' chair', ' diningtable', '', '', '\n'],
#  '2010_000716.jpg': [' dog', '', '', '', '', '\n'],
#  '2011_005998.jpg': [' person', '', '', '', '', '\n'],
#  '2012_002379.jpg': [' person', '', '', '', '', '\n'],
#  '2009_001664.jpg': [' horse', '', '', '', '', '\n'],
#  '2008_007922.jpg': [' chair', ' diningtable', '', '', '', '\n'],
#  '2009_001534.jpg': [' train', '', '', '', '', '\n'],
#  '2009_004084.jpg': [' bird', '', '', '', '', '\n'],
# ...

# %%
# Defining all categories in PASCAL VOC
categories =['person', 'bird', 'cat', 'cow', 'dog', 'horse', 'sheep', 'aeroplane', 'bicycle', 'boat', 'bus', 'car', 'motorbike', 'train', 'bottle', 'chair', 'dining table', 'potted plant', 'sofa', 'tv/monitor']
len(categories)
# Out:
# 20

# %%
redacted_dict = {key:my_dict[key] for key in target_present_trials}

# %%
for each in my_dict:
    if each in true_skill_dict.keys():
        my_dict[each].append(true_skill_dict[each])

# %%
for each in my_dict:
    print my_dict[each][-1]
# Out:
# ['19.156547420300026\n']
# ['27.437616509358644\n']
#
#
#
#
#
#
# ['30.141763061562205\n']
#
#
#
#
#
#
# ['23.169020276881632\n']
# ['21.836713940782506\n']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['25.24292824426174\n']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['24.584960773390193\n']
#
#
#
#
#
#
# ['29.0787327362723\n']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['28.81022225554137\n']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['22.95740035226037\n']
#
#
#
#
# ['28.982776870917203\n']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['27.249067166667025\n']
#
#
#
#
#
#
#
#
#
#
# ['17.23065839052537\n']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['23.087199639661307\n']
#
#
# ['19.05734476753717\n']
#
#
#
#
# ['21.116301747151233\n']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['27.457661098792915\n']
#
#
#
#
#
#
#
#
# ...

# %%
# Out:
# list
