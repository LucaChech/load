# %%
my_dict={}
with open('C:/Users/luca.chech.16/Desktop/Visual Search Exp/my_dict_final.csv', 'r') as f:
    for line in f:
        items = line.split(',')
        key, values = items[0], items[1:]
        my_dict.setdefault(key, []).extend(values)
print my_dict
# Out:
# {'': ['0', '1', '2', '3', '4', '5', '6', '7\n'], '2008_008435.jpg': [' bird', '', '', '', '', '"\n'], '2011_001870.jpg': [' bus', ' person', '', '', '', '"\n'], '2010_003329.jpg': [' bottle', '', '', '', '', '"\n'], '2008_001182.jpg': [' person', ' dog', '', '', '', '"\n'], '2008_000003.jpg': [' person', ' train', '', '', '', '"\n'], '2011_001656.jpg': [' horse', '', '', '', '', '"\n'], '2008_000777.jpg': [' person', '', '', '', '', '"\n'], '2010_003857.jpg': [' tvmonitor', '', '', '', '', '"\n'], '2009_000906.jpg': [' car', '', '', '', '', '"\n'], '2009_005279.jpg': [' bus', ' car', ' person', '', '', '"\n'], '2010_004523.jpg': [' person', ' tvmonitor', '', '', '', '"\n'], '2008_003449.jpg': [' boat', '', '', '', '', '"\n'], '2008_001118.jpg': [' train', '', '', '', '', '"\n'], '2008_006481.jpg': [' bird', ' boat', '', '', '', '"\n'], '2009_001888.jpg': [' pottedplant', ' sofa', '', '', '', '"\n'], '2010_003248.jpg': [' person', ' chair', ' diningtable', '', '', '"\n'], '2008_004371
# ...
