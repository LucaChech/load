# %%
### CREATING RANDOMIZATION.CSV
import pandas as pd
import numpy as np
import random
import csv
mypath = 'C:/Users/Nilli Lab/Desktop/'
df = pd.DataFrame.from_csv(mypath + 'Luca/all_images_2.csv')


df.reset_index(drop=False)### CREATING RANDOMIZATION.CSV
import pandas as pd
import numpy as np
import random
import csv
mypath = 'C:/Users/Nilli Lab/Desktop/'
df = pd.DataFrame.from_csv(mypath + 'Luca/all_images_2.csv')


df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# DEFINING TARGET-PRESENT TRIALS
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:### CREATING RANDOMIZATION.CSV
import pandas as pd
import numpy as np
import random
import csv
mypath = 'C:/Users/Nilli Lab/Desktop/'
df = pd.DataFrame.from_csv(mypath + 'Luca/all_images_2.csv')


df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# DEFINING TARGET-PRESENT TRIALS
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 10:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

print len(target_present)
#--------------------
target_present_dict = {key:possible_images_dict[key] for key in target_present}
target_absent_dict = dict(possible_images_dict)
for each in target_present:
    if each in target_absent_dict:
        del target_absent_dict[each]
exp_dict = dict(target_present_dict)
exp_dict.update(target_absent_dict)
#print len(target_present_dict)
#print len(target_absent_dict)
#print len(exp_dict)


for each in target_present_dict:
    target_present_dict[each].append('Target Present')
for each in target_absent_dict:
    absent_question = []
    for ogni in categories:
        if ogni not in target_absent_dict[each]:
            absent_question.append(ogni)
    absent_question = str(np.random.choice(absent_question, 1, replace= False))[2:-2]
    target_absent_dict[each].append(absent_question)
    target_absent_dict[each].append('Target Absent')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level, present_absent):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in exp_dict[element] and present_absent in exp_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <2 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        #print temp
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print len(critical_trials)
         
critical_trial('low','Target Present')
critical_trial('high','Target Present')
critical_trial('low','Target Absent')
critical_trial('high','Target Absent')
print len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    exp_dict[each].append('Critical')
for each in exp_dict:
    if 'Critical' not in exp_dict[each]:
        exp_dict[each].append('Normal')

df = pd.DataFrame.from_dict(exp_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'Luca/randomization_V2.csv')

#for category in categories:
#    i= 0
#    for each in target_absent_dict:
#        
#        if category in target_absent_dict[each][7]:
#            i = i + 1
#    print category, i

all_pics = target_absent_dict.keys() + target_present_dict.keys()
print len(all_pics)
len(all_pics) == len(set(all_pics))
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 10:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

print len(target_present)
#--------------------
target_present_dict = {key:possible_images_dict[key] for key in target_present}
target_absent_dict = dict(possible_images_dict)
for each in target_present:
    if each in target_absent_dict:
        del target_absent_dict[each]
exp_dict = dict(target_present_dict)
exp_dict.update(target_absent_dict)
#print len(target_present_dict)
#print len(target_absent_dict)
#print len(exp_dict)


for each in target_present_dict:
    target_present_dict[each].append('Target Present')
for each in target_absent_dict:
    absent_question = []
    for ogni in categories:
        if ogni not in target_absent_dict[each]:
            absent_question.append(ogni)
    absent_question = str(np.random.choice(absent_question, 1, replace= False))[2:-2]
    target_absent_dict[each].append(absent_question)
    target_absent_dict[each].append('Target Absent')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level, present_absent):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in exp_dict[element] and present_absent in exp_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <2 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        #print temp
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print len(critical_trials)
         
critical_trial('low','Target Present')
critical_trial('high','Target Present')
critical_trial('low','Target Absent')
critical_trial('high','Target Absent')
print len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    exp_dict[each].append('Critical')
for each in exp_dict:
    if 'Critical' not in exp_dict[each]:
        exp_dict[each].append('Normal')

df = pd.DataFrame.from_dict(exp_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'Luca/randomization_V2.csv')

#for category in categories:
#    i= 0
#    for each in target_absent_dict:
#        
#        if category in target_absent_dict[each][7]:
#            i = i + 1
#    print category, i

all_pics = target_absent_dict.keys() + target_present_dict.keys()
print len(all_pics)
len(all_pics) == len(set(all_pics))

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# DEFINING TARGET-PRESENT TRIALS
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:### CREATING RANDOMIZATION.CSV
import pandas as pd
import numpy as np
import random
import csv
mypath = 'C:/Users/Nilli Lab/Desktop/'
df = pd.DataFrame.from_csv(mypath + 'Luca/all_images_2.csv')


df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# DEFINING TARGET-PRESENT TRIALS
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 10:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

print len(target_present)
#--------------------
target_present_dict = {key:possible_images_dict[key] for key in target_present}
target_absent_dict = dict(possible_images_dict)
for each in target_present:
    if each in target_absent_dict:
        del target_absent_dict[each]
exp_dict = dict(target_present_dict)
exp_dict.update(target_absent_dict)
#print len(target_present_dict)
#print len(target_absent_dict)
#print len(exp_dict)


for each in target_present_dict:
    target_present_dict[each].append('Target Present')
for each in target_absent_dict:
    absent_question = []
    for ogni in categories:
        if ogni not in target_absent_dict[each]:
            absent_question.append(ogni)
    absent_question = str(np.random.choice(absent_question, 1, replace= False))[2:-2]
    target_absent_dict[each].append(absent_question)
    target_absent_dict[each].append('Target Absent')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level, present_absent):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in exp_dict[element] and present_absent in exp_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <2 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        #print temp
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print len(critical_trials)
         
critical_trial('low','Target Present')
critical_trial('high','Target Present')
critical_trial('low','Target Absent')
critical_trial('high','Target Absent')
print len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    exp_dict[each].append('Critical')
for each in exp_dict:
    if 'Critical' not in exp_dict[each]:
        exp_dict[each].append('Normal')

df = pd.DataFrame.from_dict(exp_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'Luca/randomization_V2.csv')

#for category in categories:
#    i= 0
#    for each in target_absent_dict:
#        
#        if category in target_absent_dict[each][7]:
#            i = i + 1
#    print category, i

all_pics = target_absent_dict.keys() + target_present_dict.keys()
print len(all_pics)
len(all_pics) == len(set(all_pics))
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 10:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

print len(target_present)
#--------------------
target_present_dict = {key:possible_images_dict[key] for key in target_present}
target_absent_dict = dict(possible_images_dict)
for each in target_present:
    if each in target_absent_dict:
        del target_absent_dict[each]
exp_dict = dict(target_present_dict)
exp_dict.update(target_absent_dict)
#print len(target_present_dict)
#print len(target_absent_dict)
#print len(exp_dict)


for each in target_present_dict:
    target_present_dict[each].append('Target Present')
for each in target_absent_dict:
    absent_question = []
    for ogni in categories:
        if ogni not in target_absent_dict[each]:
            absent_question.append(ogni)
    absent_question = str(np.random.choice(absent_question, 1, replace= False))[2:-2]
    target_absent_dict[each].append(absent_question)
    target_absent_dict[each].append('Target Absent')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level, present_absent):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in exp_dict[element] and present_absent in exp_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <2 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        #print temp
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print len(critical_trials)
         
critical_trial('low','Target Present')
critical_trial('high','Target Present')
critical_trial('low','Target Absent')
critical_trial('high','Target Absent')
print len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    exp_dict[each].append('Critical')
for each in exp_dict:
    if 'Critical' not in exp_dict[each]:
        exp_dict[each].append('Normal')

df = pd.DataFrame.from_dict(exp_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'Luca/randomization_V2.csv')

#for category in categories:
#    i= 0
#    for each in target_absent_dict:
#        
#        if category in target_absent_dict[each][7]:
#            i = i + 1
#    print category, i

all_pics = target_absent_dict.keys() + target_present_dict.keys()
print len(all_pics)
len(all_pics) == len(set(all_pics))
# Out:
# 240
# 24
# 48
# 72
# 96
# True
# 480
# True

# %%
a = [1,2,3]
b= ['01.jpg','02.jpg']
print len(a) == len(set(a))
print len(b) == len(set(b))
# Out:
# True
# True

# %%
# DEFINING BLOCKS
low_present_normal = []
low_present_critical = []
low_absent_normal = []
low_absent_critical = []
high_present_normal = []
high_present_critical = []
high_absent_normal = []
high_absent_critical = []

list_dict = {}
list_dict['low_present_normal'] = low_present_normal
list_dict['low_present_critical'] = low_present_critical
list_dict['low_absent_normal'] = low_absent_normal
list_dict['low_absent_critical'] = low_absent_critical
list_dict['high_present_normal'] = high_present_normal
list_dict['high_present_critical'] = high_present_critical
list_dict['high_absent_normal'] = high_absent_normal
list_dict['high_absent_critical'] = high_absent_critical

def block(load,present_absent, normal_critical,target_list_name):
    target_list = list_dict[target_list_name]
    for each in exp_dict:
        if load in exp_dict[each] and present_absent in exp_dict[each] \
            and normal_critical in exp_dict[each]:
            target_list.append(each)

block('low','Target Present','Normal','low_present_normal')  
block('low','Target Absent','Normal','low_absent_normal')
block('low','Target Present','Critical','low_present_critical')  
block('low','Target Absent','Critical','low_absent_critical')
block('high','Target Present','Normal','high_present_normal')
block('high','Target Present','Critical','high_present_critical')
block('high','Target Absent','Normal','high_absent_normal')
block('high','Target Absent','Critical','high_absent_critical')

print len(low_present_normal), len(low_absent_normal), len(low_present_critical), len(low_absent_critical)
print len(high_present_normal), len(high_absent_normal), len(high_present_critical), len(high_absent_critical)
#--------------------

available_images = exp_dict.keys()
utilized = []

low_present_subset = low_present_normal + low_present_normal
low_absent_subset = low_absent_normal + low_absent_critical
high_present_subset = high_present_normal + high_present_critical
high_absent_subset = high_absent_normal + high_absent_critical
subsets = [low_present_subset, low_absent_subset, high_present_subset, high_absent_subset]
probes_names = []

for subset in subsets:
    for category in categories:
        while True:
            name = str(np.random.choice(subset, 1, replace= False))[2:-2]
            if category in exp_dict[name][8] and name not in probes_names:
                probes_names.append(name)
                break
len(probes_names)
#i = 1
#for each in probes_names:
#    print i,exp_dict[each][6:]
#    i = i +1

probes_names_low_one = []
probes_names_low_two = []
probes_names_low_three = []
probes_names_low_four = []
probes_names_high_one = []
probes_names_high_two = []
probes_names_high_three = []
probes_names_high_four = []
probes_names_used = []

probes_dict = {}
probes_dict['low_one'] = probes_names_low_one
probes_dict['low_two'] = probes_names_low_two
probes_dict['low_three'] = probes_names_low_three
probes_dict['low_four'] = probes_names_low_four
probes_dict['high_one'] = probes_names_high_one
probes_dict['high_two'] = probes_names_high_two
probes_dict['high_three'] = probes_names_high_three
probes_dict['high_four'] = probes_names_high_four



def probes_per_block(load, list_to_append_to):
    global probes_names_used
    target_list = probes_dict[list_to_append_to]
    present_absent = ['Target Present', 'Target Absent']
    for element in present_absent:
        names = []
        while len(names) < 3:
            temp_name = str(np.random.choice(probes_names, 1, replace= False))[2:-2]
            if element in exp_dict[temp_name] and load in exp_dict[temp_name]\
                and temp_name not in names and temp_name not in probes_names_used:
                    names.append(temp_name)
        for each in names:
                target_list.append(each)
                probes_names_used.append(each)
                

probes_per_block('low','low_one')
probes_per_block('low','low_two')
probes_per_block('low','low_three')
probes_per_block('low','low_four')
probes_per_block('high','high_one')
probes_per_block('high','high_two')
probes_per_block('high','high_three')
probes_per_block('high','high_four')

for each in probes_names_low_one:
    print 'low one ', exp_dict[each]
for each in probes_names_low_two:
    print 'low two ', exp_dict[each]
for each in probes_names_low_three:
    print 'low three ', exp_dict[each]
for each in probes_names_low_four:
    print 'low four ', exp_dict[each]
for each in probes_names_high_one:
    print 'high one ', exp_dict[each]
for each in probes_names_high_two:
    print 'high two ', exp_dict[each]
for each in probes_names_high_three:
    print 'high three ', exp_dict[each]
for each in probes_names_high_four:
    print 'high four', exp_dict[each]
#-----------------------------------------------------------

low_one = []
low_two = []
low_three = []
low_four = []
high_one = []
high_two = []
high_three = []
high_four = []


block_dict = {}
block_dict['low_one'] = low_one
block_dict['low_two'] = low_two
block_dict['low_three'] = low_three
block_dict['low_four'] = low_four
block_dict['high_one'] = high_one
block_dict['high_two'] = high_two
block_dict['high_three'] = high_three
block_dict['high_four'] = high_four

building_blocks_list = [low_present_normal, low_absent_normal, low_present_critical,
                       low_absent_critical, high_present_normal, high_absent_normal,
                       high_present_critical, high_absent_critical]
# Out:
# 96 96 24 24
# 96 96 24 24
# low one  [' dog', nan, nan, nan, nan, 11.489301895545001, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# low one  [' pottedplant', nan, nan, nan, nan, 20.58416256718508, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# low one  [' horse', nan, nan, nan, nan, 19.273783114290648, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# low one  [' pottedplant', nan, nan, nan, nan, 19.906276626032106, 'low', ' pottedplant', ' cat', 'Target Absent', 'Normal']
# low one  [' pottedplant', nan, nan, nan, nan, 19.89572011801729, 'low', ' pottedplant', ' car', 'Target Absent', 'Normal']
# low one  [' person', ' boat', nan, nan, nan, 17.69816713203682, 'low', ' boat', ' chair', 'Target Absent', 'Critical']
# low two  [' person', ' boat', nan, nan, nan, 16.65124246053083, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# low two  [' bird', nan, nan, nan, nan, 14.382431817784735, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# ...

# %%
print len(low_present_normal), len(low_absent_normal), len(low_present_critical),\
    len(low_absent_critical)
print len(high_present_normal), len(high_absent_normal), len(high_present_critical), \
    len(high_absent_critical)
# Out:
# 96 96 24 24
# 96 96 24 24

# %%
def counting(probes_names_block):
    normal_present_counter = 0
    normal_absent_counter = 0
    critical_present_counter = 0
    critical_absent_counter = 0
    the_block = probes_dict[probes_names_block]
    for each in the_block:
        if 'Normal' in exp_dict[each] and 'Target Present' in exp_dict[each]:
            normal_present_counter = normal_present_counter + 1
        elif 'Normal' in exp_dict[each] and 'Target Absent' in exp_dict[each]:
            normal_absent_counter = normal_absent_counter + 1
        elif 'Critical' in exp_dict[each] and 'Target Present' in exp_dict[each]:
            critical_present_counter = critical_present_counter + 1
        elif 'Critical' in exp_dict[each] and 'Target Absent' in exp_dict[each]:
            critical_absent_counter = critical_absent_counter + 1
        
    return [normal_present_counter, normal_absent_counter, critical_present_counter,
           critical_absent_counter]
def counting_2(block_name):
    normal_present_counter = 0
    normal_absent_counter = 0
    critical_present_counter = 0
    critical_absent_counter = 0
    block = block_dict[block_name]
    for each in block:
        if 'Normal' in exp_dict[each] and 'Target Present' in exp_dict[each]:
            normal_present_counter = normal_present_counter + 1
        elif 'Normal' in exp_dict[each] and 'Target Absent' in exp_dict[each]:
            normal_absent_counter = normal_absent_counter + 1
        elif 'Critical' in exp_dict[each] and 'Target Present' in exp_dict[each]:
            critical_present_counter = critical_present_counter + 1
        elif 'Critical' in exp_dict[each] and 'Target Absent' in exp_dict[each]:
            critical_absent_counter = critical_absent_counter + 1
    return [normal_present_counter, normal_absent_counter, critical_present_counter,
            critical_absent_counter]

# %%
def blocks_low(block_name):
    global available_images, utilized, exp_dict
    images = []
    temp = []
#-------------------------------------------------------------------------------------------
    while len(temp) < (24 - counting(block_name)[0]):
        image = str(np.random.choice(building_blocks_list[0], 1, replace= False))[2:-2]
        if image not in temp and image not in images and image not in probes_names:
            temp.append(image)
            print image
    for each in temp:
        images.append(each)
        #print exp_dict[each]
    print len(temp)
    print len(images)
    temp = []
#-------------------------------------------------------------------------------------------
    while len(temp) < (24- counting(block_name)[1]):
        image = str(np.random.choice(building_blocks_list[1], 1, replace= False))[2:-2]
        if image not in temp and image not in images and image not in probes_names:
            temp.append(image)
            print image
    for each in temp:
        images.append(each)
        #print exp_dict[each]
    print len(temp)
    print len(images)
    temp = []
#-------------------------------------------------------------------------------------------
    while len(temp) < (6- counting(block_name)[2]):
        image = str(np.random.choice(building_blocks_list[2], 1, replace= False))[2:-2]
        if image not in temp and image not in images and image not in probes_names:
            temp.append(image)
            print image
    for each in temp:
        images.append(each)
        #print exp_dict[each]
    print len(temp)
    print len(images)
    temp = []
#-------------------------------------------------------------------------------------------
    while len(temp) < (6- counting(block_name)[3]):
        image = str(np.random.choice(building_blocks_list[3], 1, replace= False))[2:-2]
        if image not in temp and image not in images and image not in probes_names:
            temp.append(image)
            print image
    for each in temp:
        images.append(each)
        #print exp_dict[each]
    print len(temp)
    print len(images)
    temp = []
#-------------------------------------------------------------------------------------------    
    for image in images:
        utilized.append(image)
        block_dict[block_name].append(image)
    #block_dict[block_name] = images
    for image in utilized:
        for each_list in building_blocks_list:
            if image in each_list:
                each_list.remove(image)

def blocks_high(block_name):
    global available_images, utilized, exp_dict
    images = []
    temp = []
#-------------------------------------------------------------------------------------------
    while len(temp) < (24 - counting(block_name)[0]):
        image = str(np.random.choice(building_blocks_list[4], 1, replace= False))[2:-2]
        if image not in temp and image not in images and image not in probes_names:
            temp.append(image)
            print image
    for each in temp:
        images.append(each)
        #print exp_dict[each]
    print len(temp)
    print len(images)
    temp = []
#-------------------------------------------------------------------------------------------
    while len(temp) < (24- counting(block_name)[1]):
        image = str(np.random.choice(building_blocks_list[5], 1, replace= False))[2:-2]
        if image not in temp and image not in images and image not in probes_names:
            temp.append(image)
            print image
    for each in temp:
        images.append(each)
        #print exp_dict[each]
    print len(temp)
    print len(images)
    temp = []
#-------------------------------------------------------------------------------------------
    while len(temp) < (6- counting(block_name)[2]):
        image = str(np.random.choice(building_blocks_list[6], 1, replace= False))[2:-2]
        if image not in temp and image not in images and image not in probes_names:
            temp.append(image)
            print image
    for each in temp:
        images.append(each)
        #print exp_dict[each]
    print len(temp)
    print len(images)
    temp = []
#-------------------------------------------------------------------------------------------
    while len(temp) < (6- counting(block_name)[3]):
        image = str(np.random.choice(building_blocks_list[7], 1, replace= False))[2:-2]
        if image not in temp and image not in images and image not in probes_names:
            temp.append(image)
            print image
    for each in temp:
        images.append(each)
        #print exp_dict[each]
    print len(temp)
    print len(images)
    temp = []
#-------------------------------------------------------------------------------------------    
    for image in images:
        utilized.append(image)
        block_dict[block_name].append(image)
    #block_dict[block_name] = images
    for image in utilized:
        for each_list in building_blocks_list:
            if image in each_list:
                each_list.remove(image)

blocks_low('low_one')
blocks_low('low_two')
blocks_low('low_three')
blocks_low('low_four')
blocks_high('high_one')
blocks_high('high_two')
blocks_high('high_three')
blocks_high('high_four')
# Out:
# 2010_005257.jpg
# 2010_000073.jpg
# 2008_002379.jpg
# 2008_007012.jpg
# 2008_005467.jpg
# 2008_000777.jpg
# 2009_004713.jpg
# 2008_005443.jpg
# 2010_005409.jpg
# 2010_000447.jpg
# 2010_000750.jpg
# 2009_003127.jpg
# 2008_005345.jpg
# 2010_002990.jpg
# 2009_001746.jpg
# 2010_001731.jpg
# 2010_004231.jpg
# 2010_004311.jpg
# 2009_000647.jpg
# 2009_001782.jpg
# 2009_002374.jpg
# 21
# 21
# 2011_003098.jpg
# 2010_005376.jpg
# 2008_005831.jpg
# 2011_001825.jpg
# 2008_000037.jpg
# 2009_002415.jpg
# 2009_004984.jpg
# 2008_008533.jpg
# 2009_001894.jpg
# 2010_002661.jpg
# 2008_002442.jpg
# 2008_000491.jpg
# 2008_006784.jpg
# 2008_002357.jpg
# 2011_001543.jpg
# 2008_004138.jpg
# 2008_005251.jpg
# 2008_000151.jpg
# 2010_004307.jpg
# 2009_001312.jpg
# 2008_004270.jpg
# 2009_000939.jpg
# 22
# 43
# 2010_000805.jpg
# 2010_003259.jpg
# 2010_005217.jpg
# 2008_000952.jpg
# 2009_004639.jpg
# 2011_001198.jpg
# 6
# 49
# 2008_003135.jpg
# 2008_002145.jpg
# 2008_003838.jpg
# 2008_004036.jpg
# ...

# %%
names = ['low_one', 'low_two', 'low_three', 'low_four', 'high_one', 'high_two', 'high_three', 'high_four']
for name in names:
    print len(block_dict[name]), len(block_dict[name]) == len(set(block_dict[name]))
# Out:
# 54 True
# 54 True
# 54 True
# 54 True
# 54 True
# 54 True
# 54 True
# 54 True

# %%
#print 'low one',counting('low_one')
#print 'low one',counting_2('low_one')
#print 'low one',len(low_one)
#print 'low two',counting('low_two')
#print 'low two',counting_2('low_two')
#print 'low two',len(low_two)
#print 'low three',counting('low_three')
#print 'low three',counting_2('low_three')
#print 'low three',len(low_three)
#print 'low four',counting('low_four')
#print 'low four',counting_2('low_four')
#print 'low four',len(low_four)
#print 'high one',counting('high_one')
#print 'high one',counting_2('high_one')
#print 'high one',len(high_one)
#print 'high two',counting('high_two')
#print 'high two',counting_2('high_two')
#print 'high two',len(high_two)
#print 'high three',counting('high_three')
#print 'high three',counting_2('high_three')
#print 'high three',len(high_three)
#print 'high four',counting('high_four')
#print 'high four',counting_2('high_four')
#print 'high four',len(high_four)

# %%
def constrained_sum_sample_pos(n, total):
    """Return a randomly chosen list of n positive integers summing to total.
    Each such list is equally likely to occur."""
    global sequences_length
    dividers = sorted(random.sample(xrange(1, total), n - 1))
    sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]

# %%
### RANDOMIZING IMAGE SEQUENCE FOR EACH BLOCK

random.shuffle(low_one)
random.shuffle(low_two)
random.shuffle(low_three)
random.shuffle(low_four)
random.shuffle(high_one)
random.shuffle(high_two)
random.shuffle(low_three)
random.shuffle(low_four)

# %%
def block_constructor(block_name):
    block = block_dict[block_name]
    #print block_dict[block_name]
    block = random.sample(block, len(block))
    probes = probes_dict[block_name]
    random.shuffle(probes)
    constrained_sum_sample_pos(6,60)
    acc = 0
    new_list = []
    for i in sequences_length:
        acc = acc + i
        new_list.append(acc - 1)
    print new_list
    for i in range(len(probes)):
        block.insert(new_list[i], probes[i])
        block = block
    return  block, new_list
    #print len(block)
    #print probes
    #for i in new_list:
    #    print block[i]

# %%
#names = ['low_one', 'low_two', 'low_three', 'low_four', 'high_one', 'high_two', 'high_three', 'high_four']
#sequences = ['1','2','3','4','5','6','6','7','8']
#for i in range(len(names)):
#    b,c = block_constructor(names[i])
#    block_dict[names[i]] = b
#    sequences[i] = c
#    for each in c:
#        print exp_dict[b[each]]

# %%
#names = ['low_one', 'low_two', 'low_three', 'low_four', 'high_one', 'high_two', 'high_three', 'high_four']
#for name in names:
#    print len(block_dict[name]), len(block_dict[name]) == len(set(block_dict[name]))

# %%
#%pdb

# %%
low_one, lista_low_one = block_constructor('low_one')
low_two, lista_low_two = block_constructor('low_two')
low_three, lista_low_three = block_constructor('low_three')
low_four, lista_low_four = block_constructor('low_four')
high_one, lista_high_one = block_constructor('high_one')
high_two, lista_high_two = block_constructor('high_two')
high_three, lista_high_three = block_constructor('high_three')
high_four, lista_high_four = block_constructor('high_four')

#print len(low_one), len(low_two), len(low_three), len(low_four), len(high_one), len(high_two), len(high_three), len(high_four)
#MAKE 2ND VERSION!!!
blocks_final = [low_one] + [high_one] + [high_two] + [low_two] + [high_three] + [low_three] + [low_four] + [high_four]
sequences = [lista_low_one] + [lista_high_one] + [lista_high_two] + [lista_low_two] + [lista_high_three] + \
    [lista_low_three] + [lista_low_four] + [lista_high_four]
# Out:
# [15, 18, 33, 37, 51, 59]
# [10, 23, 36, 53, 56, 59]
# [10, 25, 41, 42, 50, 59]
# [1, 21, 26, 34, 42, 59]
# [7, 8, 39, 44, 58, 59]
# [7, 8, 11, 30, 54, 59]
# [3, 26, 31, 38, 50, 59]
# [11, 17, 25, 48, 50, 59]

# %%
for i in range(len(sequences)):
    for element in sequences[i]:
        print sequences[i],exp_dict[blocks_final[i][element]]
# Out:
# [15, 18, 33, 37, 51, 59] [' pottedplant', nan, nan, nan, nan, 19.89572011801729, 'low', ' pottedplant', ' car', 'Target Absent', 'Normal']
# [15, 18, 33, 37, 51, 59] [' horse', nan, nan, nan, nan, 19.273783114290648, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [15, 18, 33, 37, 51, 59] [' person', ' boat', nan, nan, nan, 17.69816713203682, 'low', ' boat', ' chair', 'Target Absent', 'Critical']
# [15, 18, 33, 37, 51, 59] [' dog', nan, nan, nan, nan, 11.489301895545001, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [15, 18, 33, 37, 51, 59] [' pottedplant', nan, nan, nan, nan, 20.58416256718508, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [15, 18, 33, 37, 51, 59] [' pottedplant', nan, nan, nan, nan, 19.906276626032106, 'low', ' pottedplant', ' cat', 'Target Absent', 'Normal']
# [7, 8, 39, 44, 58, 59] [' car', ' dog', nan, nan, nan, 31.13697327795364, 'high', ' car', ' sofa', 'Target Absent', 'Normal']
# ...

# %%
lista = [0,0]
def all_same(items):
    if 0 in items:
        return all(x == items[0] for x in items) 
a = all_same(lista)
print a
# Out:
# True
