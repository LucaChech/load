# %%
### CREATING RANDOMIZATION.CSV
import pandas as pd
import numpy as np
import random
import csv
mypath = ('C:/Users/luca.chech.16/Desktop/Random_probes_last/Luca/')

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                intermediate = []
                break
for each in target_absent:
    absent_list = [category for category in categories if category not in possible_images_dict[each]]
    absent_question = str(np.random.choice(absent_list, 1, replace= False))[2:-2]
    possible_images_dict[each].append(absent_question)
    possible_images_dict[each].append('Target Absent')
    print possible_images_dict[each]

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <3 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print len(critical_trials)
         
critical_trial('low')
critical_trial('high')

print len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')

df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_15.csv')
# Out:
# [' bottle', nan, nan, nan, nan, 20.465741194973702, 'low', ' bottle', ' horse', 'Target Absent']
# [' person', ' bottle', nan, nan, nan, 41.29008547648025, 'high', ' bottle', ' dog', 'Target Absent']
# [' person', ' horse', nan, nan, nan, 19.187546074203674, 'low', ' horse', ' cat', 'Target Absent']
# [' horse', nan, nan, nan, nan, 29.694123468445483, 'high', ' horse', ' car', 'Target Absent']
# [' pottedplant', nan, nan, nan, nan, 16.520476370843983, 'low', ' pottedplant', ' dog', 'Target Absent']
# [' pottedplant', ' person', ' chair', nan, nan, 30.033197364480724, 'high', ' pottedplant', ' horse', 'Target Absent']
# [' dog', nan, nan, nan, nan, 12.202109936274194, 'low', ' dog', ' horse', 'Target Absent']
# [' person', ' dog', nan, nan, nan, 32.959390221443385, 'high', ' dog', ' bottle', 'Target Absent']
# [' cat', nan, nan, nan, nan, 15.633666738732224, 'low', ' cat', ' bird', 'Target Absent']
# [' person', ' sofa', ' cat', nan, nan, 29.514189787401428, 'high', ' cat', ' pottedplant', 'Target Absent']
# [' person', ' sofa', nan, nan, nan, 19.244035875135978, 'low', ' person', ' pottedplant', 'Target Absent']
# [' tvmonitor', ' person', nan, nan, nan, 34.988021861049809, 'high', ' person', ' bottle', 'Target Absent']
# [' aeroplane', nan, nan, nan, nan, 12.091823003636206, 'low', ' aeroplane', ' sofa', 'Target Absent']
# [' person', ' aeroplane', nan, nan, nan, 32.014973550332165, 'high', ' aeroplane', ' chair', 'Target Absent']
# [' car', nan, nan, nan, nan, 18.414503851226357, 'low', ' car', ' horse', 'Target Absent']
# [' person', ' bicycle', ' car', nan, nan, 31.577906396402632, 'high', ' car', ' bird', 'Target Absent']
# [' person', ' chair', nan, nan, nan, 19.77080876077715, 'low', ' chair', ' aeroplane', 'Target Absent']
# [' tvmonitor', ' chair', ' person', nan, nan, 30.893338341187519, 'high', ' chair', ' bottle', 'Target Absent']
# [' sofa', nan, nan, nan, nan, 16.300022926435631, 'low', ' sofa', ' boat', 'Target Absent']
# [' sofa', ' person', nan, nan, nan, 31.463677231105994, 'high', ' sofa', ' bird', 'Target Absent']
# [' bird', nan, nan, nan, nan, 13.959294123390947, 'low', ' bird', ' chair', 'Target Absent']
# [' bird', nan, nan, nan, nan, 32.06509585553637, 'high', ' bird', ' horse', 'Target Absent']
# [' boat', nan, nan, nan, nan, 19.048974616120489, 'low', ' boat', ' person', 'Target Absent']
# [' boat', nan, nan, nan, nan, 30.07547411972709, 'high', ' boat', ' horse', 'Target Absent']
# 36
# 72
# True

# %%
#Defininfg blocks 
probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
print len(normal_no_probe)
# Out:
# 371

# %%
#%pdb

# %%
def block_low():
# Pick 3 present probes and 3 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 3:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 3 <= len(probes_per_block) < 6:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    for n in probes_per_block[0:3]:
        present_used.append(n)
    for n in probes_per_block[3:]:
        absent_used.append(n)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (9-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 54 - (9 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(14):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                new_list = [n for n in new_list if 'No Target' not in possible_images_dict[block[n]]]
                print new_list
                print len(new_list)
                return  block, new_list
                break
#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(15,60)
    print 'len(block): ',len(block)
#print new_list
#for n in range(len(new_list)):
#    print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list

# %%
def block_high():
# Pick 3 present probes and 3 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 3:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 3 <= len(probes_per_block) < 6:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    for n in probes_per_block[0:3]:
        present_used.append(n)
    for n in probes_per_block[3:]:
        absent_used.append(n)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (9-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 54 - (9 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(14):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                new_list = [n for n in new_list if 'No Target' not in possible_images_dict[block[n]]]
                print new_list
                print len(new_list)
                return  block, new_list
                break
#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(15,60)
    print 'len(block): ',len(block)
#print new_list
#for n in range(len(new_list)):
#    print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list

# %%
low_one, lista_low_one = block_low()
low_two, lista_low_two = block_low()
low_three, lista_low_three = block_low()
low_four, lista_low_four = block_low()
high_one, lista_high_one = block_high()
high_two, lista_high_two = block_high()
high_three, lista_high_three = block_high()
high_four, lista_high_four = block_high()
# Out:
# Present Used:  3
# Absent Used  3
# Critical probes counter:  1
# [' person', ' boat', nan, nan, nan, 19.194815950035931, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' dog', ' bottle', nan, nan, nan, 18.86070334209068, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 19.02871535870197, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', nan, nan, nan, 19.615269866751539, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' sofa', nan, nan, nan, nan, 20.506510529107977, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 17.13857605003491, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 18.608778484059602, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 16.985442334643722, 'low', ' chair', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  46
# len(to_insert):  14
# len(block):  0
# Liste scartate:  74583
# New List:  [1, 4, 7, 13, 18, 23, 26, 34, 38, 41, 44, 47, 51, 54, 59]
# [1, 4, 7, 13, 34, 54]
# 6
# len(block):  60
# Normal used: 46
# ---------------------------------------------------
# Present Used:  6
# Absent Used  6
# Critical probes counter:  1
# [' dog', nan, nan, nan, nan, 18.01939274540068, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 17.331558080669492, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' chair', ' diningtable', nan, nan, nan, 19.904514483492576, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 18.590456430582357, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 20.832521553254701, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 19.234401336670953, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' car', nan, nan, 20.934599857700228, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 15.024239426791327, 'low', ' cat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  92
# len(to_insert):  14
# len(block):  60
# Liste scartate:  19253
# New List:  [0, 3, 8, 11, 14, 17, 21, 24, 27, 32, 36, 41, 50, 55, 59]
# [8, 14, 17, 21, 24, 32]
# 6
# len(block):  60
# Normal used: 92
# ---------------------------------------------------
# Present Used:  9
# Absent Used  9
# Critical probes counter:  1
# [' sofa', ' dog', nan, nan, nan, 16.142562620916582, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' chair', ' cat', nan, nan, nan, 16.578513977418865, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' chair', ' dog', nan, nan, nan, 14.969141972913766, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' chair', nan, nan, nan, 20.224139544493688, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' sheep', ' person', nan, nan, nan, 14.023326890096051, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 20.084302537016953, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 18.100322166714271, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 9.9553684007073908, 'low', ' chair', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  138
# len(to_insert):  14
# len(block):  60
# Liste scartate:  35594
# New List:  [1, 6, 9, 13, 18, 21, 27, 31, 36, 39, 43, 48, 53, 56, 59]
# [1, 6, 18, 27, 31, 39]
# 6
# len(block):  60
# Normal used: 138
# ---------------------------------------------------
# Present Used:  12
# Absent Used  12
# Critical probes counter:  2
# [' pottedplant', ' sofa', nan, nan, nan, 18.96772267222304, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 20.837768549275857, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 9.5768677087381189, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 20.659438390323604, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 20.131411086471946, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' car', ' dog', ' person', nan, nan, 21.020159211351668, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 20.012722206539959, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  185
# len(to_insert):  13
# len(block):  60
# Liste scartate:  18045
# New List:  [4, 7, 10, 13, 19, 23, 26, 29, 36, 40, 44, 47, 50, 53, 59]
# [7, 10, 13, 29, 47, 50]
# 6
# len(block):  60
# Normal used: 185
# ---------------------------------------------------
# Present Used:  15
# Absent Used  15
# Critical probes counter:  0
# [' bird', nan, nan, nan, nan, 28.667065204437929, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' car', ' chair', ' bicycle', ' person', 30.133244112833108, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' person', ' bicycle', ' sofa', nan, 38.218905954735177, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 29.246976174425782, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' motorbike', ' car', ' bus', 30.65978031477821, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 29.547306113597852, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' car', ' horse', ' person', nan, nan, 32.996121172096558, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 31.413857547274947, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' dog', ' car', nan, 31.410853470588716, 'high', ' dog', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  230
# len(to_insert):  15
# len(block):  60
# Liste scartate:  28605
# New List:  [1, 4, 7, 13, 16, 20, 24, 27, 34, 37, 42, 46, 49, 55, 59]
# [1, 4, 13, 16, 37, 49]
# 6
# len(block):  60
# Normal used: 230
# ---------------------------------------------------
# Present Used:  18
# Absent Used  18
# Critical probes counter:  0
# [' person', ' chair', ' diningtable', nan, nan, 32.011827288051073, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', nan, nan, nan, 32.384814141647539, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' sofa', nan, nan, nan, 31.119805313465481, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 28.723636647719449, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 30.80608913442844, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 30.657341600370845, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 31.779858819461175, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' person', nan, nan, 29.723255523994041, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' dog', ' bottle', nan, nan, nan, 41.997144703218737, 'high', ' dog', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  275
# len(to_insert):  15
# len(block):  60
# Liste scartate:  101421
# New List:  [3, 8, 13, 16, 19, 22, 25, 28, 33, 39, 42, 46, 51, 54, 59]
# [3, 22, 25, 28, 42, 59]
# 6
# len(block):  60
# Normal used: 275
# ---------------------------------------------------
# Present Used:  21
# Absent Used  21
# Critical probes counter:  3
# [' chair', ' bottle', nan, nan, nan, 33.568151144703606, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', ' diningtable', nan, nan, 33.022066804988405, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 33.854821153874802, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 28.99541660743073, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 30.954010715704413, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 31.842660584206165, 'high', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  323
# len(to_insert):  12
# len(block):  60
# Liste scartate:  39868
# New List:  [0, 4, 10, 14, 17, 21, 27, 30, 34, 37, 41, 44, 52, 56, 59]
# [0, 10, 17, 21, 30, 41]
# 6
# len(block):  60
# Normal used: 323
# ---------------------------------------------------
# Present Used:  24
# Absent Used  24
# Critical probes counter:  3
# [' bird', nan, nan, nan, nan, 29.742786682331467, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' car', ' dog', ' person', nan, nan, 29.763552134631723, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' aeroplane', ' boat', nan, nan, nan, 29.287349444649571, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' sofa', ' diningtable', ' person', nan, nan, 40.507103369084113, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', ' bottle', nan, 32.261510274211375, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' bicycle', ' car', nan, 33.367152749801264, 'high', ' car', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  371
# len(to_insert):  12
# len(block):  60
# Liste scartate:  31920
# New List:  [0, 3, 11, 14, 18, 25, 30, 33, 37, 40, 45, 48, 51, 55, 59]
# [0, 11, 14, 18, 40, 48]
# 6
# len(block):  60
# Normal used: 371
# ---------------------------------------------------

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 371
# 371
# True
# 24
# 24
# True
# 24
# 24
# True
# 72
# 61
# 11

# %%
block_dict = {}
block_dict['low_one'] = low_one
block_dict['low_two'] = low_two
block_dict['low_three'] = low_three
block_dict['low_four'] = low_four
block_dict['high_one'] = high_one
block_dict['high_two'] = high_two
block_dict['high_three'] = high_three
block_dict['high_four'] = high_four

# %%
block_dict['low_one']
print len(block_dict['low_one'])
# Out:
# 60
