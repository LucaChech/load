# %%
### CREATING RANDOMIZATION.CSV
import pandas as pd
import numpy as np
import random
import csv
#mypath = ('C:/Users/luca.chech.16/Desktop/Random_probes_last/Luca/')
mypath = 'C:/Users/KeK/OneDrive - University College London/Random_probes_last/Luca/'

df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')


df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                intermediate = []
                break
for each in target_absent:
    absent_list = [category for category in categories if category not in possible_images_dict[each]]
    absent_question = str(np.random.choice(absent_list, 1, replace= False))[2:-2]
    possible_images_dict[each].append(absent_question)
    possible_images_dict[each].append('Target Absent')
    print possible_images_dict[each]

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <3 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print len(critical_trials)
         
critical_trial('low')
critical_trial('high')

print len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')

df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_1.csv')


#Defininfg blocks 
probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
print len(normal_no_probe)

#%pdb

def block_low():
# Pick 3 present probes and 3 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 3:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 3 <= len(probes_per_block) < 6:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    for n in probes_per_block[0:3]:
        present_used.append(n)
    for n in probes_per_block[3:]:
        absent_used.append(n)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (9-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 54 - (9 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(len(to_insert)):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                new_list = [n for n in new_list if 'No Target' not in possible_images_dict[block[n]]]
                print 'Probes Position: ', new_list
                print len(new_list)
                return  block, new_list
                break
#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(15,60)
    print 'len(block): ',len(block)
#print new_list
#for n in range(len(new_list)):
#    print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list
    

def block_high():
# Pick 3 present probes and 3 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 3:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 3 <= len(probes_per_block) < 6:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    for n in probes_per_block[0:3]:
        present_used.append(n)
    for n in probes_per_block[3:]:
        absent_used.append(n)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (9-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 54 - (9 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(len(to_insert)):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                new_list = [n for n in new_list if 'No Target' not in possible_images_dict[block[n]]]
                print new_list
                print len(new_list)
                return  block, new_list
                break
#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(15,60)
    print 'len(block): ',len(block)
#print new_list
#for n in range(len(new_list)):
#    print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list
    

low_one, lista_low_one = block_low()
low_two, lista_low_two = block_low()
low_three, lista_low_three = block_low()
low_four, lista_low_four = block_low()
high_one, lista_high_one = block_high()
high_two, lista_high_two = block_high()
high_three, lista_high_three = block_high()
high_four, lista_high_four = block_high()

print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter



block_dict = {}
block_dict['low_one'] = low_one
block_dict['low_two'] = low_two
block_dict['low_three'] = low_three
block_dict['low_four'] = low_four
block_dict['high_one'] = high_one
block_dict['high_two'] = high_two
block_dict['high_three'] = high_three
block_dict['high_four'] = high_four

block_dict['low_one']
print len(block_dict['low_one'])
print low_one
df.to_csv(mypath + 'randomization_new.csv')
# Out:
# [' bottle', nan, nan, nan, nan, 14.593336877343006, 'low', ' bottle', ' dog', 'Target Absent']
# [' person', ' bottle', ' diningtable', nan, nan, 34.072917550349175, 'high', ' bottle', ' pottedplant', 'Target Absent']
# [' horse', nan, nan, nan, nan, 19.789006070959889, 'low', ' horse', ' bottle', 'Target Absent']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', ' cat', 'Target Absent']
# [' pottedplant', nan, nan, nan, nan, 19.321308873350848, 'low', ' pottedplant', ' aeroplane', 'Target Absent']
# [' pottedplant', ' person', ' motorbike', nan, nan, 34.416005433315377, 'high', ' pottedplant', ' bottle', 'Target Absent']
# [' dog', ' cat', nan, nan, nan, 21.247629460380587, 'low', ' dog', ' bird', 'Target Absent']
# [' pottedplant', ' dog', nan, nan, nan, 29.851834352354174, 'high', ' dog', ' bottle', 'Target Absent']
# [' cat', nan, nan, nan, nan, 20.60608553782437, 'low', ' cat', ' sofa', 'Target Absent']
# [' pottedplant', ' tvmonitor', ' cat', nan, nan, 31.67044719842205, 'high', ' cat', ' dog', 'Target Absent']
# [' person', ' chair', nan, nan, nan, 20.224139544493688, 'low', ' person', ' pottedplant', 'Target Absent']
# [' pottedplant', ' person', ' train', nan, nan, 29.323493073246585, 'high', ' person', ' dog', 'Target Absent']
# [' aeroplane', nan, nan, nan, nan, 13.513291905037027, 'low', ' aeroplane', ' car', 'Target Absent']
# [' person', ' aeroplane', nan, nan, nan, 30.242937209299559, 'high', ' aeroplane', ' dog', 'Target Absent']
# [' car', nan, nan, nan, nan, 18.597981681742631, 'low', ' car', ' aeroplane', 'Target Absent']
# [' bus', ' person', ' car', nan, nan, 31.167936969796557, 'high', ' car', ' bottle', 'Target Absent']
# [' chair', ' diningtable', nan, nan, nan, 18.117802795100609, 'low', ' chair', ' bird', 'Target Absent']
# [' person', ' chair', ' diningtable', ' bottle', nan, 33.734529116802769, 'high', ' chair', ' pottedplant', 'Target Absent']
# [' sofa', ' cat', nan, nan, nan, 18.288477341906038, 'low', ' sofa', ' person', 'Target Absent']
# [' sofa', ' chair', ' bottle', ' person', nan, 29.051766794986211, 'high', ' sofa', ' boat', 'Target Absent']
# [' bird', nan, nan, nan, nan, 15.253871492883167, 'low', ' bird', ' cat', 'Target Absent']
# [' bird', nan, nan, nan, nan, 29.594597886254714, 'high', ' bird', ' horse', 'Target Absent']
# [' boat', nan, nan, nan, nan, 19.685752299806754, 'low', ' boat', ' car', 'Target Absent']
# [' bus', ' boat', ' car', nan, nan, 34.403914620094966, 'high', ' boat', ' bird', 'Target Absent']
# 36
# 72
# True
# 370
# Present Used:  3
# Absent Used  3
# Critical probes counter:  2
# [' dog', nan, nan, nan, nan, 19.993102773679155, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 20.465741194973702, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 16.456101242175052, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' sofa', ' chair', nan, nan, nan, 19.836491630222174, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 16.142562620916582, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 10.236635760901883, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 19.239146135217897, 'low', ' bird', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  47
# len(to_insert):  13
# len(block):  0
# Liste scartate:  33887
# New List:  [0, 7, 10, 14, 22, 25, 29, 32, 37, 41, 44, 47, 50, 55, 59]
# Probes Position:  [0, 7, 22, 29, 41, 50]
# 6
# len(block):  60
# Normal used: 47
# ---------------------------------------------------
# Present Used:  6
# Absent Used  6
# Critical probes counter:  1
# [' chair', ' dog', nan, nan, nan, 13.836710152206384, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 16.846336579249186, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 20.393526602090205, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 20.306835318139004, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 19.188834185415878, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 17.13857605003491, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 20.074715872568312, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 19.030178152384888, 'low', ' car', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  93
# len(to_insert):  14
# len(block):  60
# Liste scartate:  48810
# New List:  [5, 8, 11, 15, 18, 22, 27, 31, 34, 37, 41, 46, 53, 56, 59]
# Probes Position:  [8, 11, 15, 18, 27, 53]
# 6
# len(block):  60
# Normal used: 93
# ---------------------------------------------------
# Present Used:  9
# Absent Used  9
# Critical probes counter:  2
# [' aeroplane', nan, nan, nan, nan, 12.53657278412077, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' dog', ' bottle', nan, nan, nan, 18.86070334209068, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' sofa', nan, nan, nan, 20.216263522932969, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 8.1712447406174693, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 19.24976137409617, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 9.9553684007073926, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 19.096237359535362, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  140
# len(to_insert):  13
# len(block):  60
# Liste scartate:  12410
# New List:  [1, 4, 11, 15, 18, 22, 25, 29, 32, 35, 39, 47, 53, 57, 59]
# Probes Position:  [1, 4, 11, 22, 47, 53]
# 6
# len(block):  60
# Normal used: 140
# ---------------------------------------------------
# Present Used:  12
# Absent Used  12
# Critical probes counter:  2
# [' bird', nan, nan, nan, nan, 13.644417789905445, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 20.084302537016953, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' person', nan, nan, nan, nan, 20.358449022039405, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 19.912301015287291, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' chair', ' cat', nan, nan, nan, 17.570654058012458, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', nan, nan, nan, 17.242843490790587, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 9.1563902861608657, 'low', ' car', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  187
# len(to_insert):  13
# len(block):  60
# Liste scartate:  8311
# New List:  [0, 4, 10, 13, 19, 23, 28, 31, 35, 39, 42, 47, 55, 58, 59]
# Probes Position:  [13, 19, 23, 28, 39, 55]
# 6
# len(block):  60
# Normal used: 187
# ---------------------------------------------------
# Present Used:  15
# Absent Used  15
# Critical probes counter:  0
# [' sofa', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 33.937775623898794, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 30.95304328989037, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 29.354458493580452, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 29.270464835358208, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' dog', nan, 34.099790178372324, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', ' diningtable', ' tvmonitor', 29.247483266365705, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' chair', nan, nan, nan, 34.966628065768532, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 31.520687613930374, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 31.397027824172856, 'high', ' bird', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  232
# len(to_insert):  15
# len(block):  60
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-5f03bf1313dc> in <module>()
#     323 low_three, lista_low_three = block_low()
#     324 low_four, lista_low_four = block_low()
# --> 325 high_one, lista_high_one = block_high()
#     326 high_two, lista_high_two = block_high()
#     327 high_three, lista_high_three = block_high()
#
# <ipython-input-1-5f03bf1313dc> in block_high()
#     304 #-----------------------------------------------------------------------------
#     305     print 'len(block): ',len(block)
# --> 306     constrained_sum_sample_pos_adding_criticals(15,60)
#     307     print 'len(block): ',len(block)
#     308 #print new_list
#
# <ipython-input-1-5f03bf1313dc> in constrained_sum_sample_pos_adding_criticals(n, total)
#     287             diff = []
#     288             for i in range(len(to_insert)):
# --> 289                 diff.append(new_list[i+1] - new_list[i])
#     290             liste_scartate = liste_scartate + 1
#     291             if 1 not in diff and 2 not in diff:
#
# IndexError: list index out of range

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')


df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                intermediate = []
                break
for each in target_absent:
    absent_list = [category for category in categories if category not in possible_images_dict[each]]
    absent_question = str(np.random.choice(absent_list, 1, replace= False))[2:-2]
    possible_images_dict[each].append(absent_question)
    possible_images_dict[each].append('Target Absent')
    print possible_images_dict[each]

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <3 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print len(critical_trials)
         
critical_trial('low')
critical_trial('high')

print len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')

df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_2.csv')


#Defininfg blocks 
probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
print len(normal_no_probe)

#%pdb

def block_low():
# Pick 3 present probes and 3 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 3:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 3 <= len(probes_per_block) < 6:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    for n in probes_per_block[0:3]:
        present_used.append(n)
    for n in probes_per_block[3:]:
        absent_used.append(n)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (9-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 54 - (9 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(14):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                new_list = [n for n in new_list if 'No Target' not in possible_images_dict[block[n]]]
                print new_list
                print len(new_list)
                return  block, new_list
                break
#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(15,60)
    print 'len(block): ',len(block)
#print new_list
#for n in range(len(new_list)):
#    print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list
    

def block_high():
# Pick 3 present probes and 3 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 3:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 3 <= len(probes_per_block) < 6:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    for n in probes_per_block[0:3]:
        present_used.append(n)
    for n in probes_per_block[3:]:
        absent_used.append(n)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (9-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 54 - (9 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(14):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                new_list = [n for n in new_list if 'No Target' not in possible_images_dict[block[n]]]
                print new_list
                print len(new_list)
                return  block, new_list
                break
#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(15,60)
    print 'len(block): ',len(block)
#print new_list
#for n in range(len(new_list)):
#    print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list
    

low_five, lista_low_five = block_low()
low_six, lista_low_six = block_low()
low_seven, lista_low_seven = block_low()
low_eight, lista_low_eight = block_low()
high_five, lista_high_five = block_high()
high_six, lista_high_six = block_high()
high_seven, lista_high_seven = block_high()
high_eight, lista_high_eight = block_high()

print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter



block_dict = {}
block_dict['low_five'] = low_five
block_dict['low_six'] = low_six
block_dict['low_seven'] = low_seven
block_dict['low_eight'] = low_eight
block_dict['high_five'] = high_five
block_dict['high_six'] = high_six
block_dict['high_seven'] = high_seven
block_dict['high_eight'] = high_eight

block_dict['low_eight']
print len(block_dict['low_eight'])
print low_one

# %%
df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_15.csv')

# %%
blocks_names_list = [low_one, low_two, low_three, low_four, low_five, low_six, low_seven, low_eight,
                        high_one, high_two, high_three, high_four, high_five, high_six, high_seven, high_eight]
blocks_sequences_list = [lista_low_one, lista_low_two, lista_low_three, lista_low_four, lista_low_five, lista_low_six, lista_low_seven, lista_low_eight,
                        lista_high_one, lista_high_two, lista_high_three, lista_high_four, lista_high_five, lista_high_six, lista_high_seven, lista_high_eight]
with open('filename.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(blocks_names_list[i])
        #wr.writerow(blocks_sequences_list[i])

with open('filename2.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        #wr.writerow(blocks_names_list[i])
        wr.writerow(blocks_sequences_list[i])

#-----------------------------------------------
blocks_final = low_one + low_two + low_three +low_four + low_five + low_six + low_seven + low_eight + high_one + high_two + high_three + high_four + high_five + high_six + high_seven + high_eight 
print blocks_final == set(blocks_final)
from shutil import copyfile

for each in blocks_final:
    #print each
    copyfile(mypath + 'JPEGImages/'+each, 
            mypath + 'exp_images/'+each)

# %%
for each in blocks_sequences_list:
    print each

for each in low_one:
    print possible_images_dict[each]
