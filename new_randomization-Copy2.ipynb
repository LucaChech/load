# %%
import pandas as pd
import numpy as np
import random
import csv
#%pdb
mypath = ('E:/OneDrive - University College London/Random_probes_last/Luca/')
#mypath = 'C:/Users/KeK/OneDrive - University College London/Random_probes_last/Luca/'

# %%
import random
probe_series = []
critical_series = []

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <2 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  24
# len(critical_trials):  48

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 362
# -------------------

# %%
def block_low_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (6-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (6 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_low_2():
# Pick 5 present probes and 4 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (6-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (6 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (6-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (6 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_2():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (6-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (6 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
block_low_1()
block_high_1()
block_high_2()
block_low_2()
block_high_1()
block_low_1()
block_low_2()
block_high_2()
# Out:
# [' car', nan, nan, nan, nan, 19.030178152384888, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 12.729033444663401, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' person', ' boat', nan, nan, nan, 16.651242460530831, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 13.685993646696661, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 19.570662256086155, 'low', ' dog', ' person', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 20.529451477248333, 'low', ' person', ' car', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 18.597981681742631, 'low', ' car', ' sofa', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 10.236635760901883, 'low', ' cat', ' person', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 14.343346792518373, 'low', ' bird', ' dog', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 15.253871492883167, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 19.096237359535362, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 16.146154777978307, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' cat', nan, nan, nan, 20.139877805151375, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' person', nan, nan, nan, nan, 19.675826944132364, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 17.331558080669492, 'low', ' boat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  45
# Normal used: 45
# ---------------------------------------------------
# [' tvmonitor', ' sofa', ' bottle', ' person', nan, 29.608026491553932, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' boat', ' cow', nan, nan, nan, 29.659407124334731, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' bird', nan, nan, nan, 29.657389969329227, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' sofa', nan, nan, nan, nan, 30.980311145262871, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 37.710719022258736, 'high', ' pottedplant', ' bottle', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 35.94715000296663, 'high', ' boat', ' sofa', 'Target Absent', 'Normal']
# [' pottedplant', ' car', nan, nan, nan, 30.612693177580176, 'high', ' car', ' chair', 'Target Absent', 'Normal']
# [' person', ' chair', nan, nan, nan, 33.312072728004267, 'high', ' chair', ' car', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 29.639296311219638, 'high', ' person', ' aeroplane', 'Target Absent', 'Normal']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  0
# List of critical trials without probe:
# [' car', ' bicycle', ' motorbike', nan, nan, 29.67801392295739, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 31.779858819461175, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' diningtable', ' bottle', nan, 28.939513311425664, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 31.310599923489761, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' diningtable', ' bottle', nan, nan, 38.972642388939022, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', ' tvmonitor', nan, 29.464580095555625, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  90
# Normal used: 90
# ---------------------------------------------------
# [' pottedplant', ' chair', ' diningtable', nan, nan, 34.177834247690619, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 29.084159041893106, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 32.660663951184652, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' car', ' aeroplane', nan, nan, nan, 37.93755165753997, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 33.64739800555661, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' sofa', ' chair', ' person', nan, nan, 34.561608236038907, 'high', ' person', ' boat', 'Target Absent', 'Normal']
# [' horse', nan, nan, nan, nan, 29.28123750737463, 'high', ' horse', ' pottedplant', 'Target Absent', 'Normal']
# [' pottedplant', ' tvmonitor', ' chair', ' sofa', nan, 35.636604201684968, 'high', ' pottedplant', ' horse', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 29.547306113597852, 'high', ' aeroplane', ' dog', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  0
# List of critical trials without probe:
# [' dog', nan, nan, nan, nan, 28.961816980758506, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 30.48036175658957, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' sofa', ' chair', ' diningtable', nan, nan, 30.346694199538174, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' diningtable', ' bottle', nan, nan, 36.414042237667729, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', ' sofa', nan, 30.916466766406522, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  135
# Normal used: 135
# ---------------------------------------------------
# [' car', ' aeroplane', nan, nan, nan, 16.811685000593723, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 18.057825283941515, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 17.167558060312739, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 20.413253715842107, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 20.757885363436266, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 20.885583923700768, 'low', ' horse', ' chair', 'Target Absent', 'Normal']
# [' chair', ' dog', nan, nan, nan, 13.836710152206384, 'low', ' chair', ' horse', 'Target Absent', 'Critical']
# [' car', ' person', nan, nan, nan, 21.05297682386103, 'low', ' car', ' boat', 'Target Absent', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 19.906276626032106, 'low', ' pottedplant', ' dog', 'Target Absent', 'Normal']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  1
# List of critical trials without probe:
# [' sofa', nan, nan, nan, nan, 15.77924938689554, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 18.000361854332464, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', nan, nan, 20.561279009327844, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 17.731696099482228, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' bottle', ' dog', ' diningtable', nan, nan, 21.034646910874567, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  181
# Normal used: 181
# ---------------------------------------------------
# [' dog', ' bottle', nan, nan, nan, 41.997144703218737, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 30.39404844580157, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 30.30670761720366, 'high', ' cat', ' cat', 'Target Present', 'Critical']
# [' tvmonitor', ' chair', ' bottle', nan, nan, 32.179769175040214, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 31.520687613930374, 'high', ' pottedplant', ' cat', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 29.270464835358208, 'high', ' car', ' person', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' motorbike', nan, nan, 34.416005433315377, 'high', ' pottedplant', ' bird', 'Target Absent', 'Normal']
# [' car', ' cat', nan, nan, nan, 33.462184790468179, 'high', ' cat', ' horse', 'Target Absent', 'Normal']
# [' person', ' chair', ' motorbike', nan, nan, 31.7742392698987, 'high', ' chair', ' dog', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  1
# List of critical trials without probe:
# [' person', ' dog', ' car', nan, nan, 33.09488500291814, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' bird', ' boat', nan, nan, 31.913409738647122, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 29.608002755298447, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 29.822033003804499, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' aeroplane', ' boat', nan, nan, nan, 29.287349444649571, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  227
# Normal used: 227
# ---------------------------------------------------
# [' aeroplane', nan, nan, nan, nan, 19.095995737676468, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' bottle', ' cat', nan, nan, nan, 21.259829756421425, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 19.54050687002545, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 18.608803704733788, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' sofa', nan, nan, nan, 19.244035875135978, 'low', ' sofa', ' bird', 'Target Absent', 'Normal']
# [' chair', nan, nan, nan, nan, 20.508881463934923, 'low', ' chair', ' car', 'Target Absent', 'Normal']
# [' horse', nan, nan, nan, nan, 20.9577483152902, 'low', ' horse', ' bottle', 'Target Absent', 'Normal']
# [' chair', ' diningtable', nan, nan, nan, 20.735145690609489, 'low', ' chair', ' sofa', 'Target Absent', 'Normal']
# [' sofa', nan, nan, nan, nan, 17.055909373433501, 'low', ' sofa', ' aeroplane', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  0
# List of critical trials without probe:
# [' pottedplant', ' sofa', ' chair', nan, nan, 18.511887801846186, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 13.411221053439446, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 15.633666738732224, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 20.712898768714968, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 15.731962722166625, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 14.593336877343006, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  272
# Normal used: 272
# ---------------------------------------------------
# [' pottedplant', nan, nan, nan, nan, 21.217669901647128, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 20.138559565527519, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 20.189150337053679, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' bottle', nan, nan, nan, nan, 20.465741194973702, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' sofa', ' person', nan, nan, nan, 20.983298059388602, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 18.981598230274844, 'low', ' dog', ' horse', 'Target Absent', 'Normal']
# [' person', ' motorbike', nan, nan, nan, 19.446156687645161, 'low', ' person', ' cat', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 20.850125265290927, 'low', ' cat', ' pottedplant', 'Target Absent', 'Normal']
# [' chair', ' cat', nan, nan, nan, 19.7971714164348, 'low', ' cat', ' boat', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 18.837863956276628, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' sofa', nan, nan, nan, nan, 19.892389695505386, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 16.197035825449316, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 19.789006070959889, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 16.520476370843983, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 14.300464691841311, 'low', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  317
# Normal used: 317
# ---------------------------------------------------
# [' tvmonitor', ' chair', nan, nan, nan, 34.776343714473143, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' bottle', ' diningtable', nan, 36.665582819269645, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' car', ' dog', ' person', nan, nan, 29.763552134631723, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 32.014973550332165, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' sofa', ' chair', nan, nan, nan, 32.351474210019695, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 29.246976174425782, 'high', ' cat', ' car', 'Target Absent', 'Normal']
# [' person', ' boat', nan, nan, nan, 30.384187271419634, 'high', ' boat', ' sofa', 'Target Absent', 'Normal']
# [' person', ' chair', ' bottle', nan, nan, 33.381115383499548, 'high', ' chair', ' boat', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 30.130898028557787, 'high', ' horse', ' person', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  0
# List of critical trials without probe:
# [' chair', ' bird', ' diningtable', nan, nan, 29.361755720318889, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' train', nan, nan, 29.10600637597598, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' bicycle', ' car', nan, 33.367152749801264, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 35.669132455550852, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 34.047146905280911, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' dog', nan, nan, nan, 29.851834352354174, 'high', ' dog', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  362
# Normal used: 362
# ---------------------------------------------------

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
print probes[0]
# Out:
# ['2009_004594.jpg', '2009_004225.jpg', '2009_004888.jpg', '2008_005735.jpg', '2008_005123.jpg', '2009_003530.jpg', '2010_004014.jpg', '2010_004175.jpg', '2010_001159.jpg']

# %%
probe_series = []
critical_series = []

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
def building_the_church(w):
    while True:    
        while True:
            a = [random.randint(1,60) for r in xrange(9)]
            if sum(a) <= 60:
                break
        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]
        print 'new_list_1: ',new_list_1
        #print sum(a)

        while True:
            a = [random.randint(1,60) for r in xrange(6-w)]
            if sum(a) <= 60 and 1 not in a:
                break
        new_list_2 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_2.append(acc)
        new_list_2 = [n - 1 for n in new_list_2]
        print 'new_list_2: ', new_list_2
        #print sum(a)

        container = []
        for i in new_list_2:
            sequence = [i, i+1, i+2]
            #print sequence
            for element in sequence:
                if element in new_list_1:
                    container.append(element)
        #print len(container)
        print new_list_2
        if len(container) == 0:
            break
    print '---------------------------'
    probe_series.append(new_list_1)
    critical_series.append(new_list_2)
    print new_list_1
    print new_list_2
    return

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [1, 10, 11, 18, 23, 34, 45, 46, 51]
# new_list_2:  [22, 37, 44, 47, 51, 58]
# [22, 37, 44, 47, 51, 58]
# new_list_1:  [0, 4, 10, 17, 21, 29, 35, 36, 50]
# new_list_2:  [4, 12, 28, 33, 35, 43]
# [4, 12, 28, 33, 35, 43]
# new_list_1:  [17, 20, 29, 32, 33, 35, 43, 49, 55]
# new_list_2:  [2, 11, 15, 20, 33, 38]
# [2, 11, 15, 20, 33, 38]
# new_list_1:  [6, 8, 16, 21, 25, 33, 34, 47, 54]
# new_list_2:  [14, 18, 27, 35, 53, 55]
# [14, 18, 27, 35, 53, 55]
# new_list_1:  [3, 16, 18, 24, 27, 38, 42, 51, 55]
# new_list_2:  [4, 15, 28, 34, 40, 45]
# [4, 15, 28, 34, 40, 45]
# new_list_1:  [6, 12, 32, 38, 39, 41, 49, 51, 55]
# new_list_2:  [2, 4, 36, 41, 45, 54]
# [2, 4, 36, 41, 45, 54]
# new_list_1:  [4, 12, 16, 18, 33, 39, 41, 44, 51]
# new_list_2:  [17, 22, 33, 39, 48, 53]
# [17, 22, 33, 39, 48, 53]
# new_list_1:  [5, 7, 9, 16, 25, 38, 42, 45, 47]
# new_list_2:  [3, 7, 12, 19, 32, 37]
# [3, 7, 12, 19, 32, 37]
# new_list_1:  [0, 7, 18, 20, 22, 35, 41, 51, 57]
# new_list_2:  [3, 7, 14, 26, 40, 46]
# [3, 7, 14, 26, 40, 46]
# new_list_1:  [2, 8, 10, 23, 24, 28, 43, 44, 57]
# new_list_2:  [6, 9, 18, 21, 47, 53]
# [6, 9, 18, 21, 47, 53]
# new_list_1:  [1, 5, 7, 8, 40, 50, 55, 56, 58]
# new_list_2:  [2, 12, 15, 22, 24, 36]
# [2, 12, 15, 22, 24, 36]
# ---------------------------
# [1, 5, 7, 8, 40, 50, 55, 56, 58]
# [2, 12, 15, 22, 24, 36]
# new_list_1:  [4, 6, 11, 14, 26, 28, 45, 47, 52]
# new_list_2:  [8, 18, 24, 38, 47, 49]
# [8, 18, 24, 38, 47, 49]
# new_list_1:  [2, 10, 15, 16, 43, 49, 50, 53, 59]
# new_list_2:  [5, 43, 48, 50, 52, 56]
# [5, 43, 48, 50, 52, 56]
# new_list_1:  [12, 15, 16, 17, 35, 41, 56, 57, 58]
# new_list_2:  [14, 26, 30, 32, 34, 47]
# [14, 26, 30, 32, 34, 47]
# new_list_1:  [4, 8, 17, 21, 22, 33, 36, 42, 43]
# new_list_2:  [23, 32, 36, 44, 46, 54]
# [23, 32, 36, 44, 46, 54]
# new_list_1:  [9, 10, 11, 13, 14, 18, 22, 40, 46]
# new_list_2:  [5, 15, 29, 40, 48, 59]
# [5, 15, 29, 40, 48, 59]
# new_list_1:  [1, 3, 6, 15, 23, 28, 30, 32, 59]
# new_list_2:  [3, 28, 30, 41, 45, 50]
# [3, 28, 30, 41, 45, 50]
# new_list_1:  [6, 13, 15, 21, 27, 30, 52, 55, 56]
# new_list_2:  [6, 18, 36, 45, 47, 54]
# [6, 18, 36, 45, 47, 54]
# new_list_1:  [4, 12, 25, 27, 37, 40, 46, 49, 58]
# new_list_2:  [4, 16, 23, 25, 41, 55]
# [4, 16, 23, 25, 41, 55]
# new_list_1:  [1, 4, 18, 19, 38, 39, 46, 49, 57]
# new_list_2:  [5, 22, 32, 38, 47, 58]
# [5, 22, 32, 38, 47, 58]
# new_list_1:  [4, 6, 10, 12, 13, 32, 51, 56, 58]
# new_list_2:  [17, 23, 28, 47, 54, 59]
# [17, 23, 28, 47, 54, 59]
# new_list_1:  [2, 4, 21, 38, 45, 49, 52, 57, 59]
# new_list_2:  [17, 26, 37, 41, 48, 50]
# [17, 26, 37, 41, 48, 50]
# new_list_1:  [6, 10, 18, 20, 23, 28, 41, 42, 50]
# new_list_2:  [6, 11, 23, 25, 27, 34]
# [6, 11, 23, 25, 27, 34]
# new_list_1:  [5, 10, 16, 21, 29, 30, 31, 35, 55]
# new_list_2:  [19, 21, 27, 29, 43, 56]
# [19, 21, 27, 29, 43, 56]
# new_list_1:  [6, 13, 15, 16, 23, 28, 37, 45, 59]
# new_list_2:  [15, 19, 42, 44, 47, 57]
# [15, 19, 42, 44, 47, 57]
# new_list_1:  [1, 21, 22, 30, 43, 44, 46, 51, 57]
# new_list_2:  [5, 18, 31, 33, 37, 47]
# [5, 18, 31, 33, 37, 47]
# ---------------------------
# [1, 21, 22, 30, 43, 44, 46, 51, 57]
# [5, 18, 31, 33, 37, 47]
# new_list_1:  [11, 18, 23, 26, 27, 28, 31, 38, 48]
# new_list_2:  [2, 4, 28, 50, 54, 57]
# [2, 4, 28, 50, 54, 57]
# new_list_1:  [1, 3, 6, 11, 17, 26, 31, 36, 37]
# new_list_2:  [26, 34, 48, 52, 54, 58]
# [26, 34, 48, 52, 54, 58]
# new_list_1:  [14, 15, 17, 18, 22, 31, 40, 43, 50]
# new_list_2:  [17, 28, 32, 50, 53, 55]
# [17, 28, 32, 50, 53, 55]
# new_list_1:  [4, 19, 26, 28, 33, 36, 40, 46, 48]
# new_list_2:  [3, 22, 30, 32, 49, 59]
# [3, 22, 30, 32, 49, 59]
# new_list_1:  [5, 12, 16, 20, 27, 37, 38, 42, 45]
# new_list_2:  [9, 18, 33, 39, 46, 52]
# [9, 18, 33, 39, 46, 52]
# new_list_1:  [0, 9, 10, 23, 26, 27, 43, 45, 49]
# new_list_2:  [5, 12, 19, 40, 52, 55]
# [5, 12, 19, 40, 52, 55]
# ---------------------------
# [0, 9, 10, 23, 26, 27, 43, 45, 49]
# [5, 12, 19, 40, 52, 55]
# new_list_1:  [12, 19, 21, 31, 35, 39, 42, 43, 53]
# new_list_2:  [10, 24, 29, 44, 51]
# [10, 24, 29, 44, 51]
# new_list_1:  [6, 7, 9, 10, 19, 37, 42, 49, 50]
# new_list_2:  [6, 14, 41, 54, 58]
# [6, 14, 41, 54, 58]
# new_list_1:  [6, 10, 13, 27, 42, 45, 46, 58, 59]
# new_list_2:  [5, 13, 33, 49, 52]
# [5, 13, 33, 49, 52]
# new_list_1:  [2, 10, 13, 15, 38, 45, 47, 55, 57]
# new_list_2:  [17, 22, 28, 50, 55]
# [17, 22, 28, 50, 55]
# new_list_1:  [7, 22, 27, 37, 41, 46, 49, 51, 57]
# new_list_2:  [3, 8, 20, 31, 54]
# [3, 8, 20, 31, 54]
# new_list_1:  [5, 11, 12, 27, 31, 33, 48, 49, 50]
# new_list_2:  [9, 23, 34, 45, 48]
# [9, 23, 34, 45, 48]
# new_list_1:  [4, 13, 17, 29, 36, 44, 45, 53, 55]
# new_list_2:  [14, 17, 30, 36, 50]
# [14, 17, 30, 36, 50]
# new_list_1:  [5, 19, 23, 24, 25, 32, 33, 49, 50]
# new_list_2:  [9, 16, 23, 35, 39]
# [9, 16, 23, 35, 39]
# new_list_1:  [5, 9, 28, 31, 32, 45, 49, 56, 58]
# new_list_2:  [9, 39, 46, 53, 59]
# [9, 39, 46, 53, 59]
# new_list_1:  [8, 23, 26, 30, 33, 36, 54, 55, 57]
# new_list_2:  [2, 5, 21, 26, 45]
# [2, 5, 21, 26, 45]
# new_list_1:  [13, 15, 18, 20, 23, 29, 30, 32, 35]
# new_list_2:  [15, 20, 32, 39, 48]
# [15, 20, 32, 39, 48]
# new_list_1:  [7, 10, 13, 27, 40, 43, 47, 54, 58]
# new_list_2:  [3, 19, 27, 50, 55]
# [3, 19, 27, 50, 55]
# new_list_1:  [2, 29, 32, 34, 40, 41, 51, 53, 59]
# new_list_2:  [1, 4, 14, 25, 31]
# [1, 4, 14, 25, 31]
# new_list_1:  [8, 11, 18, 22, 25, 28, 29, 37, 41]
# new_list_2:  [5, 15, 33, 35, 49]
# [5, 15, 33, 35, 49]
# new_list_1:  [5, 18, 19, 24, 46, 48, 50, 51, 52]
# new_list_2:  [5, 29, 31, 38, 54]
# [5, 29, 31, 38, 54]
# new_list_1:  [7, 8, 23, 29, 33, 37, 39, 46, 52]
# new_list_2:  [2, 11, 21, 32, 47]
# [2, 11, 21, 32, 47]
# new_list_1:  [8, 13, 21, 26, 29, 36, 41, 43, 55]
# new_list_2:  [10, 19, 27, 39, 44]
# [10, 19, 27, 39, 44]
# new_list_1:  [10, 15, 17, 19, 21, 29, 38, 57, 58]
# new_list_2:  [2, 15, 32, 51, 55]
# [2, 15, 32, 51, 55]
# new_list_1:  [1, 4, 11, 13, 39, 44, 45, 48, 49]
# new_list_2:  [10, 18, 29, 42, 46]
# [10, 18, 29, 42, 46]
# new_list_1:  [4, 5, 8, 17, 27, 34, 44, 47, 58]
# new_list_2:  [6, 25, 43, 53, 55]
# [6, 25, 43, 53, 55]
# new_list_1:  [1, 2, 14, 35, 36, 46, 48, 52, 58]
# new_list_2:  [10, 20, 25, 27, 29]
# [10, 20, 25, 27, 29]
# ---------------------------
# [1, 2, 14, 35, 36, 46, 48, 52, 58]
# [10, 20, 25, 27, 29]
# new_list_1:  [0, 7, 16, 18, 30, 31, 35, 36, 47]
# new_list_2:  [1, 17, 31, 52, 54]
# [1, 17, 31, 52, 54]
# new_list_1:  [0, 11, 25, 30, 33, 34, 50, 52, 58]
# new_list_2:  [16, 29, 47, 55, 59]
# [16, 29, 47, 55, 59]
# new_list_1:  [15, 20, 23, 25, 31, 34, 40, 44, 52]
# new_list_2:  [18, 21, 25, 34, 54]
# [18, 21, 25, 34, 54]
# new_list_1:  [8, 9, 18, 23, 31, 33, 34, 47, 57]
# new_list_2:  [7, 30, 32, 49, 51]
# [7, 30, 32, 49, 51]
# new_list_1:  [3, 6, 25, 33, 39, 40, 55, 57, 58]
# new_list_2:  [12, 18, 25, 46, 56]
# [12, 18, 25, 46, 56]
# new_list_1:  [2, 14, 32, 35, 38, 41, 49, 56, 59]
# new_list_2:  [2, 24, 35, 53, 56]
# [2, 24, 35, 53, 56]
# new_list_1:  [23, 27, 34, 35, 39, 47, 48, 58, 59]
# new_list_2:  [20, 27, 38, 43, 48]
# [20, 27, 38, 43, 48]
# new_list_1:  [7, 22, 30, 34, 38, 41, 47, 49, 56]
# new_list_2:  [17, 29, 35, 39, 48]
# [17, 29, 35, 39, 48]
# new_list_1:  [2, 4, 5, 6, 8, 18, 31, 46, 53]
# new_list_2:  [29, 33, 36, 51, 59]
# [29, 33, 36, 51, 59]
# new_list_1:  [5, 11, 18, 22, 23, 31, 52, 55, 57]
# new_list_2:  [16, 18, 26, 37, 58]
# [16, 18, 26, 37, 58]
# new_list_1:  [4, 7, 23, 32, 37, 42, 43, 47, 48]
# new_list_2:  [7, 19, 23, 43, 49]
# [7, 19, 23, 43, 49]
# new_list_1:  [6, 7, 8, 24, 29, 30, 33, 38, 51]
# new_list_2:  [5, 22, 27, 30, 36]
# [5, 22, 27, 30, 36]
# new_list_1:  [14, 17, 22, 32, 43, 47, 49, 54, 58]
# new_list_2:  [3, 26, 35, 49, 56]
# [3, 26, 35, 49, 56]
# new_list_1:  [0, 4, 15, 27, 39, 41, 50, 56, 58]
# new_list_2:  [6, 9, 40, 55, 59]
# [6, 9, 40, 55, 59]
# new_list_1:  [1, 9, 10, 22, 27, 34, 41, 51, 56]
# new_list_2:  [16, 25, 28, 43, 51]
# [16, 25, 28, 43, 51]
# new_list_1:  [5, 6, 20, 27, 36, 41, 43, 50, 54]
# new_list_2:  [6, 15, 25, 39, 42]
# [6, 15, 25, 39, 42]
# new_list_1:  [4, 20, 21, 28, 41, 44, 48, 51, 57]
# new_list_2:  [5, 24, 46, 52, 55]
# [5, 24, 46, 52, 55]
# new_list_1:  [10, 13, 17, 25, 35, 41, 43, 46, 54]
# new_list_2:  [6, 26, 31, 44, 53]
# [6, 26, 31, 44, 53]
# new_list_1:  [0, 9, 16, 25, 38, 46, 53, 54, 57]
# new_list_2:  [5, 14, 19, 57, 59]
# [5, 14, 19, 57, 59]
# new_list_1:  [2, 6, 16, 31, 35, 50, 52, 53, 57]
# new_list_2:  [9, 28, 45, 57, 59]
# [9, 28, 45, 57, 59]
# new_list_1:  [1, 5, 6, 26, 34, 48, 55, 58, 59]
# new_list_2:  [2, 13, 18, 43, 52]
# [2, 13, 18, 43, 52]
# ---------------------------
# [1, 5, 6, 26, 34, 48, 55, 58, 59]
# [2, 13, 18, 43, 52]
# new_list_1:  [0, 13, 18, 20, 40, 41, 43, 45, 49]
# new_list_2:  [12, 20, 23, 25, 43, 47]
# [12, 20, 23, 25, 43, 47]
# new_list_1:  [0, 4, 6, 15, 16, 26, 28, 46, 51]
# new_list_2:  [5, 9, 18, 28, 32, 55]
# [5, 9, 18, 28, 32, 55]
# new_list_1:  [7, 20, 31, 34, 35, 49, 51, 52, 54]
# new_list_2:  [1, 9, 23, 31, 48, 51]
# [1, 9, 23, 31, 48, 51]
# new_list_1:  [4, 14, 24, 25, 27, 31, 40, 46, 58]
# new_list_2:  [3, 12, 19, 28, 34, 48]
# [3, 12, 19, 28, 34, 48]
# new_list_1:  [4, 6, 8, 26, 27, 32, 39, 47, 59]
# new_list_2:  [1, 33, 35, 43, 51, 59]
# [1, 33, 35, 43, 51, 59]
# new_list_1:  [0, 4, 16, 17, 25, 28, 34, 41, 49]
# new_list_2:  [3, 7, 10, 16, 21, 41]
# [3, 7, 10, 16, 21, 41]
# new_list_1:  [4, 9, 19, 26, 35, 37, 39, 41, 54]
# new_list_2:  [5, 7, 13, 33, 37, 56]
# [5, 7, 13, 33, 37, 56]
# new_list_1:  [18, 23, 25, 28, 36, 38, 48, 53, 59]
# new_list_2:  [7, 14, 27, 47, 51, 54]
# [7, 14, 27, 47, 51, 54]
# new_list_1:  [21, 24, 32, 38, 44, 47, 49, 51, 54]
# new_list_2:  [6, 15, 38, 42, 46, 53]
# [6, 15, 38, 42, 46, 53]
# new_list_1:  [7, 11, 13, 14, 16, 28, 37, 43, 51]
# new_list_2:  [3, 10, 15, 25, 38, 54]
# [3, 10, 15, 25, 38, 54]
# new_list_1:  [1, 14, 17, 31, 39, 40, 45, 50, 55]
# new_list_2:  [15, 27, 35, 38, 48, 54]
# [15, 27, 35, 38, 48, 54]
# new_list_1:  [5, 22, 24, 28, 30, 40, 41, 46, 50]
# new_list_2:  [6, 9, 13, 18, 40, 48]
# [6, 9, 13, 18, 40, 48]
# new_list_1:  [7, 13, 20, 25, 31, 39, 40, 45, 54]
# new_list_2:  [6, 11, 22, 42, 45, 52]
# [6, 11, 22, 42, 45, 52]
# new_list_1:  [2, 6, 8, 11, 17, 18, 35, 46, 55]
# new_list_2:  [4, 10, 12, 23, 36, 43]
# [4, 10, 12, 23, 36, 43]
# new_list_1:  [8, 10, 21, 23, 26, 34, 40, 49, 57]
# new_list_2:  [7, 23, 33, 38, 47, 54]
# [7, 23, 33, 38, 47, 54]
# new_list_1:  [2, 7, 12, 15, 18, 29, 42, 58, 59]
# new_list_2:  [5, 11, 21, 38, 51, 58]
# [5, 11, 21, 38, 51, 58]
# new_list_1:  [2, 30, 34, 39, 40, 43, 50, 56, 59]
# new_list_2:  [9, 15, 17, 19, 25, 40]
# [9, 15, 17, 19, 25, 40]
# new_list_1:  [1, 6, 11, 20, 32, 41, 47, 48, 51]
# new_list_2:  [5, 15, 22, 25, 53, 55]
# [5, 15, 22, 25, 53, 55]
# new_list_1:  [5, 6, 10, 14, 15, 33, 39, 50, 58]
# new_list_2:  [4, 14, 32, 44, 48, 50]
# [4, 14, 32, 44, 48, 50]
# new_list_1:  [3, 4, 7, 8, 29, 36, 42, 47, 52]
# new_list_2:  [2, 4, 13, 42, 44, 47]
# [2, 4, 13, 42, 44, 47]
# new_list_1:  [6, 7, 10, 28, 29, 33, 36, 39, 54]
# new_list_2:  [15, 30, 37, 48, 50, 59]
# [15, 30, 37, 48, 50, 59]
# new_list_1:  [9, 10, 12, 19, 21, 33, 47, 51, 59]
# new_list_2:  [5, 7, 19, 30, 54, 57]
# [5, 7, 19, 30, 54, 57]
# new_list_1:  [5, 7, 10, 22, 25, 35, 44, 51, 59]
# new_list_2:  [8, 19, 22, 30, 32, 39]
# [8, 19, 22, 30, 32, 39]
# new_list_1:  [3, 7, 13, 29, 35, 36, 45, 54, 56]
# new_list_2:  [7, 21, 24, 27, 36, 50]
# [7, 21, 24, 27, 36, 50]
# new_list_1:  [0, 7, 10, 17, 40, 42, 44, 50, 53]
# new_list_2:  [5, 13, 39, 46, 49, 58]
# [5, 13, 39, 46, 49, 58]
# new_list_1:  [0, 10, 17, 23, 35, 41, 42, 54, 56]
# new_list_2:  [2, 28, 44, 48, 51, 53]
# [2, 28, 44, 48, 51, 53]
# new_list_1:  [4, 5, 9, 12, 15, 16, 44, 50, 54]
# new_list_2:  [23, 31, 36, 39, 43, 51]
# [23, 31, 36, 39, 43, 51]
# new_list_1:  [2, 9, 13, 23, 26, 28, 35, 43, 56]
# new_list_2:  [19, 21, 42, 46, 48, 57]
# [19, 21, 42, 46, 48, 57]
# new_list_1:  [3, 11, 13, 21, 32, 34, 36, 47, 55]
# new_list_2:  [2, 9, 12, 42, 48, 57]
# [2, 9, 12, 42, 48, 57]
# new_list_1:  [0, 6, 7, 10, 17, 21, 33, 44, 58]
# new_list_2:  [9, 16, 18, 29, 40, 56]
# [9, 16, 18, 29, 40, 56]
# new_list_1:  [4, 13, 19, 24, 28, 45, 53, 56, 58]
# new_list_2:  [23, 27, 30, 34, 36, 49]
# [23, 27, 30, 34, 36, 49]
# new_list_1:  [0, 6, 9, 13, 32, 44, 45, 57, 59]
# new_list_2:  [1, 5, 28, 35, 47, 57]
# [1, 5, 28, 35, 47, 57]
# new_list_1:  [4, 15, 18, 25, 27, 33, 45, 53, 59]
# new_list_2:  [2, 4, 14, 31, 37, 39]
# [2, 4, 14, 31, 37, 39]
# new_list_1:  [23, 33, 37, 39, 45, 49, 50, 57, 58]
# new_list_2:  [12, 16, 22, 33, 38, 59]
# [12, 16, 22, 33, 38, 59]
# new_list_1:  [17, 21, 43, 45, 47, 54, 57, 58, 59]
# new_list_2:  [3, 9, 15, 29, 32, 35]
# [3, 9, 15, 29, 32, 35]
# new_list_1:  [10, 23, 26, 41, 45, 47, 49, 53, 54]
# new_list_2:  [8, 14, 22, 28, 33, 38]
# [8, 14, 22, 28, 33, 38]
# new_list_1:  [0, 5, 14, 22, 31, 36, 49, 55, 57]
# new_list_2:  [9, 32, 38, 50, 53, 59]
# [9, 32, 38, 50, 53, 59]
# new_list_1:  [14, 23, 25, 32, 33, 47, 53, 54, 59]
# new_list_2:  [2, 17, 25, 32, 38, 45]
# [2, 17, 25, 32, 38, 45]
# new_list_1:  [0, 6, 14, 32, 39, 49, 54, 57, 58]
# new_list_2:  [2, 17, 19, 34, 41, 47]
# [2, 17, 19, 34, 41, 47]
# new_list_1:  [9, 17, 23, 25, 29, 41, 44, 51, 55]
# new_list_2:  [5, 12, 31, 40, 43, 52]
# [5, 12, 31, 40, 43, 52]
# new_list_1:  [0, 3, 7, 8, 19, 20, 24, 29, 42]
# new_list_2:  [4, 13, 17, 31, 33, 57]
# [4, 13, 17, 31, 33, 57]
# new_list_1:  [2, 10, 13, 20, 39, 42, 47, 52, 58]
# new_list_2:  [1, 8, 16, 28, 41, 58]
# [1, 8, 16, 28, 41, 58]
# new_list_1:  [3, 6, 26, 32, 35, 36, 48, 52, 55]
# new_list_2:  [7, 17, 41, 43, 47, 59]
# [7, 17, 41, 43, 47, 59]
# new_list_1:  [0, 12, 17, 23, 25, 43, 46, 48, 59]
# new_list_2:  [2, 12, 29, 33, 47, 49]
# [2, 12, 29, 33, 47, 49]
# new_list_1:  [0, 13, 18, 31, 33, 34, 45, 46, 49]
# new_list_2:  [8, 19, 22, 36, 38, 59]
# [8, 19, 22, 36, 38, 59]
# ---------------------------
# [0, 13, 18, 31, 33, 34, 45, 46, 49]
# [8, 19, 22, 36, 38, 59]
# new_list_1:  [0, 1, 12, 14, 19, 35, 43, 45, 53]
# new_list_2:  [6, 8, 25, 36, 40, 42]
# [6, 8, 25, 36, 40, 42]
# new_list_1:  [11, 21, 23, 24, 27, 32, 39, 41, 59]
# new_list_2:  [1, 22, 24, 26, 39, 58]
# [1, 22, 24, 26, 39, 58]
# new_list_1:  [2, 19, 22, 28, 37, 39, 42, 51, 55]
# new_list_2:  [18, 23, 26, 29, 38, 54]
# [18, 23, 26, 29, 38, 54]
# new_list_1:  [6, 20, 27, 32, 33, 42, 44, 45, 51]
# new_list_2:  [17, 35, 42, 50, 54, 59]
# [17, 35, 42, 50, 54, 59]
# new_list_1:  [5, 19, 20, 26, 28, 34, 35, 37, 39]
# new_list_2:  [14, 27, 29, 36, 52, 59]
# [14, 27, 29, 36, 52, 59]
# new_list_1:  [7, 9, 16, 24, 34, 36, 43, 55, 59]
# new_list_2:  [3, 15, 17, 19, 23, 55]
# [3, 15, 17, 19, 23, 55]
# new_list_1:  [0, 1, 2, 12, 22, 31, 42, 43, 51]
# new_list_2:  [12, 16, 32, 35, 38, 45]
# [12, 16, 32, 35, 38, 45]
# new_list_1:  [1, 13, 20, 29, 32, 42, 46, 51, 57]
# new_list_2:  [5, 12, 31, 38, 41, 47]
# [5, 12, 31, 38, 41, 47]
# new_list_1:  [3, 6, 9, 12, 15, 21, 25, 29, 35]
# new_list_2:  [3, 7, 10, 30, 33, 44]
# [3, 7, 10, 30, 33, 44]
# new_list_1:  [0, 30, 35, 36, 47, 50, 51, 55, 58]
# new_list_2:  [28, 40, 42, 44, 48, 55]
# [28, 40, 42, 44, 48, 55]
# new_list_1:  [8, 16, 20, 22, 27, 30, 36, 38, 49]
# new_list_2:  [8, 14, 25, 29, 39, 59]
# [8, 14, 25, 29, 39, 59]
# new_list_1:  [2, 4, 15, 16, 37, 41, 43, 47, 54]
# new_list_2:  [10, 16, 18, 46, 53, 58]
# [10, 16, 18, 46, 53, 58]
# new_list_1:  [5, 13, 14, 23, 31, 36, 41, 54, 59]
# new_list_2:  [9, 15, 25, 47, 50, 52]
# [9, 15, 25, 47, 50, 52]
# new_list_1:  [4, 8, 19, 20, 25, 29, 40, 46, 48]
# new_list_2:  [4, 8, 14, 32, 44, 54]
# [4, 8, 14, 32, 44, 54]
# new_list_1:  [4, 13, 17, 22, 23, 30, 31, 37, 39]
# new_list_2:  [22, 33, 35, 45, 48, 57]
# [22, 33, 35, 45, 48, 57]
# new_list_1:  [0, 5, 18, 32, 41, 43, 46, 49, 54]
# new_list_2:  [14, 16, 18, 21, 26, 30]
# [14, 16, 18, 21, 26, 30]
# new_list_1:  [2, 6, 13, 17, 25, 28, 30, 42, 51]
# new_list_2:  [2, 6, 15, 45, 49, 51]
# [2, 6, 15, 45, 49, 51]
# new_list_1:  [4, 5, 7, 17, 30, 35, 36, 39, 46]
# new_list_2:  [9, 32, 38, 49, 55, 57]
# [9, 32, 38, 49, 55, 57]
# new_list_1:  [2, 3, 18, 24, 30, 31, 34, 52, 55]
# new_list_2:  [10, 33, 41, 52, 54, 57]
# [10, 33, 41, 52, 54, 57]
# new_list_1:  [5, 7, 8, 17, 25, 30, 35, 44, 46]
# new_list_2:  [1, 3, 10, 23, 29, 58]
# [1, 3, 10, 23, 29, 58]
# new_list_1:  [9, 11, 16, 17, 19, 24, 43, 49, 51]
# new_list_2:  [2, 10, 14, 28, 35, 52]
# [2, 10, 14, 28, 35, 52]
# new_list_1:  [6, 9, 10, 21, 31, 36, 37, 48, 57]
# new_list_2:  [4, 21, 42, 46, 51, 58]
# [4, 21, 42, 46, 51, 58]
# new_list_1:  [6, 8, 10, 13, 31, 38, 39, 41, 42]
# new_list_2:  [4, 8, 14, 27, 30, 45]
# [4, 8, 14, 27, 30, 45]
# new_list_1:  [0, 7, 10, 18, 38, 43, 45, 49, 57]
# new_list_2:  [4, 15, 34, 46, 53, 57]
# [4, 15, 34, 46, 53, 57]
# new_list_1:  [4, 6, 11, 12, 16, 20, 25, 33, 59]
# new_list_2:  [8, 17, 34, 44, 47, 58]
# [8, 17, 34, 44, 47, 58]
# new_list_1:  [0, 2, 8, 25, 27, 49, 52, 54, 58]
# new_list_2:  [17, 30, 41, 48, 52, 54]
# [17, 30, 41, 48, 52, 54]
# new_list_1:  [1, 2, 12, 16, 26, 31, 34, 39, 48]
# new_list_2:  [13, 16, 23, 34, 38, 46]
# [13, 16, 23, 34, 38, 46]
# new_list_1:  [16, 28, 29, 34, 37, 42, 49, 51, 55]
# new_list_2:  [4, 20, 22, 30, 35, 53]
# [4, 20, 22, 30, 35, 53]
# new_list_1:  [1, 2, 22, 24, 25, 39, 51, 52, 58]
# new_list_2:  [5, 12, 18, 21, 27, 39]
# [5, 12, 18, 21, 27, 39]
# new_list_1:  [1, 3, 6, 22, 23, 34, 45, 46, 51]
# new_list_2:  [2, 17, 19, 34, 42, 47]
# [2, 17, 19, 34, 42, 47]
# new_list_1:  [6, 13, 23, 26, 35, 38, 42, 50, 51]
# new_list_2:  [9, 11, 41, 44, 52, 57]
# [9, 11, 41, 44, 52, 57]
# new_list_1:  [8, 10, 11, 21, 26, 43, 47, 52, 55]
# new_list_2:  [1, 14, 16, 21, 40, 45]
# [1, 14, 16, 21, 40, 45]
# new_list_1:  [0, 7, 9, 14, 24, 35, 38, 51, 56]
# new_list_2:  [3, 15, 18, 24, 49, 51]
# [3, 15, 18, 24, 49, 51]
# new_list_1:  [2, 8, 10, 13, 38, 40, 41, 50, 59]
# new_list_2:  [3, 8, 12, 26, 47, 49]
# [3, 8, 12, 26, 47, 49]
# new_list_1:  [0, 9, 10, 15, 16, 17, 39, 40, 53]
# new_list_2:  [7, 27, 38, 42, 52, 58]
# [7, 27, 38, 42, 52, 58]
# new_list_1:  [1, 11, 14, 24, 28, 29, 36, 39, 49]
# new_list_2:  [4, 10, 21, 30, 32, 42]
# [4, 10, 21, 30, 32, 42]
# new_list_1:  [2, 5, 20, 21, 28, 30, 37, 53, 54]
# new_list_2:  [8, 24, 34, 43, 46, 53]
# [8, 24, 34, 43, 46, 53]
# new_list_1:  [1, 15, 19, 33, 35, 45, 51, 52, 54]
# new_list_2:  [3, 22, 32, 36, 40, 46]
# [3, 22, 32, 36, 40, 46]
# new_list_1:  [12, 19, 21, 28, 33, 37, 39, 45, 55]
# new_list_2:  [4, 15, 18, 24, 38, 42]
# [4, 15, 18, 24, 38, 42]
# new_list_1:  [6, 10, 27, 28, 29, 34, 41, 46, 52]
# new_list_2:  [5, 7, 18, 21, 50, 58]
# [5, 7, 18, 21, 50, 58]
# new_list_1:  [4, 14, 18, 21, 36, 37, 45, 51, 54]
# new_list_2:  [10, 18, 20, 40, 47, 51]
# [10, 18, 20, 40, 47, 51]
# new_list_1:  [0, 1, 7, 12, 17, 32, 54, 55, 57]
# new_list_2:  [8, 16, 23, 32, 37, 56]
# [8, 16, 23, 32, 37, 56]
# new_list_1:  [4, 7, 12, 17, 22, 24, 32, 34, 44]
# new_list_2:  [9, 13, 34, 38, 48, 57]
# [9, 13, 34, 38, 48, 57]
# new_list_1:  [7, 11, 15, 34, 39, 45, 48, 49, 52]
# new_list_2:  [12, 16, 19, 24, 35, 57]
# [12, 16, 19, 24, 35, 57]
# ---------------------------
# [7, 11, 15, 34, 39, 45, 48, 49, 52]
# [12, 16, 19, 24, 35, 57]
# new_list_1:  [20, 32, 33, 35, 50, 54, 57, 58, 59]
# new_list_2:  [8, 17, 28, 35, 42, 56]
# [8, 17, 28, 35, 42, 56]
# new_list_1:  [5, 15, 20, 27, 37, 43, 51, 53, 59]
# new_list_2:  [11, 20, 25, 36, 44, 56]
# [11, 20, 25, 36, 44, 56]
# new_list_1:  [9, 14, 15, 25, 27, 28, 29, 44, 46]
# new_list_2:  [5, 8, 13, 30, 33, 36]
# [5, 8, 13, 30, 33, 36]
# new_list_1:  [3, 11, 14, 19, 23, 24, 41, 45, 57]
# new_list_2:  [3, 8, 12, 18, 44, 50]
# [3, 8, 12, 18, 44, 50]
# new_list_1:  [9, 10, 14, 17, 48, 49, 52, 56, 59]
# new_list_2:  [3, 46, 48, 51, 55, 57]
# [3, 46, 48, 51, 55, 57]
# new_list_1:  [7, 8, 10, 12, 15, 34, 53, 54, 59]
# new_list_2:  [9, 12, 23, 37, 42, 49]
# [9, 12, 23, 37, 42, 49]
# new_list_1:  [4, 9, 10, 18, 37, 38, 49, 50, 53]
# new_list_2:  [2, 6, 23, 29, 32, 42]
# [2, 6, 23, 29, 32, 42]
# new_list_1:  [1, 11, 14, 19, 20, 37, 39, 41, 44]
# new_list_2:  [1, 5, 34, 39, 51, 57]
# [1, 5, 34, 39, 51, 57]
# new_list_1:  [8, 24, 34, 35, 40, 46, 47, 49, 59]
# new_list_2:  [11, 18, 22, 25, 29, 39]
# [11, 18, 22, 25, 29, 39]
# new_list_1:  [4, 13, 27, 29, 36, 48, 54, 56, 57]
# new_list_2:  [1, 4, 45, 48, 50, 55]
# [1, 4, 45, 48, 50, 55]
# new_list_1:  [2, 9, 10, 24, 33, 42, 54, 56, 59]
# new_list_2:  [5, 7, 18, 40, 46, 53]
# [5, 7, 18, 40, 46, 53]
# new_list_1:  [0, 9, 24, 26, 28, 32, 33, 41, 51]
# new_list_2:  [4, 9, 15, 41, 45, 53]
# [4, 9, 15, 41, 45, 53]
# new_list_1:  [9, 13, 21, 22, 32, 42, 48, 55, 56]
# new_list_2:  [4, 18, 35, 39, 43, 54]
# [4, 18, 35, 39, 43, 54]
# new_list_1:  [8, 17, 18, 21, 32, 34, 35, 36, 47]
# new_list_2:  [24, 33, 36, 40, 46, 57]
# [24, 33, 36, 40, 46, 57]
# new_list_1:  [9, 10, 17, 19, 26, 27, 35, 40, 49]
# new_list_2:  [13, 20, 23, 31, 43, 46]
# [13, 20, 23, 31, 43, 46]
# ---------------------------
# [9, 10, 17, 19, 26, 27, 35, 40, 49]
# [13, 20, 23, 31, 43, 46]

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])
# Out:
# 0
# 0 1 60
# 1
# 1 2 60
# 2
# 2 3 60
# 3
# 3 4 60
# 4
# 4 5 60
# 5
# 5 6 60
# 6
# 6 7 60
# 7
# 7 8 60

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 362
# 362
# True
# 36
# 36
# True
# 36
# 36
# True
# 48
# 46
# 2

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 24 + ['tone2'] * 24 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)
# Out:
# ['tone2', 'tone2', 'tone2', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone1', 'tone1', 'tone1', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone2', 'tone1', 'tone2']

# %%
df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_1.csv')
block_1_half = block
probe_series_1_half = probe_series

# %%
##################
# SECOND ITERATION#
##################

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <2 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  24
# len(critical_trials):  48

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 370
# -------------------

# %%
block_low_1()
block_high_1()
block_high_2()
block_low_2()
block_high_1()
block_low_1()
block_low_2()
block_high_2()
# Out:
# [' person', nan, nan, nan, nan, 20.358449022039405, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 16.846336579249186, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 14.300464691841311, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' sofa', nan, nan, nan, nan, 19.892389695505386, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 16.197035825449316, 'low', ' car', ' boat', 'Target Absent', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 16.69849859536183, 'low', ' sofa', ' bird', 'Target Absent', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 16.520476370843983, 'low', ' pottedplant', ' sofa', 'Target Absent', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 19.188834185415878, 'low', ' sofa', ' horse', 'Target Absent', 'Normal']
# [' person', ' boat', nan, nan, nan, 17.997748470093857, 'low', ' boat', ' aeroplane', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  2
# List of critical trials without probe:
# [' sofa', ' dog', nan, nan, nan, 21.001227278103954, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 17.516941478695085, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 13.411221053439446, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 18.414255754393281, 'low', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  47
# Normal used: 47
# ---------------------------------------------------
# [' person', ' horse', nan, nan, nan, 29.265462465033568, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' car', ' motorbike', ' person', nan, nan, 31.408721955354231, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 31.193570788757722, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' sofa', ' chair', nan, nan, nan, 32.351474210019695, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' aeroplane', ' boat', nan, nan, nan, 29.287349444649571, 'high', ' aeroplane', ' car', 'Target Absent', 'Critical']
# [' person', ' car', nan, nan, nan, 28.839741748612518, 'high', ' person', ' pottedplant', 'Target Absent', 'Normal']
# [' person', ' chair', ' diningtable', ' bottle', nan, 29.622914279842281, 'high', ' bottle', ' pottedplant', 'Target Absent', 'Normal']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 37.223815804487252, 'high', ' sofa', ' boat', 'Target Absent', 'Critical']
# [' tvmonitor', ' chair', nan, nan, nan, 34.776343714473143, 'high', ' chair', ' dog', 'Target Absent', 'Critical']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  3
# List of critical trials without probe:
# [' person', ' bicycle', ' boat', nan, nan, 34.319051607761132, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' car', ' bicycle', nan, nan, nan, 28.730946256992283, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 29.401451132133516, 'high', ' cat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  95
# Normal used: 95
# ---------------------------------------------------
# [' pottedplant', ' person', ' train', nan, nan, 29.323493073246585, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' dog', nan, nan, 30.007374331932049, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' motorbike', nan, nan, nan, 31.076858313574171, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' car', ' person', ' bus', nan, nan, 35.069419182240701, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 30.48036175658957, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' person', ' cat', nan, nan, nan, 29.867994035114002, 'high', ' cat', ' bird', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' bird', nan, nan, 32.325935045893075, 'high', ' bird', ' bottle', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 32.06509585553637, 'high', ' bird', ' aeroplane', 'Target Absent', 'Normal']
# [' person', ' bottle', nan, nan, nan, 30.93687927856223, 'high', ' person', ' bird', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  0
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 31.514885822931809, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' dog', nan, nan, nan, 28.663633475174361, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' diningtable', ' boat', 35.383633537269247, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 29.806819625699735, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', ' aeroplane', nan, nan, nan, 37.93755165753997, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 31.72817006314488, 'high', ' dog', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  140
# Normal used: 140
# ---------------------------------------------------
# [' pottedplant', nan, nan, nan, nan, 11.902212339033813, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.885436604139475, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' chair', ' cat', nan, nan, nan, 16.65486588795244, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 18.02036796686756, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' sofa', nan, nan, nan, nan, 17.316646037114566, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 18.000361854332464, 'low', ' aeroplane', ' dog', 'Target Absent', 'Normal']
# [' dog', nan, nan, nan, nan, 20.194433628678283, 'low', ' dog', ' person', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 18.29867809750948, 'low', ' car', ' aeroplane', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 21.181010736182625, 'low', ' car', ' chair', 'Target Absent', 'Normal']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  0
# List of critical trials without probe:
# [' person', ' horse', ' car', nan, nan, 20.934599857700228, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 20.138559565527519, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 19.912301015287291, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', nan, nan, nan, 18.96772267222304, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' sofa', nan, nan, nan, 19.244035875135978, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 19.598131175056185, 'low', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  185
# Normal used: 185
# ---------------------------------------------------
# [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 28.968465057520145, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 29.814920313574749, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' pottedplant', ' car', ' chair', ' bicycle', ' person', 30.133244112833108, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' person', ' bottle', ' diningtable', nan, nan, 34.072917550349175, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' bicycle', ' car', nan, 33.367152749801264, 'high', ' pottedplant', ' cat', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 31.397027824172856, 'high', ' bird', ' sofa', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 31.885877800404149, 'high', ' aeroplane', ' person', 'Target Absent', 'Critical']
# [' person', ' dog', nan, nan, nan, 30.657341600370845, 'high', ' dog', ' bottle', 'Target Absent', 'Normal']
# [' pottedplant', ' chair', nan, nan, nan, 34.966628065768532, 'high', ' pottedplant', ' aeroplane', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  1
# List of critical trials without probe:
# [' person', ' bird', ' boat', nan, nan, 31.913409738647122, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' diningtable', ' bottle', nan, nan, 38.972642388939022, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 31.487640373164247, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' diningtable', ' person', ' chair', ' dog', ' bottle', 36.040121428269742, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' sofa', ' person', nan, nan, nan, 35.925571873150382, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  231
# Normal used: 231
# ---------------------------------------------------
# [' car', nan, nan, nan, nan, 18.597981681742631, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 21.01071271736431, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 18.608803704733788, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 19.759255998410111, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 20.189150337053679, 'low', ' person', ' pottedplant', 'Target Absent', 'Critical']
# [' bird', nan, nan, nan, nan, 19.30503047810884, 'low', ' bird', ' bottle', 'Target Absent', 'Critical']
# [' sofa', ' cat', nan, nan, nan, 18.288477341906038, 'low', ' sofa', ' cat', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 19.685752299806754, 'low', ' boat', ' bird', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 18.874156232375913, 'low', ' car', ' bottle', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  2
# List of critical trials without probe:
# [' chair', ' diningtable', nan, nan, nan, 18.117802795100609, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' car', ' dog', ' person', nan, nan, 21.020159211351668, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' person', nan, nan, nan, nan, 21.23535981155764, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' bottle', ' dog', ' diningtable', nan, nan, 21.034646910874567, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  278
# Normal used: 278
# ---------------------------------------------------
# [' cat', nan, nan, nan, nan, 15.633666738732224, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 19.20795639634078, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 19.239146135217897, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' person', ' boat', nan, nan, nan, 19.194815950035924, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' bottle', nan, nan, nan, nan, 18.603518928106915, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 9.1563902861608657, 'low', ' car', ' pottedplant', 'Target Absent', 'Normal']
# [' pottedplant', ' sofa', ' chair', nan, nan, 18.511887801846186, 'low', ' pottedplant', ' cat', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 13.685993646696661, 'low', ' cat', ' chair', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 20.041574567240037, 'low', ' cat', ' car', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 17.167558060312739, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 20.272204751551552, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' chair', ' cat', nan, nan, nan, 17.570654058012458, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 14.127469618562607, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 15.759492066531687, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 20.965775321926717, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  323
# Normal used: 323
# ---------------------------------------------------
# [' person', ' boat', nan, nan, nan, 34.287988653046689, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' sofa', ' person', nan, nan, nan, 33.279582355794268, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 30.141763061562205, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' person', ' dog', nan, nan, nan, 30.20203583105944, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' boat', nan, nan, nan, 31.261037639233152, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 29.272654602537909, 'high', ' bird', ' cat', 'Target Absent', 'Critical']
# [' person', nan, nan, nan, nan, 29.639296311219638, 'high', ' person', ' chair', 'Target Absent', 'Critical']
# [' person', ' diningtable', ' bottle', nan, nan, 36.414042237667729, 'high', ' bottle', ' chair', 'Target Absent', 'Normal']
# [' person', ' chair', ' diningtable', ' bottle', nan, 33.734529116802769, 'high', ' chair', ' horse', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  2
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 30.954010715704413, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 33.64739800555661, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 28.99541660743073, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 33.702921971939176, 'high', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  370
# Normal used: 370
# ---------------------------------------------------

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
probe_series = []
critical_series = []

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [5, 8, 9, 10, 15, 17, 27, 28, 55]
# new_list_2:  [12, 15, 37, 54]
# [12, 15, 37, 54]
# new_list_1:  [5, 27, 30, 33, 37, 42, 46, 51, 58]
# new_list_2:  [22, 30, 42, 45]
# [22, 30, 42, 45]
# new_list_1:  [10, 19, 29, 44, 46, 47, 50, 53, 57]
# new_list_2:  [39, 50, 56, 58]
# [39, 50, 56, 58]
# new_list_1:  [1, 9, 17, 19, 25, 33, 38, 44, 53]
# new_list_2:  [10, 23, 38, 41]
# [10, 23, 38, 41]
# new_list_1:  [24, 28, 29, 30, 31, 35, 50, 53, 55]
# new_list_2:  [6, 22, 38, 59]
# [6, 22, 38, 59]
# new_list_1:  [4, 14, 28, 33, 34, 38, 45, 46, 49]
# new_list_2:  [13, 25, 35, 44]
# [13, 25, 35, 44]
# new_list_1:  [11, 12, 23, 25, 29, 34, 36, 39, 46]
# new_list_2:  [3, 13, 42, 52]
# [3, 13, 42, 52]
# ---------------------------
# [11, 12, 23, 25, 29, 34, 36, 39, 46]
# [3, 13, 42, 52]
# new_list_1:  [3, 5, 12, 13, 21, 30, 32, 46, 55]
# new_list_2:  [8, 29, 34]
# [8, 29, 34]
# new_list_1:  [5, 12, 14, 20, 24, 26, 42, 49, 56]
# new_list_2:  [4, 7, 53]
# [4, 7, 53]
# new_list_1:  [4, 7, 11, 13, 14, 19, 24, 31, 39]
# new_list_2:  [1, 8, 26]
# [1, 8, 26]
# ---------------------------
# [4, 7, 11, 13, 14, 19, 24, 31, 39]
# [1, 8, 26]
# new_list_1:  [3, 17, 21, 25, 28, 36, 41, 45, 50]
# new_list_2:  [2, 16, 27, 31, 52, 55]
# [2, 16, 27, 31, 52, 55]
# new_list_1:  [0, 6, 10, 18, 27, 30, 42, 44, 52]
# new_list_2:  [6, 15, 28, 44, 47, 52]
# [6, 15, 28, 44, 47, 52]
# new_list_1:  [1, 2, 8, 14, 37, 46, 51, 52, 57]
# new_list_2:  [2, 15, 23, 28, 32, 52]
# [2, 15, 23, 28, 32, 52]
# new_list_1:  [4, 13, 18, 25, 27, 38, 39, 45, 59]
# new_list_2:  [9, 20, 36, 42, 55, 58]
# [9, 20, 36, 42, 55, 58]
# new_list_1:  [7, 9, 29, 36, 39, 42, 49, 52, 57]
# new_list_2:  [8, 16, 26, 44, 55, 57]
# [8, 16, 26, 44, 55, 57]
# new_list_1:  [8, 10, 16, 37, 40, 43, 45, 46, 52]
# new_list_2:  [19, 29, 35, 41, 44, 53]
# [19, 29, 35, 41, 44, 53]
# new_list_1:  [1, 7, 10, 29, 30, 39, 44, 48, 58]
# new_list_2:  [3, 5, 12, 23, 28, 51]
# [3, 5, 12, 23, 28, 51]
# new_list_1:  [9, 14, 19, 23, 31, 32, 33, 52, 59]
# new_list_2:  [2, 8, 24, 43, 50, 55]
# [2, 8, 24, 43, 50, 55]
# new_list_1:  [4, 7, 11, 15, 16, 33, 42, 46, 49]
# new_list_2:  [4, 24, 29, 31, 50, 59]
# [4, 24, 29, 31, 50, 59]
# new_list_1:  [0, 24, 41, 44, 47, 49, 52, 54, 58]
# new_list_2:  [3, 8, 19, 25, 35, 58]
# [3, 8, 19, 25, 35, 58]
# new_list_1:  [7, 11, 13, 14, 20, 22, 30, 41, 45]
# new_list_2:  [3, 10, 18, 22, 39, 41]
# [3, 10, 18, 22, 39, 41]
# new_list_1:  [32, 34, 39, 40, 44, 51, 55, 56, 57]
# new_list_2:  [9, 18, 28, 39, 49, 58]
# [9, 18, 28, 39, 49, 58]
# new_list_1:  [1, 14, 34, 39, 41, 44, 54, 55, 59]
# new_list_2:  [14, 19, 24, 35, 45, 50]
# [14, 19, 24, 35, 45, 50]
# new_list_1:  [6, 7, 12, 28, 32, 37, 44, 45, 54]
# new_list_2:  [7, 15, 17, 23, 52, 55]
# [7, 15, 17, 23, 52, 55]
# new_list_1:  [12, 13, 26, 30, 32, 36, 49, 50, 57]
# new_list_2:  [8, 18, 23, 36, 45, 49]
# [8, 18, 23, 36, 45, 49]
# new_list_1:  [3, 6, 16, 20, 34, 44, 51, 53, 58]
# new_list_2:  [11, 20, 34, 41, 48, 54]
# [11, 20, 34, 41, 48, 54]
# new_list_1:  [8, 14, 15, 16, 17, 19, 24, 42, 53]
# new_list_2:  [2, 29, 40, 49, 52, 56]
# [2, 29, 40, 49, 52, 56]
# new_list_1:  [11, 12, 20, 24, 26, 37, 44, 45, 58]
# new_list_2:  [4, 10, 12, 29, 31, 39]
# [4, 10, 12, 29, 31, 39]
# new_list_1:  [4, 26, 28, 37, 40, 42, 43, 58, 59]
# new_list_2:  [20, 35, 40, 46, 50, 52]
# [20, 35, 40, 46, 50, 52]
# new_list_1:  [1, 8, 14, 15, 22, 25, 51, 53, 55]
# new_list_2:  [7, 27, 30, 35, 37, 53]
# [7, 27, 30, 35, 37, 53]
# new_list_1:  [9, 16, 28, 35, 39, 40, 44, 47, 54]
# new_list_2:  [21, 24, 38, 48, 52, 59]
# [21, 24, 38, 48, 52, 59]
# new_list_1:  [1, 2, 10, 13, 26, 38, 48, 54, 56]
# new_list_2:  [17, 20, 30, 36, 48, 53]
# [17, 20, 30, 36, 48, 53]
# new_list_1:  [13, 20, 24, 27, 31, 33, 45, 48, 58]
# new_list_2:  [2, 11, 22, 29, 41, 45]
# [2, 11, 22, 29, 41, 45]
# new_list_1:  [3, 4, 16, 19, 22, 29, 44, 49, 52]
# new_list_2:  [12, 34, 37, 46, 57, 59]
# [12, 34, 37, 46, 57, 59]
# ---------------------------
# [3, 4, 16, 19, 22, 29, 44, 49, 52]
# [12, 34, 37, 46, 57, 59]
# new_list_1:  [7, 16, 18, 21, 23, 25, 38, 58, 59]
# new_list_2:  [5, 8, 22, 24, 35, 41]
# [5, 8, 22, 24, 35, 41]
# new_list_1:  [1, 16, 18, 21, 26, 27, 35, 41, 47]
# new_list_2:  [3, 32, 36, 50, 53, 59]
# [3, 32, 36, 50, 53, 59]
# ---------------------------
# [1, 16, 18, 21, 26, 27, 35, 41, 47]
# [3, 32, 36, 50, 53, 59]
# new_list_1:  [4, 8, 21, 32, 41, 44, 48, 51, 59]
# new_list_2:  [11, 19, 24, 34, 57]
# [11, 19, 24, 34, 57]
# new_list_1:  [7, 11, 18, 27, 28, 29, 31, 41, 47]
# new_list_2:  [4, 11, 28, 40, 54]
# [4, 11, 28, 40, 54]
# new_list_1:  [2, 9, 11, 15, 26, 32, 35, 47, 56]
# new_list_2:  [21, 36, 40, 52, 55]
# [21, 36, 40, 52, 55]
# new_list_1:  [8, 23, 29, 35, 43, 44, 49, 57, 58]
# new_list_2:  [2, 34, 42, 49, 56]
# [2, 34, 42, 49, 56]
# new_list_1:  [2, 7, 10, 23, 32, 33, 45, 49, 58]
# new_list_2:  [2, 11, 24, 36, 59]
# [2, 11, 24, 36, 59]
# new_list_1:  [0, 5, 10, 12, 22, 28, 46, 47, 56]
# new_list_2:  [11, 31, 34, 40, 50]
# [11, 31, 34, 40, 50]
# new_list_1:  [2, 6, 12, 22, 26, 30, 48, 50, 52]
# new_list_2:  [8, 12, 31, 36, 44]
# [8, 12, 31, 36, 44]
# new_list_1:  [3, 23, 34, 37, 39, 45, 52, 56, 57]
# new_list_2:  [8, 28, 35, 38, 56]
# [8, 28, 35, 38, 56]
# new_list_1:  [7, 10, 12, 20, 30, 32, 36, 38, 52]
# new_list_2:  [24, 38, 43, 48, 57]
# [24, 38, 43, 48, 57]
# new_list_1:  [3, 6, 20, 27, 28, 31, 35, 51, 54]
# new_list_2:  [6, 9, 11, 13, 30]
# [6, 9, 11, 13, 30]
# new_list_1:  [4, 9, 13, 30, 31, 33, 40, 46, 53]
# new_list_2:  [6, 21, 36, 41, 55]
# [6, 21, 36, 41, 55]
# ---------------------------
# [4, 9, 13, 30, 31, 33, 40, 46, 53]
# [6, 21, 36, 41, 55]
# new_list_1:  [0, 4, 9, 24, 31, 32, 35, 41, 59]
# new_list_2:  [19, 31, 40, 44]
# [19, 31, 40, 44]
# new_list_1:  [2, 15, 22, 29, 31, 34, 46, 57, 58]
# new_list_2:  [9, 40, 46, 52]
# [9, 40, 46, 52]
# new_list_1:  [0, 2, 12, 21, 23, 25, 26, 27, 52]
# new_list_2:  [2, 9, 13, 15]
# [2, 9, 13, 15]
# new_list_1:  [6, 10, 15, 22, 23, 48, 55, 57, 59]
# new_list_2:  [5, 27, 31, 37]
# [5, 27, 31, 37]
# new_list_1:  [2, 9, 14, 22, 23, 34, 36, 38, 55]
# new_list_2:  [5, 7, 16, 20]
# [5, 7, 16, 20]
# new_list_1:  [7, 10, 12, 15, 16, 31, 41, 48, 49]
# new_list_2:  [10, 14, 46, 48]
# [10, 14, 46, 48]
# new_list_1:  [7, 19, 22, 34, 36, 38, 39, 46, 52]
# new_list_2:  [15, 18, 51, 56]
# [15, 18, 51, 56]
# new_list_1:  [12, 13, 16, 27, 32, 33, 34, 36, 45]
# new_list_2:  [9, 12, 53, 58]
# [9, 12, 53, 58]
# new_list_1:  [2, 11, 12, 17, 24, 30, 40, 46, 57]
# new_list_2:  [4, 33, 40, 45]
# [4, 33, 40, 45]
# new_list_1:  [7, 8, 20, 21, 40, 48, 52, 53, 57]
# new_list_2:  [8, 18, 26, 57]
# [8, 18, 26, 57]
# new_list_1:  [0, 3, 9, 10, 24, 29, 45, 56, 57]
# new_list_2:  [14, 30, 41, 48]
# [14, 30, 41, 48]
# ---------------------------
# [0, 3, 9, 10, 24, 29, 45, 56, 57]
# [14, 30, 41, 48]
# new_list_1:  [20, 36, 37, 43, 45, 49, 51, 53, 57]
# new_list_2:  [2, 7, 9, 48, 52, 55]
# [2, 7, 9, 48, 52, 55]
# new_list_1:  [1, 12, 16, 21, 25, 31, 47, 48, 55]
# new_list_2:  [10, 16, 22, 41, 45, 58]
# [10, 16, 22, 41, 45, 58]
# new_list_1:  [9, 11, 14, 15, 32, 45, 51, 56, 59]
# new_list_2:  [1, 6, 26, 29, 38, 41]
# [1, 6, 26, 29, 38, 41]
# ---------------------------
# [9, 11, 14, 15, 32, 45, 51, 56, 59]
# [1, 6, 26, 29, 38, 41]
# new_list_1:  [3, 7, 22, 24, 30, 32, 37, 43, 59]
# new_list_2:  [11, 21, 28, 56]
# [11, 21, 28, 56]
# new_list_1:  [12, 20, 23, 28, 36, 44, 45, 47, 54]
# new_list_2:  [1, 4, 10, 12]
# [1, 4, 10, 12]
# new_list_1:  [8, 12, 14, 17, 18, 31, 39, 52, 56]
# new_list_2:  [4, 15, 46, 55]
# [4, 15, 46, 55]
# new_list_1:  [3, 9, 17, 20, 28, 36, 37, 55, 56]
# new_list_2:  [7, 33, 44, 48]
# [7, 33, 44, 48]
# new_list_1:  [5, 14, 15, 16, 17, 19, 25, 32, 46]
# new_list_2:  [16, 21, 40, 52]
# [16, 21, 40, 52]
# new_list_1:  [10, 18, 27, 28, 36, 40, 44, 52, 58]
# new_list_2:  [2, 16, 49, 54]
# [2, 16, 49, 54]
# new_list_1:  [10, 11, 14, 21, 23, 26, 37, 49, 55]
# new_list_2:  [1, 7, 29, 34]
# [1, 7, 29, 34]
# ---------------------------
# [10, 11, 14, 21, 23, 26, 37, 49, 55]
# [1, 7, 29, 34]

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])
# Out:
# 0
# 0 1 60
# 1
# 1 2 60
# 2
# 2 3 60
# 3
# 3 4 60
# 4
# 4 5 60
# 5
# 5 6 60
# 6
# 6 7 60
# 7
# 7 8 60

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 370
# 370
# True
# 36
# 36
# True
# 36
# 36
# True
# 48
# 38
# 10

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 24 + ['tone2'] * 24 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)
# Out:
# ['tone2', 'tone2', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone2', 'tone1', 'tone1', 'tone1', 'tone1', 'tone2', 'tone2', 'tone1']

# %%
df_2 = pd.DataFrame.from_dict(possible_images_dict)
df_2= df_2.T
df_2.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df_2.TS = df_2.TS.astype('float')
df_2.to_csv(mypath + 'randomization_2.csv')
block_2_half = block
probe_series_2_half = probe_series

# %%
probe_series = probe_series_1_half + probe_series_2_half
block = block_1_half + block_2_half

# %%
with open('filename.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(block[i])
        #wr.writerow(blocks_sequences_list[i])

with open('filename2.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(probe_series[i])
