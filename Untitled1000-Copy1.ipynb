# %%
### CREATING RANDOMIZATION.CSV

# %%
import pandas as pd
import numpy as np
import random
import csv
#%pdb
mypath = ('E:/OneDrive - University College London/Random_probes_last/Luca/')
#mypath = 'C:/Users/KeK/OneDrive - University College London/Random_probes_last/Luca/'

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
#df

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <2 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  24
# len(critical_trials):  48

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')

#df = pd.DataFrame.from_dict(possible_images_dict)
#df= df.T
#df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
#df.TS = df.TS.astype('float')
#df.to_csv(mypath + 'randomization_15.csv')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
#%pdb
# Out:
# 365

# %%
def block_low_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, block, critical_probes_counter
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)

#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (6-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (6 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)

#-----------------------------------------------------------------------------
    print len(block)
    return block

# %%
def block_high_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)

#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (6-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (6 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)

#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    random.shuffle(to_insert)
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(len(to_insert)-1):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:# and 3 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                new_list = [n for n in new_list if 'No Target' not in possible_images_dict[block[n]]]
                print new_list
                print len(new_list)
                return  block, new_list
                break

#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(len(to_insert),60)
    print 'len(block): ',len(block)
#print new_list
    for n in range(len(new_list)):
        print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list

# %%
def block_high_2():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)

#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (6-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (6 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)

#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    random.shuffle(to_insert)
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(len(to_insert)-1):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff and 3 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                new_list = [n for n in new_list if 'No Target' not in possible_images_dict[block[n]]]
                print new_list
                print len(new_list)
                return  block, new_list
                break

#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(len(to_insert),60)
    print 'len(block): ',len(block)
#print new_list
    for n in range(len(new_list)):
        print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list

# %%
high_one, lista_high_one = block_high_1()
high_two, lista_high_two = block_high_2()
high_three, lista_high_three = block_high_1()
high_four, lista_high_four = block_high_2()
# Out:
# [' person', ' horse', nan, nan, nan, 33.702921971939176, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' diningtable', ' person', ' chair', ' dog', ' bottle', 36.040121428269742, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' person', ' bicycle', ' boat', nan, nan, 34.319051607761132, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' chair', nan, nan, nan, 29.779906614434282, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 30.088045927192198, 'high', ' horse', ' boat', 'Target Absent', 'Normal']
# [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 28.968465057520145, 'high', ' sofa', ' car', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 30.242937209299559, 'high', ' aeroplane', ' chair', 'Target Absent', 'Normal']
# [' pottedplant', ' tvmonitor', ' cat', nan, nan, 31.67044719842205, 'high', ' cat', ' boat', 'Target Absent', 'Critical']
# [' person', ' bottle', nan, nan, nan, 30.958055456079503, 'high', ' bottle', ' person', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  1
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 36.207394560965135, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 31.487640373164247, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' tvmonitor', nan, nan, 28.894989564027235, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' car', ' boat', ' person', nan, nan, 32.759267418843763, 'high', ' boat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  46
# len(to_insert):  14
# len(block):  0
# Liste scartate:  333
# New List:  [1, 5, 8, 11, 15, 20, 27, 32, 35, 39, 48, 52, 56, 59]
# [1, 5, 8, 11, 20, 39, 48, 56, 59]
# 9
# len(block):  60
# 1 [' person', ' bottle', nan, nan, nan, 30.958055456079503, 'high', ' bottle', ' person', 'Target Absent', 'Normal']
# 5 [' person', ' bicycle', ' boat', nan, nan, 34.319051607761132, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# 8 [' person', ' horse', nan, nan, nan, 30.088045927192198, 'high', ' horse', ' boat', 'Target Absent', 'Normal']
# 11 [' pottedplant', ' tvmonitor', ' cat', nan, nan, 31.67044719842205, 'high', ' cat', ' boat', 'Target Absent', 'Critical']
# 20 [' person', ' chair', nan, nan, nan, 29.779906614434282, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# 39 [' person', ' horse', nan, nan, nan, 33.702921971939176, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# 48 [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 28.968465057520145, 'high', ' sofa', ' car', 'Target Absent', 'Normal']
# 56 [' person', ' aeroplane', nan, nan, nan, 30.242937209299559, 'high', ' aeroplane', ' chair', 'Target Absent', 'Normal']
# 59 [' diningtable', ' person', ' chair', ' dog', ' bottle', 36.040121428269742, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# Normal used: 46
# ---------------------------------------------------
# [' pottedplant', ' person', ' bottle', ' diningtable', nan, 36.665582819269645, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 29.742786682331467, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' person', ' chair', ' diningtable', ' bottle', nan, 30.060591861960411, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 29.176311484999022, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 29.401451132133516, 'high', ' cat', ' cat', 'Target Present', 'Critical']
# [' person', ' chair', ' diningtable', ' bottle', nan, 33.478750472719696, 'high', ' bottle', ' person', 'Target Absent', 'Normal']
# [' sofa', ' person', nan, nan, nan, 31.051868344918073, 'high', ' sofa', ' horse', 'Target Absent', 'Normal']
# [' person', ' dog', nan, nan, nan, 32.142427134910967, 'high', ' dog', ' bird', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' dog', nan, nan, 30.007374331932049, 'high', ' dog', ' cat', 'Target Absent', 'Normal']
# Present Used:  9
# Absent Used  9
# Critical probes counter:  1
# List of critical trials without probe:
# [' chair', ' cat', nan, nan, nan, 29.798629151951733, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 31.310599923489761, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 34.544144821561908, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' car', ' person', ' bus', nan, nan, 35.069419182240701, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' person', nan, nan, 31.794729403138948, 'high', ' person', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  92
# len(to_insert):  14
# len(block):  60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-09828dcb5e06> in <module>()
#       1 high_one, lista_high_one = block_high_1()
# ----> 2 high_two, lista_high_two = block_high_2()
#       3 high_three, lista_high_three = block_high_1()
#       4 high_four, lista_high_four = block_high_2()
#
# <ipython-input-10-b2c56bbcd069> in block_high_2()
#      91 #-----------------------------------------------------------------------------
#      92     print 'len(block): ',len(block)
# ---> 93     constrained_sum_sample_pos_adding_criticals(len(to_insert),60)
#      94     print 'len(block): ',len(block)
#      95 #print new_list
#
# <ipython-input-10-b2c56bbcd069> in constrained_sum_sample_pos_adding_criticals(n, total)
#      67             sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
#      68             acc = 0
# ---> 69             new_list = []
#      70             for i in sequences_length:
#      71                 acc = acc + i
#
# KeyboardInterrupt:

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter



block_dict = {}
block_dict['low_one'] = low_one
block_dict['low_two'] = low_two
block_dict['low_three'] = low_three
block_dict['low_four'] = low_four
block_dict['high_one'] = high_one
block_dict['high_two'] = high_two
block_dict['high_three'] = high_three
block_dict['high_four'] = high_four

block_dict['low_one']
print len(block_dict['low_one'])
print low_one
# Out:
# 365
# 92
# False
# 36
# 9
# False
# 36
# 9
# False
# 48
# 10
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-492a9e042b35> in <module>()
#      23
#      24 block_dict = {}
# ---> 25 block_dict['low_one'] = low_one
#      26 block_dict['low_two'] = low_two
#      27 block_dict['low_three'] = low_three
#
# NameError: name 'low_one' is not defined

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 24 + ['tone2'] * 24 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)

# %%
df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_1.csv')

# %%
##################
# SECOND ITERATION#
##################

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <2 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')

#df = pd.DataFrame.from_dict(possible_images_dict)
#df= df.T
#df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
#df.TS = df.TS.astype('float')
#df.to_csv(mypath + 'randomization_15.csv')

# %%
#Defininfg blocks 
probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
print len(normal_no_probe)
#%pdb

# %%
low_five, lista_low_five = block_low_1()
low_six, lista_low_six = block_low_2()
low_seven, lista_low_seven = block_low_1()
low_eight, lista_low_eight = block_low_2()

# %%
high_five, lista_high_five = block_high_1()
high_six, lista_high_six = block_high_2()
high_seven, lista_high_seven = block_high_1()
high_eight, lista_high_eight = block_high_2()

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter



block_dict = {}
block_dict['low_one'] = low_one
block_dict['low_two'] = low_two
block_dict['low_three'] = low_three
block_dict['low_four'] = low_four
block_dict['high_one'] = high_one
block_dict['high_two'] = high_two
block_dict['high_three'] = high_three
block_dict['high_four'] = high_four

block_dict['low_one']
print len(block_dict['low_one'])
print low_one

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 + ['tone3'] * 12 + ['tone4'] * 12
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)

# %%
df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_2.csv')

# %%
blocks_names_list = [low_one, low_two, low_three, low_four, low_five, low_six, low_seven, low_eight,
                        high_one, high_two, high_three, high_four, high_five, high_six, high_seven, high_eight]
blocks_sequences_list = [lista_low_one, lista_low_two, lista_low_three, lista_low_four, lista_low_five, lista_low_six, lista_low_seven, lista_low_eight,
                        lista_high_one, lista_high_two, lista_high_three, lista_high_four, lista_high_five, lista_high_six, lista_high_seven, lista_high_eight]
with open('filename.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(blocks_names_list[i])
        #wr.writerow(blocks_sequences_list[i])

with open('filename2.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        #wr.writerow(blocks_names_list[i])
        wr.writerow(blocks_sequences_list[i])

#-----------------------------------------------
exp_images = low_one + low_two + low_three + low_four + high_one + high_two + high_three + high_four
blocks_final = low_one + low_two + low_three +low_four + low_five + low_six + low_seven + low_eight + high_one + high_two + high_three + high_four + high_five + high_six + high_seven + high_eight 
print blocks_final == set(blocks_final)
from shutil import copyfile

for each in exp_images:
    copyfile(mypath + 'JPEGImages/'+each, 
            mypath + 'exp_images/'+each)
