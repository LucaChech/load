# %%
from random import random

# %%
test
# Out:
# <function process.test>

# %%
tdf.loc[2,'RT_TO']
# Out:
# nan

# %%
notes
# Out:
# {'rejects_TO': [0,
#       Image_Name Cat.1 Cat.2 Cat.3 Cat.4 Cat.5   TS Load exemplar question  \
#   1          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   2          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   3          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   4          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   5          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   6          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   7          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   8          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   9          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   10         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   11         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   12         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   13         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   14         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   15         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   16         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   17         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   18         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   19         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   20         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   21         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   22         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   23         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   24         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   25         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   26         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   27         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   28         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   29         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   30         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   ..         ...   ...   ...   ...   ...   ...  ...  ...      ...      ...
#   371        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   372        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   373        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   374        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   375        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   376        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   377        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   378        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   379        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   380        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   381        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   382        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   383        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   384        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   385        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   386        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   387        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   388        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   389        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   390        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   391        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   392        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   393        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   394        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   395        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   396        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   397        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   398        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   399        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   400        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#
#        ...  trial_type tone_Hz tone_onset space    RT_TO keys    RT_VS useless  \
#   1    ...         NaN     NaN        NaN   NaN  453.669  NaN  453.669     NaN
#   2    ...         NaN     NaN        NaN   NaN  469.624  NaN  469.624     NaN
#   3    ...         NaN     NaN        NaN   NaN  470.543  NaN  470.543     NaN
#   4    ...         NaN     NaN        NaN   NaN   487.82  NaN   487.82     NaN
#   5    ...         NaN     NaN        NaN   NaN  456.196  NaN  456.196     NaN
#   6    ...         NaN     NaN        NaN   NaN  463.708  NaN  463.708     NaN
#   7    ...         NaN     NaN        NaN   NaN  462.122  NaN  462.122     NaN
#   8    ...         NaN     NaN        NaN   NaN  468.479  NaN  468.479     NaN
#   9    ...         NaN     NaN        NaN   NaN   484.22  NaN   484.22     NaN
#   10   ...         NaN     NaN        NaN   NaN  496.235  NaN  496.235     NaN
#   11   ...         NaN     NaN        NaN   NaN  495.515  NaN  495.515     NaN
#   12   ...         NaN     NaN        NaN   NaN  476.547  NaN  476.547     NaN
#   13   ...         NaN     NaN        NaN   NaN  463.657  NaN  463.657     NaN
#   14   ...         NaN     NaN        NaN   NaN  489.695  NaN  489.695     NaN
#   15   ...         NaN     NaN        NaN   NaN  452.723  NaN  452.723     NaN
#   16   ...         NaN     NaN        NaN   NaN  478.869  NaN  478.869     NaN
#   17   ...         NaN     NaN        NaN   NaN   457.13  NaN   457.13     NaN
#   18   ...         NaN     NaN        NaN   NaN   457.37  NaN   457.37     NaN
#   19   ...         NaN     NaN        NaN   NaN  484.433  NaN  484.433     NaN
#   20   ...         NaN     NaN        NaN   NaN  462.534  NaN  462.534     NaN
#   21   ...         NaN     NaN        NaN   NaN  491.775  NaN  491.775     NaN
#   22   ...         NaN     NaN        NaN   NaN  461.959  NaN  461.959     NaN
#   23   ...         NaN     NaN        NaN   NaN  489.199  NaN  489.199     NaN
#   24   ...         NaN     NaN        NaN   NaN  463.591  NaN  463.591     NaN
#   25   ...         NaN     NaN        NaN   NaN  451.109  NaN  451.109     NaN
#   26   ...         NaN     NaN        NaN   NaN  450.531  NaN  450.531     NaN
#   27   ...         NaN     NaN        NaN   NaN  461.676  NaN  461.676     NaN
#   28   ...         NaN     NaN        NaN   NaN  483.851  NaN  483.851     NaN
#   29   ...         NaN     NaN        NaN   NaN  499.864  NaN  499.864     NaN
#   30   ...         NaN     NaN        NaN   NaN  478.294  NaN  478.294     NaN
#   ..   ...         ...     ...        ...   ...      ...  ...      ...     ...
#   371  ...         NaN     NaN        NaN   NaN  456.805  NaN  456.805     NaN
#   372  ...         NaN     NaN        NaN   NaN  469.895  NaN  469.895     NaN
#   373  ...         NaN     NaN        NaN   NaN  469.163  NaN  469.163     NaN
#   374  ...         NaN     NaN        NaN   NaN  480.483  NaN  480.483     NaN
#   375  ...         NaN     NaN        NaN   NaN  476.917  NaN  476.917     NaN
#   376  ...         NaN     NaN        NaN   NaN  489.795  NaN  489.795     NaN
#   377  ...         NaN     NaN        NaN   NaN  472.451  NaN  472.451     NaN
#   378  ...         NaN     NaN        NaN   NaN  498.362  NaN  498.362     NaN
#   379  ...         NaN     NaN        NaN   NaN  469.095  NaN  469.095     NaN
#   380  ...         NaN     NaN        NaN   NaN  451.415  NaN  451.415     NaN
#   381  ...         NaN     NaN        NaN   NaN  483.715  NaN  483.715     NaN
#   382  ...         NaN     NaN        NaN   NaN  481.388  NaN  481.388     NaN
#   383  ...         NaN     NaN        NaN   NaN  453.449  NaN  453.449     NaN
#   384  ...         NaN     NaN        NaN   NaN  479.715  NaN  479.715     NaN
#   385  ...         NaN     NaN        NaN   NaN  492.314  NaN  492.314     NaN
#   386  ...         NaN     NaN        NaN   NaN  481.697  NaN  481.697     NaN
#   387  ...         NaN     NaN        NaN   NaN  475.868  NaN  475.868     NaN
#   388  ...         NaN     NaN        NaN   NaN  497.891  NaN  497.891     NaN
#   389  ...         NaN     NaN        NaN   NaN  457.383  NaN  457.383     NaN
#   390  ...         NaN     NaN        NaN   NaN  455.995  NaN  455.995     NaN
#   391  ...         NaN     NaN        NaN   NaN  463.887  NaN  463.887     NaN
#   392  ...         NaN     NaN        NaN   NaN  464.844  NaN  464.844     NaN
#   393  ...         NaN     NaN        NaN   NaN  496.257  NaN  496.257     NaN
#   394  ...         NaN     NaN        NaN   NaN  498.344  NaN  498.344     NaN
#   395  ...         NaN     NaN        NaN   NaN  499.612  NaN  499.612     NaN
#   396  ...         NaN     NaN        NaN   NaN  495.146  NaN  495.146     NaN
#   397  ...         NaN     NaN        NaN   NaN  461.717  NaN  461.717     NaN
#   398  ...         NaN     NaN        NaN   NaN  464.254  NaN  464.254     NaN
#   399  ...         NaN     NaN        NaN   NaN  475.862  NaN  475.862     NaN
#   400  ...         NaN     NaN        NaN   NaN  482.299  NaN  482.299     NaN
#
#       Trial_N_Block Block
#   1             NaN   NaN
#   2             NaN   NaN
#   3             NaN   NaN
#   4             NaN   NaN
#   5             NaN   NaN
#   6             NaN   NaN
#   7             NaN   NaN
#   8             NaN   NaN
#   9             NaN   NaN
#   10            NaN   NaN
#   11            NaN   NaN
#   12            NaN   NaN
#   13            NaN   NaN
#   14            NaN   NaN
#   15            NaN   NaN
#   16            NaN   NaN
#   17            NaN   NaN
#   18            NaN   NaN
#   19            NaN   NaN
#   20            NaN   NaN
#   21            NaN   NaN
#   22            NaN   NaN
#   23            NaN   NaN
#   24            NaN   NaN
#   25            NaN   NaN
#   26            NaN   NaN
#   27            NaN   NaN
#   28            NaN   NaN
#   29            NaN   NaN
#   30            NaN   NaN
#   ..            ...   ...
#   371           NaN   NaN
#   372           NaN   NaN
#   373           NaN   NaN
#   374           NaN   NaN
#   375           NaN   NaN
#   376           NaN   NaN
#   377           NaN   NaN
#   378           NaN   NaN
#   379           NaN   NaN
#   380           NaN   NaN
#   381           NaN   NaN
#   382           NaN   NaN
#   383           NaN   NaN
#   384           NaN   NaN
#   385           NaN   NaN
#   386           NaN   NaN
#   387           NaN   NaN
#   388           NaN   NaN
#   389           NaN   NaN
#   390           NaN   NaN
#   391           NaN   NaN
#   392           NaN   NaN
#   393           NaN   NaN
#   394           NaN   NaN
#   395           NaN   NaN
#   396           NaN   NaN
#   397           NaN   NaN
#   398           NaN   NaN
#   399           NaN   NaN
#   400           NaN   NaN
#
#   [400 rows x 21 columns]],
#  'rejects_VS': (0,
#       Image_Name Cat.1 Cat.2 Cat.3 Cat.4 Cat.5   TS Load exemplar question  \
#   1          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   2          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   3          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   4          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   5          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   6          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   7          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   8          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   9          NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   10         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   11         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   12         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   13         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   14         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   15         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   16         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   17         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   18         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   19         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   20         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   21         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   22         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   23         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   24         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   25         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   26         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   27         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   28         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   29         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   30         NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   ..         ...   ...   ...   ...   ...   ...  ...  ...      ...      ...
#   371        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   372        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   373        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   374        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   375        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   376        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   377        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   378        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   379        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   380        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   381        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   382        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   383        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   384        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   385        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   386        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   387        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   388        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   389        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   390        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   391        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   392        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   393        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   394        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   395        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   396        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   397        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   398        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   399        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#   400        NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN      NaN      NaN
#
#        ...  trial_type tone_Hz tone_onset space    RT_TO keys    RT_VS useless  \
#   1    ...         NaN     NaN        NaN   NaN  453.669  NaN  453.669     NaN
#   2    ...         NaN     NaN        NaN   NaN  469.624  NaN  469.624     NaN
#   3    ...         NaN     NaN        NaN   NaN  470.543  NaN  470.543     NaN
#   4    ...         NaN     NaN        NaN   NaN   487.82  NaN   487.82     NaN
#   5    ...         NaN     NaN        NaN   NaN  456.196  NaN  456.196     NaN
#   6    ...         NaN     NaN        NaN   NaN  463.708  NaN  463.708     NaN
#   7    ...         NaN     NaN        NaN   NaN  462.122  NaN  462.122     NaN
#   8    ...         NaN     NaN        NaN   NaN  468.479  NaN  468.479     NaN
#   9    ...         NaN     NaN        NaN   NaN   484.22  NaN   484.22     NaN
#   10   ...         NaN     NaN        NaN   NaN  496.235  NaN  496.235     NaN
#   11   ...         NaN     NaN        NaN   NaN  495.515  NaN  495.515     NaN
#   12   ...         NaN     NaN        NaN   NaN  476.547  NaN  476.547     NaN
#   13   ...         NaN     NaN        NaN   NaN  463.657  NaN  463.657     NaN
#   14   ...         NaN     NaN        NaN   NaN  489.695  NaN  489.695     NaN
#   15   ...         NaN     NaN        NaN   NaN  452.723  NaN  452.723     NaN
#   16   ...         NaN     NaN        NaN   NaN  478.869  NaN  478.869     NaN
#   17   ...         NaN     NaN        NaN   NaN   457.13  NaN   457.13     NaN
#   18   ...         NaN     NaN        NaN   NaN   457.37  NaN   457.37     NaN
#   19   ...         NaN     NaN        NaN   NaN  484.433  NaN  484.433     NaN
#   20   ...         NaN     NaN        NaN   NaN  462.534  NaN  462.534     NaN
#   21   ...         NaN     NaN        NaN   NaN  491.775  NaN  491.775     NaN
#   22   ...         NaN     NaN        NaN   NaN  461.959  NaN  461.959     NaN
#   23   ...         NaN     NaN        NaN   NaN  489.199  NaN  489.199     NaN
#   24   ...         NaN     NaN        NaN   NaN  463.591  NaN  463.591     NaN
#   25   ...         NaN     NaN        NaN   NaN  451.109  NaN  451.109     NaN
#   26   ...         NaN     NaN        NaN   NaN  450.531  NaN  450.531     NaN
#   27   ...         NaN     NaN        NaN   NaN  461.676  NaN  461.676     NaN
#   28   ...         NaN     NaN        NaN   NaN  483.851  NaN  483.851     NaN
#   29   ...         NaN     NaN        NaN   NaN  499.864  NaN  499.864     NaN
#   30   ...         NaN     NaN        NaN   NaN  478.294  NaN  478.294     NaN
#   ..   ...         ...     ...        ...   ...      ...  ...      ...     ...
#   371  ...         NaN     NaN        NaN   NaN  456.805  NaN  456.805     NaN
#   372  ...         NaN     NaN        NaN   NaN  469.895  NaN  469.895     NaN
#   373  ...         NaN     NaN        NaN   NaN  469.163  NaN  469.163     NaN
#   374  ...         NaN     NaN        NaN   NaN  480.483  NaN  480.483     NaN
#   375  ...         NaN     NaN        NaN   NaN  476.917  NaN  476.917     NaN
#   376  ...         NaN     NaN        NaN   NaN  489.795  NaN  489.795     NaN
#   377  ...         NaN     NaN        NaN   NaN  472.451  NaN  472.451     NaN
#   378  ...         NaN     NaN        NaN   NaN  498.362  NaN  498.362     NaN
#   379  ...         NaN     NaN        NaN   NaN  469.095  NaN  469.095     NaN
#   380  ...         NaN     NaN        NaN   NaN  451.415  NaN  451.415     NaN
#   381  ...         NaN     NaN        NaN   NaN  483.715  NaN  483.715     NaN
#   382  ...         NaN     NaN        NaN   NaN  481.388  NaN  481.388     NaN
#   383  ...         NaN     NaN        NaN   NaN  453.449  NaN  453.449     NaN
#   384  ...         NaN     NaN        NaN   NaN  479.715  NaN  479.715     NaN
#   385  ...         NaN     NaN        NaN   NaN  492.314  NaN  492.314     NaN
#   386  ...         NaN     NaN        NaN   NaN  481.697  NaN  481.697     NaN
#   387  ...         NaN     NaN        NaN   NaN  475.868  NaN  475.868     NaN
#   388  ...         NaN     NaN        NaN   NaN  497.891  NaN  497.891     NaN
#   389  ...         NaN     NaN        NaN   NaN  457.383  NaN  457.383     NaN
#   390  ...         NaN     NaN        NaN   NaN  455.995  NaN  455.995     NaN
#   391  ...         NaN     NaN        NaN   NaN  463.887  NaN  463.887     NaN
#   392  ...         NaN     NaN        NaN   NaN  464.844  NaN  464.844     NaN
#   393  ...         NaN     NaN        NaN   NaN  496.257  NaN  496.257     NaN
#   394  ...         NaN     NaN        NaN   NaN  498.344  NaN  498.344     NaN
#   395  ...         NaN     NaN        NaN   NaN  499.612  NaN  499.612     NaN
#   396  ...         NaN     NaN        NaN   NaN  495.146  NaN  495.146     NaN
#   397  ...         NaN     NaN        NaN   NaN  461.717  NaN  461.717     NaN
#   398  ...         NaN     NaN        NaN   NaN  464.254  NaN  464.254     NaN
#   399  ...         NaN     NaN        NaN   NaN  475.862  NaN  475.862     NaN
#   400  ...         NaN     NaN        NaN   NaN  482.299  NaN  482.299     NaN
#
#       Trial_N_Block Block
#   1             NaN   NaN
#   2             NaN   NaN
#   3             NaN   NaN
#   4             NaN   NaN
#   5             NaN   NaN
#   6             NaN   NaN
#   7             NaN   NaN
#   8             NaN   NaN
#   9             NaN   NaN
#   10            NaN   NaN
#   11            NaN   NaN
#   12            NaN   NaN
#   13            NaN   NaN
#   14            NaN   NaN
#   15            NaN   NaN
#   16            NaN   NaN
#   17            NaN   NaN
#   18            NaN   NaN
#   19            NaN   NaN
#   20            NaN   NaN
#   21            NaN   NaN
#   22            NaN   NaN
#   23            NaN   NaN
#   24            NaN   NaN
#   25            NaN   NaN
#   26            NaN   NaN
#   27            NaN   NaN
#   28            NaN   NaN
#   29            NaN   NaN
#   30            NaN   NaN
#   ..            ...   ...
#   371           NaN   NaN
#   372           NaN   NaN
#   373           NaN   NaN
#   374           NaN   NaN
#   375           NaN   NaN
#   376           NaN   NaN
#   377           NaN   NaN
#   378           NaN   NaN
#   379           NaN   NaN
#   380           NaN   NaN
#   381           NaN   NaN
#   382           NaN   NaN
#   383           NaN   NaN
#   384           NaN   NaN
#   385           NaN   NaN
#   386           NaN   NaN
#   387           NaN   NaN
#   388           NaN   NaN
#   389           NaN   NaN
#   390           NaN   NaN
#   391           NaN   NaN
#   392           NaN   NaN
#   393           NaN   NaN
#   394           NaN   NaN
#   395           NaN   NaN
#   396           NaN   NaN
#   397           NaN   NaN
#   398           NaN   NaN
#   399           NaN   NaN
#   400           NaN   NaN
#
#   [400 rows x 21 columns])}

# %%
tdf = gen_test()
out_df,notes = process(tdf)
# Out:
# MEAN TO:  473.756391975
# WINDOW:  374.323373188 573.189410763
# TO rejects n:  12
# VS rejects N:  12

# %%
tdf['RT_TO']
# Out:
# 1      453.669
# 2      469.624
# 3      470.543
# 4       487.82
# 5      456.196
# 6      463.708
# 7      462.122
# 8      468.479
# 9       484.22
# 10     496.235
# 11     495.515
# 12     476.547
# 13     463.657
# 14     489.695
# 15     452.723
# 16     478.869
# 17      457.13
# 18      457.37
# 19     484.433
# 20     462.534
# 21     491.775
# 22     461.959
# 23     489.199
# 24     463.591
# 25     451.109
# 26     450.531
# 27     461.676
# 28     483.851
# 29     499.864
# 30     478.294
#         ...
# 371    456.805
# 372    469.895
# 373    469.163
# 374    480.483
# 375    476.917
# 376    489.795
# 377    472.451
# 378    498.362
# 379    469.095
# 380    451.415
# 381    483.715
# 382    481.388
# 383    453.449
# 384    479.715
# 385    492.314
# 386    481.697
# 387    475.868
# 388    497.891
# 389    457.383
# 390    455.995
# 391    463.887
# 392    464.844
# 393    496.257
# 394    498.344
# 395    499.612
# 396    495.146
# 397    461.717
# 398    464.254
# 399    475.862
# 400    482.299
# Name: RT_TO, Length: 400, dtype: object

# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pdb
#%pdb
mypath = 'E:/OneDrive - University College London/load/pilot_6_data/'
#mypath = 'C:/Users/KeK/OneDrive - University College London/load/pilot_6_data/'
# %load_ext autoreload
# %autoreload 2

from process import *
from test import *

# %%
df,notes = process('test')
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-21-524e7a184a90> in <module>()
# ----> 1 df,notes = process('test')
#
# C:\Users\nilli lab\Desktop\load\analysis\process.py in process(obs)
#      61         if df.loc[i,'RT_VS'] != None:
#      62             if not (low < df.loc[i,'RT_VS'] < high):
# ---> 63                 df.loc[i,'RT_VS'] = new_mean_VS
#      64
#      65
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in __setitem__(self, key, value)
#     177             key = com._apply_if_callable(key, self.obj)
#     178         indexer = self._get_setitem_indexer(key)
# --> 179         self._setitem_with_indexer(indexer, value)
#     180
#     181     def _has_valid_type(self, k, axis):
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in _setitem_with_indexer(self, indexer, value)
#     441
#     442             if isinstance(value, ABCSeries):
# --> 443                 value = self._align_series(indexer, value)
#     444
#     445             info_idx = indexer[info_axis]
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in _align_series(self, indexer, ser, multiindex_indexer)
#     743             return ser.reindex(ax)._values
#     744
# --> 745         raise ValueError('Incompatible indexer with Series')
#     746
#     747     def _align_frame(self, indexer, df):
#
# ValueError: Incompatible indexer with Series

# %%
test = df[df['RT_TO'].between(3,4)]

# %%
f = '../output/participant_test.pik'
import pickle
with open(f,'r') as of:
    D = pickle.load(of)
new_df = pd.DataFrame.from_dict(D['experiment_details'],orient='index')

# %%
new_df
# Out:
#           cat_4   cat_5  tone_hz  tone_onset         cat_1         cat_2  \
# 1           NaN     NaN  No tone        -999           cat           NaN
# 2           NaN     NaN  No tone        -999         horse           NaN
# 3           NaN     NaN  No tone        -999        person          sofa
# 4           NaN     NaN  No tone        -999           car        person
# 5           NaN     NaN  No tone        -999           dog           NaN
# 6           NaN     NaN  No tone        -999          boat           NaN
# 7           NaN     NaN  No tone        -999          boat           NaN
# 8           NaN     NaN  No tone        -999          boat           NaN
# 9           NaN     NaN  No tone        -999        bottle           NaN
# 10          NaN     NaN  No tone        -999           dog           NaN
# 11          NaN     NaN  No tone        -999        person           dog
# 12          NaN     NaN  No tone        -999           cat           NaN
# 13          NaN     NaN  No tone        -999           car           NaN
# 14          NaN     NaN  No tone        -999        person        bottle
# 15          NaN     NaN  No tone        -999        person          boat
# 16          NaN     NaN  No tone        -999        person           NaN
# 17          NaN     NaN  No tone        -999        person           NaN
# 18          NaN     NaN  No tone        -999        person           cat
# 19          NaN     NaN  No tone        -999         horse           NaN
# 20          NaN     NaN  No tone        -999           dog           NaN
# 21          NaN     NaN  No tone        -999        person           NaN
# 22          NaN     NaN  No tone        -999        bottle           NaN
# 23          NaN     NaN  No tone        -999          boat           NaN
# 24          NaN     NaN  No tone        -999           cat           NaN
# 25          NaN     NaN  No tone        -999          sofa        person
# 26          NaN     NaN  No tone        -999         chair   diningtable
# 27          NaN     NaN  No tone        -999          bird           NaN
# 28          NaN     NaN    tone1         765           dog        bottle
# 29          NaN     NaN  No tone        -999     aeroplane           NaN
# 30          NaN     NaN  No tone        -999          boat           NaN
# ..          ...     ...      ...         ...           ...           ...
# 931   tvmonitor   chair  No tone        -999        person        bottle
# 932         NaN     NaN  No tone        -999        person         horse
# 933         NaN     NaN  No tone        -999          sofa         chair
# 934         NaN     NaN  No tone        -999        person          sofa
# 935         NaN     NaN  No tone        -999        person          bird
# 936         NaN     NaN  No tone        -999   pottedplant         chair
# 937         NaN     NaN  No tone        -999          boat           cow
# 938         NaN     NaN  No tone        -999        person   diningtable
# 939         NaN     NaN  No tone        -999          bird          boat
# 940         NaN     NaN  No tone        -999        person     aeroplane
# 941         NaN     NaN  No tone        -999           car           NaN
# 942         NaN     NaN  No tone        -999           car        person
# 943         NaN     NaN    tone2         786        person         horse
# 944         NaN     NaN  No tone        -999         chair   diningtable
# 945         NaN     NaN  No tone        -999        person         horse
# 946         NaN     NaN  No tone        -999         chair        bottle
# 947         NaN     NaN    tone1         448     tvmonitor   diningtable
# 948         NaN     NaN  No tone        -999           dog           NaN
# 949         NaN     NaN  No tone        -999           car           cat
# 950         NaN     NaN  No tone        -999           cat           NaN
# 951         NaN     NaN  No tone        -999          bird           NaN
# 952         NaN     NaN  No tone        -999           car          boat
# 953         NaN     NaN  No tone        -999        person     aeroplane
# 954      bottle     NaN  No tone        -999   pottedplant        person
# 955         NaN     NaN  No tone        -999        person           cat
# 956         NaN     NaN  No tone        -999   pottedplant        person
# 957         NaN     NaN  No tone        -999        person        bottle
# 958         NaN     NaN  No tone        -999        person   diningtable
# 959         NaN     NaN  No tone        -999        person         chair
# 960         NaN     NaN    tone2         536          boat           NaN
#
#             cat_3  keys  space      question   ...     load  present_absent  \
# 1             NaN  None  space           NaN   ...      low       No Target
# 2             NaN  None  space           NaN   ...      low       No Target
# 3             NaN  None  space           NaN   ...      low       No Target
# 4             NaN  None  space           NaN   ...      low       No Target
# 5             NaN  None  space           NaN   ...      low       No Target
# 6             NaN  None  space           NaN   ...      low       No Target
# 7             NaN  None  space           NaN   ...      low       No Target
# 8             NaN  None  space           NaN   ...      low       No Target
# 9             NaN     q  space          bird   ...      low   Target Absent
# 10            NaN  None  space           NaN   ...      low       No Target
# 11            NaN  None  space           NaN   ...      low       No Target
# 12            NaN     q  space           cat   ...      low  Target Present
# 13            NaN     q  space          boat   ...      low   Target Absent
# 14            NaN  None  space           NaN   ...      low       No Target
# 15            NaN  None  space           NaN   ...      low       No Target
# 16            NaN  None  space           NaN   ...      low       No Target
# 17            NaN  None  space           NaN   ...      low       No Target
# 18            NaN  None  space           NaN   ...      low       No Target
# 19            NaN  None  space           NaN   ...      low       No Target
# 20            NaN  None  space           NaN   ...      low       No Target
# 21            NaN  None  space           NaN   ...      low       No Target
# 22            NaN  None  space           NaN   ...      low       No Target
# 23            NaN  None  space           NaN   ...      low       No Target
# 24            NaN  None  space           NaN   ...      low       No Target
# 25            NaN  None  space           NaN   ...      low       No Target
# 26            NaN  None  space           NaN   ...      low       No Target
# 27            NaN  None  space           NaN   ...      low       No Target
# 28            NaN  None  space           NaN   ...      low       No Target
# 29            NaN  None  space           NaN   ...      low       No Target
# 30            NaN  None  space           NaN   ...      low       No Target
# ..            ...   ...    ...           ...   ...      ...             ...
# 931   pottedplant  None  space           NaN   ...     high       No Target
# 932           NaN  None  space           NaN   ...     high       No Target
# 933        person  None  space           NaN   ...     high       No Target
# 934           cat     q  space           cat   ...     high  Target Present
# 935          boat  None  space           NaN   ...     high       No Target
# 936           NaN  None  space           NaN   ...     high       No Target
# 937           NaN     q  space          boat   ...     high  Target Present
# 938        bottle  None  space           NaN   ...     high       No Target
# 939           NaN  None  space           NaN   ...     high       No Target
# 940           NaN  None  space           NaN   ...     high       No Target
# 941           NaN  None  space           NaN   ...     high       No Target
# 942           bus     q  space          bird   ...     high   Target Absent
# 943           NaN  None  space           NaN   ...     high       No Target
# 944           NaN  None  space           NaN   ...     high       No Target
# 945           NaN  None  space           NaN   ...     high       No Target
# 946           NaN  None  space           NaN   ...     high       No Target
# 947           cat  None  space           NaN   ...     high       No Target
# 948           NaN  None  space           NaN   ...     high       No Target
# 949           NaN  None  space           NaN   ...     high       No Target
# 950           NaN  None  space           NaN   ...     high       No Target
# 951           NaN  None  space           NaN   ...     high       No Target
# 952        person  None  space           NaN   ...     high       No Target
# 953           NaN     q  space   pottedplant   ...     high   Target Absent
# 954   diningtable  None  space           NaN   ...     high       No Target
# 955           NaN  None  space           NaN   ...     high       No Target
# 956           dog  None  space           NaN   ...     high       No Target
# 957          sofa  None  space           NaN   ...     high       No Target
# 958        bottle     q  space          sofa   ...     high   Target Absent
# 959        bottle     q  space         chair   ...     high  Target Present
# 960           NaN  None  space           NaN   ...     high       No Target
#
#     block_number  RT_VS      exemplar  trueskill  RT_TO  trial_type  \
# 1              1    NaN           cat  12.729033  6.666      Normal
# 2              1    NaN         horse  19.234401  6.666      Normal
# 3              1    NaN          sofa  19.244036  6.666      Normal
# 4              1    NaN           car  20.695715  6.666      Normal
# 5              1    NaN           dog  20.074686  6.666      Normal
# 6              1    NaN          boat  20.210044  6.666      Normal
# 7              1    NaN          boat  21.198620  6.666      Normal
# 8              1    NaN          boat  16.846337  6.666      Normal
# 9              1   6.66        bottle  19.096237  6.666      Normal
# 10             1    NaN           dog  17.102590  6.666      Normal
# 11             1    NaN           dog  20.712899  6.666      Normal
# 12             1   6.66           cat  20.463884  6.666      Normal
# 13             1   6.66           car  19.030178  6.666      Normal
# 14             1    NaN        bottle  19.869099  6.666      Normal
# 15             1    NaN        person  18.642450  6.666      Normal
# 16             1    NaN        person  15.903696  6.666      Normal
# 17             1    NaN        person  21.051373  6.666      Normal
# 18             1    NaN        person  20.139878  6.666      Normal
# 19             1    NaN         horse  20.957748  6.666      Normal
# 20             1    NaN           dog  18.045036  6.666      Normal
# 21             1    NaN        person  18.879558  6.666      Normal
# 22             1    NaN        bottle  16.598875  6.666      Normal
# 23             1    NaN          boat  19.253520  6.666      Normal
# 24             1    NaN           cat  20.537354  6.666      Normal
# 25             1    NaN          sofa  20.983298  6.666      Normal
# 26             1    NaN         chair  20.735146  6.666      Normal
# 27             1    NaN          bird  19.239146  6.666      Normal
# 28             1    NaN        bottle  18.860703  6.666    Critical
# 29             1    NaN     aeroplane  20.158044  6.666      Normal
# 30             1    NaN          boat  19.264338  6.666      Normal
# ..           ...    ...           ...        ...    ...         ...
# 931           16    NaN        bottle  31.676386  6.666      Normal
# 932           16    NaN         horse  30.530490  6.666      Normal
# 933           16    NaN          sofa  36.443792  6.666      Normal
# 934           16   6.66           cat  29.514190  6.666      Normal
# 935           16    NaN          bird  31.913410  6.666      Normal
# 936           16    NaN   pottedplant  34.966628  6.666      Normal
# 937           16   6.66          boat  29.659407  6.666      Normal
# 938           16    NaN        bottle  38.972642  6.666      Normal
# 939           16    NaN          bird  29.314234  6.666      Normal
# 940           16    NaN     aeroplane  31.885878  6.666      Normal
# 941           16    NaN           car  30.394048  6.666      Normal
# 942           16   6.66           car  35.069419  6.666      Normal
# 943           16    NaN         horse  31.310600  6.666    Critical
# 944           16    NaN         chair  29.119691  6.666      Normal
# 945           16    NaN         horse  29.265462  6.666      Normal
# 946           16    NaN         chair  30.424874  6.666      Normal
# 947           16    NaN           cat  29.842923  6.666    Critical
# 948           16    NaN           dog  40.773121  6.666      Normal
# 949           16    NaN           cat  33.462185  6.666      Normal
# 950           16    NaN           cat  31.779859  6.666      Normal
# 951           16    NaN          bird  29.176311  6.666      Normal
# 952           16    NaN          boat  32.759267  6.666      Normal
# 953           16   6.66     aeroplane  30.242937  6.666      Normal
# 954           16    NaN   pottedplant  28.939513  6.666      Normal
# 955           16    NaN           cat  32.265109  6.666      Normal
# 956           16    NaN           dog  30.007374  6.666      Normal
# 957           16    NaN        bottle  33.561186  6.666      Normal
# 958           16   6.66        bottle  36.485056  6.666      Normal
# 959           16   6.66         chair  33.381115  6.666      Normal
# 960           16    NaN          boat  34.967528  6.666    Critical
#
#     image_number  useless
# 1              0      NaN
# 2              1      NaN
# 3              2      NaN
# 4              3      NaN
# 5              4      NaN
# 6              5      NaN
# 7              6      NaN
# 8              7      NaN
# 9              8   -999.0
# 10             9      NaN
# 11            10      NaN
# 12            11   -999.0
# 13            12   -999.0
# 14            13      NaN
# 15            14      NaN
# 16            15      NaN
# 17            16      NaN
# 18            17      NaN
# 19            18      NaN
# 20            19      NaN
# 21            20      NaN
# 22            21      NaN
# 23            22      NaN
# 24            23      NaN
# 25            24      NaN
# 26            25      NaN
# 27            26      NaN
# 28            27      NaN
# 29            28      NaN
# 30            29      NaN
# ..           ...      ...
# 931           30      NaN
# 932           31      NaN
# 933           32      NaN
# 934           33   -999.0
# 935           34      NaN
# 936           35      NaN
# 937           36   -999.0
# 938           37      NaN
# 939           38      NaN
# 940           39      NaN
# 941           40      NaN
# 942           41   -999.0
# 943           42      NaN
# 944           43      NaN
# 945           44      NaN
# 946           45      NaN
# 947           46      NaN
# 948           47      NaN
# 949           48      NaN
# 950           49      NaN
# 951           50      NaN
# 952           51      NaN
# 953           52   -999.0
# 954           53      NaN
# 955           54      NaN
# 956           55      NaN
# 957           56      NaN
# 958           57   -999.0
# 959           58   -999.0
# 960           59      NaN
#
# [960 rows x 21 columns]

# %%
D['experiment_details'][1].keys()
# Out:
# ['cat_4',
#  'cat_5',
#  'tone_hz',
#  'tone_onset',
#  'cat_1',
#  'cat_2',
#  'cat_3',
#  'keys',
#  'space',
#  'question',
#  'image_name',
#  'load',
#  'present_absent',
#  'block_number',
#  'RT_VS',
#  'exemplar',
#  'trueskill',
#  'RT_TO',
#  'trial_type',
#  'image_number',
#  'useless']

# %%
df['RT_VS'].between(0, 10, inclusive=False)
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
#        ...
# 931    False
# 932    False
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# 943    False
# 944    False
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# Name: RT_VS, Length: 960, dtype: bool

# %%
df['RT_TO'].between(low, high, inclusive=False).mean()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-7c42a49a31a1> in <module>()
# ----> 1 df['RT_TO'].between(low, high, inclusive=False).mean()
#
# NameError: name 'low' is not defined

# %%
df
# Out:
#           Image_Name         Cat.1         Cat.2         Cat.3       Cat.4  \
# 1    2009_004225.jpg           cat           NaN           NaN         NaN
# 2    2010_001829.jpg         horse           NaN           NaN         NaN
# 3    2008_004270.jpg        person          sofa           NaN         NaN
# 4    2011_002303.jpg           car        person           NaN         NaN
# 5    2010_005885.jpg           dog           NaN           NaN         NaN
# 6    2008_001040.jpg          boat           NaN           NaN         NaN
# 7    2010_004662.jpg          boat           NaN           NaN         NaN
# 8    2010_005780.jpg          boat           NaN           NaN         NaN
# 9    2009_002594.jpg        bottle           NaN           NaN         NaN
# 10   2009_001568.jpg           dog           NaN           NaN         NaN
# 11   2008_005046.jpg        person           dog           NaN         NaN
# 12   2008_001836.jpg           cat           NaN           NaN         NaN
# 13   2009_004594.jpg           car           NaN           NaN         NaN
# 14   2008_004814.jpg        person        bottle           NaN         NaN
# 15   2008_008083.jpg        person          boat           NaN         NaN
# 16   2008_001098.jpg        person           NaN           NaN         NaN
# 17   2008_002700.jpg        person           NaN           NaN         NaN
# 18   2009_002439.jpg        person           cat           NaN         NaN
# 19   2009_003232.jpg         horse           NaN           NaN         NaN
# 20   2010_000811.jpg           dog           NaN           NaN         NaN
# 21   2008_002145.jpg        person           NaN           NaN         NaN
# 22   2010_002956.jpg        bottle           NaN           NaN         NaN
# 23   2009_000919.jpg          boat           NaN           NaN         NaN
# 24   2009_000716.jpg           cat           NaN           NaN         NaN
# 25   2008_004269.jpg          sofa        person           NaN         NaN
# 26   2010_001271.jpg         chair   diningtable           NaN         NaN
# 27   2011_002582.jpg          bird           NaN           NaN         NaN
# 28   2010_000805.jpg           dog        bottle           NaN         NaN
# 29   2008_007096.jpg     aeroplane           NaN           NaN         NaN
# 30   2009_001723.jpg          boat           NaN           NaN         NaN
# ..               ...           ...           ...           ...         ...
# 931  2010_002742.jpg        person        bottle   pottedplant   tvmonitor
# 932  2009_000565.jpg        person         horse           NaN         NaN
# 933  2011_002971.jpg          sofa         chair        person         NaN
# 934  2010_005606.jpg        person          sofa           cat         NaN
# 935  2011_001001.jpg        person          bird          boat         NaN
# 936  2009_000198.jpg   pottedplant         chair           NaN         NaN
# 937  2008_002709.jpg          boat           cow           NaN         NaN
# 938  2010_001645.jpg        person   diningtable        bottle         NaN
# 939  2008_006481.jpg          bird          boat           NaN         NaN
# 940  2008_006216.jpg        person     aeroplane           NaN         NaN
# 941  2008_002672.jpg           car           NaN           NaN         NaN
# 942  2008_000982.jpg           car        person           bus         NaN
# 943  2011_000628.jpg        person         horse           NaN         NaN
# 944  2009_003520.jpg         chair   diningtable           NaN         NaN
# 945  2011_002555.jpg        person         horse           NaN         NaN
# 946  2008_005347.jpg         chair        bottle           NaN         NaN
# 947  2010_001939.jpg     tvmonitor   diningtable           cat         NaN
# 948  2008_007057.jpg           dog           NaN           NaN         NaN
# 949  2008_000619.jpg           car           cat           NaN         NaN
# 950  2011_000824.jpg           cat           NaN           NaN         NaN
# 951  2008_000192.jpg          bird           NaN           NaN         NaN
# 952  2008_000833.jpg           car          boat        person         NaN
# 953  2010_005106.jpg        person     aeroplane           NaN         NaN
# 954  2011_001382.jpg   pottedplant        person   diningtable      bottle
# 955  2008_007913.jpg        person           cat           NaN         NaN
# 956  2008_002084.jpg   pottedplant        person           dog         NaN
# 957  2010_004447.jpg        person        bottle          sofa         NaN
# 958  2008_002864.jpg        person   diningtable        bottle         NaN
# 959  2011_002641.jpg        person         chair        bottle         NaN
# 960  2010_002620.jpg          boat           NaN           NaN         NaN
#
#       Cat.5       TS  Load      exemplar      question  ...  trial_type  \
# 1       NaN   12.729   low           cat           NaN  ...      Normal
# 2       NaN  19.2344   low         horse           NaN  ...      Normal
# 3       NaN   19.244   low          sofa           NaN  ...      Normal
# 4       NaN  20.6957   low           car           NaN  ...      Normal
# 5       NaN  20.0747   low           dog           NaN  ...      Normal
# 6       NaN    20.21   low          boat           NaN  ...      Normal
# 7       NaN  21.1986   low          boat           NaN  ...      Normal
# 8       NaN  16.8463   low          boat           NaN  ...      Normal
# 9       NaN  19.0962   low        bottle          bird  ...      Normal
# 10      NaN  17.1026   low           dog           NaN  ...      Normal
# 11      NaN  20.7129   low           dog           NaN  ...      Normal
# 12      NaN  20.4639   low           cat           cat  ...      Normal
# 13      NaN  19.0302   low           car          boat  ...      Normal
# 14      NaN  19.8691   low        bottle           NaN  ...      Normal
# 15      NaN  18.6425   low        person           NaN  ...      Normal
# 16      NaN  15.9037   low        person           NaN  ...      Normal
# 17      NaN  21.0514   low        person           NaN  ...      Normal
# 18      NaN  20.1399   low        person           NaN  ...      Normal
# 19      NaN  20.9577   low         horse           NaN  ...      Normal
# 20      NaN   18.045   low           dog           NaN  ...      Normal
# 21      NaN  18.8796   low        person           NaN  ...      Normal
# 22      NaN  16.5989   low        bottle           NaN  ...      Normal
# 23      NaN  19.2535   low          boat           NaN  ...      Normal
# 24      NaN  20.5374   low           cat           NaN  ...      Normal
# 25      NaN  20.9833   low          sofa           NaN  ...      Normal
# 26      NaN  20.7351   low         chair           NaN  ...      Normal
# 27      NaN  19.2391   low          bird           NaN  ...      Normal
# 28      NaN  18.8607   low        bottle           NaN  ...    Critical
# 29      NaN   20.158   low     aeroplane           NaN  ...      Normal
# 30      NaN  19.2643   low          boat           NaN  ...      Normal
# ..      ...      ...   ...           ...           ...  ...         ...
# 931   chair  31.6764  high        bottle           NaN  ...      Normal
# 932     NaN  30.5305  high         horse           NaN  ...      Normal
# 933     NaN  36.4438  high          sofa           NaN  ...      Normal
# 934     NaN  29.5142  high           cat           cat  ...      Normal
# 935     NaN  31.9134  high          bird           NaN  ...      Normal
# 936     NaN  34.9666  high   pottedplant           NaN  ...      Normal
# 937     NaN  29.6594  high          boat          boat  ...      Normal
# 938     NaN  38.9726  high        bottle           NaN  ...      Normal
# 939     NaN  29.3142  high          bird           NaN  ...      Normal
# 940     NaN  31.8859  high     aeroplane           NaN  ...      Normal
# 941     NaN   30.394  high           car           NaN  ...      Normal
# 942     NaN  35.0694  high           car          bird  ...      Normal
# 943     NaN  31.3106  high         horse           NaN  ...    Critical
# 944     NaN  29.1197  high         chair           NaN  ...      Normal
# 945     NaN  29.2655  high         horse           NaN  ...      Normal
# 946     NaN  30.4249  high         chair           NaN  ...      Normal
# 947     NaN  29.8429  high           cat           NaN  ...    Critical
# 948     NaN  40.7731  high           dog           NaN  ...      Normal
# 949     NaN  33.4622  high           cat           NaN  ...      Normal
# 950     NaN  31.7799  high           cat           NaN  ...      Normal
# 951     NaN  29.1763  high          bird           NaN  ...      Normal
# 952     NaN  32.7593  high          boat           NaN  ...      Normal
# 953     NaN  30.2429  high     aeroplane   pottedplant  ...      Normal
# 954     NaN  28.9395  high   pottedplant           NaN  ...      Normal
# 955     NaN  32.2651  high           cat           NaN  ...      Normal
# 956     NaN  30.0074  high           dog           NaN  ...      Normal
# 957     NaN  33.5612  high        bottle           NaN  ...      Normal
# 958     NaN  36.4851  high        bottle          sofa  ...      Normal
# 959     NaN  33.3811  high         chair         chair  ...      Normal
# 960     NaN  34.9675  high          boat           NaN  ...    Critical
#
#      tone_Hz tone_onset  space RT_TO  keys RT_VS useless Trial_N_Block Block
# 1    No tone       -999  space     0  None  None    None             0     1
# 2    No tone       -999  space     0  None  None    None             0     1
# 3    No tone       -999  space     0  None  None    None             0     1
# 4    No tone       -999  space     0  None  None    None             0     1
# 5    No tone       -999  space     0  None  None    None             0     1
# 6    No tone       -999  space     0  None  None    None             0     1
# 7    No tone       -999  space     0  None  None    None             0     1
# 8    No tone       -999  space     0  None  None    None             0     1
# 9    No tone       -999  space     0     q     0    -999             0     1
# 10   No tone       -999  space     0  None  None    None             0     1
# 11   No tone       -999  space     0  None  None    None             0     1
# 12   No tone       -999  space     0     q     0    -999             0     1
# 13   No tone       -999  space     0     q     0    -999             0     1
# 14   No tone       -999  space     0  None  None    None             0     1
# 15   No tone       -999  space     0  None  None    None             0     1
# 16   No tone       -999  space     0  None  None    None             0     1
# 17   No tone       -999  space     0  None  None    None             0     1
# 18   No tone       -999  space     0  None  None    None             0     1
# 19   No tone       -999  space     0  None  None    None             0     1
# 20   No tone       -999  space     0  None  None    None             0     1
# 21   No tone       -999  space     0  None  None    None             0     1
# 22   No tone       -999  space     0  None  None    None             0     1
# 23   No tone       -999  space     0  None  None    None             0     1
# 24   No tone       -999  space     0  None  None    None             0     1
# 25   No tone       -999  space     0  None  None    None             0     1
# 26   No tone       -999  space     0  None  None    None             0     1
# 27   No tone       -999  space     0  None  None    None             0     1
# 28     tone1        765  space     0  None  None    None             0     1
# 29   No tone       -999  space     0  None  None    None             0     1
# 30   No tone       -999  space     0  None  None    None             0     1
# ..       ...        ...    ...   ...   ...   ...     ...           ...   ...
# 931  No tone       -999  space     0  None  None    None             0    16
# 932  No tone       -999  space     0  None  None    None             0    16
# 933  No tone       -999  space     0  None  None    None             0    16
# 934  No tone       -999  space     0     q     0    -999             0    16
# 935  No tone       -999  space     0  None  None    None             0    16
# 936  No tone       -999  space     0  None  None    None             0    16
# 937  No tone       -999  space     0     q     0    -999             0    16
# 938  No tone       -999  space     0  None  None    None             0    16
# 939  No tone       -999  space     0  None  None    None             0    16
# 940  No tone       -999  space     0  None  None    None             0    16
# 941  No tone       -999  space     0  None  None    None             0    16
# 942  No tone       -999  space     0     q     0    -999             0    16
# 943    tone2        786  space     0  None  None    None             0    16
# 944  No tone       -999  space     0  None  None    None             0    16
# 945  No tone       -999  space     0  None  None    None             0    16
# 946  No tone       -999  space     0  None  None    None             0    16
# 947    tone1        448  space     0  None  None    None             0    16
# 948  No tone       -999  space     0  None  None    None             0    16
# 949  No tone       -999  space     0  None  None    None             0    16
# 950  No tone       -999  space     0  None  None    None             0    16
# 951  No tone       -999  space     0  None  None    None             0    16
# 952  No tone       -999  space     0  None  None    None             0    16
# 953  No tone       -999  space     0     q     0    -999             0    16
# 954  No tone       -999  space     0  None  None    None             0    16
# 955  No tone       -999  space     0  None  None    None             0    16
# 956  No tone       -999  space     0  None  None    None             0    16
# 957  No tone       -999  space     0  None  None    None             0    16
# 958  No tone       -999  space     0     q     0    -999             0    16
# 959  No tone       -999  space     0     q     0    -999             0    16
# 960    tone2        536  space     0  None  None    None             0    16
#
# [960 rows x 21 columns]

# %%
df.loc[2,'RT_TO'] = None

# %%
df['RT_TO']
# Out:
# 1        6.666
# 2        6.666
# 3        6.666
# 4        6.666
# 5        6.666
# 6        6.666
# 7        6.666
# 8        6.666
# 9        6.666
# 10       6.666
# 11       6.666
# 12       6.666
# 13       6.666
# 14       6.666
# 15       6.666
# 16       6.666
# 17       6.666
# 18       6.666
# 19       6.666
# 20       6.666
# 21       6.666
# 22       6.666
# 23       6.666
# 24       6.666
# 25       6.666
# 26       6.666
# 27       6.666
# 28       6.666
# 29       6.666
# 30       6.666
#          ...
# 932      6.666
# 933      6.666
# 934      6.666
# 935      6.666
# 936      6.666
# 937      6.666
# 938      6.666
# 939      6.666
# 940      6.666
# 941      6.666
# 942      6.666
# 943      6.666
# 944      6.666
# 945      6.666
# 946      6.666
# 947      6.666
# 948      6.666
# 949      6.666
# 950      6.666
# 951      6.666
# 952      6.666
# 953      6.666
# 954      6.666
# 955      6.666
# 956      6.666
# 957      6.666
# 958      6.666
# 959      6.666
# 960      6.666
# RT_TO      NaN
# Name: RT_TO, Length: 961, dtype: object

# %%
df.loc['Image_Name',1]
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-26-b5fd4a05b48c> in <module>()
# ----> 1 df.loc['Image_Name',1]
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in _getitem_lowerdim(self, tup)
#     965         for i, key in enumerate(tup):
#     966             if is_label_like(key) or isinstance(key, tuple):
# --> 967                 section = self._getitem_axis(key, axis=i)
#     968
#     969                 # we have yielded a scalar ?
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in _has_valid_type(self, key, axis)
#    1440                 raise
#    1441             except:
# -> 1442                 error()
#    1443
#    1444         return True
#
# C:\ProgramData\Anaconda2_32\lib\site-packages\pandas\core\indexing.pyc in error()
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#    1431             try:
#
# KeyError: 'the label [Image_Name] is not in the [index]'

# %%
results = []
for o in observers:
    result = process_observer(o)
    results.append(result)
# Out:
# DIRTY! 2
# DIRTY! 22
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 91
# DIRTY! 93
# DIRTY! 107
# DIRTY! 160
# DIRTY! 172
# DIRTY! 207
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# DIRTY! 245
# DIRTY! 253
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 319
# DIRTY! 322
# DIRTY! 336
# FOUND RT IN FIRST 337
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 379
# FOUND RT IN FIRST 380
# DIRTY! 417
# DIRTY! 440
# DIRTY! 443
# DIRTY! 451
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 526
# DIRTY! 532
# DIRTY! 541
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 637
# FOUND RT IN FIRST 638
# DIRTY! 646
# DIRTY! 710
# DIRTY! 761
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 810
# DIRTY! 828
# DIRTY! 837
# DIRTY! 841
# DIRTY! 869
# DIRTY! 901
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# DIRTY! 929
# DIRTY! 934
# Take Over:
# mean RT:  1.21444117647
# SD:  0.250411800978
# Outliers:  0
# Visual Search:
# mean RT:  0.929076388889
# SD:  0.210972848433
# Outliers:  4
# 2.19
# 1.462
# 1.478
# 1.816
# 0.759036144578
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 57 66
# CC:
# 50 65
# CC:
# 107 131
# 4    848
# 1     63
# 2     32
# 0     13
# 3      4
# Name: sdt, dtype: int64
# ---------
# 4    422
# 1     34
# 2     14
# 0      8
# 3      2
# Name: sdt, dtype: int64
# ---------
# 4    426
# 1     29
# 2     18
# 0      5
# 3      2
# Name: sdt, dtype: int64
# {'c': 1.0236959533474321, 'beta': 25.001776742370616, 'd': 3.1444364720910603, 'Ad': 0.98690734355292931}
# {'c': 1.1507360331257703, 'beta': 28.035141494277774, 'd': 2.8968057666243325, 'Ad': 0.97973719051325792}
# Load     Acc_VS
#  'high'  0         0.941933
#          1         0.925063
#          666            NaN
#          999       0.842571
#  'low'   0         0.817675
#          1         0.899212
#          666       0.967000
#          999       0.939200
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         15
#          1         50
#          666        0
#          999        7
#  'low'   0          9
#          1         57
#          666        1
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.736793
#                       999       0.816000
#           'Normal'    666       1.058500
#                       999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.743588
#           'Normal'    666       1.379000
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          18
#                       1          29
#                       999         1
#           'Normal'    666         2
#                       999       430
#  'low'    'Critical'  0          14
#                       1          34
#           'Normal'    666         2
#                       999       430
# Name: Acc_DT, dtype: int64
# DIRTY! 207
# DIRTY! 283
# DIRTY! 417
# DIRTY! 440
# FOUND RT IN SECOND 442
# DIRTY! 726
# DIRTY! 761
# DIRTY! 766
# DIRTY! 794
# DIRTY! 804
# DIRTY! 841
# DIRTY! 901
# DIRTY! 907
# DIRTY! 911
# DIRTY! 929
# DIRTY! 934
# Take Over:
# mean RT:  1.24885882353
# SD:  1.76767268831
# Outliers:  1
# -14.5
# Visual Search:
# mean RT:  1.75756944444
# SD:  0.962669657867
# Outliers:  4
# 4.389
# 4.474
# 8.16
# 4.55
# 0.872340425532
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 59 66
# CC:
# 50 65
# CC:
# 109 131
# 4    859
# 1     82
# 2     14
# 3      3
# 0      2
# Name: sdt, dtype: int64
# ---------
# 4    430
# 1     43
# 2      5
# 3      2
# Name: sdt, dtype: int64
# ---------
# 4    429
# 1     39
# 2      9
# 0      2
# 3      1
# Name: sdt, dtype: int64
# {'c': 0.67208443329700862, 'beta': 13.390916051725734, 'd': 3.8604919887202107, 'Ad': 0.99683117042719505}
# {'c': 0.97155177859414188, 'beta': 37.02685097792302, 'd': 3.7173966752260359, 'Ad': 0.99571309742558678}
# Load     Acc_VS
#  'high'  0         2.091600
#          1         1.549520
#          666            NaN
#          999       1.596571
#  'low'   0         2.024224
#          1         1.560605
#          666       3.201000
#          999       1.815000
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         15
#          1         50
#          666        0
#          999        7
#  'low'   0          7
#          1         59
#          666        1
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         1.089026
#           'Normal'    666       0.792000
#                       999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.935741
#           'Normal'    666       0.494500
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0           9
#                       1          39
#           'Normal'    666         1
#                       999       431
#  'low'    'Critical'  0           5
#                       1          43
#           'Normal'    666         2
#                       999       430
# Name: Acc_DT, dtype: int64
# DIRTY! 107
# DIRTY! 132
# DIRTY! 175
# DIRTY! 283
# DIRTY! 440
# DIRTY! 483
# DIRTY! 612
# DIRTY! 837
# DIRTY! 841
# Take Over:
# mean RT:  1.18514772727
# SD:  0.487979776494
# Outliers:  1
# -2.68
# Visual Search:
# mean RT:  1.09506944444
# SD:  0.452403314606
# Outliers:  4
# 2.426
# 3.78
# 2.274
# 2.525
# 0.901098901099
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 56 67
# CC:
# 49 64
# CC:
# 105 131
# 4    863
# 1     82
# 2      9
# 0      5
# 3      1
# Name: sdt, dtype: int64
# ---------
# 4    432
# 1     42
# 2      3
# 0      3
# Name: sdt, dtype: int64
# ---------
# 4    431
# 1     40
# 2      6
# 0      2
# 3      1
# Name: sdt, dtype: int64
# {'c': 0.77273364670290634, 'beta': 33.58615107765381, 'd': 4.5476391854938623, 'Ad': 0.99934929013628182}
# {'c': 0.85369805132471555, 'beta': 29.291326265750364, 'd': 3.956072565786708, 'Ad': 0.99742394123298161}
# Load     Acc_VS
#  'high'  0         1.166071
#          1         1.048309
#          666       0.635000
#          999       1.066429
#  'low'   0         1.318734
#          1         0.940661
#          999       1.384800
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         15
#          1         49
#          666        1
#          999        7
#  'low'   0         11
#          1         56
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.733825
#                       999       0.665000
#           'Normal'    666       1.185148
#                       999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.758476
#                       999       0.806000
#           'Normal'    999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0           6
#                       1          40
#                       999         2
#           'Normal'    666         1
#                       999       431
#  'low'    'Critical'  0           3
#                       1          42
#                       999         3
#           'Normal'    999       432
# Name: Acc_DT, dtype: int64
# DIRTY! 172
# DIRTY! 209
# DIRTY! 242
# DIRTY! 245
# DIRTY! 308
# DIRTY! 379
# DIRTY! 433
# DIRTY! 541
# FOUND RT IN FIRST 542
# DIRTY! 612
# DIRTY! 663
# DIRTY! 775
# DIRTY! 810
# DIRTY! 837
# DIRTY! 878
# DIRTY! 901
# Take Over:
# mean RT:  1.22903658537
# SD:  0.343985835114
# Outliers:  3
# 2.588
# 2.36
# -0.22
# Visual Search:
# mean RT:  0.940208333333
# SD:  0.283065434009
# Outliers:  5
# 1.963
# 1.653
# 2.038
# 1.653
# 1.851
# 0.86170212766
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 63 67
# CC:
# 52 65
# CC:
# 115 132
# 4    863
# 1     81
# 2     14
# 0      2
# Name: sdt, dtype: int64
# ---------
# 4    432
# 1     41
# 2      7
# Name: sdt, dtype: int64
# ---------
# 4    431
# 1     40
# 2      7
# 0      2
# Name: sdt, dtype: int64
# {'c': 0.9960403938398924, 'beta': 59.429292505014274, 'd': 4.1010256912198901, 'Ad': 0.99813337149371661}
# {'c': 1.0024247806907227, 'beta': 60.14589128747726, 'd': 4.0868633848936797, 'Ad': 0.99807286428715303}
# Load     Acc_VS
#  'high'  0         0.986894
#          1         0.936196
#          999       0.794857
#  'low'   0         0.742500
#          1         0.891571
#          999       0.943642
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         13
#          1         52
#          999        7
#  'low'   0          4
#          1         63
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.777502
#                       999       0.884000
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.786977
#           'Normal'    999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0           7
#                       1          40
#                       999         1
#           'Normal'    999       432
#  'low'    'Critical'  0           7
#                       1          41
#           'Normal'    999       432
# Name: Acc_DT, dtype: int64
# DIRTY! 107
# DIRTY! 322
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 417
# DIRTY! 451
# DIRTY! 526
# DIRTY! 559
# DIRTY! 612
# FOUND RT IN SECOND 614
# DIRTY! 634
# DIRTY! 646
# DIRTY! 663
# DIRTY! 710
# DIRTY! 766
# DIRTY! 794
# DIRTY! 837
# DIRTY! 841
# DIRTY! 901
# DIRTY! 911
# DIRTY! 934
# Take Over:
# mean RT:  1.443625
# SD:  0.831911359085
# Outliers:  3
# -1.87
# 3.726
# -3.5
# Visual Search:
# mean RT:  1.16585416667
# SD:  0.440441397425
# Outliers:  5
# 2.875
# 2.557
# 3.208
# 2.578
# 2.396
# 0.846153846154
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 58 67
# CC:
# 50 65
# CC:
# 108 132
# 4    860
# 1     77
# 2     17
# 0      5
# 3      1
# Name: sdt, dtype: int64
# ---------
# 4    430
# 1     38
# 2      8
# 0      3
# 3      1
# Name: sdt, dtype: int64
# ---------
# 4    430
# 1     39
# 2      9
# 0      2
# Name: sdt, dtype: int64
# {'c': 0.94608942530917073, 'beta': 35.39515677151673, 'd': 3.7698074843721479, 'Ad': 0.99615809133836553}
# {'c': 1.0790056964574586, 'beta': 69.61492385251219, 'd': 3.9323045109526693, 'Ad': 0.99728673164901804}
# Load     Acc_VS
#  'high'  0         1.021067
#          1         1.122254
#          999       0.949857
#  'low'   0         1.262444
#          1         1.099547
#          666            NaN
#          999       1.376971
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         15
#          1         50
#          999        7
#  'low'   0          9
#          1         58
#          666        0
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         1.024221
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         1.050480
#                       999       1.782500
#           'Normal'    666       0.590000
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0           9
#                       1          39
#           'Normal'    999       432
#  'low'    'Critical'  0           8
#                       1          38
#                       999         2
#           'Normal'    666         1
#                       999       431
# Name: Acc_DT, dtype: int64
# DIRTY! 2
# DIRTY! 12
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 36
# FOUND RT IN FIRST 37
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 91
# FOUND RT IN FIRST 92
# DIRTY! 97
# DIRTY! 125
# FOUND RT IN FIRST 126
# DIRTY! 132
# FOUND RT IN FIRST 133
# DIRTY! 160
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 205
# FOUND RT IN FIRST 206
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 253
# FOUND RT IN FIRST 254
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 292
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 319
# FOUND RT IN FIRST 320
# DIRTY! 322
# DIRTY! 336
# FOUND RT IN FIRST 337
# DIRTY! 338
# DIRTY! 359
# DIRTY! 379
# DIRTY! 384
# FOUND RT IN FIRST 385
# DIRTY! 433
# FOUND RT IN FIRST 434
# DIRTY! 440
# DIRTY! 443
# FOUND RT IN FIRST 444
# DIRTY! 451
# DIRTY! 463
# DIRTY! 483
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 522
# FOUND RT IN FIRST 523
# DIRTY! 526
# DIRTY! 541
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 551
# DIRTY! 553
# DIRTY! 566
# DIRTY! 612
# DIRTY! 634
# DIRTY! 637
# DIRTY! 646
# DIRTY! 657
# DIRTY! 663
# DIRTY! 692
# FOUND RT IN FIRST 693
# DIRTY! 726
# DIRTY! 741
# DIRTY! 756
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 775
# DIRTY! 794
# DIRTY! 804
# DIRTY! 810
# FOUND RT IN FIRST 811
# DIRTY! 821
# FOUND RT IN FIRST 822
# DIRTY! 837
# DIRTY! 846
# DIRTY! 866
# DIRTY! 869
# FOUND RT IN FIRST 870
# DIRTY! 881
# FOUND RT IN FIRST 882
# DIRTY! 901
# FOUND RT IN FIRST 902
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# FOUND RT IN FIRST 912
# DIRTY! 929
# FOUND RT IN FIRST 930
# Take Over:
# mean RT:  1.28123076923
# SD:  0.345771902103
# Outliers:  2
# -0.25
# 2.219
# Visual Search:
# mean RT:  0.8764375
# SD:  0.21037624096
# Outliers:  4
# 1.647
# 1.456
# 1.455
# 1.411
# 0.96875
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 64 67
# CC:
# 55 65
# CC:
# 119 132
# 4    831
# 1     62
# 2     33
# 0     32
# 3      2
# Name: sdt, dtype: int64
# ---------
# 4    416
# 1     34
# 0     15
# 2     14
# 3      1
# Name: sdt, dtype: int64
# ---------
# 4    415
# 1     28
# 2     19
# 0     17
# 3      1
# Name: sdt, dtype: int64
# {'c': 1.1359461822971264, 'beta': 45.92139103022002, 'd': 3.3689369299904488, 'Ad': 0.99139518277349703}
# {'c': 1.2886481782977055, 'beta': 51.71927262947524, 'd': 3.0619920600790151, 'Ad': 0.98481210479282455}
# Load     Acc_VS
#  'high'  0         0.988900
#          1         0.888889
#          666            NaN
#          999       0.838286
#  'low'   0         0.800667
#          1         0.809701
#          666            NaN
#          999       0.975000
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         10
#          1         55
#          666        0
#          999        7
#  'low'   0          3
#          1         64
#          666        0
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.826723
#                       999       1.132000
#           'Normal'    666       1.281231
#                       999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.806647
#           'Normal'    666       0.549000
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          19
#                       1          28
#                       999         1
#           'Normal'    666         1
#                       999       431
#  'low'    'Critical'  0          14
#                       1          34
#           'Normal'    666         1
#                       999       431
# Name: Acc_DT, dtype: int64
# DIRTY! 12
# FOUND RT IN FIRST 13
# DIRTY! 15
# FOUND RT IN FIRST 16
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 36
# FOUND RT IN FIRST 37
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 107
# DIRTY! 125
# DIRTY! 160
# FOUND RT IN FIRST 161
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 175
# DIRTY! 190
# FOUND RT IN FIRST 191
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# DIRTY! 253
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 292
# FOUND RT IN FIRST 293
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 319
# FOUND RT IN FIRST 320
# DIRTY! 336
# FOUND RT IN FIRST 337
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 379
# FOUND RT IN FIRST 380
# DIRTY! 433
# FOUND RT IN FIRST 434
# DIRTY! 440
# DIRTY! 443
# FOUND RT IN FIRST 444
# DIRTY! 451
# FOUND RT IN FIRST 452
# DIRTY! 463
# FOUND RT IN FIRST 464
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 532
# FOUND RT IN FIRST 533
# DIRTY! 541
# FOUND RT IN FIRST 542
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 612
# FOUND RT IN FIRST 613
# DIRTY! 637
# FOUND RT IN FIRST 638
# DIRTY! 663
# DIRTY! 692
# DIRTY! 710
# DIRTY! 741
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 804
# DIRTY! 810
# FOUND RT IN FIRST 811
# DIRTY! 821
# FOUND RT IN FIRST 822
# DIRTY! 837
# DIRTY! 901
# FOUND RT IN FIRST 902
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# DIRTY! 929
# FOUND RT IN FIRST 930
# Take Over:
# mean RT:  1.27062650602
# SD:  0.2799709413
# Outliers:  3
# 2.003
# 1.989
# 2.168
# Visual Search:
# mean RT:  1.3383125
# SD:  0.65561592615
# Outliers:  4
# 3.043
# 4.108
# 3.994
# 5.682
# 1.33333333333
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 59 67
# CC:
# 53 65
# CC:
# 112 132
# 4    831
# 1     80
# 0     36
# 2     13
# Name: sdt, dtype: int64
# ---------
# 4    416
# 1     42
# 0     17
# 2      5
# Name: sdt, dtype: int64
# ---------
# 4    415
# 1     38
# 0     19
# 2      8
# Name: sdt, dtype: int64
# {'c': 0.894596866850212, 'beta': 46.05953905537339, 'd': 4.2811852229542975, 'Ad': 0.99876607203619117}
# {'c': 1.0478246264782551, 'beta': 64.2832061521254, 'd': 3.9732778867103167, 'Ad': 0.99751931864096954}
# Load     Acc_VS
#  'high'  0         1.331635
#          1         1.256717
#          999       1.054571
#  'low'   0         1.461164
#          1         1.176441
#          999       2.035263
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         12
#          1         53
#          999        7
#  'low'   0          8
#          1         59
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.809954
#                       999       0.740000
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.799967
#                       999       0.818000
#           'Normal'    999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0           8
#                       1          38
#                       999         2
#           'Normal'    999       432
#  'low'    'Critical'  0           5
#                       1          42
#                       999         1
#           'Normal'    999       432
# Name: Acc_DT, dtype: int64
# DIRTY! 2
# FOUND RT IN FIRST 3
# DIRTY! 12
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 91
# DIRTY! 107
# DIRTY! 125
# FOUND RT IN FIRST 126
# DIRTY! 139
# DIRTY! 160
# FOUND RT IN FIRST 161
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 190
# FOUND RT IN FIRST 191
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 245
# DIRTY! 253
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 292
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 336
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 359
# FOUND RT IN FIRST 360
# DIRTY! 379
# FOUND RT IN FIRST 380
# DIRTY! 417
# DIRTY! 440
# FOUND RT IN FIRST 441
# DIRTY! 443
# FOUND RT IN FIRST 444
# DIRTY! 451
# FOUND RT IN FIRST 452
# DIRTY! 493
# DIRTY! 532
# FOUND RT IN FIRST 533
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 551
# DIRTY! 612
# DIRTY! 637
# FOUND RT IN FIRST 638
# DIRTY! 646
# DIRTY! 761
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 810
# FOUND RT IN FIRST 811
# DIRTY! 901
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 929
# FOUND RT IN FIRST 930
# DIRTY! 934
# FOUND RT IN FIRST 935
# Take Over:
# mean RT:  1.19507407407
# SD:  0.605194423974
# Outliers:  1
# -3.64
# Visual Search:
# mean RT:  1.375125
# SD:  0.615591482449
# Outliers:  5
# 3.654
# 4.069
# 3.395
# 3.404
# 3.129
# 1.15625
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 61 67
# CC:
# 49 65
# CC:
# 110 132
# 4    839
# 1     74
# 0     32
# 2     15
# Name: sdt, dtype: int64
# ---------
# 4    421
# 1     39
# 0     16
# 2      4
# Name: sdt, dtype: int64
# ---------
# 4    418
# 1     35
# 0     16
# 2     11
# Name: sdt, dtype: int64
# {'c': 0.85821273888466554, 'beta': 42.21602286115415, 'd': 4.361156235568771, 'Ad': 0.99897813612302433}
# {'c': 1.1637665654058966, 'beta': 78.19180192518043, 'd': 3.7457381376298411, 'Ad': 0.99595914377565431}
# Load     Acc_VS
#  'high'  0         1.374687
#          1         1.245737
#          999       1.397000
#  'low'   0         1.284854
#          1         1.265678
#          999       1.902400
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         16
#          1         49
#          999        7
#  'low'   0          6
#          1         61
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.784943
#                       999       0.674000
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.795643
#                       999       0.859000
#           'Normal'    999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          11
#                       1          35
#                       999         2
#           'Normal'    999       432
#  'low'    'Critical'  0           4
#                       1          39
#                       999         5
#           'Normal'    999       432
# Name: Acc_DT, dtype: int64
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 97
# FOUND RT IN FIRST 98
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 253
# FOUND RT IN FIRST 254
# DIRTY! 292
# FOUND RT IN FIRST 293
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 379
# FOUND RT IN FIRST 380
# DIRTY! 417
# FOUND RT IN FIRST 418
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 509
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 637
# FOUND RT IN FIRST 638
# DIRTY! 646
# FOUND RT IN FIRST 647
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 810
# FOUND RT IN FIRST 811
# DIRTY! 821
# FOUND RT IN FIRST 822
# DIRTY! 901
# FOUND RT IN FIRST 902
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 929
# FOUND RT IN FIRST 930
# Take Over:
# mean RT:  1.11407
# SD:  0.296272957085
# Outliers:  1
# 1.87
# Visual Search:
# mean RT:  0.750381944444
# SD:  0.139814410546
# Outliers:  3
# 1.302
# 1.25
# 1.294
# 1.29166666667
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 58 65
# CC:
# 46 65
# CC:
# 104 130
# 4    837
# 1     93
# 0     24
# 3      5
# 2      1
# Name: sdt, dtype: int64
# ---------
# 4    417
# 1     46
# 0     11
# 3      5
# 2      1
# Name: sdt, dtype: int64
# ---------
# 4    420
# 1     47
# 0     13
# Name: sdt, dtype: int64
# {'c': 0.11697126111495804, 'beta': 1.6517183378223168, 'd': 4.2900808120977283, 'Ad': 0.9987915076321342}
# {'c': 0.36751718016721413, 'beta': 7.12030988700346, 'd': 5.3411142495139927, 'Ad': 0.99992055217227649}
# Load     Acc_VS
#  'high'  0         0.784303
#          1         0.762087
#          999       0.731429
#  'low'   0         0.696769
#          1         0.700655
#          666       0.942000
#          999       0.796600
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         19
#          1         46
#          999        7
#  'low'   0          7
#          1         58
#          666        2
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  1         0.629340
#                       999       0.486000
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.637565
#                       999       0.506000
#           'Normal'    666       1.189214
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  1          47
#                       999         1
#           'Normal'    999       432
#  'low'    'Critical'  0           1
#                       1          46
#                       999         1
#           'Normal'    666         5
#                       999       427
# Name: Acc_DT, dtype: int64
# DIRTY! 12
# FOUND RT IN FIRST 13
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 107
# FOUND RT IN FIRST 108
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 190
# FOUND RT IN FIRST 191
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 253
# FOUND RT IN FIRST 254
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 292
# FOUND RT IN FIRST 293
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 376
# DIRTY! 433
# FOUND RT IN FIRST 434
# DIRTY! 440
# DIRTY! 443
# DIRTY! 451
# FOUND RT IN FIRST 452
# DIRTY! 466
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 522
# FOUND RT IN FIRST 523
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 612
# FOUND RT IN FIRST 613
# DIRTY! 637
# FOUND RT IN FIRST 638
# DIRTY! 657
# FOUND RT IN FIRST 658
# DIRTY! 726
# DIRTY! 741
# FOUND RT IN FIRST 742
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 775
# FOUND RT IN FIRST 776
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 901
# FOUND RT IN FIRST 902
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 929
# FOUND RT IN FIRST 930
# Take Over:
# mean RT:  1.20039784946
# SD:  0.40466880497
# Outliers:  2
# -1.44
# 2.361
# Visual Search:
# mean RT:  1.18058333333
# SD:  0.340002992225
# Outliers:  5
# 2.046
# 2.181
# 2.261
# 2.2
# 2.9
# 1.34328358209
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 63 66
# CC:
# 53 65
# CC:
# 116 131
# 4    834
# 1     90
# 0     29
# 2      5
# 3      2
# Name: sdt, dtype: int64
# ---------
# 4    421
# 1     47
# 0      9
# 3      2
# 2      1
# Name: sdt, dtype: int64
# ---------
# 4    413
# 1     43
# 0     20
# 2      4
# Name: sdt, dtype: int64
# {'c': 0.27913430392536021, 'beta': 3.643455244451272, 'd': 4.6319368712534956, 'Ad': 0.99947220226286271}
# {'c': 0.83074278556321146, 'beta': 38.823612363479185, 'd': 4.4045265167320871, 'Ad': 0.99907862329887964}
# Load     Acc_VS
#  'high'  0         1.375215
#          1         1.178539
#          999       1.100571
#  'low'   0         0.983333
#          1         1.084209
#          666       1.201000
#          999       1.038717
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         12
#          1         53
#          999        7
#  'low'   0          3
#          1         63
#          666        1
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.760093
#                       999       0.808000
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.720477
#           'Normal'    666       1.560199
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0           4
#                       1          43
#                       999         1
#           'Normal'    999       432
#  'low'    'Critical'  0           1
#                       1          47
#           'Normal'    666         2
#                       999       430
# Name: Acc_DT, dtype: int64
# DIRTY! 2
# FOUND RT IN FIRST 3
# DIRTY! 24
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 107
# DIRTY! 125
# FOUND RT IN FIRST 126
# DIRTY! 160
# FOUND RT IN FIRST 161
# DIRTY! 172
# DIRTY! 175
# FOUND RT IN FIRST 176
# DIRTY! 190
# FOUND RT IN FIRST 191
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 253
# FOUND RT IN FIRST 254
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 292
# FOUND RT IN FIRST 293
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 336
# FOUND RT IN FIRST 337
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 372
# FOUND RT IN FIRST 373
# DIRTY! 376
# FOUND RT IN FIRST 377
# DIRTY! 379
# FOUND RT IN FIRST 380
# DIRTY! 440
# DIRTY! 463
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 541
# FOUND RT IN FIRST 542
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 612
# FOUND RT IN FIRST 613
# DIRTY! 637
# FOUND RT IN FIRST 638
# DIRTY! 657
# FOUND RT IN FIRST 658
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 766
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 837
# DIRTY! 841
# FOUND RT IN FIRST 842
# DIRTY! 901
# FOUND RT IN FIRST 902
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 929
# FOUND RT IN FIRST 930
# Take Over:
# mean RT:  1.23675555556
# SD:  0.271908412322
# Outliers:  2
# 1.987
# 0.392
# Visual Search:
# mean RT:  1.67928472222
# SD:  0.606006665521
# Outliers:  1
# 6.944
# 1.32835820896
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 65 67
# CC:
# 55 65
# CC:
# 120 132
# 4    834
# 1     89
# 0     29
# 2      7
# 3      1
# Name: sdt, dtype: int64
# ---------
# 4    420
# 1     46
# 0     12
# 2      2
# Name: sdt, dtype: int64
# ---------
# 4    414
# 1     43
# 0     17
# 2      5
# 3      1
# Name: sdt, dtype: int64
# {'c': 0.65320495440098247, 'beta': 22.547336658923992, 'd': 4.7697387010464558, 'Ad': 0.99962784467736154}
# {'c': 0.78035508874316872, 'beta': 24.08366192866071, 'd': 4.0770332996125305, 'Ad': 0.99802982428540177}
# Load     Acc_VS
#  'high'  0         2.156500
#          1         1.706818
#          666            NaN
#          999       1.526857
#  'low'   0         1.337142
#          1         1.534569
#          999       1.600600
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         10
#          1         55
#          666        0
#          999        7
#  'low'   0          2
#          1         65
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.776581
#           'Normal'    666       1.236756
#                       999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.773843
#           'Normal'    999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0           5
#                       1          43
#           'Normal'    666         1
#                       999       431
#  'low'    'Critical'  0           2
#                       1          46
#           'Normal'    999       432
# Name: Acc_DT, dtype: int64
# DIRTY! 12
# FOUND RT IN FIRST 13
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 107
# DIRTY! 125
# FOUND RT IN FIRST 126
# DIRTY! 139
# FOUND RT IN FIRST 140
# DIRTY! 160
# FOUND RT IN FIRST 161
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 175
# FOUND RT IN FIRST 176
# DIRTY! 190
# FOUND RT IN FIRST 191
# DIRTY! 205
# FOUND RT IN FIRST 206
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 253
# FOUND RT IN FIRST 254
# DIRTY! 283
# FOUND RT IN FIRST 284
# DIRTY! 292
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 319
# FOUND RT IN FIRST 320
# DIRTY! 336
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 359
# DIRTY! 372
# DIRTY! 379
# DIRTY! 384
# DIRTY! 440
# FOUND RT IN SECOND 442
# DIRTY! 451
# DIRTY! 463
# DIRTY! 466
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 509
# FOUND RT IN FIRST 510
# DIRTY! 522
# FOUND RT IN FIRST 523
# DIRTY! 526
# DIRTY! 532
# DIRTY! 541
# DIRTY! 548
# DIRTY! 551
# DIRTY! 553
# DIRTY! 559
# DIRTY! 566
# DIRTY! 612
# DIRTY! 637
# FOUND RT IN FIRST 638
# DIRTY! 657
# FOUND RT IN FIRST 658
# DIRTY! 663
# DIRTY! 726
# DIRTY! 761
# DIRTY! 766
# DIRTY! 775
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 804
# DIRTY! 810
# FOUND RT IN FIRST 811
# DIRTY! 821
# DIRTY! 837
# DIRTY! 841
# DIRTY! 869
# FOUND RT IN FIRST 870
# DIRTY! 901
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# FOUND RT IN FIRST 912
# DIRTY! 929
# FOUND RT IN FIRST 930
# DIRTY! 934
# FOUND RT IN FIRST 935
# Take Over:
# mean RT:  1.33060294118
# SD:  0.434732850344
# Outliers:  1
# 3.692
# Visual Search:
# mean RT:  1.23209027778
# SD:  0.356288602454
# Outliers:  6
# 2.132
# 2.275
# 2.486
# 2.193
# 2.259
# 2.245
# 1.03076923077
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 66 67
# CC:
# 53 65
# CC:
# 119 132
# 4    832
# 1     67
# 0     31
# 2     29
# 3      1
# Name: sdt, dtype: int64
# ---------
# 4    417
# 1     36
# 0     14
# 2     12
# 3      1
# Name: sdt, dtype: int64
# ---------
# 4    415
# 1     31
# 2     17
# 0     17
# Name: sdt, dtype: int64
# {'c': 1.0733466577418309, 'beta': 42.60913783659646, 'd': 3.495672815875825, 'Ad': 0.99327852720555154}
# {'c': 1.3301840798178448, 'beta': 93.13135261355201, 'd': 3.4085589800311373, 'Ad': 0.99202844262017686}
# Load     Acc_VS
#  'high'  0         1.437083
#          1         1.227533
#          999       1.125000
#  'low'   0         0.910000
#          1         1.108063
#          666            NaN
#          999       1.400418
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         12
#          1         53
#          999        7
#  'low'   0          1
#          1         66
#          666        0
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.806890
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.843833
#           'Normal'    666       1.042000
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          17
#                       1          31
#           'Normal'    999       432
#  'low'    'Critical'  0          12
#                       1          36
#           'Normal'    666         1
#                       999       431
# Name: Acc_DT, dtype: int64
# DIRTY! 12
# DIRTY! 22
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 36
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 93
# DIRTY! 107
# DIRTY! 125
# DIRTY! 132
# DIRTY! 160
# DIRTY! 172
# DIRTY! 175
# DIRTY! 190
# DIRTY! 200
# DIRTY! 205
# DIRTY! 207
# DIRTY! 209
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 245
# DIRTY! 253
# FOUND RT IN SECOND 255
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 283
# DIRTY! 292
# FOUND RT IN FIRST 293
# DIRTY! 308
# DIRTY! 319
# FOUND RT IN SECOND 321
# DIRTY! 322
# DIRTY! 336
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 359
# DIRTY! 372
# DIRTY! 376
# FOUND RT IN FIRST 377
# DIRTY! 379
# DIRTY! 384
# FOUND RT IN FIRST 385
# DIRTY! 395
# DIRTY! 417
# DIRTY! 433
# DIRTY! 440
# DIRTY! 443
# DIRTY! 451
# DIRTY! 466
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 526
# DIRTY! 532
# DIRTY! 541
# DIRTY! 548
# DIRTY! 551
# DIRTY! 553
# DIRTY! 612
# DIRTY! 637
# DIRTY! 646
# DIRTY! 663
# DIRTY! 692
# DIRTY! 710
# DIRTY! 713
# DIRTY! 719
# DIRTY! 726
# FOUND RT IN FIRST 727
# DIRTY! 756
# FOUND RT IN FIRST 757
# DIRTY! 761
# DIRTY! 766
# DIRTY! 775
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 804
# DIRTY! 810
# DIRTY! 828
# FOUND RT IN FIRST 829
# DIRTY! 837
# FOUND RT IN FIRST 838
# DIRTY! 841
# DIRTY! 846
# DIRTY! 869
# DIRTY! 878
# DIRTY! 881
# FOUND RT IN FIRST 882
# DIRTY! 901
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# DIRTY! 929
# FOUND RT IN FIRST 930
# DIRTY! 934
# Take Over:
# mean RT:  0.981392156863
# SD:  1.17644711186
# Outliers:  3
# -3.31
# -2.44
# -2.12
# Visual Search:
# mean RT:  1.027625
# SD:  0.36642897362
# Outliers:  5
# 2.128
# 2.123
# 2.065
# 2.238
# 2.042
# 0.533333333333
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 60 66
# CC:
# 48 65
# CC:
# 108 131
# 4    832
# 2     56
# 1     40
# 0     21
# 3     11
# Name: sdt, dtype: int64
# ---------
# 4    415
# 2     29
# 1     19
# 0     11
# 3      6
# Name: sdt, dtype: int64
# ---------
# 4    417
# 2     27
# 1     21
# 0     10
# 3      5
# Name: sdt, dtype: int64
# {'c': 1.2272160647114299, 'beta': 10.631142996987256, 'd': 1.9261381757710128, 'Ad': 0.91339874818644717}
# {'c': 1.2096611758869964, 'beta': 12.755659627245599, 'd': 2.1047009825536516, 'Ad': 0.93165729299919908}
# Load     Acc_VS
#  'high'  0         1.203588
#          1         0.999310
#          666            NaN
#          999       0.920714
#  'low'   0         1.146833
#          1         0.925260
#          666       0.683000
#          999       0.913525
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         17
#          1         48
#          666        0
#          999        7
#  'low'   0          6
#          1         60
#          666        1
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.999762
#           'Normal'    666       0.647278
#                       999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.866000
#           'Normal'    666       0.039631
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          27
#                       1          21
#           'Normal'    666         5
#                       999       427
#  'low'    'Critical'  0          29
#                       1          19
#           'Normal'    666         6
#                       999       426
# Name: Acc_DT, dtype: int64
# DIRTY! 2
# FOUND RT IN FIRST 3
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 107
# DIRTY! 125
# FOUND RT IN FIRST 126
# DIRTY! 132
# DIRTY! 160
# FOUND RT IN FIRST 161
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 209
# DIRTY! 226
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 253
# FOUND RT IN FIRST 254
# DIRTY! 292
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 319
# DIRTY! 336
# FOUND RT IN FIRST 337
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 379
# FOUND RT IN FIRST 380
# DIRTY! 417
# DIRTY! 440
# DIRTY! 443
# DIRTY! 451
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 541
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 612
# FOUND RT IN FIRST 613
# DIRTY! 637
# DIRTY! 646
# DIRTY! 657
# FOUND RT IN FIRST 658
# DIRTY! 663
# DIRTY! 692
# DIRTY! 710
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 766
# DIRTY! 775
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 821
# FOUND RT IN FIRST 822
# DIRTY! 841
# DIRTY! 881
# DIRTY! 901
# DIRTY! 907
# DIRTY! 911
# DIRTY! 929
# FOUND RT IN FIRST 930
# Take Over:
# mean RT:  1.16610526316
# SD:  0.376086166602
# Outliers:  4
# 2.29
# 2.176
# 0.126
# -0.24
# Visual Search:
# mean RT:  1.408625
# SD:  0.487661039997
# Outliers:  5
# 3.127
# 2.702
# 2.878
# 3.503
# 2.965
# 0.960526315789
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 65 67
# CC:
# 52 65
# CC:
# 117 132
# 4    841
# 1     73
# 2     23
# 0     20
# 3      3
# Name: sdt, dtype: int64
# ---------
# 4    420
# 1     39
# 2      9
# 0      9
# 3      3
# Name: sdt, dtype: int64
# ---------
# 4    421
# 1     34
# 2     14
# 0     11
# Name: sdt, dtype: int64
# {'c': 0.78270640361523336, 'beta': 13.653681795914617, 'd': 3.3397059252682189, 'Ad': 0.990900118605333}
# {'c': 1.2451342869854765, 'beta': 87.06775319974386, 'd': 3.5873131393671489, 'Ad': 0.99440347650722261}
# Load     Acc_VS
#  'high'  0         1.698538
#          1         1.315401
#          999       1.319857
#  'low'   0         1.497500
#          1         1.315871
#          666            NaN
#          999       1.292525
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         13
#          1         52
#          999        7
#  'low'   0          2
#          1         65
#          666        0
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.735918
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.692974
#           'Normal'    666       1.195404
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          14
#                       1          34
#           'Normal'    999       432
#  'low'    'Critical'  0           9
#                       1          39
#           'Normal'    666         3
#                       999       429
# Name: Acc_DT, dtype: int64
# DIRTY! 2
# FOUND RT IN FIRST 3
# DIRTY! 12
# FOUND RT IN FIRST 13
# DIRTY! 15
# FOUND RT IN FIRST 16
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 36
# FOUND RT IN FIRST 37
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 93
# FOUND RT IN FIRST 94
# DIRTY! 107
# DIRTY! 125
# DIRTY! 132
# DIRTY! 139
# DIRTY! 160
# DIRTY! 172
# DIRTY! 175
# DIRTY! 190
# DIRTY! 200
# DIRTY! 205
# DIRTY! 207
# DIRTY! 209
# DIRTY! 226
# DIRTY! 242
# DIRTY! 245
# DIRTY! 253
# DIRTY! 258
# DIRTY! 283
# DIRTY! 292
# DIRTY! 308
# DIRTY! 319
# DIRTY! 322
# DIRTY! 336
# DIRTY! 338
# DIRTY! 359
# DIRTY! 372
# FOUND RT IN FIRST 373
# DIRTY! 379
# FOUND RT IN FIRST 380
# DIRTY! 384
# FOUND RT IN FIRST 385
# DIRTY! 395
# DIRTY! 417
# FOUND RT IN FIRST 418
# DIRTY! 433
# DIRTY! 440
# DIRTY! 443
# DIRTY! 451
# FOUND RT IN FIRST 452
# DIRTY! 466
# DIRTY! 483
# FOUND RT IN FIRST 484
# DIRTY! 493
# DIRTY! 532
# FOUND RT IN FIRST 533
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 612
# DIRTY! 634
# DIRTY! 637
# DIRTY! 646
# DIRTY! 657
# FOUND RT IN FIRST 658
# DIRTY! 659
# DIRTY! 663
# DIRTY! 692
# DIRTY! 710
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 766
# DIRTY! 775
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 810
# DIRTY! 821
# FOUND RT IN FIRST 822
# DIRTY! 828
# FOUND RT IN FIRST 829
# DIRTY! 837
# DIRTY! 841
# DIRTY! 846
# DIRTY! 869
# DIRTY! 878
# FOUND RT IN FIRST 879
# DIRTY! 881
# FOUND RT IN FIRST 882
# DIRTY! 901
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# DIRTY! 921
# DIRTY! 929
# DIRTY! 934
# Take Over:
# mean RT:  1.41168085106
# SD:  0.446806688953
# Outliers:  1
# 0.109
# Visual Search:
# mean RT:  1.92386111111
# SD:  0.764176323195
# Outliers:  3
# 5.06
# 3.887
# 7.128
# 0.605633802817
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 61 67
# CC:
# 47 65
# CC:
# 108 132
# 4    839
# 2     51
# 1     43
# 0     25
# 3      2
# Name: sdt, dtype: int64
# ---------
# 4    414
# 1     24
# 2     22
# 0     18
# 3      2
# Name: sdt, dtype: int64
# ---------
# 4    425
# 2     29
# 1     19
# 0      7
# Name: sdt, dtype: int64
# {'c': 1.2674217359281474, 'beta': 28.52875793286754, 'd': 2.6438813015524971, 'Ad': 0.96922380275739806}
# {'c': 1.6528928486697387, 'beta': 98.58274441700372, 'd': 2.7774917436876305, 'Ad': 0.9752339826016948}
# Load     Acc_VS
#  'high'  0         2.041040
#          1         1.764997
#          999       1.576143
#  'low'   0         2.126000
#          1         1.839410
#          666            NaN
#          999       2.209200
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         18
#          1         47
#          999        7
#  'low'   0          6
#          1         61
#          666        0
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         1.000947
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         1.058542
#                       999       1.307000
#           'Normal'    666       0.875840
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          29
#                       1          19
#           'Normal'    999       432
#  'low'    'Critical'  0          22
#                       1          24
#                       999         2
#           'Normal'    666         2
#                       999       430
# Name: Acc_DT, dtype: int64
# DIRTY! 2
# DIRTY! 12
# DIRTY! 24
# DIRTY! 36
# FOUND RT IN FIRST 37
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 93
# DIRTY! 107
# DIRTY! 125
# FOUND RT IN FIRST 126
# DIRTY! 160
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 190
# FOUND RT IN FIRST 191
# DIRTY! 200
# DIRTY! 205
# FOUND RT IN FIRST 206
# DIRTY! 207
# DIRTY! 209
# DIRTY! 226
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 245
# DIRTY! 253
# FOUND RT IN FIRST 254
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 283
# DIRTY! 292
# FOUND RT IN FIRST 293
# DIRTY! 336
# DIRTY! 338
# FOUND RT IN FIRST 339
# DIRTY! 372
# DIRTY! 376
# FOUND RT IN FIRST 377
# DIRTY! 379
# DIRTY! 433
# DIRTY! 443
# DIRTY! 451
# DIRTY! 466
# FOUND RT IN FIRST 467
# DIRTY! 493
# DIRTY! 522
# FOUND RT IN FIRST 523
# DIRTY! 526
# DIRTY! 532
# DIRTY! 548
# DIRTY! 551
# DIRTY! 566
# DIRTY! 637
# DIRTY! 646
# DIRTY! 657
# FOUND RT IN FIRST 658
# DIRTY! 659
# DIRTY! 663
# DIRTY! 692
# FOUND RT IN FIRST 693
# DIRTY! 713
# FOUND RT IN SECOND 715
# DIRTY! 719
# DIRTY! 761
# DIRTY! 766
# DIRTY! 775
# DIRTY! 794
# FOUND RT IN FIRST 795
# DIRTY! 804
# DIRTY! 810
# FOUND RT IN FIRST 811
# DIRTY! 828
# DIRTY! 837
# DIRTY! 841
# DIRTY! 846
# DIRTY! 869
# DIRTY! 881
# DIRTY! 901
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# DIRTY! 929
# DIRTY! 934
# Take Over:
# mean RT:  1.32652830189
# SD:  0.418390879973
# Outliers:  1
# 3.39
# Visual Search:
# mean RT:  1.03384027778
# SD:  0.191646798361
# Outliers:  2
# 1.857
# 1.597
# 0.706666666667
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object
# CC:
# 64 67
# CC:
# 52 65
# CC:
# 116 132
# 4    843
# 1     53
# 2     43
# 0     21
# Name: sdt, dtype: int64
# ---------
# 4    421
# 1     26
# 2     22
# 0     11
# Name: sdt, dtype: int64
# ---------
# 4    422
# 1     27
# 2     21
# 0     10
# Name: sdt, dtype: int64
# {'c': 1.4670787005274879, 'beta': 100.6501714257203, 'd': 3.143424312283126, 'Ad': 0.98688321839645265}
# {'c': 1.4410974401879648, 'beta': 100.17550663857435, 'd': 3.1968162495962709, 'Ad': 0.98810458570748294}
# Load     Acc_VS
#  'high'  0         1.125615
#          1         1.033285
#          999       0.958714
#  'low'   0         0.982667
#          1         1.005529
#          999       1.022000
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         13
#          1         52
#          999        7
#  'low'   0          3
#          1         64
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.818222
#           'Normal'    999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.875020
#           'Normal'    999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          21
#                       1          27
#           'Normal'    999       432
#  'low'    'Critical'  0          22
#                       1          26
#           'Normal'    999       432
# Name: Acc_DT, dtype: int64

# %%
import scipy

# %%
lows = [x['vs_accuracy_low'] for x in results]
highs = [x['vs_accuracy_high'] for x in results]

# %%
scipy.stats.ttest_rel(lows,highs)
# Out:
# Ttest_relResult(statistic=13.794897893969367, pvalue=6.2939446225113983e-10)

# %%
lows = [x['h_rate_low_detection'] for x in results]
highs = [x['h_rate_high_detection'] for x in results]
scipy.stats.ttest_rel(lows,highs)
# Out:
# Ttest_relResult(statistic=4.1965906619356135, pvalue=0.0007782444562446306)

# %%
cols = ['Image_Name','Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','space','RT_TO','keys','RT_VS','useless','Trial_N_Block','Block']

# %%
observers = ['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','p11','p12','p13','p14','p15','p16']

# %%
def dataframe_from_dict(DE):
    df = pd.DataFrame(index=DE.keys(), columns = cols)

    for t in DE.keys():
        row = [DE[t]['image_name'], 
            DE[t]['cat_1'],
               DE[t]['cat_2'],
               DE[t]['cat_3'],
               DE[t]['cat_4'],
               DE[t]['cat_5'],
               DE[t]['trueskill'],
               DE[t]['load'],
               DE[t]['exemplar'],
               DE[t]['question'],
               DE[t]['present_absent'],
               DE[t]['trial_type'],
               DE[t]['tone_hz'],
               DE[t]['tone_onset'],
               DE[t]['space'],
               DE[t]['RT_TO'],
               DE[t]['keys'],
               DE[t]['RT_VS'],
               DE[t]['useless'],
               0,
               DE[t]['block_number'],

        ]
        df.loc[t] = row
    return df

# %%
def calc_vs_accuracy(df, load_level):
    n = df.shape[0]
    count = 0
    correct = 0
    
    for i in range(n):
        pa = df.loc[i,'present_absent']
        sdt = df.loc[i,'sdt']
        keys = df.loc[i,'keys']
#         pdb.set_trace()
        if 'Normal' in df.loc[i, 'trial_type'] and sdt != 3 and load_level in df.loc[i,'Load']  and ('Target Present' in pa or 'Target Absent' in pa):
            count += 1
            if 'Target Present' in pa:
                if 'q' in keys:
                    c = True
                else:
                    c = False
            if 'Target Absent' in pa:
                if 'p' in keys:
                    c = True
                else:
                    c = False
           
            if c == True:
                correct += 1
#     set_trace()
    acc = correct/float(count)
    print 'CC:'
    print correct, count
    return acc

# %%
def calc_vs_accuracy_both(df):
    n = df.shape[0]
    count = 0
    correct = 0
    
    for i in range(n):
        pa = df.loc[i,'present_absent']
        sdt = df.loc[i,'sdt']
        keys = df.loc[i,'keys']
#         pdb.set_trace()
        if 'Normal' in df.loc[i, 'trial_type'] and sdt != 3  and ('Target Present' in pa or 'Target Absent' in pa):
            count += 1
            if 'Target Present' in pa:
                if 'q' in keys:
                    c = True
                else:
                    c = False
            if 'Target Absent' in pa:
                if 'p' in keys:
                    c = True
                else:
                    c = False
           
            if c == True:
                correct += 1
    acc = correct/float(count)
    print 'CC:'
    print correct, count
    return acc

# %%
f = '../output/participant_test.pik'
import pickle
with open(f,'r') as of:
    D = pickle.load(of)
df = dataframe_from_dict(D['experiment_details'])

# %%
len(df)
# Out:
# 960

# %%
def process_observer_old(obs):
    f = '../output/participant_'+obs+'.pik'
    import pickle
    with open(f,'r') as of:
        D = pickle.load(of)
    df = dataframe_from_dict(D['experiment_details'])
    
    
       
    df['valid'] = df['Block']
    df['valid'] = 1
    df['sdt'] = 0
    df.drop(['Image_Name','
             Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','exemplar','question','space','useless'], axis=1, inplace=True)
    invalid_count = fix_reaction_times(df)
    
    RT_TO = df['RT_TO'].tolist()
    RT_VS = df['RT_VS'].tolist()
    Audio = df['trial_type'].tolist()
    Present_absent = df['present_absent'].tolist()
    Audio = df['trial_type'].tolist()
    Keys = df['keys'].tolist()
    Tone_onset = df['tone_onset'].tolist()

#     RT_TO = [str('NaN') if n == 'No timing' else float(n[0:5]) for n in RT_TO]
#     RT_VS = [str('NaN') if n == None else float(n[0:5])-1.3 for n in RT_VS]
#     Keys = [str(n[2:-1]) for n in Keys]
    RT_TO_floats = [n for n in RT_TO if type(n) == float]
    sd_TO = np.std(RT_TO_floats)
    mean_TO = np.mean(RT_TO_floats)

    #Getting rid of outliers for TO RT (outliers are replaced with mean)
    RT_TO_no_outliers = []
    counter_TO = 0
    RT_TO_outliers = []
    for i in RT_TO:
        if type(i) != float:
            RT_TO_no_outliers.append(i)
        elif type(i) == float:
            if (mean_TO - 2.5 * sd_TO) < i < (mean_TO + 2.5 * sd_TO):
                RT_TO_no_outliers.append(i)
            else:
                counter_TO = counter_TO + 1
                #print 'Outlier ' + str(counter_TO) + ': ' + str(i) 
                RT_TO_no_outliers.append(mean_TO)
                RT_TO_outliers.append(i)
    RT_TO = RT_TO_no_outliers

    Tone_onset = [int(n) for n in Tone_onset]
    for i in range(len(Tone_onset)):
        if Tone_onset[i] != -999:
            Tone_onset[i] = float(Tone_onset[i])/1000
            if type(RT_TO[i]) == float:
                #print RT_TO[i], '-', Tone_onset[i] 
                RT_TO[i] = RT_TO[i] - Tone_onset[i]
                #print RT_TO[i]


    RT_VS_floats = [n for n in RT_VS if type(n) == float]
    sd_VS = np.std(RT_VS_floats)
    mean_VS = np.mean(RT_VS_floats)

    #Getting rid of outliers for TO RT (outliers are replaced with mean)
    RT_VS_no_outliers = []
    counter_VS = 0
    RT_VS_outliers = []
    for i in RT_VS:
        if type(i) != float:
            RT_VS_no_outliers.append(i)
        elif type(i) == float:
            if (mean_VS - 2.5 * sd_VS) < i < (mean_VS + 2.5 * sd_VS):
                RT_VS_no_outliers.append(i)
            else:
                counter_VS = counter_VS + 1
                #print 'Outlier ' + str(counter_TO) + ': ' + str(i) 
                RT_VS_no_outliers.append(mean_VS)
                RT_VS_outliers.append(i)
    RT_VS = RT_VS_no_outliers

    print 'Take Over:'
    print 'mean RT: ', mean_TO
    print 'SD: ', sd_TO
    print 'Outliers: ', len(RT_TO_outliers)
    for i in RT_TO_outliers:
        print i

    print 'Visual Search:'
    print 'mean RT: ', mean_VS
    print 'SD: ', sd_VS
    print 'Outliers: ', len(RT_VS_outliers)
    for i in RT_VS_outliers:
        print i


    #######
    Acc_VS = []
    for i in range(960):
        if 'Critical' in Audio[i]:
            #print i
            Acc_VS.append('999')
        elif 'Normal' in Audio[i] and RT_TO[i] != 'NaN':
            Acc_VS.append('666')
        elif 'Target Present' in Present_absent[i] and 'q' in Keys[i]:
            Acc_VS.append(1)
        elif 'Target Present' in Present_absent[i] and 'p' in Keys[i]:
            Acc_VS.append(0)
        elif 'Target Absent' in Present_absent[i] and 'p' in Keys[i]:
            Acc_VS.append(1)   
        elif 'Target Absent' in Present_absent[i] and 'q' in Keys[i]:
            Acc_VS.append(0)
        elif 'No Target' in Present_absent[i]:
            Acc_VS.append('999')

    #print len(Acc_VS)
    #######

    #######
    # CREATING Acc_DT (1 = included for analysis; 0 = excluded from analysis)
    Acc_DT = []
    for i in range(960):
        if 'Critical' in Audio[i] and type(RT_TO[i]) != str:
            # Was visual search correct?
            if 'Target Present' in Present_absent[i] and 'q' in Keys[i]:
                Acc_DT.append(1)
                df.loc[i,'sdt'] = 1
            elif 'Target Absent' in Present_absent[i] and 'p' in Keys[i]:
                Acc_DT.append(1)
                df.loc[i,'sdt'] = 1
            elif 'Target Present' in Present_absent[i] and 'p' in Keys[i]:
                Acc_DT.append(999)
                df.loc[i,'sdt'] = 0
            elif 'Target Absent' in Present_absent[i] and 'q' in Keys[i]:
                Acc_DT.append(999)
                df.loc[i,'sdt'] = 0
            elif 'No Target' in Present_absent[i]:
                Acc_DT.append(1)
                df.loc[i,'sdt'] = 1

        # Incorrect on tone
        elif 'Critical' in Audio[i] and type(RT_TO[i]) == str:
            Acc_DT.append(0)
            df.loc[i,'sdt'] = 2
        #Throw out normal trials
        elif 'Normal' in Audio[i] and type(RT_TO[i]) != str:
            Acc_DT.append(666) # 666 are false alarms
            df.loc[i,'sdt'] = 3
        elif 'Normal' in Audio[i] and type(RT_TO[i]) == str:
            Acc_DT.append(999)
            df.loc[i,'sdt'] = 4
    for i in range(960):
        if df.loc[i,'valid'] == 0:
            df.loc[i,'sdt'] = 0
    #print len(Acc_DT) 

    correct_response_counter = len([n for n in Acc_DT if n == 1])
    incorrect_response_counter = len([n for n in Acc_DT if n == 0])
    incorrect_response_counter

    n_present = correct_response_counter + incorrect_response_counter
    hit_rate = float(correct_response_counter) / (n_present - invalid_count)
    print hit_rate

    # Converting lists into pandas.series...
    RT_TO = pd.Series(data=RT_TO)
    RT_VS = pd.Series(data=RT_VS)
    Acc_VS = pd.Series(data=Acc_VS)
    Acc_DT = pd.Series(data=Acc_DT)
    #False_Alarms = pd.Series(data=False_Alarms)
    # ...and combining them into a pandas dataframe

    df.drop(['RT_TO','RT_VS'], axis = 1, inplace = True)
    df['RT_TO'] = RT_TO.values
    df['RT_VS'] = RT_VS.values
    df['Acc_VS'] = Acc_VS.values
    df['Acc_DT'] = Acc_DT.values

    df[['RT_TO','RT_VS']] = df[['RT_TO','RT_VS']].astype('float')
    df[['Acc_VS','Acc_DT']] = df[['Acc_VS','Acc_DT']].astype('int')
    print df.dtypes

    df_low = df[df['Load'].str.contains("low")]
    df_high = df[df['Load'].str.contains("high")]

    counts = df['sdt'].value_counts()
    counts_low = df_low['sdt'].value_counts()
    counts_high = df_high['sdt'].value_counts()
    
    result['vs_accuracy_low'] = calc_vs_accuracy(df, 'low')
    result['vs_accuracy_high'] = calc_vs_accuracy(df, 'high')
    calc_vs_accuracy_both(df)
    
    print counts
    print '---------'
    print counts_low
    print '---------'
    print counts_high

    n_h = float(counts[1])
    n_m = float(counts[2])
    try:
        n_fa = float(counts[3])
    except:
        n_fa = 0
    n_cr = float(counts[4])

    h_rate = n_h / (n_h + n_m)
    fa_rate = n_fa / (n_cr + n_fa)
    h_rate

    n_h_low = float(counts_low[1])
    try:
        n_m_low = float(counts_low[2])
    except:
        n_m_low = 0
    try:
        n_fa_low = float(counts_low[3])
    except:
        n_fa_low = 0
    n_cr_low = float(counts_low[4])

    h_rate_low = n_h_low / (n_h_low + n_m_low)
    fa_rate_low = n_fa_low / (n_cr_low + n_fa_low)
    
    result['h_rate_low_detection'] = h_rate_low

    n_h_high = float(counts_high[1])
    try:
        n_m_high = float(counts_high[2])
    except:
        n_m_high = 0
    try:
        n_fa_high = float(counts_high[3])
    except:
        n_fa_high = 0
    n_cr_high = float(counts_high[4])

    h_rate_high = n_h_high / (n_h_high + n_m_high)
    fa_rate_high = n_fa_high / (n_cr_high + n_fa_high)
    
    result['h_rate_high_detection'] = h_rate_high

    print d_prime(n_h_low, n_m_low, n_fa_low, n_cr_low)
    print d_prime(n_h_high, n_m_high, n_fa_high, n_cr_high)

    #TABLE 1
    print df.groupby(['Load','Acc_VS']).RT_VS.mean()
    print df.groupby(['Load','Acc_VS']).RT_VS.count()

    # TABLE 2
    #print df.groupby(['Load','Acc_VS','present_absent']).RT_VS.mean()
    #print df.groupby(['Load','Acc_VS','present_absent']).RT_VS.count()

    #TABLE 3
    print df.groupby(['Load','trial_type','Acc_DT']).RT_TO.mean()
    print df.groupby(['Load','trial_type','Acc_DT']).Acc_DT.count()
    
    return result

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
# Out:
# (480, 21)

# %%
#df2
# Out:
# (480, 21)

# %%
df
# Out:
# DIRTY! 2
# DIRTY! 12
# DIRTY! 24
# FOUND RT IN FIRST 25
# DIRTY! 36
# FOUND RT IN FIRST 37
# DIRTY! 65
# FOUND RT IN FIRST 66
# DIRTY! 91
# FOUND RT IN FIRST 92
# DIRTY! 97
# DIRTY! 125
# FOUND RT IN FIRST 126
# DIRTY! 132
# FOUND RT IN FIRST 133
# DIRTY! 160
# DIRTY! 172
# FOUND RT IN FIRST 173
# DIRTY! 205
# FOUND RT IN FIRST 206
# DIRTY! 209
# FOUND RT IN FIRST 210
# DIRTY! 242
# FOUND RT IN FIRST 243
# DIRTY! 253
# FOUND RT IN FIRST 254
# DIRTY! 258
# FOUND RT IN FIRST 259
# DIRTY! 292
# DIRTY! 308
# FOUND RT IN FIRST 309
# DIRTY! 319
# FOUND RT IN FIRST 320
# DIRTY! 322
# DIRTY! 336
# FOUND RT IN FIRST 337
# DIRTY! 338
# DIRTY! 359
# DIRTY! 379
# DIRTY! 384
# FOUND RT IN FIRST 385
# DIRTY! 433
# FOUND RT IN FIRST 434
# DIRTY! 440
# DIRTY! 443
# FOUND RT IN FIRST 444
# DIRTY! 451
# DIRTY! 463
# DIRTY! 483
# DIRTY! 493
# FOUND RT IN FIRST 494
# DIRTY! 522
# FOUND RT IN FIRST 523
# DIRTY! 526
# DIRTY! 541
# DIRTY! 548
# FOUND RT IN FIRST 549
# DIRTY! 551
# DIRTY! 553
# DIRTY! 566
# DIRTY! 612
# DIRTY! 634
# DIRTY! 637
# DIRTY! 646
# DIRTY! 657
# DIRTY! 663
# DIRTY! 692
# FOUND RT IN FIRST 693
# DIRTY! 726
# DIRTY! 741
# DIRTY! 756
# DIRTY! 761
# FOUND RT IN FIRST 762
# DIRTY! 775
# DIRTY! 794
# DIRTY! 804
# DIRTY! 810
# FOUND RT IN FIRST 811
# DIRTY! 821
# FOUND RT IN FIRST 822
# DIRTY! 837
# DIRTY! 846
# DIRTY! 866
# DIRTY! 869
# FOUND RT IN FIRST 870
# DIRTY! 881
# FOUND RT IN FIRST 882
# DIRTY! 901
# FOUND RT IN FIRST 902
# DIRTY! 907
# FOUND RT IN FIRST 908
# DIRTY! 911
# FOUND RT IN FIRST 912
# DIRTY! 929
# FOUND RT IN FIRST 930
#         Load     present_absent   trial_type     tone_Hz  tone_onset  \
# 0      'low'        'No Target'     'Normal'   'No tone'        -999
# 1      'low'    'Target Absent'     'Normal'   'No tone'        -999
# 2      'low'        'No Target'   'Critical'     'tone2'         481
# 3      'low'        'No Target'     'Normal'   'No tone'        -999
# 4      'low'        'No Target'     'Normal'   'No tone'        -999
# 5      'low'   'Target Present'     'Normal'   'No tone'        -999
# 6      'low'        'No Target'     'Normal'   'No tone'        -999
# 7      'low'   'Target Present'     'Normal'   'No tone'        -999
# 8      'low'    'Target Absent'     'Normal'   'No tone'        -999
# 9      'low'        'No Target'     'Normal'   'No tone'        -999
# 10     'low'        'No Target'     'Normal'   'No tone'        -999
# 11     'low'        'No Target'     'Normal'   'No tone'        -999
# 12     'low'        'No Target'   'Critical'     'tone2'         631
# 13     'low'        'No Target'     'Normal'   'No tone'        -999
# 14     'low'        'No Target'     'Normal'   'No tone'        -999
# 15     'low'        'No Target'   'Critical'     'tone2'         305
# 16     'low'        'No Target'     'Normal'   'No tone'        -999
# 17     'low'        'No Target'     'Normal'   'No tone'        -999
# 18     'low'        'No Target'     'Normal'   'No tone'        -999
# 19     'low'        'No Target'     'Normal'   'No tone'        -999
# 20     'low'        'No Target'     'Normal'   'No tone'        -999
# 21     'low'        'No Target'     'Normal'   'No tone'        -999
# 22     'low'        'No Target'   'Critical'     'tone1'          78
# 23     'low'        'No Target'     'Normal'   'No tone'        -999
# 24     'low'        'No Target'   'Critical'     'tone2'         946
# 25     'low'        'No Target'     'Normal'   'No tone'        -999
# 26     'low'        'No Target'     'Normal'   'No tone'        -999
# 27     'low'        'No Target'     'Normal'   'No tone'        -999
# 28     'low'        'No Target'     'Normal'   'No tone'        -999
# 29     'low'        'No Target'     'Normal'   'No tone'        -999
# ..       ...                ...          ...         ...         ...
# 930   'high'        'No Target'     'Normal'   'No tone'        -999
# 931   'high'        'No Target'     'Normal'   'No tone'        -999
# 932   'high'        'No Target'     'Normal'   'No tone'        -999
# 933   'high'        'No Target'     'Normal'   'No tone'        -999
# 934   'high'        'No Target'   'Critical'     'tone1'         385
# 935   'high'        'No Target'     'Normal'   'No tone'        -999
# 936   'high'        'No Target'     'Normal'   'No tone'        -999
# 937   'high'   'Target Present'     'Normal'   'No tone'        -999
# 938   'high'        'No Target'     'Normal'   'No tone'        -999
# 939   'high'        'No Target'     'Normal'   'No tone'        -999
# 940   'high'        'No Target'     'Normal'   'No tone'        -999
# 941   'high'        'No Target'     'Normal'   'No tone'        -999
# 942   'high'        'No Target'     'Normal'   'No tone'        -999
# 943   'high'        'No Target'     'Normal'   'No tone'        -999
# 944   'high'        'No Target'     'Normal'   'No tone'        -999
# 945   'high'        'No Target'     'Normal'   'No tone'        -999
# 946   'high'        'No Target'     'Normal'   'No tone'        -999
# 947   'high'        'No Target'     'Normal'   'No tone'        -999
# 948   'high'        'No Target'     'Normal'   'No tone'        -999
# 949   'high'   'Target Present'     'Normal'   'No tone'        -999
# 950   'high'        'No Target'     'Normal'   'No tone'        -999
# 951   'high'        'No Target'     'Normal'   'No tone'        -999
# 952   'high'        'No Target'     'Normal'   'No tone'        -999
# 953   'high'        'No Target'     'Normal'   'No tone'        -999
# 954   'high'        'No Target'     'Normal'   'No tone'        -999
# 955   'high'   'Target Present'     'Normal'   'No tone'        -999
# 956   'high'        'No Target'     'Normal'   'No tone'        -999
# 957   'high'        'No Target'     'Normal'   'No tone'        -999
# 958   'high'        'No Target'     'Normal'   'No tone'        -999
# 959   'high'        'No Target'     'Normal'   'No tone'        -999
#
#             RT_TO   keys  RT_VS  Trial_N_Block  Block  valid  sdt     space
# 0     'No timing'   'Na'   'Na'              0      1      1    0       NaN
# 1     'No timing'    'p'  2.235              1      1      1    0       NaN
# 2     'No timing'   'Na'   'Na'              2      1      1    0       NaN
# 3     'No timing'   'Na'   'Na'              3      1      1    0       NaN
# 4     'No timing'   'Na'   'Na'              4      1      1    0       NaN
# 5     'No timing'    'q'  2.355              5      1      1    0       NaN
# 6     'No timing'   'Na'   'Na'              6      1      1    0       NaN
# 7     'No timing'    'p'  2.241              7      1      1    0       NaN
# 8     'No timing'    'p'  2.572              8      1      1    0       NaN
# 9     'No timing'   'Na'   'Na'              9      1      1    0       NaN
# 10    'No timing'   'Na'   'Na'             10      1      1    0       NaN
# 11    'No timing'   'Na'   'Na'             11      1      1    0       NaN
# 12    'No timing'   'Na'   'Na'             12      1      1    0       NaN
# 13    'No timing'   'Na'   'Na'             13      1      1    0       NaN
# 14    'No timing'   'Na'   'Na'             14      1      1    0       NaN
# 15    0.944818019   'Na'   'Na'             15      1      1    0       NaN
# 16    'No timing'   'Na'   'Na'             16      1      1    0       NaN
# 17    'No timing'   'Na'   'Na'             17      1      1    0       NaN
# 18    'No timing'   'Na'   'Na'             18      1      1    0       NaN
# 19    'No timing'   'Na'   'Na'             19      1      1    0       NaN
# 20    'No timing'   'Na'   'Na'             20      1      1    0       NaN
# 21    'No timing'   'Na'   'Na'             21      1      1    0       NaN
# 22    0.878087262   'Na'   'Na'             22      1      1    0       NaN
# 23    'No timing'   'Na'   'Na'             23      1      1    0       NaN
# 24    1.644229233   'Na'   'Na'             24      1      1    0     space
# 25      No timing   'Na'   'Na'             25      1      0    0  No space
# 26    'No timing'   'Na'   'Na'             26      1      1    0       NaN
# 27    'No timing'   'Na'   'Na'             27      1      1    0       NaN
# 28    'No timing'   'Na'   'Na'             28      1      1    0       NaN
# 29    'No timing'   'Na'   'Na'             29      1      1    0       NaN
# ..            ...    ...    ...            ...    ...    ...  ...       ...
# 930     No timing   'Na'   'Na'             30     16      0    0  No space
# 931   'No timing'   'Na'   'Na'             31     16      1    0       NaN
# 932   'No timing'   'Na'   'Na'             32     16      1    0       NaN
# 933   'No timing'   'Na'   'Na'             33     16      1    0       NaN
# 934    1.34208187   'Na'   'Na'             34     16      1    0       NaN
# 935   'No timing'   'Na'   'Na'             35     16      1    0       NaN
# 936   'No timing'   'Na'   'Na'             36     16      1    0       NaN
# 937   'No timing'    'q'  2.008             37     16      1    0       NaN
# 938   'No timing'   'Na'   'Na'             38     16      1    0       NaN
# 939   'No timing'   'Na'   'Na'             39     16      1    0       NaN
# 940   'No timing'   'Na'   'Na'             40     16      1    0       NaN
# 941   'No timing'   'Na'   'Na'             41     16      1    0       NaN
# 942   'No timing'   'Na'   'Na'             42     16      1    0       NaN
# 943   'No timing'   'Na'   'Na'             43     16      1    0       NaN
# 944   'No timing'   'Na'   'Na'             44     16      1    0       NaN
# 945   'No timing'   'Na'   'Na'             45     16      1    0       NaN
# 946   'No timing'   'Na'   'Na'             46     16      1    0       NaN
# 947   'No timing'   'Na'   'Na'             47     16      1    0       NaN
# 948   'No timing'   'Na'   'Na'             48     16      1    0       NaN
# 949   'No timing'    'q'  1.976             49     16      1    0       NaN
# 950   'No timing'   'Na'   'Na'             50     16      1    0       NaN
# 951   'No timing'   'Na'   'Na'             51     16      1    0       NaN
# 952   'No timing'   'Na'   'Na'             52     16      1    0       NaN
# 953   'No timing'   'Na'   'Na'             53     16      1    0       NaN
# 954   'No timing'   'Na'   'Na'             54     16      1    0       NaN
# 955   'No timing'    'q'  1.892             55     16      1    0       NaN
# 956   'No timing'   'Na'   'Na'             56     16      1    0       NaN
# 957   'No timing'   'Na'   'Na'             57     16      1    0       NaN
# 958   'No timing'   'Na'   'Na'             58     16      1    0       NaN
# 959   'No timing'   'Na'   'Na'             59     16      1    0       NaN
#
# [960 rows x 13 columns]

# %%
#RT_TO

# %%
# Out:
# Take Over:
# mean RT:  1.28123076923
# SD:  0.345771902103
# Outliers:  2
# -0.25
# 2.219
# Visual Search:
# mean RT:  0.8764375
# SD:  0.21037624096
# Outliers:  4
# 1.647
# 1.456
# 1.455
# 1.411

# %%
#for i in RT_TO:
#    print i, type(i)

# %%
# Calculating D' :
# to calculate D' prime you need:
#1) hit rate
#2) false alarms rate
# the z-transformed of 1 and 2
# the formula is:....
# 1 and 2 cannot be equal to 1 or 0
# Out:
# 33

# %%
# Out:
# 0.96875

# %%
n_present
# Out:
# 95

# %%
correct_response_counter
# Out:
# 62

# %%
# Out:
# Load               object
# present_absent     object
# trial_type         object
# tone_Hz            object
# tone_onset          int64
# keys               object
# Trial_N_Block       int64
# Block               int64
# valid               int64
# sdt                 int64
# space              object
# RT_TO             float64
# RT_VS             float64
# Acc_VS              int32
# Acc_DT              int32
# dtype: object

# %%
# Out:
# 4    831
# 1     62
# 2     33
# 0     32
# 3      2
# Name: sdt, dtype: int64
# ---------
# 4    416
# 1     34
# 0     15
# 2     14
# 3      1
# Name: sdt, dtype: int64
# ---------
# 4    415
# 1     28
# 2     19
# 0     17
# 3      1
# Name: sdt, dtype: int64

# %%
# Out:
# 0.6526315789473685

# %%
from __future__ import division # Not neccessary in Python 3 and later
from scipy.stats import norm
from math import exp,sqrt
Z = norm.ppf
 
def d_prime(hits, misses, fas, crs):
    # Floors an ceilings are replaced by half hits and half FA's
    halfHit = 0.5/(hits+misses)
    halfFa = 0.5/(fas+crs)
 
    # Calculate hitrate and avoid d' infinity
    hitRate = hits/(hits+misses)
    if hitRate == 1: hitRate = 1-halfHit
    if hitRate == 0: hitRate = halfHit
 
    # Calculate false alarm rate and avoid d' infinity
    faRate = fas/(fas+crs)
    if faRate == 1: faRate = 1-halfFa
    if faRate == 0: faRate = halfFa
 
    # Return d', beta, c and Ad'
    out = {}
    out['d'] = Z(hitRate) - Z(faRate)
    out['beta'] = exp((Z(faRate)**2 - Z(hitRate)**2)/2)
    out['c'] = -(Z(hitRate) + Z(faRate))/2
    out['Ad'] = norm.cdf(out['d']/sqrt(2))
    return out

# %%
#print d_prime(n_h, n_m, n_fa, n_cr)
# Out:
# {'c': 1.1359461822971264, 'beta': 45.92139103022002, 'd': 3.3689369299904488, 'Ad': 0.99139518277349703}
# {'c': 1.2886481782977055, 'beta': 51.71927262947524, 'd': 3.0619920600790151, 'Ad': 0.98481210479282455}

# %%
# Calculating D' :
# to calculate D' prime you need:
#1) hit rate
#2) false alarms rate
# the z-transformed of 1 and 2
# the formula is:....
# 1 and 2 cannot be equal to 1 or 0

# %%
# Out:
# Load     Acc_VS
#  'high'  0         0.988900
#          1         0.888889
#          666            NaN
#          999       0.838286
#  'low'   0         0.800667
#          1         0.809701
#          666            NaN
#          999       0.975000
# Name: RT_VS, dtype: float64
# Load     Acc_VS
#  'high'  0         10
#          1         55
#          666        0
#          999        7
#  'low'   0          3
#          1         64
#          666        0
#          999        5
# Name: RT_VS, dtype: int64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0              NaN
#                       1         0.826723
#                       999       1.132000
#           'Normal'    666       1.281231
#                       999            NaN
#  'low'    'Critical'  0              NaN
#                       1         0.806647
#           'Normal'    666       0.549000
#                       999            NaN
# Name: RT_TO, dtype: float64
# Load     trial_type   Acc_DT
#  'high'   'Critical'  0          19
#                       1          28
#                       999         1
#           'Normal'    666         1
#                       999       431
#  'low'    'Critical'  0          14
#                       1          34
#           'Normal'    666         1
#                       999       431
# Name: Acc_DT, dtype: int64

# %%
#with open('reports/test.html', 'wb') as file:
#    file.write('<html><table><tr><td>1</td></tr><tr><td>2</td></tr></table></html>')
