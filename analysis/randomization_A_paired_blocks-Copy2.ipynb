# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pickle
from copy import deepcopy
#%pdb
mypath = ('')
trials = {}
categories = [' bottle', ' horse', ' pottedplant', ' dog',
                  ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]
p_load = ['low','high']

pd.set_option('display.max_rows', 9000)
pd.set_option('display.max_columns', 9000)

# %%
def present_absent_trials(input_1, input_2):
    global target_present, lista, categories, p_load, odd, even
    # DEFINING TARGET-PRESENT PROBES
    
    #target_present = []
    intermediate = []
    
#next two lines are to check that the images picked as target present and target absent trials
                    #are different from the ones chosen in previous iterations
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_1:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break
    #print len(target_present)
    for n in target_present:
        possible_images_dict[n].append('Target Present')

    #target_present = [n for n in lista if 'Target Present' in possible_images_dict[n]]


    # DEFINING TARGET-ABSENT PROBES
    #target_absent = []
    intermediate = []
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_2:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)

                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for each in target_absent:
        possible_images_dict[each].append('Target Absent')
        

    # DEFINING NO-TARGET IMAGES
    for image in lista:
        if image not in target_present and image not in target_absent:
            possible_images_dict[image].append('NA')
            possible_images_dict[image].append('No Target')
    
    return target_present, target_absent

# %%
# DEFINING CRITICAL TRIALS
#Criteria:
# - images of set load level
# - images containing a certain category
# - image is not already in the list of critical trials for this level of load
#- image is not aready in the list of critical trials (regardless of level of load)

def pre_select_critical_trial(load_level):
    global categories, critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and 'Critical' not in possible_images_dict[intermediate]: # this is just a sanity check
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)      
        temp =[]

# %%
def appending_critical_trials():
    global critical_low_present_probes, critical_low_absent_probes, critical_high_present_probes, critical_high_absent_probes
    global critical_trials
    cycles = 1
    while True:

        #picking critical trials
        pre_select_critical_trial('low')
        pre_select_critical_trial('high')      

        # counting critical probes
        crit_p = 0
        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1


        critical_low_counter = 0
        critical_high_counter = 0
        crit_p = 0

        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1
            if 'No Target' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_counter = critical_low_counter + 1
            if 'No Target' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_counter = critical_high_counter +1
            if 'Target Present' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_absent_probes.append(n)
            if 'Target Present' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_absent_probes.append(n)
        #print crit_p
        #print critical_low_counter
        #print critical_high_counter
        #print critical_low_present_probes
        #print critical_low_absent_probes
        #print critical_high_present_probes
        #print critical_high_absent_probes

        #######################################################
        if crit_p == 0 or len(critical_low_present_probes) == len(critical_high_present_probes) and len(critical_low_absent_probes) == \
        len(critical_high_absent_probes): #check if there is an even number of critical probes
            break
            print 'cycles : ',cycles
        else:
            cycles = cycles + 1
            critical_low_present_probes = []
            critical_low_absent_probes = []
            critical_high_present_probes = []
            critical_high_absent_probes = []
            #print len(critical_low_present_probes)
            #print len(critical_high_present_probes)
            #print len(critical_low_absent_probes)
            #print len(critical_high_absent_probes)
            #print '#######################'

            #why did I reset target_present and target_absent???

            #target_present = []
            #target_absent = []
            critical_trials = []

    # appendinf words 'critical' and 'normal' to dict
    for each in critical_trials:
        possible_images_dict[each].append('Critical')
    for each in possible_images_dict:
        if 'Critical' not in possible_images_dict[each]:
            possible_images_dict[each].append('Normal')

    #######################################################
    #print 'Probe trials: ', len(probe_trials_1)
    print 'Target Present Probes: ', len(target_present)
    print 'Target Absent probes: ', len(target_absent)
    print 'Critical trials:', len(critical_trials)
    print 'Critical, low: ' , critical_low_counter
    print 'Critical, high: ' , critical_high_counter
    print 'Are all critical trials unique? ', len(critical_trials) == len(set(critical_trials))
    #######################################################
    print 'Number of critical probes: ' , crit_p
    print 'critical_low_present_probes: ' , len(critical_low_present_probes)
    print 'critical_high_present_probes: ' , len(critical_high_present_probes)
    print 'critical_low_absent_probes: ' , len(critical_low_absent_probes)
    print 'critical_high_absent_probes: ', len(critical_high_absent_probes)
    print 'cycles : ',cycles
    
    return

# %%
def critical_probes_distribution(starting):
    global critical_low_present_probes, critical_low_absent_probes
    while True:
        p_left = len(starting)
        p_max = p_left
        distribution = []
        for i in range(4):
            if p_left > 0:
                x = random.randint(0,p_left)
                distribution.append(x)
                p_left = p_left - x
            else:
                distribution.append(0)
        if sum(distribution) == p_max:
            break
    random.shuffle(distribution)
    return distribution

# %%
def block_pair(present_n,absent_n):
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block
    global present_crit_distribution, absent_crit_distribution
    global present_critical_per_block, absent_critical_per_block, critical_probes_used, critical_probes_set
    global present_per_block, absent_per_block
    
    present_crit = present_crit_distribution.pop(0)
    absent_crit = absent_crit_distribution.pop(0)
    block = []
    
    for load in p_load:
        #PRINTING STUFF
        print 'present_crit_distribution_original: ',present_crit_distribution_original
        print 'absent_crit_distribution_original: ', absent_crit_distribution_original
        print 'present_crit', present_crit
        print 'absent_crit', absent_crit
        print 'present_crit_distribution: ', present_crit_distribution
        print 'absent_crit_distribution: ', absent_crit_distribution
        print 'critical present set: ', critical_present_set
        print 'critical absent set: ', critical_absent_set
        print'---------------------------------------------------'
        normal_availble = [n for n in normal if n not in normal_used]
        print 'normal available:', len(normal_availble)
    # PICKING CRITICAL PROBES    
    #------------------------------------------------------------------------------
        if present_crit != 0:
            present_critical_per_block = []
            while len(present_critical_per_block) < present_crit:
                crit_probe = str(np.random.choice(critical_present_set,1,replace = False))[2:-2]
                if crit_probe not in present_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Present' in possible_images_dict[crit_probe]:

                    present_critical_per_block.append(crit_probe)
            critical_present.append(present_critical_per_block)
                    
        print 'present_critical_per_block:', present_critical_per_block
        
        if absent_crit != 0:
            absent_critical_per_block = []
            while len(absent_critical_per_block) < absent_crit:
                crit_probe = str(np.random.choice(critical_absent_set,1,replace = False))[2:-2]
                if crit_probe not in absent_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Absent' in possible_images_dict[crit_probe]:

                    absent_critical_per_block.append(crit_probe)
            critical_absent.append(absent_critical_per_block)
            
        print 'absent_critical_per_block:', absent_critical_per_block  
        print 'critical_present: ',critical_present
        print 'critical_absent: ',critical_absent
        
        for n in present_critical_per_block + absent_critical_per_block:
            critical_probes_used.append(n)
            
        print 'critical_probes_used: ', critical_probes_used
    #------------------------------------------------------------------------------
    # PICKING PRESENT AND ABSENT PROBES
        total = present_n + absent_n
        while len(probes_per_block) < (present_n - present_crit):
            probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in present_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        while (present_n - present_crit) <= len(probes_per_block) < total - present_crit - absent_crit:
            probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in absent_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        for n in probes_per_block:
            if 'Target Present' in possible_images_dict[n]:
                present_used.append(n)
            elif 'Target Absent' in possible_images_dict[n]:
                absent_used.append(n)

        probes.append(probes_per_block)
        
        print 'probes: ', probes
        present_per_block = [n for n in probes_per_block if 'Target Present' in possible_images_dict[n]]
        absent_per_block = [n for n in probes_per_block if 'Target Absent' in possible_images_dict[n]]
        print 'Present Used in block: ',len(present_per_block)
        print 'Absent Used in block',len(absent_per_block)
    #------------------------------------------------------------------------------    
    #Counting critical probes    
        critical_probes_counter = len(present_critical_per_block + absent_critical_per_block)
        print 'Critical probes counter: ',critical_probes_counter
        print 'Present Critical: ', len(present_critical_per_block)
        print 'Absent Critical: ', len(absent_critical_per_block)

        modifier.append(critical_probes_counter)
    #------------------------------------------------------------------------------
    #Picking critical trials
        while len(critical_per_block) < (3-critical_probes_counter):
            image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
            if image not in critical_per_block and image not in critical_used \
                and 'No Target' in possible_images_dict[image] and load in possible_images_dict[image]:
                critical_per_block.append(image) 
        print 'List of critical trials without probe: '
        for n in critical_per_block:
            critical_used.append(n)
            print possible_images_dict[n]
        #temp = []

        critical.append(critical_per_block)

    #------------------------------------------------------------------------------
    #Picking normal trials
        while len(normal_per_block) < 51 - (3 - critical_probes_counter):
            image = str(np.random.choice(normal,1,replace = False))[2:-2]
            if image not in normal_per_block and image not in normal_used and load in possible_images_dict[image]:
                normal_per_block.append(image)
        for n in normal_per_block:
            normal_used.append(n)
        print 'normal in this block: ', len(normal_per_block)
        print 'normal used overall: ',len(normal_used)

        normal_builder.append(normal_per_block)
    #----------------------------------------------------------------------------
        
        print 'critical_probes_used', critical_probes_used 
        
        
        
        if 'sequence_final' in locals():
            print 'sequence_final exists'
        else:
            print 'sequence final does not exist'
            sequence_final = position_finder()
            print sequence_final
        print'---------------------------------------------------'
        print 'END OF BLOCK PROCESSING'
        print'---------------------------------------------------'
        print 'BUILDING THE BLOCK'
        first_element = [x[0] for x in sequence_final]
        second_element = [x[1] for x in sequence_final]
        second_element_counter = 0
        probes_position = []
        for image in range(60):
            #print [x[1] for x in sequence_final if x[0] ==image][0]
            if image in first_element:
                
                print 'image', image, second_element[second_element_counter]
        
                if second_element[second_element_counter] == 'Target Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break       
                elif second_element[second_element_counter] == 'Target Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical':
                    while True:
                        element = str(np.random.choice(critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break     
                elif second_element[second_element_counter] == 'Critical Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break  
            else:
                while True:
                    element = str(np.random.choice(normal_per_block,1,replace = False))[2:-2]
                    if element not in block:
                        block.append(element)
                        break
                
        print 'block:', len(block)   
        print'---------------------------------------------------'
        print 'probes_position: ', probes_position
    #-----------------------------------------------------------------------------
        normal_per_block = []
        probes_per_block = []
        critical_per_block = []
        present_critical_per_block = []
        absent_critical_per_block = []
    #-----------------------------------------------------------------------------
    return block

# %%
def position_finder():
    global present_critical_per_block, absent_critical_per_block, present_per_block, absent_per_block, critical_per_block
    x = len(present_critical_per_block + absent_critical_per_block)
    print 'x', x
    print 'present_critical_per_block', len(present_critical_per_block)
    print 'absent_critical_per_block', len(absent_critical_per_block)
    while True:    
        while True:
            a = [random.randint(1,10) for r in xrange(12-x)]
            if sum(a) <= 60:
                break

        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]

        if len(present_critical_per_block) == 0 and len(absent_critical_per_block) == 0:
            print 'ciao', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block) + ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        if len(present_critical_per_block) != 0 or len(absent_critical_per_block) != 0:
            print 'ciao2', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block)  +\
            ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block) +\
            ['Critical Present'] * len(present_critical_per_block) +\
            ['Critical Absent'] * len(absent_critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        sequence_final = zip(new_list_1, sequence)
        #print sequence_final
        #print len(sequence_final)
        gap_check = [n[0] for n in sequence_final if 'Critical' in n[1]] 
        #print gap_check
        container = []
        for i in gap_check:
            elements = [i+1, i+2]
            for element in elements:
                if element in new_list_1:
                    container.append(element)
        #print 'container', len(container),container
        if len(container) == 0:
            break
        else:
            sequence_final = []

    print '------------------'
    print new_list_1, len(new_list_1)
    print 'gap_check: ', gap_check
    print len(sequence_final)

    for i in sequence_final:
        print i
    return sequence_final

# %%
def block_unpacker(splitting_index,present,absent):
    block = block_pair(present,absent) #, probes_position
    low_block = []
    high_block = []
    for i in range(len(block)):
        if i < (len(block)/2):
            low_block.append(block[i])
        else:
            high_block.append(block[i])
    #print probes_position
    print len(low_block), len(high_block)
    return low_block, high_block #, probes_position

# %%
def tone_properties():
    while True:
        possible_tones = ['tone1','tone2']
        low_one_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_two_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_three_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_four_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        high_one_tones = []
        high_two_tones = []
        high_three_tones = []
        high_four_tones = []
        for each in low_one_tones:
            if each == 'tone1':
                high_one_tones.append('tone2')
            elif each == 'tone2':
                high_one_tones.append('tone1')
        for each in low_two_tones:
            if each == 'tone1':
                high_two_tones.append('tone2')
            elif each == 'tone2':
                high_two_tones.append('tone1')
        for each in low_three_tones:
            if each == 'tone1':
                high_three_tones.append('tone2')
            elif each == 'tone2':
                high_three_tones.append('tone1')
        for each in low_four_tones:
            if each == 'tone1':
                high_four_tones.append('tone2')
            elif each == 'tone2':
                high_four_tones.append('tone1')
        sound_Hz = low_one_tones + low_two_tones + low_three_tones + low_four_tones + high_one_tones + high_two_tones +\
        high_three_tones + high_four_tones

        tone1_counter = 0
        tone2_counter = 0
        for each in sound_Hz:
            if each == 'tone1':
                tone1_counter = tone1_counter + 1
            elif each == 'tone2':
                tone2_counter = tone2_counter + 1

        low_load_tones = [n for n in sound_Hz[0:12]]
        high_load_tones = [n for n in sound_Hz[12:25]]
        low_load_tone1s = [n for n in low_load_tones if n == 'tone1']
        low_load_tone2s = [n for n in low_load_tones if n == 'tone2']
        high_load_tone1s = [n for n in high_load_tones if n == 'tone1']
        high_load_tone2s = [n for n in high_load_tones if n =='tone2']

        if len(low_load_tone1s) == len(low_load_tone2s) and len(high_load_tone1s) == len(high_load_tone2s):
            print low_one_tones
            print high_one_tones
            print '----------------------'
            print low_two_tones
            print high_two_tones
            print '----------------------'
            print low_three_tones
            print high_three_tones
            print '----------------------'
            print low_four_tones
            print high_four_tones
            print '----------------------'
            print 'total n of tones: ', len(sound_Hz)
            print '----------------------'
            print 'total n of 1500 Hz tones: ', tone1_counter
            print 'total n of 2000 Hz tones: ', tone2_counter
            print '----------------------'
            print len(low_load_tone1s) == len(low_load_tone2s)
            print len(low_load_tone1s)
            print len(low_load_tone2s)
            print len(high_load_tone1s) == len(high_load_tone2s)
            print len(high_load_tone1s)
            print len(high_load_tone2s)
            break
        # Re-ordering tones according to the block order
    sound_Hz_new = low_one_tones + high_two_tones + high_one_tones + low_two_tones + high_three_tones + low_four_tones +\
        low_three_tones + high_four_tones 
    print sound_Hz_new
    sound_onset = []
    for i in range(48):
        a = random.uniform(0, 0.999)
        a = int(str(a)[2:5])
        #print a
        sound_onset.append(a)
    return sound_Hz_new

    #------------------------------------------------------------------------------
    # APPEND TO DICT
    #sound_index = 0
    #for each in possible_images_dict:
    #    if 'Critical' in possible_images_dict[each]:
    #        possible_images_dict[each].append(sound_Hz_new[sound_index])
    #        print sound_Hz_new[sound_index]
    #        possible_images_dict[each].append(sound_onset[sound_index])
    #        sound_index = sound_index + 1
    #    elif 'Normal' in possible_images_dict[each]:
    #        possible_images_dict[each].append('No tone')
    #        possible_images_dict[each].append(-999)

# %%
def appending_to_dict(trial_n):
    global blocks
    for b in range(8):
        this_block_images = blocks[b]
        for im in this_block_images:
            trials[trial_n] = possible_images_dict[im]
            trials[trial_n].append(im)
            trial_n += 1
    print 'len(trials): ', len(trials)

# %%
######################
### FIRST ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  50
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  []
# critical absent set:  ['2011_002911.jpg', '2009_002306.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_005437.jpg', '2008_000760.jpg', '2008_007704.jpg', '2010_000616.jpg']
# probes_per_block : ['2010_005437.jpg', '2008_000760.jpg', '2008_007704.jpg', '2010_000616.jpg', '2008_000634.jpg', '2009_003679.jpg', '2008_003045.jpg', '2008_001708.jpg', '2008_001040.jpg']
# probes:  [['2010_005437.jpg', '2008_000760.jpg', '2008_007704.jpg', '2010_000616.jpg', '2008_000634.jpg', '2009_003679.jpg', '2008_003045.jpg', '2008_001708.jpg', '2008_001040.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', ' dog', nan, nan, nan, 21.001227278103954, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', ' person', nan, nan, nan, 17.856305662122608, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 19.54050687002545, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [2, 3, 13, 14, 19, 29, 36, 39, 43, 44, 47, 52] 12
# gap_check:  [3, 36, 44]
# 12
# (2, 'Target Present')
# (3, 'Critical')
# (13, 'Target Absent')
# (14, 'Target Absent')
# (19, 'Target Absent')
# (29, 'Target Present')
# (36, 'Critical')
# (39, 'Target Absent')
# (43, 'Target Present')
# (44, 'Critical')
# (47, 'Target Absent')
# (52, 'Target Present')
# [(2, 'Target Present'), (3, 'Critical'), (13, 'Target Absent'), (14, 'Target Absent'), (19, 'Target Absent'), (29, 'Target Present'), (36, 'Critical'), (39, 'Target Absent'), (43, 'Target Present'), (44, 'Critical'), (47, 'Target Absent'), (52, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Present
# image 3 Critical
# image 13 Target Absent
# image 14 Target Absent
# image 19 Target Absent
# image 29 Target Present
# image 36 Critical
# image 39 Target Absent
# image 43 Target Present
# image 44 Critical
# image 47 Target Absent
# image 52 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [2, 13, 14, 19, 29, 39, 43, 47, 52]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  []
# critical absent set:  ['2011_002911.jpg', '2009_002306.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_000792.jpg', '2010_005718.jpg', '2008_008210.jpg', '2010_003579.jpg']
# probes_per_block : ['2010_000792.jpg', '2010_005718.jpg', '2008_008210.jpg', '2010_003579.jpg', '2009_004794.jpg', '2009_001021.jpg', '2009_003520.jpg', '2008_007143.jpg', '2010_003943.jpg']
# probes:  [['2010_005437.jpg', '2008_000760.jpg', '2008_007704.jpg', '2010_000616.jpg', '2008_000634.jpg', '2009_003679.jpg', '2008_003045.jpg', '2008_001708.jpg', '2008_001040.jpg'], ['2010_000792.jpg', '2010_005718.jpg', '2008_008210.jpg', '2010_003579.jpg', '2009_004794.jpg', '2009_001021.jpg', '2009_003520.jpg', '2008_007143.jpg', '2010_003943.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' sofa', ' chair', ' diningtable', ' tvmonitor', 29.247483266365705, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 31.779858819461175, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' dog', nan, nan, nan, 29.851834352354174, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Present
# image 3 Critical
# image 13 Target Absent
# image 14 Target Absent
# image 19 Target Absent
# image 29 Target Present
# image 36 Critical
# image 39 Target Absent
# image 43 Target Present
# image 44 Critical
# image 47 Target Absent
# image 52 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [2, 13, 14, 19, 29, 39, 43, 47, 52]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  []
# critical absent set:  ['2011_002911.jpg', '2009_002306.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: ['2011_002911.jpg']
# critical_present:  []
# critical_absent:  [['2011_002911.jpg']]
# critical_probes_used:  ['2011_002911.jpg']
# probes_per_block : ['2009_002137.jpg', '2009_001568.jpg', '2008_006703.jpg', '2008_005903.jpg', '2009_001305.jpg']
# probes_per_block : ['2009_002137.jpg', '2009_001568.jpg', '2008_006703.jpg', '2008_005903.jpg', '2009_001305.jpg', '2009_004598.jpg', '2010_000132.jpg', '2009_001894.jpg']
# probes:  [['2010_005437.jpg', '2008_000760.jpg', '2008_007704.jpg', '2010_000616.jpg', '2008_000634.jpg', '2009_003679.jpg', '2008_003045.jpg', '2008_001708.jpg', '2008_001040.jpg'], ['2010_000792.jpg', '2010_005718.jpg', '2008_008210.jpg', '2010_003579.jpg', '2009_004794.jpg', '2009_001021.jpg', '2009_003520.jpg', '2008_007143.jpg', '2010_003943.jpg'], ['2009_002137.jpg', '2009_001568.jpg', '2008_006703.jpg', '2008_005903.jpg', '2009_001305.jpg', '2009_004598.jpg', '2010_000132.jpg', '2009_001894.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 12.53657278412077, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 19.09625234571384, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  145
# critical_probes_used ['2011_002911.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [0, 1, 5, 12, 21, 29, 33, 38, 40, 46, 56] 11
# gap_check:  [1, 29, 33]
# 11
# (0, 'Target Absent')
# (1, 'Critical')
# (5, 'Target Present')
# (12, 'Target Present')
# (21, 'Target Present')
# (29, 'Critical Absent')
# (33, 'Critical')
# (38, 'Target Present')
# (40, 'Target Absent')
# (46, 'Target Absent')
# (56, 'Target Present')
# [(0, 'Target Absent'), (1, 'Critical'), (5, 'Target Present'), (12, 'Target Present'), (21, 'Target Present'), (29, 'Critical Absent'), (33, 'Critical'), (38, 'Target Present'), (40, 'Target Absent'), (46, 'Target Absent'), (56, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 1 Critical
# image 5 Target Present
# image 12 Target Present
# image 21 Target Present
# image 29 Critical Absent
# image 33 Critical
# image 38 Target Present
# image 40 Target Absent
# image 46 Target Absent
# image 56 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 5, 12, 21, 29, 38, 40, 46, 56]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  []
# critical absent set:  ['2011_002911.jpg', '2009_002306.jpg']
# ---------------------------------------------------
# normal available: 241
# present_critical_per_block: []
# absent_critical_per_block: ['2009_002306.jpg']
# critical_present:  []
# critical_absent:  [['2011_002911.jpg'], ['2009_002306.jpg']]
# critical_probes_used:  ['2011_002911.jpg', '2009_002306.jpg']
# probes_per_block : ['2008_000274.jpg', '2008_006912.jpg', '2008_004487.jpg', '2009_000067.jpg', '2008_001965.jpg']
# probes_per_block : ['2008_000274.jpg', '2008_006912.jpg', '2008_004487.jpg', '2009_000067.jpg', '2008_001965.jpg', '2008_003701.jpg', '2008_000488.jpg', '2008_008229.jpg']
# probes:  [['2010_005437.jpg', '2008_000760.jpg', '2008_007704.jpg', '2010_000616.jpg', '2008_000634.jpg', '2009_003679.jpg', '2008_003045.jpg', '2008_001708.jpg', '2008_001040.jpg'], ['2010_000792.jpg', '2010_005718.jpg', '2008_008210.jpg', '2010_003579.jpg', '2009_004794.jpg', '2009_001021.jpg', '2009_003520.jpg', '2008_007143.jpg', '2010_003943.jpg'], ['2009_002137.jpg', '2009_001568.jpg', '2008_006703.jpg', '2008_005903.jpg', '2009_001305.jpg', '2009_004598.jpg', '2010_000132.jpg', '2009_001894.jpg'], ['2008_000274.jpg', '2008_006912.jpg', '2008_004487.jpg', '2009_000067.jpg', '2008_001965.jpg', '2008_003701.jpg', '2008_000488.jpg', '2008_008229.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 29.594597886254714, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' bottle', ' diningtable', nan, 35.13485651284549, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  194
# critical_probes_used ['2011_002911.jpg', '2009_002306.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 1 Critical
# image 5 Target Present
# image 12 Target Present
# image 21 Target Present
# image 29 Critical Absent
# image 33 Critical
# image 38 Target Present
# image 40 Target Absent
# image 46 Target Absent
# image 56 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 5, 12, 21, 29, 38, 40, 46, 56]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2011_002911.jpg', '2009_002306.jpg']
# ---------------------------------------------------
# normal available: 192
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2011_002911.jpg'], ['2009_002306.jpg']]
# critical_probes_used:  ['2011_002911.jpg', '2009_002306.jpg']
# probes_per_block : ['2009_000260.jpg', '2009_002439.jpg', '2010_004231.jpg', '2010_003890.jpg']
# probes_per_block : ['2009_000260.jpg', '2009_002439.jpg', '2010_004231.jpg', '2010_003890.jpg', '2008_006564.jpg', '2011_000224.jpg', '2009_005036.jpg', '2008_004893.jpg', '2009_000919.jpg']
# probes:  [['2010_005437.jpg', '2008_000760.jpg', '2008_007704.jpg', '2010_000616.jpg', '2008_000634.jpg', '2009_003679.jpg', '2008_003045.jpg', '2008_001708.jpg', '2008_001040.jpg'], ['2010_000792.jpg', '2010_005718.jpg', '2008_008210.jpg', '2010_003579.jpg', '2009_004794.jpg', '2009_001021.jpg', '2009_003520.jpg', '2008_007143.jpg', '2010_003943.jpg'], ['2009_002137.jpg', '2009_001568.jpg', '2008_006703.jpg', '2008_005903.jpg', '2009_001305.jpg', '2009_004598.jpg', '2010_000132.jpg', '2009_001894.jpg'], ['2008_000274.jpg', '2008_006912.jpg', '2008_004487.jpg', '2009_000067.jpg', '2008_001965.jpg', '2008_003701.jpg', '2008_000488.jpg', '2008_008229.jpg'], ['2009_000260.jpg', '2009_002439.jpg', '2010_004231.jpg', '2010_003890.jpg', '2008_006564.jpg', '2011_000224.jpg', '2009_005036.jpg', '2008_004893.jpg', '2009_000919.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' boat', nan, nan, nan, 17.69816713203682, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 20.529451477248333, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 19.803149147012245, 'low', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  242
# critical_probes_used ['2011_002911.jpg', '2009_002306.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [7, 10, 15, 23, 28, 31, 35, 38, 39, 41, 51, 59] 12
# gap_check:  [15, 31, 59]
# 12
# (7, 'Target Present')
# (10, 'Target Absent')
# (15, 'Critical')
# (23, 'Target Present')
# (28, 'Target Present')
# (31, 'Critical')
# (35, 'Target Absent')
# (38, 'Target Absent')
# (39, 'Target Absent')
# (41, 'Target Present')
# (51, 'Target Absent')
# (59, 'Critical')
# [(7, 'Target Present'), (10, 'Target Absent'), (15, 'Critical'), (23, 'Target Present'), (28, 'Target Present'), (31, 'Critical'), (35, 'Target Absent'), (38, 'Target Absent'), (39, 'Target Absent'), (41, 'Target Present'), (51, 'Target Absent'), (59, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image
Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [6, 9, 16, 21, 29, 36, 37, 43, 58]
# 60 60
# ['tone2', 'tone1', 'tone2']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone2']
# ['tone2', 'tone1', 'tone1']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone1']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2']
# tone2
# tone1
# tone2
# tone2
# tone1
# tone1
# tone1
# tone2
# tone1
# tone1
# tone2
# tone2
# tone2
# tone2
# tone1
# tone1
# tone2
# tone1
# tone1
# tone1
# tone2
# tone2
# tone1
# tone2
# len(trials):  480

# %%
######################
### SECOND ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(481)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  6
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2009_002803.jpg', '2009_001021.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_000912.jpg', '2009_002521.jpg', '2008_002904.jpg', '2008_008533.jpg']
# probes_per_block : ['2008_000912.jpg', '2009_002521.jpg', '2008_002904.jpg', '2008_008533.jpg', '2010_002393.jpg', '2010_002349.jpg', '2008_001040.jpg', '2010_003746.jpg', '2008_002504.jpg']
# probes:  [['2008_000912.jpg', '2009_002521.jpg', '2008_002904.jpg', '2008_008533.jpg', '2010_002393.jpg', '2010_002349.jpg', '2008_001040.jpg', '2010_003746.jpg', '2008_002504.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' chair', ' diningtable', nan, nan, 17.13857605003491, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 21.198620417532712, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 20.821731630747827, 'low', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [5, 11, 19, 20, 27, 35, 37, 39, 47, 53, 54, 56] 12
# gap_check:  [11, 27, 47]
# 12
# (5, 'Target Present')
# (11, 'Critical')
# (19, 'Target Absent')
# (20, 'Target Absent')
# (27, 'Critical')
# (35, 'Target Present')
# (37, 'Target Absent')
# (39, 'Target Present')
# (47, 'Critical')
# (53, 'Target Absent')
# (54, 'Target Present')
# (56, 'Target Absent')
# [(5, 'Target Present'), (11, 'Critical'), (19, 'Target Absent'), (20, 'Target Absent'), (27, 'Critical'), (35, 'Target Present'), (37, 'Target Absent'), (39, 'Target Present'), (47, 'Critical'), (53, 'Target Absent'), (54, 'Target Present'), (56, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Present
# image 11 Critical
# image 19 Target Absent
# image 20 Target Absent
# image 27 Critical
# image 35 Target Present
# image 37 Target Absent
# image 39 Target Present
# image 47 Critical
# image 53 Target Absent
# image 54 Target Present
# image 56 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 19, 20, 35, 37, 39, 53, 54, 56]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2009_002803.jpg', '2009_001021.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_003579.jpg', '2009_000198.jpg', '2008_003378.jpg', '2011_000548.jpg']
# probes_per_block : ['2010_003579.jpg', '2009_000198.jpg', '2008_003378.jpg', '2011_000548.jpg', '2008_007423.jpg', '2010_003419.jpg', '2008_002350.jpg', '2008_001333.jpg', '2008_008470.jpg']
# probes:  [['2008_000912.jpg', '2009_002521.jpg', '2008_002904.jpg', '2008_008533.jpg', '2010_002393.jpg', '2010_002349.jpg', '2008_001040.jpg', '2010_003746.jpg', '2008_002504.jpg'], ['2010_003579.jpg', '2009_000198.jpg', '2008_003378.jpg', '2011_000548.jpg', '2008_007423.jpg', '2010_003419.jpg', '2008_002350.jpg', '2008_001333.jpg', '2008_008470.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' train', ' sofa', nan, nan, 31.65115644279944, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 30.384187271419634, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 31.892125506726913, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Present
# image 11 Critical
# image 19 Target Absent
# image 20 Target Absent
# image 27 Critical
# image 35 Target Present
# image 37 Target Absent
# image 39 Target Present
# image 47 Critical
# image 53 Target Absent
# image 54 Target Present
# image 56 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 19, 20, 35, 37, 39, 53, 54, 56]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2009_002803.jpg', '2009_001021.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_007208.jpg', '2008_000734.jpg', '2008_000740.jpg', '2008_001238.jpg', '2010_001907.jpg']
# probes_per_block : ['2008_007208.jpg', '2008_000734.jpg', '2008_000740.jpg', '2008_001238.jpg', '2010_001907.jpg', '2010_003400.jpg', '2008_002700.jpg', '2009_002325.jpg', '2010_001993.jpg']
# probes:  [['2008_000912.jpg', '2009_002521.jpg', '2008_002904.jpg', '2008_008533.jpg', '2010_002393.jpg', '2010_002349.jpg', '2008_001040.jpg', '2010_003746.jpg', '2008_002504.jpg'], ['2010_003579.jpg', '2009_000198.jpg', '2008_003378.jpg', '2011_000548.jpg', '2008_007423.jpg', '2010_003419.jpg', '2008_002350.jpg', '2008_001333.jpg', '2008_008470.jpg'], ['2008_007208.jpg', '2008_000734.jpg', '2008_000740.jpg', '2008_001238.jpg', '2010_001907.jpg', '2010_003400.jpg', '2008_002700.jpg', '2009_002325.jpg', '2010_001993.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 20.48716672648194, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 20.712898768714968, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 18.135096838925413, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [7, 10, 15, 24, 25, 30, 37, 41, 42, 47, 52, 59] 12
# gap_check:  [7, 30, 42]
# 12
# (7, 'Critical')
# (10, 'Target Present')
# (15, 'Target Present')
# (24, 'Target Present')
# (25, 'Target Present')
# (30, 'Critical')
# (37, 'Target Absent')
# (41, 'Target Absent')
# (42, 'Critical')
# (47, 'Target Absent')
# (52, 'Target Present')
# (59, 'Target Absent')
# [(7, 'Critical'), (10, 'Target Present'), (15, 'Target Present'), (24, 'Target Present'), (25, 'Target Present'), (30, 'Critical'), (37, 'Target Absent'), (41, 'Target Absent'), (42, 'Critical'), (47, 'Target Absent'), (52, 'Target Present'), (59, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Critical
# image 10 Target Present
# image 15 Target Present
# image 24 Target Present
# image 25 Target Present
# image 30 Critical
# image 37 Target Absent
# image 41 Target Absent
# image 42 Critical
# image 47 Target Absent
# image 52 Target Present
# image 59 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [10, 15, 24, 25, 37, 41, 47, 52, 59]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2009_002803.jpg', '2009_001021.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_004763.jpg', '2008_005472.jpg', '2008_002864.jpg', '2011_002971.jpg', '2010_003490.jpg']
# probes_per_block : ['2010_004763.jpg', '2008_005472.jpg', '2008_002864.jpg', '2011_002971.jpg', '2010_003490.jpg', '2008_006663.jpg', '2008_000196.jpg', '2010_000074.jpg', '2010_000815.jpg']
# probes:  [['2008_000912.jpg', '2009_002521.jpg', '2008_002904.jpg', '2008_008533.jpg', '2010_002393.jpg', '2010_002349.jpg', '2008_001040.jpg', '2010_003746.jpg', '2008_002504.jpg'], ['2010_003579.jpg', '2009_000198.jpg', '2008_003378.jpg', '2011_000548.jpg', '2008_007423.jpg', '2010_003419.jpg', '2008_002350.jpg', '2008_001333.jpg', '2008_008470.jpg'], ['2008_007208.jpg', '2008_000734.jpg', '2008_000740.jpg', '2008_001238.jpg', '2010_001907.jpg', '2010_003400.jpg', '2008_002700.jpg', '2009_002325.jpg', '2010_001993.jpg'], ['2010_004763.jpg', '2008_005472.jpg', '2008_002864.jpg', '2011_002971.jpg', '2010_003490.jpg', '2008_006663.jpg', '2008_000196.jpg', '2010_000074.jpg', '2010_000815.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' tvmonitor', ' cat', nan, nan, 31.67044719842205, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 34.96752773409758, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 30.39404844580157, 'high', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Critical
# image 10 Target Present
# image 15 Target Present
# image 24 Target Present
# image 25 Target Present
# image 30 Critical
# image 37 Target Absent
# image 41 Target Absent
# image 42 Critical
# image 47 Target Absent
# image 52 Target Present
# image 59 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [10, 15, 24, 25, 37, 41, 47, 52, 59]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2009_002803.jpg', '2009_001021.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: ['2009_002803.jpg']
# critical_present:  []
# critical_absent:  [['2009_002803.jpg']]
# critical_probes_used:  ['2009_002803.jpg']
# probes_per_block : ['2009_002817.jpg', '2010_002498.jpg', '2008_000105.jpg', '2010_002645.jpg']
# probes_per_block : ['2009_002817.jpg', '2010_002498.jpg', '2008_000105.jpg', '2010_002645.jpg', '2011_002453.jpg', '2011_001656.jpg', '2008_004893.jpg', '2009_002594.jpg']
# probes:  [['2008_000912.jpg', '2009_002521.jpg', '2008_002904.jpg', '2008_008533.jpg', '2010_002393.jpg', '2010_002349.jpg', '2008_001040.jpg', '2010_003746.jpg', '2008_002504.jpg'], ['2010_003579.jpg', '2009_000198.jpg', '2008_003378.jpg', '2011_000548.jpg', '2008_007423.jpg', '2010_003419.jpg', '2008_002350.jpg', '2008_001333.jpg', '2008_008470.jpg'], ['2008_007208.jpg', '2008_000734.jpg', '2008_000740.jpg', '2008_001238.jpg', '2010_001907.jpg', '2010_003400.jpg', '2008_002700.jpg', '2009_002325.jpg', '2010_001993.jpg'], ['2010_004763.jpg', '2008_005472.jpg', '2008_002864.jpg', '2011_002971.jpg', '2010_003490.jpg', '2008_006663.jpg', '2008_000196.jpg', '2010_000074.jpg', '2010_000815.jpg'], ['2009_002817.jpg', '2010_002498.jpg', '2008_000105.jpg', '2010_002645.jpg', '2011_002453.jpg', '2011_001656.jpg', '2008_004893.jpg', '2009_002594.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' bottle', nan, nan, nan, 19.86909924741182, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 19.234401336670953, 'low', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  241
# critical_probes_used ['2009_002803.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [2, 12, 13, 16, 25, 29, 33, 36, 44, 54, 59] 11
# gap_check:  [2, 33, 36]
# 11
# (2, 'Critical')
# (12, 'Target Absent')
# (13, 'Target Absent')
# (16, 'Target Absent')
# (25, 'Target Absent')
# (29, 'Target Present')
# (33, 'Critical')
# (36, 'Critical Absent')
# (44, 'Target Present')
# (54, 'Target Present')
# (59, 'Target Present')
# [(2, 'Critical'), (12, 'Target Absent'), (13, 'Target Absent'), (16, 'Target Absent'), (25, 'Target Absent'), (29, 'Target Present'), (33, 'Critical'), (36, 'Critical Absent'), (44, 'Target Present'), (54, 'Target Present'), (59, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Critical
# image 12 Target Absent
# image 13 Target Absent
# image 16 Target Absent
# image 25 Target Absent
# image 29 Target Present
# image 33 Critical
# image 36 Critical Absent
# image 44 Target Present
# image 54 Target Present
# image 59 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [12, 13, 16, 25, 29, 36, 44, 54, 59]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2009_002803.jpg', '2009_001021.jpg']
# ---------------------------------------------------
# normal available: 145
# present_critical_per_block: []
# absent_critical_per_block: ['2009_001021.jpg']
# critical_present:  []
# critical_absent:  [['2009_002803.jpg'], ['2009_001021.jpg']]
# critical_probes_used:  ['2009_002803.jpg', '2009_001021.jpg']
# probes_per_block : ['2008_003180.jpg', '2011_000628.jpg', '2008_000833.jpg', '2010_002127.jpg']
# probes_per_block : ['2008_003180.jpg', '2011_000628.jpg', '2008_000833.jpg', '2010_002127.jpg', '2008_002195.jpg', '2009_000760.jpg', '2008_007970.jpg', '2008_000321.jpg']
# probes:  [['2008_000912.jpg', '2009_002521.jpg', '2008_002904.jpg', '2008_008533.jpg', '2010_002393.jpg', '2010_002349.jpg', '2008_001040.jpg', '2010_003746.jpg', '2008_002504.jpg'], ['2010_003579.jpg', '2009_000198.jpg', '2008_003378.jpg', '2011_000548.jpg', '2008_007423.jpg', '2010_003419.jpg', '2008_002350.jpg', '2008_001333.jpg', '2008_008470.jpg'], ['2008_007208.jpg', '2008_000734.jpg', '2008_000740.jpg', '2008_001238.jpg', '2010_001907.jpg', '2010_003400.jpg', '2008_002700.jpg', '2009_002325.jpg', '2010_001993.jpg'], ['2010_004763.jpg', '2008_005472.jpg', '2008_002864.jpg', '2011_002971.jpg', '2010_003490.jpg', '2008_006663.jpg', '2008_000196.jpg', '2010_000074.jpg', '2010_000815.jpg'], ['2009_002817.jpg', '2010_002498.jpg', '2008_000105.jpg', '2010_002645.jpg', '2011_002453.jpg', '2011_001656.jpg', '2008_004893.jpg', '2009_002594.jpg'], ['2008_003180.jpg', '2011_000628.jpg', '2008_000833.jpg', '2010_002127.jpg', '2008_002195.jpg', '2009_000760.jpg', '2008_007970.jpg', '2008_000321.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 31.96963432435441, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 31.520687613930374, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  290
# critical_probes_used ['2009_002803.jpg', '2009_001021.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Critical
# image 12 Target Absent
# image 13 Target Absent
# image 16 Target Absent
# image 25 Target Absent
# image 29 Target Present
# image 33 Critical
# image 36 Critical Absent
# image 44 Target Present
# image 54 Target Present
# image 59 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  
_001238.jpg', '2010_001907.jpg', '2010_003400.jpg', '2008_002700.jpg', '2009_002325.jpg', '2010_001993.jpg'], ['2010_004763.jpg', '2008_005472.jpg', '2008_002864.jpg', '2011_002971.jpg', '2010_003490.jpg', '2008_006663.jpg', '2008_000196.jpg', '2010_000074.jpg', '2010_000815.jpg'], ['2009_002817.jpg', '2010_002498.jpg', '2008_000105.jpg', '2010_002645.jpg', '2011_002453.jpg', '2011_001656.jpg', '2008_004893.jpg', '2009_002594.jpg'], ['2008_003180.jpg', '2011_000628.jpg', '2008_000833.jpg', '2010_002127.jpg', '2008_002195.jpg', '2009_000760.jpg', '2008_007970.jpg', '2008_000321.jpg'], ['2008_006703.jpg', '2011_002582.jpg', '2009_000919.jpg', '2008_000952.jpg', '2009_002439.jpg', '2010_005885.jpg', '2008_004270.jpg', '2009_003373.jpg', '2008_004269.jpg'], ['2011_000530.jpg', '2008_004188.jpg', '2008_000541.jpg', '2008_005526.jpg', '2009_003705.jpg', '2008_004690.jpg', '2008_005600.jpg', '2009_002414.jpg', '2008_002773.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' dog', nan, nan, nan, nan, 31.72817006314488, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 31.676385713707838, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' bottle', nan, nan, 32.179769175040214, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  386
# critical_probes_used ['2009_002803.jpg', '2009_001021.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 1 Critical
# image 7 Target Present
# image 17 Target Present
# image 20 Target Absent
# image 22 Critical
# image 26 Target Absent
# image 28 Target Absent
# image 30 Target Present
# image 32 Critical
# image 41 Target Present
# image 50 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 7, 17, 20, 26, 28, 30, 41, 50]
# 60 60
# ['tone2', 'tone2', 'tone2']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone2', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone2']
# tone2
# tone2
# tone2
# tone1
# tone2
# tone2
# tone1
# tone1
# tone1
# tone2
# tone1
# tone1
# tone1
# tone2
# tone2
# tone2
# tone1
# tone1
# tone2
# tone1
# tone1
# tone1
# tone2
# tone2
# len(trials):  960

# %%
######################
### THIRD ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(961)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  22
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2011_001432.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_001238.jpg', '2011_001967.jpg', '2008_000952.jpg', '2008_000940.jpg']
# probes_per_block : ['2008_001238.jpg', '2011_001967.jpg', '2008_000952.jpg', '2008_000940.jpg', '2008_000189.jpg', '2008_000398.jpg', '2010_003287.jpg', '2009_002888.jpg', '2008_005728.jpg']
# probes:  [['2008_001238.jpg', '2011_001967.jpg', '2008_000952.jpg', '2008_000940.jpg', '2008_000189.jpg', '2008_000398.jpg', '2010_003287.jpg', '2009_002888.jpg', '2008_005728.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' chair', ' diningtable', ' bottle', nan, nan, 20.038119878562025, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 14.1064450150686, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 19.25351959992476, 'low', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [0, 6, 11, 21, 27, 35, 41, 45, 48, 52, 56, 59] 12
# gap_check:  [0, 21, 27]
# 12
# (0, 'Critical')
# (6, 'Target Present')
# (11, 'Target Absent')
# (21, 'Critical')
# (27, 'Critical')
# (35, 'Target Absent')
# (41, 'Target Absent')
# (45, 'Target Present')
# (48, 'Target Absent')
# (52, 'Target Present')
# (56, 'Target Absent')
# (59, 'Target Present')
# [(0, 'Critical'), (6, 'Target Present'), (11, 'Target Absent'), (21, 'Critical'), (27, 'Critical'), (35, 'Target Absent'), (41, 'Target Absent'), (45, 'Target Present'), (48, 'Target Absent'), (52, 'Target Present'), (56, 'Target Absent'), (59, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Critical
# image 6 Target Present
# image 11 Target Absent
# image 21 Critical
# image 27 Critical
# image 35 Target Absent
# image 41 Target Absent
# image 45 Target Present
# image 48 Target Absent
# image 52 Target Present
# image 56 Target Absent
# image 59 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [6, 11, 35, 41, 45, 48, 52, 56, 59]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2011_001432.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_005347.jpg', '2010_004447.jpg', '2009_000995.jpg', '2010_005572.jpg']
# probes_per_block : ['2008_005347.jpg', '2010_004447.jpg', '2009_000995.jpg', '2010_005572.jpg', '2008_006870.jpg', '2011_002810.jpg', '2008_000202.jpg', '2008_000321.jpg', '2010_000815.jpg']
# probes:  [['2008_001238.jpg', '2011_001967.jpg', '2008_000952.jpg', '2008_000940.jpg', '2008_000189.jpg', '2008_000398.jpg', '2010_003287.jpg', '2009_002888.jpg', '2008_005728.jpg'], ['2008_005347.jpg', '2010_004447.jpg', '2009_000995.jpg', '2010_005572.jpg', '2008_006870.jpg', '2011_002810.jpg', '2008_000202.jpg', '2008_000321.jpg', '2010_000815.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 31.892125506726913, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 31.53785712566009, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 34.28798865304669, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Critical
# image 6 Target Present
# image 11 Target Absent
# image 21 Critical
# image 27 Critical
# image 35 Target Absent
# image 41 Target Absent
# image 45 Target Present
# image 48 Target Absent
# image 52 Target Present
# image 56 Target Absent
# image 59 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [6, 11, 35, 41, 45, 48, 52, 56, 59]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2011_001432.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_005869.jpg', '2010_001451.jpg', '2011_001613.jpg', '2009_000059.jpg', '2010_004175.jpg']
# probes_per_block : ['2008_005869.jpg', '2010_001451.jpg', '2011_001613.jpg', '2009_000059.jpg', '2010_004175.jpg', '2011_001624.jpg', '2008_004269.jpg', '2008_001098.jpg', '2010_001691.jpg']
# probes:  [['2008_001238.jpg', '2011_001967.jpg', '2008_000952.jpg', '2008_000940.jpg', '2008_000189.jpg', '2008_000398.jpg', '2010_003287.jpg', '2009_002888.jpg', '2008_005728.jpg'], ['2008_005347.jpg', '2010_004447.jpg', '2009_000995.jpg', '2010_005572.jpg', '2008_006870.jpg', '2011_002810.jpg', '2008_000202.jpg', '2008_000321.jpg', '2010_000815.jpg'], ['2008_005869.jpg', '2010_001451.jpg', '2011_001613.jpg', '2009_000059.jpg', '2010_004175.jpg', '2011_001624.jpg', '2008_004269.jpg', '2008_001098.jpg', '2010_001691.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', nan, nan, nan, nan, 18.03153744936175, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' sofa', ' chair', nan, nan, nan, 19.836491630222174, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 21.181010736182625, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [4, 11, 14, 16, 19, 24, 34, 36, 40, 43, 53, 58] 12
# gap_check:  [11, 16, 53]
# 12
# (4, 'Target Absent')
# (11, 'Critical')
# (14, 'Target Present')
# (16, 'Critical')
# (19, 'Target Absent')
# (24, 'Target Present')
# (34, 'Target Present')
# (36, 'Target Present')
# (40, 'Target Absent')
# (43, 'Target Present')
# (53, 'Critical')
# (58, 'Target Absent')
# [(4, 'Target Absent'), (11, 'Critical'), (14, 'Target Present'), (16, 'Critical'), (19, 'Target Absent'), (24, 'Target Present'), (34, 'Target Present'), (36, 'Target Present'), (40, 'Target Absent'), (43, 'Target Present'), (53, 'Critical'), (58, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 4 Target Absent
# image 11 Critical
# image 14 Target Present
# image 16 Critical
# image 19 Target Absent
# image 24 Target Present
# image 34 Target Present
# image 36 Target Present
# image 40 Target Absent
# image 43 Target Present
# image 53 Critical
# image 58 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [4, 14, 19, 24, 34, 36, 40, 43, 58]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2011_001432.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_000860.jpg', '2010_005718.jpg', '2010_002183.jpg', '2011_001025.jpg', '2008_002736.jpg']
# probes_per_block : ['2008_000860.jpg', '2010_005718.jpg', '2010_002183.jpg', '2011_001025.jpg', '2008_002736.jpg', '2008_007629.jpg', '2010_002278.jpg', '2010_006033.jpg', '2008_004482.jpg']
# probes:  [['2008_001238.jpg', '2011_001967.jpg', '2008_000952.jpg', '2008_000940.jpg', '2008_000189.jpg', '2008_000398.jpg', '2010_003287.jpg', '2009_002888.jpg', '2008_005728.jpg'], ['2008_005347.jpg', '2010_004447.jpg', '2009_000995.jpg', '2010_005572.jpg', '2008_006870.jpg', '2011_002810.jpg', '2008_000202.jpg', '2008_000321.jpg', '2010_000815.jpg'], ['2008_005869.jpg', '2010_001451.jpg', '2011_001613.jpg', '2009_000059.jpg', '2010_004175.jpg', '2011_001624.jpg', '2008_004269.jpg', '2008_001098.jpg', '2010_001691.jpg'], ['2008_000860.jpg', '2010_005718.jpg', '2010_002183.jpg', '2011_001025.jpg', '2008_002736.jpg', '2008_007629.jpg', '2010_002278.jpg', '2010_006033.jpg', '2008_004482.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 30.141763061562205, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 30.95304328989037, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' chair', ' dog', ' diningtable', nan, nan, 29.611440342795753, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 4 Target Absent
# image 11 Critical
# image 14 Target Present
# image 16 Critical
# image 19 Target Absent
# image 24 Target Present
# image 34 Target Present
# image 36 Target Present
# image 40 Target Absent
# image 43 Target Present
# image 53 Critical
# image 58 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [4, 14, 19, 24, 34, 36, 40, 43, 58]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2011_001432.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: ['2011_001432.jpg']
# critical_present:  []
# critical_absent:  [['2011_001432.jpg']]
# critical_probes_used:  ['2011_001432.jpg']
# probes_per_block : ['2011_002911.jpg', '2010_002349.jpg', '2010_000109.jpg', '2008_005214.jpg']
# probes_per_block : ['2011_002911.jpg', '2010_002349.jpg', '2010_000109.jpg', '2008_005214.jpg', '2010_002645.jpg', '2008_007274.jpg', '2008_007208.jpg', '2009_003993.jpg']
# probes:  [['2008_001238.jpg', '2011_001967.jpg', '2008_000952.jpg', '2008_000940.jpg', '2008_000189.jpg', '2008_000398.jpg', '2010_003287.jpg', '2009_002888.jpg', '2008_005728.jpg'], ['2008_005347.jpg', '2010_004447.jpg', '2009_000995.jpg', '2010_005572.jpg', '2008_006870.jpg', '2011_002810.jpg', '2008_000202.jpg', '2008_000321.jpg', '2010_000815.jpg'], ['2008_005869.jpg', '2010_001451.jpg', '2011_001613.jpg', '2009_000059.jpg', '2010_004175.jpg', '2011_001624.jpg', '2008_004269.jpg', '2008_001098.jpg', '2010_001691.jpg'], ['2008_000860.jpg', '2010_005718.jpg', '2010_002183.jpg', '2011_001025.jpg', '2008_002736.jpg', '2008_007629.jpg', '2010_002278.jpg', '2010_006033.jpg', '2008_004482.jpg'], ['2011_002911.jpg', '2010_002349.jpg', '2010_000109.jpg', '2008_005214.jpg', '2010_002645.jpg', '2008_007274.jpg', '2008_007208.jpg', '2009_003993.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 18.41425575439328, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' sofa', nan, nan, nan, 20.707877775353552, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  241
# critical_probes_used ['2011_001432.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
#
jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Absent
# image 6 Target Absent
# image 7 Critical
# image 10 Target Absent
# image 19 Target Absent
# image 21 Critical
# image 24 Target Present
# image 31 Target Present
# image 41 Target Present
# image 48 Target Present
# image 52 Target Present
# image 58 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [2, 6, 10, 19, 24, 31, 41, 48, 52]
# 60 60
# ['tone1', 'tone2', 'tone1']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone2']
# ['tone2', 'tone1', 'tone1']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone2', 'tone1']
# tone1
# tone2
# tone1
# tone1
# tone2
# tone1
# tone2
# tone1
# tone2
# tone2
# tone1
# tone2
# tone2
# tone1
# tone1
# tone1
# tone1
# tone2
# tone1
# tone2
# tone2
# tone2
# tone2
# tone1
# len(trials):  1440

# %%
######################
### FOURTH ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1441)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  13
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  []
# critical absent set:  ['2008_005046.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_000189.jpg', '2010_005217.jpg', '2008_004269.jpg', '2009_002803.jpg']
# probes_per_block : ['2008_000189.jpg', '2010_005217.jpg', '2008_004269.jpg', '2009_002803.jpg', '2011_001613.jpg', '2008_008263.jpg', '2010_002956.jpg', '2010_002379.jpg', '2011_000293.jpg']
# probes:  [['2008_000189.jpg', '2010_005217.jpg', '2008_004269.jpg', '2009_002803.jpg', '2011_001613.jpg', '2008_008263.jpg', '2010_002956.jpg', '2010_002379.jpg', '2011_000293.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', nan, nan, nan, nan, 17.0559093734335, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' cat', nan, nan, nan, 20.139877805151375, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 20.15804441055767, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [5, 6, 8, 10, 14, 23, 27, 34, 39, 43, 50, 56] 12
# gap_check:  [14, 34, 43]
# 12
# (5, 'Target Present')
# (6, 'Target Absent')
# (8, 'Target Absent')
# (10, 'Target Absent')
# (14, 'Critical')
# (23, 'Target Present')
# (27, 'Target Absent')
# (34, 'Critical')
# (39, 'Target Absent')
# (43, 'Critical')
# (50, 'Target Present')
# (56, 'Target Present')
# [(5, 'Target Present'), (6, 'Target Absent'), (8, 'Target Absent'), (10, 'Target Absent'), (14, 'Critical'), (23, 'Target Present'), (27, 'Target Absent'), (34, 'Critical'), (39, 'Target Absent'), (43, 'Critical'), (50, 'Target Present'), (56, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Present
# image 6 Target Absent
# image 8 Target Absent
# image 10 Target Absent
# image 14 Critical
# image 23 Target Present
# image 27 Target Absent
# image 34 Critical
# image 39 Target Absent
# image 43 Critical
# image 50 Target Present
# image 56 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 6, 8, 10, 23, 27, 39, 50, 56]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  []
# critical absent set:  ['2008_005046.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_008500.jpg', '2008_008210.jpg', '2008_004487.jpg', '2008_000798.jpg']
# probes_per_block : ['2008_008500.jpg', '2008_008210.jpg', '2008_004487.jpg', '2008_000798.jpg', '2009_001321.jpg', '2009_003884.jpg', '2011_001605.jpg', '2008_002774.jpg', '2009_005118.jpg']
# probes:  [['2008_000189.jpg', '2010_005217.jpg', '2008_004269.jpg', '2009_002803.jpg', '2011_001613.jpg', '2008_008263.jpg', '2010_002956.jpg', '2010_002379.jpg', '2011_000293.jpg'], ['2008_008500.jpg', '2008_008210.jpg', '2008_004487.jpg', '2008_000798.jpg', '2009_001321.jpg', '2009_003884.jpg', '2011_001605.jpg', '2008_002774.jpg', '2009_005118.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 29.246976174425782, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 29.26546246503357, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 29.27265460253791, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Present
# image 6 Target Absent
# image 8 Target Absent
# image 10 Target Absent
# image 14 Critical
# image 23 Target Present
# image 27 Target Absent
# image 34 Critical
# image 39 Target Absent
# image 43 Critical
# image 50 Target Present
# image 56 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 6, 8, 10, 23, 27, 39, 50, 56]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  []
# critical absent set:  ['2008_005046.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: ['2008_005046.jpg']
# critical_present:  []
# critical_absent:  [['2008_005046.jpg']]
# critical_probes_used:  ['2008_005046.jpg']
# probes_per_block : ['2008_002700.jpg', '2010_001036.jpg', '2010_000229.jpg', '2011_001886.jpg', '2008_008083.jpg']
# probes_per_block : ['2008_002700.jpg', '2010_001036.jpg', '2010_000229.jpg', '2011_001886.jpg', '2008_008083.jpg', '2008_001185.jpg', '2008_007208.jpg', '2008_008533.jpg']
# probes:  [['2008_000189.jpg', '2010_005217.jpg', '2008_004269.jpg', '2009_002803.jpg', '2011_001613.jpg', '2008_008263.jpg', '2010_002956.jpg', '2010_002379.jpg', '2011_000293.jpg'], ['2008_008500.jpg', '2008_008210.jpg', '2008_004487.jpg', '2008_000798.jpg', '2009_001321.jpg', '2009_003884.jpg', '2011_001605.jpg', '2008_002774.jpg', '2009_005118.jpg'], ['2008_002700.jpg', '2010_001036.jpg', '2010_000229.jpg', '2011_001886.jpg', '2008_008083.jpg', '2008_001185.jpg', '2008_007208.jpg', '2008_008533.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' dog', nan, nan, nan, nan, 16.693372571654717, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' chair', ' diningtable', ' bottle', nan, nan, 20.038119878562025, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  145
# critical_probes_used ['2008_005046.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [4, 10, 20, 22, 25, 26, 33, 34, 38, 43, 46] 11
# gap_check:  [4, 38, 43]
# 11
# (4, 'Critical Absent')
# (10, 'Target Present')
# (20, 'Target Present')
# (22, 'Target Present')
# (25, 'Target Present')
# (26, 'Target Absent')
# (33, 'Target Absent')
# (34, 'Target Present')
# (38, 'Critical')
# (43, 'Critical')
# (46, 'Target Absent')
# [(4, 'Critical Absent'), (10, 'Target Present'), (20, 'Target Present'), (22, 'Target Present'), (25, 'Target Present'), (26, 'Target Absent'), (33, 'Target Absent'), (34, 'Target Present'), (38, 'Critical'), (43, 'Critical'), (46, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 4 Critical Absent
# image 10 Target Present
# image 20 Target Present
# image 22 Target Present
# image 25 Target Present
# image 26 Target Absent
# image 33 Target Absent
# image 34 Target Present
# image 38 Critical
# image 43 Critical
# image 46 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [4, 10, 20, 22, 25, 26, 33, 34, 46]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  []
# critical absent set:  ['2008_005046.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 241
# present_critical_per_block: []
# absent_critical_per_block: ['2008_006844.jpg']
# critical_present:  []
# critical_absent:  [['2008_005046.jpg'], ['2008_006844.jpg']]
# critical_probes_used:  ['2008_005046.jpg', '2008_006844.jpg']
# probes_per_block : ['2010_001645.jpg', '2008_005526.jpg', '2008_007043.jpg', '2008_007913.jpg', '2008_003701.jpg']
# probes_per_block : ['2010_001645.jpg', '2008_005526.jpg', '2008_007043.jpg', '2008_007913.jpg', '2008_003701.jpg', '2008_000984.jpg', '2008_004042.jpg', '2011_000282.jpg']
# probes:  [['2008_000189.jpg', '2010_005217.jpg', '2008_004269.jpg', '2009_002803.jpg', '2011_001613.jpg', '2008_008263.jpg', '2010_002956.jpg', '2010_002379.jpg', '2011_000293.jpg'], ['2008_008500.jpg', '2008_008210.jpg', '2008_004487.jpg', '2008_000798.jpg', '2009_001321.jpg', '2009_003884.jpg', '2011_001605.jpg', '2008_002774.jpg', '2009_005118.jpg'], ['2008_002700.jpg', '2010_001036.jpg', '2010_000229.jpg', '2011_001886.jpg', '2008_008083.jpg', '2008_001185.jpg', '2008_007208.jpg', '2008_008533.jpg'], ['2010_001645.jpg', '2008_005526.jpg', '2008_007043.jpg', '2008_007913.jpg', '2008_003701.jpg', '2008_000984.jpg', '2008_004042.jpg', '2011_000282.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 29.201869461183065, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', ' bottle', nan, 33.478750472719696, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  194
# critical_probes_used ['2008_005046.jpg', '2008_006844.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 4 Critical Absent
# image 10 Target Present
# image 20 Target Present
# image 22 Target Present
# image 25 Target Present
# image 26 Target Absent
# image 33 Target Absent
# image 34 Target Present
# image 38 Critical
# image 43 Critical
# image 46 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [4, 10, 20, 22, 25, 26, 33, 34, 46]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2008_005046.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 192
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2008_005046.jpg'], ['2008_006844.jpg']]
# critical_probes_used:  ['2008_005046.jpg', '2008_006844.jpg']
# probes_per_block : ['2008_006470.jpg', '2008_003767.jpg', '2010_000613.jpg', '2010_001908.jpg']
# probes_per_block : ['2008_006470.jpg', '2008_003767.jpg', '2010_000613.jpg', '2010_001908.jpg', '2011_003145.jpg', '2010_003911.jpg', '2009_000059.jpg', '2008_008395.jpg', '2010_002393.jpg']
# probes:  [['2008_000189.jpg', '2010_005217.jpg', '2008_004269.jpg', '2009_002803.jpg', '2011_001613.jpg', '2008_008263.jpg', '2010_002956.jpg', '2010_002379.jpg', '2011_000293.jpg'], ['2008_008500.jpg', '2008_008210.jpg', '2008_004487.jpg', '2008_000798.jpg', '2009_001321.jpg', '2009_003884.jpg', '2011_001605.jpg', '2008_002774.jpg', '2009_005118.jpg'], ['2008_002700.jpg', '2010_001036.jpg', '2010_000229.jpg', '2011_001886.jpg', '2008_008083.jpg', '2008_001185.jpg', '2008_007208.jpg', '2008_008533.jpg'], ['2010_001645.jpg', '2008_005526.jpg', '2008_007043.jpg', '2008_007913.jpg', '2008_003701.jpg', '2008_000984.jpg', '2008_004042.jpg', '2011_000282.jpg'], ['2008_006470.jpg', '2008_003767.jpg', '2010_000613.jpg', '2010_001908.jpg', '2011_003145.jpg', '2010_003911.jpg', '2009_000059.jpg', '2008_008395.jpg', '2010_002393.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 18.837863956276628, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 19.54050687002545, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' car', ' dog', ' person', nan, nan, 21.020159211351668, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  242
# critical_probes_used ['2008_005046.jpg', '2008_006844.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [0, 1, 4, 9, 16, 17, 26, 27, 33, 43, 53, 56] 12
# gap_check:  [4, 17, 33]
# 12
# (0, 'Target Present')
# (1, 'Target Present')
# (4, 'Critical')
# (9, 'Target Absent')
# (16, 'Target Absent')
# (17, 'Critical')
# (26, 'Target Present')
# (27, 'Target Absent')
# (33, 'Critical')
# (43, 'Target Absent')
# (53, 'Target Absent')
# (56, 'Target Present')
# [(0, 'Target Present'), (1, 'Target Present'), (4, 'Critical'), (9, 'Target Absent'), (16, 'Target Absent'), (17, 'Critical'), (26, 'Target Present'), (27, 'Target Absent'), (33, 'Critical'), (43, 'Target Absent'), (53, 'Target Absent'), (56, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Present
# image 1 Target Present
# image 4 Critical
# image 9 Target Absent
# image 16 Target Absent
# image 17 Critical
# image 26 Target Present
# image 27 Target Absent
# image 33 Critical
# image 43 Target Absent
# image 53 Target Absent
# image 56 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 1, 9, 16, 26, 27, 43, 53, 56]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2008_005046.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 144
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2008_005046.jpg'], ['2008_006844.jpg']]
# critical_probes_used:  ['
one2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone1']
# tone1
# tone2
# tone1
# tone2
# tone2
# tone1
# tone2
# tone1
# tone2
# tone1
# tone1
# tone2
# tone2
# tone1
# tone1
# tone2
# tone1
# tone2
# tone1
# tone2
# tone2
# tone1
# tone2
# tone1
# len(trials):  1920

# %%
print len(normal_no_probe_before)
print len(normal_used)
print len(normal_no_probe_before) == len(set(normal_used))
print len(target_present_before)
print len(present_used)
print len(target_present_before) == len(set(present_used))
print len(target_absent_before)
print len(absent_used)
print len(target_absent_before) == len(set(absent_used))

#the following is not a good check
print len(set(critical_trials_before)) == len(set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes))

print set(critical_trials_before) == set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes)

print len(low_four)
print len(low_one) == len(low_two) == len(low_three) == len(low_four) == len(high_one) == len(high_two) == len(high_three) == len(high_four)
print len(set(low_one) & set(low_two) & set(low_three) & set(low_four) & set(high_one) & set(high_two) & set(high_three) & set(high_four))
# Out:
# 386
# 386
# True
# 36
# 36
# True
# 36
# 34
# False
# True
# True
# 60
# True
# 0

# %%
for i in range(len(trials.keys())):
    trials[i+1].append(i/60+1)

import pickle
with open('../config/randomization.pik', 'wb') as of:
    pickle.dump(trials,of)

# %%
df = pd.DataFrame.from_dict(trials)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','image_name','block']
df.TS = df.TS.astype('float')
df.to_csv(mypath + '../Config/randomization_1.csv')

# %%
df[df['trial_type']=='Critical']
# Out:
#              Cat.1         Cat.2         Cat.3         Cat.4       Cat.5  \
# 4      pottedplant           NaN           NaN           NaN         NaN
# 37             car        person           NaN           NaN         NaN
# 45            sofa           dog           NaN           NaN         NaN
# 62            bird           NaN           NaN           NaN         NaN
# 90            boat           NaN           NaN           NaN         NaN
# 94          person         chair        bottle   diningtable         NaN
# 124            cat           NaN           NaN           NaN         NaN
# 157    pottedplant           dog           NaN           NaN         NaN
# 165    pottedplant          sofa         chair   diningtable   tvmonitor
# 182            cat           NaN           NaN           NaN         NaN
# 210         bottle           dog   diningtable           NaN         NaN
# 214      aeroplane           NaN           NaN           NaN         NaN
# 256          horse           NaN           NaN           NaN         NaN
# 272    pottedplant        person         chair   diningtable        boat
# 300         person     aeroplane           NaN           NaN         NaN
# 312          chair           cat           NaN           NaN         NaN
# 347           bird           NaN           NaN           NaN         NaN
# 354         person           NaN           NaN           NaN         NaN
# 376         person          boat           NaN           NaN         NaN
# 392            dog           NaN           NaN           NaN         NaN
# 420         person         horse           NaN           NaN         NaN
# 432           boat           NaN           NaN           NaN         NaN
# 467          chair           dog   diningtable           NaN         NaN
# 474    pottedplant        person       bicycle           car         NaN
# 492    pottedplant         chair   diningtable           NaN         NaN
# 508           boat           NaN           NaN           NaN         NaN
# 528           bird           NaN           NaN           NaN         NaN
# 548           boat           NaN           NaN           NaN         NaN
# 571            car           NaN           NaN           NaN         NaN
# 583    pottedplant     tvmonitor           cat           NaN         NaN
# 612         person         train          sofa           NaN         NaN
# 628           bird           NaN           NaN           NaN         NaN
# 648         person          boat           NaN           NaN         NaN
# 668            cat           NaN           NaN           NaN         NaN
# 691         person           dog           NaN           NaN         NaN
# 703            car           NaN           NaN           NaN         NaN
# 723    pottedplant        person         chair   diningtable         NaN
# 754         person         horse           NaN           NaN         NaN
# 757    pottedplant          sofa         chair           NaN         NaN
# 782          chair           cat           NaN           NaN         NaN
# 803      aeroplane           NaN           NaN           NaN         NaN
# 813           sofa           dog           NaN           NaN         NaN
# 843          horse           NaN           NaN           NaN         NaN
# 874         person        bottle           NaN           NaN         NaN
# 877            dog           NaN           NaN           NaN         NaN
# 902            dog           NaN           NaN           NaN         NaN
# 923         person        bottle   pottedplant     tvmonitor       chair
# 933      tvmonitor         chair        bottle           NaN         NaN
# 961           boat           NaN           NaN           NaN         NaN
# 982          chair   diningtable        bottle           NaN         NaN
# 988      aeroplane           NaN           NaN           NaN         NaN
# 1032         chair           dog   diningtable           NaN         NaN
# 1037        person         horse           NaN           NaN         NaN
# 1074        person     aeroplane           NaN           NaN         NaN
# 1081          bird           NaN           NaN           NaN         NaN
# 1102           dog           NaN           NaN           NaN         NaN
# 1108        person          boat           NaN           NaN         NaN
# 1152   pottedplant           NaN           NaN           NaN         NaN
# 1157          sofa         chair           NaN           NaN         NaN
# 1194           car           NaN           NaN           NaN         NaN
# 1221   pottedplant        person     motorbike           NaN         NaN
# 1224           car       bicycle     motorbike           NaN         NaN
# 1247        person         chair           cat           NaN         NaN
# 1268        person          sofa           NaN           NaN         NaN
# 1282        bottle           cat           NaN           NaN         NaN
# 1319           dog        bottle           NaN           NaN         NaN
# 1341        person          sofa           NaN           NaN         NaN
# 1344          bird           NaN           NaN           NaN         NaN
# 1367         horse           NaN           NaN           NaN         NaN
# 1388        person          boat           car           NaN         NaN
# 1402   pottedplant       bicycle        bottle           cat         NaN
# 1439           car     motorbike        person           NaN         NaN
# 1455        person           cat           NaN           NaN         NaN
# 1475     aeroplane           NaN           NaN           NaN         NaN
# 1484          sofa           NaN           NaN           NaN         NaN
# 1505        person           dog           car           NaN         NaN
# 1539        person         chair   diningtable        bottle         NaN
# 1544     aeroplane           NaN           NaN           NaN         NaN
# 1575          bird           NaN           NaN           NaN         NaN
# 1595        person         horse           NaN           NaN         NaN
# 1604           cat           NaN           NaN           NaN         NaN
# 1625        person           dog           NaN           NaN         NaN
# 1659         chair   diningtable        bottle           NaN         NaN
# 1664           dog           NaN           NaN           NaN         NaN
# 1685   pottedplant          sofa         chair           NaN         NaN
# 1698           car         train           NaN           NaN         NaN
# 1714          boat           NaN           NaN           NaN         NaN
# 1759        person          boat           NaN           NaN         NaN
# 1765         chair           dog           NaN           NaN         NaN
# 1788        person         horse           NaN           NaN         NaN
# 1805   pottedplant           NaN           NaN           NaN         NaN
# 1818           car           dog        person           NaN         NaN
# 1834          bird           NaN           NaN           NaN         NaN
# 1879   pottedplant          sofa         chair     tvmonitor         NaN
# 1885        person         chair   diningtable        bottle         NaN
# 1908          sofa         chair        person           NaN         NaN
#
#              TS  Load      exemplar    question present_absent trial_type  \
# 4     19.540507   low   pottedplant          NA      No Target   Critical
# 37    17.856306   low           car          NA      No Target   Critical
# 45    21.001227   low          sofa          NA      No Target   Critical
# 62    29.594598  high          bird          NA      No Target   Critical
# 90    30.065266  high          boat      person  Target Absent   Critical
# 94    35.134857  high        bottle          NA      No Target   Critical
# 124   31.779859  high           cat          NA      No Target   Critical
# 157   29.851834  high           dog          NA      No Target   Critical
# 165   29.247483  high   pottedplant          NA      No Target   Critical
# 182   19.096252   low           cat          NA      No Target   Critical
# 210   21.034647   low        bottle       chair  Target Absent   Critical
# 214   12.536573   low     aeroplane          NA      No Target   Critical
# 256   29.281238  high         horse          NA      No Target   Critical
# 272   35.383634  high   pottedplant          NA      No Target   Critical
# 300   32.014974  high     aeroplane          NA      No Target   Critical
# 312   17.570654   low         chair          NA      No Target   Critical
# 347   14.343347   low          bird          NA      No Target   Critical
# 354   18.716529   low        person          NA      No Target   Critical
# 376   17.698167   low          boat          NA      No Target   Critical
# 392   19.803149   low           dog          NA      No Target   Critical
# 420   20.529451   low        person          NA      No Target   Critical
# 432   29.608003  high          boat          NA      No Target   Critical
# 467   29.611440  high           dog          NA      No Target   Critical
# 474   33.367153  high   pottedplant          NA      No Target   Critical
# 492   17.138576   low   pottedplant          NA      No Target   Critical
# 508   21.198620   low          boat          NA      No Target   Critical
# 528   20.821732   low          bird          NA      No Target   Critical
# 548   34.967528  high          boat          NA      No Target   Critical
# 571   30.394048  high           car          NA      No Target   Critical
# 583   31.670447  high           cat          NA      No Target   Critical
# 612   31.651156  high          sofa          NA      No Target   Critical
# 628   31.892126  high          bird          NA      No Target   Critical
# 648   30.384187  high          boat          NA      No Target   Critical
# 668   18.135097   low           cat          NA      No Target   Critical
# 691   20.712899   low           dog          NA      No Target   Critical
# 703   20.487167   low           car          NA      No Target   Critical
# 723   31.520688  high   pottedplant          NA      No Target   Critical
# 754   31.969634  high         horse          NA      No Target   Critical
# 757   31.427288  high          sofa   aeroplane  Target Absent   Critical
# 782   17.570654   low         chair          NA      No Target   Critical
# 803   13.513292   low     aeroplane          NA      No Target   Critical
# 813   16.142563   low           dog          NA      No Target   Critical
# 843   19.234401   low         horse          NA      No Target   Critical
# 874   19.869099   low        bottle          NA      No Target   Critical
# 877   20.194434   low           dog       horse  Target Absent   Critical
# 902   31.728170  high           dog          NA      No Target   Critical
# 923   31.676386  high        bottle          NA      No Target   Critical
# 933   32.179769  high        bottle          NA      No Target   Critical
# 961   19.253520   low          boat          NA      No Target   Critical
# 982   20.038120   low        bottle          NA      No Target   Critical
# 988   14.106445   low     aeroplane          NA      No Target   Critical
# 1032  29.611440  high           dog          NA      No Target   Critical
# 1037  30.141763  high         horse          NA      No Target   Critical
# 1074  30.953043  high     aeroplane          NA      No Target   Critical
# 1081  31.892126  high          bird          NA      No Target   Critical
# 1102  31.537857  high           dog          NA      No Target   Critical
# 1108  34.287989  high          boat          NA      No Target   Critical
# 1152  18.031537   low   pottedplant          NA      No Target   Critical
# 1157  19.836492   low          sofa          NA      No Target   Critical
# 1194  21.181011   low           car          NA      No Target   Critical
# 1221  34.416005  high   pottedplant          NA      No Target   Critical
# 1224  29.678014  high           car        sofa  Target Absent   Critical
# 1247  30.878848  high           cat          NA      No Target   Critical
# 1268  20.185339   low          sofa          NA      No Target   Critical
# 1282  21.259830   low        bottle          NA      No Target   Critical
# 1319  18.860703   low        bottle          NA      No Target   Critical
# 1341  20.707878   low          sofa          NA      No Target   Critical
# 1344  19.735592   low          bird      bottle  Target Absent   Critical
# 1367  18.414256   low         horse          NA      No Target   Critical
# 1388  35.704709  high          boat          NA      No Target   Critical
# 1402  35.353784  high           cat          NA      No Target   Critical
# 1439  31.408722  high           car          NA      No Target   Critical
# 1455  20.139878   low        person          NA      No Target   Critical
# 1475  20.158044   low     aeroplane          NA      No Target   Critical
# 1484  17.055909   low          sofa          NA      No Target   Critical
# 1505  33.094885  high           dog        bird  Target Absent   Critical
# 1539  33.478750  high        bottle          NA      No Target   Critical
# 1544  29.201869  high     aeroplane          NA      No Target   Critical
# 1575  29.272655  high          bird          NA      No Target   Critical
# 1595  29.265462  high         horse          NA      No Target   Critical
# 1604  29.246976  high           cat          NA      No Target   Critical
# 1625  20.712899   low           dog       chair  Target Absent   Critical
# 1659  20.038120   low        bottle          NA      No Target   Critical
# 1664  16.693373   low           dog          NA      No Target   Critical
# 1685  31.427288  high          sofa          NA      No Target   Critical
# 1698  30.208843  high           car          NA      No Target   Critical
# 1714  33.494613  high          boat          NA      No Target   Critical
# 1759  17.698167   low          boat          NA      No Target   Critical
# 1765  13.836710   low         chair          NA      No Target   Critical
# 1788  20.529451   low        person          NA      No Target   Critical
# 1805  19.540507   low   pottedplant          NA      No Target   Critical
# 1818  21.020159   low           car          NA      No Target   Critical
# 1834  18.837864   low          bird          NA      No Target   Critical
# 1879  29.464580  high   pottedplant          NA      No Target   Critical
# 1885  30.060592  high        bottle          NA      No Target   Critical
# 1908  36.443792  high          sofa          NA      No Target   Critical
#
#      tone_Hz tone_onset       image_name block
# 4      tone2        468  2009_002817.jpg     1
# 37     tone2        276  2009_002711.jpg     1
# 45     tone2        348  2008_001238.jpg     1
# 62     tone2        574  2008_000798.jpg     2
# 90     tone2        741  2009_002306.jpg     2
# 94     tone2        102  2011_000282.jpg     2
# 124    tone2        764  2011_000824.jpg     3
# 157    tone1        248  2008_007108.jpg     3
# 165    tone2         86  2008_004661.jpg     3
# 182    tone1        895  2009_004779.jpg     4
# 210    tone1        679  2011_002911.jpg     4
# 214    tone1        232  2010_006023.jpg     4
# 256    tone2        150  2008_005702.jpg     5
# 272    tone2        443  2011_001221.jpg     5
# 300    tone1        441  2008_004646.jpg     5
# 312    tone2        525  2008_000115.jpg     6
# 347    tone1        110  2010_001159.jpg     6
# 354    tone2        928  2008_006998.jpg     6
# 376    tone1        667  2011_001591.jpg     7
# 392    tone1        651  2008_007208.jpg     7
# 420    tone1         88  2009_003530.jpg     7
# 432    tone1        661  2009_002897.jpg     8
# 467    tone1        206  2008_007378.jpg     8
# 474    tone1        315  2011_001025.jpg     8
# 492    tone1        981  2008_002379.jpg     9
# 508    tone2        736  2010_004662.jpg     9
# 528    tone2        927  2010_005217.jpg     9
# 548    tone1        630  2010_002620.jpg    10
