# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pickle
from copy import deepcopy
#%pdb
mypath = ('')

# %%
#GLOBALS
trials = {}
############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
categories = [' bottle', ' horse', ' pottedplant', ' dog',
                  ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']
target_present = []
target_absent = []
critical_trials = []

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()

# %%
def present_absent_trials():
    global target_present, lista, categories, p_load
    # DEFINING TARGET-PRESENT PROBES
    
    #target_present = []
    intermediate = []
    
    odd = categories[::2]
    even = categories[1::2]
#next two lines are to check that the images picked as target present and target absent trials
                    #are different from the ones chosen in previous iterations
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in odd:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break
    #print len(target_present)
    for n in target_present:
        possible_images_dict[n].append('Target Present')

    #target_present = [n for n in lista if 'Target Present' in possible_images_dict[n]]


    # DEFINING TARGET-ABSENT PROBES
    #target_absent = []
    intermediate = []
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in even:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)

                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for each in target_absent:
        possible_images_dict[each].append('Target Absent')
        

    # DEFINING NO-TARGET IMAGES
    for image in lista:
        if image not in target_present and image not in target_absent:
            possible_images_dict[image].append('NA')
            possible_images_dict[image].append('No Target')
    
    return target_present, target_absent

# %%
# DEFINING CRITICAL TRIALS
#Criteria:
# - images of set load level
# - images containing a certain category
# - image is not already in the list of critical trials for this level of load
#- image is not aready in the list of critical trials (regardless of level of load)

def pre_select_critical_trial(load_level):
    global categories, critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and 'Critical' not in possible_images_dict[intermediate]: # this is just a sanity check
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)      
        temp =[]

# %%
def appending_critical_trials():
    global critical_low_present_probes, critical_low_absent_probes, critical_high_present_probes, critical_high_absent_probes
    global critical_trials
    cycles = 1
    while True:

        #picking critical trials
        pre_select_critical_trial('low')
        pre_select_critical_trial('high')      

        # counting critical probes
        crit_p = 0
        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1


        critical_low_counter = 0
        critical_high_counter = 0
        crit_p = 0

        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1
            if 'No Target' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_counter = critical_low_counter + 1
            if 'No Target' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_counter = critical_high_counter +1
            if 'Target Present' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_absent_probes.append(n)
            if 'Target Present' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_absent_probes.append(n)
        #print crit_p
        #print critical_low_counter
        #print critical_high_counter
        #print critical_low_present_probes
        #print critical_low_absent_probes
        #print critical_high_present_probes
        #print critical_high_absent_probes

        #######################################################
        if crit_p == 0 or len(critical_low_present_probes) == len(critical_high_present_probes) and len(critical_low_absent_probes) == \
        len(critical_high_absent_probes): #check if there is an even number of critical probes
            break
            print 'cycles : ',cycles
        else:
            cycles = cycles + 1
            critical_low_present_probes = []
            critical_low_absent_probes = []
            critical_high_present_probes = []
            critical_high_absent_probes = []
            #print len(critical_low_present_probes)
            #print len(critical_high_present_probes)
            #print len(critical_low_absent_probes)
            #print len(critical_high_absent_probes)
            #print '#######################'

            #why did I reset target_present and target_absent???

            #target_present = []
            #target_absent = []
            critical_trials = []

    # appendinf words 'critical' and 'normal' to dict
    for each in critical_trials:
        possible_images_dict[each].append('Critical')
    for each in possible_images_dict:
        if 'Critical' not in possible_images_dict[each]:
            possible_images_dict[each].append('Normal')

    #######################################################
    #print 'Probe trials: ', len(probe_trials_1)
    print 'Target Present Probes: ', len(target_present)
    print 'Target Absent probes: ', len(target_absent)
    print 'Critical trials:', len(critical_trials)
    print 'Critical, low: ' , critical_low_counter
    print 'Critical, high: ' , critical_high_counter
    print 'Are all critical trials unique? ', len(critical_trials) == len(set(critical_trials))
    #######################################################
    print 'Number of critical probes: ' , crit_p
    print 'critical_low_present_probes: ' , len(critical_low_present_probes)
    print 'critical_high_present_probes: ' , len(critical_high_present_probes)
    print 'critical_low_absent_probes: ' , len(critical_low_absent_probes)
    print 'critical_high_absent_probes: ', len(critical_high_absent_probes)
    print 'cycles : ',cycles
    
    return

# %%
def critical_probes_distribution(starting):
    global critical_low_present_probes, critical_low_absent_probes
    while True:
        p_left = len(starting)
        p_max = p_left
        distribution = []
        for i in range(4):
            if p_left > 0:
                x = random.randint(0,p_left)
                distribution.append(x)
                p_left = p_left - x
            else:
                distribution.append(0)
        if sum(distribution) == p_max:
            break
    random.shuffle(distribution)
    return distribution

# %%
def block_pair(present_n,absent_n):
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block
    global present_crit_distribution, absent_crit_distribution
    global present_critical_per_block, absent_critical_per_block, critical_probes_used, critical_probes_set
    global present_per_block, absent_per_block
    
    present_crit = present_crit_distribution.pop(0)
    absent_crit = absent_crit_distribution.pop(0)
    block = []
    
    for load in p_load:
        #PRINTING STUFF
        print 'present_crit_distribution_original: ',present_crit_distribution_original
        print 'absent_crit_distribution_original: ', absent_crit_distribution_original
        print 'present_crit', present_crit
        print 'absent_crit', absent_crit
        print 'present_crit_distribution: ', present_crit_distribution
        print 'absent_crit_distribution: ', absent_crit_distribution
        print 'critical present set: ', critical_present_set
        print 'critical absent set: ', critical_absent_set
        print'---------------------------------------------------'
        normal_availble = [n for n in normal if n not in normal_used]
        print 'normal available:', len(normal_availble)
    # PICKING CRITICAL PROBES    
    #------------------------------------------------------------------------------
        if present_crit != 0:
            present_critical_per_block = []
            while len(present_critical_per_block) < present_crit:
                crit_probe = str(np.random.choice(critical_present_set,1,replace = False))[2:-2]
                if crit_probe not in present_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Present' in possible_images_dict[crit_probe]:

                    present_critical_per_block.append(crit_probe)
            critical_present.append(present_critical_per_block)
                    
        print 'present_critical_per_block:', present_critical_per_block
        
        if absent_crit != 0:
            absent_critical_per_block = []
            while len(absent_critical_per_block) < absent_crit:
                crit_probe = str(np.random.choice(critical_absent_set,1,replace = False))[2:-2]
                if crit_probe not in absent_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Absent' in possible_images_dict[crit_probe]:

                    absent_critical_per_block.append(crit_probe)
            critical_absent.append(absent_critical_per_block)
            
        print 'absent_critical_per_block:', absent_critical_per_block  
        print 'critical_present: ',critical_present
        print 'critical_absent: ',critical_absent
        
        for n in present_critical_per_block + absent_critical_per_block:
            critical_probes_used.append(n)
            
        print 'critical_probes_used: ', critical_probes_used
    #------------------------------------------------------------------------------
    # PICKING PRESENT AND ABSENT PROBES
        total = present_n + absent_n
        while len(probes_per_block) < (present_n - present_crit):
            probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in present_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        while (present_n - present_crit) <= len(probes_per_block) < total - present_crit - absent_crit:
            probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in absent_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        for n in probes_per_block:
            if 'Target Present' in possible_images_dict[n]:
                present_used.append(n)
            elif 'Target Absent' in possible_images_dict[n]:
                absent_used.append(n)

        probes.append(probes_per_block)
        
        print 'probes: ', probes
        present_per_block = [n for n in probes_per_block if 'Target Present' in possible_images_dict[n]]
        absent_per_block = [n for n in probes_per_block if 'Target Absent' in possible_images_dict[n]]
        print 'Present Used in block: ',len(present_per_block)
        print 'Absent Used in block',len(absent_per_block)
    #------------------------------------------------------------------------------    
    #Counting critical probes    
        critical_probes_counter = len(present_critical_per_block + absent_critical_per_block)
        print 'Critical probes counter: ',critical_probes_counter
        print 'Present Critical: ', len(present_critical_per_block)
        print 'Absent Critical: ', len(absent_critical_per_block)

        modifier.append(critical_probes_counter)
    #------------------------------------------------------------------------------
    #Picking critical trials
        while len(critical_per_block) < (3-critical_probes_counter):
            image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
            if image not in critical_per_block and image not in critical_used \
                and 'No Target' in possible_images_dict[image] and load in possible_images_dict[image]:
                critical_per_block.append(image) 
        print 'List of critical trials without probe: '
        for n in critical_per_block:
            critical_used.append(n)
            print possible_images_dict[n]
        #temp = []

        critical.append(critical_per_block)

    #------------------------------------------------------------------------------
    #Picking normal trials
        while len(normal_per_block) < 51 - (3 - critical_probes_counter):
            image = str(np.random.choice(normal,1,replace = False))[2:-2]
            if image not in normal_per_block and image not in normal_used and load in possible_images_dict[image]:
                normal_per_block.append(image)
        for n in normal_per_block:
            normal_used.append(n)
        print 'normal in this block: ', len(normal_per_block)
        print 'normal used overall: ',len(normal_used)

        normal_builder.append(normal_per_block)
    #----------------------------------------------------------------------------
        
        print 'critical_probes_used', critical_probes_used 
        
        
        
        if 'sequence_final' in locals():
            print 'sequence_final exists'
        else:
            print 'sequence final does not exist'
            sequence_final = position_finder()
            print sequence_final
        print'---------------------------------------------------'
        print 'END OF BLOCK PROCESSING'
        print'---------------------------------------------------'
        print 'BUILDING THE BLOCK'
        first_element = [x[0] for x in sequence_final]
        second_element = [x[1] for x in sequence_final]
        second_element_counter = 0
        probes_position = []
        for image in range(60):
            #print [x[1] for x in sequence_final if x[0] ==image][0]
            if image in first_element:
                
                print 'image', image, second_element[second_element_counter]
        
                if second_element[second_element_counter] == 'Target Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break       
                elif second_element[second_element_counter] == 'Target Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical':
                    while True:
                        element = str(np.random.choice(critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break     
                elif second_element[second_element_counter] == 'Critical Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break  
            else:
                while True:
                    element = str(np.random.choice(normal_per_block,1,replace = False))[2:-2]
                    if element not in block:
                        block.append(element)
                        break
                
        print 'block:', len(block)   
        print'---------------------------------------------------'
        print 'probes_position: ', probes_position
    #-----------------------------------------------------------------------------
        normal_per_block = []
        probes_per_block = []
        critical_per_block = []
        present_critical_per_block = []
        absent_critical_per_block = []
    #-----------------------------------------------------------------------------
    return block

# %%
def position_finder():
    global present_critical_per_block, absent_critical_per_block, present_per_block, absent_per_block, critical_per_block
    x = len(present_critical_per_block + absent_critical_per_block)
    print 'x', x
    print 'present_critical_per_block', len(present_critical_per_block)
    print 'absent_critical_per_block', len(absent_critical_per_block)
    while True:    
        while True:
            a = [random.randint(1,10) for r in xrange(12-x)]
            if sum(a) <= 60:
                break

        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]

        if len(present_critical_per_block) == 0 and len(absent_critical_per_block) == 0:
            print 'ciao', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block) + ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        if len(present_critical_per_block) != 0 or len(absent_critical_per_block) != 0:
            print 'ciao2', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block)  +\
            ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block) +\
            ['Critical Present'] * len(present_critical_per_block) +\
            ['Critical Absent'] * len(absent_critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        sequence_final = zip(new_list_1, sequence)
        #print sequence_final
        #print len(sequence_final)
        gap_check = [n[0] for n in sequence_final if 'Critical' in n[1]] 
        #print gap_check
        container = []
        for i in gap_check:
            elements = [i+1, i+2]
            for element in elements:
                if element in new_list_1:
                    container.append(element)
        #print 'container', len(container),container
        if len(container) == 0:
            break
        else:
            sequence_final = []

    print '------------------'
    print new_list_1, len(new_list_1)
    print 'gap_check: ', gap_check
    print len(sequence_final)

    for i in sequence_final:
        print i
    return sequence_final

# %%
def block_unpacker(splitting_index,present,absent):
    block = block_pair(present,absent) #, probes_position
    low_block = []
    high_block = []
    for i in range(len(block)):
        if i < (len(block)/2):
            low_block.append(block[i])
        else:
            high_block.append(block[i])
    #print probes_position
    print len(low_block), len(high_block)
    return low_block, high_block #, probes_position

# %%
def tone_properties():
    while True:
        possible_tones = ['tone1','tone2']
        low_one_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_two_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_three_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_four_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        high_one_tones = []
        high_two_tones = []
        high_three_tones = []
        high_four_tones = []
        for each in low_one_tones:
            if each == 'tone1':
                high_one_tones.append('tone2')
            elif each == 'tone2':
                high_one_tones.append('tone1')
        for each in low_two_tones:
            if each == 'tone1':
                high_two_tones.append('tone2')
            elif each == 'tone2':
                high_two_tones.append('tone1')
        for each in low_three_tones:
            if each == 'tone1':
                high_three_tones.append('tone2')
            elif each == 'tone2':
                high_three_tones.append('tone1')
        for each in low_four_tones:
            if each == 'tone1':
                high_four_tones.append('tone2')
            elif each == 'tone2':
                high_four_tones.append('tone1')
        sound_Hz = low_one_tones + low_two_tones + low_three_tones + low_four_tones + high_one_tones + high_two_tones +\
        high_three_tones + high_four_tones

        tone1_counter = 0
        tone2_counter = 0
        for each in sound_Hz:
            if each == 'tone1':
                tone1_counter = tone1_counter + 1
            elif each == 'tone2':
                tone2_counter = tone2_counter + 1

        low_load_tones = [n for n in sound_Hz[0:12]]
        high_load_tones = [n for n in sound_Hz[12:25]]
        low_load_tone1s = [n for n in low_load_tones if n == 'tone1']
        low_load_tone2s = [n for n in low_load_tones if n == 'tone2']
        high_load_tone1s = [n for n in high_load_tones if n == 'tone1']
        high_load_tone2s = [n for n in high_load_tones if n =='tone2']

        if len(low_load_tone1s) == len(low_load_tone2s) and len(high_load_tone1s) == len(high_load_tone2s):
            print low_one_tones
            print high_one_tones
            print '----------------------'
            print low_two_tones
            print high_two_tones
            print '----------------------'
            print low_three_tones
            print high_three_tones
            print '----------------------'
            print low_four_tones
            print high_four_tones
            print '----------------------'
            print 'total n of tones: ', len(sound_Hz)
            print '----------------------'
            print 'total n of 1500 Hz tones: ', tone1_counter
            print 'total n of 2000 Hz tones: ', tone2_counter
            print '----------------------'
            print len(low_load_tone1s) == len(low_load_tone2s)
            print len(low_load_tone1s)
            print len(low_load_tone2s)
            print len(high_load_tone1s) == len(high_load_tone2s)
            print len(high_load_tone1s)
            print len(high_load_tone2s)
            break
    sound_onset = []
    for i in range(48):
        a = random.uniform(0, 0.999)
        a = int(str(a)[2:5])
        #print a
        sound_onset.append(a)

    #------------------------------------------------------------------------------
    # APPEND TO DICT
    sound_index = 0
    for each in possible_images_dict:
        if 'Critical' in possible_images_dict[each]:
            possible_images_dict[each].append(sound_Hz[sound_index])
            possible_images_dict[each].append(sound_onset[sound_index])
            sound_index = sound_index + 1
        elif 'Normal' in possible_images_dict[each]:
            possible_images_dict[each].append('No tone')
            possible_images_dict[each].append(-999)

# %%
target_present, target_absent= present_absent_trials()
appending_critical_trials()
#-----------------------------------------------------

normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
        
print 'present_crit_distribution', present_crit_distribution
print 'absent_crit_distribution', absent_crit_distribution
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) #, probes_1_3
low_two, high_one = block_unpacker(60,5,4) #, probes_2_4
low_four, high_three = block_unpacker(60,4,5) #, probes_5_7
low_three, high_four = block_unpacker(60,5,4) #, probes_6_8

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four

trial_n = 1
for b in range(8):
    this_block_images = blocks[b]
    for im in this_block_images:
        trials[trial_n] = possible_images_dict[im]
        trials[trial_n].append(im)
        trial_n += 1

len(trials)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  10
# Critical, high:  10
# Are all critical trials unique?  True
# Number of critical probes:  4
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  2
# critical_high_absent_probes:  2
# cycles :  15
# present_crit_distribution [0, 0, 0, 0]
# absent_crit_distribution [0, 0, 0, 2]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 2]
# critical present set:  []
# critical absent set:  ['2009_005075.jpg', '2008_000734.jpg', '2010_004683.jpg', '2010_002620.jpg']
# ---------------------------------------------------
# normal available: 388
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg']
# probes_per_block : ['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg']
# probes:  [['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' chair', ' diningtable', nan, nan, 20.561279009327844, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 17.770158360863313, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 16.598874860824477, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [1, 4, 7, 13, 22, 30, 35, 40, 41, 45, 50, 57] 12
# gap_check:  [4, 22, 41]
# 12
# (1, 'Target Absent')
# (4, 'Critical')
# (7, 'Target Present')
# (13, 'Target Absent')
# (22, 'Critical')
# (30, 'Target Absent')
# (35, 'Target Present')
# (40, 'Target Present')
# (41, 'Critical')
# (45, 'Target Present')
# (50, 'Target Absent')
# (57, 'Target Absent')
# [(1, 'Target Absent'), (4, 'Critical'), (7, 'Target Present'), (13, 'Target Absent'), (22, 'Critical'), (30, 'Target Absent'), (35, 'Target Present'), (40, 'Target Present'), (41, 'Critical'), (45, 'Target Present'), (50, 'Target Absent'), (57, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 4 Critical
# image 7 Target Present
# image 13 Target Absent
# image 22 Critical
# image 30 Target Absent
# image 35 Target Present
# image 40 Target Present
# image 41 Critical
# image 45 Target Present
# image 50 Target Absent
# image 57 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 7, 13, 30, 35, 40, 45, 50, 57]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 2]
# critical present set:  []
# critical absent set:  ['2009_005075.jpg', '2008_000734.jpg', '2010_004683.jpg', '2010_002620.jpg']
# ---------------------------------------------------
# normal available: 340
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg']
# probes_per_block : ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg', '2008_004188.jpg', '2010_001939.jpg', '2009_000120.jpg', '2008_000798.jpg', '2008_002195.jpg']
# probes:  [['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg'], ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg', '2008_004188.jpg', '2010_001939.jpg', '2009_000120.jpg', '2008_000798.jpg', '2008_002195.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' chair', ' diningtable', ' bottle', nan, 30.06059186196041, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 29.875362071673013, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' cat', nan, nan, nan, 29.867994035114002, 'high', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 4 Critical
# image 7 Target Present
# image 13 Target Absent
# image 22 Critical
# image 30 Target Absent
# image 35 Target Present
# image 40 Target Present
# image 41 Critical
# image 45 Target Present
# image 50 Target Absent
# image 57 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 7, 13, 30, 35, 40, 45, 50, 57]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 2]
# critical present set:  []
# critical absent set:  ['2009_005075.jpg', '2008_000734.jpg', '2010_004683.jpg', '2010_002620.jpg']
# ---------------------------------------------------
# normal available: 292
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_002998.jpg', '2008_004814.jpg', '2008_008331.jpg', '2010_000299.jpg', '2008_002504.jpg']
# probes_per_block : ['2009_002998.jpg', '2008_004814.jpg', '2008_008331.jpg', '2010_000299.jpg', '2008_002504.jpg', '2008_003876.jpg', '2010_001451.jpg', '2009_002521.jpg', '2009_004076.jpg']
# probes:  [['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg'], ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg', '2008_004188.jpg', '2010_001939.jpg', '2009_000120.jpg', '2008_000798.jpg', '2008_002195.jpg'], ['2009_002998.jpg', '2008_004814.jpg', '2008_008331.jpg', '2010_000299.jpg', '2008_002504.jpg', '2008_003876.jpg', '2010_001451.jpg', '2009_002521.jpg', '2009_004076.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 18.41425575439328, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', nan, nan, 18.511887801846186, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 16.417039192791336, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [6, 13, 14, 18, 22, 24, 28, 33, 36, 43, 48, 52] 12
# gap_check:  [6, 18, 48]
# 12
# (6, 'Critical')
# (13, 'Target Present')
# (14, 'Target Present')
# (18, 'Critical')
# (22, 'Target Absent')
# (24, 'Target Absent')
# (28, 'Target Present')
# (33, 'Target Absent')
# (36, 'Target Present')
# (43, 'Target Present')
# (48, 'Critical')
# (52, 'Target Absent')
# [(6, 'Critical'), (13, 'Target Present'), (14, 'Target Present'), (18, 'Critical'), (22, 'Target Absent'), (24, 'Target Absent'), (28, 'Target Present'), (33, 'Target Absent'), (36, 'Target Present'), (43, 'Target Present'), (48, 'Critical'), (52, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Critical
# image 13 Target Present
# image 14 Target Present
# image 18 Critical
# image 22 Target Absent
# image 24 Target Absent
# image 28 Target Present
# image 33 Target Absent
# image 36 Target Present
# image 43 Target Present
# image 48 Critical
# image 52 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [13, 14, 22, 24, 28, 33, 36, 43, 52]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 2]
# critical present set:  []
# critical absent set:  ['2009_005075.jpg', '2008_000734.jpg', '2010_004683.jpg', '2010_002620.jpg']
# ---------------------------------------------------
# normal available: 244
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_006216.jpg', '2009_004283.jpg', '2009_000466.jpg', '2010_005628.jpg', '2010_002603.jpg']
# probes_per_block : ['2008_006216.jpg', '2009_004283.jpg', '2009_000466.jpg', '2010_005628.jpg', '2010_002603.jpg', '2009_002571.jpg', '2008_004482.jpg', '2008_001965.jpg', '2010_000792.jpg']
# probes:  [['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg'], ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg', '2008_004188.jpg', '2010_001939.jpg', '2009_000120.jpg', '2008_000798.jpg', '2008_002195.jpg'], ['2009_002998.jpg', '2008_004814.jpg', '2008_008331.jpg', '2010_000299.jpg', '2008_002504.jpg', '2008_003876.jpg', '2010_001451.jpg', '2009_002521.jpg', '2009_004076.jpg'], ['2008_006216.jpg', '2009_004283.jpg', '2009_000466.jpg', '2010_005628.jpg', '2010_002603.jpg', '2009_002571.jpg', '2008_004482.jpg', '2008_001965.jpg', '2010_000792.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' dog', nan, nan, nan, nan, 31.72817006314488, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' chair', nan, nan, nan, 34.70717080948356, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' car', ' dog', ' person', nan, nan, 29.763552134631723, 'high', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Critical
# image 13 Target Present
# image 14 Target Present
# image 18 Critical
# image 22 Target Absent
# image 24 Target Absent
# image 28 Target Present
# image 33 Target Absent
# image 36 Target Present
# image 43 Target Present
# image 48 Critical
# image 52 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [13, 14, 22, 24, 28, 33, 36, 43, 52]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [2]
# critical present set:  []
# critical absent set:  ['2009_005075.jpg', '2008_000734.jpg', '2010_004683.jpg', '2010_002620.jpg']
# ---------------------------------------------------
# normal available: 196
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_001305.jpg', '2008_002904.jpg', '2008_001367.jpg', '2009_004262.jpg']
# probes_per_block : ['2009_001305.jpg', '2008_002904.jpg', '2008_001367.jpg', '2009_004262.jpg', '2010_000613.jpg', '2008_001617.jpg', '2008_002379.jpg', '2008_000760.jpg', '2008_001040.jpg']
# probes:  [['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg'], ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg', '2008_004188.jpg', '2010_001939.jpg', '2009_000120.jpg', '2008_000798.jpg', '2008_002195.jpg'], ['2009_002998.jpg', '2008_004814.jpg', '2008_008331.jpg', '2010_000299.jpg', '2008_002504.jpg', '2008_003876.jpg', '2010_001451.jpg', '2009_002521.jpg', '2009_004076.jpg'], ['2008_006216.jpg', '2009_004283.jpg', '2009_000466.jpg', '2010_005628.jpg', '2010_002603.jpg', '2009_002571.jpg', '2008_004482.jpg', '2008_001965.jpg', '2010_000792.jpg'], ['2009_001305.jpg', '2008_002904.jpg', '2008_001367.jpg', '2009_004262.jpg', '2010_000613.jpg', '2008_001617.jpg', '2008_002379.jpg', '2008_000760.jpg', '2008_001040.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 19.75925599841011, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 20.166020393270408, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 19.30503047810884, 'low', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  240
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [6, 8, 14, 20, 23, 24, 25, 27, 37, 40, 46, 53] 12
# gap_check:  [14, 40, 53]
# 12
# (6, 'Target Absent')
# (8, 'Target Absent')
# (14, 'Critical')
# (20, 'Target Present')
# (23, 'Target Absent')
# (24, 'Target Present')
# (25, 'Target Absent')
# (27, 'Target Present')
# (37, 'Target Present')
# (40, 'Critical')
# (46, 'Target Absent')
# (53, 'Critical')
# [(6, 'Target Absent'), (8, 'Target Absent'), (14, 'Critical'), (20, 'Target Present'), (23, 'Target Absent'), (24, 'Target Present'), (25, 'Target Absent'), (27, 'Target Present'), (37, 'Target Present'), (40, 'Critical'), (46, 'Target Absent'), (53, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Absent
# image 8 Target Absent
# image 14 Critical
# image 20 Target Present
# image 23 Target Absent
# image 24 Target Present
# image 25 Target Absent
# image 27 Target Present
# image 37 Target Present
# image 40 Critical
# image 46 Target Absent
# image 53 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [6, 8, 20, 23, 24, 25, 27, 37, 46]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [2]
# critical present set:  []
# critical absent set:  ['2009_005075.jpg', '2008_000734.jpg', '2010_004683.jpg', '2010_002620.jpg']
# ---------------------------------------------------
# normal available: 148
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2011_002810.jpg', '2009_002414.jpg', '2009_000629.jpg', '2011_001800.jpg']
# probes_per_block : ['2011_002810.jpg', '2009_002414.jpg', '2009_000629.jpg', '2011_001800.jpg', '2011_001025.jpg', '2008_002084.jpg', '2011_002971.jpg', '2008_007143.jpg', '2008_000541.jpg']
# probes:  [['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg'], ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg', '2008_004188.jpg', '2010_001939.jpg', '2009_000120.jpg', '2008_000798.jpg', '2008_002195.jpg'], ['2009_002998.jpg', '2008_004814.jpg', '2008_008331.jpg', '2010_000299.jpg', '2008_002504.jpg', '2008_003876.jpg', '2010_001451.jpg', '2009_002521.jpg', '2009_004076.jpg'], ['2008_006216.jpg', '2009_004283.jpg', '2009_000466.jpg', '2010_005628.jpg', '2010_002603.jpg', '2009_002571.jpg', '2008_004482.jpg', '2008_001965.jpg', '2010_000792.jpg'], ['2009_001305.jpg', '2008_002904.jpg', '2008_001367.jpg', '2009_004262.jpg', '2010_000613.jpg', '2008_001617.jpg', '2008_002379.jpg', '2008_000760.jpg', '2008_001040.jpg'], ['2011_002810.jpg', '2009_002414.jpg', '2009_000629.jpg', '2011_001800.jpg', '2011_001025.jpg', '2008_002084.jpg', '2011_002971.jpg', '2008_007143.jpg', '2008_000541.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', nan, nan, nan, nan, 30.98031114526287, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' bottle', ' diningtable', nan, 35.13485651284549, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 31.142308501142768, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  288
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Absent
# image 8 Target Absent
# image 14 Critical
# image 20 Target Present
# image 23 Target Absent
# image 24 Target Present
# image 25 Target Absent
# image 27 Target Present
# image 37 Target Present
# image 40 Critical
# image 46 Target Absent
# image 53 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [6, 8, 20, 23, 24, 25, 27, 37, 46]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 2]
# present_crit 0
# absent_crit 2
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2009_005075.jpg', '2008_000734.jpg', '2010_004683.jpg', '2010_002620.jpg']
# ---------------------------------------------------
# normal available: 100
# present_critical_per_block: []
# absent_critical_per_block: ['2009_005075.jpg', '2008_000734.jpg']
# critical_present:  []
# critical_absent:  [['2009_005075.jpg', '2008_000734.jpg']]
# critical_probes_used:  ['2009_005075.jpg', '2008_000734.jpg']
# probes_per_block : ['2011_001611.jpg', '2009_004129.jpg', '2010_005257.jpg', '2008_006470.jpg', '2011_000293.jpg']
# probes_per_block : ['2011_001611.jpg', '2009_004129.jpg', '2010_005257.jpg', '2008_006470.jpg', '2011_000293.jpg', '2008_004171.jpg', '2009_003309.jpg']
# probes:  [['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg'], ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg', '2008_004188.jpg', '2010_001939.jpg', '2009_000120.jpg', '2008_000798.jpg', '2008_002195.jpg'], ['2009_002998.jpg', '2008_004814.jpg', '2008_008331.jpg', '2010_000299.jpg', '2008_002504.jpg', '2008_003876.jpg', '2010_001451.jpg', '2009_002521.jpg', '2009_004076.jpg'], ['2008_006216.jpg', '2009_004283.jpg', '2009_000466.jpg', '2010_005628.jpg', '2010_002603.jpg', '2009_002571.jpg', '2008_004482.jpg', '2008_001965.jpg', '2010_000792.jpg'], ['2009_001305.jpg', '2008_002904.jpg', '2008_001367.jpg', '2009_004262.jpg', '2010_000613.jpg', '2008_001617.jpg', '2008_002379.jpg', '2008_000760.jpg', '2008_001040.jpg'], ['2011_002810.jpg', '2009_002414.jpg', '2009_000629.jpg', '2011_001800.jpg', '2011_001025.jpg', '2008_002084.jpg', '2011_002971.jpg', '2008_007143.jpg', '2008_000541.jpg'], ['2011_001611.jpg', '2009_004129.jpg', '2010_005257.jpg', '2008_006470.jpg', '2011_000293.jpg', '2008_004171.jpg', '2009_003309.jpg']]
# Present Used in block:  5
# Absent Used in block 2
# Critical probes counter:  2
# Present Critical:  0
# Absent Critical:  2
# List of critical trials without probe:
# [' person', ' boat', nan, nan, nan, 18.642450428633328, 'low', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  338
# critical_probes_used ['2009_005075.jpg', '2008_000734.jpg']
# sequence final does not exist
# x 2
# present_critical_per_block 0
# absent_critical_per_block 2
# ciao2 1
# ------------------
# [3, 6, 15, 18, 24, 34, 40, 41, 49, 52] 10
# gap_check:  [3, 6, 18]
# 10
# (3, 'Critical Absent')
# (6, 'Critical Absent')
# (15, 'Target Present')
# (18, 'Critical')
# (24, 'Target Absent')
# (34, 'Target Present')
# (40, 'Target Absent')
# (41, 'Target Present')
# (49, 'Target Present')
# (52, 'Target Present')
# [(3, 'Critical Absent'), (6, 'Critical Absent'), (15, 'Target Present'), (18, 'Critical'), (24, 'Target Absent'), (34, 'Target Present'), (40, 'Target Absent'), (41, 'Target Present'), (49, 'Target Present'), (52, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Critical Absent
# image 6 Critical Absent
# image 15 Target Present
# image 18 Critical
# image 24 Target Absent
# image 34 Target Present
# image 40 Target Absent
# image 41 Target Present
# image 49 Target Present
# image 52 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 6, 15, 24, 34, 40, 41, 49, 52]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 2]
# present_crit 0
# absent_crit 2
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2009_005075.jpg', '2008_000734.jpg', '2010_004683.jpg', '2010_002620.jpg']
# ---------------------------------------------------
# normal available: 50
# present_critical_per_block: []
# absent_critical_per_block: ['2010_002620.jpg', '2010_004683.jpg']
# critical_present:  []
# critical_absent:  [['2009_005075.jpg', '2008_000734.jpg'], ['2010_002620.jpg', '2010_004683.jpg']]
# critical_probes_used:  ['2009_005075.jpg', '2008_000734.jpg', '2010_002620.jpg', '2010_004683.jpg']
# probes_per_block : ['2008_007250.jpg', '2008_004670.jpg', '2008_004614.jpg', '2011_001440.jpg', '2008_000619.jpg']
# probes_per_block : ['2008_007250.jpg', '2008_004670.jpg', '2008_004614.jpg', '2011_001440.jpg', '2008_000619.jpg', '2008_001210.jpg', '2008_000885.jpg']
# probes:  [['2008_008263.jpg', '2011_001624.jpg', '2008_006954.jpg', '2011_002911.jpg', '2010_002393.jpg', '2008_000912.jpg', '2008_000972.jpg', '2008_006703.jpg', '2009_000716.jpg'], ['2008_002709.jpg', '2008_008500.jpg', '2008_000202.jpg', '2008_004991.jpg', '2008_004188.jpg', '2010_001939.jpg', '2009_000120.jpg', '2008_000798.jpg', '2008_002195.jpg'], ['2009_002998.jpg', '2008_004814.jpg', '2008_008331.jpg', '2010_000299.jpg', '2008_002504.jpg', '2008_003876.jpg', '2010_001451.jpg', '2009_002521.jpg', '2009_004076.jpg'], ['2008_006216.jpg', '2009_004283.jpg', '2009_000466.jpg', '2010_005628.jpg', '2010_002603.jpg', '2009_002571.jpg', '2008_004482.jpg', '2008_001965.jpg', '2010_000792.jpg'], ['2009_001305.jpg', '2008_002904.jpg', '2008_001367.jpg', '2009_004262.jpg', '2010_000613.jpg', '2008_001617.jpg', '2008_002379.jpg', '2008_000760.jpg', '2008_001040.jpg'], ['2011_002810.jpg', '2009_002414.jpg', '2009_000629.jpg', '2011_001800.jpg', '2011_001025.jpg', '2008_002084.jpg', '2011_002971.jpg', '2008_007143.jpg', '2008_000541.jpg'], ['2011_001611.jpg', '2009_004129.jpg', '2010_005257.jpg', '2008_006470.jpg', '2011_000293.jpg', '2008_004171.jpg', '2009_003309.jpg'], ['2008_007250.jpg', '2008_004670.jpg', '2008_004614.jpg', '2011_001440.jpg', '2008_000619.jpg', '2008_001210.jpg', '2008_000885.jpg']]
# Present Used in block:  5
# Absent Used in block 2
# Critical probes counter:  2
# Present Critical:  0
# Absent Critical:  2
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 29.81492031357475, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  388
# critical_probes_used ['2009_005075.jpg', '2008_000734.jpg', '2010_002620.jpg', '2010_004683.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Critical Absent
# image 6 Critical Absent
# image 15 Target Present
# image 18 Critical
# image 24 Target Absent
# image 34 Target Present
# image 40 Target Absent
# image 41 Target Present
# image 49 Target Present
# image 52 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 6, 15, 24, 34, 40, 41, 49, 52]
# 60 60
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone1']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# 480

# %%
# print len(normal_no_probe_before)
# print len(normal_used)
# print len(normal_no_probe_before) == len(set(normal_used))
# print len(target_present_before)
# print len(present_used)
# print len(target_present_before) == len(set(present_used))
# print len(target_absent_before)
# print len(absent_used)
# print len(target_absent_before) == len(set(absent_used))

# #the following is not a good check
# print len(set(critical_trials_before)) == len(set(critical_used + critical_low_present_probes + critical_low_absent_probes +
#                                              critical_high_present_probes + critical_high_absent_probes))

# print set(critical_trials_before) == set(critical_used + critical_low_present_probes + critical_low_absent_probes +
#                                              critical_high_present_probes + critical_high_absent_probes)

# print len(low_four)
# print len(low_one) == len(low_two) == len(low_three) == len(low_four) == len(high_one) == len(high_two) == len(high_three) == len(high_four)
# print len(set(low_one) & set(low_two) & set(low_three) & set(low_four) & set(high_one) & set(high_two) & set(high_three) & set(high_four))

# %%
##################
# SECOND ITERATION#
##################
#GLOBALS
trials = {}
############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
categories = [' bottle', ' horse', ' pottedplant', ' dog',
                  ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

target_present = []
target_absent = []
critical_trials = []

df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()




target_present, target_absent= present_absent_trials()
appending_critical_trials()
#-----------------------------------------------------

normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
        
print 'present_crit_distribution', present_crit_distribution
print 'absent_crit_distribution', absent_crit_distribution
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) #, probes_1_3
low_two, high_one = block_unpacker(60,5,4) #, probes_2_4
low_four, high_three = block_unpacker(60,4,5) #, probes_5_7
low_three, high_four = block_unpacker(60,5,4) #, probes_6_8

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four

trial_n = 481
for b in range(8):
    this_block_images = blocks[b]
    for im in this_block_images:
        trials[trial_n] = possible_images_dict[im]
        trials[trial_n].append(im)
        trial_n += 1
for i in range(len(trials.keys())):
    trials[i+1].append(i/60+1)
len(trials)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  9
# Critical, high:  9
# Are all critical trials unique?  True
# Number of critical probes:  6
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  2
# critical_high_absent_probes:  2
# cycles :  6
# present_crit_distribution [0, 1, 0, 0]
# absent_crit_distribution [0, 0, 1, 1]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [0, 1, 1]
# critical present set:  ['2011_001198.jpg', '2008_004670.jpg']
# critical absent set:  ['2008_001542.jpg', '2011_000224.jpg', '2008_000196.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 390
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg']
# probes_per_block : ['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg']
# probes:  [['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', nan, nan, nan, nan, 19.89572011801729, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 13.440366765570474, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 21.19410161612616, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [8, 14, 22, 25, 29, 31, 38, 39, 41, 42, 46, 49] 12
# gap_check:  [22, 42, 46]
# 12
# (8, 'Target Absent')
# (14, 'Target Present')
# (22, 'Critical')
# (25, 'Target Absent')
# (29, 'Target Present')
# (31, 'Target Present')
# (38, 'Target Absent')
# (39, 'Target Present')
# (41, 'Target Absent')
# (42, 'Critical')
# (46, 'Critical')
# (49, 'Target Absent')
# [(8, 'Target Absent'), (14, 'Target Present'), (22, 'Critical'), (25, 'Target Absent'), (29, 'Target Present'), (31, 'Target Present'), (38, 'Target Absent'), (39, 'Target Present'), (41, 'Target Absent'), (42, 'Critical'), (46, 'Critical'), (49, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 8 Target Absent
# image 14 Target Present
# image 22 Critical
# image 25 Target Absent
# image 29 Target Present
# image 31 Target Present
# image 38 Target Absent
# image 39 Target Present
# image 41 Target Absent
# image 42 Critical
# image 46 Critical
# image 49 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [8, 14, 25, 29, 31, 38, 39, 41, 49]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [0, 1, 1]
# critical present set:  ['2011_001198.jpg', '2008_004670.jpg']
# critical absent set:  ['2008_001542.jpg', '2011_000224.jpg', '2008_000196.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 342
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg']
# probes_per_block : ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg', '2010_005270.jpg', '2008_004188.jpg', '2008_002864.jpg', '2009_000198.jpg', '2011_001382.jpg']
# probes:  [['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg'], ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg', '2010_005270.jpg', '2008_004188.jpg', '2008_002864.jpg', '2009_000198.jpg', '2011_001382.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 31.397027824172856, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 29.201869461183065, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 32.97739588330027, 'high', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 8 Target Absent
# image 14 Target Present
# image 22 Critical
# image 25 Target Absent
# image 29 Target Present
# image 31 Target Present
# image 38 Target Absent
# image 39 Target Present
# image 41 Target Absent
# image 42 Critical
# image 46 Critical
# image 49 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [8, 14, 25, 29, 31, 38, 39, 41, 49]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 1]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 1]
# critical present set:  ['2011_001198.jpg', '2008_004670.jpg']
# critical absent set:  ['2008_001542.jpg', '2011_000224.jpg', '2008_000196.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 294
# present_critical_per_block: ['2011_001198.jpg']
# absent_critical_per_block: []
# critical_present:  [['2011_001198.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2011_001198.jpg']
# probes_per_block : ['2010_000613.jpg', '2008_001708.jpg', '2008_002700.jpg', '2011_000661.jpg']
# probes_per_block : ['2010_000613.jpg', '2008_001708.jpg', '2008_002700.jpg', '2011_000661.jpg', '2008_006564.jpg', '2011_000514.jpg', '2009_001406.jpg', '2008_000912.jpg']
# probes:  [['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg'], ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg', '2010_005270.jpg', '2008_004188.jpg', '2008_002864.jpg', '2009_000198.jpg', '2011_001382.jpg'], ['2010_000613.jpg', '2008_001708.jpg', '2008_002700.jpg', '2011_000661.jpg', '2008_006564.jpg', '2011_000514.jpg', '2009_001406.jpg', '2008_000912.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' boat', nan, nan, nan, 16.65124246053083, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 18.29867809750948, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  145
# critical_probes_used ['2011_001198.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 1
# absent_critical_per_block 0
# ciao2 2
# ciao2 2
# ------------------
# [5, 8, 9, 16, 26, 31, 34, 43, 46, 50, 58] 11
# gap_check:  [5, 16, 43]
# 11
# (5, 'Critical')
# (8, 'Target Absent')
# (9, 'Target Absent')
# (16, 'Critical Present')
# (26, 'Target Present')
# (31, 'Target Present')
# (34, 'Target Present')
# (43, 'Critical')
# (46, 'Target Absent')
# (50, 'Target Present')
# (58, 'Target Absent')
# [(5, 'Critical'), (8, 'Target Absent'), (9, 'Target Absent'), (16, 'Critical Present'), (26, 'Target Present'), (31, 'Target Present'), (34, 'Target Present'), (43, 'Critical'), (46, 'Target Absent'), (50, 'Target Present'), (58, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical
# image 8 Target Absent
# image 9 Target Absent
# image 16 Critical Present
# image 26 Target Present
# image 31 Target Present
# image 34 Target Present
# image 43 Critical
# image 46 Target Absent
# image 50 Target Present
# image 58 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [8, 9, 16, 26, 31, 34, 46, 50, 58]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 1]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 1]
# critical present set:  ['2011_001198.jpg', '2008_004670.jpg']
# critical absent set:  ['2008_001542.jpg', '2011_000224.jpg', '2008_000196.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 245
# present_critical_per_block: ['2008_004670.jpg']
# absent_critical_per_block: []
# critical_present:  [['2011_001198.jpg'], ['2008_004670.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2011_001198.jpg', '2008_004670.jpg']
# probes_per_block : ['2008_005845.jpg', '2008_000928.jpg', '2010_004423.jpg', '2011_000530.jpg']
# probes_per_block : ['2008_005845.jpg', '2008_000928.jpg', '2010_004423.jpg', '2011_000530.jpg', '2008_000270.jpg', '2008_007745.jpg', '2011_001304.jpg', '2008_002195.jpg']
# probes:  [['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg'], ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg', '2010_005270.jpg', '2008_004188.jpg', '2008_002864.jpg', '2009_000198.jpg', '2011_001382.jpg'], ['2010_000613.jpg', '2008_001708.jpg', '2008_002700.jpg', '2011_000661.jpg', '2008_006564.jpg', '2011_000514.jpg', '2009_001406.jpg', '2008_000912.jpg'], ['2008_005845.jpg', '2008_000928.jpg', '2010_004423.jpg', '2011_000530.jpg', '2008_000270.jpg', '2008_007745.jpg', '2011_001304.jpg', '2008_002195.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' tvmonitor', ' chair', ' sofa', nan, 35.63660420168497, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' sofa', ' chair', ' person', nan, nan, 30.035339131770247, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  194
# critical_probes_used ['2011_001198.jpg', '2008_004670.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical
# image 8 Target Absent
# image 9 Target Absent
# image 16 Critical Present
# image 26 Target Present
# image 31 Target Present
# image 34 Target Present
# image 43 Critical
# image 46 Target Absent
# image 50 Target Present
# image 58 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [8, 9, 16, 26, 31, 34, 46, 50, 58]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 1]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [1]
# critical present set:  ['2011_001198.jpg', '2008_004670.jpg']
# critical absent set:  ['2008_001542.jpg', '2011_000224.jpg', '2008_000196.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 196
# present_critical_per_block: []
# absent_critical_per_block: ['2008_001542.jpg']
# critical_present:  [['2011_001198.jpg'], ['2008_004670.jpg']]
# critical_absent:  [['2008_001542.jpg']]
# critical_probes_used:  ['2011_001198.jpg', '2008_004670.jpg', '2008_001542.jpg']
# probes_per_block : ['2008_001040.jpg', '2008_008506.jpg', '2009_000260.jpg', '2011_001967.jpg']
# probes_per_block : ['2008_001040.jpg', '2008_008506.jpg', '2009_000260.jpg', '2011_001967.jpg', '2009_004737.jpg', '2009_003084.jpg', '2010_004175.jpg', '2008_006703.jpg']
# probes:  [['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg'], ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg', '2010_005270.jpg', '2008_004188.jpg', '2008_002864.jpg', '2009_000198.jpg', '2011_001382.jpg'], ['2010_000613.jpg', '2008_001708.jpg', '2008_002700.jpg', '2011_000661.jpg', '2008_006564.jpg', '2011_000514.jpg', '2009_001406.jpg', '2008_000912.jpg'], ['2008_005845.jpg', '2008_000928.jpg', '2010_004423.jpg', '2011_000530.jpg', '2008_000270.jpg', '2008_007745.jpg', '2011_001304.jpg', '2008_002195.jpg'], ['2008_001040.jpg', '2008_008506.jpg', '2009_000260.jpg', '2011_001967.jpg', '2009_004737.jpg', '2009_003084.jpg', '2010_004175.jpg', '2008_006703.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 19.30503047810884, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' chair', ' diningtable', nan, nan, nan, 18.11780279510061, 'low', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  243
# critical_probes_used ['2011_001198.jpg', '2008_004670.jpg', '2008_001542.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [1, 4, 10, 15, 16, 20, 22, 28, 31, 36, 46] 11
# gap_check:  [1, 22, 31]
# 11
# (1, 'Critical Absent')
# (4, 'Target Absent')
# (10, 'Target Absent')
# (15, 'Target Absent')
# (16, 'Target Present')
# (20, 'Target Present')
# (22, 'Critical')
# (28, 'Target Absent')
# (31, 'Critical')
# (36, 'Target Present')
# (46, 'Target Present')
# [(1, 'Critical Absent'), (4, 'Target Absent'), (10, 'Target Absent'), (15, 'Target Absent'), (16, 'Target Present'), (20, 'Target Present'), (22, 'Critical'), (28, 'Target Absent'), (31, 'Critical'), (36, 'Target Present'), (46, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical Absent
# image 4 Target Absent
# image 10 Target Absent
# image 15 Target Absent
# image 16 Target Present
# image 20 Target Present
# image 22 Critical
# image 28 Target Absent
# image 31 Critical
# image 36 Target Present
# image 46 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 4, 10, 15, 16, 20, 28, 36, 46]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 1]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [1]
# critical present set:  ['2011_001198.jpg', '2008_004670.jpg']
# critical absent set:  ['2008_001542.jpg', '2011_000224.jpg', '2008_000196.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 147
# present_critical_per_block: []
# absent_critical_per_block: ['2008_000196.jpg']
# critical_present:  [['2011_001198.jpg'], ['2008_004670.jpg']]
# critical_absent:  [['2008_001542.jpg'], ['2008_000196.jpg']]
# critical_probes_used:  ['2011_001198.jpg', '2008_004670.jpg', '2008_001542.jpg', '2008_000196.jpg']
# probes_per_block : ['2010_002472.jpg', '2008_006663.jpg', '2010_003579.jpg', '2009_000021.jpg']
# probes_per_block : ['2010_002472.jpg', '2008_006663.jpg', '2010_003579.jpg', '2009_000021.jpg', '2011_000628.jpg', '2008_008628.jpg', '2008_000457.jpg', '2011_002482.jpg']
# probes:  [['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg'], ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg', '2010_005270.jpg', '2008_004188.jpg', '2008_002864.jpg', '2009_000198.jpg', '2011_001382.jpg'], ['2010_000613.jpg', '2008_001708.jpg', '2008_002700.jpg', '2011_000661.jpg', '2008_006564.jpg', '2011_000514.jpg', '2009_001406.jpg', '2008_000912.jpg'], ['2008_005845.jpg', '2008_000928.jpg', '2010_004423.jpg', '2011_000530.jpg', '2008_000270.jpg', '2008_007745.jpg', '2011_001304.jpg', '2008_002195.jpg'], ['2008_001040.jpg', '2008_008506.jpg', '2009_000260.jpg', '2011_001967.jpg', '2009_004737.jpg', '2009_003084.jpg', '2010_004175.jpg', '2008_006703.jpg'], ['2010_002472.jpg', '2008_006663.jpg', '2010_003579.jpg', '2009_000021.jpg', '2011_000628.jpg', '2008_008628.jpg', '2008_000457.jpg', '2011_002482.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' pottedplant', ' sofa', nan, nan, nan, 29.04248886812048, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 35.66913245555085, 'high', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  292
# critical_probes_used ['2011_001198.jpg', '2008_004670.jpg', '2008_001542.jpg', '2008_000196.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical Absent
# image 4 Target Absent
# image 10 Target Absent
# image 15 Target Absent
# image 16 Target Present
# image 20 Target Present
# image 22 Critical
# image 28 Target Absent
# image 31 Critical
# image 36 Target Present
# image 46 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 4, 10, 15, 16, 20, 28, 36, 46]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 1]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2011_001198.jpg', '2008_004670.jpg']
# critical absent set:  ['2008_001542.jpg', '2011_000224.jpg', '2008_000196.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 98
# present_critical_per_block: []
# absent_critical_per_block: ['2011_000224.jpg']
# critical_present:  [['2011_001198.jpg'], ['2008_004670.jpg']]
# critical_absent:  [['2008_001542.jpg'], ['2008_000196.jpg'], ['2011_000224.jpg']]
# critical_probes_used:  ['2011_001198.jpg', '2008_004670.jpg', '2008_001542.jpg', '2008_000196.jpg', '2011_000224.jpg']
# probes_per_block : ['2009_002137.jpg', '2010_000090.jpg', '2011_002453.jpg', '2008_002899.jpg', '2009_005008.jpg']
# probes_per_block : ['2009_002137.jpg', '2010_000090.jpg', '2011_002453.jpg', '2008_002899.jpg', '2009_005008.jpg', '2008_006784.jpg', '2009_001894.jpg', '2008_000219.jpg']
# probes:  [['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg'], ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg', '2010_005270.jpg', '2008_004188.jpg', '2008_002864.jpg', '2009_000198.jpg', '2011_001382.jpg'], ['2010_000613.jpg', '2008_001708.jpg', '2008_002700.jpg', '2011_000661.jpg', '2008_006564.jpg', '2011_000514.jpg', '2009_001406.jpg', '2008_000912.jpg'], ['2008_005845.jpg', '2008_000928.jpg', '2010_004423.jpg', '2011_000530.jpg', '2008_000270.jpg', '2008_007745.jpg', '2011_001304.jpg', '2008_002195.jpg'], ['2008_001040.jpg', '2008_008506.jpg', '2009_000260.jpg', '2011_001967.jpg', '2009_004737.jpg', '2009_003084.jpg', '2010_004175.jpg', '2008_006703.jpg'], ['2010_002472.jpg', '2008_006663.jpg', '2010_003579.jpg', '2009_000021.jpg', '2011_000628.jpg', '2008_008628.jpg', '2008_000457.jpg', '2011_002482.jpg'], ['2009_002137.jpg', '2010_000090.jpg', '2011_002453.jpg', '2008_002899.jpg', '2009_005008.jpg', '2008_006784.jpg', '2009_001894.jpg', '2008_000219.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' bottle', nan, nan, nan, nan, 20.96364307633711, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' car', ' person', nan, nan, nan, 20.695714607410885, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  341
# critical_probes_used ['2011_001198.jpg', '2008_004670.jpg', '2008_001542.jpg', '2008_000196.jpg', '2011_000224.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ciao2 2
# ciao2 2
# ------------------
# [7, 11, 14, 19, 25, 26, 35, 41, 43, 52, 55] 11
# gap_check:  [11, 19, 43]
# 11
# (7, 'Target Present')
# (11, 'Critical')
# (14, 'Target Present')
# (19, 'Critical')
# (25, 'Target Absent')
# (26, 'Target Present')
# (35, 'Target Absent')
# (41, 'Target Present')
# (43, 'Critical Absent')
# (52, 'Target Present')
# (55, 'Target Absent')
# [(7, 'Target Present'), (11, 'Critical'), (14, 'Target Present'), (19, 'Critical'), (25, 'Target Absent'), (26, 'Target Present'), (35, 'Target Absent'), (41, 'Target Present'), (43, 'Critical Absent'), (52, 'Target Present'), (55, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 11 Critical
# image 14 Target Present
# image 19 Critical
# image 25 Target Absent
# image 26 Target Present
# image 35 Target Absent
# image 41 Target Present
# image 43 Critical Absent
# image 52 Target Present
# image 55 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [7, 14, 25, 26, 35, 41, 43, 52, 55]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 1]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2011_001198.jpg', '2008_004670.jpg']
# critical absent set:  ['2008_001542.jpg', '2011_000224.jpg', '2008_000196.jpg', '2008_006844.jpg']
# ---------------------------------------------------
# normal available: 49
# present_critical_per_block: []
# absent_critical_per_block: ['2008_006844.jpg']
# critical_present:  [['2011_001198.jpg'], ['2008_004670.jpg']]
# critical_absent:  [['2008_001542.jpg'], ['2008_000196.jpg'], ['2011_000224.jpg'], ['2008_006844.jpg']]
# critical_probes_used:  ['2011_001198.jpg', '2008_004670.jpg', '2008_001542.jpg', '2008_000196.jpg', '2011_000224.jpg', '2008_006844.jpg']
# probes_per_block : ['2008_000274.jpg', '2009_004794.jpg', '2008_006912.jpg', '2008_002350.jpg', '2008_002709.jpg']
# probes_per_block : ['2008_000274.jpg', '2009_004794.jpg', '2008_006912.jpg', '2008_002350.jpg', '2008_002709.jpg', '2008_002725.jpg', '2008_008500.jpg', '2010_002278.jpg']
# probes:  [['2008_002062.jpg', '2010_006023.jpg', '2010_000426.jpg', '2008_006470.jpg', '2010_002645.jpg', '2009_001470.jpg', '2010_005785.jpg', '2010_000616.jpg', '2008_002704.jpg'], ['2008_000192.jpg', '2008_000202.jpg', '2008_006216.jpg', '2008_000381.jpg', '2010_005270.jpg', '2008_004188.jpg', '2008_002864.jpg', '2009_000198.jpg', '2011_001382.jpg'], ['2010_000613.jpg', '2008_001708.jpg', '2008_002700.jpg', '2011_000661.jpg', '2008_006564.jpg', '2011_000514.jpg', '2009_001406.jpg', '2008_000912.jpg'], ['2008_005845.jpg', '2008_000928.jpg', '2010_004423.jpg', '2011_000530.jpg', '2008_000270.jpg', '2008_007745.jpg', '2011_001304.jpg', '2008_002195.jpg'], ['2008_001040.jpg', '2008_008506.jpg', '2009_000260.jpg', '2011_001967.jpg', '2009_004737.jpg', '2009_003084.jpg', '2010_004175.jpg', '2008_006703.jpg'], ['2010_002472.jpg', '2008_006663.jpg', '2010_003579.jpg', '2009_000021.jpg', '2011_000628.jpg', '2008_008628.jpg', '2008_000457.jpg', '2011_002482.jpg'], ['2009_002137.jpg', '2010_000090.jpg', '2011_002453.jpg', '2008_002899.jpg', '2009_005008.jpg', '2008_006784.jpg', '2009_001894.jpg', '2008_000219.jpg'], ['2008_000274.jpg', '2009_004794.jpg', '2008_006912.jpg', '2008_002350.jpg', '2008_002709.jpg', '2008_002725.jpg', '2008_008500.jpg', '2010_002278.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 31.19357078875772, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' motorbike', ' boat', 31.58048990210689, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  390
# critical_probes_used ['2011_001198.jpg', '2008_004670.jpg', '2008_001542.jpg', '2008_000196.jpg', '2011_000224.jpg', '2008_006844.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 11 Critical
# image 14 Target Present
# image 19 Critical
# image 25 Target Absent
# image 26 Target Present
# image 35 Target Absent
# image 41 Target Present
# image 43 Critical Absent
# image 52 Target Present
# image 55 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [7, 14, 25, 26, 35, 41, 43, 52, 55]
# 60 60
# ['tone1', 'tone1', 'tone1']
# ['tone2', 'tone2', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# KeyErrorTraceback (most recent call last)
# <ipython-input-14-dd4399f84ff5> in <module>()
#     108         trial_n += 1
#     109 for i in range(len(trials.keys())):
# --> 110     trials[i+1].append(i/60+1)
#     111 len(trials)
#     112
#
# KeyError: 1

# %%
import pickle
with open('../config/randomization.pik', 'wb') as of:
    pickle.dump(trials,of)

# %%
trials
# Out:
# {481: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   19.793376112600363,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003587.jpg'],
#  482: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.60608553782437,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007842.jpg'],
#  483: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.846336579249186,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005780.jpg'],
#  484: [' chair',
#   ' diningtable',
#   ' bottle',
#   nan,
#   nan,
#   20.038119878562025,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007704.jpg'],
#  485: [' chair',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   17.570654058012458,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000115.jpg'],
#  486: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.137458117206307,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006452.jpg'],
#  487: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.803898838362514,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003890.jpg'],
#  488: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.906276626032106,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000132.jpg'],
#  489: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.135096838925413,
#   'low',
#   ' cat',
#   ' car',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000616.jpg'],
#  490: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.25351959992476,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000919.jpg'],
#  491: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.20795639634078,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008533.jpg'],
#  492: [' sofa',
#   ' tvmonitor',
#   nan,
#   nan,
#   nan,
#   15.574047189150072,
#   'low',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003373.jpg'],
#  493: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.686905104738816,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005673.jpg'],
#  494: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.321308873350848,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008331.jpg'],
#  495: [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.883134744539575,
#   'low',
#   ' bottle',
#   ' bottle',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000426.jpg'],
#  496: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.057825283941515,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002283.jpg'],
#  497: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.413253715842107,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004412.jpg'],
#  498: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.803149147012245,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007208.jpg'],
#  499: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.590456430582357,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004145.jpg'],
#  500: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   11.459232377151848,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004129.jpg'],
#  501: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.470663952413528,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002504.jpg'],
#  502: [' dog',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   18.86070334209068,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000805.jpg'],
#  503: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.89572011801729,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone1',
#   148,
#   '2010_002379.jpg'],
#  504: [' bicycle',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   18.893798014446215,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004984.jpg'],
#  505: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.041574567240037,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005257.jpg'],
#  506: [' sofa',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   19.188834185415878,
#   'low',
#   ' sofa',
#   ' car',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_001470.jpg'],
#  507: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.646066025131248,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000760.jpg'],
#  508: [' sofa',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   16.142562620916582,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_001774.jpg'],
#  509: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.234401336670953,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_001829.jpg'],
#  510: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.78745072135656,
#   'low',
#   ' car',
#   ' car',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002062.jpg'],
#  511: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.608803704733788,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005391.jpg'],
#  512: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.005917005737068,
#   'low',
#   ' chair',
#   ' chair',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006470.jpg'],
#  513: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.78900607095989,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002697.jpg'],
#  514: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.102590259239356,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_001568.jpg'],
#  515: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.731696099482228,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003453.jpg'],
#  516: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   9.57686770873812,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001959.jpg'],
#  517: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.523024266211753,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001185.jpg'],
#  518: [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   13.414126280812802,
#   'low',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005490.jpg'],
#  519: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.197035825449316,
#   'low',
#   ' car',
#   ' boat',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005785.jpg'],
#  520: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   12.53657278412077,
#   'low',
#   ' aeroplane',
#   ' aeroplane',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_006023.jpg'],
#  521: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.580374337830555,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004907.jpg'],
#  522: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.4399393845732,
#   'low',
#   ' car',
#   ' aeroplane',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002704.jpg'],
#  523: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.440366765570474,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone2',
#   849,
#   '2008_003876.jpg'],
#  524: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.000361854332464,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002888.jpg'],
#  525: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.821731630747827,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005217.jpg'],
#  526: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.463883689453848,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001836.jpg'],
#  527: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.19410161612616,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone1',
#   123,
#   '2010_000109.jpg'],
#  528: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.350033322032775,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005101.jpg'],
#  529: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.13855956552752,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002374.jpg'],
#  530: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.850125265290927,
#   'low',
#   ' cat',
#   ' person',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002645.jpg'],
#  531: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.01071271736431,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000740.jpg'],
#  532: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   8.17124474061747,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000151.jpg'],
#  533: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.1064450150686,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008359.jpg'],
#  534: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   19.187546074203674,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000119.jpg'],
#  535: [' person',
#   ' horse',
#   ' car',
#   nan,
#   nan,
#   20.934599857700228,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000169.jpg'],
#  536: [' chair',
#   ' diningtable',
#   nan,
#   nan,
#   nan,
#   15.830708942989276,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004231.jpg'],
#  537: [' bottle',
#   ' dog',
#   ' diningtable',
#   nan,
#   nan,
#   21.034646910874567,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002911.jpg'],
#  538: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   8.062836492776528,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004893.jpg'],
#  539: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.396955524186414,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000177.jpg'],
#  540: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.341894736874325,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000229.jpg'],
#  541: [' tvmonitor',
#   ' chair',
#   ' sofa',
#   nan,
#   nan,
#   29.8220330038045,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000093.jpg'],
#  542: [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   31.463677231105994,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000995.jpg'],
#  543: [' pottedplant',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   29.851834352354174,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007108.jpg'],
#  544: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.9571992215138,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003701.jpg'],
#  545: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   30.20203583105944,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002037.jpg'],
#  546: [' pottedplant',
#   ' tvmonitor',
#   ' chair',
#   ' sofa',
#   nan,
#   35.63660420168497,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone2',
#   362,
#   '2011_002810.jpg'],
#  547: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   29.547306113597852,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003705.jpg'],
#  548: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   34.55757716862823,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002183.jpg'],
#  549: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   30.48036175658957,
#   'high',
#   ' aeroplane',
#   ' bird',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002195.jpg'],
#  550: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   32.959390221443385,
#   'high',
#   ' dog',
#   ' person',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007745.jpg'],
#  551: [' sofa',
#   ' chair',
#   ' bottle',
#   ' person',
#   nan,
#   29.05176679498621,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001333.jpg'],
#  552: [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   31.26103763923315,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005526.jpg'],
#  553: [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   29.006457456633935,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003081.jpg'],
#  554: [' person',
#   ' bird',
#   nan,
#   nan,
#   nan,
#   29.657389969329227,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003724.jpg'],
#  555: [' car',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   33.46218479046818,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000619.jpg'],
#  556: [' pottedplant',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   31.62452384083404,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001440.jpg'],
#  557: [' sofa',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   32.351474210019695,
#   'high',
#   ' chair',
#   ' chair',
#   'Target Present',
#   'Critical',
#   'tone1',
#   464,
#   '2008_004670.jpg'],
#  558: [' car',
#   ' dog',
#   ' person',
#   nan,
#   nan,
#   29.763552134631723,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003755.jpg'],
#  559: [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   33.27958235579427,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007043.jpg'],
#  560: [' pottedplant',
#   ' person',
#   ' chair',
#   ' diningtable',
#   ' boat',
#   35.38363353726925,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001221.jpg'],
#  561: [' pottedplant',
#   ' person',
#   ' chair',
#   ' dog',
#   nan,
#   34.099790178372324,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005628.jpg'],
#  562: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.027958359084288,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005894.jpg'],
#  563: [' chair',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   30.42487388731773,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005347.jpg'],
#  564: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   30.657341600370845,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006870.jpg'],
#  565: [' car',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   32.224520766602424,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005718.jpg'],
#  566: [' pottedplant',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   28.76635784450944,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007388.jpg'],
#  567: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.961816980758506,
#   'high',
#   ' dog',
#   ' dog',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005845.jpg'],
#  568: [' tvmonitor',
#   ' sofa',
#   ' bottle',
#   ' person',
#   nan,
#   29.608026491553932,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005090.jpg'],
#  569: [' tvmonitor',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   31.79472940313895,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001576.jpg'],
#  570: [' pottedplant',
#   ' person',
#   ' dog',
#   nan,
#   nan,
#   30.00737433193205,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002084.jpg'],
#  571: [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   31.124437166631626,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004459.jpg'],
#  572: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.996977820829354,
#   'high',
#   ' person',
#   ' person',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000928.jpg'],
#  573: [' person',
#   ' diningtable',
#   ' bottle',
#   nan,
#   nan,
#   33.461904083445745,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000885.jpg'],
#  574: [' person',
#   ' chair',
#   ' bottle',
#   ' diningtable',
#   nan,
#   35.13485651284549,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000282.jpg'],
#  575: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.739677956098852,
#   'high',
#   ' aeroplane',
#   ' aeroplane',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004423.jpg'],
#  576: [' car',
#   ' bicycle',
#   ' motorbike',
#   nan,
#   nan,
#   29.67801392295739,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003802.jpg'],
#  577: [' person',
#   ' chair',
#   ' cat',
#   nan,
#   nan,
#   30.87884814240284,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006863.jpg'],
#  578: [' car',
#   ' bicycle',
#   ' motorbike',
#   ' bus',
#   ' person',
#   30.26344946567593,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008097.jpg'],
#  579: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.54166437440535,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000536.jpg'],
#  580: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   39.79411022613925,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003193.jpg'],
#  581: [' tvmonitor',
#   ' chair',
#   ' bottle',
#   nan,
#   nan,
#   32.179769175040214,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000495.jpg'],
#  582: [' person',
#   ' chair',
#   ' diningtable',
#   ' sofa',
#   nan,
#   30.916466766406522,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005170.jpg'],
#  583: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.142308501142768,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007629.jpg'],
#  584: [' sofa',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   30.035339131770247,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone1',
#   948,
#   '2008_006841.jpg'],
#  585: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.66706520443793,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003419.jpg'],
#  586: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   29.354458493580452,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000539.jpg'],
#  587: [' person',
#   ' dog',
#   ' sofa',
#   nan,
#   nan,
#   29.935618386927253,
#   'high',
#   ' dog',
#   ' person',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000270.jpg'],
#  588: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.270464835358208,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_005133.jpg'],
#  589: [' pottedplant',
#   ' person',
#   ' motorbike',
#   nan,
#   nan,
#   34.41600543331538,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001605.jpg'],
#  590: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.779858819461175,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000824.jpg'],
#  591: [' pottedplant',
#   ' sofa',
#   ' chair',
#   ' diningtable',
#   nan,
#   29.806819625699735,
#   'high',
#   ' sofa',
#   ' sofa',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000530.jpg'],
#  592: [' tvmonitor',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   32.38481414164753,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007527.jpg'],
#  593: [' bus',
#   ' boat',
#   ' car',
#   nan,
#   nan,
#   34.403914620094966,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005720.jpg'],
#  594: [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   29.27630230662073,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000792.jpg'],
#  595: [' pottedplant',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   28.66363347517436,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004683.jpg'],
#  596: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.80608913442844,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000120.jpg'],
#  597: [' pottedplant',
#   ' person',
#   ' bicycle',
#   ' car',
#   nan,
#   33.367152749801264,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001025.jpg'],
#  598: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.954010715704413,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000466.jpg'],
#  599: [' tvmonitor',
#   ' chair',
#   ' sofa',
#   nan,
#   nan,
#   37.22381580448725,
#   'high',
#   ' sofa',
#   ' bottle',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001304.jpg'],
#  600: [' sofa',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   36.443791926636216,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002971.jpg'],
#  601: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.068803282805252,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004633.jpg'],
#  602: [' chair',
#   ' diningtable',
#   nan,
#   nan,
#   nan,
#   29.119691130314802,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003520.jpg'],
#  603: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.096920358380203,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002260.jpg'],
#  604: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.53785712566009,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003180.jpg'],
#  605: [' tvmonitor',
#   ' diningtable',
#   ' cat',
#   nan,
#   nan,
#   29.842922502719393,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_001939.jpg'],
#  606: [' pottedplant',
#   ' sofa',
#   ' chair',
#   ' tvmonitor',
#   nan,
#   29.464580095555625,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002119.jpg'],
#  607: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.246976174425782,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001210.jpg'],
#  608: [' chair',
#   ' diningtable',
#   nan,
#   nan,
#   nan,
#   28.72863626121521,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003884.jpg'],
#  609: [' person',
#   ' diningtable',
#   ' bottle',
#   nan,
#   nan,
#   36.4850555132999,
#   'high',
#   ' bottle',
#   ' horse',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002864.jpg'],
#  610: [' tvmonitor',
#   ' chair',
#   ' sofa',
#   nan,
#   nan,
#   30.457957800415656,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000499.jpg'],
#  611: [' chair',
#   ' dog',
#   ' diningtable',
#   nan,
#   nan,
#   29.611440342795753,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007378.jpg'],
#  612: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   31.96963432435441,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003297.jpg'],
#  613: [' car',
#   ' boat',
#   ' person',
#   nan,
#   nan,
#   32.75926741884376,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000833.jpg'],
#  614: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   37.706201599515055,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000631.jpg'],
#  615: [' person',
#   ' chair',
#   ' bottle',
#   ' tvmonitor',
#   nan,
#   34.633056090581924,
#   'high',
#   ' bottle',
#   ' bottle',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000202.jpg'],
#  616: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.742786682331467,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002414.jpg'],
#  617: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.608002755298447,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002897.jpg'],
#  618: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   32.480531856762035,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001278.jpg'],
#  619: [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   29.639010239051967,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000541.jpg'],
#  620: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   29.875362071673013,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003805.jpg'],
#  621: [' person',
#   ' bottle',
#   ' diningtable',
#   nan,
#   nan,
#   34.072917550349175,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000058.jpg'],
#  622: [' person',
#   ' bicycle',
#   ' boat',
#   nan,
#   nan,
#   34.31905160776113,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000191.jpg'],
#  623: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.201869461183065,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone1',
#   502,
#   '2008_005750.jpg'],
#  624: [' person',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   32.2651090829965,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007913.jpg'],
#  625: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   35.94715000296663,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000414.jpg'],
#  626: [' pottedplant',
#   ' person',
#   ' diningtable',
#   ' bottle',
#   nan,
#   28.939513311425664,
#   'high',
#   ' pottedplant',
#   ' boat',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001382.jpg'],
#  627: [' pottedplant',
#   ' person',
#   ' bird',
#   nan,
#   nan,
#   32.325935045893075,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001283.jpg'],
#  628: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.77784058169977,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002775.jpg'],
#  629: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.710284354349575,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_005118.jpg'],
#  630: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   31.88587780040415,
#   'high',
#   ' aeroplane',
#   ' aeroplane',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006216.jpg'],
#  631: [' aeroplane',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   29.28734944464957,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002773.jpg'],
#  632: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.176311484999022,
#   'high',
#   ' bird',
#   ' bird',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000192.jpg'],
#  633: [' dog',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   41.99714470321874,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002098.jpg'],
#  634: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   32.020689907436754,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008607.jpg'],
#  635: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.141763061562205,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002750.jpg'],
#  636: [' person',
#   ' bottle',
#   ' pottedplant',
#   ' tvmonitor',
#   ' chair',
#   31.676385713707838,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002742.jpg'],
#  637: [' person',
#   ' bottle',
#   ' sofa',
#   nan,
#   nan,
#   33.561185784733894,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004447.jpg'],
#  638: [' person',
#   ' chair',
#   ' motorbike',
#   nan,
#   nan,
#   31.7742392698987,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004849.jpg'],
#  639: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   37.00638726224365,
#   'high',
#   ' dog',
#   ' boat',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004188.jpg'],
#  640: [' person',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   29.77990661443428,
#   'high',
#   ' chair',
#   ' chair',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000381.jpg'],
#  641: [' person',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   33.31207272800427,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002758.jpg'],
#  642: [' person',
#   ' horse',
#   ' dog',
#   nan,
#   nan,
#   31.37245999871385,
#   'high',
#   ' horse',
#   ' sofa',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005270.jpg'],
#  643: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.397027824172856,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone1',
#   976,
#   '2008_004042.jpg'],
#  644: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.130898028557787,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003338.jpg'],
#  645: [' pottedplant',
#   ' tvmonitor',
#   ' cat',
#   nan,
#   nan,
#   31.67044719842205,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000488.jpg'],
#  646: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   32.014973550332165,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004646.jpg'],
#  647: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   32.97739588330027,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone2',
#   547,
#   '2010_006033.jpg'],
#  648: [' person',
#   ' diningtable',
#   ' bottle',
#   nan,
#   nan,
#   36.41404223766773,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002736.jpg'],
#  649: [' sofa',
#   ' bottle',
#   ' pottedplant',
#   ' tvmonitor',
#   ' chair',
#   33.937775623898794,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002814.jpg'],
#  650: [' pottedplant',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   34.96662806576853,
#   'high',
#   ' pottedplant',
#   ' dog',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000198.jpg'],
#  651: [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   35.92557187315038,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000321.jpg'],
#  652: [' car',
#   ' train',
#   nan,
#   nan,
#   nan,
#   30.20884285223731,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008681.jpg'],
#  653: [' person',
#   ' chair',
#   ' diningtable',
#   ' bottle',
#   nan,
#   33.82355011426018,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002789.jpg'],
#  654: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.51488582293181,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003490.jpg'],
#  655: [' sofa',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   31.26054000326653,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_001434.jpg'],
#  656: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   31.07062434195711,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003575.jpg'],
#  657: [' car',
#   ' bicycle',
#   ' person',
#   nan,
#   nan,
#   30.476929097619227,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004858.jpg'],
#  658: [' pottedplant',
#   ' sofa',
#   ' chair',
#   nan,
#   nan,
#   31.427287995992387,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_001021.jpg'],
#  659: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   34.04714690528091,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001991.jpg'],
#  660: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   33.33497246868347,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001335.jpg'],
#  661: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.675826944132364,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001205.jpg'],
#  662: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.59798168174263,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004014.jpg'],
#  663: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.497069987457937,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_003145.jpg'],
#  664: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.981598230274844,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003209.jpg'],
#  665: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.01566888749068,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005903.jpg'],
#  666: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.29867809750948,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone2',
#   620,
#   '2008_000501.jpg'],
#  667: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.39542994429513,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003679.jpg'],
#  668: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.16755806031274,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003170.jpg'],
#  669: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.513291905037027,
#   'low',
#   ' aeroplane',
#   ' bottle',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006564.jpg'],
#  670: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.03153744936175,
#   'low',
#   ' pottedplant',
#   ' dog',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000514.jpg'],
#  671: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.33155808066949,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002050.jpg'],
#  672: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.25588754749905,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003767.jpg'],
#  673: [' tvmonitor',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   20.155193047230767,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003287.jpg'],
#  674: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.757885363436266,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003993.jpg'],
#  675: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.48716672648194,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005437.jpg'],
#  676: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.68599364669666,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005735.jpg'],
#  677: [' sofa',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   16.69849859536183,
#   'low',
#   ' sofa',
#   ' sofa',
#   'Target Present',
#   'Critical',
#   'tone2',
#   532,
#   '2011_001198.jpg'],
#  678: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   18.281400610092522,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_001908.jpg'],
#  679: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.520476370843983,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005345.jpg'],
#  680: [' tvmonitor',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   20.21626352293297,
#   'low',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005054.jpg'],
#  681: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.890088651606888,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005728.jpg'],
#  682: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.239146135217897,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002582.jpg'],
#  683: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.084302537016953,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003911.jpg'],
#  684: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.350665469404078,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008263.jpg'],
#  685: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.731962722166625,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003369.jpg'],
#  686: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.02036796686756,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004339.jpg'],
#  687: [' dog',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   21.247629460380587,
#   'low',
#   ' dog',
#   ' dog',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001708.jpg'],
#  688: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.156547420300022,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001656.jpg'],
#  689: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.07468613183729,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005885.jpg'],
#  690: [' sofa',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   20.934059682149233,
#   'low',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000189.jpg'],
#  691: [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   17.242843490790587,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005869.jpg'],
#  692: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.885583923700768,
#   'low',
#   ' horse',
#   ' horse',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000613.jpg'],
#  693: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.53735353764835,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000716.jpg'],
#  694: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.120761243201123,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004791.jpg'],
#  695: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.051373291159546,
#   'low',
#   ' person',
#   ' person',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002700.jpg'],
#  696: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.876667793733738,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001546.jpg'],
#  697: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.264337675075122,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_001723.jpg'],
#  698: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   20.166020393270408,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002116.jpg'],
#  699: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.45316735456659,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000105.jpg'],
#  700: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.58416256718508,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004171.jpg'],
#  701: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   11.740304537002435,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003400.jpg'],
#  702: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.693372571654717,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007274.jpg'],
#  703: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.720728543179284,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003686.jpg'],
#  704: [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   16.65124246053083,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone1',
#   841,
#   '2009_004888.jpg'],
#  705: [' bottle',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   21.259829756421425,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000112.jpg'],
#  706: [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   17.516941478695085,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001613.jpg'],
#  707: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.505883447655105,
#   'low',
#   ' horse',
#   ' dog',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000912.jpg'],
#  708: [' person',
#   ' car',
#   nan,
#   nan,
#   nan,
#   18.390878339274188,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000189.jpg'],
#  709: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.358449022039405,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001367.jpg'],
#  710: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.272204751551552,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_005075.jpg'],
#  711: [' chair',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   19.7971714164348,
#   'low',
#   ' cat',
#   ' cat',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000661.jpg'],
#  712: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.181010736182625,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000523.jpg'],
#  713: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.755286187157022,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000183.jpg'],
#  714: [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.259900940752694,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006072.jpg'],
#  715: [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.77924938689554,
#   'low',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003709.jpg'],
#  716: [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.90085669678468,
#   'low',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000070.jpg'],
#  717: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.22948510797022,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001495.jpg'],
#  718: [' pottedplant',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   18.96772267222304,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001005.jpg'],
#  719: [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   19.901616892338367,
#   'low',
#   ' boat',
#   ' sofa',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_001406.jpg'],
#  720: [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.892389695505386,
#   'low',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000087.jpg'],
#  721: [' person',
#   ' chair',
#   ' diningtable',
#   ' bottle',
#   nan,
#   30.06059186196041,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004778.jpg'],
#  722: [' pottedplant',
#   ' bicycle',
#   ' bottle',
#   ' cat',
#   nan,
#   35.35378442994306,
#   'high',
#   ' cat',
#   ' car',
#   'Target Absent',
#   'Critical',
#   'tone2',
#   735,
#   '2008_000196.jpg'],
#  723: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.530489775112553,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000565.jpg'],
#  724: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.27265460253791,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005608.jpg'],
#  725: [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   30.93687927856223,
#   'high',
#   ' person',
#   ' aeroplane',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002482.jpg'],
#  726: [' person',
#   ' chair',
#   ' bird',
#   nan,
#   nan,
#   29.63012122697995,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001673.jpg'],
#  727: [' pottedplant',
#   ' person',
#   ' train',
#   nan,
#   nan,
#   29.10600637597598,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005996.jpg'],
#  728: [' tvmonitor',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   34.77634371447314,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000629.jpg'],
#  729: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.74888565488975,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000984.jpg'],
#  730: [' car',
#   ' bus',
#   ' person',
#   nan,
#   nan,
#   31.30513576919045,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004614.jpg'],
#  731: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   36.207394560965135,
#   'high',
#   ' car',
#   ' sofa',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000457.jpg'],
#  732: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   34.54414482156191,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002001.jpg'],
#  733: [' person',
#   ' chair',
#   ' diningtable',
#   ' bottle',
#   nan,
#   33.73452911680277,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_003066.jpg'],
#  734: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   29.26546246503357,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002555.jpg'],
#  735: [' car',
#   ' person',
#   ' bus',
#   nan,
#   nan,
#   35.0694191822407,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000982.jpg'],
#  736: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   31.31059992348976,
#   'high',
#   ' horse',
#   ' cat',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000628.jpg'],
#  737: [' chair',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   29.798629151951733,
#   'high',
#   ' cat',
#   ' cat',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003579.jpg'],
#  738: [' car',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   35.87217940794205,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000251.jpg'],
#  739: [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   28.91651536968804,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004991.jpg'],
#  740: [' car',
#   ' chair',
#   ' bicycle',
#   nan,
#   nan,
#   29.730810134821,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003378.jpg'],
#  741: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   32.66066395118465,
#   'high',
#   ' cat',
#   ' cat',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002472.jpg'],
#  742: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.088045927192198,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003283.jpg'],
#  743: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   35.66913245555085,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone2',
#   493,
#   '2010_001856.jpg'],
#  744: [' car',
#   ' bicycle',
#   ' person',
#   nan,
#   nan,
#   28.874416244148048,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005542.jpg'],
#  745: [' bus',
#   ' person',
#   ' car',
#   nan,
#   nan,
#   31.167936969796557,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005878.jpg'],
#  746: [' pottedplant',
#   ' car',
#   nan,
#   nan,
#   nan,
#   30.612693177580176,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000488.jpg'],
#  747: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   40.773121275105424,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007057.jpg'],
#  748: [' person',
#   ' train',
#   ' sofa',
#   nan,
#   nan,
#   31.65115644279944,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_001586.jpg'],
#  749: [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.98031114526287,
#   'high',
#   ' sofa',
#   ' chair',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008628.jpg'],
#  750: [' pottedplant',
#   ' person',
#   ' train',
#   nan,
#   nan,
#   29.323493073246585,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000916.jpg'],
#  751: [' person',
#   ' bicycle',
#   ' car',
#   nan,
#   nan,
#   31.577906396402632,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008210.jpg'],
#  752: [' pottedplant',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   29.04248886812048,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone1',
#   51,
#   '2009_004283.jpg'],
#  753: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.28123750737463,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005702.jpg'],
#  754: [' pottedplant',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   34.17783424769062,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000760.jpg'],
#  755: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.401451132133516,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000860.jpg'],
#  756: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.51535276170641,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004690.jpg'],
#  757: [' person',
#   ' bottle',
#   ' diningtable',
#   nan,
#   nan,
#   29.775484131000805,
#   'high',
#   ' bottle',
#   ' bottle',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006663.jpg'],
#  758: [' person',
#   ' boat',
# ...
#   'low',
#   ' chair',
#   ' horse',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004737.jpg'],
#  870: [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.965775321926717,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003329.jpg'],
#  871: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.633666738732224,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003659.jpg'],
#  872: [' chair',
#   ' diningtable',
#   nan,
#   nan,
#   nan,
#   18.11780279510061,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone1',
#   823,
#   '2011_002241.jpg'],
#  873: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   20.306835318139004,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003280.jpg'],
#  874: [' chair',
#   ' diningtable',
#   nan,
#   nan,
#   nan,
#   20.73514569060949,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_001271.jpg'],
#  875: [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.194433628678283,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002803.jpg'],
#  876: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.23535981155764,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000634.jpg'],
#  877: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.90844822407169,
#   'low',
#   ' bird',
#   ' bird',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001967.jpg'],
#  878: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.095995737676468,
#   'low',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_003309.jpg'],
#  879: [' pottedplant',
#   ' person',
#   nan,
#   nan,
#   nan,
#   13.786733463571188,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_001137.jpg'],
#  880: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.131411086471946,
#   'low',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002393.jpg'],
#  881: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.18915033705368,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000940.jpg'],
#  882: [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   19.244035875135978,
#   'low',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004270.jpg'],
#  883: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   20.712898768714968,
#   'low',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005046.jpg'],
#  884: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   12.433989779329734,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000123.jpg'],
#  885: [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.096237359535362,
#   'low',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002594.jpg'],
#  886: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.644417789905445,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002604.jpg'],
#  887: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.21004370358339,
#   'low',
#   ' boat',
#   ' boat',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001040.jpg'],
#  888: [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   18.642450428633328,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008083.jpg'],
#  889: [' pottedplant',
#   ' sofa',
#   ' chair',
#   nan,
#   nan,
#   18.511887801846186,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001694.jpg'],
#  890: [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.030178152384888,
#   'low',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004594.jpg'],
#  891: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.456101242175052,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000839.jpg'],
#  892: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.879557532788805,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002145.jpg'],
#  893: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   19.91230101528729,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008395.jpg'],
#  894: [' person',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   20.139877805151375,
#   'low',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002439.jpg'],
#  895: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.508881463934923,
#   'low',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_003074.jpg'],
#  896: [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.54050687002545,
#   'low',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002817.jpg'],
#  897: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.706122139777047,
#   'low',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000299.jpg'],
#  898: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.879634097368903,
#   'low',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004624.jpg'],
#  899: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.09625234571384,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004779.jpg'],
#  900: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.417039192791336,
#   'low',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003045.jpg'],
#  901: [' person',
#   ' boat',
#   ' car',
#   nan,
#   nan,
#   35.70470893485066,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002702.jpg'],
#  902: [' diningtable',
#   ' person',
#   ' chair',
#   ' dog',
#   ' bottle',
#   36.04012142826974,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007664.jpg'],
#  903: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   28.99541660743073,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_001345.jpg'],
#  904: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   33.494613420346774,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007143.jpg'],
#  905: [' person',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   37.05291171015417,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002603.jpg'],
#  906: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.065266395495016,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_002306.jpg'],
#  907: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   30.073041628958684,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007970.jpg'],
#  908: [' pottedplant',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   32.054269676274835,
#   'high',
#   ' pottedplant',
#   ' pottedplant',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000274.jpg'],
#  909: [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   30.958055456079503,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000705.jpg'],
#  910: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   32.20276402074853,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001880.jpg'],
#  911: [' pottedplant',
#   ' person',
#   ' chair',
#   ' dog',
#   ' bottle',
#   31.05804957013649,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001862.jpg'],
#  912: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.19357078875772,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone2',
#   843,
#   '2010_003943.jpg'],
#  913: [' pottedplant',
#   ' sofa',
#   ' chair',
#   ' diningtable',
#   ' tvmonitor',
#   29.247483266365705,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004661.jpg'],
#  914: [' sofa',
#   ' person',
#   ' tvmonitor',
#   nan,
#   nan,
#   31.14925641648057,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000434.jpg'],
#  915: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   28.936239221739456,
#   'high',
#   ' horse',
#   ' horse',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006912.jpg'],
#  916: [' person',
#   ' bird',
#   ' boat',
#   nan,
#   nan,
#   31.913409738647122,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_001001.jpg'],
#  917: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.892125506726913,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007250.jpg'],
#  918: [' pottedplant',
#   ' person',
#   ' chair',
#   ' diningtable',
#   nan,
#   31.520687613930374,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005519.jpg'],
#  919: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   28.838956354168435,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_001965.jpg'],
#  920: [' pottedplant',
#   ' person',
#   ' chair',
#   ' motorbike',
#   ' boat',
#   31.58048990210689,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Critical',
#   'tone2',
#   210,
#   '2009_003351.jpg'],
#  921: [' person',
#   ' train',
#   ' car',
#   nan,
#   nan,
#   31.026856988880144,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000865.jpg'],
#  922: [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   32.14242713491097,
#   'high',
#   ' dog',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000074.jpg'],
#  923: [' bird',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   29.314233597971626,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006481.jpg'],
#  924: [' tvmonitor',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   29.993781428251964,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006062.jpg'],
#  925: [' sofa',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   34.56160823603891,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000704.jpg'],
#  926: [' person',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   29.867994035114002,
#   'high',
#   ' cat',
#   ' car',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002278.jpg'],
#  927: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.81492031357475,
#   'high',
#   ' bird',
#   ' bird',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002350.jpg'],
#  928: [' person',
#   ' diningtable',
#   ' bottle',
#   nan,
#   nan,
#   36.156012963588545,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003635.jpg'],
#  929: [' person',
#   ' motorbike',
#   nan,
#   nan,
#   nan,
#   31.07685831357417,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005572.jpg'],
#  930: [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   33.26176817697461,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_004763.jpg'],
#  931: [' sofa',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   30.346694199538174,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008470.jpg'],
#  932: [' car',
#   ' bicycle',
#   nan,
#   nan,
#   nan,
#   28.730946256992283,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004364.jpg'],
#  933: [' person',
#   ' motorbike',
#   nan,
#   nan,
#   nan,
#   32.12330736234191,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002774.jpg'],
#  934: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.182430259996877,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_006461.jpg'],
#  935: [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   32.06509585553637,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000697.jpg'],
#  936: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   33.96835298009745,
#   'high',
#   ' horse',
#   ' pottedplant',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008500.jpg'],
#  937: [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   35.97296008400705,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004414.jpg'],
#  938: [' person',
#   ' chair',
#   ' tvmonitor',
#   nan,
#   nan,
#   28.894989564027235,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_002509.jpg'],
#  939: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   33.702921971939176,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_008229.jpg'],
#  940: [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.084159041893106,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005818.jpg'],
#  941: [' bus',
#   ' car',
#   nan,
#   nan,
#   nan,
#   39.116317372229396,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_001118.jpg'],
#  942: [' pottedplant',
#   ' person',
#   ' bottle',
#   ' diningtable',
#   nan,
#   36.665582819269645,
#   'high',
#   ' pottedplant',
#   ' pottedplant',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004794.jpg'],
#  943: [' pottedplant',
#   ' car',
#   ' chair',
#   ' bicycle',
#   ' person',
#   30.133244112833108,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_003729.jpg'],
#  944: [' person',
#   ' dog',
#   ' car',
#   nan,
#   nan,
#   33.09488500291814,
#   'high',
#   ' dog',
#   ' horse',
#   'Target Absent',
#   'Critical',
#   'tone2',
#   467,
#   '2008_006844.jpg'],
#  945: [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.92721034000856,
#   'high',
#   ' horse',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003461.jpg'],
#  946: [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   34.28798865304669,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002887.jpg'],
#  947: [' person',
#   ' chair',
#   ' diningtable',
#   ' bottle',
#   nan,
#   29.62291427984228,
#   'high',
#   ' bottle',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_004154.jpg'],
#  948: [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   30.24293720929956,
#   'high',
#   ' aeroplane',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_005106.jpg'],
#  949: [' bird',
#   ' cow',
#   nan,
#   nan,
#   nan,
#   30.96122100405093,
#   'high',
#   ' bird',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2011_000548.jpg'],
#  950: [' pottedplant',
#   ' person',
#   ' chair',
#   ' diningtable',
#   nan,
#   37.710719022258736,
#   'high',
#   ' pottedplant',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_000041.jpg'],
#  951: [' chair',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   35.925064893420085,
#   'high',
#   ' chair',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004487.jpg'],
#  952: [' person',
#   ' car',
#   nan,
#   nan,
#   nan,
#   28.839741748612518,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_005472.jpg'],
#  953: [' boat',
#   ' cow',
#   nan,
#   nan,
#   nan,
#   29.65940712433473,
#   'high',
#   ' boat',
#   ' boat',
#   'Target Present',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002709.jpg'],
#  954: [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   34.96752773409758,
#   'high',
#   ' boat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_002620.jpg'],
#  955: [' person',
#   ' bicycle',
#   ' car',
#   nan,
#   nan,
#   30.89167221982163,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_004482.jpg'],
#  956: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   35.696632302033265,
#   'high',
#   ' person',
#   ' dog',
#   'Target Absent',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_002725.jpg'],
#  957: [' car',
#   ' motorbike',
#   ' person',
#   nan,
#   nan,
#   31.40872195535423,
#   'high',
#   ' car',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_003844.jpg'],
#  958: [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.30670761720366,
#   'high',
#   ' cat',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2010_000815.jpg'],
#  959: [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   31.051868344918073,
#   'high',
#   ' sofa',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2008_007091.jpg'],
#  960: [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.63929631121964,
#   'high',
#   ' person',
#   'NA',
#   'No Target',
#   'Normal',
#   'No tone',
#   -999,
#   '2009_000067.jpg']}

# %%
df = pd.DataFrame.from_dict(trials)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','image_name','block']
df.TS = df.TS.astype('float')
df.to_csv(mypath + '../Config/randomization_1.csv')

# %%
len(trials)

# %%
trials

# %%
df

# %%
possibl

# %%
#with open('../Config/images.csv', 'wb') as myfile:
#    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
#    
#    for i in range(16):
#        wr.writerow(block[i])
#        #wr.writerow(blocks_sequences_list[i])
#
#with open('../Config/probes.csv', 'wb') as myfile:
#    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
#    
#    for i in range(16):
#        wr.writerow(probe_series[i])
