# %%
import pandas as pd
import numpy as np
import random
import csv
#%pdb
#mypath = ('E:/OneDrive - University College London/Random_probes_last/Luca/')
mypath = 'C:/Users/nilli lab/Desktop/load/analysis/'

# %%
import random
probe_series = []
critical_series = []

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
print len(target_present)

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
print len(target_present)
for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
probe_trials_1 = target_present_counter + target_absent_counter
critical_trials_1 = critical_trials
print len(probe_trials_1)
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# 24
# 36
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  12
# len(critical_trials):  24
# 72

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 392
# -------------------

# %%
def block_low_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
    
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_low_2():
# Pick 5 present probes and 4 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_2():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
block_high_1()
block_low_1()
block_low_2()
block_high_2()
block_low_1()
block_high_1()
block_high_2()
block_low_2()
# Out:
# [' sofa', ' chair', ' bottle', ' person', nan, 29.05176679498621, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' person', ' bottle', ' car', nan, nan, 34.31316104129318, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' person', ' bird', nan, nan, nan, 29.657389969329227, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' person', ' bottle', ' diningtable', nan, nan, 29.775484131000805, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' bus', ' boat', ' car', nan, nan, 34.403914620094966, 'high', ' boat', ' dog', 'Target Absent', 'Normal']
# [' pottedplant', ' bicycle', ' bottle', ' cat', nan, 35.35378442994306, 'high', ' cat', ' person', 'Target Absent', 'Normal']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', ' bottle', 'Target Absent', 'Normal']
# [' bird', ' boat', nan, nan, nan, 29.314233597971626, 'high', ' bird', ' horse', 'Target Absent', 'Normal']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 34.17783424769062, 'high', ' pottedplant', ' horse', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 29.26546246503357, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' bicycle', ' car', nan, nan, 31.577906396402632, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 32.06509585553637, 'high', ' bird', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  48
# Normal used: 48
# ---------------------------------------------------
# [' car', nan, nan, nan, nan, 19.4399393845732, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' chair', ' diningtable', nan, nan, nan, 18.11780279510061, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' sofa', nan, nan, nan, 13.414126280812802, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 19.264337675075122, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' bottle', nan, nan, nan, nan, 20.96364307633711, 'low', ' bottle', ' aeroplane', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 19.706122139777047, 'low', ' bird', ' dog', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.120761243201123, 'low', ' aeroplane', ' sofa', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 18.29867809750948, 'low', ' car', ' boat', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 19.095995737676468, 'low', ' aeroplane', ' person', 'Target Absent', 'Critical']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  1
# List of critical trials without probe:
# [' bottle', nan, nan, nan, nan, 14.593336877343006, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', nan, nan, nan, 13.786733463571188, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  97
# Normal used: 97
# ---------------------------------------------------
# [' cat', nan, nan, nan, nan, 13.68599364669666, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 18.03153744936175, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' bottle', nan, nan, nan, nan, 20.965775321926717, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 18.523024266211753, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 12.53657278412077, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 19.24976137409617, 'low', ' pottedplant', ' car', 'Target Absent', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 16.520476370843983, 'low', ' pottedplant', ' person', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 19.735592352687934, 'low', ' bird', ' pottedplant', 'Target Absent', 'Normal']
# [' dog', nan, nan, nan, nan, 19.570662256086155, 'low', ' dog', ' sofa', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  0
# List of critical trials without probe:
# [' pottedplant', ' sofa', ' chair', nan, nan, 18.511887801846186, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 10.236635760901883, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 18.01566888749068, 'low', ' bird', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  145
# Normal used: 145
# ---------------------------------------------------
# [' pottedplant', ' person', ' bicycle', ' car', nan, 33.367152749801264, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Critical']
# [' cat', nan, nan, nan, nan, 32.66066395118465, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' tvmonitor', ' chair', nan, nan, nan, 32.38481414164753, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 29.201869461183065, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 33.64739800555661, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' chair', ' motorbike', ' boat', 31.58048990210689, 'high', ' boat', ' person', 'Target Absent', 'Critical']
# [' person', ' chair', ' bottle', ' tvmonitor', nan, 34.633056090581924, 'high', ' bottle', ' boat', 'Target Absent', 'Normal']
# [' sofa', ' person', nan, nan, nan, 31.463677231105994, 'high', ' sofa', ' dog', 'Target Absent', 'Normal']
# [' pottedplant', ' dog', nan, nan, nan, 29.851834352354174, 'high', ' dog', ' car', 'Target Absent', 'Normal']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  2
# List of critical trials without probe:
# [' car', ' aeroplane', nan, nan, nan, 32.224520766602424, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  195
# Normal used: 195
# ---------------------------------------------------
# [' person', nan, nan, nan, nan, 19.675826944132364, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 9.57686770873812, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' pottedplant', ' sofa', nan, nan, nan, 18.96772267222304, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' person', ' bottle', nan, nan, nan, 19.86909924741182, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.559862456799, 'low', ' aeroplane', ' horse', 'Target Absent', 'Normal']
# [' dog', nan, nan, nan, nan, 13.411221053439446, 'low', ' dog', ' bird', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 17.33155808066949, 'low', ' boat', ' car', 'Target Absent', 'Normal']
# [' horse', nan, nan, nan, nan, 19.803898838362514, 'low', ' horse', ' bottle', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 13.90844822407169, 'low', ' bird', ' boat', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  0
# List of critical trials without probe:
# [' bottle', ' dog', ' diningtable', nan, nan, 21.034646910874567, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 18.505883447655105, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' car', ' person', nan, nan, nan, 20.695714607410885, 'low', ' car', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  243
# Normal used: 243
# ---------------------------------------------------
# [' car', ' aeroplane', nan, nan, nan, 37.93755165753997, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' person', ' dog', ' car', nan, nan, 33.09488500291814, 'high', ' dog', ' dog', 'Target Present', 'Critical']
# [' tvmonitor', ' chair', nan, nan, nan, 34.77634371447314, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' chair', ' cat', nan, nan, nan, 29.798629151951733, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' sofa', ' person', nan, nan, nan, 31.051868344918073, 'high', ' sofa', ' cat', 'Target Absent', 'Critical']
# [' person', ' dog', nan, nan, nan, 30.657341600370845, 'high', ' dog', ' aeroplane', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 31.88587780040415, 'high', ' aeroplane', ' boat', 'Target Absent', 'Normal']
# [' person', ' chair', ' diningtable', ' bottle', nan, 33.73452911680277, 'high', ' chair', ' sofa', 'Target Absent', 'Critical']
# [' pottedplant', ' person', ' train', nan, nan, 29.10600637597598, 'high', ' pottedplant', ' bird', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  3
# List of critical trials without probe:
# len(normal_no_probe_used):  294
# Normal used: 294
# ---------------------------------------------------
# [' person', nan, nan, nan, nan, 30.74888565488975, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 31.520687613930374, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Critical']
# [' person', ' boat', nan, nan, nan, 30.384187271419634, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' chair', ' bottle', ' diningtable', nan, 35.13485651284549, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 30.130898028557787, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 28.936239221739456, 'high', ' horse', ' pottedplant', 'Target Absent', 'Normal']
# [' person', ' chair', nan, nan, nan, 37.05291171015417, 'high', ' person', ' chair', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 32.480531856762035, 'high', ' horse', ' car', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 28.99541660743073, 'high', ' aeroplane', ' sofa', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  1
# List of critical trials without probe:
# [' pottedplant', ' person', ' train', nan, nan, 29.323493073246585, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 37.22381580448725, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  343
# Normal used: 343
# ---------------------------------------------------
# [' chair', ' cat', nan, nan, nan, 17.570654058012458, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' sofa', ' dog', nan, nan, nan, 16.142562620916582, 'low', ' dog', ' dog', 'Target Present', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 13.440366765570474, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 20.885583923700768, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 20.463883689453848, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 16.86296621161062, 'low', ' boat', ' dog', 'Target Absent', 'Normal']
# [' dog', nan, nan, nan, nan, 19.993102773679155, 'low', ' dog', ' cat', 'Target Absent', 'Normal']
# [' sofa', ' dog', nan, nan, nan, 20.934059682149233, 'low', ' sofa', ' chair', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 18.879557532788805, 'low', ' person', ' horse', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  1
# List of critical trials without probe:
# [' person', ' boat', nan, nan, nan, 19.194815950035924, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 20.166020393270408, 'low', ' person', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  392
# Normal used: 392
# ---------------------------------------------------

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
print probes[0]
# Out:
# ['2008_001333.jpg', '2010_002127.jpg', '2010_003724.jpg', '2008_006663.jpg', '2008_005720.jpg', '2008_000196.jpg', '2010_005270.jpg', '2008_006481.jpg', '2009_000760.jpg']

# %%
probe_series = []
critical_series = []

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
def building_the_church(w):
    while True:    
        while True:
            a = [random.randint(1,60) for r in xrange(9)]
            if sum(a) <= 60:
                break
        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]
        print 'new_list_1: ',new_list_1
        #print sum(a)

        while True:
            while True:
                a = [random.randint(1,60) for r in xrange(3-w)]
                if sum(a) <= 60: 
                    break
            print sum(a)
            new_list_2 = []
            acc = 0
            for i in a:
                acc = acc + i
                new_list_2.append(acc)
            print new_list_2
            two_gap = []
            for i in range(2-w): # add "-w"
                two_gap.append(new_list_2[i+1] - new_list_2[i])
                print two_gap
            if 1 not in two_gap and 2 not in two_gap:
                break
        print new_list_2

        container = []
        for i in new_list_2:
            sequence = [i, i+1, i+2]
            #print sequence
            for element in sequence:
                if element in new_list_1:
                    container.append(element)
        #print len(container)
        print new_list_2
        if len(container) == 0:
            break
    print '---------------------------'
    probe_series.append(new_list_1)
    critical_series.append(new_list_2)
    print new_list_1
    print new_list_2
    return

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [5, 8, 11, 30, 31, 35, 38, 55, 56]
# 45
# [4, 36, 45]
# [32]
# [32, 9]
# [4, 36, 45]
# [4, 36, 45]
# new_list_1:  [11, 16, 19, 23, 24, 25, 31, 33, 45]
# 56
# [15, 25, 56]
# [10]
# [10, 31]
# [15, 25, 56]
# [15, 25, 56]
# new_list_1:  [2, 6, 8, 16, 19, 29, 35, 41, 54]
# 43
# [8, 41, 43]
# [33]
# [33, 2]
# 57
# [4, 18, 57]
# [14]
# [14, 39]
# [4, 18, 57]
# [4, 18, 57]
# new_list_1:  [0, 10, 20, 21, 30, 34, 36, 56, 58]
# 38
# [11, 26, 38]
# [15]
# [15, 12]
# [11, 26, 38]
# [11, 26, 38]
# ---------------------------
# [0, 10, 20, 21, 30, 34, 36, 56, 58]
# [11, 26, 38]
# new_list_1:  [0, 6, 12, 27, 36, 39, 41, 44, 51]
# 46
# [38, 46]
# [8]
# [38, 46]
# [38, 46]
# new_list_1:  [8, 19, 21, 25, 30, 34, 38, 39, 55]
# 47
# [15, 47]
# [32]
# [15, 47]
# [15, 47]
# ---------------------------
# [8, 19, 21, 25, 30, 34, 38, 39, 55]
# [15, 47]
# new_list_1:  [7, 13, 24, 37, 50, 53, 54, 56, 57]
# 51
# [2, 46, 51]
# [44]
# [44, 5]
# [2, 46, 51]
# [2, 46, 51]
# new_list_1:  [5, 6, 15, 24, 46, 51, 54, 58, 59]
# 56
# [12, 42, 56]
# [30]
# [30, 14]
# [12, 42, 56]
# [12, 42, 56]
# new_list_1:  [0, 16, 18, 19, 30, 34, 40, 42, 48]
# 42
# [31, 32, 42]
# [1]
# [1, 10]
# 31
# [2, 12, 31]
# [10]
# [10, 19]
# [2, 12, 31]
# [2, 12, 31]
# ---------------------------
# [0, 16, 18, 19, 30, 34, 40, 42, 48]
# [2, 12, 31]
# new_list_1:  [0, 9, 10, 11, 23, 31, 52, 53, 56]
# 1
# [1]
# [1]
# [1]
# ---------------------------
# [0, 9, 10, 11, 23, 31, 52, 53, 56]
# [1]
# new_list_1:  [2, 4, 21, 26, 36, 39, 41, 50, 54]
# 60
# [40, 42, 60]
# [2]
# [2, 18]
# 28
# [12, 20, 28]
# [8]
# [8, 8]
# [12, 20, 28]
# [12, 20, 28]
# new_list_1:  [13, 20, 30, 32, 35, 39, 45, 46, 48]
# 41
# [4, 31, 41]
# [27]
# [27, 10]
# [4, 31, 41]
# [4, 31, 41]
# new_list_1:  [2, 11, 12, 23, 42, 53, 54, 57, 59]
# 57
# [31, 51, 57]
# [20]
# [20, 6]
# [31, 51, 57]
# [31, 51, 57]
# new_list_1:  [0, 3, 39, 43, 46, 54, 55, 56, 59]
# 43
# [11, 14, 43]
# [3]
# [3, 29]
# [11, 14, 43]
# [11, 14, 43]
# new_list_1:  [3, 5, 7, 9, 10, 16, 18, 24, 32]
# 59
# [18, 21, 59]
# [3]
# [3, 38]
# [18, 21, 59]
# [18, 21, 59]
# new_list_1:  [12, 20, 25, 28, 41, 46, 47, 52, 55]
# 38
# [16, 37, 38]
# [21]
# [21, 1]
# 45
# [7, 36, 45]
# [29]
# [29, 9]
# [7, 36, 45]
# [7, 36, 45]
# new_list_1:  [7, 14, 16, 25, 29, 31, 32, 43, 48]
# 57
# [32, 52, 57]
# [20]
# [20, 5]
# [32, 52, 57]
# [32, 52, 57]
# new_list_1:  [6, 8, 9, 32, 45, 48, 54, 56, 57]
# 48
# [12, 38, 48]
# [26]
# [26, 10]
# [12, 38, 48]
# [12, 38, 48]
# new_list_1:  [0, 8, 12, 17, 18, 25, 40, 41, 42]
# 36
# [4, 35, 36]
# [31]
# [31, 1]
# 42
# [11, 29, 42]
# [18]
# [18, 13]
# [11, 29, 42]
# [11, 29, 42]
# new_list_1:  [7, 14, 18, 28, 29, 38, 43, 56, 57]
# 24
# [6, 23, 24]
# [17]
# [17, 1]
# 44
# [6, 23, 44]
# [17]
# [17, 21]
# [6, 23, 44]
# [6, 23, 44]
# new_list_1:  [10, 16, 17, 19, 28, 31, 41, 44, 51]
# 25
# [13, 24, 25]
# [11]
# [11, 1]
# 59
# [47, 56, 59]
# [9]
# [9, 3]
# [47, 56, 59]
# [47, 56, 59]
# ---------------------------
# [10, 16, 17, 19, 28, 31, 41, 44, 51]
# [47, 56, 59]
# new_list_1:  [1, 3, 8, 9, 12, 38, 42, 54, 58]
# 0
# []
# []
# []
# ---------------------------
# [1, 3, 8, 9, 12, 38, 42, 54, 58]
# []
# new_list_1:  [5, 6, 13, 15, 18, 21, 51, 52, 56]
# 56
# [6, 56]
# [50]
# [6, 56]
# [6, 56]
# new_list_1:  [2, 28, 35, 37, 42, 48, 49, 53, 59]
# 35
# [29, 35]
# [6]
# [29, 35]
# [29, 35]
# new_list_1:  [5, 10, 14, 22, 24, 37, 49, 50, 55]
# 54
# [52, 54]
# [2]
# 39
# [2, 39]
# [37]
# [2, 39]
# [2, 39]
# ---------------------------
# [5, 10, 14, 22, 24, 37, 49, 50, 55]
# [2, 39]
# new_list_1:  [0, 6, 7, 10, 24, 30, 49, 55, 57]
# 32
# [11, 32]
# [21]
# [11, 32]
# [11, 32]
# ---------------------------
# [0, 6, 7, 10, 24, 30, 49, 55, 57]
# [11, 32]

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])
# Out:
# 0
# 0 1 60
# 1
# 1 2 60
# 2
# 2 3 60
# 3
# 3 4 60
# 4
# 4 5 60
# 5
# 5 6 60
# 6
# 6 7 60
# 7
# 7 8 60

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 392
# 392
# True
# 36
# 36
# True
# 36
# 36
# True
# 24
# 16
# 8

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)
# Out:
# ['tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1']

# %%
df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df.TS = df.TS.astype('float')
df.to_csv(mypath + '../Config/randomization_1.csv')
block_1_half = block
probe_series_1_half = probe_series

# %%
##################
# SECOND ITERATION#
##################

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present \
                and trial not in probe_trials_1:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present \
                and trial not in probe_trials_1:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and intermediate not in critical_trials_1 \
                and intermediate not in probe_trials_1:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  12
# len(critical_trials):  24

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 388
# -------------------

# %%
block_high_1()
block_low_1()
block_low_2()
block_high_2()
block_low_1()
block_high_1()
block_high_2()
block_low_2()
# Out:
# [' person', ' horse', nan, nan, nan, 30.92721034000856, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 31.51488582293181, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' tvmonitor', ' sofa', ' bottle', ' person', nan, 29.608026491553932, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' car', ' dog', ' person', nan, nan, 29.763552134631723, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 31.96963432435441, 'high', ' horse', ' pottedplant', 'Target Absent', 'Normal']
# [' car', ' aeroplane', nan, nan, nan, 35.87217940794205, 'high', ' aeroplane', ' sofa', 'Target Absent', 'Normal']
# [' car', ' bus', ' person', nan, nan, 31.30513576919045, 'high', ' car', ' chair', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 32.020689907436754, 'high', ' aeroplane', ' cat', 'Target Absent', 'Normal']
# [' person', ' diningtable', ' bottle', nan, nan, 36.156012963588545, 'high', ' bottle', ' boat', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  0
# List of critical trials without probe:
# [' sofa', ' chair', ' person', nan, nan, 30.035339131770247, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 31.892125506726913, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' tvmonitor', ' cat', nan, nan, 31.67044719842205, 'high', ' cat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  48
# Normal used: 48
# ---------------------------------------------------
# [' cat', nan, nan, nan, nan, 15.633666738732224, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 17.190044648210367, 'low', ' dog', ' dog', 'Target Present', 'Critical']
# [' horse', nan, nan, nan, nan, 19.234401336670953, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 17.102590259239356, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' chair', ' dog', nan, nan, nan, 13.836710152206384, 'low', ' chair', ' horse', 'Target Absent', 'Normal']
# [' chair', ' diningtable', ' bottle', nan, nan, 20.038119878562025, 'low', ' bottle', ' chair', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.272204751551552, 'low', ' aeroplane', ' bird', 'Target Absent', 'Normal']
# [' car', ' dog', ' person', nan, nan, 21.020159211351668, 'low', ' car', ' cat', 'Target Absent', 'Normal']
# [' chair', nan, nan, nan, nan, 13.727438736718454, 'low', ' chair', ' person', 'Target Absent', 'Critical']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  2
# List of critical trials without probe:
# [' car', ' aeroplane', nan, nan, nan, 16.811685000593723, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  98
# Normal used: 98
# ---------------------------------------------------
# [' boat', nan, nan, nan, nan, 20.470663952413528, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 19.803898838362514, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 18.523024266211753, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' person', ' bottle', nan, nan, nan, 19.86909924741182, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 21.217669901647128, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 19.598131175056185, 'low', ' horse', ' cat', 'Target Absent', 'Normal']
# [' person', ' boat', nan, nan, nan, 16.146154777978307, 'low', ' boat', ' chair', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 17.497069987457937, 'low', ' bird', ' pottedplant', 'Target Absent', 'Normal']
# [' person', ' sofa', nan, nan, nan, 20.707877775353552, 'low', ' sofa', ' bottle', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  0
# List of critical trials without probe:
# [' pottedplant', nan, nan, nan, nan, 21.25588754749905, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 19.107696549923208, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' sofa', nan, nan, nan, nan, 17.0559093734335, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  146
# Normal used: 146
# ---------------------------------------------------
# [' bird', nan, nan, nan, nan, 29.176311484999022, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 35.94715000296663, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' cat', nan, nan, nan, 29.77854418273715, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' person', ' boat', nan, nan, nan, 29.006457456633935, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 30.065266395495016, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' bicycle', ' boat', nan, nan, 34.31905160776113, 'high', ' boat', ' dog', 'Target Absent', 'Normal']
# [' sofa', ' chair', ' person', nan, nan, 34.56160823603891, 'high', ' person', ' aeroplane', 'Target Absent', 'Normal']
# [' person', ' bottle', nan, nan, nan, 28.91651536968804, 'high', ' bottle', ' person', 'Target Absent', 'Normal']
# [' sofa', ' person', nan, nan, nan, 33.27958235579427, 'high', ' sofa', ' car', 'Target Absent', 'Normal']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  0
# List of critical trials without probe:
# [' person', ' aeroplane', nan, nan, nan, 32.014973550332165, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' sofa', ' chair', ' diningtable', nan, nan, 30.346694199538174, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 33.96835298009745, 'high', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  194
# Normal used: 194
# ---------------------------------------------------
# [' car', nan, nan, nan, nan, 17.731696099482228, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 19.675826944132364, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 21.005917005737068, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' sofa', nan, nan, nan, nan, 17.316646037114566, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 18.590456430582357, 'low', ' horse', ' bottle', 'Target Absent', 'Normal']
# [' horse', nan, nan, nan, nan, 19.76483640822989, 'low', ' horse', ' bird', 'Target Absent', 'Normal']
# [' bottle', nan, nan, nan, nan, 19.096237359535362, 'low', ' bottle', ' aeroplane', 'Target Absent', 'Normal']
# [' bottle', nan, nan, nan, nan, 15.713624833374665, 'low', ' bottle', ' dog', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 20.757885363436266, 'low', ' bird', ' boat', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  0
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 18.720728543179284, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 19.91230101528729, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 19.75925599841011, 'low', ' car', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  242
# Normal used: 242
# ---------------------------------------------------
# [' car', ' bicycle', nan, nan, nan, 28.730946256992283, 'high', ' car', ' car', 'Target Present', 'Critical']
# [' sofa', ' chair', nan, nan, nan, 31.26054000326653, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 30.48036175658957, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' chair', ' dog', ' diningtable', nan, nan, 29.611440342795753, 'high', ' dog', ' dog', 'Target Present', 'Critical']
# [' bird', nan, nan, nan, nan, 30.068803282805252, 'high', ' bird', ' cat', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 37.706201599515055, 'high', ' boat', ' pottedplant', 'Target Absent', 'Normal']
# [' car', ' boat', ' person', nan, nan, 32.75926741884376, 'high', ' boat', ' chair', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' dog', nan, nan, 30.00737433193205, 'high', ' dog', ' bird', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 35.66913245555085, 'high', ' horse', ' bottle', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  2
# List of critical trials without probe:
# [' person', ' aeroplane', nan, nan, nan, 30.073041628958684, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  292
# Normal used: 292
# ---------------------------------------------------
# [' person', ' train', ' sofa', nan, nan, 31.65115644279944, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' person', ' dog', ' car', nan, nan, 33.09488500291814, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' pottedplant', ' car', ' chair', ' bicycle', ' person', 30.133244112833108, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' pottedplant', ' car', nan, nan, nan, 30.612693177580176, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 33.26176817697461, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' dog', nan, nan, nan, 32.959390221443385, 'high', ' dog', ' horse', 'Target Absent', 'Normal']
# [' car', ' motorbike', ' person', nan, nan, 31.40872195535423, 'high', ' car', ' bottle', 'Target Absent', 'Normal']
# [' person', ' dog', nan, nan, nan, 30.20203583105944, 'high', ' dog', ' aeroplane', 'Target Absent', 'Normal']
# [' car', ' train', nan, nan, nan, 30.20884285223731, 'high', ' car', ' bird', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  0
# List of critical trials without probe:
# [' diningtable', ' person', ' chair', ' dog', ' bottle', 36.04012142826974, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 31.26103763923315, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' dog', nan, 34.099790178372324, 'high', ' dog', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  340
# Normal used: 340
# ---------------------------------------------------
# [' person', ' horse', nan, nan, nan, 19.187546074203674, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' person', ' car', nan, nan, nan, 18.390878339274188, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' person', ' boat', nan, nan, nan, 19.901616892338367, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 18.000361854332464, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' sofa', ' dog', nan, nan, nan, 19.188834185415878, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 18.02036796686756, 'low', ' dog', ' car', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 20.131411086471946, 'low', ' boat', ' pottedplant', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 16.456101242175052, 'low', ' cat', ' aeroplane', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 20.074715872568312, 'low', ' boat', ' sofa', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 20.821731630747827, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', nan, nan, nan, 17.242843490790587, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 20.084302537016953, 'low', ' boat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  388
# Normal used: 388
# ---------------------------------------------------

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
probe_series = []
critical_series = []

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [11, 13, 16, 20, 23, 35, 38, 49, 54]
# 50
# [34, 44, 50]
# [10]
# [10, 6]
# [34, 44, 50]
# [34, 44, 50]
# new_list_1:  [5, 7, 13, 18, 23, 25, 31, 45, 54]
# 19
# [3, 6, 19]
# [3]
# [3, 13]
# [3, 6, 19]
# [3, 6, 19]
# new_list_1:  [2, 24, 28, 32, 34, 44, 51, 52, 58]
# 30
# [24, 29, 30]
# [5]
# [5, 1]
# 53
# [1, 35, 53]
# [34]
# [34, 18]
# [1, 35, 53]
# [1, 35, 53]
# new_list_1:  [1, 2, 25, 28, 32, 38, 43, 57, 58]
# 44
# [16, 33, 44]
# [17]
# [17, 11]
# [16, 33, 44]
# [16, 33, 44]
# ---------------------------
# [1, 2, 25, 28, 32, 38, 43, 57, 58]
# [16, 33, 44]
# new_list_1:  [10, 18, 24, 41, 43, 44, 54, 55, 58]
# 16
# [16]
# [16]
# [16]
# new_list_1:  [4, 5, 8, 14, 24, 30, 36, 38, 44]
# 45
# [45]
# [45]
# [45]
# ---------------------------
# [4, 5, 8, 14, 24, 30, 36, 38, 44]
# [45]
# new_list_1:  [2, 35, 36, 40, 42, 45, 46, 52, 54]
# 60
# [48, 51, 60]
# [3]
# [3, 9]
# [48, 51, 60]
# [48, 51, 60]
# new_list_1:  [8, 13, 14, 16, 29, 35, 36, 58, 59]
# 58
# [26, 56, 58]
# [30]
# [30, 2]
# 56
# [14, 42, 56]
# [28]
# [28, 14]
# [14, 42, 56]
# [14, 42, 56]
# new_list_1:  [1, 6, 14, 33, 34, 41, 46, 55, 58]
# 41
# [6, 20, 41]
# [14]
# [14, 21]
# [6, 20, 41]
# [6, 20, 41]
# new_list_1:  [2, 4, 15, 29, 35, 45, 46, 54, 55]
# 51
# [22, 29, 51]
# [7]
# [7, 22]
# [22, 29, 51]
# [22, 29, 51]
# new_list_1:  [2, 3, 6, 16, 28, 30, 33, 41, 51]
# 48
# [1, 27, 48]
# [26]
# [26, 21]
# [1, 27, 48]
# [1, 27, 48]
# new_list_1:  [4, 13, 34, 42, 44, 47, 53, 56, 58]
# 41
# [23, 38, 41]
# [15]
# [15, 3]
# [23, 38, 41]
# [23, 38, 41]
# new_list_1:  [3, 19, 21, 32, 43, 44, 50, 52, 57]
# 56
# [24, 41, 56]
# [17]
# [17, 15]
# [24, 41, 56]
# [24, 41, 56]
# new_list_1:  [1, 9, 10, 26, 29, 30, 49, 50, 54]
# 48
# [22, 47, 48]
# [25]
# [25, 1]
# 59
# [28, 48, 59]
# [20]
# [20, 11]
# [28, 48, 59]
# [28, 48, 59]
# new_list_1:  [2, 3, 15, 17, 24, 28, 31, 35, 49]
# 57
# [1, 38, 57]
# [37]
# [37, 19]
# [1, 38, 57]
# [1, 38, 57]
# new_list_1:  [6, 9, 14, 30, 36, 37, 44, 53, 58]
# 53
# [13, 43, 53]
# [30]
# [30, 10]
# [13, 43, 53]
# [13, 43, 53]
# new_list_1:  [2, 5, 29, 31, 32, 33, 34, 51, 57]
# 25
# [15, 16, 25]
# [1]
# [1, 9]
# 37
# [4, 35, 37]
# [31]
# [31, 2]
# 46
# [5, 13, 46]
# [8]
# [8, 33]
# [5, 13, 46]
# [5, 13, 46]
# new_list_1:  [11, 17, 24, 25, 31, 36, 44, 48, 51]
# 55
# [34, 46, 55]
# [12]
# [12, 9]
# [34, 46, 55]
# [34, 46, 55]
# new_list_1:  [1, 4, 7, 11, 17, 30, 39, 42, 50]
# 54
# [39, 51, 54]
# [12]
# [12, 3]
# [39, 51, 54]
# [39, 51, 54]
# new_list_1:  [8, 12, 17, 19, 32, 34, 46, 51, 57]
# 52
# [9, 27, 52]
# [18]
# [18, 25]
# [9, 27, 52]
# [9, 27, 52]
# ---------------------------
# [8, 12, 17, 19, 32, 34, 46, 51, 57]
# [9, 27, 52]
# new_list_1:  [14, 19, 24, 27, 28, 29, 30, 54, 57]
# 29
# [3, 5, 29]
# [2]
# [2, 24]
# 43
# [6, 31, 43]
# [25]
# [25, 12]
# [6, 31, 43]
# [6, 31, 43]
# ---------------------------
# [14, 19, 24, 27, 28, 29, 30, 54, 57]
# [6, 31, 43]
# new_list_1:  [13, 16, 23, 24, 25, 28, 35, 37, 39]
# 17
# [7, 8, 17]
# [1]
# [1, 9]
# 45
# [16, 44, 45]
# [28]
# [28, 1]
# 53
# [10, 36, 53]
# [26]
# [26, 17]
# [10, 36, 53]
# [10, 36, 53]
# new_list_1:  [4, 23, 26, 30, 36, 40, 41, 47, 50]
# 35
# [18, 30, 35]
# [12]
# [12, 5]
# [18, 30, 35]
# [18, 30, 35]
# new_list_1:  [2, 5, 14, 24, 30, 32, 37, 43, 56]
# 31
# [11, 16, 31]
# [5]
# [5, 15]
# [11, 16, 31]
# [11, 16, 31]
# new_list_1:  [1, 2, 9, 10, 11, 13, 16, 39, 42]
# 54
# [20, 24, 54]
# [4]
# [4, 30]
# [20, 24, 54]
# [20, 24, 54]
# ---------------------------
# [1, 2, 9, 10, 11, 13, 16, 39, 42]
# [20, 24, 54]
# new_list_1:  [1, 9, 13, 16, 18, 26, 28, 41, 50]
# 52
# [52]
# [52]
# [52]
# ---------------------------
# [1, 9, 13, 16, 18, 26, 28, 41, 50]
# [52]
# new_list_1:  [0, 2, 9, 31, 37, 41, 49, 58, 59]
# 58
# [11, 37, 58]
# [26]
# [26, 21]
# [11, 37, 58]
# [11, 37, 58]
# new_list_1:  [0, 7, 11, 12, 28, 29, 36, 58, 59]
# 35
# [7, 21, 35]
# [14]
# [14, 14]
# [7, 21, 35]
# [7, 21, 35]
# new_list_1:  [1, 5, 14, 15, 21, 37, 48, 53, 58]
# 47
# [1, 20, 47]
# [19]
# [19, 27]
# [1, 20, 47]
# [1, 20, 47]
# new_list_1:  [18, 26, 28, 31, 36, 41, 43, 47, 55]
# 54
# [38, 48, 54]
# [10]
# [10, 6]
# [38, 48, 54]
# [38, 48, 54]
# new_list_1:  [3, 14, 20, 25, 39, 49, 53, 55, 58]
# 45
# [38, 39, 45]
# [1]
# [1, 6]
# 50
# [15, 35, 50]
# [20]
# [20, 15]
# [15, 35, 50]
# [15, 35, 50]
# ---------------------------
# [3, 14, 20, 25, 39, 49, 53, 55, 58]
# [15, 35, 50]
# new_list_1:  [8, 11, 12, 20, 21, 27, 40, 53, 59]
# 58
# [10, 51, 58]
# [41]
# [41, 7]
# [10, 51, 58]
# [10, 51, 58]
# new_list_1:  [2, 8, 16, 18, 19, 29, 37, 49, 54]
# 40
# [9, 24, 40]
# [15]
# [15, 16]
# [9, 24, 40]
# [9, 24, 40]
# ---------------------------
# [2, 8, 16, 18, 19, 29, 37, 49, 54]
# [9, 24, 40]

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])
# Out:
# 0
# 0 1 60
# 1
# 1 2 60
# 2
# 2 3 60
# 3
# 3 4 60
# 4
# 4 5 60
# 5
# 5 6 60
# 6
# 6 7 60
# 7
# 7 8 60

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 388
# 388
# True
# 36
# 36
# True
# 36
# 36
# True
# 24
# 20
# 4

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)
# Out:
# ['tone2', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone1', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2']

# %%
df_2 = pd.DataFrame.from_dict(possible_images_dict)
df_2= df_2.T
df_2.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df_2.TS = df_2.TS.astype('float')
df_2.to_csv(mypath + '../Config/randomization_2.csv')
block_2_half = block
probe_series_2_half = probe_series

# %%
probe_series = probe_series_1_half + probe_series_2_half
block = block_1_half + block_2_half

# %%
with open('../Config/images.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(block[i])
        #wr.writerow(blocks_sequences_list[i])

with open('../Config/probes.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(probe_series[i])
