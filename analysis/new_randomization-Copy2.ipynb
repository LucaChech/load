# %%
import pandas as pd
import numpy as np
import random
import csv
#%pdb
#mypath = ('E:/OneDrive - University College London/Random_probes_last/Luca/')
mypath = 'C:/Users/nilli lab/Desktop/load/analysis/'

# %%
import random
probe_series = []
critical_series = []

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
print len(target_present)

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
print len(target_present)
for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# 24
# 36
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  12
# len(critical_trials):  24

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 389
# -------------------

# %%
def block_low_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
    
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_low_2():
# Pick 5 present probes and 4 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_2():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
block_low_1()
print critical_used
block_high_1()
print critical_used
block_high_2()
print critical_used
block_low_2()
print critical_used
block_high_1()
print critical_used
block_low_1()
print critical_used
block_low_2()
print critical_used
block_high_2()
print critical_used
# Out:
# [' person', ' bicycle', nan, nan, nan, 18.23776823647068, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 18.523024266211753, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' car', ' dog', ' person', nan, nan, 21.020159211351668, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 20.131411086471946, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' bottle', nan, nan, nan, nan, 21.116301747151233, 'low', ' bottle', ' cat', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 19.45316735456659, 'low', ' car', ' horse', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 21.22948510797022, 'low', ' bird', ' horse', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 12.7290334446634, 'low', ' cat', ' bird', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 19.239146135217897, 'low', ' bird', ' sofa', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  0
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 13.513291905037027, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 18.608803704733788, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' chair', ' dog', ' diningtable', nan, nan, 18.206263900870965, 'low', ' chair', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  48
# Normal used: 48
# ---------------------------------------------------
# ['2008_006564.jpg', '2010_005391.jpg', '2008_006837.jpg']
# [' sofa', ' person', nan, nan, nan, 31.051868344918073, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' person', ' boat', nan, nan, nan, 34.28798865304669, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 30.088045927192198, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' car', ' bicycle', ' motorbike', ' bus', ' person', 30.26344946567593, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' person', ' chair', ' tvmonitor', nan, nan, 28.894989564027235, 'high', ' chair', ' sofa', 'Target Absent', 'Normal']
# [' person', ' chair', ' bird', nan, nan, 29.63012122697995, 'high', ' bird', ' boat', 'Target Absent', 'Normal']
# [' bird', ' cow', nan, nan, nan, 30.96122100405093, 'high', ' bird', ' car', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 29.26546246503357, 'high', ' horse', ' aeroplane', 'Target Absent', 'Critical']
# [' bird', nan, nan, nan, nan, 29.27265460253791, 'high', ' bird', ' sofa', 'Target Absent', 'Critical']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  2
# List of critical trials without probe:
# [' dog', nan, nan, nan, nan, 29.77784058169977, 'high', ' dog', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  98
# Normal used: 98
# ---------------------------------------------------
# ['2008_006564.jpg', '2010_005391.jpg', '2008_006837.jpg', '2010_002775.jpg']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 28.76635784450944, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' chair', ' diningtable', ' bottle', nan, 30.06059186196041, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' aeroplane', ' boat', nan, nan, nan, 29.28734944464957, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 30.24293720929956, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 31.182430259996877, 'high', ' bird', ' bird', 'Target Present', 'Critical']
# [' pottedplant', ' person', ' train', nan, nan, 29.10600637597598, 'high', ' pottedplant', ' person', 'Target Absent', 'Normal']
# [' person', ' cat', nan, nan, nan, 29.867994035114002, 'high', ' cat', ' dog', 'Target Absent', 'Normal']
# [' car', ' aeroplane', nan, nan, nan, 35.87217940794205, 'high', ' aeroplane', ' horse', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 32.020689907436754, 'high', ' aeroplane', ' bottle', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  1
# List of critical trials without probe:
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 37.710719022258736, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' motorbike', ' boat', 31.58048990210689, 'high', ' boat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  147
# Normal used: 147
# ---------------------------------------------------
# ['2008_006564.jpg', '2010_005391.jpg', '2008_006837.jpg', '2010_002775.jpg', '2008_000041.jpg', '2009_003351.jpg']
# [' chair', ' dog', nan, nan, nan, 13.836710152206384, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 16.876667793733738, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' person', ' bottle', nan, nan, nan, 20.423795473772003, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 20.413253715842107, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' horse', ' car', nan, nan, 20.934599857700228, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 20.53735353764835, 'low', ' cat', ' dog', 'Target Absent', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 19.906276626032106, 'low', ' pottedplant', ' chair', 'Target Absent', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 17.49302399164143, 'low', ' pottedplant', ' dog', 'Target Absent', 'Normal']
# [' person', ' car', nan, nan, nan, 18.390878339274188, 'low', ' car', ' person', 'Target Absent', 'Normal']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  1
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 20.850125265290927, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' sofa', nan, nan, nan, 19.244035875135978, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  196
# Normal used: 196
# ---------------------------------------------------
# ['2008_006564.jpg', '2010_005391.jpg', '2008_006837.jpg', '2010_002775.jpg', '2008_000041.jpg', '2009_003351.jpg', '2010_002645.jpg', '2008_004270.jpg']
# [' pottedplant', ' sofa', ' chair', ' diningtable', ' tvmonitor', 29.247483266365705, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' person', ' bottle', nan, nan, nan, 29.27630230662073, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 29.176311484999022, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 40.773121275105424, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' bottle', ' diningtable', nan, nan, 29.775484131000805, 'high', ' bottle', ' dog', 'Target Absent', 'Normal']
# [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 29.806819625699735, 'high', ' sofa', ' person', 'Target Absent', 'Normal']
# [' chair', ' bottle', nan, nan, nan, 35.925064893420085, 'high', ' chair', ' cat', 'Target Absent', 'Normal']
# [' person', ' chair', ' bottle', nan, nan, 33.38111538349955, 'high', ' chair', ' pottedplant', 'Target Absent', 'Normal']
# [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 28.968465057520145, 'high', ' sofa', ' chair', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 31.54166437440535, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' boat', ' car', nan, nan, 35.70470893485066, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', ' bottle', nan, 33.82355011426018, 'high', ' chair', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  244
# Normal used: 244
# ---------------------------------------------------
# ['2008_006564.jpg', '2010_005391.jpg', '2008_006837.jpg', '2010_002775.jpg', '2008_000041.jpg', '2009_003351.jpg', '2010_002645.jpg', '2008_004270.jpg', '2010_000536.jpg', '2010_002702.jpg', '2008_002789.jpg']
# [' dog', ' bottle', nan, nan, nan, 18.86070334209068, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' sofa', nan, nan, nan, nan, 17.0559093734335, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 18.837863956276628, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 12.53657278412077, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 14.1064450150686, 'low', ' aeroplane', ' car', 'Target Absent', 'Normal']
# [' sofa', ' dog', nan, nan, nan, 19.188834185415878, 'low', ' sofa', ' bottle', 'Target Absent', 'Critical']
# [' person', ' cat', nan, nan, nan, 20.139877805151375, 'low', ' person', ' boat', 'Target Absent', 'Normal']
# [' bottle', nan, nan, nan, nan, 20.8325215532547, 'low', ' bottle', ' person', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.272204751551552, 'low', ' aeroplane', ' pottedplant', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  1
# List of critical trials without probe:
# [' sofa', ' dog', nan, nan, nan, 21.001227278103954, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', ' person', nan, nan, nan, 20.695714607410885, 'low', ' car', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  293
# Normal used: 293
# ---------------------------------------------------
# ['2008_006564.jpg', '2010_005391.jpg', '2008_006837.jpg', '2010_002775.jpg', '2008_000041.jpg', '2009_003351.jpg', '2010_002645.jpg', '2008_004270.jpg', '2010_000536.jpg', '2010_002702.jpg', '2008_002789.jpg', '2008_001238.jpg', '2011_002303.jpg']
# [' cat', nan, nan, nan, nan, 10.236635760901883, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 20.39542994429513, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 21.217669901647128, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 21.19410161612616, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 16.693372571654717, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 18.057825283941515, 'low', ' horse', ' boat', 'Target Absent', 'Normal']
# [' horse', nan, nan, nan, nan, 19.78900607095989, 'low', ' horse', ' aeroplane', 'Target Absent', 'Normal']
# [' dog', nan, nan, nan, nan, 18.02036796686756, 'low', ' dog', ' car', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 20.306835318139004, 'low', ' horse', ' sofa', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 15.253871492883167, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 19.234401336670953, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 20.470663952413528, 'low', ' boat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  341
# Normal used: 341
# ---------------------------------------------------
# ['2008_006564.jpg', '2010_005391.jpg', '2008_006837.jpg', '2010_002775.jpg', '2008_000041.jpg', '2009_003351.jpg', '2010_002645.jpg', '2008_004270.jpg', '2010_000536.jpg', '2010_002702.jpg', '2008_002789.jpg', '2008_001238.jpg', '2011_002303.jpg', '2010_001988.jpg', '2010_001829.jpg', '2008_002504.jpg']
# [' pottedplant', ' chair', nan, nan, nan, 34.96662806576853, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' tvmonitor', ' chair', ' person', nan, nan, 31.79472940313895, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' chair', ' cat', nan, nan, nan, 29.798629151951733, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 30.30670761720366, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' person', ' chair', nan, nan, nan, 34.70717080948356, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 32.66066395118465, 'high', ' cat', ' car', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' train', nan, nan, 29.323493073246585, 'high', ' person', ' boat', 'Target Absent', 'Normal']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 29.8220330038045, 'high', ' sofa', ' horse', 'Target Absent', 'Normal']
# [' chair', nan, nan, nan, nan, 33.26176817697461, 'high', ' chair', ' bird', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  0
# List of critical trials without probe:
# [' person', ' car', nan, nan, nan, 28.839741748612518, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 30.95304328989037, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 29.9571992215138, 'high', ' boat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  389
# Normal used: 389
# ---------------------------------------------------
# ['2008_006564.jpg', '2010_005391.jpg', '2008_006837.jpg', '2010_002775.jpg', '2008_000041.jpg', '2009_003351.jpg', '2010_002645.jpg', '2008_004270.jpg', '2010_000536.jpg', '2010_002702.jpg', '2008_002789.jpg', '2008_001238.jpg', '2011_002303.jpg', '2010_001988.jpg', '2010_001829.jpg', '2008_002504.jpg', '2008_005472.jpg', '2011_001800.jpg', '2008_003701.jpg']

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
print probes[0]
# Out:
# ['2008_005978.jpg', '2008_001185.jpg', '2010_003746.jpg', '2010_002393.jpg', '2009_005308.jpg', '2008_000105.jpg', '2008_001495.jpg', '2009_004225.jpg', '2011_002582.jpg']

# %%
probe_series = []
critical_series = []

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
def building_the_church(w):
    while True:    
        while True:
            a = [random.randint(1,60) for r in xrange(9)]
            if sum(a) <= 60:
                break
        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]
        print 'new_list_1: ',new_list_1
        #print sum(a)

        while True:
            a = [random.randint(1,60) for r in xrange(3-w)]
            if sum(a) <= 60: #and 1 not in a:
                break
        new_list_2 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_2.append(acc)
        new_list_2 = [n - 1 for n in new_list_2]
        print 'new_list_2: ', new_list_2
        #print sum(a)

        container = []
        for i in new_list_2:
            sequence = [i, i+1, i+2]
            #print sequence
            for element in sequence:
                if element in new_list_1:
                    container.append(element)
        #print len(container)
        print new_list_2
        if len(container) == 0:
            break
    print '---------------------------'
    probe_series.append(new_list_1)
    critical_series.append(new_list_2)
    print new_list_1
    print new_list_2
    return

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [11, 16, 18, 20, 27, 28, 40, 43, 56]
# new_list_2:  [5, 38, 59]
# [5, 38, 59]
# new_list_1:  [7, 12, 13, 21, 33, 37, 53, 55, 56]
# new_list_2:  [37, 48, 55]
# [37, 48, 55]
# new_list_1:  [0, 5, 12, 13, 22, 39, 40, 52, 57]
# new_list_2:  [10, 29, 58]
# [10, 29, 58]
# new_list_1:  [0, 1, 2, 19, 24, 46, 49, 54, 55]
# new_list_2:  [17, 35, 38]
# [17, 35, 38]
# new_list_1:  [0, 7, 11, 15, 19, 37, 38, 44, 54]
# new_list_2:  [7, 10, 42]
# [7, 10, 42]
# new_list_1:  [0, 3, 8, 20, 29, 38, 52, 57, 58]
# new_list_2:  [2, 19, 57]
# [2, 19, 57]
# new_list_1:  [4, 13, 15, 41, 45, 53, 56, 57, 59]
# new_list_2:  [10, 41, 49]
# [10, 41, 49]
# new_list_1:  [0, 3, 12, 21, 22, 26, 36, 43, 46]
# new_list_2:  [7, 22, 32]
# [7, 22, 32]
# new_list_1:  [6, 13, 16, 23, 32, 33, 34, 36, 44]
# new_list_2:  [5, 37, 46]
# [5, 37, 46]
# new_list_1:  [4, 14, 19, 28, 30, 34, 41, 44, 45]
# new_list_2:  [3, 18, 53]
# [3, 18, 53]
# new_list_1:  [14, 22, 30, 32, 39, 40, 46, 47, 55]
# new_list_2:  [14, 47, 59]
# [14, 47, 59]
# new_list_1:  [5, 8, 13, 14, 27, 30, 41, 53, 56]
# new_list_2:  [9, 49, 51]
# [9, 49, 51]
# new_list_1:  [5, 7, 8, 20, 21, 24, 41, 44, 49]
# new_list_2:  [2, 16, 39]
# [2, 16, 39]
# new_list_1:  [8, 14, 16, 19, 22, 30, 32, 58, 59]
# new_list_2:  [4, 7, 49]
# [4, 7, 49]
# new_list_1:  [9, 13, 14, 23, 32, 36, 37, 40, 57]
# new_list_2:  [3, 20, 27]
# [3, 20, 27]
# ---------------------------
# [9, 13, 14, 23, 32, 36, 37, 40, 57]
# [3, 20, 27]
# new_list_1:  [12, 13, 21, 24, 27, 36, 37, 38, 44]
# new_list_2:  [35]
# [35]
# new_list_1:  [3, 4, 17, 24, 37, 38, 41, 53, 55]
# new_list_2:  [24]
# [24]
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-22-dc4dd0ab9b3e> in <module>()
#       1 building_the_church(modifier[0])
# ----> 2 building_the_church(modifier[1])
#       3 building_the_church(modifier[2])
#       4 building_the_church(modifier[3])
#       5 building_the_church(modifier[4])
#
# <ipython-input-21-671e2dcee3e4> in building_the_church(w)
#       2     while True:
#       3         while True:
# ----> 4             a = [random.randint(1,60) for r in xrange(9)]
#       5             if sum(a) <= 60:
#       6                 break
#
# KeyboardInterrupt:
# > <ipython-input-21-671e2dcee3e4>(4)building_the_church()
#       2     while True:
#       3         while True:
# ----> 4             a = [random.randint(1,60) for r in xrange(9)]
#       5             if sum(a) <= 60:
#       6                 break

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)

# %%
df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_1.csv')
block_1_half = block
probe_series_1_half = probe_series

# %%
##################
# SECOND ITERATION#
##################

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb

# %%
block_low_1()
block_high_1()
block_high_2()
block_low_2()
block_high_1()
block_low_1()
block_low_2()
block_high_2()

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)

# %%
probe_series = []
critical_series = []

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)

# %%
df_2 = pd.DataFrame.from_dict(possible_images_dict)
df_2= df_2.T
df_2.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df_2.TS = df_2.TS.astype('float')
df_2.to_csv(mypath + 'randomization_2.csv')
block_2_half = block
probe_series_2_half = probe_series

# %%
probe_series = probe_series_1_half + probe_series_2_half
block = block_1_half + block_2_half

# %%
with open('filename.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(block[i])
        #wr.writerow(blocks_sequences_list[i])

with open('filename2.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(probe_series[i])
