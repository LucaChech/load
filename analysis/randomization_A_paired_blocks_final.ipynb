# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pickle
from copy import deepcopy
#%pdb
mypath = ('')
trials = {}
categories = [' bottle', ' horse', ' pottedplant', ' dog',
                  ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]
p_load = ['low','high']

pd.set_option('display.max_rows', 9000)
pd.set_option('display.max_columns', 9000)

# %%
def present_absent_trials(input_1, input_2):
    global target_present, lista, categories, p_load, odd, even
    # DEFINING TARGET-PRESENT PROBES
    
    #target_present = []
    intermediate = []
    
#next two lines are to check that the images picked as target present and target absent trials
                    #are different from the ones chosen in previous iterations
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_1:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break
    #print len(target_present)
    for n in target_present:
        possible_images_dict[n].append('Target Present')

    #target_present = [n for n in lista if 'Target Present' in possible_images_dict[n]]


    # DEFINING TARGET-ABSENT PROBES
    #target_absent = []
    intermediate = []
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_2:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)

                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for each in target_absent:
        possible_images_dict[each].append('Target Absent')
        

    # DEFINING NO-TARGET IMAGES
    for image in lista:
        if image not in target_present and image not in target_absent:
            possible_images_dict[image].append('NA')
            possible_images_dict[image].append('No Target')
    
    return target_present, target_absent

# %%
# DEFINING CRITICAL TRIALS
#Criteria:
# - images of set load level
# - images containing a certain category
# - image is not already in the list of critical trials for this level of load
#- image is not aready in the list of critical trials (regardless of level of load)

def pre_select_critical_trial(load_level):
    global categories, critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and 'Critical' not in possible_images_dict[intermediate]: # this is just a sanity check
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)      
        temp =[]

# %%
def appending_critical_trials():
    global critical_low_present_probes, critical_low_absent_probes, critical_high_present_probes, critical_high_absent_probes
    global critical_trials
    cycles = 1
    while True:

        #picking critical trials
        pre_select_critical_trial('low')
        pre_select_critical_trial('high')      

        # counting critical probes
        crit_p = 0
        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1


        critical_low_counter = 0
        critical_high_counter = 0
        crit_p = 0

        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1
            if 'No Target' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_counter = critical_low_counter + 1
            if 'No Target' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_counter = critical_high_counter +1
            if 'Target Present' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_absent_probes.append(n)
            if 'Target Present' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_absent_probes.append(n)
        #print crit_p
        #print critical_low_counter
        #print critical_high_counter
        #print critical_low_present_probes
        #print critical_low_absent_probes
        #print critical_high_present_probes
        #print critical_high_absent_probes

        #######################################################
        if crit_p == 0 or len(critical_low_present_probes) == len(critical_high_present_probes) and len(critical_low_absent_probes) == \
        len(critical_high_absent_probes): #check if there is an even number of critical probes
            break
            print 'cycles : ',cycles
        else:
            cycles = cycles + 1
            critical_low_present_probes = []
            critical_low_absent_probes = []
            critical_high_present_probes = []
            critical_high_absent_probes = []
            #print len(critical_low_present_probes)
            #print len(critical_high_present_probes)
            #print len(critical_low_absent_probes)
            #print len(critical_high_absent_probes)
            #print '#######################'

            #why did I reset target_present and target_absent???

            #target_present = []
            #target_absent = []
            critical_trials = []

    # appendinf words 'critical' and 'normal' to dict
    for each in critical_trials:
        possible_images_dict[each].append('Critical')
    for each in possible_images_dict:
        if 'Critical' not in possible_images_dict[each]:
            possible_images_dict[each].append('Normal')

    #######################################################
    #print 'Probe trials: ', len(probe_trials_1)
    print 'Target Present Probes: ', len(target_present)
    print 'Target Absent probes: ', len(target_absent)
    print 'Critical trials:', len(critical_trials)
    print 'Critical, low: ' , critical_low_counter
    print 'Critical, high: ' , critical_high_counter
    print 'Are all critical trials unique? ', len(critical_trials) == len(set(critical_trials))
    #######################################################
    print 'Number of critical probes: ' , crit_p
    print 'critical_low_present_probes: ' , len(critical_low_present_probes)
    print 'critical_high_present_probes: ' , len(critical_high_present_probes)
    print 'critical_low_absent_probes: ' , len(critical_low_absent_probes)
    print 'critical_high_absent_probes: ', len(critical_high_absent_probes)
    print 'cycles : ',cycles
    
    return

# %%
def critical_probes_distribution(starting):
    global critical_low_present_probes, critical_low_absent_probes
    while True:
        p_left = len(starting)
        p_max = p_left
        distribution = []
        for i in range(4):
            if p_left > 0:
                x = random.randint(0,p_left)
                distribution.append(x)
                p_left = p_left - x
            else:
                distribution.append(0)
        if sum(distribution) == p_max:
            break
    random.shuffle(distribution)
    return distribution

# %%
def block_pair(present_n,absent_n):
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block
    global present_crit_distribution, absent_crit_distribution
    global present_critical_per_block, absent_critical_per_block, critical_probes_used, critical_probes_set
    global present_per_block, absent_per_block
    
    present_crit = present_crit_distribution.pop(0)
    absent_crit = absent_crit_distribution.pop(0)
    block = []
    
    for load in p_load:
        #PRINTING STUFF
        print 'present_crit_distribution_original: ',present_crit_distribution_original
        print 'absent_crit_distribution_original: ', absent_crit_distribution_original
        print 'present_crit', present_crit
        print 'absent_crit', absent_crit
        print 'present_crit_distribution: ', present_crit_distribution
        print 'absent_crit_distribution: ', absent_crit_distribution
        print 'critical present set: ', critical_present_set
        print 'critical absent set: ', critical_absent_set
        print'---------------------------------------------------'
        normal_availble = [n for n in normal if n not in normal_used]
        print 'normal available:', len(normal_availble)
    # PICKING CRITICAL PROBES    
    #------------------------------------------------------------------------------
        if present_crit != 0:
            present_critical_per_block = []
            while len(present_critical_per_block) < present_crit:
                crit_probe = str(np.random.choice(critical_present_set,1,replace = False))[2:-2]
                if crit_probe not in present_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Present' in possible_images_dict[crit_probe]:

                    present_critical_per_block.append(crit_probe)
            critical_present.append(present_critical_per_block)
                    
        print 'present_critical_per_block:', present_critical_per_block
        
        if absent_crit != 0:
            absent_critical_per_block = []
            while len(absent_critical_per_block) < absent_crit:
                crit_probe = str(np.random.choice(critical_absent_set,1,replace = False))[2:-2]
                if crit_probe not in absent_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Absent' in possible_images_dict[crit_probe]:

                    absent_critical_per_block.append(crit_probe)
            critical_absent.append(absent_critical_per_block)
            
        print 'absent_critical_per_block:', absent_critical_per_block  
        print 'critical_present: ',critical_present
        print 'critical_absent: ',critical_absent
        
        for n in present_critical_per_block + absent_critical_per_block:
            critical_probes_used.append(n)
            
        print 'critical_probes_used: ', critical_probes_used
    #------------------------------------------------------------------------------
    # PICKING PRESENT AND ABSENT PROBES
        total = present_n + absent_n
        while len(probes_per_block) < (present_n - present_crit):
            probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in present_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        while (present_n - present_crit) <= len(probes_per_block) < total - present_crit - absent_crit:
            probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in absent_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        for n in probes_per_block:
            if 'Target Present' in possible_images_dict[n]:
                present_used.append(n)
            elif 'Target Absent' in possible_images_dict[n]:
                absent_used.append(n)

        probes.append(probes_per_block)
        
        print 'probes: ', probes
        present_per_block = [n for n in probes_per_block if 'Target Present' in possible_images_dict[n]]
        absent_per_block = [n for n in probes_per_block if 'Target Absent' in possible_images_dict[n]]
        print 'Present Used in block: ',len(present_per_block)
        print 'Absent Used in block',len(absent_per_block)
    #------------------------------------------------------------------------------    
    #Counting critical probes    
        critical_probes_counter = len(present_critical_per_block + absent_critical_per_block)
        print 'Critical probes counter: ',critical_probes_counter
        print 'Present Critical: ', len(present_critical_per_block)
        print 'Absent Critical: ', len(absent_critical_per_block)

        modifier.append(critical_probes_counter)
    #------------------------------------------------------------------------------
    #Picking critical trials
        while len(critical_per_block) < (3-critical_probes_counter):
            image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
            if image not in critical_per_block and image not in critical_used \
                and 'No Target' in possible_images_dict[image] and load in possible_images_dict[image]:
                critical_per_block.append(image) 
        print 'List of critical trials without probe: '
        for n in critical_per_block:
            critical_used.append(n)
            print possible_images_dict[n]
        #temp = []

        critical.append(critical_per_block)

    #------------------------------------------------------------------------------
    #Picking normal trials
        while len(normal_per_block) < 51 - (3 - critical_probes_counter):
            image = str(np.random.choice(normal,1,replace = False))[2:-2]
            if image not in normal_per_block and image not in normal_used and load in possible_images_dict[image]:
                normal_per_block.append(image)
        for n in normal_per_block:
            normal_used.append(n)
        print 'normal in this block: ', len(normal_per_block)
        print 'normal used overall: ',len(normal_used)

        normal_builder.append(normal_per_block)
    #----------------------------------------------------------------------------
        
        print 'critical_probes_used', critical_probes_used 
        
        
        
        if 'sequence_final' in locals():
            print 'sequence_final exists'
        else:
            print 'sequence final does not exist'
            sequence_final = position_finder()
            print sequence_final
        print'---------------------------------------------------'
        print 'END OF BLOCK PROCESSING'
        print'---------------------------------------------------'
        print 'BUILDING THE BLOCK'
        first_element = [x[0] for x in sequence_final]
        second_element = [x[1] for x in sequence_final]
        second_element_counter = 0
        probes_position = []
        for image in range(60):
            #print [x[1] for x in sequence_final if x[0] ==image][0]
            if image in first_element:
                
                print 'image', image, second_element[second_element_counter]
        
                if second_element[second_element_counter] == 'Target Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break       
                elif second_element[second_element_counter] == 'Target Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical':
                    while True:
                        element = str(np.random.choice(critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break     
                elif second_element[second_element_counter] == 'Critical Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break  
            else:
                while True:
                    element = str(np.random.choice(normal_per_block,1,replace = False))[2:-2]
                    if element not in block:
                        block.append(element)
                        break
                
        print 'block:', len(block)   
        print'---------------------------------------------------'
        print 'probes_position: ', probes_position
    #-----------------------------------------------------------------------------
        normal_per_block = []
        probes_per_block = []
        critical_per_block = []
        present_critical_per_block = []
        absent_critical_per_block = []
    #-----------------------------------------------------------------------------
    return block

# %%
def position_finder():
    global present_critical_per_block, absent_critical_per_block, present_per_block, absent_per_block, critical_per_block
    x = len(present_critical_per_block + absent_critical_per_block)
    print 'x', x
    print 'present_critical_per_block', len(present_critical_per_block)
    print 'absent_critical_per_block', len(absent_critical_per_block)
    while True:    
        while True:
            a = [random.randint(1,10) for r in xrange(12-x)]
            if sum(a) <= 60:
                break

        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]

        if len(present_critical_per_block) == 0 and len(absent_critical_per_block) == 0:
            print 'ciao', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block) + ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        if len(present_critical_per_block) != 0 or len(absent_critical_per_block) != 0:
            print 'ciao2', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block)  +\
            ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block) +\
            ['Critical Present'] * len(present_critical_per_block) +\
            ['Critical Absent'] * len(absent_critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        sequence_final = zip(new_list_1, sequence)
        #print sequence_final
        #print len(sequence_final)
        gap_check = [n[0] for n in sequence_final if 'Critical' in n[1]] 
        #print gap_check
        container = []
        for i in gap_check:
            elements = [i+1, i+2]
            for element in elements:
                if element in new_list_1:
                    container.append(element)
        #print 'container', len(container),container
        if len(container) == 0:
            break
        else:
            sequence_final = []

    print '------------------'
    print new_list_1, len(new_list_1)
    print 'gap_check: ', gap_check
    print len(sequence_final)

    for i in sequence_final:
        print i
    return sequence_final

# %%
def block_unpacker(splitting_index,present,absent):
    block = block_pair(present,absent) #, probes_position
    low_block = []
    high_block = []
    for i in range(len(block)):
        if i < (len(block)/2):
            low_block.append(block[i])
        else:
            high_block.append(block[i])
    #print probes_position
    print len(low_block), len(high_block)
    return low_block, high_block #, probes_position

# %%
def tone_properties():
    while True:
        possible_tones = ['tone1','tone2']
        low_one_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_two_tones = []
        low_three_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_four_tones = []
        
        for each in low_one_tones:
            if each == 'tone1':
                low_two_tones.append('tone2')
            elif each == 'tone2':
                low_two_tones.append('tone1')
        for each in low_three_tones:
            if each == 'tone1':
                low_four_tones.append('tone2')
            elif each == 'tone2':
                low_four_tones.append('tone1')
        high_one_tones = low_one_tones
        high_two_tones = low_two_tones
        high_three_tones = low_three_tones
        high_four_tones = low_four_tones
        
        sound_Hz = low_one_tones + low_two_tones + low_three_tones + low_four_tones + high_one_tones + high_two_tones +\
        high_three_tones + high_four_tones

        tone1_counter = 0
        tone2_counter = 0
        for each in sound_Hz:
            if each == 'tone1':
                tone1_counter = tone1_counter + 1
            elif each == 'tone2':
                tone2_counter = tone2_counter + 1

        low_load_tones = [n for n in sound_Hz[0:12]]
        high_load_tones = [n for n in sound_Hz[12:25]]
        low_load_tone1s = [n for n in low_load_tones if n == 'tone1']
        low_load_tone2s = [n for n in low_load_tones if n == 'tone2']
        high_load_tone1s = [n for n in high_load_tones if n == 'tone1']
        high_load_tone2s = [n for n in high_load_tones if n =='tone2']

        if len(low_load_tone1s) == len(low_load_tone2s) and len(high_load_tone1s) == len(high_load_tone2s):
            print low_one_tones
            print high_one_tones
            print '----------------------'
            print low_two_tones
            print high_two_tones
            print '----------------------'
            print low_three_tones
            print high_three_tones
            print '----------------------'
            print low_four_tones
            print high_four_tones
            print '----------------------'
            print 'total n of tones: ', len(sound_Hz)
            print '----------------------'
            print 'total n of 1500 Hz tones: ', tone1_counter
            print 'total n of 2000 Hz tones: ', tone2_counter
            print '----------------------'
            print len(low_load_tone1s) == len(low_load_tone2s)
            print len(low_load_tone1s)
            print len(low_load_tone2s)
            print len(high_load_tone1s) == len(high_load_tone2s)
            print len(high_load_tone1s)
            print len(high_load_tone2s)
            break
        # Re-ordering tones according to the block order
    sound_Hz = low_one_tones + high_two_tones + high_one_tones + low_two_tones + high_three_tones + low_four_tones +\
        low_three_tones + high_four_tones 
    sound_onset1 = np.random.uniform(0,0.949,3).tolist()
    sound_onset2 = np.random.uniform(0,0.949,3).tolist()
    sound_onset3 = np.random.uniform(0,0.949,3).tolist()
    sound_onset4 = np.random.uniform(0,0.949,3).tolist()
   
    sound_onset_pre_rounding = sound_onset1 + sound_onset2 + sound_onset1 + sound_onset2 + sound_onset3 + sound_onset4 + sound_onset3 + sound_onset4
    sound_onset = [round(n,3)*1000 for n in sound_onset_pre_rounding]
    return sound_Hz, sound_onset

# %%
def appending_to_dict(trial_n):
    global blocks
    for b in range(8):
        this_block_images = blocks[b]
        for im in this_block_images:
            trials[trial_n] = possible_images_dict[im]
            trials[trial_n].append(im)
            trial_n += 1
    print 'len(trials): ', len(trials)

# %%
######################
### FIRST ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  1
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2009_000619.jpg', '2009_004849.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg']
# probes_per_block : ['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg']
# probes:  [['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 20.9577483152902, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 18.259900940752694, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 19.030178152384888, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [0, 5, 11, 17, 24, 26, 31, 34, 40, 48, 50, 54] 12
# gap_check:  [11, 17, 31]
# 12
# (0, 'Target Present')
# (5, 'Target Absent')
# (11, 'Critical')
# (17, 'Critical')
# (24, 'Target Absent')
# (26, 'Target Present')
# (31, 'Critical')
# (34, 'Target Absent')
# (40, 'Target Absent')
# (48, 'Target Absent')
# (50, 'Target Present')
# (54, 'Target Present')
# [(0, 'Target Present'), (5, 'Target Absent'), (11, 'Critical'), (17, 'Critical'), (24, 'Target Absent'), (26, 'Target Present'), (31, 'Critical'), (34, 'Target Absent'), (40, 'Target Absent'), (48, 'Target Absent'), (50, 'Target Present'), (54, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Present
# image 5 Target Absent
# image 11 Critical
# image 17 Critical
# image 24 Target Absent
# image 26 Target Present
# image 31 Critical
# image 34 Target Absent
# image 40 Target Absent
# image 48 Target Absent
# image 50 Target Present
# image 54 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 5, 24, 26, 34, 40, 48, 50, 54]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2009_000619.jpg', '2009_004849.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg']
# probes_per_block : ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg', '2010_005606.jpg', '2009_000995.jpg', '2008_000982.jpg', '2011_002260.jpg', '2008_000488.jpg']
# probes:  [['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg'], ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg', '2010_005606.jpg', '2009_000995.jpg', '2008_000982.jpg', '2011_002260.jpg', '2008_000488.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' chair', ' diningtable', nan, nan, nan, 28.72863626121521, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', nan, nan, nan, 31.62452384083404, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Present
# image 5 Target Absent
# image 11 Critical
# image 17 Critical
# image 24 Target Absent
# image 26 Target Present
# image 31 Critical
# image 34 Target Absent
# image 40 Target Absent
# image 48 Target Absent
# image 50 Target Present
# image 54 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 5, 24, 26, 34, 40, 48, 50, 54]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2009_000619.jpg', '2009_004849.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_002283.jpg', '2008_007096.jpg', '2008_006452.jpg', '2009_001137.jpg', '2011_001959.jpg']
# probes_per_block : ['2010_002283.jpg', '2008_007096.jpg', '2008_006452.jpg', '2009_001137.jpg', '2011_001959.jpg', '2009_005044.jpg', '2009_000523.jpg', '2010_004791.jpg', '2010_005101.jpg']
# probes:  [['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg'], ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg', '2010_005606.jpg', '2009_000995.jpg', '2008_000982.jpg', '2011_002260.jpg', '2008_000488.jpg'], ['2010_002283.jpg', '2008_007096.jpg', '2008_006452.jpg', '2009_001137.jpg', '2011_001959.jpg', '2009_005044.jpg', '2009_000523.jpg', '2010_004791.jpg', '2010_005101.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' boat', nan, nan, nan, nan, 16.846336579249186, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 17.13857605003491, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 19.188834185415878, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [1, 3, 10, 19, 25, 30, 37, 40, 47, 51, 52, 55] 12
# gap_check:  [25, 52, 55]
# 12
# (1, 'Target Present')
# (3, 'Target Absent')
# (10, 'Target Absent')
# (19, 'Target Present')
# (25, 'Critical')
# (30, 'Target Present')
# (37, 'Target Absent')
# (40, 'Target Present')
# (47, 'Target Absent')
# (51, 'Target Present')
# (52, 'Critical')
# (55, 'Critical')
# [(1, 'Target Present'), (3, 'Target Absent'), (10, 'Target Absent'), (19, 'Target Present'), (25, 'Critical'), (30, 'Target Present'), (37, 'Target Absent'), (40, 'Target Present'), (47, 'Target Absent'), (51, 'Target Present'), (52, 'Critical'), (55, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 3 Target Absent
# image 10 Target Absent
# image 19 Target Present
# image 25 Critical
# image 30 Target Present
# image 37 Target Absent
# image 40 Target Present
# image 47 Target Absent
# image 51 Target Present
# image 52 Critical
# image 55 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 3, 10, 19, 30, 37, 40, 47, 51]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2009_000619.jpg', '2009_004849.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_000466.jpg', '2008_001673.jpg', '2010_002702.jpg', '2008_000251.jpg', '2011_000499.jpg']
# probes_per_block : ['2009_000466.jpg', '2008_001673.jpg', '2010_002702.jpg', '2008_000251.jpg', '2011_000499.jpg', '2008_000928.jpg', '2008_000274.jpg', '2008_005750.jpg', '2008_006663.jpg']
# probes:  [['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg'], ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg', '2010_005606.jpg', '2009_000995.jpg', '2008_000982.jpg', '2011_002260.jpg', '2008_000488.jpg'], ['2010_002283.jpg', '2008_007096.jpg', '2008_006452.jpg', '2009_001137.jpg', '2011_001959.jpg', '2009_005044.jpg', '2009_000523.jpg', '2010_004791.jpg', '2010_005101.jpg'], ['2009_000466.jpg', '2008_001673.jpg', '2010_002702.jpg', '2008_000251.jpg', '2011_000499.jpg', '2008_000928.jpg', '2008_000274.jpg', '2008_005750.jpg', '2008_006663.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' aeroplane', nan, nan, nan, 34.54414482156191, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' dog', nan, nan, nan, 29.851834352354174, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 35.94715000296663, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 3 Target Absent
# image 10 Target Absent
# image 19 Target Present
# image 25 Critical
# image 30 Target Present
# image 37 Target Absent
# image 40 Target Present
# image 47 Target Absent
# image 51 Target Present
# image 52 Critical
# image 55 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 3, 10, 19, 30, 37, 40, 47, 51]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2009_000619.jpg', '2009_004849.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: ['2009_000619.jpg']
# critical_present:  []
# critical_absent:  [['2009_000619.jpg']]
# critical_probes_used:  ['2009_000619.jpg']
# probes_per_block : ['2011_001886.jpg', '2008_001546.jpg', '2008_004814.jpg', '2008_000398.jpg']
# probes_per_block : ['2011_001886.jpg', '2008_001546.jpg', '2008_004814.jpg', '2008_000398.jpg', '2008_000972.jpg', '2010_003890.jpg', '2008_004270.jpg', '2010_003400.jpg']
# probes:  [['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg'], ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg', '2010_005606.jpg', '2009_000995.jpg', '2008_000982.jpg', '2011_002260.jpg', '2008_000488.jpg'], ['2010_002283.jpg', '2008_007096.jpg', '2008_006452.jpg', '2009_001137.jpg', '2011_001959.jpg', '2009_005044.jpg', '2009_000523.jpg', '2010_004791.jpg', '2010_005101.jpg'], ['2009_000466.jpg', '2008_001673.jpg', '2010_002702.jpg', '2008_000251.jpg', '2011_000499.jpg', '2008_000928.jpg', '2008_000274.jpg', '2008_005750.jpg', '2008_006663.jpg'], ['2011_001886.jpg', '2008_001546.jpg', '2008_004814.jpg', '2008_000398.jpg', '2008_000972.jpg', '2010_003890.jpg', '2008_004270.jpg', '2010_003400.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', nan, nan, nan, nan, 18.13905315137702, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' sofa', nan, nan, nan, 20.21626352293297, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  241
# critical_probes_used ['2009_000619.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ------------------
# [0, 3, 6, 13, 19, 28, 32, 36, 39, 42, 50] 11
# gap_check:  [28, 39, 42]
# 11
# (0, 'Target Absent')
# (3, 'Target Present')
# (6, 'Target Present')
# (13, 'Target Present')
# (19, 'Target Absent')
# (28, 'Critical')
# (32, 'Target Present')
# (36, 'Target Absent')
# (39, 'Critical Absent')
# (42, 'Critical')
# (50, 'Target Absent')
# [(0, 'Target Absent'), (3, 'Target Present'), (6, 'Target Present'), (13, 'Target Present'), (19, 'Target Absent'), (28, 'Critical'), (32, 'Target Present'), (36, 'Target Absent'), (39, 'Critical Absent'), (42, 'Critical'), (50, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 3 Target Present
# image 6 Target Present
# image 13 Target Present
# image 19 Target Absent
# image 28 Critical
# image 32 Target Present
# image 36 Target Absent
# image 39 Critical Absent
# image 42 Critical
# image 50 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 3, 6, 13, 19, 32, 36, 39, 50]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2009_000619.jpg', '2009_004849.jpg']
# ---------------------------------------------------
# normal available: 145
# present_critical_per_block: []
# absent_critical_per_block: ['2009_004849.jpg']
# critical_present:  []
# critical_absent:  [['2009_000619.jpg'], ['2009_004849.jpg']]
# critical_probes_used:  ['2009_000619.jpg', '2009_004849.jpg']
# probes_per_block : ['2008_004487.jpg', '2009_000565.jpg', '2008_005845.jpg', '2010_004778.jpg']
# probes_per_block : ['2008_004487.jpg', '2009_000565.jpg', '2008_005845.jpg', '2010_004778.jpg', '2011_001139.jpg', '2009_004364.jpg', '2010_005718.jpg', '2009_003338.jpg']
# probes:  [['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg'], ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg', '2010_005606.jpg', '2009_000995.jpg', '2008_000982.jpg', '2011_002260.jpg', '2008_000488.jpg'], ['2010_002283.jpg', '2008_007096.jpg', '2008_006452.jpg', '2009_001137.jpg', '2011_001959.jpg', '2009_005044.jpg', '2009_000523.jpg', '2010_004791.jpg', '2010_005101.jpg'], ['2009_000466.jpg', '2008_001673.jpg', '2010_002702.jpg', '2008_000251.jpg', '2011_000499.jpg', '2008_000928.jpg', '2008_000274.jpg', '2008_005750.jpg', '2008_006663.jpg'], ['2011_001886.jpg', '2008_001546.jpg', '2008_004814.jpg', '2008_000398.jpg', '2008_000972.jpg', '2010_003890.jpg', '2008_004270.jpg', '2010_003400.jpg'], ['2008_004487.jpg', '2009_000565.jpg', '2008_005845.jpg', '2010_004778.jpg', '2011_001139.jpg', '2009_004364.jpg', '2010_005718.jpg', '2009_003338.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' diningtable', ' bottle', nan, nan, 36.41404223766773, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 32.06509585553637, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  290
# critical_probes_used ['2009_000619.jpg', '2009_004849.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 3 Target Present
# image 6 Target Present
# image 13 Target Present
# image 19 Target Absent
# image 28 Critical
# image 32 Target Present
# image 36 Target Absent
# image 39 Critical Absent
# image 42 Critical
# image 50 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 3, 6, 13, 19, 32, 36, 39, 50]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2009_000619.jpg', '2009_004849.jpg']
# ---------------------------------------------------
# normal available: 96
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2009_000619.jpg'], ['2009_004849.jpg']]
# critical_probes_used:  ['2009_000619.jpg', '2009_004849.jpg']
# probes_per_block : ['2011_003145.jpg', '2011_000661.jpg', '2010_004231.jpg', '2010_000750.jpg', '2008_000839.jpg']
# probes_per_block : ['2011_003145.jpg', '2011_000661.jpg', '2010_004231.jpg', '2010_000750.jpg', '2008_000839.jpg', '2011_001005.jpg', '2011_002582.jpg', '2009_005036.jpg', '2008_002062.jpg']
# probes:  [['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg'], ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg', '2010_005606.jpg', '2009_000995.jpg', '2008_000982.jpg', '2011_002260.jpg', '2008_000488.jpg'], ['2010_002283.jpg', '2008_007096.jpg', '2008_006452.jpg', '2009_001137.jpg', '2011_001959.jpg', '2009_005044.jpg', '2009_000523.jpg', '2010_004791.jpg', '2010_005101.jpg'], ['2009_000466.jpg', '2008_001673.jpg', '2010_002702.jpg', '2008_000251.jpg', '2011_000499.jpg', '2008_000928.jpg', '2008_000274.jpg', '2008_005750.jpg', '2008_006663.jpg'], ['2011_001886.jpg', '2008_001546.jpg', '2008_004814.jpg', '2008_000398.jpg', '2008_000972.jpg', '2010_003890.jpg', '2008_004270.jpg', '2010_003400.jpg'], ['2008_004487.jpg', '2009_000565.jpg', '2008_005845.jpg', '2010_004778.jpg', '2011_001139.jpg', '2009_004364.jpg', '2010_005718.jpg', '2009_003338.jpg'], ['2011_003145.jpg', '2011_000661.jpg', '2010_004231.jpg', '2010_000750.jpg', '2008_000839.jpg', '2011_001005.jpg', '2011_002582.jpg', '2009_005036.jpg', '2008_002062.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' chair', ' diningtable', nan, nan, nan, 18.11780279510061, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 19.706122139777047, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 19.107696549923208, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  338
# critical_probes_used ['2009_000619.jpg', '2009_004849.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [1, 10, 13, 16, 26, 35, 40, 48, 54, 55, 56, 58] 12
# gap_check:  [13, 26, 35]
# 12
# (1, 'Target Absent')
# (10, 'Target Present')
# (13, 'Critical')
# (16, 'Target Present')
# (26, 'Critical')
# (35, 'Critical')
# (40, 'Target Present')
# (48, 'Target Present')
# (54, 'Target Absent')
# (55, 'Target Absent')
# (56, 'Target Present')
# (58, 'Target Absent')
# [(1, 'Target Absent'), (10, 'Target Present'), (13, 'Critical'), (16, 'Target Present'), (26, 'Critical'), (35, 'Critical'), (40, 'Target Present'), (48, 'Target Present'), (54, 'Target Absent'), (55, 'Target Absent'), (56, 'Target Present'), (58, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 10 Target Present
# image 13 Critical
# image 16 Target Present
# image 26 Critical
# image 35 Critical
# image 40 Target Present
# image 48 Target Present
# image 54 Target Absent
# image 55 Target Absent
# image 56 Target Present
# image 58 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 10, 16, 40, 48, 54, 55, 56, 58]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2009_000619.jpg', '2009_004849.jpg']
# ---------------------------------------------------
# normal available: 48
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2009_000619.jpg'], ['2009_004849.jpg']]
# critical_probes_used:  ['2009_000619.jpg', '2009_004849.jpg']
# probes_per_block : ['2008_007664.jpg', '2011_001605.jpg', '2011_001880.jpg', '2008_004690.jpg', '2008_000541.jpg']
# probes_per_block : ['2008_007664.jpg', '2011_001605.jpg', '2011_001880.jpg', '2008_004690.jpg', '2008_000541.jpg', '2011_000631.jpg', '2011_001649.jpg', '2008_007423.jpg', '2009_003705.jpg']
# probes:  [['2009_001782.jpg', '2008_000740.jpg', '2009_004076.jpg', '2008_000760.jpg', '2010_001908.jpg', '2008_003170.jpg', '2008_005903.jpg', '2011_002050.jpg', '2008_006954.jpg'], ['2009_003520.jpg', '2008_008681.jpg', '2008_000196.jpg', '2008_001451.jpg', '2010_005606.jpg', '2009_000995.jpg', '2008_000982.jpg', '2011_002260.jpg', '2008_000488.jpg'], ['2010_002283.jpg', '2008_007096.jpg', '2008_006452.jpg', '2009_001137.jpg', '2011_001959.jpg', '2009_005044.jpg', '2009_000523.jpg', '2010_004791.jpg', '2010_005101.jpg'], ['2009_000466.jpg', '2008_001673.jpg', '2010_002702.jpg', '2008_000251.jpg', '2011_000499.jpg', '2008_000928.jpg', '2008_000274.jpg', '2008_005750.jpg', '2008_006663.jpg'], ['2011_001886.jpg', '2008_001546.jpg', '2008_004814.jpg', '2008_000398.jpg', '2008_000972.jpg', '2010_003890.jpg', '2008_004270.jpg', '2010_003400.jpg'], ['2008_004487.jpg', '2009_000565.jpg', '2008_005845.jpg', '2010_004778.jpg', '2011_001139.jpg', '2009_004364.jpg', '2010_005718.jpg', '2009_003338.jpg'], ['2011_003145.jpg', '2011_000661.jpg', '2010_004231.jpg', '2010_000750.jpg', '2008_000839.jpg', '2011_001005.jpg', '2011_002582.jpg', '2009_005036.jpg', '2008_002062.jpg'], ['2008_007664.jpg', '2011_001605.jpg', '2011_001880.jpg', '2008_004690.jpg', '2008_000541.jpg', '2011_000631.jpg', '2011_001649.jpg', '2008_007423.jpg', '2009_003705.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', ' person', nan, nan, nan, 35.92557187315038, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', ' motorbike', ' person', nan, nan, 31.40872195535423, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' diningtable', ' cat', nan, nan, 29.842922502719393, 'high', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  386
# critical_probes_used ['2009_000619.jpg', '2009_004849.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 10 Target Present
# image 13 Critical
# image 16 Target Present
# image 26 Critical
# image 35 Critical
# image 40 Target Present
# image 48 Target Present
# image 54 Target Absent
# image 55 Target Absent
# image 56 Target Present
# image 58 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 10, 16, 40, 48, 54, 55, 56, 58]
# 60 60
# len(trials):  480

# %%
######################
### SECOND ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(481)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  3
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 1]
# critical present set:  []
# critical absent set:  ['2008_000972.jpg', '2008_001673.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg']
# probes_per_block : ['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg']
# probes:  [['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 19.803898838362514, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 19.906276626032106, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' sofa', ' tvmonitor', nan, nan, nan, 15.574047189150072, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [7, 15, 17, 19, 23, 25, 30, 39, 41, 51, 52, 53] 12
# gap_check:  [7, 30, 53]
# 12
# (7, 'Critical')
# (15, 'Target Present')
# (17, 'Target Present')
# (19, 'Target Absent')
# (23, 'Target Absent')
# (25, 'Target Present')
# (30, 'Critical')
# (39, 'Target Present')
# (41, 'Target Absent')
# (51, 'Target Absent')
# (52, 'Target Absent')
# (53, 'Critical')
# [(7, 'Critical'), (15, 'Target Present'), (17, 'Target Present'), (19, 'Target Absent'), (23, 'Target Absent'), (25, 'Target Present'), (30, 'Critical'), (39, 'Target Present'), (41, 'Target Absent'), (51, 'Target Absent'), (52, 'Target Absent'), (53, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Critical
# image 15 Target Present
# image 17 Target Present
# image 19 Target Absent
# image 23 Target Absent
# image 25 Target Present
# image 30 Critical
# image 39 Target Present
# image 41 Target Absent
# image 51 Target Absent
# image 52 Target Absent
# image 53 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [15, 17, 19, 23, 25, 39, 41, 51, 52]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 1]
# critical present set:  []
# critical absent set:  ['2008_000972.jpg', '2008_001673.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg']
# probes_per_block : ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg', '2008_005600.jpg', '2010_000792.jpg', '2008_002774.jpg', '2011_002482.jpg', '2008_007913.jpg']
# probes:  [['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg'], ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg', '2008_005600.jpg', '2010_000792.jpg', '2008_002774.jpg', '2011_002482.jpg', '2008_007913.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 30.39404844580157, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' sofa', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 33.937775623898794, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' sofa', ' chair', ' person', nan, nan, 34.56160823603891, 'high', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Critical
# image 15 Target Present
# image 17 Target Present
# image 19 Target Absent
# image 23 Target Absent
# image 25 Target Present
# image 30 Critical
# image 39 Target Present
# image 41 Target Absent
# image 51 Target Absent
# image 52 Target Absent
# image 53 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [15, 17, 19, 23, 25, 39, 41, 51, 52]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 1]
# critical present set:  []
# critical absent set:  ['2008_000972.jpg', '2008_001673.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_003530.jpg', '2010_005257.jpg', '2009_005036.jpg', '2008_000740.jpg', '2008_004607.jpg']
# probes_per_block : ['2009_003530.jpg', '2010_005257.jpg', '2009_005036.jpg', '2008_000740.jpg', '2008_004607.jpg', '2010_000109.jpg', '2008_007274.jpg', '2008_004907.jpg', '2009_002711.jpg']
# probes:  [['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg'], ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg', '2008_005600.jpg', '2010_000792.jpg', '2008_002774.jpg', '2011_002482.jpg', '2008_007913.jpg'], ['2009_003530.jpg', '2010_005257.jpg', '2009_005036.jpg', '2008_000740.jpg', '2008_004607.jpg', '2010_000109.jpg', '2008_007274.jpg', '2008_004907.jpg', '2009_002711.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 20.463883689453848, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 19.706122139777047, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 19.646066025131248, 'low', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [0, 6, 8, 16, 22, 25, 28, 33, 37, 39, 42, 45] 12
# gap_check:  [22, 25, 33]
# 12
# (0, 'Target Present')
# (6, 'Target Present')
# (8, 'Target Present')
# (16, 'Target Absent')
# (22, 'Critical')
# (25, 'Critical')
# (28, 'Target Present')
# (33, 'Critical')
# (37, 'Target Absent')
# (39, 'Target Present')
# (42, 'Target Absent')
# (45, 'Target Absent')
# [(0, 'Target Present'), (6, 'Target Present'), (8, 'Target Present'), (16, 'Target Absent'), (22, 'Critical'), (25, 'Critical'), (28, 'Target Present'), (33, 'Critical'), (37, 'Target Absent'), (39, 'Target Present'), (42, 'Target Absent'), (45, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Present
# image 6 Target Present
# image 8 Target Present
# image 16 Target Absent
# image 22 Critical
# image 25 Critical
# image 28 Target Present
# image 33 Critical
# image 37 Target Absent
# image 39 Target Present
# image 42 Target Absent
# image 45 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 6, 8, 16, 28, 37, 39, 42, 45]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 1]
# critical present set:  []
# critical absent set:  ['2008_000972.jpg', '2008_001673.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_006461.jpg', '2008_007108.jpg', '2008_000274.jpg', '2008_007091.jpg', '2008_004858.jpg']
# probes_per_block : ['2008_006461.jpg', '2008_007108.jpg', '2008_000274.jpg', '2008_007091.jpg', '2008_004858.jpg', '2009_001345.jpg', '2010_002472.jpg', '2008_008628.jpg', '2010_000536.jpg']
# probes:  [['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg'], ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg', '2008_005600.jpg', '2010_000792.jpg', '2008_002774.jpg', '2011_002482.jpg', '2008_007913.jpg'], ['2009_003530.jpg', '2010_005257.jpg', '2009_005036.jpg', '2008_000740.jpg', '2008_004607.jpg', '2010_000109.jpg', '2008_007274.jpg', '2008_004907.jpg', '2009_002711.jpg'], ['2008_006461.jpg', '2008_007108.jpg', '2008_000274.jpg', '2008_007091.jpg', '2008_004858.jpg', '2009_001345.jpg', '2010_002472.jpg', '2008_008628.jpg', '2010_000536.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 30.141763061562205, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' sofa', ' chair', nan, nan, nan, 32.351474210019695, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Present
# image 6 Target Present
# image 8 Target Present
# image 16 Target Absent
# image 22 Critical
# image 25 Critical
# image 28 Target Present
# image 33 Critical
# image 37 Target Absent
# image 39 Target Present
# image 42 Target Absent
# image 45 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 6, 8, 16, 28, 37, 39, 42, 45]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [1]
# critical present set:  []
# critical absent set:  ['2008_000972.jpg', '2008_001673.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_004129.jpg', '2009_003679.jpg', '2008_007208.jpg', '2011_001198.jpg']
# probes_per_block : ['2009_004129.jpg', '2009_003679.jpg', '2008_007208.jpg', '2011_001198.jpg', '2010_004175.jpg', '2008_005673.jpg', '2009_001406.jpg', '2011_001613.jpg', '2008_004893.jpg']
# probes:  [['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg'], ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg', '2008_005600.jpg', '2010_000792.jpg', '2008_002774.jpg', '2011_002482.jpg', '2008_007913.jpg'], ['2009_003530.jpg', '2010_005257.jpg', '2009_005036.jpg', '2008_000740.jpg', '2008_004607.jpg', '2010_000109.jpg', '2008_007274.jpg', '2008_004907.jpg', '2009_002711.jpg'], ['2008_006461.jpg', '2008_007108.jpg', '2008_000274.jpg', '2008_007091.jpg', '2008_004858.jpg', '2009_001345.jpg', '2010_002472.jpg', '2008_008628.jpg', '2010_000536.jpg'], ['2009_004129.jpg', '2009_003679.jpg', '2008_007208.jpg', '2011_001198.jpg', '2010_004175.jpg', '2008_005673.jpg', '2009_001406.jpg', '2011_001613.jpg', '2008_004893.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' dog', nan, nan, nan, 19.793376112600363, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' car', nan, nan, 20.934599857700228, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 20.088435845702712, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  240
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [3, 8, 11, 14, 17, 18, 23, 32, 37, 40, 44, 47] 12
# gap_check:  [3, 44, 47]
# 12
# (3, 'Critical')
# (8, 'Target Present')
# (11, 'Target Present')
# (14, 'Target Present')
# (17, 'Target Absent')
# (18, 'Target Absent')
# (23, 'Target Present')
# (32, 'Target Absent')
# (37, 'Target Absent')
# (40, 'Target Absent')
# (44, 'Critical')
# (47, 'Critical')
# [(3, 'Critical'), (8, 'Target Present'), (11, 'Target Present'), (14, 'Target Present'), (17, 'Target Absent'), (18, 'Target Absent'), (23, 'Target Present'), (32, 'Target Absent'), (37, 'Target Absent'), (40, 'Target Absent'), (44, 'Critical'), (47, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Critical
# image 8 Target Present
# image 11 Target Present
# image 14 Target Present
# image 17 Target Absent
# image 18 Target Absent
# image 23 Target Present
# image 32 Target Absent
# image 37 Target Absent
# image 40 Target Absent
# image 44 Critical
# image 47 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [8, 11, 14, 17, 18, 23, 32, 37, 40]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [1]
# critical present set:  []
# critical absent set:  ['2008_000972.jpg', '2008_001673.jpg']
# ---------------------------------------------------
# normal available: 146
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_002306.jpg', '2011_002641.jpg', '2011_001304.jpg', '2010_003297.jpg']
# probes_per_block : ['2009_002306.jpg', '2011_002641.jpg', '2011_001304.jpg', '2010_003297.jpg', '2008_003461.jpg', '2008_001576.jpg', '2008_005702.jpg', '2008_007057.jpg', '2008_005472.jpg']
# probes:  [['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg'], ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg', '2008_005600.jpg', '2010_000792.jpg', '2008_002774.jpg', '2011_002482.jpg', '2008_007913.jpg'], ['2009_003530.jpg', '2010_005257.jpg', '2009_005036.jpg', '2008_000740.jpg', '2008_004607.jpg', '2010_000109.jpg', '2008_007274.jpg', '2008_004907.jpg', '2009_002711.jpg'], ['2008_006461.jpg', '2008_007108.jpg', '2008_000274.jpg', '2008_007091.jpg', '2008_004858.jpg', '2009_001345.jpg', '2010_002472.jpg', '2008_008628.jpg', '2010_000536.jpg'], ['2009_004129.jpg', '2009_003679.jpg', '2008_007208.jpg', '2011_001198.jpg', '2010_004175.jpg', '2008_005673.jpg', '2009_001406.jpg', '2011_001613.jpg', '2008_004893.jpg'], ['2009_002306.jpg', '2011_002641.jpg', '2011_001304.jpg', '2010_003297.jpg', '2008_003461.jpg', '2008_001576.jpg', '2008_005702.jpg', '2008_007057.jpg', '2008_005472.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' chair', nan, nan, nan, 37.05291171015417, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' tvmonitor', ' chair', ' sofa', nan, 35.63660420168497, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 34.96752773409758, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  288
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Critical
# image 8 Target Present
# image 11 Target Present
# image 14 Target Present
# image 17 Target Absent
# image 18 Target Absent
# image 23 Target Present
# image 32 Target Absent
# image 37 Target Absent
# image 40 Target Absent
# image 44 Critical
# image 47 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [8, 11, 14, 17, 18, 23, 32, 37, 40]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2008_000972.jpg', '2008_001673.jpg']
# ---------------------------------------------------
# normal available: 98
# present_critical_per_block: []
# absent_critical_per_block: ['2008_000972.jpg']
# critical_present:  []
# critical_absent:  [['2008_000972.jpg']]
# critical_probes_used:  ['2008_000972.jpg']
# probes_per_block : ['2008_000177.jpg', '2008_000189.jpg', '2009_001723.jpg', '2010_002283.jpg', '2011_001591.jpg']
# probes_per_block : ['2008_000177.jpg', '2008_000189.jpg', '2009_001723.jpg', '2010_002283.jpg', '2011_001591.jpg', '2009_003209.jpg', '2008_003876.jpg', '2010_000811.jpg']
# probes:  [['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg'], ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg', '2008_005600.jpg', '2010_000792.jpg', '2008_002774.jpg', '2011_002482.jpg', '2008_007913.jpg'], ['2009_003530.jpg', '2010_005257.jpg', '2009_005036.jpg', '2008_000740.jpg', '2008_004607.jpg', '2010_000109.jpg', '2008_007274.jpg', '2008_004907.jpg', '2009_002711.jpg'], ['2008_006461.jpg', '2008_007108.jpg', '2008_000274.jpg', '2008_007091.jpg', '2008_004858.jpg', '2009_001345.jpg', '2010_002472.jpg', '2008_008628.jpg', '2010_000536.jpg'], ['2009_004129.jpg', '2009_003679.jpg', '2008_007208.jpg', '2011_001198.jpg', '2010_004175.jpg', '2008_005673.jpg', '2009_001406.jpg', '2011_001613.jpg', '2008_004893.jpg'], ['2009_002306.jpg', '2011_002641.jpg', '2011_001304.jpg', '2010_003297.jpg', '2008_003461.jpg', '2008_001576.jpg', '2008_005702.jpg', '2008_007057.jpg', '2008_005472.jpg'], ['2008_000177.jpg', '2008_000189.jpg', '2009_001723.jpg', '2010_002283.jpg', '2011_001591.jpg', '2009_003209.jpg', '2008_003876.jpg', '2010_000811.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' boat', nan, nan, nan, nan, 20.21004370358339, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 16.146154777978307, 'low', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  337
# critical_probes_used ['2008_000972.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [7, 16, 23, 32, 37, 43, 44, 49, 50, 54, 59] 11
# gap_check:  [16, 32, 50]
# 11
# (7, 'Target Absent')
# (16, 'Critical')
# (23, 'Target Present')
# (32, 'Critical Absent')
# (37, 'Target Absent')
# (43, 'Target Absent')
# (44, 'Target Present')
# (49, 'Target Present')
# (50, 'Critical')
# (54, 'Target Present')
# (59, 'Target Present')
# [(7, 'Target Absent'), (16, 'Critical'), (23, 'Target Present'), (32, 'Critical Absent'), (37, 'Target Absent'), (43, 'Target Absent'), (44, 'Target Present'), (49, 'Target Present'), (50, 'Critical'), (54, 'Target Present'), (59, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Absent
# image 16 Critical
# image 23 Target Present
# image 32 Critical Absent
# image 37 Target Absent
# image 43 Target Absent
# image 44 Target Present
# image 49 Target Present
# image 50 Critical
# image 54 Target Present
# image 59 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [7, 23, 32, 37, 43, 44, 49, 54, 59]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2008_000972.jpg', '2008_001673.jpg']
# ---------------------------------------------------
# normal available: 49
# present_critical_per_block: []
# absent_critical_per_block: ['2008_001673.jpg']
# critical_present:  []
# critical_absent:  [['2008_000972.jpg'], ['2008_001673.jpg']]
# critical_probes_used:  ['2008_000972.jpg', '2008_001673.jpg']
# probes_per_block : ['2008_000982.jpg', '2009_004154.jpg', '2008_002725.jpg', '2008_001278.jpg', '2009_003705.jpg']
# probes_per_block : ['2008_000982.jpg', '2009_004154.jpg', '2008_002725.jpg', '2008_001278.jpg', '2009_003705.jpg', '2008_006841.jpg', '2008_000251.jpg', '2009_000466.jpg']
# probes:  [['2010_004339.jpg', '2011_002303.jpg', '2011_000224.jpg', '2009_000619.jpg', '2008_007842.jpg', '2008_002372.jpg', '2009_002325.jpg', '2008_005345.jpg', '2009_000716.jpg'], ['2008_004188.jpg', '2011_000824.jpg', '2008_002709.jpg', '2008_003755.jpg', '2008_005600.jpg', '2010_000792.jpg', '2008_002774.jpg', '2011_002482.jpg', '2008_007913.jpg'], ['2009_003530.jpg', '2010_005257.jpg', '2009_005036.jpg', '2008_000740.jpg', '2008_004607.jpg', '2010_000109.jpg', '2008_007274.jpg', '2008_004907.jpg', '2009_002711.jpg'], ['2008_006461.jpg', '2008_007108.jpg', '2008_000274.jpg', '2008_007091.jpg', '2008_004858.jpg', '2009_001345.jpg', '2010_002472.jpg', '2008_008628.jpg', '2010_000536.jpg'], ['2009_004129.jpg', '2009_003679.jpg', '2008_007208.jpg', '2011_001198.jpg', '2010_004175.jpg', '2008_005673.jpg', '2009_001406.jpg', '2011_001613.jpg', '2008_004893.jpg'], ['2009_002306.jpg', '2011_002641.jpg', '2011_001304.jpg', '2010_003297.jpg', '2008_003461.jpg', '2008_001576.jpg', '2008_005702.jpg', '2008_007057.jpg', '2008_005472.jpg'], ['2008_000177.jpg', '2008_000189.jpg', '2009_001723.jpg', '2010_002283.jpg', '2011_001591.jpg', '2009_003209.jpg', '2008_003876.jpg', '2010_000811.jpg'], ['2008_000982.jpg', '2009_004154.jpg', '2008_002725.jpg', '2008_001278.jpg', '2009_003705.jpg', '2008_006841.jpg', '2008_000251.jpg', '2009_000466.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' cat', nan, nan, nan, 29.867994035114002, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 30.182885716527558, 'high', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  386
# critical_probes_used ['2008_000972.jpg', '2008_001673.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Absent
# image 16 Critical
# image 23 Target Present
# image 32 Critical Absent
# image 37 Target Absent
# image 43 Target Absent
# image 44 Target Present
# image 49 Target Present
# image 50 Critical
# image 54 Target Present
# image 59 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [7, 23, 32, 37, 43, 44, 49, 54, 59]
# 60 60
# len(trials):  960

# %%
######################
### THIRD ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(961)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  12
# Critical, high:  12
# Are all critical trials unique?  True
# Number of critical probes:  0
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  0
# critical_high_absent_probes:  0
# cycles :  16
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  []
# critical absent set:  []
# ---------------------------------------------------
# normal available: 384
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg']
# probes_per_block : ['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg']
# probes:  [['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' sofa', nan, nan, nan, 19.244035875135978, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 15.553393150912814, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 9.57686770873812, 'low', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [6, 11, 17, 21, 27, 28, 30, 33, 38, 40, 46, 54] 12
# gap_check:  [17, 30, 40]
# 12
# (6, 'Target Present')
# (11, 'Target Present')
# (17, 'Critical')
# (21, 'Target Absent')
# (27, 'Target Present')
# (28, 'Target Absent')
# (30, 'Critical')
# (33, 'Target Absent')
# (38, 'Target Present')
# (40, 'Critical')
# (46, 'Target Absent')
# (54, 'Target Absent')
# [(6, 'Target Present'), (11, 'Target Present'), (17, 'Critical'), (21, 'Target Absent'), (27, 'Target Present'), (28, 'Target Absent'), (30, 'Critical'), (33, 'Target Absent'), (38, 'Target Present'), (40, 'Critical'), (46, 'Target Absent'), (54, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Present
# image 11 Target Present
# image 17 Critical
# image 21 Target Absent
# image 27 Target Present
# image 28 Target Absent
# image 30 Critical
# image 33 Target Absent
# image 38 Target Present
# image 40 Critical
# image 46 Target Absent
# image 54 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [6, 11, 21, 27, 28, 33, 38, 46, 54]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  []
# critical absent set:  []
# ---------------------------------------------------
# normal available: 336
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg']
# probes_per_block : ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg', '2011_001991.jpg', '2008_004614.jpg', '2011_001221.jpg', '2008_002195.jpg', '2011_000824.jpg']
# probes:  [['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg'], ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg', '2011_001991.jpg', '2008_004614.jpg', '2011_001221.jpg', '2008_002195.jpg', '2011_000824.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 30.92721034000856, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' dog', nan, 34.099790178372324, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Present
# image 11 Target Present
# image 17 Critical
# image 21 Target Absent
# image 27 Target Present
# image 28 Target Absent
# image 30 Critical
# image 33 Target Absent
# image 38 Target Present
# image 40 Critical
# image 46 Target Absent
# image 54 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [6, 11, 21, 27, 28, 33, 38, 46, 54]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  []
# critical absent set:  []
# ---------------------------------------------------
# normal available: 288
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_000619.jpg', '2010_002956.jpg', '2008_008331.jpg', '2010_005391.jpg', '2010_004753.jpg']
# probes_per_block : ['2009_000619.jpg', '2010_002956.jpg', '2008_008331.jpg', '2010_005391.jpg', '2010_004753.jpg', '2010_000811.jpg', '2011_002558.jpg', '2008_000760.jpg', '2009_002803.jpg']
# probes:  [['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg'], ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg', '2011_001991.jpg', '2008_004614.jpg', '2011_001221.jpg', '2008_002195.jpg', '2011_000824.jpg'], ['2009_000619.jpg', '2010_002956.jpg', '2008_008331.jpg', '2010_005391.jpg', '2010_004753.jpg', '2010_000811.jpg', '2011_002558.jpg', '2008_000760.jpg', '2009_002803.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' person', nan, nan, nan, 13.786733463571188, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 20.850125265290927, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 17.997748470093857, 'low', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [1, 6, 7, 11, 16, 19, 26, 28, 29, 39, 40, 42] 12
# gap_check:  [1, 16, 29]
# 12
# (1, 'Critical')
# (6, 'Target Present')
# (7, 'Target Present')
# (11, 'Target Present')
# (16, 'Critical')
# (19, 'Target Present')
# (26, 'Target Absent')
# (28, 'Target Present')
# (29, 'Critical')
# (39, 'Target Absent')
# (40, 'Target Absent')
# (42, 'Target Absent')
# [(1, 'Critical'), (6, 'Target Present'), (7, 'Target Present'), (11, 'Target Present'), (16, 'Critical'), (19, 'Target Present'), (26, 'Target Absent'), (28, 'Target Present'), (29, 'Critical'), (39, 'Target Absent'), (40, 'Target Absent'), (42, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical
# image 6 Target Present
# image 7 Target Present
# image 11 Target Present
# image 16 Critical
# image 19 Target Present
# image 26 Target Absent
# image 28 Target Present
# image 29 Critical
# image 39 Target Absent
# image 40 Target Absent
# image 42 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [6, 7, 11, 19, 26, 28, 39, 40, 42]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  []
# critical absent set:  []
# ---------------------------------------------------
# normal available: 240
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_002350.jpg', '2010_000792.jpg', '2008_000196.jpg', '2008_002037.jpg', '2011_001880.jpg']
# probes_per_block : ['2008_002350.jpg', '2010_000792.jpg', '2008_000196.jpg', '2008_002037.jpg', '2011_001880.jpg', '2008_004858.jpg', '2010_002472.jpg', '2010_002620.jpg', '2009_004154.jpg']
# probes:  [['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg'], ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg', '2011_001991.jpg', '2008_004614.jpg', '2011_001221.jpg', '2008_002195.jpg', '2011_000824.jpg'], ['2009_000619.jpg', '2010_002956.jpg', '2008_008331.jpg', '2010_005391.jpg', '2010_004753.jpg', '2010_000811.jpg', '2011_002558.jpg', '2008_000760.jpg', '2009_002803.jpg'], ['2008_002350.jpg', '2010_000792.jpg', '2008_000196.jpg', '2008_002037.jpg', '2011_001880.jpg', '2008_004858.jpg', '2010_002472.jpg', '2010_002620.jpg', '2009_004154.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' tvmonitor', ' chair', ' sofa', nan, 35.63660420168497, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 35.94715000296663, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' dog', ' sofa', nan, nan, 29.935618386927253, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical
# image 6 Target Present
# image 7 Target Present
# image 11 Target Present
# image 16 Critical
# image 19 Target Present
# image 26 Target Absent
# image 28 Target Present
# image 29 Critical
# image 39 Target Absent
# image 40 Target Absent
# image 42 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [6, 7, 11, 19, 26, 28, 39, 40, 42]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  []
# ---------------------------------------------------
# normal available: 192
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_007842.jpg', '2008_000839.jpg', '2010_003746.jpg', '2010_004791.jpg']
# probes_per_block : ['2008_007842.jpg', '2008_000839.jpg', '2010_003746.jpg', '2010_004791.jpg', '2010_003287.jpg', '2009_002711.jpg', '2010_003101.jpg', '2009_002594.jpg', '2009_002697.jpg']
# probes:  [['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg'], ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg', '2011_001991.jpg', '2008_004614.jpg', '2011_001221.jpg', '2008_002195.jpg', '2011_000824.jpg'], ['2009_000619.jpg', '2010_002956.jpg', '2008_008331.jpg', '2010_005391.jpg', '2010_004753.jpg', '2010_000811.jpg', '2011_002558.jpg', '2008_000760.jpg', '2009_002803.jpg'], ['2008_002350.jpg', '2010_000792.jpg', '2008_000196.jpg', '2008_002037.jpg', '2011_001880.jpg', '2008_004858.jpg', '2010_002472.jpg', '2010_002620.jpg', '2009_004154.jpg'], ['2008_007842.jpg', '2008_000839.jpg', '2010_003746.jpg', '2010_004791.jpg', '2010_003287.jpg', '2009_002711.jpg', '2010_003101.jpg', '2009_002594.jpg', '2009_002697.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bottle', ' dog', ' diningtable', nan, nan, 21.034646910874567, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 8.17124474061747, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 18.720728543179284, 'low', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  240
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [1, 5, 11, 15, 18, 19, 22, 25, 31, 38, 40, 46] 12
# gap_check:  [15, 40, 46]
# 12
# (1, 'Target Absent')
# (5, 'Target Absent')
# (11, 'Target Present')
# (15, 'Critical')
# (18, 'Target Absent')
# (19, 'Target Absent')
# (22, 'Target Present')
# (25, 'Target Present')
# (31, 'Target Absent')
# (38, 'Target Present')
# (40, 'Critical')
# (46, 'Critical')
# [(1, 'Target Absent'), (5, 'Target Absent'), (11, 'Target Present'), (15, 'Critical'), (18, 'Target Absent'), (19, 'Target Absent'), (22, 'Target Present'), (25, 'Target Present'), (31, 'Target Absent'), (38, 'Target Present'), (40, 'Critical'), (46, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 5 Target Absent
# image 11 Target Present
# image 15 Critical
# image 18 Target Absent
# image 19 Target Absent
# image 22 Target Present
# image 25 Target Present
# image 31 Target Absent
# image 38 Target Present
# image 40 Critical
# image 46 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 5, 11, 18, 19, 22, 25, 31, 38]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  []
# ---------------------------------------------------
# normal available: 144
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2011_000631.jpg', '2008_003378.jpg', '2011_002641.jpg', '2011_001025.jpg']
# probes_per_block : ['2011_000631.jpg', '2008_003378.jpg', '2011_002641.jpg', '2011_001025.jpg', '2009_003520.jpg', '2010_001856.jpg', '2011_001944.jpg', '2008_000321.jpg', '2010_003297.jpg']
# probes:  [['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg'], ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg', '2011_001991.jpg', '2008_004614.jpg', '2011_001221.jpg', '2008_002195.jpg', '2011_000824.jpg'], ['2009_000619.jpg', '2010_002956.jpg', '2008_008331.jpg', '2010_005391.jpg', '2010_004753.jpg', '2010_000811.jpg', '2011_002558.jpg', '2008_000760.jpg', '2009_002803.jpg'], ['2008_002350.jpg', '2010_000792.jpg', '2008_000196.jpg', '2008_002037.jpg', '2011_001880.jpg', '2008_004858.jpg', '2010_002472.jpg', '2010_002620.jpg', '2009_004154.jpg'], ['2008_007842.jpg', '2008_000839.jpg', '2010_003746.jpg', '2010_004791.jpg', '2010_003287.jpg', '2009_002711.jpg', '2010_003101.jpg', '2009_002594.jpg', '2009_002697.jpg'], ['2011_000631.jpg', '2008_003378.jpg', '2011_002641.jpg', '2011_001025.jpg', '2009_003520.jpg', '2010_001856.jpg', '2011_001944.jpg', '2008_000321.jpg', '2010_003297.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', ' aeroplane', nan, nan, nan, 35.87217940794205, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 31.19357078875772, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 29.739677956098852, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  288
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 5 Target Absent
# image 11 Target Present
# image 15 Critical
# image 18 Target Absent
# image 19 Target Absent
# image 22 Target Present
# image 25 Target Present
# image 31 Target Absent
# image 38 Target Present
# image 40 Critical
# image 46 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 5, 11, 18, 19, 22, 25, 31, 38]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  []
# ---------------------------------------------------
# normal available: 96
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_003369.jpg', '2009_005008.jpg', '2008_005869.jpg', '2009_004888.jpg', '2008_004893.jpg']
# probes_per_block : ['2008_003369.jpg', '2009_005008.jpg', '2008_005869.jpg', '2009_004888.jpg', '2008_004893.jpg', '2008_002899.jpg', '2008_002145.jpg', '2009_000059.jpg', '2011_002050.jpg']
# probes:  [['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg'], ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg', '2011_001991.jpg', '2008_004614.jpg', '2011_001221.jpg', '2008_002195.jpg', '2011_000824.jpg'], ['2009_000619.jpg', '2010_002956.jpg', '2008_008331.jpg', '2010_005391.jpg', '2010_004753.jpg', '2010_000811.jpg', '2011_002558.jpg', '2008_000760.jpg', '2009_002803.jpg'], ['2008_002350.jpg', '2010_000792.jpg', '2008_000196.jpg', '2008_002037.jpg', '2011_001880.jpg', '2008_004858.jpg', '2010_002472.jpg', '2010_002620.jpg', '2009_004154.jpg'], ['2008_007842.jpg', '2008_000839.jpg', '2010_003746.jpg', '2010_004791.jpg', '2010_003287.jpg', '2009_002711.jpg', '2010_003101.jpg', '2009_002594.jpg', '2009_002697.jpg'], ['2011_000631.jpg', '2008_003378.jpg', '2011_002641.jpg', '2011_001025.jpg', '2009_003520.jpg', '2010_001856.jpg', '2011_001944.jpg', '2008_000321.jpg', '2010_003297.jpg'], ['2008_003369.jpg', '2009_005008.jpg', '2008_005869.jpg', '2009_004888.jpg', '2008_004893.jpg', '2008_002899.jpg', '2008_002145.jpg', '2009_000059.jpg', '2011_002050.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 19.75925599841011, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 9.955368400707393, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' sofa', nan, nan, nan, nan, 17.316646037114566, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  336
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [0, 7, 16, 19, 21, 26, 32, 37, 42, 46, 52, 53] 12
# gap_check:  [16, 32, 42]
# 12
# (0, 'Target Absent')
# (7, 'Target Present')
# (16, 'Critical')
# (19, 'Target Present')
# (21, 'Target Absent')
# (26, 'Target Absent')
# (32, 'Critical')
# (37, 'Target Absent')
# (42, 'Critical')
# (46, 'Target Present')
# (52, 'Target Present')
# (53, 'Target Present')
# [(0, 'Target Absent'), (7, 'Target Present'), (16, 'Critical'), (19, 'Target Present'), (21, 'Target Absent'), (26, 'Target Absent'), (32, 'Critical'), (37, 'Target Absent'), (42, 'Critical'), (46, 'Target Present'), (52, 'Target Present'), (53, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 7 Target Present
# image 16 Critical
# image 19 Target Present
# image 21 Target Absent
# image 26 Target Absent
# image 32 Critical
# image 37 Target Absent
# image 42 Critical
# image 46 Target Present
# image 52 Target Present
# image 53 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 7, 19, 21, 26, 37, 46, 52, 53]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  []
# ---------------------------------------------------
# normal available: 48
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_005606.jpg', '2010_002183.jpg', '2009_000760.jpg', '2008_005750.jpg', '2008_000704.jpg']
# probes_per_block : ['2010_005606.jpg', '2010_002183.jpg', '2009_000760.jpg', '2008_005750.jpg', '2008_000704.jpg', '2009_000539.jpg', '2010_004778.jpg', '2008_007108.jpg', '2010_002702.jpg']
# probes:  [['2010_003280.jpg', '2009_003373.jpg', '2008_001098.jpg', '2008_007048.jpg', '2010_005885.jpg', '2008_003587.jpg', '2008_005673.jpg', '2009_001723.jpg', '2009_001568.jpg'], ['2008_007091.jpg', '2009_004849.jpg', '2010_003419.jpg', '2008_006663.jpg', '2011_001991.jpg', '2008_004614.jpg', '2011_001221.jpg', '2008_002195.jpg', '2011_000824.jpg'], ['2009_000619.jpg', '2010_002956.jpg', '2008_008331.jpg', '2010_005391.jpg', '2010_004753.jpg', '2010_000811.jpg', '2011_002558.jpg', '2008_000760.jpg', '2009_002803.jpg'], ['2008_002350.jpg', '2010_000792.jpg', '2008_000196.jpg', '2008_002037.jpg', '2011_001880.jpg', '2008_004858.jpg', '2010_002472.jpg', '2010_002620.jpg', '2009_004154.jpg'], ['2008_007842.jpg', '2008_000839.jpg', '2010_003746.jpg', '2010_004791.jpg', '2010_003287.jpg', '2009_002711.jpg', '2010_003101.jpg', '2009_002594.jpg', '2009_002697.jpg'], ['2011_000631.jpg', '2008_003378.jpg', '2011_002641.jpg', '2011_001025.jpg', '2009_003520.jpg', '2010_001856.jpg', '2011_001944.jpg', '2008_000321.jpg', '2010_003297.jpg'], ['2008_003369.jpg', '2009_005008.jpg', '2008_005869.jpg', '2009_004888.jpg', '2008_004893.jpg', '2008_002899.jpg', '2008_002145.jpg', '2009_000059.jpg', '2011_002050.jpg'], ['2010_005606.jpg', '2010_002183.jpg', '2009_000760.jpg', '2008_005750.jpg', '2008_000704.jpg', '2009_000539.jpg', '2010_004778.jpg', '2008_007108.jpg', '2010_002702.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' person', ' motorbike', nan, nan, 34.41600543331538, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' bird', ' boat', nan, nan, nan, 29.314233597971626, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' dog', ' bottle', 31.05804957013649, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  384
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 7 Target Present
# image 16 Critical
# image 19 Target Present
# image 21 Target Absent
# image 26 Target Absent
# image 32 Critical
# image 37 Target Absent
# image 42 Critical
# image 46 Target Present
# image 52 Target Present
# image 53 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 7, 19, 21, 26, 37, 46, 52, 53]
# 60 60
# len(trials):  1440

# %%
######################
### FOURTH ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1441)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  28
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2011_002050.jpg', '2008_006870.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg']
# probes_per_block : ['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg']
# probes:  [['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bottle', nan, nan, nan, nan, 19.096237359535362, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 17.49302399164143, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 20.041574567240037, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [3, 12, 18, 21, 27, 36, 39, 42, 45, 48, 55, 59] 12
# gap_check:  [18, 42, 59]
# 12
# (3, 'Target Present')
# (12, 'Target Absent')
# (18, 'Critical')
# (21, 'Target Absent')
# (27, 'Target Absent')
# (36, 'Target Present')
# (39, 'Target Absent')
# (42, 'Critical')
# (45, 'Target Absent')
# (48, 'Target Present')
# (55, 'Target Present')
# (59, 'Critical')
# [(3, 'Target Present'), (12, 'Target Absent'), (18, 'Critical'), (21, 'Target Absent'), (27, 'Target Absent'), (36, 'Target Present'), (39, 'Target Absent'), (42, 'Critical'), (45, 'Target Absent'), (48, 'Target Present'), (55, 'Target Present'), (59, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 12 Target Absent
# image 18 Critical
# image 21 Target Absent
# image 27 Target Absent
# image 36 Target Present
# image 39 Target Absent
# image 42 Critical
# image 45 Target Absent
# image 48 Target Present
# image 55 Target Present
# image 59 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 12, 21, 27, 36, 39, 45, 48, 55]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2011_002050.jpg', '2008_006870.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg']
# probes_per_block : ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg', '2008_006481.jpg', '2008_003755.jpg', '2008_000860.jpg', '2011_002641.jpg', '2008_000928.jpg']
# probes:  [['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg'], ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg', '2008_006481.jpg', '2008_003755.jpg', '2008_000860.jpg', '2011_002641.jpg', '2008_000928.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 31.397027824172856, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' motorbike', ' boat', 31.58048990210689, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 31.31059992348976, 'high', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 12 Target Absent
# image 18 Critical
# image 21 Target Absent
# image 27 Target Absent
# image 36 Target Present
# image 39 Target Absent
# image 42 Critical
# image 45 Target Absent
# image 48 Target Present
# image 55 Target Present
# image 59 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 12, 21, 27, 36, 39, 45, 48, 55]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2011_002050.jpg', '2008_006870.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_003209.jpg', '2008_000740.jpg', '2009_000919.jpg', '2009_005075.jpg', '2011_000224.jpg']
# probes_per_block : ['2009_003209.jpg', '2008_000740.jpg', '2009_000919.jpg', '2009_005075.jpg', '2011_000224.jpg', '2011_002303.jpg', '2009_005308.jpg', '2009_000619.jpg', '2008_003369.jpg']
# probes:  [['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg'], ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg', '2008_006481.jpg', '2008_003755.jpg', '2008_000860.jpg', '2011_002641.jpg', '2008_000928.jpg'], ['2009_003209.jpg', '2008_000740.jpg', '2009_000919.jpg', '2009_005075.jpg', '2011_000224.jpg', '2011_002303.jpg', '2009_005308.jpg', '2009_000619.jpg', '2008_003369.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 19.4399393845732, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 19.793376112600363, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 19.735592352687934, 'low', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [7, 10, 18, 26, 27, 28, 29, 33, 37, 38, 47, 57] 12
# gap_check:  [10, 18, 57]
# 12
# (7, 'Target Present')
# (10, 'Critical')
# (18, 'Critical')
# (26, 'Target Present')
# (27, 'Target Absent')
# (28, 'Target Absent')
# (29, 'Target Present')
# (33, 'Target Present')
# (37, 'Target Present')
# (38, 'Target Absent')
# (47, 'Target Absent')
# (57, 'Critical')
# [(7, 'Target Present'), (10, 'Critical'), (18, 'Critical'), (26, 'Target Present'), (27, 'Target Absent'), (28, 'Target Absent'), (29, 'Target Present'), (33, 'Target Present'), (37, 'Target Present'), (38, 'Target Absent'), (47, 'Target Absent'), (57, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 10 Critical
# image 18 Critical
# image 26 Target Present
# image 27 Target Absent
# image 28 Target Absent
# image 29 Target Present
# image 33 Target Present
# image 37 Target Present
# image 38 Target Absent
# image 47 Target Absent
# image 57 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [7, 26, 27, 28, 29, 33, 37, 38, 47]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2011_002050.jpg', '2008_006870.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_002084.jpg', '2009_000488.jpg', '2008_003081.jpg', '2010_005996.jpg', '2008_000984.jpg']
# probes_per_block : ['2008_002084.jpg', '2009_000488.jpg', '2008_003081.jpg', '2010_005996.jpg', '2008_000984.jpg', '2010_000074.jpg', '2011_001649.jpg', '2008_004614.jpg', '2008_004459.jpg']
# probes:  [['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg'], ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg', '2008_006481.jpg', '2008_003755.jpg', '2008_000860.jpg', '2011_002641.jpg', '2008_000928.jpg'], ['2009_003209.jpg', '2008_000740.jpg', '2009_000919.jpg', '2009_005075.jpg', '2011_000224.jpg', '2011_002303.jpg', '2009_005308.jpg', '2009_000619.jpg', '2008_003369.jpg'], ['2008_002084.jpg', '2009_000488.jpg', '2008_003081.jpg', '2010_005996.jpg', '2008_000984.jpg', '2010_000074.jpg', '2011_001649.jpg', '2008_004614.jpg', '2008_004459.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' tvmonitor', ' chair', ' sofa', nan, 35.63660420168497, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' dog', nan, nan, nan, 28.66363347517436, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' bottle', ' diningtable', nan, 35.13485651284549, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 10 Critical
# image 18 Critical
# image 26 Target Present
# image 27 Target Absent
# image 28 Target Absent
# image 29 Target Present
# image 33 Target Present
# image 37 Target Present
# image 38 Target Absent
# image 47 Target Absent
# image 57 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [7, 26, 27, 28, 29, 33, 37, 38, 47]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2011_002050.jpg', '2008_006870.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: ['2011_002050.jpg']
# critical_present:  []
# critical_absent:  [['2011_002050.jpg']]
# critical_probes_used:  ['2011_002050.jpg']
# probes_per_block : ['2008_008083.jpg', '2011_000661.jpg', '2010_001271.jpg', '2008_000163.jpg']
# probes_per_block : ['2008_008083.jpg', '2011_000661.jpg', '2010_001271.jpg', '2008_000163.jpg', '2008_004907.jpg', '2008_004624.jpg', '2008_000189.jpg', '2008_002062.jpg']
# probes:  [['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg'], ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg', '2008_006481.jpg', '2008_003755.jpg', '2008_000860.jpg', '2011_002641.jpg', '2008_000928.jpg'], ['2009_003209.jpg', '2008_000740.jpg', '2009_000919.jpg', '2009_005075.jpg', '2011_000224.jpg', '2011_002303.jpg', '2009_005308.jpg', '2009_000619.jpg', '2008_003369.jpg'], ['2008_002084.jpg', '2009_000488.jpg', '2008_003081.jpg', '2010_005996.jpg', '2008_000984.jpg', '2010_000074.jpg', '2011_001649.jpg', '2008_004614.jpg', '2008_004459.jpg'], ['2008_008083.jpg', '2011_000661.jpg', '2010_001271.jpg', '2008_000163.jpg', '2008_004907.jpg', '2008_004624.jpg', '2008_000189.jpg', '2008_002062.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 16.876667793733738, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 19.598131175056185, 'low', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  241
# critical_probes_used ['2011_002050.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [5, 9, 10, 19, 27, 31, 38, 42, 44, 45, 51] 11
# gap_check:  [31, 38, 45]
# 11
# (5, 'Target Present')
# (9, 'Target Present')
# (10, 'Target Absent')
# (19, 'Target Absent')
# (27, 'Target Absent')
# (31, 'Critical')
# (38, 'Critical')
# (42, 'Target Present')
# (44, 'Target Present')
# (45, 'Critical Absent')
# (51, 'Target Absent')
# [(5, 'Target Present'), (9, 'Target Present'), (10, 'Target Absent'), (19, 'Target Absent'), (27, 'Target Absent'), (31, 'Critical'), (38, 'Critical'), (42, 'Target Present'), (44, 'Target Present'), (45, 'Critical Absent'), (51, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Present
# image 9 Target Present
# image 10 Target Absent
# image 19 Target Absent
# image 27 Target Absent
# image 31 Critical
# image 38 Critical
# image 42 Target Present
# image 44 Target Present
# image 45 Critical Absent
# image 51 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 9, 10, 19, 27, 42, 44, 45, 51]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2011_002050.jpg', '2008_006870.jpg']
# ---------------------------------------------------
# normal available: 145
# present_critical_per_block: []
# absent_critical_per_block: ['2008_006870.jpg']
# critical_present:  []
# critical_absent:  [['2011_002050.jpg'], ['2008_006870.jpg']]
# critical_probes_used:  ['2011_002050.jpg', '2008_006870.jpg']
# probes_per_block : ['2008_006841.jpg', '2008_004991.jpg', '2011_002260.jpg', '2009_003802.jpg']
# probes_per_block : ['2008_006841.jpg', '2008_004991.jpg', '2011_002260.jpg', '2009_003802.jpg', '2011_002193.jpg', '2008_005818.jpg', '2008_000270.jpg', '2008_002709.jpg']
# probes:  [['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg'], ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg', '2008_006481.jpg', '2008_003755.jpg', '2008_000860.jpg', '2011_002641.jpg', '2008_000928.jpg'], ['2009_003209.jpg', '2008_000740.jpg', '2009_000919.jpg', '2009_005075.jpg', '2011_000224.jpg', '2011_002303.jpg', '2009_005308.jpg', '2009_000619.jpg', '2008_003369.jpg'], ['2008_002084.jpg', '2009_000488.jpg', '2008_003081.jpg', '2010_005996.jpg', '2008_000984.jpg', '2010_000074.jpg', '2011_001649.jpg', '2008_004614.jpg', '2008_004459.jpg'], ['2008_008083.jpg', '2011_000661.jpg', '2010_001271.jpg', '2008_000163.jpg', '2008_004907.jpg', '2008_004624.jpg', '2008_000189.jpg', '2008_002062.jpg'], ['2008_006841.jpg', '2008_004991.jpg', '2011_002260.jpg', '2009_003802.jpg', '2011_002193.jpg', '2008_005818.jpg', '2008_000270.jpg', '2008_002709.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' pottedplant', ' sofa', ' chair', nan, nan, 31.427287995992387, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 32.014973550332165, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  290
# critical_probes_used ['2011_002050.jpg', '2008_006870.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Present
# image 9 Target Present
# image 10 Target Absent
# image 19 Target Absent
# image 27 Target Absent
# image 31 Critical
# image 38 Critical
# image 42 Target Present
# image 44 Target Present
# image 45 Critical Absent
# image 51 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 9, 10, 19, 27, 42, 44, 45, 51]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2011_002050.jpg', '2008_006870.jpg']
# ---------------------------------------------------
# normal available: 96
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2011_002050.jpg'], ['2008_006870.jpg']]
# critical_probes_used:  ['2011_002050.jpg', '2008_006870.jpg']
# probes_per_block : ['2008_006452.jpg', '2008_000972.jpg', '2008_001185.jpg', '2009_004888.jpg', '2010_004145.jpg']
# probes_per_block : ['2008_006452.jpg', '2008_000972.jpg', '2008_001185.jpg', '2009_004888.jpg', '2010_004145.jpg', '2008_000112.jpg', '2008_000123.jpg', '2009_002697.jpg', '2008_000119.jpg']
# probes:  [['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg'], ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg', '2008_006481.jpg', '2008_003755.jpg', '2008_000860.jpg', '2011_002641.jpg', '2008_000928.jpg'], ['2009_003209.jpg', '2008_000740.jpg', '2009_000919.jpg', '2009_005075.jpg', '2011_000224.jpg', '2011_002303.jpg', '2009_005308.jpg', '2009_000619.jpg', '2008_003369.jpg'], ['2008_002084.jpg', '2009_000488.jpg', '2008_003081.jpg', '2010_005996.jpg', '2008_000984.jpg', '2010_000074.jpg', '2011_001649.jpg', '2008_004614.jpg', '2008_004459.jpg'], ['2008_008083.jpg', '2011_000661.jpg', '2010_001271.jpg', '2008_000163.jpg', '2008_004907.jpg', '2008_004624.jpg', '2008_000189.jpg', '2008_002062.jpg'], ['2008_006841.jpg', '2008_004991.jpg', '2011_002260.jpg', '2009_003802.jpg', '2011_002193.jpg', '2008_005818.jpg', '2008_000270.jpg', '2008_002709.jpg'], ['2008_006452.jpg', '2008_000972.jpg', '2008_001185.jpg', '2009_004888.jpg', '2010_004145.jpg', '2008_000112.jpg', '2008_000123.jpg', '2009_002697.jpg', '2008_000119.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', ' person', nan, nan, nan, 17.856305662122608, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' sofa', ' person', nan, nan, nan, 20.983298059388602, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' chair', nan, nan, nan, 16.606806579152448, 'low', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  338
# critical_probes_used ['2011_002050.jpg', '2008_006870.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [3, 7, 8, 9, 11, 19, 25, 34, 43, 45, 52, 55] 12
# gap_check:  [19, 25, 55]
# 12
# (3, 'Target Absent')
# (7, 'Target Present')
# (8, 'Target Present')
# (9, 'Target Present')
# (11, 'Target Absent')
# (19, 'Critical')
# (25, 'Critical')
# (34, 'Target Absent')
# (43, 'Target Present')
# (45, 'Target Present')
# (52, 'Target Absent')
# (55, 'Critical')
# [(3, 'Target Absent'), (7, 'Target Present'), (8, 'Target Present'), (9, 'Target Present'), (11, 'Target Absent'), (19, 'Critical'), (25, 'Critical'), (34, 'Target Absent'), (43, 'Target Present'), (45, 'Target Present'), (52, 'Target Absent'), (55, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Absent
# image 7 Target Present
# image 8 Target Present
# image 9 Target Present
# image 11 Target Absent
# image 19 Critical
# image 25 Critical
# image 34 Target Absent
# image 43 Target Present
# image 45 Target Present
# image 52 Target Absent
# image 55 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 7, 8, 9, 11, 34, 43, 45, 52]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2011_002050.jpg', '2008_006870.jpg']
# ---------------------------------------------------
# normal available: 48
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2011_002050.jpg'], ['2008_006870.jpg']]
# critical_probes_used:  ['2011_002050.jpg', '2008_006870.jpg']
# probes_per_block : ['2008_000191.jpg', '2009_003338.jpg', '2009_000120.jpg', '2008_008500.jpg', '2008_004188.jpg']
# probes_per_block : ['2008_000191.jpg', '2009_003338.jpg', '2009_000120.jpg', '2008_008500.jpg', '2008_004188.jpg', '2009_000995.jpg', '2011_001221.jpg', '2008_004690.jpg', '2008_000093.jpg']
# probes:  [['2008_001542.jpg', '2009_002137.jpg', '2011_000293.jpg', '2008_003767.jpg', '2008_000151.jpg', '2010_003890.jpg', '2008_003709.jpg', '2009_001568.jpg', '2010_004014.jpg'], ['2010_005718.jpg', '2010_005608.jpg', '2011_000530.jpg', '2008_008681.jpg', '2008_006481.jpg', '2008_003755.jpg', '2008_000860.jpg', '2011_002641.jpg', '2008_000928.jpg'], ['2009_003209.jpg', '2008_000740.jpg', '2009_000919.jpg', '2009_005075.jpg', '2011_000224.jpg', '2011_002303.jpg', '2009_005308.jpg', '2009_000619.jpg', '2008_003369.jpg'], ['2008_002084.jpg', '2009_000488.jpg', '2008_003081.jpg', '2010_005996.jpg', '2008_000984.jpg', '2010_000074.jpg', '2011_001649.jpg', '2008_004614.jpg', '2008_004459.jpg'], ['2008_008083.jpg', '2011_000661.jpg', '2010_001271.jpg', '2008_000163.jpg', '2008_004907.jpg', '2008_004624.jpg', '2008_000189.jpg', '2008_002062.jpg'], ['2008_006841.jpg', '2008_004991.jpg', '2011_002260.jpg', '2009_003802.jpg', '2011_002193.jpg', '2008_005818.jpg', '2008_000270.jpg', '2008_002709.jpg'], ['2008_006452.jpg', '2008_000972.jpg', '2008_001185.jpg', '2009_004888.jpg', '2010_004145.jpg', '2008_000112.jpg', '2008_000123.jpg', '2009_002697.jpg', '2008_000119.jpg'], ['2008_000191.jpg', '2009_003338.jpg', '2009_000120.jpg', '2008_008500.jpg', '2008_004188.jpg', '2009_000995.jpg', '2011_001221.jpg', '2008_004690.jpg', '2008_000093.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 30.30670761720366, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 36.207394560965135, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', ' bottle', nan, 33.73452911680277, 'high', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  386
# critical_probes_used ['2011_002050.jpg', '2008_006870.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Absent
# image 7 Target Present
# image 8 Target Present
# image 9 Target Present
# image 11 Target Absent
# image 19 Critical
# image 25 Critical
# image 34 Target Absent
# image 43 Target Present
# image 45 Target Present
# image 52 Target Absent
# image 55 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 7, 8, 9, 11, 34, 43, 45, 52]
# 60 60
# len(trials):  1920

# %%
print len(normal_no_probe_before)
print len(normal_used)
print len(normal_no_probe_before) == len(set(normal_used))
print len(target_present_before)
print len(present_used)
print len(target_present_before) == len(set(present_used))
print len(target_absent_before)
print len(absent_used)
print len(target_absent_before) == len(set(absent_used))

#the following is not a good check
print len(set(critical_trials_before)) == len(set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes))

print set(critical_trials_before) == set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes)

print len(low_four)
print len(low_one) == len(low_two) == len(low_three) == len(low_four) == len(high_one) == len(high_two) == len(high_three) == len(high_four)
print len(set(low_one) & set(low_two) & set(low_three) & set(low_four) & set(high_one) & set(high_two) & set(high_three) & set(high_four))
# Out:
# 386
# 386
# True
# 36
# 36
# True
# 36
# 34
# False
# True
# True
# 60
# True
# 0

# %%
#CREATE BLOCK COLUMN
for i in range(len(trials.keys())):
    trials[i+1].append(i/60+1)

# %%
tone_Hz1, sound_onset1 = tone_properties()
tone_Hz2, sound_onset2 = tone_properties()
tone_Hz3, sound_onset3 = tone_properties()
tone_Hz4, sound_onset4 = tone_properties()
tone_Hz = tone_Hz1+tone_Hz2+tone_Hz3+tone_Hz4
sound_onset = sound_onset1 + sound_onset2 + sound_onset3 + sound_onset4
# Out:
# ['tone1', 'tone2', 'tone1']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone2', 'tone2', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone1']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone1', 'tone1', 'tone1']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone2', 'tone2', 'tone2']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone1', 'tone2', 'tone1']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone1', 'tone2', 'tone1']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone1', 'tone2', 'tone1']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone1', 'tone1', 'tone2']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone1']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone2', 'tone1', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone2']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6

# %%
# %pdb
prova = []
tone_counter = 0
for i in sorted(trials.keys()):
    if 'Critical' in trials[i]:
        trials[i].append(tone_Hz[tone_counter])
        trials[i].append(sound_onset[tone_counter])
        tone_counter = tone_counter + 1
    else:
        trials[i].append('No tone')
        trials[i].append(-999)
# Out:
# Automatic pdb calling has been turned ON

# %%
for i in sorted(trials.iteritems()):
    l = i[1]
    l.insert(11, l.pop(13))
    l.insert(12, l.pop(14))
    #l.insert(newindex, l.pop(oldindex))

# %%
with open('../config/randomization.pik', 'wb') as of:
    pickle.dump(trials,of)

# %%
df = pd.DataFrame.from_dict(trials)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','image_name','block']
df.TS = df.TS.astype('float')                                                                                #10
df.to_csv(mypath + '../Config/randomization_1.csv')

# %%
df[df['trial_type']=='Critical']
# Out:
#              Cat.1         Cat.2         Cat.3         Cat.4    Cat.5  \
# 12             car           NaN           NaN           NaN      NaN
# 18          bottle           NaN           NaN           NaN      NaN
# 32           horse           NaN           NaN           NaN      NaN
# 86            boat           NaN           NaN           NaN      NaN
# 113         person     aeroplane           NaN           NaN      NaN
# 116    pottedplant           dog           NaN           NaN      NaN
# 132         person         horse           dog           NaN      NaN
# 138          chair   diningtable           NaN           NaN      NaN
# 152    pottedplant          sofa           NaN           NaN      NaN
# 206    pottedplant         chair   diningtable           NaN      NaN
# 233           sofa           dog           NaN           NaN      NaN
# 236           boat           NaN           NaN           NaN      NaN
# 269         person   diningtable        bottle           NaN      NaN
# 280         person         chair     motorbike           NaN      NaN
# 283           bird           NaN           NaN           NaN      NaN
# 314          chair   diningtable           NaN           NaN      NaN
# 327           bird           NaN           NaN           NaN      NaN
# 336            cat           NaN           NaN           NaN      NaN
# 389      tvmonitor          sofa           NaN           NaN      NaN
# 400           bird           NaN           NaN           NaN      NaN
# 403         person           NaN           NaN           NaN      NaN
# 434      tvmonitor   diningtable           cat           NaN      NaN
# 447            car     motorbike        person           NaN      NaN
# 456           sofa        person           NaN           NaN      NaN
# 488    pottedplant           NaN           NaN           NaN      NaN
# 511           sofa     tvmonitor           NaN           NaN      NaN
# 534          horse           NaN           NaN           NaN      NaN
# 563         person         horse           dog           NaN      NaN
# 566           sofa         chair           NaN           NaN      NaN
# 574         person         horse           NaN           NaN      NaN
# 608            car           NaN           NaN           NaN      NaN
# 631           sofa         chair        person           NaN      NaN
# 654           sofa        bottle   pottedplant     tvmonitor    chair
# 683           bird           NaN           NaN           NaN      NaN
# 686          chair           NaN           NaN           NaN      NaN
# 694            cat           NaN           NaN           NaN      NaN
# 724           boat           NaN           NaN           NaN      NaN
# 765         person         chair           NaN           NaN      NaN
# 768    pottedplant     tvmonitor         chair          sofa      NaN
# 797         person          boat           NaN           NaN      NaN
# 813         person          sofa           NaN           NaN      NaN
# 831           boat           NaN           NaN           NaN      NaN
# 844         person         horse           car           NaN      NaN
# 885         person           dog           NaN           NaN      NaN
# 888      aeroplane           NaN           NaN           NaN      NaN
# 917         person     aeroplane           NaN           NaN      NaN
# 933         person         chair          bird           NaN      NaN
# 951         person           cat           NaN           NaN      NaN
# 978         person          sofa           NaN           NaN      NaN
# 991           sofa           dog           NaN           NaN      NaN
# 1001          bird           NaN           NaN           NaN      NaN
# 1022   pottedplant     tvmonitor         chair          sofa      NaN
# 1037        person           dog          sofa           NaN      NaN
# 1050          boat           NaN           NaN           NaN      NaN
# 1098        person         horse           NaN           NaN      NaN
# 1111        person         horse           dog           NaN      NaN
# 1121   pottedplant        person         chair           dog      NaN
# 1142           cat           NaN           NaN           NaN      NaN
# 1157        person          boat           NaN           NaN      NaN
# 1170   pottedplant        person           NaN           NaN      NaN
# 1216           car     aeroplane           NaN           NaN      NaN
# 1241           cat           NaN           NaN           NaN      NaN
# 1247     aeroplane           NaN           NaN           NaN      NaN
# 1277           car           NaN           NaN           NaN      NaN
# 1293          sofa           NaN           NaN           NaN      NaN
# 1303         chair           NaN           NaN           NaN      NaN
# 1336         horse           NaN           NaN           NaN      NaN
# 1361     aeroplane           NaN           NaN           NaN      NaN
# 1367        bottle           dog   diningtable           NaN      NaN
# 1397          bird          boat           NaN           NaN      NaN
# 1413   pottedplant        person     motorbike           NaN      NaN
# 1423   pottedplant        person         chair           dog   bottle
# 1459   pottedplant           NaN           NaN           NaN      NaN
# 1483           cat           NaN           NaN           NaN      NaN
# 1500        bottle           NaN           NaN           NaN      NaN
# 1511        person         chair        bottle   diningtable      NaN
# 1519   pottedplant     tvmonitor         chair          sofa      NaN
# 1558   pottedplant           dog           NaN           NaN      NaN
# 1579   pottedplant        person         chair     motorbike     boat
# 1603          bird           NaN           NaN           NaN      NaN
# 1620        person         horse           NaN           NaN      NaN
# 1631        person           dog           NaN           NaN      NaN
# 1639           car           NaN           NaN           NaN      NaN
# 1678          bird           NaN           NaN           NaN      NaN
# 1712        person     aeroplane           NaN           NaN      NaN
# 1719   pottedplant          sofa         chair           NaN      NaN
# 1726        person           dog           NaN           NaN      NaN
# 1760          sofa        person           NaN           NaN      NaN
# 1766        person         chair           NaN           NaN      NaN
# 1796           car        person           NaN           NaN      NaN
# 1832     aeroplane           NaN           NaN           NaN      NaN
# 1839         horse           NaN           NaN           NaN      NaN
# 1846          boat           NaN           NaN           NaN      NaN
# 1880           car           NaN           NaN           NaN      NaN
# 1886        person         chair   diningtable        bottle      NaN
# 1916           cat           NaN           NaN           NaN      NaN
#
#              TS  Load      exemplar    question present_absent trial_type  \
# 12    19.030178   low           car          NA      No Target   Critical
# 18    18.259901   low        bottle          NA      No Target   Critical
# 32    20.957748   low         horse          NA      No Target   Critical
# 86    35.947150  high          boat          NA      No Target   Critical
# 113   34.544145  high     aeroplane          NA      No Target   Critical
# 116   29.851834  high           dog          NA      No Target   Critical
# 132   31.372460  high         horse          NA      No Target   Critical
# 138   28.728636  high         chair          NA      No Target   Critical
# 152   31.624524  high   pottedplant          NA      No Target   Critical
# 206   17.138576   low   pottedplant          NA      No Target   Critical
# 233   19.188834   low          sofa          NA      No Target   Critical
# 236   16.846337   low          boat          NA      No Target   Critical
# 269   36.414042  high        bottle          NA      No Target   Critical
# 280   31.774239  high         chair       horse  Target Absent   Critical
# 283   32.065096  high          bird          NA      No Target   Critical
# 314   18.117803   low         chair          NA      No Target   Critical
# 327   19.706122   low          bird          NA      No Target   Critical
# 336   19.107697   low           cat          NA      No Target   Critical
# 389   20.216264   low          sofa          NA      No Target   Critical
# 400   19.305030   low          bird   aeroplane  Target Absent   Critical
# 403   18.139053   low        person          NA      No Target   Critical
# 434   29.842923  high           cat          NA      No Target   Critical
# 447   31.408722  high           car          NA      No Target   Critical
# 456   35.925572  high          sofa          NA      No Target   Critical
# 488   19.906277   low   pottedplant          NA      No Target   Critical
# 511   15.574047   low          sofa          NA      No Target   Critical
# 534   19.803899   low         horse          NA      No Target   Critical
# 563   31.372460  high         horse          NA      No Target   Critical
# 566   32.351474  high         chair          NA      No Target   Critical
# 574   30.141763  high         horse          NA      No Target   Critical
# 608   30.394048  high           car          NA      No Target   Critical
# 631   34.561608  high        person          NA      No Target   Critical
# 654   33.937776  high   pottedplant          NA      No Target   Critical
# 683   19.706122   low          bird          NA      No Target   Critical
# 686   19.646066   low         chair          NA      No Target   Critical
# 694   20.463884   low           cat          NA      No Target   Critical
# 724   34.967528  high          boat          NA      No Target   Critical
# 765   37.052912  high        person          NA      No Target   Critical
# 768   35.636604  high   pottedplant          NA      No Target   Critical
# 797   16.146155   low          boat          NA      No Target   Critical
# 813   20.707878   low          sofa      bottle  Target Absent   Critical
# 831   20.210044   low          boat          NA      No Target   Critical
# 844   20.934600   low         horse          NA      No Target   Critical
# 885   19.793376   low        person          NA      No Target   Critical
# 888   20.088436   low     aeroplane          NA      No Target   Critical
# 917   30.182886  high        person          NA      No Target   Critical
# 933   29.630121  high          bird   aeroplane  Target Absent   Critical
# 951   29.867994  high           cat          NA      No Target   Critical
# 978   19.244036   low          sofa          NA      No Target   Critical
# 991   15.553393   low          sofa          NA      No Target   Critical
# 1001   9.576868   low          bird          NA      No Target   Critical
# 1022  35.636604  high   pottedplant          NA      No Target   Critical
# 1037  29.935618  high           dog          NA      No Target   Critical
# 1050  35.947150  high          boat          NA      No Target   Critical
# 1098  30.927210  high         horse          NA      No Target   Critical
# 1111  31.372460  high         horse          NA      No Target   Critical
# 1121  34.099790  high           dog          NA      No Target   Critical
# 1142  20.850125   low           cat          NA      No Target   Critical
# 1157  17.997748   low          boat          NA      No Target   Critical
# 1170  13.786733   low   pottedplant          NA      No Target   Critical
# 1216  35.872179  high     aeroplane          NA      No Target   Critical
# 1241  31.193571  high           cat          NA      No Target   Critical
# 1247  29.739678  high     aeroplane          NA      No Target   Critical
# 1277  19.759256   low           car          NA      No Target   Critical
# 1293  17.316646   low          sofa          NA      No Target   Critical
# 1303   9.955368   low         chair          NA      No Target   Critical
# 1336  18.720729   low         horse          NA      No Target   Critical
# 1361   8.171245   low     aeroplane          NA      No Target   Critical
# 1367  21.034647   low        bottle          NA      No Target   Critical
# 1397  29.314234  high          bird          NA      No Target   Critical
# 1413  34.416005  high   pottedplant          NA      No Target   Critical
# 1423  31.058050  high           dog          NA      No Target   Critical
# 1459  17.493024   low   pottedplant          NA      No Target   Critical
# 1483  20.041575   low           cat          NA      No Target   Critical
# 1500  19.096237   low        bottle          NA      No Target   Critical
# 1511  35.134857  high        bottle          NA      No Target   Critical
# 1519  35.636604  high   pottedplant          NA      No Target   Critical
# 1558  28.663633  high   pottedplant          NA      No Target   Critical
# 1579  31.580490  high          boat          NA      No Target   Critical
# 1603  31.397028  high          bird          NA      No Target   Critical
# 1620  31.310600  high         horse          NA      No Target   Critical
# 1631  19.793376   low        person          NA      No Target   Critical
# 1639  19.439939   low           car          NA      No Target   Critical
# 1678  19.735592   low          bird          NA      No Target   Critical
# 1712  32.014974  high     aeroplane          NA      No Target   Critical
# 1719  31.427288  high          sofa          NA      No Target   Critical
# 1726  30.657342  high           dog      person  Target Absent   Critical
# 1760  20.983298   low          sofa          NA      No Target   Critical
# 1766  16.606807   low        person          NA      No Target   Critical
# 1796  17.856306   low           car          NA      No Target   Critical
# 1832  16.876668   low     aeroplane          NA      No Target   Critical
# 1839  19.598131   low         horse          NA      No Target   Critical
# 1846  17.331558   low          boat      bottle  Target Absent   Critical
# 1880  36.207395  high           car          NA      No Target   Critical
# 1886  33.734529  high         chair          NA      No Target   Critical
# 1916  30.306708  high           cat          NA      No Target   Critical
#
#      tone_Hz tone_onset       image_name block
# 12     tone1        464  2009_004594.jpg     1
# 18     tone2        361  2008_006072.jpg     1
# 32     tone1        116  2009_003232.jpg     1
# 86     tone2        610  2008_000414.jpg     2
# 113    tone1        519  2009_002001.jpg     2
# 116    tone2         26  2008_007108.jpg     2
# 132    tone1        464  2010_005270.jpg     3
# 138    tone2        361  2009_003884.jpg     3
# 152    tone1        116  2011_001440.jpg     3
# 206    tone2        610  2008_002379.jpg     4
# 233    tone1        519  2009_001470.jpg     4
# 236    tone2         26  2010_005780.jpg     4
# 269    tone2        782  2008_002736.jpg     5
# 280    tone2        387  2009_004849.jpg     5
# 283    tone2        595  2008_000697.jpg     5
# 314    tone1        212  2011_002241.jpg     6
# 327    tone1        828  2010_000299.jpg     6
# 336    tone1        492  2009_001894.jpg     6
# 389    tone2        782  2010_005054.jpg     7
# 400    tone2        387  2009_000619.jpg     7
# 403    tone2        595  2008_001221.jpg     7
# 434    tone1        212  2010_001939.jpg     8
# 447    tone1        828  2008_003844.jpg     8
# 456    tone1        492  2008_000321.jpg     8
# 488    tone1        376  2010_000132.jpg     9
# 511    tone1         65  2009_003373.jpg     9
# 534    tone1        123  2010_003890.jpg     9
# 563    tone2        574  2010_005270.jpg    10
# 566    tone2        348  2008_004670.jpg    10
# 574    tone2        144  2009_002750.jpg    10
# 608    tone1        376  2008_002672.jpg    11
# 631    tone1         65  2008_000704.jpg    11
# 654    tone1        123  2011_002814.jpg    11
# 683    tone2        574  2010_000299.jpg    12
# 686    tone2        348  2008_000760.jpg    12
# 694    tone2        144  2008_001836.jpg    12
# 724    tone2        446  2010_002620.jpg    13
# 765    tone1        474  2010_002603.jpg    13
# 768    tone2        239  2011_002810.jpg    13
# 797    tone1        735  2011_002558.jpg    14
# 813    tone2        766  2008_000972.jpg    14
# 831    tone1        448  2008_001040.jpg    14
# 844    tone2        446  2009_000169.jpg    15
# 885    tone1        474  2008_003587.jpg    15
# 888    tone2        239  2009_000260.jpg    15
# 917    tone1        735  2011_002193.jpg    16
# 933    tone2        766  2008_001673.jpg    16
# 951    tone1        448  2010_002278.jpg    16
# 978    tone1        162  2008_004270.jpg    17
# 991    tone2        848  2009_004076.jpg    17
# 1001   tone1        187  2011_001959.jpg    17
# 1022   tone2        435  2011_002810.jpg    18
# 1037   tone1        165  2008_000270.jpg    18
# 1050   tone2         12  2008_000414.jpg    18
# 1098   tone1        162  2008_003461.jpg    19
# 1111   tone2        848  2010_005270.jpg    19
# 1121   tone1        187  2010_005628.jpg    19
# 1142   tone2        435  2010_002645.jpg    20
# 1157   tone1        165  2010_002498.jpg    20
# 1170   tone2         12  2009_001137.jpg    20
# 1216   tone1        162  2008_000251.jpg    21
# 1241   tone2        941  2010_003943.jpg    21
# 1247   tone1        630  2010_004423.jpg    21
# 1277   tone2        787  2008_000952.jpg    22
# 1293   tone1        157  2011_000224.jpg    22
# 1303   tone2        834  2010_001731.jpg    22
# 1336   tone1        162  2009_003686.jpg    23
# 1361   tone2        941  2008_000151.jpg    23
# 1367   tone1        630  2011_002911.jpg    23
# 1397   tone2        787  2008_006481.jpg    24
# 1413   tone1        157  2011_001605.jpg    24
# 1423   tone2        834  2008_001862.jpg    24
# 1459   tone1         96  2009_001975.jpg    25
# 1483   tone1        820  2010_005257.jpg    25
# 1500   tone2        679  2009_002594.jpg    25
# 1511   tone2        643  2011_000282.jpg    26
# 1519   tone2         85  2011_002810.jpg    26
# 1558   tone1        887  2010_004683.jpg    26
# 1579   tone1         96  2009_003351.jpg    27
# 1603   tone1        820  2008_004042.jpg    27
# 1620   tone2        679  2011_000628.jpg    27
# 1631   tone2        643  2008_003587.jpg    28
# 1639   tone2         85  2008_002704.jpg    28
# 1678   tone1        887  2011_001432.jpg    28
# 1712   tone2        768  2008_004646.jpg    29
# 1719   tone1         95  2009_001021.jpg    29
# 1726   tone1        261  2008_006870.jpg    29
# 1760   tone1        903  2008_004269.jpg    30
# 1766   tone2        129  2010_004223.jpg    30
# 1796   tone2         18  2009_002711.jpg    30
# 1832   tone2        768  2008_001546.jpg    31
# 1839   tone1         95  2008_000219.jpg    31
# 1846   tone1        261  2011_002050.jpg    31
# 1880   tone1        903  2008_000457.jpg    32
# 1886   tone2        129  2011_003066.jpg    32
# 1916   tone2         18  2010_000815.jpg    32
