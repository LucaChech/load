# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pickle
from copy import deepcopy
#%pdb
mypath = ('')
trials = {}
categories = [' bottle', ' horse', ' pottedplant', ' dog',
                  ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]
p_load = ['low','high']

pd.set_option('display.max_rows', 9000)
pd.set_option('display.max_columns', 9000)

# %%
def present_absent_trials(input_1, input_2):
    global target_present, lista, categories, p_load, odd, even
    # DEFINING TARGET-PRESENT PROBES
    
    #target_present = []
    intermediate = []
    
#next two lines are to check that the images picked as target present and target absent trials
                    #are different from the ones chosen in previous iterations
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_1:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break
    #print len(target_present)
    for n in target_present:
        possible_images_dict[n].append('Target Present')

    #target_present = [n for n in lista if 'Target Present' in possible_images_dict[n]]


    # DEFINING TARGET-ABSENT PROBES
    #target_absent = []
    intermediate = []
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_2:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)

                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for each in target_absent:
        possible_images_dict[each].append('Target Absent')
        

    # DEFINING NO-TARGET IMAGES
    for image in lista:
        if image not in target_present and image not in target_absent:
            possible_images_dict[image].append('NA')
            possible_images_dict[image].append('No Target')
    
    return target_present, target_absent

# %%
# DEFINING CRITICAL TRIALS
#Criteria:
# - images of set load level
# - images containing a certain category
# - image is not already in the list of critical trials for this level of load
#- image is not aready in the list of critical trials (regardless of level of load)

def pre_select_critical_trial(load_level):
    global categories, critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and 'Critical' not in possible_images_dict[intermediate]: # this is just a sanity check
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)      
        temp =[]

# %%
def appending_critical_trials():
    global critical_low_present_probes, critical_low_absent_probes, critical_high_present_probes, critical_high_absent_probes
    global critical_trials
    cycles = 1
    while True:

        #picking critical trials
        pre_select_critical_trial('low')
        pre_select_critical_trial('high')      

        # counting critical probes
        crit_p = 0
        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1


        critical_low_counter = 0
        critical_high_counter = 0
        crit_p = 0

        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1
            if 'No Target' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_counter = critical_low_counter + 1
            if 'No Target' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_counter = critical_high_counter +1
            if 'Target Present' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_absent_probes.append(n)
            if 'Target Present' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_absent_probes.append(n)
        #print crit_p
        #print critical_low_counter
        #print critical_high_counter
        #print critical_low_present_probes
        #print critical_low_absent_probes
        #print critical_high_present_probes
        #print critical_high_absent_probes

        #######################################################
        if crit_p == 0 or len(critical_low_present_probes) == len(critical_high_present_probes) and len(critical_low_absent_probes) == \
        len(critical_high_absent_probes): #check if there is an even number of critical probes
            break
            print 'cycles : ',cycles
        else:
            cycles = cycles + 1
            critical_low_present_probes = []
            critical_low_absent_probes = []
            critical_high_present_probes = []
            critical_high_absent_probes = []
            #print len(critical_low_present_probes)
            #print len(critical_high_present_probes)
            #print len(critical_low_absent_probes)
            #print len(critical_high_absent_probes)
            #print '#######################'

            #why did I reset target_present and target_absent???

            #target_present = []
            #target_absent = []
            critical_trials = []

    # appendinf words 'critical' and 'normal' to dict
    for each in critical_trials:
        possible_images_dict[each].append('Critical')
    for each in possible_images_dict:
        if 'Critical' not in possible_images_dict[each]:
            possible_images_dict[each].append('Normal')

    #######################################################
    #print 'Probe trials: ', len(probe_trials_1)
    print 'Target Present Probes: ', len(target_present)
    print 'Target Absent probes: ', len(target_absent)
    print 'Critical trials:', len(critical_trials)
    print 'Critical, low: ' , critical_low_counter
    print 'Critical, high: ' , critical_high_counter
    print 'Are all critical trials unique? ', len(critical_trials) == len(set(critical_trials))
    #######################################################
    print 'Number of critical probes: ' , crit_p
    print 'critical_low_present_probes: ' , len(critical_low_present_probes)
    print 'critical_high_present_probes: ' , len(critical_high_present_probes)
    print 'critical_low_absent_probes: ' , len(critical_low_absent_probes)
    print 'critical_high_absent_probes: ', len(critical_high_absent_probes)
    print 'cycles : ',cycles
    
    return

# %%
def critical_probes_distribution(starting):
    global critical_low_present_probes, critical_low_absent_probes
    while True:
        p_left = len(starting)
        p_max = p_left
        distribution = []
        for i in range(4):
            if p_left > 0:
                x = random.randint(0,p_left)
                distribution.append(x)
                p_left = p_left - x
            else:
                distribution.append(0)
        if sum(distribution) == p_max:
            break
    random.shuffle(distribution)
    return distribution

# %%
def block_pair(present_n,absent_n):
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block
    global present_crit_distribution, absent_crit_distribution
    global present_critical_per_block, absent_critical_per_block, critical_probes_used, critical_probes_set
    global present_per_block, absent_per_block
    
    present_crit = present_crit_distribution.pop(0)
    absent_crit = absent_crit_distribution.pop(0)
    block = []
    
    for load in p_load:
        #PRINTING STUFF
        print 'present_crit_distribution_original: ',present_crit_distribution_original
        print 'absent_crit_distribution_original: ', absent_crit_distribution_original
        print 'present_crit', present_crit
        print 'absent_crit', absent_crit
        print 'present_crit_distribution: ', present_crit_distribution
        print 'absent_crit_distribution: ', absent_crit_distribution
        print 'critical present set: ', critical_present_set
        print 'critical absent set: ', critical_absent_set
        print'---------------------------------------------------'
        normal_availble = [n for n in normal if n not in normal_used]
        print 'normal available:', len(normal_availble)
    # PICKING CRITICAL PROBES    
    #------------------------------------------------------------------------------
        if present_crit != 0:
            present_critical_per_block = []
            while len(present_critical_per_block) < present_crit:
                crit_probe = str(np.random.choice(critical_present_set,1,replace = False))[2:-2]
                if crit_probe not in present_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Present' in possible_images_dict[crit_probe]:

                    present_critical_per_block.append(crit_probe)
            critical_present.append(present_critical_per_block)
                    
        print 'present_critical_per_block:', present_critical_per_block
        
        if absent_crit != 0:
            absent_critical_per_block = []
            while len(absent_critical_per_block) < absent_crit:
                crit_probe = str(np.random.choice(critical_absent_set,1,replace = False))[2:-2]
                if crit_probe not in absent_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Absent' in possible_images_dict[crit_probe]:

                    absent_critical_per_block.append(crit_probe)
            critical_absent.append(absent_critical_per_block)
            
        print 'absent_critical_per_block:', absent_critical_per_block  
        print 'critical_present: ',critical_present
        print 'critical_absent: ',critical_absent
        
        for n in present_critical_per_block + absent_critical_per_block:
            critical_probes_used.append(n)
            
        print 'critical_probes_used: ', critical_probes_used
    #------------------------------------------------------------------------------
    # PICKING PRESENT AND ABSENT PROBES
        total = present_n + absent_n
        while len(probes_per_block) < (present_n - present_crit):
            probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in present_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        while (present_n - present_crit) <= len(probes_per_block) < total - present_crit - absent_crit:
            probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in absent_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        for n in probes_per_block:
            if 'Target Present' in possible_images_dict[n]:
                present_used.append(n)
            elif 'Target Absent' in possible_images_dict[n]:
                absent_used.append(n)

        probes.append(probes_per_block)
        
        print 'probes: ', probes
        present_per_block = [n for n in probes_per_block if 'Target Present' in possible_images_dict[n]]
        absent_per_block = [n for n in probes_per_block if 'Target Absent' in possible_images_dict[n]]
        print 'Present Used in block: ',len(present_per_block)
        print 'Absent Used in block',len(absent_per_block)
    #------------------------------------------------------------------------------    
    #Counting critical probes    
        critical_probes_counter = len(present_critical_per_block + absent_critical_per_block)
        print 'Critical probes counter: ',critical_probes_counter
        print 'Present Critical: ', len(present_critical_per_block)
        print 'Absent Critical: ', len(absent_critical_per_block)

        modifier.append(critical_probes_counter)
    #------------------------------------------------------------------------------
    #Picking critical trials
        while len(critical_per_block) < (3-critical_probes_counter):
            image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
            if image not in critical_per_block and image not in critical_used \
                and 'No Target' in possible_images_dict[image] and load in possible_images_dict[image]:
                critical_per_block.append(image) 
        print 'List of critical trials without probe: '
        for n in critical_per_block:
            critical_used.append(n)
            print possible_images_dict[n]
        #temp = []

        critical.append(critical_per_block)

    #------------------------------------------------------------------------------
    #Picking normal trials
        while len(normal_per_block) < 51 - (3 - critical_probes_counter):
            image = str(np.random.choice(normal,1,replace = False))[2:-2]
            if image not in normal_per_block and image not in normal_used and load in possible_images_dict[image]:
                normal_per_block.append(image)
        for n in normal_per_block:
            normal_used.append(n)
        print 'normal in this block: ', len(normal_per_block)
        print 'normal used overall: ',len(normal_used)

        normal_builder.append(normal_per_block)
    #----------------------------------------------------------------------------
        
        print 'critical_probes_used', critical_probes_used 
        
        
        
        if 'sequence_final' in locals():
            print 'sequence_final exists'
        else:
            print 'sequence final does not exist'
            sequence_final = position_finder()
            print sequence_final
        print'---------------------------------------------------'
        print 'END OF BLOCK PROCESSING'
        print'---------------------------------------------------'
        print 'BUILDING THE BLOCK'
        first_element = [x[0] for x in sequence_final]
        second_element = [x[1] for x in sequence_final]
        second_element_counter = 0
        probes_position = []
        for image in range(60):
            #print [x[1] for x in sequence_final if x[0] ==image][0]
            if image in first_element:
                
                print 'image', image, second_element[second_element_counter]
        
                if second_element[second_element_counter] == 'Target Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break       
                elif second_element[second_element_counter] == 'Target Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical':
                    while True:
                        element = str(np.random.choice(critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break     
                elif second_element[second_element_counter] == 'Critical Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break  
            else:
                while True:
                    element = str(np.random.choice(normal_per_block,1,replace = False))[2:-2]
                    if element not in block:
                        block.append(element)
                        break
                
        print 'block:', len(block)   
        print'---------------------------------------------------'
        print 'probes_position: ', probes_position
    #-----------------------------------------------------------------------------
        normal_per_block = []
        probes_per_block = []
        critical_per_block = []
        present_critical_per_block = []
        absent_critical_per_block = []
    #-----------------------------------------------------------------------------
    return block

# %%
def position_finder():
    global present_critical_per_block, absent_critical_per_block, present_per_block, absent_per_block, critical_per_block
    x = len(present_critical_per_block + absent_critical_per_block)
    print 'x', x
    print 'present_critical_per_block', len(present_critical_per_block)
    print 'absent_critical_per_block', len(absent_critical_per_block)
    while True:    
        while True:
            a = [random.randint(1,10) for r in xrange(12-x)]
            if sum(a) <= 60:
                break

        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]

        if len(present_critical_per_block) == 0 and len(absent_critical_per_block) == 0:
            print 'ciao', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block) + ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        if len(present_critical_per_block) != 0 or len(absent_critical_per_block) != 0:
            print 'ciao2', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block)  +\
            ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block) +\
            ['Critical Present'] * len(present_critical_per_block) +\
            ['Critical Absent'] * len(absent_critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        sequence_final = zip(new_list_1, sequence)
        #print sequence_final
        #print len(sequence_final)
        gap_check = [n[0] for n in sequence_final if 'Critical' in n[1]] 
        #print gap_check
        container = []
        for i in gap_check:
            elements = [i+1, i+2]
            for element in elements:
                if element in new_list_1:
                    container.append(element)
        #print 'container', len(container),container
        if len(container) == 0:
            break
        else:
            sequence_final = []

    print '------------------'
    print new_list_1, len(new_list_1)
    print 'gap_check: ', gap_check
    print len(sequence_final)

    for i in sequence_final:
        print i
    return sequence_final

# %%
def block_unpacker(splitting_index,present,absent):
    block = block_pair(present,absent) #, probes_position
    low_block = []
    high_block = []
    for i in range(len(block)):
        if i < (len(block)/2):
            low_block.append(block[i])
        else:
            high_block.append(block[i])
    #print probes_position
    print len(low_block), len(high_block)
    return low_block, high_block #, probes_position

# %%
def tone_properties():
    while True:
        possible_tones = ['tone1','tone2']
        low_one_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_two_tones = []
        low_three_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_four_tones = []
        
        for each in low_one_tones:
            if each == 'tone1':
                low_two_tones.append('tone2')
            elif each == 'tone2':
                low_two_tones.append('tone1')
        for each in low_three_tones:
            if each == 'tone1':
                low_four_tones.append('tone2')
            elif each == 'tone2':
                low_four_tones.append('tone1')
        high_one_tones = low_one_tones
        high_two_tones = low_two_tones
        high_three_tones = low_three_tones
        high_four_tones = low_four_tones
        
        sound_Hz = low_one_tones + low_two_tones + low_three_tones + low_four_tones + high_one_tones + high_two_tones +\
        high_three_tones + high_four_tones

        tone1_counter = 0
        tone2_counter = 0
        for each in sound_Hz:
            if each == 'tone1':
                tone1_counter = tone1_counter + 1
            elif each == 'tone2':
                tone2_counter = tone2_counter + 1

        low_load_tones = [n for n in sound_Hz[0:12]]
        high_load_tones = [n for n in sound_Hz[12:25]]
        low_load_tone1s = [n for n in low_load_tones if n == 'tone1']
        low_load_tone2s = [n for n in low_load_tones if n == 'tone2']
        high_load_tone1s = [n for n in high_load_tones if n == 'tone1']
        high_load_tone2s = [n for n in high_load_tones if n =='tone2']

        if len(low_load_tone1s) == len(low_load_tone2s) and len(high_load_tone1s) == len(high_load_tone2s):
            print low_one_tones
            print high_one_tones
            print '----------------------'
            print low_two_tones
            print high_two_tones
            print '----------------------'
            print low_three_tones
            print high_three_tones
            print '----------------------'
            print low_four_tones
            print high_four_tones
            print '----------------------'
            print 'total n of tones: ', len(sound_Hz)
            print '----------------------'
            print 'total n of 1500 Hz tones: ', tone1_counter
            print 'total n of 2000 Hz tones: ', tone2_counter
            print '----------------------'
            print len(low_load_tone1s) == len(low_load_tone2s)
            print len(low_load_tone1s)
            print len(low_load_tone2s)
            print len(high_load_tone1s) == len(high_load_tone2s)
            print len(high_load_tone1s)
            print len(high_load_tone2s)
            break
        # Re-ordering tones according to the block order
    sound_Hz = low_one_tones + high_two_tones + high_one_tones + low_two_tones + high_three_tones + low_four_tones +\
        low_three_tones + high_four_tones 
    sound_onset1 = np.random.uniform(0,0.949,3).tolist()
    sound_onset2 = np.random.uniform(0,0.949,3).tolist()
    sound_onset3 = np.random.uniform(0,0.949,3).tolist()
    sound_onset4 = np.random.uniform(0,0.949,3).tolist()
   
    sound_onset_pre_rounding = sound_onset1 + sound_onset2 + sound_onset1 + sound_onset2 + sound_onset3 + sound_onset4 + sound_onset3 + sound_onset4
    sound_onset = [round(n,3) for n in sound_onset_pre_rounding]
    return sound_Hz, sound_onset

# %%
def appending_to_dict(trial_n):
    global blocks
    for b in range(8):
        this_block_images = blocks[b]
        for im in this_block_images:
            trials[trial_n] = possible_images_dict[im]
            trials[trial_n].append(im)
            trial_n += 1
    print 'len(trials): ', len(trials)

# %%
######################
### FIRST ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  9
# Critical, high:  9
# Are all critical trials unique?  True
# Number of critical probes:  6
# critical_low_present_probes:  2
# critical_high_present_probes:  2
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  32
# present_crit_distribution_original:  [1, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  ['2009_003686.jpg', '2008_001185.jpg', '2011_000530.jpg', '2008_006461.jpg']
# critical absent set:  ['2009_003309.jpg', '2008_006481.jpg']
# ---------------------------------------------------
# normal available: 390
# present_critical_per_block: ['2008_001185.jpg']
# absent_critical_per_block: []
# critical_present:  [['2008_001185.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2008_001185.jpg']
# probes_per_block : ['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg']
# probes_per_block : ['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg', '2010_000132.jpg', '2010_000750.jpg', '2008_003876.jpg', '2008_007704.jpg', '2008_004814.jpg']
# probes:  [['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg', '2010_000132.jpg', '2010_000750.jpg', '2008_003876.jpg', '2008_007704.jpg', '2008_004814.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 20.529451477248333, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 20.07468613183729, 'low', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  49
# critical_probes_used ['2008_001185.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 1
# absent_critical_per_block 0
# ciao2 2
# ------------------
# [5, 8, 11, 16, 18, 22, 25, 34, 35, 38, 44] 11
# gap_check:  [11, 35, 44]
# 11
# (5, 'Target Absent')
# (8, 'Target Absent')
# (11, 'Critical')
# (16, 'Target Present')
# (18, 'Target Absent')
# (22, 'Target Absent')
# (25, 'Target Absent')
# (34, 'Target Present')
# (35, 'Critical Present')
# (38, 'Target Present')
# (44, 'Critical')
# [(5, 'Target Absent'), (8, 'Target Absent'), (11, 'Critical'), (16, 'Target Present'), (18, 'Target Absent'), (22, 'Target Absent'), (25, 'Target Absent'), (34, 'Target Present'), (35, 'Critical Present'), (38, 'Target Present'), (44, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Absent
# image 8 Target Absent
# image 11 Critical
# image 16 Target Present
# image 18 Target Absent
# image 22 Target Absent
# image 25 Target Absent
# image 34 Target Present
# image 35 Critical Present
# image 38 Target Present
# image 44 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 8, 16, 18, 22, 25, 34, 35, 38]
# present_crit_distribution_original:  [1, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  ['2009_003686.jpg', '2008_001185.jpg', '2011_000530.jpg', '2008_006461.jpg']
# critical absent set:  ['2009_003309.jpg', '2008_006481.jpg']
# ---------------------------------------------------
# normal available: 341
# present_critical_per_block: ['2008_006461.jpg']
# absent_critical_per_block: []
# critical_present:  [['2008_001185.jpg'], ['2008_006461.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2008_001185.jpg', '2008_006461.jpg']
# probes_per_block : ['2009_002414.jpg', '2008_005090.jpg', '2008_000860.jpg']
# probes_per_block : ['2009_002414.jpg', '2008_005090.jpg', '2008_000860.jpg', '2008_001333.jpg', '2011_001335.jpg', '2009_000120.jpg', '2009_003705.jpg', '2008_005600.jpg']
# probes:  [['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg', '2010_000132.jpg', '2010_000750.jpg', '2008_003876.jpg', '2008_007704.jpg', '2008_004814.jpg'], ['2009_002414.jpg', '2008_005090.jpg', '2008_000860.jpg', '2008_001333.jpg', '2011_001335.jpg', '2009_000120.jpg', '2009_003705.jpg', '2008_005600.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' cat', nan, nan, nan, 32.2651090829965, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' chair', ' dog', ' diningtable', nan, nan, 29.611440342795753, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  98
# critical_probes_used ['2008_001185.jpg', '2008_006461.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Absent
# image 8 Target Absent
# image 11 Critical
# image 16 Target Present
# image 18 Target Absent
# image 22 Target Absent
# image 25 Target Absent
# image 34 Target Present
# image 35 Critical Present
# image 38 Target Present
# image 44 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 8, 16, 18, 22, 25, 34, 35, 38]
# 60 60
# present_crit_distribution_original:  [1, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 1
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_003686.jpg', '2008_001185.jpg', '2011_000530.jpg', '2008_006461.jpg']
# critical absent set:  ['2009_003309.jpg', '2008_006481.jpg']
# ---------------------------------------------------
# normal available: 292
# present_critical_per_block: ['2009_003686.jpg']
# absent_critical_per_block: ['2009_003309.jpg']
# critical_present:  [['2008_001185.jpg'], ['2008_006461.jpg'], ['2009_003686.jpg']]
# critical_absent:  [['2009_003309.jpg']]
# critical_probes_used:  ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg']
# probes_per_block : ['2009_000260.jpg', '2011_001005.jpg', '2011_001886.jpg', '2009_002803.jpg']
# probes_per_block : ['2009_000260.jpg', '2011_001005.jpg', '2011_001886.jpg', '2009_002803.jpg', '2008_000123.jpg', '2011_001613.jpg', '2010_003101.jpg']
# probes:  [['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg', '2010_000132.jpg', '2010_000750.jpg', '2008_003876.jpg', '2008_007704.jpg', '2008_004814.jpg'], ['2009_002414.jpg', '2008_005090.jpg', '2008_000860.jpg', '2008_001333.jpg', '2011_001335.jpg', '2009_000120.jpg', '2009_003705.jpg', '2008_005600.jpg'], ['2009_000260.jpg', '2011_001005.jpg', '2011_001886.jpg', '2009_002803.jpg', '2008_000123.jpg', '2011_001613.jpg', '2010_003101.jpg']]
# Present Used in block:  4
# Absent Used in block 3
# Critical probes counter:  2
# Present Critical:  1
# Absent Critical:  1
# List of critical trials without probe:
# [' bottle', nan, nan, nan, nan, 20.965775321926717, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  148
# critical_probes_used ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg']
# sequence final does not exist
# x 2
# present_critical_per_block 1
# absent_critical_per_block 1
# ciao2 1
# ciao2 1
# ------------------
# [7, 15, 16, 21, 30, 36, 38, 40, 48, 50] 10
# gap_check:  [16, 40, 50]
# 10
# (7, 'Target Present')
# (15, 'Target Absent')
# (16, 'Critical')
# (21, 'Target Present')
# (30, 'Target Absent')
# (36, 'Target Present')
# (38, 'Target Present')
# (40, 'Critical Absent')
# (48, 'Target Absent')
# (50, 'Critical Present')
# [(7, 'Target Present'), (15, 'Target Absent'), (16, 'Critical'), (21, 'Target Present'), (30, 'Target Absent'), (36, 'Target Present'), (38, 'Target Present'), (40, 'Critical Absent'), (48, 'Target Absent'), (50, 'Critical Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 15 Target Absent
# image 16 Critical
# image 21 Target Present
# image 30 Target Absent
# image 36 Target Present
# image 38 Target Present
# image 40 Critical Absent
# image 48 Target Absent
# image 50 Critical Present
# block: 60
# ---------------------------------------------------
# probes_position:  [7, 15, 21, 30, 36, 38, 40, 48, 50]
# present_crit_distribution_original:  [1, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 1
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_003686.jpg', '2008_001185.jpg', '2011_000530.jpg', '2008_006461.jpg']
# critical absent set:  ['2009_003309.jpg', '2008_006481.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: ['2011_000530.jpg']
# absent_critical_per_block: ['2008_006481.jpg']
# critical_present:  [['2008_001185.jpg'], ['2008_006461.jpg'], ['2009_003686.jpg'], ['2011_000530.jpg']]
# critical_absent:  [['2009_003309.jpg'], ['2008_006481.jpg']]
# critical_probes_used:  ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg', '2011_000530.jpg', '2008_006481.jpg']
# probes_per_block : ['2008_008097.jpg', '2011_001382.jpg', '2011_001605.jpg', '2008_000833.jpg']
# probes_per_block : ['2008_008097.jpg', '2011_001382.jpg', '2011_001605.jpg', '2008_000833.jpg', '2010_005606.jpg', '2008_002350.jpg', '2010_003729.jpg']
# probes:  [['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg', '2010_000132.jpg', '2010_000750.jpg', '2008_003876.jpg', '2008_007704.jpg', '2008_004814.jpg'], ['2009_002414.jpg', '2008_005090.jpg', '2008_000860.jpg', '2008_001333.jpg', '2011_001335.jpg', '2009_000120.jpg', '2009_003705.jpg', '2008_005600.jpg'], ['2009_000260.jpg', '2011_001005.jpg', '2011_001886.jpg', '2009_002803.jpg', '2008_000123.jpg', '2011_001613.jpg', '2010_003101.jpg'], ['2008_008097.jpg', '2011_001382.jpg', '2011_001605.jpg', '2008_000833.jpg', '2010_005606.jpg', '2008_002350.jpg', '2010_003729.jpg']]
# Present Used in block:  4
# Absent Used in block 3
# Critical probes counter:  2
# Present Critical:  1
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 31.96963432435441, 'high', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  198
# critical_probes_used ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg', '2011_000530.jpg', '2008_006481.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 15 Target Absent
# image 16 Critical
# image 21 Target Present
# image 30 Target Absent
# image 36 Target Present
# image 38 Target Present
# image 40 Critical Absent
# image 48 Target Absent
# image 50 Critical Present
# block: 120
# ---------------------------------------------------
# probes_position:  [7, 15, 21, 30, 36, 38, 40, 48, 50]
# 60 60
# present_crit_distribution_original:  [1, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_003686.jpg', '2008_001185.jpg', '2011_000530.jpg', '2008_006461.jpg']
# critical absent set:  ['2009_003309.jpg', '2008_006481.jpg']
# ---------------------------------------------------
# normal available: 192
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2008_001185.jpg'], ['2008_006461.jpg'], ['2009_003686.jpg'], ['2011_000530.jpg']]
# critical_absent:  [['2009_003309.jpg'], ['2008_006481.jpg']]
# critical_probes_used:  ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg', '2011_000530.jpg', '2008_006481.jpg']
# probes_per_block : ['2008_005673.jpg', '2010_001993.jpg', '2008_003587.jpg', '2008_000115.jpg']
# probes_per_block : ['2008_005673.jpg', '2010_001993.jpg', '2008_003587.jpg', '2008_000115.jpg', '2010_004231.jpg', '2010_005054.jpg', '2008_000163.jpg', '2008_008083.jpg', '2008_004624.jpg']
# probes:  [['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg', '2010_000132.jpg', '2010_000750.jpg', '2008_003876.jpg', '2008_007704.jpg', '2008_004814.jpg'], ['2009_002414.jpg', '2008_005090.jpg', '2008_000860.jpg', '2008_001333.jpg', '2011_001335.jpg', '2009_000120.jpg', '2009_003705.jpg', '2008_005600.jpg'], ['2009_000260.jpg', '2011_001005.jpg', '2011_001886.jpg', '2009_002803.jpg', '2008_000123.jpg', '2011_001613.jpg', '2010_003101.jpg'], ['2008_008097.jpg', '2011_001382.jpg', '2011_001605.jpg', '2008_000833.jpg', '2010_005606.jpg', '2008_002350.jpg', '2010_003729.jpg'], ['2008_005673.jpg', '2010_001993.jpg', '2008_003587.jpg', '2008_000115.jpg', '2010_004231.jpg', '2010_005054.jpg', '2008_000163.jpg', '2008_008083.jpg', '2008_004624.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' sofa', ' chair', nan, nan, 18.511887801846186, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' sofa', ' chair', nan, nan, nan, 19.836491630222174, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 19.321308873350848, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  246
# critical_probes_used ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg', '2011_000530.jpg', '2008_006481.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [6, 13, 14, 18, 24, 27, 31, 35, 40, 48, 56, 59] 12
# gap_check:  [6, 14, 31]
# 12
# (6, 'Critical')
# (13, 'Target Present')
# (14, 'Critical')
# (18, 'Target Present')
# (24, 'Target Present')
# (27, 'Target Present')
# (31, 'Critical')
# (35, 'Target Absent')
# (40, 'Target Absent')
# (48, 'Target Absent')
# (56, 'Target Absent')
# (59, 'Target Absent')
# [(6, 'Critical'), (13, 'Target Present'), (14, 'Critical'), (18, 'Target Present'), (24, 'Target Present'), (27, 'Target Present'), (31, 'Critical'), (35, 'Target Absent'), (40, 'Target Absent'), (48, 'Target Absent'), (56, 'Target Absent'), (59, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Critical
# image 13 Target Present
# image 14 Critical
# image 18 Target Present
# image 24 Target Present
# image 27 Target Present
# image 31 Critical
# image 35 Target Absent
# image 40 Target Absent
# image 48 Target Absent
# image 56 Target Absent
# image 59 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [13, 18, 24, 27, 35, 40, 48, 56, 59]
# present_crit_distribution_original:  [1, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_003686.jpg', '2008_001185.jpg', '2011_000530.jpg', '2008_006461.jpg']
# critical absent set:  ['2009_003309.jpg', '2008_006481.jpg']
# ---------------------------------------------------
# normal available: 144
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2008_001185.jpg'], ['2008_006461.jpg'], ['2009_003686.jpg'], ['2011_000530.jpg']]
# critical_absent:  [['2009_003309.jpg'], ['2008_006481.jpg']]
# critical_probes_used:  ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg', '2011_000530.jpg', '2008_006481.jpg']
# probes_per_block : ['2008_007745.jpg', '2008_000495.jpg', '2011_002641.jpg', '2010_001939.jpg']
# probes_per_block : ['2008_007745.jpg', '2008_000495.jpg', '2011_002641.jpg', '2010_001939.jpg', '2010_001586.jpg', '2011_001944.jpg', '2010_005628.jpg', '2008_003081.jpg', '2008_006912.jpg']
# probes:  [['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg', '2010_000132.jpg', '2010_000750.jpg', '2008_003876.jpg', '2008_007704.jpg', '2008_004814.jpg'], ['2009_002414.jpg', '2008_005090.jpg', '2008_000860.jpg', '2008_001333.jpg', '2011_001335.jpg', '2009_000120.jpg', '2009_003705.jpg', '2008_005600.jpg'], ['2009_000260.jpg', '2011_001005.jpg', '2011_001886.jpg', '2009_002803.jpg', '2008_000123.jpg', '2011_001613.jpg', '2010_003101.jpg'], ['2008_008097.jpg', '2011_001382.jpg', '2011_001605.jpg', '2008_000833.jpg', '2010_005606.jpg', '2008_002350.jpg', '2010_003729.jpg'], ['2008_005673.jpg', '2010_001993.jpg', '2008_003587.jpg', '2008_000115.jpg', '2010_004231.jpg', '2010_005054.jpg', '2008_000163.jpg', '2008_008083.jpg', '2008_004624.jpg'], ['2008_007745.jpg', '2008_000495.jpg', '2011_002641.jpg', '2010_001939.jpg', '2010_001586.jpg', '2011_001944.jpg', '2010_005628.jpg', '2008_003081.jpg', '2008_006912.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' bicycle', ' bottle', ' cat', nan, 35.35378442994306, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 37.22381580448725, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' dog', ' bottle', 31.05804957013649, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  294
# critical_probes_used ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg', '2011_000530.jpg', '2008_006481.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Critical
# image 13 Target Present
# image 14 Critical
# image 18 Target Present
# image 24 Target Present
# image 27 Target Present
# image 31 Critical
# image 35 Target Absent
# image 40 Target Absent
# image 48 Target Absent
# image 56 Target Absent
# image 59 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [13, 18, 24, 27, 35, 40, 48, 56, 59]
# 60 60
# present_crit_distribution_original:  [1, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2009_003686.jpg', '2008_001185.jpg', '2011_000530.jpg', '2008_006461.jpg']
# critical absent set:  ['2009_003309.jpg', '2008_006481.jpg']
# ---------------------------------------------------
# normal available: 96
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2008_001185.jpg'], ['2008_006461.jpg'], ['2009_003686.jpg'], ['2011_000530.jpg']]
# critical_absent:  [['2009_003309.jpg'], ['2008_006481.jpg']]
# critical_probes_used:  ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg', '2011_000530.jpg', '2008_006481.jpg']
# probes_per_block : ['2008_001495.jpg', '2010_005257.jpg', '2009_004129.jpg', '2008_004269.jpg', '2008_001546.jpg']
# probes_per_block : ['2008_001495.jpg', '2010_005257.jpg', '2009_004129.jpg', '2008_004269.jpg', '2008_001546.jpg', '2010_004425.jpg', '2011_002453.jpg', '2011_000481.jpg', '2011_000070.jpg']
# probes:  [['2008_004171.jpg', '2010_000805.jpg', '2009_005044.jpg', '2010_000132.jpg', '2010_000750.jpg', '2008_003876.jpg', '2008_007704.jpg', '2008_004814.jpg'], ['2009_002414.jpg', '2008_005090.jpg', '2008_000860.jpg', '2008_001333.jpg', '2011_001335.jpg', '2009_000120.jpg', '2009_003705.jpg', '2008_005600.jpg'], ['2009_000260.jpg', '2011_001005.jpg', '2011_001886.jpg', '2009_002803.jpg', '2008_000123.jpg', '2011_001613.jpg', '2010_003101.jpg'], ['2008_008097.jpg', '2011_001382.jpg', '2011_001605.jpg', '2008_000833.jpg', '2010_005606.jpg', '2008_002350.jpg', '2010_003729.jpg'], ['2008_005673.jpg', '2010_001993.jpg', '2008_003587.jpg', '2008_000115.jpg', '2010_004231.jpg', '2010_005054.jpg', '2008_000163.jpg', '2008_008083.jpg', '2008_004624.jpg'], ['2008_007745.jpg', '2008_000495.jpg', '2011_002641.jpg', '2010_001939.jpg', '2010_001586.jpg', '2011_001944.jpg', '2010_005628.jpg', '2008_003081.jpg', '2008_006912.jpg'], ['2008_001495.jpg', '2010_005257.jpg', '2009_004129.jpg', '2008_004269.jpg', '2008_001546.jpg', '2010_004425.jpg', '2011_002453.jpg', '2011_000481.jpg', '2011_000070.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 18.874156232375913, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' dog', ' cat', nan, nan, nan, 21.247629460380587, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 16.86296621161062, 'low', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  342
# critical_probes_used ['2008_001185.jpg', '2008_006461.jpg', '2009_003686.jpg', '2009_003309.jpg', '2011_000530.jpg', '2008_006481.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [0, 5, 7, 8, 12, 14, 21, 30, 34, 38, 39, 43] 12
# gap_check:  [8, 21, 34]
# 12
# (0, 'Target Absent')
# (5, 'Target Present')
# (7, 'Target Present')
# (8, 'Critical')
# (12, 'Target Absent')
# (14, 'Target Absent')
# (21, 'Critical')
# (30, 'Target Present')
# (34, 'Critical')
# (38, 'Target Present')
# (39, 'Target Present')
# (43, 'Target Absent')
# [(0, 'Target Absent'), (5, 'Target Present'), (7, 'Target Present'), (8, 'Critical'), (12, 'Target Absent'), (14, 'Target Absent'), (21, 'Critical'), (30, 'Target Present'), (34, 'Critical'), (38, 'Target Present'), (39, 'Target Present'), (43, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 5 Target Present
# image 7 Target Present
# image 8 Critical
# image 12 Target Absent
# image 14 Target Absent
# image 21 Critical
# image 30 Target Present
# image 34 Critical
# image 38 Target Present
# image 39 Target Present
# image 43 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 5, 7, 12, 14, 30, 38, 39, 43]
# present_crit_distribution_original:  [1, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2009
 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 12.7290334446634, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  49
# critical_probes_used ['2010_004014.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ciao2 2
# ------------------
# [1, 5, 12, 19, 22, 29, 38, 39, 43, 47, 56] 11
# gap_check:  [1, 12, 22]
# 11
# (1, 'Critical')
# (5, 'Target Present')
# (12, 'Critical')
# (19, 'Target Absent')
# (22, 'Critical Absent')
# (29, 'Target Present')
# (38, 'Target Present')
# (39, 'Target Present')
# (43, 'Target Absent')
# (47, 'Target Absent')
# (56, 'Target Absent')
# [(1, 'Critical'), (5, 'Target Present'), (12, 'Critical'), (19, 'Target Absent'), (22, 'Critical Absent'), (29, 'Target Present'), (38, 'Target Present'), (39, 'Target Present'), (43, 'Target Absent'), (47, 'Target Absent'), (56, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical
# image 5 Target Present
# image 12 Critical
# image 19 Target Absent
# image 22 Critical Absent
# image 29 Target Present
# image 38 Target Present
# image 39 Target Present
# image 43 Target Absent
# image 47 Target Absent
# image 56 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 19, 22, 29, 38, 39, 43, 47, 56]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [1, 0, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0, 1, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2009_004888.jpg', '2008_007745.jpg']
# critical absent set:  ['2010_004014.jpg', '2008_006461.jpg']
# ---------------------------------------------------
# normal available: 339
# present_critical_per_block: []
# absent_critical_per_block: ['2008_006461.jpg']
# critical_present:  []
# critical_absent:  [['2010_004014.jpg'], ['2008_006461.jpg']]
# critical_probes_used:  ['2010_004014.jpg', '2008_006461.jpg']
# probes_per_block : ['2009_000067.jpg', '2008_000798.jpg', '2008_003461.jpg', '2011_000499.jpg']
# probes_per_block : ['2009_000067.jpg', '2008_000798.jpg', '2008_003461.jpg', '2011_000499.jpg', '2010_004683.jpg', '2011_000631.jpg', '2008_000251.jpg', '2008_000202.jpg']
# probes:  [['2008_004036.jpg', '2010_000109.jpg', '2008_007274.jpg', '2010_001451.jpg', '2009_002374.jpg', '2009_004076.jpg', '2008_004814.jpg', '2008_008083.jpg'], ['2009_000067.jpg', '2008_000798.jpg', '2008_003461.jpg', '2011_000499.jpg', '2010_004683.jpg', '2011_000631.jpg', '2008_000251.jpg', '2008_000202.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 30.530489775112553, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 28.99541660743073, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  98
# critical_probes_used ['2010_004014.jpg', '2008_006461.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical
# image 5 Target Present
# image 12 Critical
# image 19 Target Absent
# image 22 Critical Absent
# image 29 Target Present
# image 38 Target Present
# image 39 Target Present
# image 43 Target Absent
# image 47 Target Absent
# image 56 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 19, 22, 29, 38, 39, 43, 47, 56]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [1, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_004888.jpg', '2008_007745.jpg']
# critical absent set:  ['2010_004014.jpg', '2008_006461.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2010_004014.jpg'], ['2008_006461.jpg']]
# critical_probes_used:  ['2010_004014.jpg', '2008_006461.jpg']
# probes_per_block : ['2010_002349.jpg', '2009_002888.jpg', '2011_002303.jpg', '2010_002956.jpg', '2008_008331.jpg']
# probes_per_block : ['2010_002349.jpg', '2009_002888.jpg', '2011_002303.jpg', '2010_002956.jpg', '2008_008331.jpg', '2008_005673.jpg', '2011_001959.jpg', '2009_002521.jpg', '2008_007704.jpg']
# probes:  [['2008_004036.jpg', '2010_000109.jpg', '2008_007274.jpg', '2010_001451.jpg', '2009_002374.jpg', '2009_004076.jpg', '2008_004814.jpg', '2008_008083.jpg'], ['2009_000067.jpg', '2008_000798.jpg', '2008_003461.jpg', '2011_000499.jpg', '2010_004683.jpg', '2011_000631.jpg', '2008_000251.jpg', '2008_000202.jpg'], ['2010_002349.jpg', '2009_002888.jpg', '2011_002303.jpg', '2010_002956.jpg', '2008_008331.jpg', '2008_005673.jpg', '2011_001959.jpg', '2009_002521.jpg', '2008_007704.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bottle', ' cat', nan, nan, nan, 21.259829756421425, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 18.837863956276628, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 16.520476370843983, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  146
# critical_probes_used ['2010_004014.jpg', '2008_006461.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [3, 5, 9, 14, 17, 18, 26, 28, 33, 34, 41, 42] 12
# gap_check:  [9, 34, 42]
# 12
# (3, 'Target Absent')
# (5, 'Target Present')
# (9, 'Critical')
# (14, 'Target Present')
# (17, 'Target Absent')
# (18, 'Target Present')
# (26, 'Target Absent')
# (28, 'Target Present')
# (33, 'Target Present')
# (34, 'Critical')
# (41, 'Target Absent')
# (42, 'Critical')
# [(3, 'Target Absent'), (5, 'Target Present'), (9, 'Critical'), (14, 'Target Present'), (17, 'Target Absent'), (18, 'Target Present'), (26, 'Target Absent'), (28, 'Target Present'), (33, 'Target Present'), (34, 'Critical'), (41, 'Target Absent'), (42, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Absent
# image 5 Target Present
# image 9 Critical
# image 14 Target Present
# image 17 Target Absent
# image 18 Target Present
# image 26 Target Absent
# image 28 Target Present
# image 33 Target Present
# image 34 Critical
# image 41 Target Absent
# image 42 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 5, 14, 17, 18, 26, 28, 33, 41]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [1, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_004888.jpg', '2008_007745.jpg']
# critical absent set:  ['2010_004014.jpg', '2008_006461.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2010_004014.jpg'], ['2008_006461.jpg']]
# critical_probes_used:  ['2010_004014.jpg', '2008_006461.jpg']
# probes_per_block : ['2008_000982.jpg', '2010_003297.jpg', '2008_006663.jpg', '2009_004794.jpg', '2008_002758.jpg']
# probes_per_block : ['2008_000982.jpg', '2010_003297.jpg', '2008_006663.jpg', '2009_004794.jpg', '2008_002758.jpg', '2010_002278.jpg', '2008_007108.jpg', '2010_005572.jpg', '2008_005600.jpg']
# probes:  [['2008_004036.jpg', '2010_000109.jpg', '2008_007274.jpg', '2010_001451.jpg', '2009_002374.jpg', '2009_004076.jpg', '2008_004814.jpg', '2008_008083.jpg'], ['2009_000067.jpg', '2008_000798.jpg', '2008_003461.jpg', '2011_000499.jpg', '2010_004683.jpg', '2011_000631.jpg', '2008_000251.jpg', '2008_000202.jpg'], ['2010_002349.jpg', '2009_002888.jpg', '2011_002303.jpg', '2010_002956.jpg', '2008_008331.jpg', '2008_005673.jpg', '2011_001959.jpg', '2009_002521.jpg', '2008_007704.jpg'], ['2008_000982.jpg', '2010_003297.jpg', '2008_006663.jpg', '2009_004794.jpg', '2008_002758.jpg', '2010_002278.jpg', '2008_007108.jpg', '2010_005572.jpg', '2008_005600.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bird', ' boat', nan, nan, nan, 29.314233597971626, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 30.80608913442844, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' diningtable', ' bottle', nan, nan, 38.97264238893902, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  194
# critical_probes_used ['2010_004014.jpg', '2008_006461.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Absent
# image 5 Target Present
# image 9 Critical
# image 14 Target Present
# image 17 Target Absent
# image 18 Target Present
# image 26 Target Absent
# image 28 Target Present
# image 33 Target Present
# image 34 Critical
# image 41 Target Absent
# image 42 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 5, 14, 17, 18, 26, 28, 33, 41]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [1, 0, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_004888.jpg', '2008_007745.jpg']
# critical absent set:  ['2010_004014.jpg', '2008_006461.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: ['2009_004888.jpg']
# absent_critical_per_block: []
# critical_present:  [['2009_004888.jpg']]
# critical_absent:  [['2010_004014.jpg'], ['2008_006461.jpg']]
# critical_probes_used:  ['2010_004014.jpg', '2008_006461.jpg', '2009_004888.jpg']
# probes_per_block : ['2009_002711.jpg', '2008_000177.jpg', '2011_000070.jpg']
# probes_per_block : ['2009_002711.jpg', '2008_000177.jpg', '2011_000070.jpg', '2009_001470.jpg', '2008_001694.jpg', '2009_001406.jpg', '2010_005785.jpg', '2008_001221.jpg']
# probes:  [['2008_004036.jpg', '2010_000109.jpg', '2008_007274.jpg', '2010_001451.jpg', '2009_002374.jpg', '2009_004076.jpg', '2008_004814.jpg', '2008_008083.jp
 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', ' bicycle', ' motorbike', ' bus', ' person', 30.26344946567593, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 34.17783424769062, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  388
# critical_probes_used ['2010_004014.jpg', '2008_006461.jpg', '2009_004888.jpg', '2008_007745.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 15 Target Present
# image 18 Target Present
# image 19 Target Absent
# image 25 Critical
# image 28 Target Absent
# image 31 Target Absent
# image 35 Critical
# image 40 Target Absent
# image 46 Target Present
# image 50 Target Present
# image 51 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [7, 15, 18, 19, 28, 31, 40, 46, 50]
# 60 60
# len(trials):  960

# %%
######################
### THIRD ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(961)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  10
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 1]
# critical present set:  []
# critical absent set:  ['2008_002504.jpg', '2009_000539.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg']
# probes_per_block : ['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg', '2008_003709.jpg', '2009_002711.jpg', '2010_000750.jpg', '2010_000805.jpg', '2008_004412.jpg']
# probes:  [['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg', '2008_003709.jpg', '2009_002711.jpg', '2010_000750.jpg', '2010_000805.jpg', '2008_004412.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' boat', nan, nan, nan, nan, 19.685752299806754, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 16.98544233464372, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' chair', ' diningtable', ' bottle', nan, nan, 20.038119878562025, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [6, 11, 12, 19, 22, 23, 29, 32, 35, 44, 46, 53] 12
# gap_check:  [6, 29, 53]
# 12
# (6, 'Critical')
# (11, 'Target Absent')
# (12, 'Target Present')
# (19, 'Target Present')
# (22, 'Target Absent')
# (23, 'Target Present')
# (29, 'Critical')
# (32, 'Target Absent')
# (35, 'Target Present')
# (44, 'Target Absent')
# (46, 'Target Absent')
# (53, 'Critical')
# [(6, 'Critical'), (11, 'Target Absent'), (12, 'Target Present'), (19, 'Target Present'), (22, 'Target Absent'), (23, 'Target Present'), (29, 'Critical'), (32, 'Target Absent'), (35, 'Target Present'), (44, 'Target Absent'), (46, 'Target Absent'), (53, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Critical
# image 11 Target Absent
# image 12 Target Present
# image 19 Target Present
# image 22 Target Absent
# image 23 Target Present
# image 29 Critical
# image 32 Target Absent
# image 35 Target Present
# image 44 Target Absent
# image 46 Target Absent
# image 53 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [11, 12, 19, 22, 23, 32, 35, 44, 46]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 1]
# critical present set:  []
# critical absent set:  ['2008_002504.jpg', '2009_000539.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_003724.jpg', '2010_000815.jpg', '2009_002571.jpg', '2010_001939.jpg']
# probes_per_block : ['2010_003724.jpg', '2010_000815.jpg', '2009_002571.jpg', '2010_001939.jpg', '2010_004683.jpg', '2008_005090.jpg', '2009_004364.jpg', '2008_001673.jpg', '2009_002414.jpg']
# probes:  [['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg', '2008_003709.jpg', '2009_002711.jpg', '2010_000750.jpg', '2010_000805.jpg', '2008_004412.jpg'], ['2010_003724.jpg', '2010_000815.jpg', '2009_002571.jpg', '2010_001939.jpg', '2010_004683.jpg', '2008_005090.jpg', '2009_004364.jpg', '2008_001673.jpg', '2009_002414.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' bottle', nan, nan, nan, 30.958055456079503, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' boat', ' car', nan, nan, 35.70470893485066, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' car', ' bus', ' person', nan, nan, 31.30513576919045, 'high', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Critical
# image 11 Target Absent
# image 12 Target Present
# image 19 Target Present
# image 22 Target Absent
# image 23 Target Present
# image 29 Critical
# image 32 Target Absent
# image 35 Target Present
# image 44 Target Absent
# image 46 Target Absent
# image 53 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [11, 12, 19, 22, 23, 32, 35, 44, 46]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 1]
# critical present set:  []
# critical absent set:  ['2008_002504.jpg', '2009_000539.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_004984.jpg', '2008_005735.jpg', '2009_000523.jpg', '2008_008359.jpg', '2011_001959.jpg']
# probes_per_block : ['2009_004984.jpg', '2008_005735.jpg', '2009_000523.jpg', '2008_008359.jpg', '2011_001959.jpg', '2009_003232.jpg', '2009_002998.jpg', '2008_003587.jpg', '2008_004893.jpg']
# probes:  [['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg', '2008_003709.jpg', '2009_002711.jpg', '2010_000750.jpg', '2010_000805.jpg', '2008_004412.jpg'], ['2010_003724.jpg', '2010_000815.jpg', '2009_002571.jpg', '2010_001939.jpg', '2010_004683.jpg', '2008_005090.jpg', '2009_004364.jpg', '2008_001673.jpg', '2009_002414.jpg'], ['2009_004984.jpg', '2008_005735.jpg', '2009_000523.jpg', '2008_008359.jpg', '2011_001959.jpg', '2009_003232.jpg', '2009_002998.jpg', '2008_003587.jpg', '2008_004893.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' sofa', nan, nan, nan, 18.96772267222304, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 20.757885363436266, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 20.48716672648194, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [2, 4, 7, 11, 16, 26, 27, 34, 38, 42, 44, 50] 12
# gap_check:  [7, 11, 16]
# 12
# (2, 'Target Present')
# (4, 'Target Present')
# (7, 'Critical')
# (11, 'Critical')
# (16, 'Critical')
# (26, 'Target Absent')
# (27, 'Target Absent')
# (34, 'Target Present')
# (38, 'Target Present')
# (42, 'Target Present')
# (44, 'Target Absent')
# (50, 'Target Absent')
# [(2, 'Target Present'), (4, 'Target Present'), (7, 'Critical'), (11, 'Critical'), (16, 'Critical'), (26, 'Target Absent'), (27, 'Target Absent'), (34, 'Target Present'), (38, 'Target Present'), (42, 'Target Present'), (44, 'Target Absent'), (50, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Present
# image 4 Target Present
# image 7 Critical
# image 11 Critical
# image 16 Critical
# image 26 Target Absent
# image 27 Target Absent
# image 34 Target Present
# image 38 Target Present
# image 42 Target Present
# image 44 Target Absent
# image 50 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [2, 4, 26, 27, 34, 38, 42, 44, 50]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 1]
# critical present set:  []
# critical absent set:  ['2008_002504.jpg', '2009_000539.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_007423.jpg', '2010_004423.jpg', '2009_005133.jpg', '2008_001278.jpg', '2011_001221.jpg']
# probes_per_block : ['2008_007423.jpg', '2010_004423.jpg', '2009_005133.jpg', '2008_001278.jpg', '2011_001221.jpg', '2009_004849.jpg', '2011_002814.jpg', '2008_000982.jpg', '2008_004690.jpg']
# probes:  [['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg', '2008_003709.jpg', '2009_002711.jpg', '2010_000750.jpg', '2010_000805.jpg', '2008_004412.jpg'], ['2010_003724.jpg', '2010_000815.jpg', '2009_002571.jpg', '2010_001939.jpg', '2010_004683.jpg', '2008_005090.jpg', '2009_004364.jpg', '2008_001673.jpg', '2009_002414.jpg'], ['2009_004984.jpg', '2008_005735.jpg', '2009_000523.jpg', '2008_008359.jpg', '2011_001959.jpg', '2009_003232.jpg', '2009_002998.jpg', '2008_003587.jpg', '2008_004893.jpg'], ['2008_007423.jpg', '2010_004423.jpg', '2009_005133.jpg', '2008_001278.jpg', '2011_001221.jpg', '2009_004849.jpg', '2011_002814.jpg', '2008_000982.jpg', '2008_004690.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', ' aeroplane', nan, nan, nan, 35.87217940794205, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 33.33497246868347, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' dog', ' car', nan, nan, 33.09488500291814, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Present
# image 4 Target Present
# image 7 Critical
# image 11 Critical
# image 16 Critical
# image 26 Target Absent
# image 27 Target Absent
# image 34 Target Present
# image 38 Target Present
# image 42 Target Present
# image 44 Target Absent
# image 50 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [2, 4, 26, 27, 34, 38, 42, 44, 50]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [1]
# critical present set:  []
# critical absent set:  ['2008_002504.jpg', '2009_000539.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_006564.jpg', '2010_004339.jpg', '2010_003287.jpg', '2009_002697.jpg']
# probes_per_block : ['2008_006564.jpg', '2010_004339.jpg', '2010_003287.jpg', '2009_002697.jpg', '2008_004624.jpg', '2009_002749.jpg', '2009_003309.jpg', '2010_005054.jpg', '2008_006072.jpg']
# probes:  [['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg', '2008_003709.jpg', '2009_002711.jpg', '2010_000750.jpg', '2010_000805.jpg', '2008_004412.jpg'], ['2010_003724.jpg', '2010_000815.jpg', '2009_002571.jpg', '2010_001939.jpg', '2010_004683.jpg', '2008_005090.jpg', '2009_004364.jpg', '2008_001673.jpg', '2009_002414.jpg'], ['2009_004984.jpg', '2008_005735.jpg', '2009_000523.jpg', '2008_008359.jpg', '2011_001959.jpg', '2009_003232.jpg', '2009_002998.jpg', '2008_003587.jpg', '2008_004893.jpg'], ['2008_007423.jpg', '2010_004423.jpg', '2009_005133.jpg', '2008_001278.jpg', '2011_001221.jpg', '2009_004849.jpg', '2011_002814.jpg', '2008_000982.jpg', '2008_004690.jpg'], ['2008_006564.jpg', '2010_004339.jpg', '2010_003287.jpg', '2009_002697.jpg', '2008_004624.jpg', '2009_002749.jpg', '2009_003309.jpg', '2010_005054.jpg', '2008_006072.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 21.19410161612616, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 16.69849859536183, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 19.901616892338367, 'low', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  240
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [1, 3, 5, 11, 17, 18, 27, 35, 39, 45, 52, 57] 12
# gap_check:  [5, 11, 27]
# 12
# (1, 'Target Absent')
# (3, 'Target Absent')
# (5, 'Critical')
# (11, 'Critical')
# (17, 'Target Present')
# (18, 'Target Present')
# (27, 'Critical')
# (35, 'Target Present')
# (39, 'Target Absent')
# (45, 'Target Present')
# (52, 'Target Absent')
# (57, 'Target Absent')
# [(1, 'Target Absent'), (3, 'Target Absent'), (5, 'Critical'), (11, 'Critical'), (17, 'Target Present'), (18, 'Target Present'), (27, 'Critical'), (35, 'Target Present'), (39, 'Target Absent'), (45, 'Target Present'), (52, 'Target Absent'), (57, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 3 Target Absent
# image 5 Critical
# image 11 Critical
# image 17 Target Present
# image 18 Target Present
# image 27 Critical
# image 35 Target Present
# image 39 Target Absent
# image 45 Target Present
# image 52 Target Absent
# image 57 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 3, 17, 18, 35, 39, 45, 52, 57]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [1]
# critical present set:  []
# critical absent set:  ['2008_002504.jpg', '2009_000539.jpg']
# ---------------------------------------------------
# normal available: 146
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_008470.jpg', '2008_003081.jpg', '2008_000495.jpg', '2010_005894.jpg']
# probes_per_block : ['2008_008470.jpg', '2008_003081.jpg', '2008_000495.jpg', '2010_005894.jpg', '2010_002620.jpg', '2011_001800.jpg', '2009_000629.jpg', '2010_002183.jpg', '2008_007057.jpg']
# probes:  [['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg', '2008_003709.jpg', '2009_002711.jpg', '2010_000750.jpg', '2010_000805.jpg', '2008_004412.jpg'], ['2010_003724.jpg', '2010_000815.jpg', '2009_002571.jpg', '2010_001939.jpg', '2010_004683.jpg', '2008_005090.jpg', '2009_004364.jpg', '2008_001673.jpg', '2009_002414.jpg'], ['2009_004984.jpg', '2008_005735.jpg', '2009_000523.jpg', '2008_008359.jpg', '2011_001959.jpg', '2009_003232.jpg', '2009_002998.jpg', '2008_003587.jpg', '2008_004893.jpg'], ['2008_007423.jpg', '2010_004423.jpg', '2009_005133.jpg', '2008_001278.jpg', '2011_001221.jpg', '2009_004849.jpg', '2011_002814.jpg', '2008_000982.jpg', '2008_004690.jpg'], ['2008_006564.jpg', '2010_004339.jpg', '2010_003287.jpg', '2009_002697.jpg', '2008_004624.jpg', '2009_002749.jpg', '2009_003309.jpg', '2010_005054.jpg', '2008_006072.jpg'], ['2008_008470.jpg', '2008_003081.jpg', '2008_000495.jpg', '2010_005894.jpg', '2010_002620.jpg', '2011_001800.jpg', '2009_000629.jpg', '2010_002183.jpg', '2008_007057.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' chair', nan, nan, nan, 32.054269676274835, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', ' diningtable', ' tvmonitor', 29.247483266365705, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 29.27265460253791, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  288
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 3 Target Absent
# image 5 Critical
# image 11 Critical
# image 17 Target Present
# image 18 Target Present
# image 27 Critical
# image 35 Target Present
# image 39 Target Absent
# image 45 Target Present
# image 52 Target Absent
# image 57 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 3, 17, 18, 35, 39, 45, 52, 57]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 1]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  []
# critical absent set:  ['2008_002504.jpg', '2009_000539.jpg']
# ---------------------------------------------------
# normal available: 98
# present_critical_per_block: []
# absent_critical_per_block: ['2008_002504.jpg']
# critical_present:  []
# critical_absent:  [['2008_002504.jpg']]
# critical_probes_used:  ['2008_002504.jpg']
# probes_per_block : ['2011_002558.jpg', '2009_004598.jpg', '2010_005217.jpg', '2008_008331.jpg', '2009_003679.jpg']
# probes_per_block : ['2011_002558.jpg', '2009_004598.jpg', '2010_005217.jpg', '2008_008331.jpg', '2009_003679.jpg', '2009_000619.jpg', '2008_001479.jpg', '2008_000734.jpg']
# probes:  [['2009_004129.jpg', '2010_004425.jpg', '2009_005044.jpg', '2008_001098.jpg', '2008_003709.jpg', '2009_002711.jpg', '2010_000750.jpg', '2010_000805.jpg', '2008_004412.jp
_006564.jpg', '2010_004339.jpg', '2010_003287.jpg', '2009_002697.jpg', '2008_004624.jpg', '2009_002749.jpg', '2009_003309.jpg', '2010_005054.jpg', '2008_006072.jpg'], ['2008_008470.jpg', '2008_003081.jpg', '2008_000495.jpg', '2010_005894.jpg', '2010_002620.jpg', '2011_001800.jpg', '2009_000629.jpg', '2010_002183.jpg', '2008_007057.jpg'], ['2011_002558.jpg', '2009_004598.jpg', '2010_005217.jpg', '2008_008331.jpg', '2009_003679.jpg', '2009_000619.jpg', '2008_001479.jpg', '2008_000734.jpg'], ['2008_006216.jpg', '2011_002810.jpg', '2011_000282.jpg', '2008_001965.jpg', '2008_003701.jpg', '2008_003449.jpg', '2010_001586.jpg', '2008_008607.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' tvmonitor', ' chair', ' sofa', nan, nan, 37.22381580448725, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 31.779858819461175, 'high', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  386
# critical_probes_used ['2008_002504.jpg', '2009_000539.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 4 Target Absent
# image 14 Target Present
# image 16 Target Absent
# image 17 Target Present
# image 19 Target Present
# image 26 Critical
# image 31 Critical Absent
# image 38 Target Present
# image 44 Target Absent
# image 46 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 4, 14, 16, 17, 19, 31, 38, 44]
# 60 60
# len(trials):  1440

# %%
######################
### FOURTH ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1441)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  9
# Critical, high:  9
# Are all critical trials unique?  True
# Number of critical probes:  6
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  2
# critical_high_absent_probes:  2
# cycles :  25
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [2, 0, 0, 0]
# present_crit 0
# absent_crit 2
# present_crit_distribution:  [0, 1, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2009_000523.jpg', '2009_002571.jpg']
# critical absent set:  ['2008_005490.jpg', '2011_001959.jpg', '2010_004778.jpg', '2008_004661.jpg']
# ---------------------------------------------------
# normal available: 390
# present_critical_per_block: []
# absent_critical_per_block: ['2011_001959.jpg', '2008_005490.jpg']
# critical_present:  []
# critical_absent:  [['2011_001959.jpg', '2008_005490.jpg']]
# critical_probes_used:  ['2011_001959.jpg', '2008_005490.jpg']
# probes_per_block : ['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg']
# probes_per_block : ['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg', '2009_005308.jpg', '2008_005978.jpg', '2009_001137.jpg']
# probes:  [['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg', '2009_005308.jpg', '2008_005978.jpg', '2009_001137.jpg']]
# Present Used in block:  4
# Absent Used in block 3
# Critical probes counter:  2
# Present Critical:  0
# Absent Critical:  2
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 20.559862456799, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  50
# critical_probes_used ['2011_001959.jpg', '2008_005490.jpg']
# sequence final does not exist
# x 2
# present_critical_per_block 0
# absent_critical_per_block 2
# ciao2 1
# ciao2 1
# ciao2 1
# ------------------
# [5, 10, 18, 20, 25, 26, 36, 37, 42, 46] 10
# gap_check:  [5, 10, 42]
# 10
# (5, 'Critical Absent')
# (10, 'Critical Absent')
# (18, 'Target Absent')
# (20, 'Target Present')
# (25, 'Target Present')
# (26, 'Target Absent')
# (36, 'Target Present')
# (37, 'Target Absent')
# (42, 'Critical')
# (46, 'Target Present')
# [(5, 'Critical Absent'), (10, 'Critical Absent'), (18, 'Target Absent'), (20, 'Target Present'), (25, 'Target Present'), (26, 'Target Absent'), (36, 'Target Present'), (37, 'Target Absent'), (42, 'Critical'), (46, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical Absent
# image 10 Critical Absent
# image 18 Target Absent
# image 20 Target Present
# image 25 Target Present
# image 26 Target Absent
# image 36 Target Present
# image 37 Target Absent
# image 42 Critical
# image 46 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 10, 18, 20, 25, 26, 36, 37, 46]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [2, 0, 0, 0]
# present_crit 0
# absent_crit 2
# present_crit_distribution:  [0, 1, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2009_000523.jpg', '2009_002571.jpg']
# critical absent set:  ['2008_005490.jpg', '2011_001959.jpg', '2010_004778.jpg', '2008_004661.jpg']
# ---------------------------------------------------
# normal available: 340
# present_critical_per_block: []
# absent_critical_per_block: ['2008_004661.jpg', '2010_004778.jpg']
# critical_present:  []
# critical_absent:  [['2011_001959.jpg', '2008_005490.jpg'], ['2008_004661.jpg', '2010_004778.jpg']]
# critical_probes_used:  ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg']
# probes_per_block : ['2008_005600.jpg', '2008_005720.jpg', '2008_002758.jpg', '2008_007143.jpg']
# probes_per_block : ['2008_005600.jpg', '2008_005720.jpg', '2008_002758.jpg', '2008_007143.jpg', '2011_000628.jpg', '2008_002774.jpg', '2010_004683.jpg']
# probes:  [['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg', '2009_005308.jpg', '2008_005978.jpg', '2009_001137.jpg'], ['2008_005600.jpg', '2008_005720.jpg', '2008_002758.jpg', '2008_007143.jpg', '2011_000628.jpg', '2008_002774.jpg', '2010_004683.jpg']]
# Present Used in block:  4
# Absent Used in block 3
# Critical probes counter:  2
# Present Critical:  0
# Absent Critical:  2
# List of critical trials without probe:
# [' person', ' diningtable', ' bottle', nan, nan, 36.41404223766773, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  100
# critical_probes_used ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical Absent
# image 10 Critical Absent
# image 18 Target Absent
# image 20 Target Present
# image 25 Target Present
# image 26 Target Absent
# image 36 Target Present
# image 37 Target Absent
# image 42 Critical
# image 46 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 10, 18, 20, 25, 26, 36, 37, 46]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [2, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_000523.jpg', '2009_002571.jpg']
# critical absent set:  ['2008_005490.jpg', '2011_001959.jpg', '2010_004778.jpg', '2008_004661.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2011_001959.jpg', '2008_005490.jpg'], ['2008_004661.jpg', '2010_004778.jpg']]
# critical_probes_used:  ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg']
# probes_per_block : ['2008_000105.jpg', '2009_000260.jpg', '2009_003209.jpg', '2008_002145.jpg', '2008_002504.jpg']
# probes_per_block : ['2008_000105.jpg', '2009_000260.jpg', '2009_003209.jpg', '2008_002145.jpg', '2008_002504.jpg', '2009_000919.jpg', '2008_001617.jpg', '2008_006837.jpg', '2010_001907.jpg']
# probes:  [['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg', '2009_005308.jpg', '2008_005978.jpg', '2009_001137.jpg'], ['2008_005600.jpg', '2008_005720.jpg', '2008_002758.jpg', '2008_007143.jpg', '2011_000628.jpg', '2008_002774.jpg', '2010_004683.jpg'], ['2008_000105.jpg', '2009_000260.jpg', '2009_003209.jpg', '2008_002145.jpg', '2008_002504.jpg', '2009_000919.jpg', '2008_001617.jpg', '2008_006837.jpg', '2010_001907.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 16.417039192791336, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' car', nan, nan, 20.934599857700228, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 18.642450428633328, 'low', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  148
# critical_probes_used ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [3, 5, 13, 21, 23, 25, 34, 35, 40, 41, 44, 50] 12
# gap_check:  [5, 35, 50]
# 12
# (3, 'Target Present')
# (5, 'Critical')
# (13, 'Target Absent')
# (21, 'Target Present')
# (23, 'Target Absent')
# (25, 'Target Absent')
# (34, 'Target Present')
# (35, 'Critical')
# (40, 'Target Present')
# (41, 'Target Present')
# (44, 'Target Absent')
# (50, 'Critical')
# [(3, 'Target Present'), (5, 'Critical'), (13, 'Target Absent'), (21, 'Target Present'), (23, 'Target Absent'), (25, 'Target Absent'), (34, 'Target Present'), (35, 'Critical'), (40, 'Target Present'), (41, 'Target Present'), (44, 'Target Absent'), (50, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 5 Critical
# image 13 Target Absent
# image 21 Target Present
# image 23 Target Absent
# image 25 Target Absent
# image 34 Target Present
# image 35 Critical
# image 40 Target Present
# image 41 Target Present
# image 44 Target Absent
# image 50 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 13, 21, 23, 25, 34, 40, 41, 44]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [2, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_000523.jpg', '2009_002571.jpg']
# critical absent set:  ['2008_005490.jpg', '2011_001959.jpg', '2010_004778.jpg', '2008_004661.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  [['2011_001959.jpg', '2008_005490.jpg'], ['2008_004661.jpg', '2010_004778.jpg']]
# critical_probes_used:  ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg']
# probes_per_block : ['2008_003081.jpg', '2008_001451.jpg', '2011_001304.jpg', '2008_002350.jpg', '2011_002555.jpg']
# probes_per_block : ['2008_003081.jpg', '2008_001451.jpg', '2011_001304.jpg', '2008_002350.jpg', '2011_002555.jpg', '2008_003635.jpg', '2008_008210.jpg', '2008_006062.jpg', '2008_000798.jpg']
# probes:  [['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg', '2009_005308.jpg', '2008_005978.jpg', '2009_001137.jpg'], ['2008_005600.jpg', '2008_005720.jpg', '2008_002758.jpg', '2008_007143.jpg', '2011_000628.jpg', '2008_002774.jpg', '2010_004683.jpg'], ['2008_000105.jpg', '2009_000260.jpg', '2009_003209.jpg', '2008_002145.jpg', '2008_002504.jpg', '2009_000919.jpg', '2008_001617.jpg', '2008_006837.jpg', '2010_001907.jpg'], ['2008_003081.jpg', '2008_001451.jpg', '2011_001304.jpg', '2008_002350.jpg', '2011_002555.jpg', '2008_003635.jpg', '2008_008210.jpg', '2008_006062.jpg', '2008_000798.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 35.66913245555085, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 30.065266395495016, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', ' car', nan, nan, 34.31316104129318, 'high', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  196
# critical_probes_used ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 5 Critical
# image 13 Target Absent
# image 21 Target Present
# image 23 Target Absent
# image 25 Target Absent
# image 34 Target Present
# image 35 Critical
# image 40 Target Present
# image 41 Target Present
# image 44 Target Absent
# image 50 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 13, 21, 23, 25, 34, 40, 41, 44]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [2, 0, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_000523.jpg', '2009_002571.jpg']
# critical absent set:  ['2008_005490.jpg', '2011_001959.jpg', '2010_004778.jpg', '2008_004661.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: ['2009_000523.jpg']
# absent_critical_per_block: []
# critical_present:  [['2009_000523.jpg']]
# critical_absent:  [['2011_001959.jpg', '2008_005490.jpg'], ['2008_004661.jpg', '2010_004778.jpg']]
# critical_probes_used:  ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg', '2009_000523.jpg']
# probes_per_block : ['2008_000940.jpg', '2010_005054.jpg', '2008_004171.jpg']
# probes_per_block : ['2008_000940.jpg', '2010_005054.jpg', '2008_004171.jpg', '2009_003084.jpg', '2008_000839.jpg', '2008_002062.jpg', '2008_000123.jpg', '2008_000740.jpg']
# probes:  [['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg', '2009_005308.jpg', '2008_005978.jpg', '2009_001137.jpg'], ['2008_005600.jpg', '2008_005720.jpg', '2008_002758.jpg', '2008_007143.jpg', '2011_000628.jpg', '2008_002774.jpg', '2010_004683.jpg'], ['2008_000105.jpg', '2009_000260.jpg', '2009_003209.jpg', '2008_002145.jpg', '2008_002504.jpg', '2009_000919.jpg', '2008_001617.jpg', '2008_006837.jpg', '2010_001907.jpg'], ['2008_003081.jpg', '2008_001451.jpg', '2011_001304.jpg', '2008_002350.jpg', '2011_002555.jpg', '2008_003635.jpg', '2008_008210.jpg', '2008_006062.jpg', '2008_000798.jpg'], ['2008_000940.jpg', '2010_005054.jpg', '2008_004171.jpg', '2009_003084.jpg', '2008_000839.jpg', '2008_002062.jpg', '2008_000123.jpg', '2008_000740.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', ' dog', nan, nan, nan, 16.142562620916582, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' chair', ' diningtable', nan, nan, nan, 15.830708942989276, 'low', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  245
# critical_probes_used ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg', '2009_000523.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 1
# absent_critical_per_block 0
# ciao2 2
# ------------------
# [4, 12, 20, 27, 33, 39, 41, 45, 46, 49, 58] 11
# gap_check:  [12, 27, 33]
# 11
# (4, 'Target Present')
# (12, 'Critical Present')
# (20, 'Target Absent')
# (27, 'Critical')
# (33, 'Critical')
# (39, 'Target Absent')
# (41, 'Target Absent')
# (45, 'Target Absent')
# (46, 'Target Present')
# (49, 'Target Present')
# (58, 'Target Absent')
# [(4, 'Target Present'), (12, 'Critical Present'), (20, 'Target Absent'), (27, 'Critical'), (33, 'Critical'), (39, 'Target Absent'), (41, 'Target Absent'), (45, 'Target Absent'), (46, 'Target Present'), (49, 'Target Present'), (58, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 4 Target Present
# image 12 Critical Present
# image 20 Target Absent
# image 27 Critical
# image 33 Critical
# image 39 Target Absent
# image 41 Target Absent
# image 45 Target Absent
# image 46 Target Present
# image 49 Target Present
# image 58 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [4, 12, 20, 39, 41, 45, 46, 49, 58]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [2, 0, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_000523.jpg', '2009_002571.jpg']
# critical absent set:  ['2008_005490.jpg', '2011_001959.jpg', '2010_004778.jpg', '2008_004661.jpg']
# ---------------------------------------------------
# normal available: 145
# present_critical_per_block: ['2009_002571.jpg']
# absent_critical_per_block: []
# critical_present:  [['2009_000523.jpg'], ['2009_002571.jpg']]
# critical_absent:  [['2011_001959.jpg', '2008_005490.jpg'], ['2008_004661.jpg', '2010_004778.jpg']]
# critical_probes_used:  ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg', '2009_000523.jpg', '2009_002571.jpg']
# probes_per_block : ['2011_001335.jpg', '2008_007745.jpg', '2009_004414.jpg']
# probes_per_block : ['2011_001335.jpg', '2008_007745.jpg', '2009_004414.jpg', '2011_001001.jpg', '2008_006481.jpg', '2008_000833.jpg', '2008_002119.jpg', '2008_007423.jpg']
# probes:  [['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg', '2009_005308.jpg', '2008_005978.jpg', '2009_001137.jpg'], ['2008_005600.jpg', '2008_005720.jpg', '2008_002758.jpg', '2008_007143.jpg', '2011_000628.jpg', '2008_002774.jpg', '2010_004683.jpg'], ['2008_000105.jpg', '2009_000260.jpg', '2009_003209.jpg', '2008_002145.jpg', '2008_002504.jpg', '2009_000919.jpg', '2008_001617.jpg', '2008_006837.jpg', '2010_001907.jpg'], ['2008_003081.jpg', '2008_001451.jpg', '2011_001304.jpg', '2008_002350.jpg', '2011_002555.jpg', '2008_003635.jpg', '2008_008210.jpg', '2008_006062.jpg', '2008_000798.jpg'], ['2008_000940.jpg', '2010_005054.jpg', '2008_004171.jp
['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg', '2009_000523.jpg', '2009_002571.jpg']
# probes_per_block : ['2008_002864.jpg', '2011_002482.jpg', '2008_006870.jpg', '2008_002672.jpg', '2010_000865.jpg']
# probes_per_block : ['2008_002864.jpg', '2011_002482.jpg', '2008_006870.jpg', '2008_002672.jpg', '2010_000865.jpg', '2011_003066.jpg', '2009_003884.jpg', '2009_004154.jpg', '2008_000381.jpg']
# probes:  [['2008_004607.jpg', '2009_004779.jpg', '2011_001886.jpg', '2011_002582.jpg', '2009_005308.jpg', '2008_005978.jpg', '2009_001137.jpg'], ['2008_005600.jpg', '2008_005720.jpg', '2008_002758.jpg', '2008_007143.jpg', '2011_000628.jpg', '2008_002774.jpg', '2010_004683.jpg'], ['2008_000105.jpg', '2009_000260.jpg', '2009_003209.jpg', '2008_002145.jpg', '2008_002504.jpg', '2009_000919.jpg', '2008_001617.jpg', '2008_006837.jpg', '2010_001907.jpg'], ['2008_003081.jpg', '2008_001451.jpg', '2011_001304.jpg', '2008_002350.jpg', '2011_002555.jpg', '2008_003635.jpg', '2008_008210.jpg', '2008_006062.jpg', '2008_000798.jpg'], ['2008_000940.jpg', '2010_005054.jpg', '2008_004171.jpg', '2009_003084.jpg', '2008_000839.jpg', '2008_002062.jpg', '2008_000123.jpg', '2008_000740.jpg'], ['2011_001335.jpg', '2008_007745.jpg', '2009_004414.jpg', '2011_001001.jpg', '2008_006481.jpg', '2008_000833.jpg', '2008_002119.jpg', '2008_007423.jpg'], ['2008_000177.jpg', '2011_003074.jpg', '2008_005728.jpg', '2010_001451.jpg', '2008_000734.jpg', '2008_007048.jpg', '2010_000426.jpg', '2010_005785.jpg', '2010_005391.jpg'], ['2008_002864.jpg', '2011_002482.jpg', '2008_006870.jpg', '2008_002672.jpg', '2010_000865.jpg', '2011_003066.jpg', '2009_003884.jpg', '2009_004154.jpg', '2008_000381.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 31.19357078875772, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 30.51535276170641, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 30.20203583105944, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  390
# critical_probes_used ['2011_001959.jpg', '2008_005490.jpg', '2008_004661.jpg', '2010_004778.jpg', '2009_000523.jpg', '2009_002571.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 2 Target Absent
# image 4 Critical
# image 8 Target Absent
# image 9 Target Present
# image 14 Critical
# image 17 Target Present
# image 26 Target Present
# image 30 Target Present
# image 37 Target Absent
# image 41 Critical
# image 46 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 2, 8, 9, 17, 26, 30, 37, 46]
# 60 60
# len(trials):  1920

# %%
print len(normal_no_probe_before)
print len(normal_used)
print len(normal_no_probe_before) == len(set(normal_used))
print len(target_present_before)
print len(present_used)
print len(target_present_before) == len(set(present_used))
print len(target_absent_before)
print len(absent_used)
print len(target_absent_before) == len(set(absent_used))

#the following is not a good check
print len(set(critical_trials_before)) == len(set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes))

print set(critical_trials_before) == set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes)

print len(low_four)
print len(low_one) == len(low_two) == len(low_three) == len(low_four) == len(high_one) == len(high_two) == len(high_three) == len(high_four)
print len(set(low_one) & set(low_two) & set(low_three) & set(low_four) & set(high_one) & set(high_two) & set(high_three) & set(high_four))
# Out:
# 390
# 390
# True
# 36
# 34
# False
# 36
# 32
# False
# True
# True
# 60
# True
# 0

# %%
#CREATE BLOCK COLUMN
for i in range(len(trials.keys())):
    trials[i+1].append(i/60+1)

# %%
tone_Hz1, sound_onset1 = tone_properties()
tone_Hz2, sound_onset2 = tone_properties()
tone_Hz3, sound_onset3 = tone_properties()
tone_Hz4, sound_onset4 = tone_properties()
tone_Hz = tone_Hz1+tone_Hz2+tone_Hz3+tone_Hz4
sound_onset = sound_onset1 + sound_onset2 + sound_onset3 + sound_onset4
# Out:
# ['tone2', 'tone2', 'tone1']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone1', 'tone2', 'tone1']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone1', 'tone1', 'tone1']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone2', 'tone2', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone1']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone2', 'tone2', 'tone2']
# ['tone2', 'tone2', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone1']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone1']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone1', 'tone2', 'tone2']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone2', 'tone1', 'tone1']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone1']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6

# %%
# %pdb
prova = []
tone_counter = 0
for i in sorted(trials.keys()):
    if 'Critical' in trials[i]:
        trials[i].append(tone_Hz[tone_counter])
        trials[i].append(sound_onset[tone_counter])
        tone_counter = tone_counter + 1
    else:
        trials[i].append('No tone')
        trials[i].append(-999)
# Out:
# Automatic pdb calling has been turned ON

# %%
for i in sorted(trials.iteritems()):
    l = i[1]
    l.insert(11, l.pop(13))
    l.insert(12, l.pop(14))
    #l.insert(newindex, l.pop(oldindex))

# %%
with open('../config/randomization.pik', 'wb') as of:
    pickle.dump(trials,of)

# %%
df = pd.DataFrame.from_dict(trials)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','image_name','block']
df.TS = df.TS.astype('float')                                                                                #10
df.to_csv(mypath + '../Config/randomization_1.csv')

# %%
df[df['trial_type']=='Critical']
# Out:
#              Cat.1         Cat.2         Cat.3         Cat.4       Cat.5  \
# 12             dog           NaN           NaN           NaN         NaN
# 36            bird           NaN           NaN           NaN         NaN
# 45          person         horse           NaN           NaN         NaN
# 77          person         horse           NaN           NaN         NaN
# 101           bird          boat           NaN           NaN         NaN
# 111    pottedplant          sofa         chair   diningtable         NaN
# 132         person           cat           NaN           NaN         NaN
# 156           bird           NaN           NaN           NaN         NaN
# 165          chair           dog   diningtable           NaN         NaN
# 197         bottle           NaN           NaN           NaN         NaN
# 221      aeroplane           NaN           NaN           NaN         NaN
# 231          horse           NaN           NaN           NaN         NaN
# 247      tvmonitor         chair          sofa           NaN         NaN
# 255    pottedplant       bicycle        bottle           cat         NaN
# 272    pottedplant        person         chair           dog      bottle
# 309            car           NaN           NaN           NaN         NaN
# 322           boat           NaN           NaN           NaN         NaN
# 335            dog           cat           NaN           NaN         NaN
# 367           sofa         chair           NaN           NaN         NaN
# 375    pottedplant          sofa         chair           NaN         NaN
# 392    pottedplant           NaN           NaN           NaN         NaN
# 429            car           NaN           NaN           NaN         NaN
# 442      aeroplane           NaN           NaN           NaN         NaN
# 455           sofa         chair        person           NaN         NaN
# 482            cat           NaN           NaN           NaN         NaN
# 493          chair   diningtable           NaN           NaN         NaN
# 503            car           NaN           NaN           NaN         NaN
# 550         person   diningtable        bottle           NaN         NaN
# 575           bird          boat           NaN           NaN         NaN
# 583           boat           NaN           NaN           NaN         NaN
# 602         person     aeroplane           NaN           NaN         NaN
# 613         person         horse           NaN           NaN         NaN
# 623           bird           NaN           NaN           NaN         NaN
# 670           bird           NaN           NaN           NaN         NaN
# 695    pottedplant           NaN           NaN           NaN         NaN
# 703         bottle           cat           NaN           NaN         NaN
# 758    pottedplant        person     motorbike           NaN         NaN
# 762    pottedplant        person       bicycle           car         NaN
# 767         person           dog           NaN           NaN         NaN
# 806           sofa           dog           NaN           NaN         NaN
# 816         person          sofa           NaN           NaN         NaN
# 832          horse           NaN           NaN           NaN         NaN
# 878      aeroplane           NaN           NaN           NaN         NaN
# 882         person           NaN           NaN           NaN         NaN
# 887         person          boat           NaN           NaN         NaN
# 926    pottedplant         chair   diningtable           NaN         NaN
# 936            car       bicycle     motorbike           bus      person
# 952           sofa           NaN           NaN           NaN         NaN
# 967           boat           NaN           NaN           NaN         NaN
# 990          chair           NaN           NaN           NaN         NaN
# 1014         chair   diningtable        bottle           NaN         NaN
# 1028           car     aeroplane           NaN           NaN         NaN
# 1032        person         horse           NaN           NaN         NaN
# 1037        person           dog           car           NaN         NaN
# 1087        person          boat           car           NaN         NaN
# 1110           car           bus        person           NaN         NaN
# 1134        person        bottle           NaN           NaN         NaN
# 1148          bird           NaN           NaN           NaN         NaN
# 1152           car           NaN           NaN           NaN         NaN
# 1157   pottedplant          sofa           NaN           NaN         NaN
# 1206          bird           NaN           NaN           NaN         NaN
# 1212   pottedplant          sofa         chair   diningtable   tvmonitor
# 1228   pottedplant         chair           NaN           NaN         NaN
# 1287     aeroplane           NaN           NaN           NaN         NaN
# 1292          boat           NaN           NaN           NaN         NaN
# 1307        person         horse           NaN           NaN         NaN
# 1326          sofa           dog           NaN           NaN         NaN
# 1332           cat           NaN           NaN           NaN         NaN
# 1348        person          boat           NaN           NaN         NaN
# 1407     tvmonitor         chair          sofa           NaN         NaN
# 1412        person           dog           NaN           NaN         NaN
# 1427           cat           NaN           NaN           NaN         NaN
# 1446        person          sofa           NaN           NaN         NaN
# 1451          bird           NaN           NaN           NaN         NaN
# 1483     aeroplane           NaN           NaN           NaN         NaN
# 1506          boat           NaN           NaN           NaN         NaN
# 1536        person        bottle           car           NaN         NaN
# 1551        person         horse           NaN           NaN         NaN
# 1566        person         chair   diningtable        bottle         NaN
# 1571   pottedplant          sofa         chair   diningtable   tvmonitor
# 1603        person   diningtable        bottle           NaN         NaN
# 1626           cat           NaN           NaN           NaN         NaN
# 1656        person         horse           car           NaN         NaN
# 1671        person          boat           NaN           NaN         NaN
# 1693   pottedplant          sofa         chair   diningtable         NaN
# 1708           car         train           NaN           NaN         NaN
# 1714        person     aeroplane           NaN           NaN         NaN
# 1745        person          boat           NaN           NaN         NaN
# 1755   pottedplant           NaN           NaN           NaN         NaN
# 1782        person        bottle           NaN           NaN         NaN
# 1813           car           NaN           NaN           NaN         NaN
# 1828         chair   diningtable           NaN           NaN         NaN
# 1834          sofa           dog           NaN           NaN         NaN
# 1865           cat           NaN           NaN           NaN         NaN
# 1875        person           dog           NaN           NaN         NaN
# 1902          bird           NaN           NaN           NaN         NaN
#
#              TS  Load      exemplar      question  present_absent trial_type  \
# 12    20.074686   low           dog            NA       No Target   Critical
# 36    18.523024   low          bird          bird  Target Present   Critical
# 45    20.529451   low        person            NA       No Target   Critical
# 77    31.969634  high         horse            NA       No Target   Critical
# 101   29.314234  high          bird           car   Target Absent   Critical
# 111   29.806820  high          sofa          sofa  Target Present   Critical
# 132   32.265109  high           cat            NA       No Target   Critical
# 156   31.182430  high          bird          bird  Target Present   Critical
# 165   29.611440  high           dog            NA       No Target   Critical
# 197   20.965775   low        bottle            NA       No Target   Critical
# 221   19.095996   low     aeroplane           cat   Target Absent   Critical
# 231   18.720729   low         horse         horse  Target Present   Critical
# 247   37.223816  high          sofa            NA       No Target   Critical
# 255   35.353784  high           cat            NA       No Target   Critical
# 272   31.058050  high           dog            NA       No Target   Critical
# 309   18.874156   low           car            NA       No Target   Critical
# 322   16.862966   low          boat            NA       No Target   Critical
# 335   21.247629   low           dog            NA       No Target   Critical
# 367   19.836492   low          sofa            NA       No Target   Critical
# 375   18.511888   low   pottedplant            NA       No Target   Critical
# 392   19.321309   low   pottedplant            NA       No Target   Critical
# 429   30.394048  high           car            NA       No Target   Critical
# 442   35.972960  high     aeroplane            NA       No Target   Critical
# 455   36.443792  high          sofa            NA       No Target   Critical
# 482   12.729033   low           cat            NA       No Target   Critical
# 493   18.117803   low         chair            NA       No Target   Critical
# 503   18.597982   low           car         horse   Target Absent   Critical
# 550   38.972642  high        bottle            NA       No Target   Critical
# 575   29.314234  high          bird            NA       No Target   Critical
# 583   30.806089  high          boat            NA       No Target   Critical
# 602   28.995417  high     aeroplane            NA       No Target   Critical
# 613   30.530490  high         horse            NA       No Target   Critical
# 623   31.182430  high          bird           cat   Target Absent   Critical
# 670   18.837864   low          bird            NA       No Target   Critical
# 695   16.520476   low   pottedplant            NA       No Target   Critical
# 703   21.259830   low        bottle            NA       No Target   Critical
# 758   34.416005  high   pottedplant            NA       No Target   Critical
# 762   33.367153  high   pottedplant            NA       No Target   Critical
# 767   32.959390  high           dog           dog  Target Present   Critical
# 806   16.698499   low          sofa            NA       No Target   Critical
# 816   19.244036   low          sofa            NA       No Target   Critical
# 832   18.720729   low         horse            NA       No Target   Critical
# 878   14.106445   low     aeroplane            NA       No Target   Critical
# 882   20.189150   low        person            NA       No Target   Critical
# 887   16.651242   low          boat          boat  Target Present   Critical
# 926   34.177834  high   pottedplant            NA       No Target   Critical
# 936   30.263449  high           car            NA       No Target   Critical
# 952   30.980311  high          sofa            NA       No Target   Critical
# 967   19.685752   low          boat            NA       No Target   Critical
# 990   16.985442   low         chair            NA       No Target   Critical
# 1014  20.038120   low        bottle            NA       No Target   Critical
# 1028  35.872179  high     aeroplane            NA       No Target   Critical
# 1032  33.334972  high         horse            NA       No Target   Critical
# 1037  33.094885  high           dog            NA       No Target   Critical
# 1087  35.704709  high          boat            NA       No Target   Critical
# 1110  31.305136  high           car            NA       No Target   Critical
# 1134  30.958055  high        bottle            NA       No Target   Critical
# 1148  20.757885   low          bird            NA       No Target   Critical
# 1152  20.487167   low           car            NA       No Target   Critical
# 1157  18.967723   low   pottedplant            NA       No Target   Critical
# 1206  29.272655  high          bird            NA       No Target   Critical
# 1212  29.247483  high   pottedplant            NA       No Target   Critical
# 1228  32.054270  high   pottedplant            NA       No Target   Critical
# 1287  20.120761   low     aeroplane            NA       No Target   Critical
# 1292  20.470664   low          boat          sofa   Target Absent   Critical
# 1307  20.306835   low         horse            NA       No Target   Critical
# 1326  16.698499   low          sofa            NA       No Target   Critical
# 1332  21.194102   low           cat            NA       No Target   Critical
# 1348  19.901617   low          boat            NA       No Target   Critical
# 1407  37.223816  high          sofa            NA       No Target   Critical
# 1412  29.354458  high           dog         horse   Target Absent   Critical
# 1427  31.779859  high           cat            NA       No Target   Critical
# 1446  13.414126   low          sofa           dog   Target Absent   Critical
# 1451   9.576868   low          bird     aeroplane   Target Absent   Critical
# 1483  20.559862   low     aeroplane            NA       No Target   Critical
# 1506  30.065266  high          boat            NA       No Target   Critical
# 1536  34.313161  high           car            NA       No Target   Critical
# 1551  35.669132  high         horse            NA       No Target   Critical
# 1566  30.060592  high        bottle   pottedplant   Target Absent   Critical
# 1571  29.247483  high   pottedplant          bird   Target Absent   Critical
# 1603  36.414042  high        bottle            NA       No Target   Critical
# 1626  16.417039   low           cat            NA       No Target   Critical
# 1656  20.934600   low         horse            NA       No Target   Critical
# 1671  18.642450   low        person            NA       No Target   Critical
# 1693  28.968465  high          sofa          sofa  Target Present   Critical
# 1708  30.208843  high           car            NA       No Target   Critical
# 1714  28.995417  high     aeroplane            NA       No Target   Critical
# 1745  16.146155   low          boat            NA       No Target   Critical
# 1755  19.252735   low   pottedplant            NA       No Target   Critical
# 1782  17.242843   low        bottle            NA       No Target   Critical
# 1813  21.181011   low           car           car  Target Present   Critical
# 1828  15.830709   low         chair            NA       No Target   Critical
# 1834  16.142563   low           dog            NA       No Target   Critical
# 1865  31.193571  high           cat            NA       No Target   Critical
# 1875  30.202036  high           dog            NA       No Target   Critical
# 1902  30.515353  high          bird            NA       No Target   Critical
#
#      tone_Hz tone_onset       image_name block
# 12     tone2      0.785  2010_005885.jpg     1
# 36     tone2      0.369  2008_001185.jpg     1
# 45     tone1      0.728  2009_003530.jpg     1
# 77     tone1       0.55  2010_003297.jpg     2
# 101    tone1        0.4  2008_006481.jpg     2
# 111    tone2      0.596  2011_000530.jpg     2
# 132    tone2      0.785  2008_007913.jpg     3
# 156    tone2      0.369  2008_006461.jpg     3
# 165    tone1      0.728  2008_007378.jpg     3
# 197    tone1       0.55  2010_003329.jpg     4
# 221    tone1        0.4  2009_003309.jpg     4
# 231    tone2      0.596  2009_003686.jpg     4
# 247    tone2      0.475  2011_001304.jpg     5
# 255    tone1      0.518  2008_000196.jpg     5
# 272    tone2       0.04  2008_001862.jpg     5
# 309    tone1      0.503  2009_001782.jpg     6
# 322    tone2      0.153  2010_001691.jpg     6
# 335    tone1      0.619  2008_001708.jpg     6
# 367    tone2      0.475  2009_002325.jpg     7
# 375    tone1      0.518  2008_001694.jpg     7
# 392    tone2       0.04  2008_008331.jpg     7
# 429    tone1      0.503  2008_002672.jpg     8
# 442    tone2      0.153  2009_004414.jpg     8
# 455    tone1      0.619  2011_002971.jpg     8
# 482    tone1       0.71  2009_004225.jpg     9
# 493    tone1      0.059  2011_002241.jpg     9
# 503    tone1      0.082  2010_004014.jpg     9
# 550    tone2      0.811  2010_001645.jpg    10
# 575    tone2      0.674  2008_006481.jpg    10
# 583    tone2      0.645  2009_000120.jpg    10
# 602    tone1       0.71  2009_001345.jpg    11
# 613    tone1      0.059  2009_000565.jpg    11
# 623    tone1      0.082  2008_006461.jpg    11
