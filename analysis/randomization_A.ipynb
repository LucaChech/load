# %%
import pandas as pd
import numpy as np
import random
import csv
#%pdb
#mypath = ('E:/OneDrive - University College London/Random_probes_last/Luca/')
mypath = 'C:/Users/nilli lab/Desktop/load/analysis/'

# %%
import random
probe_series = []
critical_series = []

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
print len(target_present)

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
print len(target_present)
for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
probe_trials_1 = target_present_counter + target_absent_counter
critical_trials_1 = critical_trials
print len(probe_trials_1)
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# 24
# 36
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  12
# len(critical_trials):  24
# 72

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 390
# -------------------

# %%
def block_low_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
    
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_low_2():
# Pick 5 present probes and 4 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_2():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
block_low_1()
print critical_used
block_high_1()
print critical_used
block_high_2()
print critical_used
block_low_2()
print critical_used
block_high_1()
print critical_used
block_low_1()
print critical_used
block_low_2()
print critical_used
block_high_2()
print critical_used
# Out:
# [' boat', nan, nan, nan, nan, 16.846336579249186, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' sofa', nan, nan, nan, nan, 16.90085669678468, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.120761243201123, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 16.520476370843983, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 12.433989779329734, 'low', ' bird', ' car', 'Target Absent', 'Normal']
# [' chair', ' diningtable', nan, nan, nan, 15.830708942989276, 'low', ' chair', ' person', 'Target Absent', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 17.350665469404078, 'low', ' aeroplane', ' pottedplant', 'Target Absent', 'Normal']
# [' sofa', ' dog', nan, nan, nan, 16.142562620916582, 'low', ' dog', ' boat', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 15.903696109038165, 'low', ' person', ' horse', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  1
# List of critical trials without probe:
# [' chair', nan, nan, nan, nan, 11.459232377151848, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' sofa', nan, nan, nan, nan, 20.95630728619632, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  49
# Normal used: 49
# ---------------------------------------------------
# ['2009_004129.jpg', '2009_002998.jpg']
# [' dog', nan, nan, nan, nan, 31.72817006314488, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' bicycle', ' boat', nan, nan, 34.31905160776113, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' pottedplant', ' dog', nan, nan, nan, 28.66363347517436, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' person', ' chair', ' cat', nan, nan, 30.87884814240284, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' person', ' bottle', ' sofa', nan, nan, 33.561185784733894, 'high', ' bottle', ' dog', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 32.014973550332165, 'high', ' aeroplane', ' horse', 'Target Absent', 'Normal']
# [' car', ' bicycle', ' motorbike', ' bus', ' person', 30.26344946567593, 'high', ' car', ' person', 'Target Absent', 'Normal']
# [' person', ' chair', ' bottle', nan, nan, 33.38111538349955, 'high', ' chair', ' car', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 34.54414482156191, 'high', ' aeroplane', ' boat', 'Target Absent', 'Normal']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 29.246976174425782, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' car', nan, nan, nan, 28.839741748612518, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 30.073041628958684, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  97
# Normal used: 97
# ---------------------------------------------------
# ['2009_004129.jpg', '2009_002998.jpg', '2008_001210.jpg', '2008_005472.jpg', '2008_007970.jpg']
# [' person', ' bottle', ' diningtable', nan, nan, 29.775484131000805, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 29.027958359084288, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' bird', ' boat', nan, nan, 31.913409738647122, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 31.487640373164247, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 30.95304328989037, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' boat', ' cow', nan, nan, nan, 29.65940712433473, 'high', ' boat', ' chair', 'Target Absent', 'Critical']
# [' person', ' chair', nan, nan, nan, 29.77990661443428, 'high', ' chair', ' sofa', 'Target Absent', 'Normal']
# [' chair', ' diningtable', nan, nan, nan, 28.72863626121521, 'high', ' chair', ' horse', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 30.74888565488975, 'high', ' person', ' boat', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  1
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 29.176311484999022, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 31.31059992348976, 'high', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  146
# Normal used: 146
# ---------------------------------------------------
# ['2009_004129.jpg', '2009_002998.jpg', '2008_001210.jpg', '2008_005472.jpg', '2008_007970.jpg', '2008_000192.jpg', '2011_000628.jpg']
# [' cat', nan, nan, nan, nan, 10.236635760901883, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 19.646066025131248, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' bicycle', ' bottle', nan, nan, nan, 18.893798014446215, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' pottedplant', ' sofa', ' chair', nan, nan, 18.511887801846186, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Critical']
# [' person', ' car', nan, nan, nan, 18.390878339274188, 'low', ' car', ' car', 'Target Present', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 17.770158360863313, 'low', ' pottedplant', ' car', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.559862456799, 'low', ' aeroplane', ' dog', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 20.53735353764835, 'low', ' cat', ' aeroplane', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 19.675826944132364, 'low', ' person', ' horse', 'Target Absent', 'Normal']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  2
# List of critical trials without probe:
# [' person', ' boat', nan, nan, nan, 18.642450428633328, 'low', ' person', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  196
# Normal used: 196
# ---------------------------------------------------
# ['2009_004129.jpg', '2009_002998.jpg', '2008_001210.jpg', '2008_005472.jpg', '2008_007970.jpg', '2008_000192.jpg', '2011_000628.jpg', '2008_008083.jpg']
# [' car', ' train', nan, nan, nan, 30.20884285223731, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' car', ' cat', nan, nan, nan, 33.46218479046818, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' person', ' sofa', nan, nan, nan, 31.124437166631626, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' sofa', ' chair', nan, nan, nan, 32.351474210019695, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' pottedplant', ' sofa', ' chair', ' tvmonitor', nan, 29.464580095555625, 'high', ' pottedplant', ' bottle', 'Target Absent', 'Critical']
# [' pottedplant', ' car', nan, nan, nan, 30.612693177580176, 'high', ' car', ' aeroplane', 'Target Absent', 'Normal']
# [' person', ' cat', nan, nan, nan, 29.77854418273715, 'high', ' cat', ' bird', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 35.94715000296663, 'high', ' boat', ' pottedplant', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 32.020689907436754, 'high', ' aeroplane', ' sofa', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  1
# List of critical trials without probe:
# [' sofa', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 33.937775623898794, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' car', ' dog', ' person', nan, nan, 29.763552134631723, 'high', ' person', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  245
# Normal used: 245
# ---------------------------------------------------
# ['2009_004129.jpg', '2009_002998.jpg', '2008_001210.jpg', '2008_005472.jpg', '2008_007970.jpg', '2008_000192.jpg', '2011_000628.jpg', '2008_008083.jpg', '2011_002814.jpg', '2008_003755.jpg']
# [' bird', nan, nan, nan, nan, 18.01566888749068, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 13.350033322032775, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 18.13905315137702, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 16.396955524186414, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 19.107696549923208, 'low', ' cat', ' bottle', 'Target Absent', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 19.906276626032106, 'low', ' pottedplant', ' person', 'Target Absent', 'Normal']
# [' dog', ' bottle', nan, nan, nan, 18.86070334209068, 'low', ' bottle', ' chair', 'Target Absent', 'Normal']
# [' chair', ' diningtable', nan, nan, nan, 20.017308322976007, 'low', ' chair', ' cat', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 19.30503047810884, 'low', ' bird', ' sofa', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  0
# List of critical trials without probe:
# [' person', ' bottle', nan, nan, nan, 17.242843490790587, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' chair', ' dog', ' diningtable', nan, nan, 18.206263900870965, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' dog', ' cat', nan, nan, nan, 21.247629460380587, 'low', ' dog', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  293
# Normal used: 293
# ---------------------------------------------------
# ['2009_004129.jpg', '2009_002998.jpg', '2008_001210.jpg', '2008_005472.jpg', '2008_007970.jpg', '2008_000192.jpg', '2011_000628.jpg', '2008_008083.jpg', '2011_002814.jpg', '2008_003755.jpg', '2008_005869.jpg', '2008_006837.jpg', '2008_001708.jpg']
# [' dog', nan, nan, nan, nan, 18.608803704733788, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 20.463883689453848, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 13.727438736718454, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 17.497069987457937, 'low', ' bird', ' bird', 'Target Present', 'Critical']
# [' bottle', nan, nan, nan, nan, 20.96364307633711, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 18.135096838925413, 'low', ' cat', ' bird', 'Target Absent', 'Normal']
# [' horse', nan, nan, nan, nan, 18.057825283941515, 'low', ' horse', ' sofa', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 14.341894736874325, 'low', ' aeroplane', ' boat', 'Target Absent', 'Normal']
# [' person', ' boat', nan, nan, nan, 17.997748470093857, 'low', ' boat', ' dog', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  1
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 19.78900607095989, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 12.53657278412077, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  342
# Normal used: 342
# ---------------------------------------------------
# ['2009_004129.jpg', '2009_002998.jpg', '2008_001210.jpg', '2008_005472.jpg', '2008_007970.jpg', '2008_000192.jpg', '2011_000628.jpg', '2008_008083.jpg', '2011_002814.jpg', '2008_003755.jpg', '2008_005869.jpg', '2008_006837.jpg', '2008_001708.jpg', '2009_002697.jpg', '2010_006023.jpg']
# [' person', ' aeroplane', nan, nan, nan, 30.48036175658957, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' person', ' bottle', nan, nan, nan, 30.958055456079503, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 29.63929631121964, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' bird', ' cow', nan, nan, nan, 30.96122100405093, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 28.936239221739456, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' car', ' aeroplane', nan, nan, nan, 35.87217940794205, 'high', ' aeroplane', ' dog', 'Target Absent', 'Normal']
# [' pottedplant', ' chair', nan, nan, nan, 32.054269676274835, 'high', ' pottedplant', ' person', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 30.141763061562205, 'high', ' horse', ' car', 'Target Absent', 'Normal']
# [' sofa', ' chair', ' person', nan, nan, 36.443791926636216, 'high', ' sofa', ' cat', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  0
# List of critical trials without probe:
# [' pottedplant', ' person', ' chair', ' diningtable', ' boat', 35.38363353726925, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 34.55757716862823, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' train', nan, nan, 29.10600637597598, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  390
# Normal used: 390
# ---------------------------------------------------
# ['2009_004129.jpg', '2009_002998.jpg', '2008_001210.jpg', '2008_005472.jpg', '2008_007970.jpg', '2008_000192.jpg', '2011_000628.jpg', '2008_008083.jpg', '2011_002814.jpg', '2008_003755.jpg', '2008_005869.jpg', '2008_006837.jpg', '2008_001708.jpg', '2009_002697.jpg', '2010_006023.jpg', '2011_001221.jpg', '2010_002183.jpg', '2010_005996.jpg']

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
print probes[0]
# Out:
# ['2010_005780.jpg', '2011_000070.jpg', '2010_004791.jpg', '2008_005345.jpg', '2008_000123.jpg', '2010_004231.jpg', '2008_008263.jpg', '2009_001774.jpg', '2008_001098.jpg']

# %%
probe_series = []
critical_series = []

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
def building_the_church(w):
    while True:    
        while True:
            a = [random.randint(1,60) for r in xrange(9)]
            if sum(a) <= 60:
                break
        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]
        print 'new_list_1: ',new_list_1
        #print sum(a)

        while True:
            while True:
                a = [random.randint(1,60) for r in xrange(3-w)]
                if sum(a) <= 60: 
                    break
            print sum(a)
            new_list_2 = []
            acc = 0
            for i in a:
                acc = acc + i
                new_list_2.append(acc)
            print new_list_2
            two_gap = []
            for i in range(2-w): # add "-w"
                two_gap.append(new_list_2[i+1] - new_list_2[i])
                print two_gap
            if 1 not in two_gap and 2 not in two_gap:
                break
        print new_list_2

        container = []
        for i in new_list_2:
            sequence = [i, i+1, i+2]
            #print sequence
            for element in sequence:
                if element in new_list_1:
                    container.append(element)
        #print len(container)
        print new_list_2
        if len(container) == 0:
            break
    print '---------------------------'
    probe_series.append(new_list_1)
    critical_series.append(new_list_2)
    print new_list_1
    print new_list_2
    return

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [15, 17, 24, 29, 42, 49, 52, 53, 57]
# 45
# [4, 45]
# [41]
# [4, 45]
# [4, 45]
# ---------------------------
# [15, 17, 24, 29, 42, 49, 52, 53, 57]
# [4, 45]
# new_list_1:  [0, 10, 11, 15, 17, 18, 19, 32, 38]
# 55
# [10, 46, 55]
# [36]
# [36, 9]
# [10, 46, 55]
# [10, 46, 55]
# new_list_1:  [1, 8, 13, 14, 18, 30, 32, 39, 45]
# 51
# [6, 13, 51]
# [7]
# [7, 38]
# [6, 13, 51]
# [6, 13, 51]
# new_list_1:  [3, 19, 26, 33, 46, 48, 53, 57, 58]
# 58
# [19, 30, 58]
# [11]
# [11, 28]
# [19, 30, 58]
# [19, 30, 58]
# new_list_1:  [0, 11, 16, 19, 24, 25, 33, 52, 55]
# 60
# [2, 52, 60]
# [50]
# [50, 8]
# [2, 52, 60]
# [2, 52, 60]
# new_list_1:  [4, 5, 7, 20, 29, 30, 43, 45, 47]
# 60
# [37, 46, 60]
# [9]
# [9, 14]
# [37, 46, 60]
# [37, 46, 60]
# new_list_1:  [2, 15, 17, 19, 21, 23, 36, 42, 47]
# 42
# [2, 17, 42]
# [15]
# [15, 25]
# [2, 17, 42]
# [2, 17, 42]
# new_list_1:  [2, 5, 9, 15, 19, 23, 46, 50, 52]
# 53
# [35, 44, 53]
# [9]
# [9, 9]
# [35, 44, 53]
# [35, 44, 53]
# new_list_1:  [1, 3, 5, 11, 13, 14, 18, 34, 57]
# 48
# [5, 10, 48]
# [5]
# [5, 38]
# [5, 10, 48]
# [5, 10, 48]
# new_list_1:  [3, 9, 12, 18, 20, 33, 34, 36, 39]
# 45
# [20, 22, 45]
# [2]
# [2, 23]
# 45
# [20, 34, 45]
# [14]
# [14, 11]
# [20, 34, 45]
# [20, 34, 45]
# new_list_1:  [6, 30, 35, 39, 42, 48, 50, 51, 59]
# 56
# [6, 14, 56]
# [8]
# [8, 42]
# [6, 14, 56]
# [6, 14, 56]
# new_list_1:  [2, 18, 22, 28, 30, 34, 35, 41, 56]
# 53
# [35, 51, 53]
# [16]
# [16, 2]
# 50
# [13, 47, 50]
# [34]
# [34, 3]
# [13, 47, 50]
# [13, 47, 50]
# ---------------------------
# [2, 18, 22, 28, 30, 34, 35, 41, 56]
# [13, 47, 50]
# new_list_1:  [9, 17, 19, 28, 33, 36, 44, 53, 55]
# 53
# [17, 53]
# [36]
# [17, 53]
# [17, 53]
# new_list_1:  [9, 12, 16, 27, 29, 41, 49, 53, 54]
# 38
# [2, 38]
# [36]
# [2, 38]
# [2, 38]
# ---------------------------
# [9, 12, 16, 27, 29, 41, 49, 53, 54]
# [2, 38]
# new_list_1:  [10, 14, 24, 27, 30, 38, 43, 47, 55]
# 15
# [15]
# [15]
# [15]
# ---------------------------
# [10, 14, 24, 27, 30, 38, 43, 47, 55]
# [15]
# new_list_1:  [14, 22, 24, 36, 39, 41, 45, 53, 55]
# 10
# [4, 10]
# [6]
# [4, 10]
# [4, 10]
# ---------------------------
# [14, 22, 24, 36, 39, 41, 45, 53, 55]
# [4, 10]
# new_list_1:  [6, 10, 16, 18, 22, 23, 35, 50, 59]
# 45
# [16, 21, 45]
# [5]
# [5, 24]
# [16, 21, 45]
# [16, 21, 45]
# new_list_1:  [7, 22, 27, 36, 43, 47, 49, 55, 56]
# 47
# [7, 12, 47]
# [5]
# [5, 35]
# [7, 12, 47]
# [7, 12, 47]
# new_list_1:  [8, 10, 14, 31, 34, 36, 41, 47, 54]
# 46
# [18, 19, 46]
# [1]
# [1, 27]
# 42
# [19, 31, 42]
# [12]
# [12, 11]
# [19, 31, 42]
# [19, 31, 42]
# new_list_1:  [5, 22, 30, 38, 39, 45, 46, 52, 56]
# 33
# [26, 27, 33]
# [1]
# [1, 6]
# 51
# [22, 48, 51]
# [26]
# [26, 3]
# [22, 48, 51]
# [22, 48, 51]
# new_list_1:  [3, 11, 23, 36, 38, 44, 46, 48, 58]
# 55
# [7, 34, 55]
# [27]
# [27, 21]
# [7, 34, 55]
# [7, 34, 55]
# new_list_1:  [0, 17, 18, 23, 27, 30, 35, 40, 49]
# 36
# [7, 11, 36]
# [4]
# [4, 25]
# [7, 11, 36]
# [7, 11, 36]
# ---------------------------
# [0, 17, 18, 23, 27, 30, 35, 40, 49]
# [7, 11, 36]
# new_list_1:  [0, 5, 24, 26, 36, 38, 41, 42, 49]
# 45
# [19, 45]
# [26]
# [19, 45]
# [19, 45]
# ---------------------------
# [0, 5, 24, 26, 36, 38, 41, 42, 49]
# [19, 45]
# new_list_1:  [0, 15, 18, 24, 25, 41, 47, 56, 58]
# 36
# [7, 13, 36]
# [6]
# [6, 23]
# [7, 13, 36]
# [7, 13, 36]
# new_list_1:  [7, 11, 12, 16, 23, 28, 31, 38, 48]
# 53
# [1, 51, 53]
# [50]
# [50, 2]
# 41
# [20, 30, 41]
# [10]
# [10, 11]
# [20, 30, 41]
# [20, 30, 41]
# new_list_1:  [0, 11, 21, 23, 24, 26, 32, 34, 50]
# 47
# [6, 40, 47]
# [34]
# [34, 7]
# [6, 40, 47]
# [6, 40, 47]
# ---------------------------
# [0, 11, 21, 23, 24, 26, 32, 34, 50]
# [6, 40, 47]

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])
# Out:
# 0
# 0 1 60
# 1
# 1 2 60
# 2
# 2 3 60
# 3
# 3 4 60
# 4
# 4 5 60
# 5
# 5 6 60
# 6
# 6 7 60
# 7
# 7 8 60

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 390
# 390
# True
# 36
# 36
# True
# 36
# 36
# True
# 24
# 18
# 6

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)
# Out:
# ['tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone1', 'tone1', 'tone1']

# %%
df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df.TS = df.TS.astype('float')
df.to_csv(mypath + '../Config/randomization_1.csv')
block_1_half = block
probe_series_1_half = probe_series

# %%
##################
# SECOND ITERATION#
##################

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present \
                and trial not in probe_trials_1:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present \
                and trial not in probe_trials_1:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and intermediate not in critical_trials_1 \
                and intermediate not in probe_trials_1:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  12
# len(critical_trials):  24

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 390
# -------------------

# %%
block_low_1()
block_high_1()
block_high_2()
block_low_2()
block_high_1()
block_low_1()
block_low_2()
block_high_2()
# Out:
# [' person', ' cat', nan, nan, nan, 20.139877805151375, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' car', ' person', nan, nan, nan, 20.695714607410885, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 20.508881463934923, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 18.78745072135656, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 13.68599364669666, 'low', ' cat', ' bottle', 'Target Absent', 'Critical']
# [' cat', nan, nan, nan, nan, 16.656599770121232, 'low', ' cat', ' aeroplane', 'Target Absent', 'Normal']
# [' car', ' person', nan, nan, nan, 21.05297682386103, 'low', ' car', ' bird', 'Target Absent', 'Normal']
# [' person', ' chair', nan, nan, nan, 16.606806579152448, 'low', ' person', ' cat', 'Target Absent', 'Normal']
# [' bottle', nan, nan, nan, nan, 19.096237359535362, 'low', ' bottle', ' pottedplant', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  1
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 19.75925599841011, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' person', nan, nan, nan, nan, 21.051373291159546, 'low', ' person', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  49
# Normal used: 49
# ---------------------------------------------------
# [' person', ' aeroplane', nan, nan, nan, 30.073041628958684, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' person', ' car', nan, nan, nan, 28.839741748612518, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 30.51535276170641, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' pottedplant', ' sofa', nan, nan, nan, 29.04248886812048, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 29.26546246503357, 'high', ' horse', ' cat', 'Target Absent', 'Normal']
# [' car', ' chair', ' bicycle', nan, nan, 29.730810134821, 'high', ' car', ' person', 'Target Absent', 'Normal']
# [' person', ' chair', ' tvmonitor', nan, nan, 28.894989564027235, 'high', ' chair', ' aeroplane', 'Target Absent', 'Normal']
# [' person', ' cat', nan, nan, nan, 30.22651637937125, 'high', ' cat', ' horse', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 39.79411022613925, 'high', ' person', ' pottedplant', 'Target Absent', 'Normal']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 30.068803282805252, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' dog', nan, nan, nan, 29.851834352354174, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 33.33497246868347, 'high', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  97
# Normal used: 97
# ---------------------------------------------------
# [' tvmonitor', ' chair', nan, nan, nan, 34.77634371447314, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 30.088045927192198, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' person', ' dog', nan, nan, nan, 32.14242713491097, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' bus', ' person', ' car', nan, nan, 31.167936969796557, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 29.77784058169977, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 30.39404844580157, 'high', ' car', ' pottedplant', 'Target Absent', 'Critical']
# [' pottedplant', ' tvmonitor', ' chair', ' sofa', nan, 35.63660420168497, 'high', ' pottedplant', ' aeroplane', 'Target Absent', 'Normal']
# [' person', ' chair', nan, nan, nan, 34.70717080948356, 'high', ' chair', ' bottle', 'Target Absent', 'Normal']
# [' sofa', ' person', ' tvmonitor', nan, nan, 31.14925641648057, 'high', ' sofa', ' dog', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  1
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 31.142308501142768, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 30.30670761720366, 'high', ' cat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  146
# Normal used: 146
# ---------------------------------------------------
# [' person', ' boat', nan, nan, nan, 17.997748470093857, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 19.755286187157022, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 15.633666738732224, 'low', ' cat', ' cat', 'Target Present', 'Critical']
# [' dog', nan, nan, nan, nan, 19.570662256086155, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' bicycle', nan, nan, nan, 18.23776823647068, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 18.045035650575528, 'low', ' dog', ' chair', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 20.074715872568312, 'low', ' boat', ' chair', 'Target Absent', 'Normal']
# [' dog', ' cat', nan, nan, nan, 21.247629460380587, 'low', ' dog', ' cat', 'Target Absent', 'Normal']
# [' bottle', nan, nan, nan, nan, 16.598874860824477, 'low', ' bottle', ' sofa', 'Target Absent', 'Normal']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  1
# List of critical trials without probe:
# [' sofa', ' dog', nan, nan, nan, 20.934059682149233, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 17.13857605003491, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  195
# Normal used: 195
# ---------------------------------------------------
# [' person', ' boat', ' car', nan, nan, 35.70470893485066, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' bottle', nan, nan, nan, 30.958055456079503, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' sofa', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 33.937775623898794, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' person', ' cat', nan, nan, nan, 29.867994035114002, 'high', ' cat', ' bottle', 'Target Absent', 'Normal']
# [' person', ' chair', nan, nan, nan, 37.05291171015417, 'high', ' person', ' car', 'Target Absent', 'Normal']
# [' person', ' bottle', ' car', nan, nan, 34.31316104129318, 'high', ' car', ' chair', 'Target Absent', 'Critical']
# [' boat', nan, nan, nan, nan, 30.065266395495016, 'high', ' boat', ' bird', 'Target Absent', 'Normal']
# [' person', ' diningtable', ' bottle', nan, nan, 38.97264238893902, 'high', ' bottle', ' cat', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  1
# List of critical trials without probe:
# [' person', ' dog', nan, nan, nan, 29.354458493580452, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', ' bottle', nan, 33.73452911680277, 'high', ' chair', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  244
# Normal used: 244
# ---------------------------------------------------
# [' sofa', nan, nan, nan, nan, 19.892389695505386, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.088435845702712, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 19.803898838362514, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 19.25273490800736, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 19.993102773679155, 'low', ' dog', ' aeroplane', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 9.156390286160866, 'low', ' car', ' boat', 'Target Absent', 'Normal']
# [' person', ' dog', nan, nan, nan, 20.712898768714968, 'low', ' dog', ' horse', 'Target Absent', 'Critical']
# [' person', nan, nan, nan, nan, 20.358449022039405, 'low', ' person', ' bottle', 'Target Absent', 'Normal']
# [' horse', nan, nan, nan, nan, 20.9577483152902, 'low', ' horse', ' person', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  1
# List of critical trials without probe:
# [' sofa', ' dog', nan, nan, nan, 16.69849859536183, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 21.217669901647128, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  293
# Normal used: 293
# ---------------------------------------------------
# [' horse', nan, nan, nan, nan, 19.598131175056185, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' sofa', ' cat', nan, nan, nan, 18.288477341906038, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' chair', ' diningtable', ' bottle', nan, nan, 20.038119878562025, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 8.062836492776528, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 16.580374337830555, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 20.393526602090205, 'low', ' pottedplant', ' car', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 19.239146135217897, 'low', ' bird', ' pottedplant', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 21.23535981155764, 'low', ' person', ' bird', 'Target Absent', 'Normal']
# [' car', ' person', nan, nan, nan, 17.856305662122608, 'low', ' car', ' dog', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  0
# List of critical trials without probe:
# [' person', ' boat', nan, nan, nan, 17.69816713203682, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 13.440366765570474, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 9.57686770873812, 'low', ' bird', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  341
# Normal used: 341
# ---------------------------------------------------
# [' bus', ' boat', ' car', nan, nan, 34.403914620094966, 'high', ' boat', ' boat', 'Target Present', 'Critical']
# [' cat', nan, nan, nan, nan, 31.779858819461175, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' train', nan, nan, 29.323493073246585, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' sofa', ' person', nan, nan, nan, 31.463677231105994, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 32.97739588330027, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' chair', ' dog', ' bottle', 31.05804957013649, 'high', ' dog', ' sofa', 'Target Absent', 'Normal']
# [' person', ' dog', ' sofa', nan, nan, 29.935618386927253, 'high', ' dog', ' boat', 'Target Absent', 'Normal']
# [' pottedplant', ' person', nan, nan, nan, 36.595770973484505, 'high', ' pottedplant', ' bird', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' chair', ' sofa', ' cat', 29.72712959729897, 'high', ' cat', ' chair', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  1
# List of critical trials without probe:
# [' pottedplant', ' sofa', ' chair', nan, nan, 31.427287995992387, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' train', ' sofa', nan, nan, 31.65115644279944, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  390
# Normal used: 390
# ---------------------------------------------------

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
probe_series = []
critical_series = []

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [2, 7, 18, 22, 27, 32, 42, 52, 53]
# 48
# [5, 48]
# [43]
# [5, 48]
# [5, 48]
# new_list_1:  [8, 13, 16, 18, 34, 36, 39, 46, 53]
# 28
# [5, 28]
# [23]
# [5, 28]
# [5, 28]
# ---------------------------
# [8, 13, 16, 18, 34, 36, 39, 46, 53]
# [5, 28]
# new_list_1:  [11, 29, 30, 37, 40, 46, 49, 55, 58]
# 54
# [7, 32, 54]
# [25]
# [25, 22]
# [7, 32, 54]
# [7, 32, 54]
# new_list_1:  [4, 6, 7, 13, 26, 38, 52, 56, 57]
# 41
# [13, 22, 41]
# [9]
# [9, 19]
# [13, 22, 41]
# [13, 22, 41]
# new_list_1:  [7, 9, 10, 26, 27, 34, 38, 40, 42]
# 30
# [8, 13, 30]
# [5]
# [5, 17]
# [8, 13, 30]
# [8, 13, 30]
# new_list_1:  [0, 2, 4, 5, 15, 24, 38, 39, 45]
# 45
# [14, 29, 45]
# [15]
# [15, 16]
# [14, 29, 45]
# [14, 29, 45]
# new_list_1:  [24, 26, 42, 43, 44, 47, 50, 51, 58]
# 52
# [18, 49, 52]
# [31]
# [31, 3]
# [18, 49, 52]
# [18, 49, 52]
# new_list_1:  [9, 13, 20, 22, 36, 38, 39, 47, 49]
# 45
# [4, 21, 45]
# [17]
# [17, 24]
# [4, 21, 45]
# [4, 21, 45]
# new_list_1:  [0, 1, 4, 19, 22, 25, 34, 41, 59]
# 38
# [2, 22, 38]
# [20]
# [20, 16]
# [2, 22, 38]
# [2, 22, 38]
# new_list_1:  [13, 17, 31, 39, 41, 43, 50, 54, 56]
# 51
# [9, 30, 51]
# [21]
# [21, 21]
# [9, 30, 51]
# [9, 30, 51]
# new_list_1:  [10, 25, 30, 35, 48, 50, 55, 58, 59]
# 60
# [16, 28, 60]
# [12]
# [12, 32]
# [16, 28, 60]
# [16, 28, 60]
# new_list_1:  [6, 14, 17, 18, 21, 24, 41, 45, 58]
# 13
# [3, 9, 13]
# [6]
# [6, 4]
# [3, 9, 13]
# [3, 9, 13]
# new_list_1:  [2, 8, 20, 22, 24, 30, 37, 43, 53]
# 25
# [1, 21, 25]
# [20]
# [20, 4]
# [1, 21, 25]
# [1, 21, 25]
# new_list_1:  [2, 5, 6, 7, 14, 21, 26, 41, 48]
# 37
# [18, 22, 37]
# [4]
# [4, 15]
# [18, 22, 37]
# [18, 22, 37]
# ---------------------------
# [2, 5, 6, 7, 14, 21, 26, 41, 48]
# [18, 22, 37]
# new_list_1:  [4, 6, 14, 16, 19, 26, 35, 40, 56]
# 51
# [1, 51]
# [50]
# [1, 51]
# [1, 51]
# ---------------------------
# [4, 6, 14, 16, 19, 26, 35, 40, 56]
# [1, 51]
# new_list_1:  [7, 11, 23, 32, 34, 42, 47, 54, 57]
# 47
# [9, 47]
# [38]
# [9, 47]
# [9, 47]
# new_list_1:  [3, 18, 19, 20, 28, 37, 43, 46, 51]
# 30
# [17, 30]
# [13]
# [17, 30]
# [17, 30]
# new_list_1:  [4, 6, 18, 21, 24, 26, 37, 43, 50]
# 33
# [18, 33]
# [15]
# [18, 33]
# [18, 33]
# new_list_1:  [5, 12, 19, 25, 29, 41, 45, 52, 57]
# 52
# [7, 52]
# [45]
# [7, 52]
# [7, 52]
# new_list_1:  [4, 10, 17, 18, 27, 34, 43, 52, 58]
# 27
# [24, 27]
# [3]
# [24, 27]
# [24, 27]
# new_list_1:  [5, 13, 18, 21, 32, 35, 39, 51, 59]
# 48
# [31, 48]
# [17]
# [31, 48]
# [31, 48]
# new_list_1:  [1, 17, 20, 22, 37, 43, 49, 50, 51]
# 55
# [10, 55]
# [45]
# [10, 55]
# [10, 55]
# ---------------------------
# [1, 17, 20, 22, 37, 43, 49, 50, 51]
# [10, 55]
# new_list_1:  [8, 16, 30, 31, 34, 40, 45, 47, 57]
# 43
# [21, 43]
# [22]
# [21, 43]
# [21, 43]
# new_list_1:  [8, 15, 24, 28, 43, 49, 53, 54, 55]
# 56
# [39, 56]
# [17]
# [39, 56]
# [39, 56]
# ---------------------------
# [8, 15, 24, 28, 43, 49, 53, 54, 55]
# [39, 56]
# new_list_1:  [0, 3, 4, 12, 16, 23, 26, 33, 40]
# 51
# [47, 51]
# [4]
# [47, 51]
# [47, 51]
# ---------------------------
# [0, 3, 4, 12, 16, 23, 26, 33, 40]
# [47, 51]
# new_list_1:  [3, 7, 12, 21, 29, 31, 35, 49, 57]
# 57
# [10, 14, 57]
# [4]
# [4, 43]
# [10, 14, 57]
# [10, 14, 57]
# new_list_1:  [0, 5, 21, 41, 43, 47, 48, 51, 59]
# 50
# [30, 41, 50]
# [11]
# [11, 9]
# [30, 41, 50]
# [30, 41, 50]
# new_list_1:  [3, 13, 31, 32, 34, 42, 54, 58, 59]
# 28
# [11, 13, 28]
# [2]
# [2, 15]
# 47
# [24, 36, 47]
# [12]
# [12, 11]
# [24, 36, 47]
# [24, 36, 47]
# ---------------------------
# [3, 13, 31, 32, 34, 42, 54, 58, 59]
# [24, 36, 47]
# new_list_1:  [4, 13, 23, 30, 34, 40, 42, 55, 57]
# 11
# [4, 11]
# [7]
# [4, 11]
# [4, 11]
# new_list_1:  [8, 14, 15, 17, 27, 31, 34, 37, 47]
# 49
# [40, 49]
# [9]
# [40, 49]
# [40, 49]
# ---------------------------
# [8, 14, 15, 17, 27, 31, 34, 37, 47]
# [40, 49]

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])
# Out:
# 0
# 0 1 60
# 1
# 1 2 60
# 2
# 2 3 60
# 3
# 3 4 60
# 4
# 4 5 60
# 5
# 5 6 60
# 6
# 6 7 60
# 7
# 7 8 60

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 390
# 390
# True
# 36
# 36
# True
# 36
# 36
# True
# 24
# 18
# 6

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)
# Out:
# ['tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2']

# %%
df_2 = pd.DataFrame.from_dict(possible_images_dict)
df_2= df_2.T
df_2.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df_2.TS = df_2.TS.astype('float')
df_2.to_csv(mypath + '../Config/randomization_2.csv')
block_2_half = block
probe_series_2_half = probe_series

# %%
probe_series = probe_series_1_half + probe_series_2_half
block = block_1_half + block_2_half

# %%
with open('../Config/images.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(block[i])
        #wr.writerow(blocks_sequences_list[i])

with open('../Config/probes.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(probe_series[i])
