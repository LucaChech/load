# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pickle
from copy import deepcopy
#%pdb
mypath = ('')
trials = {}
categories = [' bottle', ' horse', ' pottedplant', ' dog',
                  ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]
p_load = ['low','high']

pd.set_option('display.max_rows', 9000)
pd.set_option('display.max_columns', 9000)

# %%
def present_absent_trials(input_1, input_2):
    global target_present, lista, categories, p_load, odd, even
    # DEFINING TARGET-PRESENT PROBES
    
    #target_present = []
    intermediate = []
    
#next two lines are to check that the images picked as target present and target absent trials
                    #are different from the ones chosen in previous iterations
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_1:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break
    #print len(target_present)
    for n in target_present:
        possible_images_dict[n].append('Target Present')

    #target_present = [n for n in lista if 'Target Present' in possible_images_dict[n]]


    # DEFINING TARGET-ABSENT PROBES
    #target_absent = []
    intermediate = []
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_2:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)

                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for each in target_absent:
        possible_images_dict[each].append('Target Absent')
        

    # DEFINING NO-TARGET IMAGES
    for image in lista:
        if image not in target_present and image not in target_absent:
            possible_images_dict[image].append('NA')
            possible_images_dict[image].append('No Target')
    
    return target_present, target_absent

# %%
# DEFINING CRITICAL TRIALS
#Criteria:
# - images of set load level
# - images containing a certain category
# - image is not already in the list of critical trials for this level of load
#- image is not aready in the list of critical trials (regardless of level of load)

def pre_select_critical_trial(load_level):
    global categories, critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and 'Critical' not in possible_images_dict[intermediate]: # this is just a sanity check
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)      
        temp =[]

# %%
def appending_critical_trials():
    global critical_low_present_probes, critical_low_absent_probes, critical_high_present_probes, critical_high_absent_probes
    global critical_trials
    cycles = 1
    while True:

        #picking critical trials
        pre_select_critical_trial('low')
        pre_select_critical_trial('high')      

        # counting critical probes
        crit_p = 0
        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1


        critical_low_counter = 0
        critical_high_counter = 0
        crit_p = 0

        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1
            if 'No Target' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_counter = critical_low_counter + 1
            if 'No Target' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_counter = critical_high_counter +1
            if 'Target Present' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_absent_probes.append(n)
            if 'Target Present' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_absent_probes.append(n)
        #print crit_p
        #print critical_low_counter
        #print critical_high_counter
        #print critical_low_present_probes
        #print critical_low_absent_probes
        #print critical_high_present_probes
        #print critical_high_absent_probes

        #######################################################
        if crit_p == 0 or len(critical_low_present_probes) == len(critical_high_present_probes) and len(critical_low_absent_probes) == \
        len(critical_high_absent_probes): #check if there is an even number of critical probes
            break
            print 'cycles : ',cycles
        else:
            cycles = cycles + 1
            critical_low_present_probes = []
            critical_low_absent_probes = []
            critical_high_present_probes = []
            critical_high_absent_probes = []
            #print len(critical_low_present_probes)
            #print len(critical_high_present_probes)
            #print len(critical_low_absent_probes)
            #print len(critical_high_absent_probes)
            #print '#######################'

            #why did I reset target_present and target_absent???

            #target_present = []
            #target_absent = []
            critical_trials = []

    # appendinf words 'critical' and 'normal' to dict
    for each in critical_trials:
        possible_images_dict[each].append('Critical')
    for each in possible_images_dict:
        if 'Critical' not in possible_images_dict[each]:
            possible_images_dict[each].append('Normal')

    #######################################################
    #print 'Probe trials: ', len(probe_trials_1)
    print 'Target Present Probes: ', len(target_present)
    print 'Target Absent probes: ', len(target_absent)
    print 'Critical trials:', len(critical_trials)
    print 'Critical, low: ' , critical_low_counter
    print 'Critical, high: ' , critical_high_counter
    print 'Are all critical trials unique? ', len(critical_trials) == len(set(critical_trials))
    #######################################################
    print 'Number of critical probes: ' , crit_p
    print 'critical_low_present_probes: ' , len(critical_low_present_probes)
    print 'critical_high_present_probes: ' , len(critical_high_present_probes)
    print 'critical_low_absent_probes: ' , len(critical_low_absent_probes)
    print 'critical_high_absent_probes: ', len(critical_high_absent_probes)
    print 'cycles : ',cycles
    
    return

# %%
def critical_probes_distribution(starting):
    global critical_low_present_probes, critical_low_absent_probes
    while True:
        p_left = len(starting)
        p_max = p_left
        distribution = []
        for i in range(4):
            if p_left > 0:
                x = random.randint(0,p_left)
                distribution.append(x)
                p_left = p_left - x
            else:
                distribution.append(0)
        if sum(distribution) == p_max:
            break
    random.shuffle(distribution)
    return distribution

# %%
def block_pair(present_n,absent_n):
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block
    global present_crit_distribution, absent_crit_distribution
    global present_critical_per_block, absent_critical_per_block, critical_probes_used, critical_probes_set
    global present_per_block, absent_per_block
    
    present_crit = present_crit_distribution.pop(0)
    absent_crit = absent_crit_distribution.pop(0)
    block = []
    
    for load in p_load:
        #PRINTING STUFF
        print 'present_crit_distribution_original: ',present_crit_distribution_original
        print 'absent_crit_distribution_original: ', absent_crit_distribution_original
        print 'present_crit', present_crit
        print 'absent_crit', absent_crit
        print 'present_crit_distribution: ', present_crit_distribution
        print 'absent_crit_distribution: ', absent_crit_distribution
        print 'critical present set: ', critical_present_set
        print 'critical absent set: ', critical_absent_set
        print'---------------------------------------------------'
        normal_availble = [n for n in normal if n not in normal_used]
        print 'normal available:', len(normal_availble)
    # PICKING CRITICAL PROBES    
    #------------------------------------------------------------------------------
        if present_crit != 0:
            present_critical_per_block = []
            while len(present_critical_per_block) < present_crit:
                crit_probe = str(np.random.choice(critical_present_set,1,replace = False))[2:-2]
                if crit_probe not in present_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Present' in possible_images_dict[crit_probe]:

                    present_critical_per_block.append(crit_probe)
            critical_present.append(present_critical_per_block)
                    
        print 'present_critical_per_block:', present_critical_per_block
        
        if absent_crit != 0:
            absent_critical_per_block = []
            while len(absent_critical_per_block) < absent_crit:
                crit_probe = str(np.random.choice(critical_absent_set,1,replace = False))[2:-2]
                if crit_probe not in absent_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Absent' in possible_images_dict[crit_probe]:

                    absent_critical_per_block.append(crit_probe)
            critical_absent.append(absent_critical_per_block)
            
        print 'absent_critical_per_block:', absent_critical_per_block  
        print 'critical_present: ',critical_present
        print 'critical_absent: ',critical_absent
        
        for n in present_critical_per_block + absent_critical_per_block:
            critical_probes_used.append(n)
            
        print 'critical_probes_used: ', critical_probes_used
    #------------------------------------------------------------------------------
    # PICKING PRESENT AND ABSENT PROBES
        total = present_n + absent_n
        while len(probes_per_block) < (present_n - present_crit):
            probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in present_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        while (present_n - present_crit) <= len(probes_per_block) < total - present_crit - absent_crit:
            probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in absent_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        for n in probes_per_block:
            if 'Target Present' in possible_images_dict[n]:
                present_used.append(n)
            elif 'Target Absent' in possible_images_dict[n]:
                absent_used.append(n)

        probes.append(probes_per_block)
        
        print 'probes: ', probes
        present_per_block = [n for n in probes_per_block if 'Target Present' in possible_images_dict[n]]
        absent_per_block = [n for n in probes_per_block if 'Target Absent' in possible_images_dict[n]]
        print 'Present Used in block: ',len(present_per_block)
        print 'Absent Used in block',len(absent_per_block)
    #------------------------------------------------------------------------------    
    #Counting critical probes    
        critical_probes_counter = len(present_critical_per_block + absent_critical_per_block)
        print 'Critical probes counter: ',critical_probes_counter
        print 'Present Critical: ', len(present_critical_per_block)
        print 'Absent Critical: ', len(absent_critical_per_block)

        modifier.append(critical_probes_counter)
    #------------------------------------------------------------------------------
    #Picking critical trials
        while len(critical_per_block) < (3-critical_probes_counter):
            image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
            if image not in critical_per_block and image not in critical_used \
                and 'No Target' in possible_images_dict[image] and load in possible_images_dict[image]:
                critical_per_block.append(image) 
        print 'List of critical trials without probe: '
        for n in critical_per_block:
            critical_used.append(n)
            print possible_images_dict[n]
        #temp = []

        critical.append(critical_per_block)

    #------------------------------------------------------------------------------
    #Picking normal trials
        while len(normal_per_block) < 51 - (3 - critical_probes_counter):
            image = str(np.random.choice(normal,1,replace = False))[2:-2]
            if image not in normal_per_block and image not in normal_used and load in possible_images_dict[image]:
                normal_per_block.append(image)
        for n in normal_per_block:
            normal_used.append(n)
        print 'normal in this block: ', len(normal_per_block)
        print 'normal used overall: ',len(normal_used)

        normal_builder.append(normal_per_block)
    #----------------------------------------------------------------------------
        
        print 'critical_probes_used', critical_probes_used 
        
        
        
        if 'sequence_final' in locals():
            print 'sequence_final exists'
        else:
            print 'sequence final does not exist'
            sequence_final = position_finder()
            print sequence_final
        print'---------------------------------------------------'
        print 'END OF BLOCK PROCESSING'
        print'---------------------------------------------------'
        print 'BUILDING THE BLOCK'
        first_element = [x[0] for x in sequence_final]
        second_element = [x[1] for x in sequence_final]
        second_element_counter = 0
        probes_position = []
        for image in range(60):
            #print [x[1] for x in sequence_final if x[0] ==image][0]
            if image in first_element:
                
                print 'image', image, second_element[second_element_counter]
        
                if second_element[second_element_counter] == 'Target Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break       
                elif second_element[second_element_counter] == 'Target Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical':
                    while True:
                        element = str(np.random.choice(critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break     
                elif second_element[second_element_counter] == 'Critical Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break  
            else:
                while True:
                    element = str(np.random.choice(normal_per_block,1,replace = False))[2:-2]
                    if element not in block:
                        block.append(element)
                        break
                
        print 'block:', len(block)   
        print'---------------------------------------------------'
        print 'probes_position: ', probes_position
    #-----------------------------------------------------------------------------
        normal_per_block = []
        probes_per_block = []
        critical_per_block = []
        present_critical_per_block = []
        absent_critical_per_block = []
    #-----------------------------------------------------------------------------
    return block

# %%
def position_finder():
    global present_critical_per_block, absent_critical_per_block, present_per_block, absent_per_block, critical_per_block
    x = len(present_critical_per_block + absent_critical_per_block)
    print 'x', x
    print 'present_critical_per_block', len(present_critical_per_block)
    print 'absent_critical_per_block', len(absent_critical_per_block)
    while True:    
        while True:
            a = [random.randint(1,10) for r in xrange(12-x)]
            if sum(a) <= 60:
                break

        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]

        if len(present_critical_per_block) == 0 and len(absent_critical_per_block) == 0:
            print 'ciao', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block) + ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        if len(present_critical_per_block) != 0 or len(absent_critical_per_block) != 0:
            print 'ciao2', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block)  +\
            ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block) +\
            ['Critical Present'] * len(present_critical_per_block) +\
            ['Critical Absent'] * len(absent_critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        sequence_final = zip(new_list_1, sequence)
        #print sequence_final
        #print len(sequence_final)
        gap_check = [n[0] for n in sequence_final if 'Critical' in n[1]] 
        #print gap_check
        container = []
        for i in gap_check:
            elements = [i+1, i+2]
            for element in elements:
                if element in new_list_1:
                    container.append(element)
        #print 'container', len(container),container
        if len(container) == 0:
            break
        else:
            sequence_final = []

    print '------------------'
    print new_list_1, len(new_list_1)
    print 'gap_check: ', gap_check
    print len(sequence_final)

    for i in sequence_final:
        print i
    return sequence_final

# %%
def block_unpacker(splitting_index,present,absent):
    block = block_pair(present,absent) #, probes_position
    low_block = []
    high_block = []
    for i in range(len(block)):
        if i < (len(block)/2):
            low_block.append(block[i])
        else:
            high_block.append(block[i])
    #print probes_position
    print len(low_block), len(high_block)
    return low_block, high_block #, probes_position

# %%
def tone_properties():
    while True:
        possible_tones = ['tone1','tone2']
        low_one_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_two_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_three_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_four_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        high_one_tones = []
        high_two_tones = []
        high_three_tones = []
        high_four_tones = []
        for each in low_one_tones:
            if each == 'tone1':
                high_one_tones.append('tone2')
            elif each == 'tone2':
                high_one_tones.append('tone1')
        for each in low_two_tones:
            if each == 'tone1':
                high_two_tones.append('tone2')
            elif each == 'tone2':
                high_two_tones.append('tone1')
        for each in low_three_tones:
            if each == 'tone1':
                high_three_tones.append('tone2')
            elif each == 'tone2':
                high_three_tones.append('tone1')
        for each in low_four_tones:
            if each == 'tone1':
                high_four_tones.append('tone2')
            elif each == 'tone2':
                high_four_tones.append('tone1')
        sound_Hz = low_one_tones + low_two_tones + low_three_tones + low_four_tones + high_one_tones + high_two_tones +\
        high_three_tones + high_four_tones

        tone1_counter = 0
        tone2_counter = 0
        for each in sound_Hz:
            if each == 'tone1':
                tone1_counter = tone1_counter + 1
            elif each == 'tone2':
                tone2_counter = tone2_counter + 1

        low_load_tones = [n for n in sound_Hz[0:12]]
        high_load_tones = [n for n in sound_Hz[12:25]]
        low_load_tone1s = [n for n in low_load_tones if n == 'tone1']
        low_load_tone2s = [n for n in low_load_tones if n == 'tone2']
        high_load_tone1s = [n for n in high_load_tones if n == 'tone1']
        high_load_tone2s = [n for n in high_load_tones if n =='tone2']

        if len(low_load_tone1s) == len(low_load_tone2s) and len(high_load_tone1s) == len(high_load_tone2s):
            print low_one_tones
            print high_one_tones
            print '----------------------'
            print low_two_tones
            print high_two_tones
            print '----------------------'
            print low_three_tones
            print high_three_tones
            print '----------------------'
            print low_four_tones
            print high_four_tones
            print '----------------------'
            print 'total n of tones: ', len(sound_Hz)
            print '----------------------'
            print 'total n of 1500 Hz tones: ', tone1_counter
            print 'total n of 2000 Hz tones: ', tone2_counter
            print '----------------------'
            print len(low_load_tone1s) == len(low_load_tone2s)
            print len(low_load_tone1s)
            print len(low_load_tone2s)
            print len(high_load_tone1s) == len(high_load_tone2s)
            print len(high_load_tone1s)
            print len(high_load_tone2s)
            break
        # Re-ordering tones according to the block order
    sound_Hz = low_one_tones + high_two_tones + high_one_tones + low_two_tones + high_three_tones + low_four_tones +\
        low_three_tones + high_four_tones 
    sound_onset1 = np.random.uniform(0,0.949,3).tolist()
    sound_onset2 = np.random.uniform(0,0.949,3).tolist()
    sound_onset3 = np.random.uniform(0,0.949,3).tolist()
    sound_onset4 = np.random.uniform(0,0.949,3).tolist()
    sound_onset = sound_onset1 + sound_onset2 + sound_onset1 + sound_onset2 + sound_onset3 + sound_onset4 + sound_onset3 + sound_onset4
    return sound_Hz, sound_onset

    #------------------------------------------------------------------------------
    # APPEND TO DICT
    #sound_index = 0
    #for each in possible_images_dict:
    #    if 'Critical' in possible_images_dict[each]:
    #        possible_images_dict[each].append(sound_Hz_new[sound_index])
    #        print sound_Hz_new[sound_index]
    #        possible_images_dict[each].append(sound_onset[sound_index])
    #        sound_index = sound_index + 1
    #    elif 'Normal' in possible_images_dict[each]:
    #        possible_images_dict[each].append('No tone')
    #        possible_images_dict[each].append(-999)

# %%
def appending_to_dict(trial_n):
    global blocks
    for b in range(8):
        this_block_images = blocks[b]
        for im in this_block_images:
            trials[trial_n] = possible_images_dict[im]
            trials[trial_n].append(im)
            trial_n += 1
    print 'len(trials): ', len(trials)

# %%
######################
### FIRST ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  0
# critical_high_absent_probes:  0
# cycles :  19
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 1, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2008_002372.jpg', '2010_000536.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_003287.jpg', '2009_004129.jpg', '2010_000109.jpg', '2008_006452.jpg']
# probes_per_block : ['2010_003287.jpg', '2009_004129.jpg', '2010_000109.jpg', '2008_006452.jpg', '2010_003400.jpg', '2008_000972.jpg', '2009_001894.jpg', '2011_001611.jpg', '2010_005785.jpg']
# probes:  [['2010_003287.jpg', '2009_004129.jpg', '2010_000109.jpg', '2008_006452.jpg', '2010_003400.jpg', '2008_000972.jpg', '2009_001894.jpg', '2011_001611.jpg', '2010_005785.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' sofa', ' chair', nan, nan, 18.511887801846186, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', nan, nan, nan, nan, 20.358449022039405, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 14.341894736874325, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [1, 6, 13, 17, 22, 28, 34, 37, 41, 49, 51, 54] 12
# gap_check:  [6, 37, 51]
# 12
# (1, 'Target Absent')
# (6, 'Critical')
# (13, 'Target Present')
# (17, 'Target Absent')
# (22, 'Target Present')
# (28, 'Target Absent')
# (34, 'Target Absent')
# (37, 'Critical')
# (41, 'Target Absent')
# (49, 'Target Present')
# (51, 'Critical')
# (54, 'Target Present')
# [(1, 'Target Absent'), (6, 'Critical'), (13, 'Target Present'), (17, 'Target Absent'), (22, 'Target Present'), (28, 'Target Absent'), (34, 'Target Absent'), (37, 'Critical'), (41, 'Target Absent'), (49, 'Target Present'), (51, 'Critical'), (54, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 6 Critical
# image 13 Target Present
# image 17 Target Absent
# image 22 Target Present
# image 28 Target Absent
# image 34 Target Absent
# image 37 Critical
# image 41 Target Absent
# image 49 Target Present
# image 51 Critical
# image 54 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 13, 17, 22, 28, 34, 41, 49, 54]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 1, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2008_002372.jpg', '2010_000536.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_003705.jpg', '2010_002620.jpg', '2008_007043.jpg', '2008_000495.jpg']
# probes_per_block : ['2009_003705.jpg', '2010_002620.jpg', '2008_007043.jpg', '2008_000495.jpg', '2008_005750.jpg', '2008_006663.jpg', '2008_000704.jpg', '2011_001139.jpg', '2008_004042.jpg']
# probes:  [['2010_003287.jpg', '2009_004129.jpg', '2010_000109.jpg', '2008_006452.jpg', '2010_003400.jpg', '2008_000972.jpg', '2009_001894.jpg', '2011_001611.jpg', '2010_005785.jpg'], ['2009_003705.jpg', '2010_002620.jpg', '2008_007043.jpg', '2008_000495.jpg', '2008_005750.jpg', '2008_006663.jpg', '2008_000704.jpg', '2011_001139.jpg', '2008_004042.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' chair', ' bottle', ' tvmonitor', nan, 34.633056090581924, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' sofa', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 33.937775623898794, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' car', ' boat', ' person', nan, nan, 32.75926741884376, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 6 Critical
# image 13 Target Present
# image 17 Target Absent
# image 22 Target Present
# image 28 Target Absent
# image 34 Target Absent
# image 37 Critical
# image 41 Target Absent
# image 49 Target Present
# image 51 Critical
# image 54 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 13, 17, 22, 28, 34, 41, 49, 54]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2008_002372.jpg', '2010_000536.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_001159.jpg', '2010_005217.jpg', '2009_002594.jpg', '2008_006564.jpg', '2009_003686.jpg']
# probes_per_block : ['2010_001159.jpg', '2010_005217.jpg', '2009_002594.jpg', '2008_006564.jpg', '2009_003686.jpg', '2009_000523.jpg', '2011_001624.jpg', '2008_000123.jpg', '2011_000293.jpg']
# probes:  [['2010_003287.jpg', '2009_004129.jpg', '2010_000109.jpg', '2008_006452.jpg', '2010_003400.jpg', '2008_000972.jpg', '2009_001894.jpg', '2011_001611.jpg', '2010_005785.jpg'], ['2009_003705.jpg', '2010_002620.jpg', '2008_007043.jpg', '2008_000495.jpg', '2008_005750.jpg', '2008_006663.jpg', '2008_000704.jpg', '2011_001139.jpg', '2008_004042.jpg'], ['2010_001159.jpg', '2010_005217.jpg', '2009_002594.jpg', '2008_006564.jpg', '2009_003686.jpg', '2009_000523.jpg', '2011_001624.jpg', '2008_000123.jpg', '2011_000293.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' dog', nan, nan, nan, nan, 18.045035650575528, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' chair', ' cat', nan, nan, nan, 19.7971714164348, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 20.39542994429513, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [1, 7, 9, 15, 20, 25, 29, 38, 44, 46, 50, 58] 12
# gap_check:  [9, 15, 29]
# 12
# (1, 'Target Absent')
# (7, 'Target Present')
# (9, 'Critical')
# (15, 'Critical')
# (20, 'Target Absent')
# (25, 'Target Absent')
# (29, 'Critical')
# (38, 'Target Present')
# (44, 'Target Present')
# (46, 'Target Present')
# (50, 'Target Present')
# (58, 'Target Absent')
# [(1, 'Target Absent'), (7, 'Target Present'), (9, 'Critical'), (15, 'Critical'), (20, 'Target Absent'), (25, 'Target Absent'), (29, 'Critical'), (38, 'Target Present'), (44, 'Target Present'), (46, 'Target Present'), (50, 'Target Present'), (58, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 7 Target Present
# image 9 Critical
# image 15 Critical
# image 20 Target Absent
# image 25 Target Absent
# image 29 Critical
# image 38 Target Present
# image 44 Target Present
# image 46 Target Present
# image 50 Target Present
# image 58 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 7, 20, 25, 38, 44, 46, 50, 58]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2008_002372.jpg', '2010_000536.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_000041.jpg', '2011_000824.jpg', '2011_002482.jpg', '2008_007970.jpg', '2008_004633.jpg']
# probes_per_block : ['2008_000041.jpg', '2011_000824.jpg', '2011_002482.jpg', '2008_007970.jpg', '2008_004633.jpg', '2008_008628.jpg', '2008_007664.jpg', '2008_007423.jpg', '2010_001118.jpg']
# probes:  [['2010_003287.jpg', '2009_004129.jpg', '2010_000109.jpg', '2008_006452.jpg', '2010_003400.jpg', '2008_000972.jpg', '2009_001894.jpg', '2011_001611.jpg', '2010_005785.jpg'], ['2009_003705.jpg', '2010_002620.jpg', '2008_007043.jpg', '2008_000495.jpg', '2008_005750.jpg', '2008_006663.jpg', '2008_000704.jpg', '2011_001139.jpg', '2008_004042.jpg'], ['2010_001159.jpg', '2010_005217.jpg', '2009_002594.jpg', '2008_006564.jpg', '2009_003686.jpg', '2009_000523.jpg', '2011_001624.jpg', '2008_000123.jpg', '2011_000293.jpg'], ['2008_000041.jpg', '2011_000824.jpg', '2011_002482.jpg', '2008_007970.jpg', '2008_004633.jpg', '2008_008628.jpg', '2008_007664.jpg', '2008_007423.jpg', '2010_001118.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 35.66913245555085, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' bird', ' boat', nan, nan, 31.913409738647122, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 31.88587780040415, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 7 Target Present
# image 9 Critical
# image 15 Critical
# image 20 Target Absent
# image 25 Target Absent
# image 29 Critical
# image 38 Target Present
# image 44 Target Present
# image 46 Target Present
# image 50 Target Present
# image 58 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 7, 20, 25, 38, 44, 46, 50, 58]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2008_002372.jpg', '2010_000536.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: ['2008_002372.jpg']
# absent_critical_per_block: []
# critical_present:  [['2008_002372.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2008_002372.jpg']
# probes_per_block : ['2009_005075.jpg', '2010_000616.jpg', '2010_003101.jpg']
# probes_per_block : ['2009_005075.jpg', '2010_000616.jpg', '2010_003101.jpg', '2009_002711.jpg', '2009_002521.jpg', '2009_003530.jpg', '2011_001834.jpg', '2010_001829.jpg']
# probes:  [['2010_003287.jpg', '2009_004129.jpg', '2010_000109.jpg', '2008_006452.jpg', '2010_003400.jpg', '2008_000972.jpg', '2009_001894.jpg', '2011_001611.jpg', '2010_005785.jpg'], ['2009_003705.jpg', '2010_002620.jpg', '2008_007043.jpg', '2008_000495.jpg', '2008_005750.jpg', '2008_006663.jpg', '2008_000704.jpg', '2011_001139.jpg', '2008_004042.jpg'], ['2010_001159.jpg', '2010_005217.jpg', '2009_002594.jpg', '2008_006564.jpg', '2009_003686.jpg', '2009_000523.jpg', '2011_001624.jpg', '2008_000123.jpg', '2011_000293.jpg'], ['2008_000041.jpg', '2011_000824.jpg', '2011_002482.jpg', '2008_007970.jpg', '2008_004633.jpg', '2008_008628.jpg', '2008_007664.jpg', '2008_007423.jpg', '2010_001118.jpg'], ['2009_005075.jpg', '2010_000616.jpg', '2010_003101.jpg', '2009_002711.jpg', '2009_002521.jpg', '2009_003530.jpg', '2011_001834.jpg', '2010_001829.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' boat', nan, nan, nan, nan, 19.685752299806754, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 18.78745072135656, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  241
# critical_probes_used ['2008_002372.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 1
# absent_critical_per_block 0
# ciao2 2
# ------------------
# [3, 9, 13, 17, 23, 31, 36, 37, 45, 47, 53] 11
# gap_check:  [9, 17, 37]
# 11
# (3, 'Target Absent')
# (9, 'Critical')
# (13, 'Target Absent')
# (17, 'Critical Present')
# (23, 'Target Absent')
# (31, 'Target Absent')
# (36, 'Target Present')
# (37, 'Critical')
# (45, 'Target Present')
# (47, 'Target Absent')
# (53, 'Target Present')
# [(3, 'Target Absent'), (9, 'Critical'), (13, 'Target Absent'), (17, 'Critical Present'), (23, 'Target Absent'), (31, 'Target Absent'), (36, 'Target Present'), (37, 'Critical'), (45, 'Target Present'), (47, 'Target Absent'), (53, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Absent
# image
Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [6, 7, 10, 11, 14, 17, 25, 26, 35]
# 60 60
# len(trials):  480

# %%
######################
### SECOND ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(481)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  0
# critical_high_absent_probes:  0
# cycles :  2
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2009_002325.jpg', '2010_005608.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: ['2009_002325.jpg']
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2009_002325.jpg']
# probes_per_block : ['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg']
# probes_per_block : ['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg', '2009_002594.jpg', '2008_002904.jpg', '2008_005728.jpg', '2010_000616.jpg', '2010_005780.jpg']
# probes:  [['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg', '2009_002594.jpg', '2008_002904.jpg', '2008_005728.jpg', '2010_000616.jpg', '2010_005780.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' person', nan, nan, nan, nan, 21.23535981155764, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 19.264337675075122, 'low', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  49
# critical_probes_used ['2009_002325.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 1
# absent_critical_per_block 0
# ciao2 2
# ciao2 2
# ciao2 2
# ------------------
# [1, 4, 14, 18, 24, 33, 35, 41, 43, 49, 53] 11
# gap_check:  [14, 24, 49]
# 11
# (1, 'Target Absent')
# (4, 'Target Absent')
# (14, 'Critical')
# (18, 'Target Present')
# (24, 'Critical Present')
# (33, 'Target Present')
# (35, 'Target Absent')
# (41, 'Target Present')
# (43, 'Target Absent')
# (49, 'Critical')
# (53, 'Target Absent')
# [(1, 'Target Absent'), (4, 'Target Absent'), (14, 'Critical'), (18, 'Target Present'), (24, 'Critical Present'), (33, 'Target Present'), (35, 'Target Absent'), (41, 'Target Present'), (43, 'Target Absent'), (49, 'Critical'), (53, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 4 Target Absent
# image 14 Critical
# image 18 Target Present
# image 24 Critical Present
# image 33 Target Present
# image 35 Target Absent
# image 41 Target Present
# image 43 Target Absent
# image 49 Critical
# image 53 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 4, 18, 24, 33, 35, 41, 43, 53]
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2009_002325.jpg', '2010_005608.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 337
# present_critical_per_block: ['2010_005608.jpg']
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg'], ['2010_005608.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2009_002325.jpg', '2010_005608.jpg']
# probes_per_block : ['2008_002037.jpg', '2008_005818.jpg', '2008_006863.jpg']
# probes_per_block : ['2008_002037.jpg', '2008_005818.jpg', '2008_006863.jpg', '2008_007388.jpg', '2010_000536.jpg', '2008_000885.jpg', '2009_000629.jpg', '2009_005133.jpg']
# probes:  [['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg', '2009_002594.jpg', '2008_002904.jpg', '2008_005728.jpg', '2010_000616.jpg', '2010_005780.jpg'], ['2008_002037.jpg', '2008_005818.jpg', '2008_006863.jpg', '2008_007388.jpg', '2010_000536.jpg', '2008_000885.jpg', '2009_000629.jpg', '2009_005133.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' car', ' motorbike', ' person', nan, nan, 31.40872195535423, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' aeroplane', ' boat', nan, nan, nan, 29.28734944464957, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  98
# critical_probes_used ['2009_002325.jpg', '2010_005608.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 4 Target Absent
# image 14 Critical
# image 18 Target Present
# image 24 Critical Present
# image 33 Target Present
# image 35 Target Absent
# image 41 Target Present
# image 43 Target Absent
# image 49 Critical
# image 53 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 4, 18, 24, 33, 35, 41, 43, 53]
# 60 60
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_002325.jpg', '2010_005608.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 288
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg'], ['2010_005608.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2009_002325.jpg', '2010_005608.jpg']
# probes_per_block : ['2011_000481.jpg', '2008_003587.jpg', '2010_003453.jpg', '2009_004598.jpg', '2010_004753.jpg']
# probes_per_block : ['2011_000481.jpg', '2008_003587.jpg', '2010_003453.jpg', '2009_004598.jpg', '2010_004753.jpg', '2008_008331.jpg', '2010_005885.jpg', '2009_002604.jpg', '2011_001834.jpg']
# probes:  [['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg', '2009_002594.jpg', '2008_002904.jpg', '2008_005728.jpg', '2010_000616.jpg', '2010_005780.jpg'], ['2008_002037.jpg', '2008_005818.jpg', '2008_006863.jpg', '2008_007388.jpg', '2010_000536.jpg', '2008_000885.jpg', '2009_000629.jpg', '2009_005133.jpg'], ['2011_000481.jpg', '2008_003587.jpg', '2010_003453.jpg', '2009_004598.jpg', '2010_004753.jpg', '2008_008331.jpg', '2010_005885.jpg', '2009_002604.jpg', '2011_001834.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', nan, nan, nan, nan, 21.25588754749905, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 18.59798168174263, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 17.883134744539575, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  146
# critical_probes_used ['2009_002325.jpg', '2010_005608.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [6, 9, 16, 18, 26, 30, 31, 33, 39, 48, 56, 57] 12
# gap_check:  [9, 26, 57]
# 12
# (6, 'Target Absent')
# (9, 'Critical')
# (16, 'Target Present')
# (18, 'Target Absent')
# (26, 'Critical')
# (30, 'Target Absent')
# (31, 'Target Absent')
# (33, 'Target Present')
# (39, 'Target Present')
# (48, 'Target Present')
# (56, 'Target Present')
# (57, 'Critical')
# [(6, 'Target Absent'), (9, 'Critical'), (16, 'Target Present'), (18, 'Target Absent'), (26, 'Critical'), (30, 'Target Absent'), (31, 'Target Absent'), (33, 'Target Present'), (39, 'Target Present'), (48, 'Target Present'), (56, 'Target Present'), (57, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Absent
# image 9 Critical
# image 16 Target Present
# image 18 Target Absent
# image 26 Critical
# image 30 Target Absent
# image 31 Target Absent
# image 33 Target Present
# image 39 Target Present
# image 48 Target Present
# image 56 Target Present
# image 57 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [6, 16, 18, 30, 31, 33, 39, 48, 56]
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_002325.jpg', '2010_005608.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 240
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg'], ['2010_005608.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2009_002325.jpg', '2010_005608.jpg']
# probes_per_block : ['2008_005720.jpg', '2009_004364.jpg', '2008_004487.jpg', '2008_008681.jpg', '2011_001440.jpg']
# probes_per_block : ['2008_005720.jpg', '2009_004364.jpg', '2008_004487.jpg', '2008_008681.jpg', '2011_001440.jpg', '2009_000067.jpg', '2011_000530.jpg', '2008_007664.jpg', '2009_000120.jpg']
# probes:  [['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg', '2009_002594.jpg', '2008_002904.jpg', '2008_005728.jpg', '2010_000616.jpg', '2010_005780.jpg'], ['2008_002037.jpg', '2008_005818.jpg', '2008_006863.jpg', '2008_007388.jpg', '2010_000536.jpg', '2008_000885.jpg', '2009_000629.jpg', '2009_005133.jpg'], ['2011_000481.jpg', '2008_003587.jpg', '2010_003453.jpg', '2009_004598.jpg', '2010_004753.jpg', '2008_008331.jpg', '2010_005885.jpg', '2009_002604.jpg', '2011_001834.jpg'], ['2008_005720.jpg', '2009_004364.jpg', '2008_004487.jpg', '2008_008681.jpg', '2011_001440.jpg', '2009_000067.jpg', '2011_000530.jpg', '2008_007664.jpg', '2009_000120.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' dog', ' bottle', nan, nan, nan, 41.99714470321874, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' motorbike', ' boat', 31.58048990210689, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  194
# critical_probes_used ['2009_002325.jpg', '2010_005608.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Absent
# image 9 Critical
# image 16 Target Present
# image 18 Target Absent
# image 26 Critical
# image 30 Target Absent
# image 31 Target Absent
# image 33 Target Present
# image 39 Target Present
# image 48 Target Present
# image 56 Target Present
# image 57 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [6, 16, 18, 30, 31, 33, 39, 48, 56]
# 60 60
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_002325.jpg', '2010_005608.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 192
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg'], ['2010_005608.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2009_002325.jpg', '2010_005608.jpg']
# probes_per_block : ['2010_003890.jpg', '2008_008395.jpg', '2008_004171.jpg', '2008_001708.jpg']
# probes_per_block : ['2010_003890.jpg', '2008_008395.jpg', '2008_004171.jpg', '2008_001708.jpg', '2009_000260.jpg', '2008_000123.jpg', '2011_000661.jpg', '2010_003746.jpg', '2011_003074.jpg']
# probes:  [['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg', '2009_002594.jpg', '2008_002904.jpg', '2008_005728.jpg', '2010_000616.jpg', '2010_005780.jpg'], ['2008_002037.jpg', '2008_005818.jpg', '2008_006863.jpg', '2008_007388.jpg', '2010_000536.jpg', '2008_000885.jpg', '2009_000629.jpg', '2009_005133.jpg'], ['2011_000481.jpg', '2008_003587.jpg', '2010_003453.jpg', '2009_004598.jpg', '2010_004753.jpg', '2008_008331.jpg', '2010_005885.jpg', '2009_002604.jpg', '2011_001834.jpg'], ['2008_005720.jpg', '2009_004364.jpg', '2008_004487.jpg', '2008_008681.jpg', '2011_001440.jpg', '2009_000067.jpg', '2011_000530.jpg', '2008_007664.jpg', '2009_000120.jpg'], ['2010_003890.jpg', '2008_008395.jpg', '2008_004171.jpg', '2008_001708.jpg', '2009_000260.jpg', '2008_000123.jpg', '2011_000661.jpg', '2010_003746.jpg', '2011_003074.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' dog', nan, nan, nan, nan, 16.693372571654717, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 13.879634097368903, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 14.343346792518373, 'low', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  242
# critical_probes_used ['2009_002325.jpg', '2010_005608.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [6, 10, 16, 19, 25, 30, 32, 40, 42, 47, 50, 54] 12
# gap_check:  [10, 16, 32]
# 12
# (6, 'Target Present')
# (10, 'Critical')
# (16, 'Critical')
# (19, 'Target Present')
# (25, 'Target Present')
# (30, 'Target Absent')
# (32, 'Critical')
# (40, 'Target Absent')
# (42, 'Target Absent')
# (47, 'Target Absent')
# (50, 'Target Present')
# (54, 'Target Absent')
# [(6, 'Target Present'), (10, 'Critical'), (16, 'Critical'), (19, 'Target Present'), (25, 'Target Present'), (30, 'Target Absent'), (32, 'Critical'), (40, 'Target Absent'), (42, 'Target Absent'), (47, 'Target Absent'), (50, 'Target Present'), (54, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Present
# image 10 Critical
# image 16 Critical
# image 19 Target Present
# image 25 Target Present
# image 30 Target Absent
# image 32 Critical
# image 40 Target Absent
# image 42 Target Absent
# image 47 Target Absent
# image 50 Target Present
# image 54 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [6, 19, 25, 30, 40, 42, 47, 50, 54]
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_002325.jpg', '2010_005608.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 144
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg'], ['2010_005608.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2009_002325.jpg', '2010_005608.jpg']
# probes_per_block : ['2008_007143.jpg', '2008_007091.jpg', '2008_003283.jpg', '2008_004646.jpg']
# probes_per_block : ['2008_007143.jpg', '2008_007091.jpg', '2008_003283.jpg', '2008_004646.jpg', '2008_002195.jpg', '2011_000824.jpg', '2008_006461.jpg', '2008_006062.jpg', '2008_000928.jpg']
# probes:  [['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg', '2009_002594.jpg', '2008_002904.jpg', '2008_005728.jpg', '2010_000616.jpg', '2010_005780.jpg'], ['2008_002037.jpg', '2008_005818.jpg', '2008_006863.jpg', '2008_007388.jpg', '2010_000536.jpg', '2008_000885.jpg', '2009_000629.jpg', '2009_005133.jpg'], ['2011_000481.jpg', '2008_003587.jpg', '2010_003453.jpg', '2009_004598.jpg', '2010_004753.jpg', '2008_008331.jpg', '2010_005885.jpg', '2009_002604.jpg', '2011_001834.jpg'], ['2008_005720.jpg', '2009_004364.jpg', '2008_004487.jpg', '2008_008681.jpg', '2011_001440.jpg', '2009_000067.jpg', '2011_000530.jpg', '2008_007664.jpg', '2009_000120.jpg'], ['2010_003890.jpg', '2008_008395.jpg', '2008_004171.jpg', '2008_001708.jpg', '2009_000260.jpg', '2008_000123.jpg', '2011_000661.jpg', '2010_003746.jpg', '2011_003074.jpg'], ['2008_007143.jpg', '2008_007091.jpg', '2008_003283.jpg', '2008_004646.jpg', '2008_002195.jpg', '2011_000824.jpg', '2008_006461.jpg', '2008_006062.jpg', '2008_000928.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' train', ' car', nan, nan, 31.026856988880144, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', ' tvmonitor', nan, 29.464580095555625, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' sofa', ' bottle', ' person', nan, 29.608026491553932, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  290
# critical_probes_used ['2009_002325.jpg', '2010_005608.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Present
# image 10 Critical
# image 16 Critical
# image 19 Target Present
# image 25 Target Present
# image 30 Target Absent
# image 32 Critical
# image 40 Target Absent
# image 42 Target Absent
# image 47 Target Absent
# image 50 Target Present
# image 54 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [6, 19, 25, 30, 40, 42, 47, 50, 54]
# 60 60
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2009_002325.jpg', '2010_005608.jpg']
# critical absent set:  []
# ---------------------------------------------------
# normal available: 96
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg'], ['2010_005608.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2009_002325.jpg', '2010_005608.jpg']
# probes_per_block : ['2009_003209.jpg', '2011_001613.jpg', '2010_003329.jpg', '2008_000952.jpg', '2008_008506.jpg']
# probes_per_block : ['2009_003209.jpg', '2011_001613.jpg', '2010_003329.jpg', '2008_000952.jpg', '2008_008506.jpg', '2011_002303.jpg', '2008_006954.jpg', '2008_000398.jpg', '2009_003530.jpg']
# probes:  [['2008_001617.jpg', '2011_001198.jpg', '2009_001406.jpg', '2009_002594.jpg', '2008_002904.jpg', '2008_005728.jpg', '2010_000616.jpg', '2010_005780.jpg'], ['2008_002037.jpg', '2008_005818.jpg', '2008_006863.jpg', '2008_007388.jpg', '2010_000536.jpg', '2008_000885.jpg', '2009_000629.jpg', '2009_005133.jpg'], ['2011_000481.jpg', '2008_003587.jpg', '2010_003453.jpg', '2009_004598.jpg', '2010_004753.jpg', '2008_008331.jpg', '2010_005885.jpg', '2009_002604.jpg', '2011_001834.jpg'], ['2008_005720.jpg', '2009_004364.jpg', '2008_004487.jpg', '2008_008681.jpg', '2011_001440.jpg', '2009_000067.jpg', '2011_000530.jpg', '2008_007664.jpg', '2009_000120.jpg'], ['2010_003890.jpg', '2008_008395.jpg', '2008_004171.jpg', '2008_001708.jp
g', '2008_004646.jpg', '2008_002195.jpg', '2011_000824.jpg', '2008_006461.jpg', '2008_006062.jpg', '2008_000928.jpg'], ['2009_003209.jpg', '2011_001613.jpg', '2010_003329.jpg', '2008_000952.jpg', '2008_008506.jpg', '2011_002303.jpg', '2008_006954.jpg', '2008_000398.jpg', '2009_003530.jpg'], ['2008_002774.jpg', '2008_001333.jpg', '2008_000495.jpg', '2008_001576.jpg', '2008_002084.jpg', '2008_007043.jpg', '2008_006844.jpg', '2010_004447.jpg', '2008_003193.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' car', ' chair', ' bicycle', ' person', 30.133244112833108, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' diningtable', ' cat', nan, nan, 29.842922502719393, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 31.26103763923315, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  386
# critical_probes_used ['2009_002325.jpg', '2010_005608.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 8 Target Present
# image 9 Target Absent
# image 15 Target Present
# image 18 Target Absent
# image 28 Critical
# image 36 Target Absent
# image 40 Target Absent
# image 42 Target Present
# image 43 Critical
# image 48 Target Present
# image 51 Target Present
# image 55 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [8, 9, 15, 18, 36, 40, 42, 48, 51]
# 60 60
# len(trials):  960

# %%
######################
### THIRD ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

#tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(961)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  10
# Critical, high:  10
# Are all critical trials unique?  True
# Number of critical probes:  4
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  1
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  ['2008_004814.jpg', '2009_003351.jpg']
# critical absent set:  ['2009_002521.jpg', '2010_003490.jpg']
# ---------------------------------------------------
# normal available: 388
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_001546.jpg', '2010_002498.jpg', '2010_003101.jpg', '2008_002704.jpg']
# probes_per_block : ['2008_001546.jpg', '2010_002498.jpg', '2010_003101.jpg', '2008_002704.jpg', '2009_003530.jpg', '2008_004893.jpg', '2008_005123.jpg', '2010_001271.jpg', '2010_004145.jpg']
# probes:  [['2008_001546.jpg', '2010_002498.jpg', '2010_003101.jpg', '2008_002704.jpg', '2009_003530.jpg', '2008_004893.jpg', '2008_005123.jpg', '2010_001271.jpg', '2010_004145.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', ' person', nan, nan, nan, 21.05297682386103, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 17.69816713203682, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 20.58416256718508, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [3, 6, 14, 17, 27, 28, 32, 33, 35, 44, 52, 59] 12
# gap_check:  [28, 35, 59]
# 12
# (3, 'Target Present')
# (6, 'Target Absent')
# (14, 'Target Absent')
# (17, 'Target Present')
# (27, 'Target Absent')
# (28, 'Critical')
# (32, 'Target Present')
# (33, 'Target Absent')
# (35, 'Critical')
# (44, 'Target Absent')
# (52, 'Target Present')
# (59, 'Critical')
# [(3, 'Target Present'), (6, 'Target Absent'), (14, 'Target Absent'), (17, 'Target Present'), (27, 'Target Absent'), (28, 'Critical'), (32, 'Target Present'), (33, 'Target Absent'), (35, 'Critical'), (44, 'Target Absent'), (52, 'Target Present'), (59, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 6 Target Absent
# image 14 Target Absent
# image 17 Target Present
# image 27 Target Absent
# image 28 Critical
# image 32 Target Present
# image 33 Target Absent
# image 35 Critical
# image 44 Target Absent
# image 52 Target Present
# image 59 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 6, 14, 17, 27, 32, 33, 44, 52]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  ['2008_004814.jpg', '2009_003351.jpg']
# critical absent set:  ['2009_002521.jpg', '2010_003490.jpg']
# ---------------------------------------------------
# normal available: 340
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_002672.jpg', '2008_000928.jpg', '2008_008607.jpg', '2008_006663.jpg']
# probes_per_block : ['2008_002672.jpg', '2008_000928.jpg', '2008_008607.jpg', '2008_006663.jpg', '2008_006216.jpg', '2010_005572.jpg', '2008_005519.jpg', '2008_003701.jpg', '2008_002119.jpg']
# probes:  [['2008_001546.jpg', '2010_002498.jpg', '2010_003101.jpg', '2008_002704.jpg', '2009_003530.jpg', '2008_004893.jpg', '2008_005123.jpg', '2010_001271.jpg', '2010_004145.jpg'], ['2008_002672.jpg', '2008_000928.jpg', '2008_008607.jpg', '2008_006663.jpg', '2008_006216.jpg', '2010_005572.jpg', '2008_005519.jpg', '2008_003701.jpg', '2008_002119.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' chair', ' bird', nan, nan, 29.63012122697995, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' car', nan, nan, nan, 28.839741748612518, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' car', ' dog', ' person', nan, nan, 29.763552134631723, 'high', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 6 Target Absent
# image 14 Target Absent
# image 17 Target Present
# image 27 Target Absent
# image 28 Critical
# image 32 Target Present
# image 33 Target Absent
# image 35 Critical
# image 44 Target Absent
# image 52 Target Present
# image 59 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 6, 14, 17, 27, 32, 33, 44, 52]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 1
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2008_004814.jpg', '2009_003351.jpg']
# critical absent set:  ['2009_002521.jpg', '2010_003490.jpg']
# ---------------------------------------------------
# normal available: 292
# present_critical_per_block: ['2008_004814.jpg']
# absent_critical_per_block: ['2009_002521.jpg']
# critical_present:  [['2008_004814.jpg']]
# critical_absent:  [['2009_002521.jpg']]
# critical_probes_used:  ['2008_004814.jpg', '2009_002521.jpg']
# probes_per_block : ['2009_002817.jpg', '2008_001185.jpg', '2008_004270.jpg', '2010_000426.jpg']
# probes_per_block : ['2009_002817.jpg', '2008_001185.jpg', '2008_004270.jpg', '2010_000426.jpg', '2008_005735.jpg', '2010_001907.jpg', '2010_001159.jpg']
# probes:  [['2008_001546.jpg', '2010_002498.jpg', '2010_003101.jpg', '2008_002704.jpg', '2009_003530.jpg', '2008_004893.jpg', '2008_005123.jpg', '2010_001271.jpg', '2010_004145.jpg'], ['2008_002672.jpg', '2008_000928.jpg', '2008_008607.jpg', '2008_006663.jpg', '2008_006216.jpg', '2010_005572.jpg', '2008_005519.jpg', '2008_003701.jpg', '2008_002119.jpg'], ['2009_002817.jpg', '2008_001185.jpg', '2008_004270.jpg', '2010_000426.jpg', '2008_005735.jpg', '2010_001907.jpg', '2010_001159.jpg']]
# Present Used in block:  4
# Absent Used in block 3
# Critical probes counter:  2
# Present Critical:  1
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' cat', nan, nan, nan, 20.139877805151375, 'low', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  146
# critical_probes_used ['2008_004814.jpg', '2009_002521.jpg']
# sequence final does not exist
# x 2
# present_critical_per_block 1
# absent_critical_per_block 1
# ciao2 1
# ciao2 1
# ciao2 1
# ciao2 1
# ciao2 1
# ciao2 1
# ciao2 1
# ------------------
# [0, 10, 14, 18, 28, 29, 33, 41, 51, 57] 10
# gap_check:  [0, 10, 18]
# 10
# (0, 'Critical Absent')
# (10, 'Critical Present')
# (14, 'Target Absent')
# (18, 'Critical')
# (28, 'Target Present')
# (29, 'Target Present')
# (33, 'Target Present')
# (41, 'Target Absent')
# (51, 'Target Absent')
# (57, 'Target Present')
# [(0, 'Critical Absent'), (10, 'Critical Present'), (14, 'Target Absent'), (18, 'Critical'), (28, 'Target Present'), (29, 'Target Present'), (33, 'Target Present'), (41, 'Target Absent'), (51, 'Target Absent'), (57, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Critical Absent
# image 10 Critical Present
# image 14 Target Absent
# image 18 Critical
# image 28 Target Present
# image 29 Target Present
# image 33 Target Present
# image 41 Target Absent
# image 51 Target Absent
# image 57 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 10, 14, 28, 29, 33, 41, 51, 57]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 1
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2008_004814.jpg', '2009_003351.jpg']
# critical absent set:  ['2009_002521.jpg', '2010_003490.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: ['2009_003351.jpg']
# absent_critical_per_block: ['2010_003490.jpg']
# critical_present:  [['2008_004814.jpg'], ['2009_003351.jpg']]
# critical_absent:  [['2009_002521.jpg'], ['2010_003490.jpg']]
# critical_probes_used:  ['2008_004814.jpg', '2009_002521.jpg', '2009_003351.jpg', '2010_003490.jpg']
# probes_per_block : ['2008_000798.jpg', '2008_002773.jpg', '2011_001304.jpg', '2008_001210.jpg']
# probes_per_block : ['2008_000798.jpg', '2008_002773.jpg', '2011_001304.jpg', '2008_001210.jpg', '2011_001025.jpg', '2010_001586.jpg', '2008_000457.jpg']
# probes:  [['2008_001546.jpg', '2010_002498.jpg', '2010_003101.jpg', '2008_002704.jpg', '2009_003530.jpg', '2008_004893.jpg', '2008_005123.jpg', '2010_001271.jpg', '2010_004145.jpg'], ['2008_002672.jpg', '2008_000928.jpg', '2008_008607.jpg', '2008_006663.jpg', '2008_006216.jpg', '2010_005572.jpg', '2008_005519.jpg', '2008_003701.jpg', '2008_002119.jpg'], ['2009_002817.jpg', '2008_001185.jpg', '2008_004270.jpg', '2010_000426.jpg', '2008_005735.jpg', '2010_001907.jpg', '2010_001159.jpg'], ['2008_000798.jpg', '2008_002773.jpg', '2011_001304.jpg', '2008_001210.jpg', '2011_001025.jpg', '2010_001586.jpg', '2008_000457.jpg']]
# Present Used in block:  4
# Absent Used in block 3
# Critical probes counter:  2
# Present Critical:  1
# Absent Critical:  1
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 32.66066395118465, 'high', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  196
# critical_probes_used ['2008_004814.jpg', '2009_002521.jpg', '2009_003351.jpg', '2010_003490.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Critical Absent
# image 10 Critical Present
# image 14 Target Absent
# image 18 Critical
# image 28 Target Present
# image 29 Target Present
# image 33 Target Present
# image 41 Target Absent
# image 51 Target Absent
# image 57 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 10, 14, 28, 29, 33, 41, 51, 57]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2008_004814.jpg', '2009_003351.jpg']
# critical absent set:  ['2009_002521.jpg', '2010_003490.jpg']
# ---------------------------------------------------
# normal available: 192
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2008_004814.jpg'], ['2009_003351.jpg']]
# critical_absent:  [['2009_002521.jpg'], ['2010_003490.jpg']]
# critical_probes_used:  ['2008_004814.jpg', '2009_002521.jpg', '2009_003351.jpg', '2010_003490.jpg']
# probes_per_block : ['2008_003369.jpg', '2008_007048.jpg', '2010_003890.jpg', '2010_005885.jpg']
# probes_per_block : ['2008_003369.jpg', '2008_007048.jpg', '2010_003890.jpg', '2010_005885.jpg', '2009_002697.jpg', '2010_002393.jpg', '2008_000734.jpg', '2008_005728.jpg', '2010_005785.jpg']
# probes:  [['2008_001546.jpg', '2010_002498.jpg', '2010_003101.jpg', '2008_002704.jpg', '2009_003530.jpg', '2008_004893.jpg', '2008_005123.jpg', '2010_001271.jpg', '2010_004145.jpg'], ['2008_002672.jpg', '2008_000928.jpg', '2008_008607.jpg', '2008_006663.jpg', '2008_006216.jpg', '2010_005572.jpg', '2008_005519.jpg', '2008_003701.jpg', '2008_002119.jpg'], ['2009_002817.jpg', '2008_001185.jpg', '2008_004270.jpg', '2010_000426.jpg', '2008_005735.jpg', '2010_001907.jpg', '2010_001159.jpg'], ['2008_000798.jpg', '2008_002773.jpg', '2011_001304.jpg', '2008_001210.jpg', '2011_001025.jpg', '2010_001586.jpg', '2008_000457.jpg'], ['2008_003369.jpg', '2008_007048.jpg', '2010_003890.jpg', '2010_005885.jpg', '2009_002697.jpg', '2010_002393.jpg', '2008_000734.jpg', '2008_005728.jpg', '2010_005785.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 20.559862456799, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' chair', nan, nan, nan, 20.22413954449369, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 18.720728543179284, 'low', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  244
# critical_probes_used ['2008_004814.jpg', '2009_002521.jpg', '2009_003351.jpg', '2010_003490.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [6, 14, 17, 19, 21, 22, 26, 28, 30, 34, 43, 47] 12
# gap_check:  [22, 30, 34]
# 12
# (6, 'Target Absent')
# (14, 'Target Present')
# (17, 'Target Absent')
# (19, 'Target Absent')
# (21, 'Target Present')
# (22, 'Critical')
# (26, 'Target Present')
# (28, 'Target Present')
# (30, 'Critical')
# (34, 'Critical')
# (43, 'Target Absent')
# (47, 'Target Absent')
# [(6, 'Target Absent'), (14, 'Target Present'), (17, 'Target Absent'), (19, 'Target Absent'), (21, 'Target Present'), (22, 'Critical'), (26, 'Target Present'), (28, 'Target Present'), (30, 'Critical'), (34, 'Critical'), (43, 'Target Absent'), (47, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Target Absent
# image 14 Target Present
# image 17 Target Absent
# image 19 Target Absent
# image 21 Target Present
# image 22 Critical
# image 26 Target Present
# image 28 Target Present
# image 30 Critical
# image 34 Critical
# image 43 Target Absent
# image 47 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [6, 14, 17, 19, 21, 26, 28, 43, 47]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2008_004814.jpg', '2009_003351.jpg']
# critical absent set:  ['2009_002521.jpg', '2010_003490.jpg']
# ---------------------------------------------------
# normal available: 144
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2008_004814.jpg'], ['2009_003351.jpg']]
# critical_absent:  [['2009_002521.jpg'], ['2010_003490.jpg']]
# critical_probes_used:  ['2008_004814.jpg', '2009_002521.jpg', '2009_003351.jpg', '2010_003490.jpg']
# probes_per_block : ['2008
 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [2, 6, 15, 22, 28, 31, 35, 36, 45, 48, 53, 59] 12
# gap_check:  [15, 36, 53]
# 12
# (2, 'Target Absent')
# (6, 'Target Absent')
# (15, 'Critical')
# (22, 'Target Present')
# (28, 'Target Present')
# (31, 'Target Absent')
# (35, 'Target Present')
# (36, 'Critical')
# (45, 'Target Absent')
# (48, 'Target Absent')
# (53, 'Critical')
# (59, 'Target Present')
# [(2, 'Target Absent'), (6, 'Target Absent'), (15, 'Critical'), (22, 'Target Present'), (28, 'Target Present'), (31, 'Target Absent'), (35, 'Target Present'), (36, 'Critical'), (45, 'Target Absent'), (48, 'Target Absent'), (53, 'Critical'), (59, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Absent
# image 6 Target Absent
# image 15 Critical
# image 22 Target Present
# image 28 Target Present
# image 31 Target Absent
# image 35 Target Present
# image 36 Critical
# image 45 Target Absent
# image 48 Target Absent
# image 53 Critical
# image 59 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [2, 6, 22, 28, 31, 35, 45, 48, 59]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 1, 0]
# absent_crit_distribution:  [0, 2, 0]
# critical present set:  ['2008_007208.jpg', '2010_002603.jpg']
# critical absent set:  ['2009_003232.jpg', '2010_002393.jpg', '2008_005750.jpg', '2008_000274.jpg']
# ---------------------------------------------------
# normal available: 342
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_003943.jpg', '2008_002725.jpg', '2009_003351.jpg', '2010_002742.jpg']
# probes_per_block : ['2010_003943.jpg', '2008_002725.jpg', '2009_003351.jpg', '2010_002742.jpg', '2010_003861.jpg', '2008_007388.jpg', '2008_007664.jpg', '2011_002509.jpg', '2008_003180.jpg']
# probes:  [['2009_000523.jpg', '2008_008331.jpg', '2010_004753.jpg', '2008_005123.jpg', '2009_001975.jpg', '2011_001624.jpg', '2008_008263.jpg', '2008_002372.jpg', '2010_005785.jpg'], ['2010_003943.jpg', '2008_002725.jpg', '2009_003351.jpg', '2010_002742.jpg', '2010_003861.jpg', '2008_007388.jpg', '2008_007664.jpg', '2011_002509.jpg', '2008_003180.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' sofa', nan, nan, nan, 31.62452384083404, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 29.28123750737463, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 31.182430259996877, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Absent
# image 6 Target Absent
# image 15 Critical
# image 22 Target Present
# image 28 Target Present
# image 31 Target Absent
# image 35 Target Present
# image 36 Critical
# image 45 Target Absent
# image 48 Target Absent
# image 53 Critical
# image 59 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [2, 6, 22, 28, 31, 35, 45, 48, 59]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [2, 0]
# critical present set:  ['2008_007208.jpg', '2010_002603.jpg']
# critical absent set:  ['2009_003232.jpg', '2010_002393.jpg', '2008_005750.jpg', '2008_000274.jpg']
# ---------------------------------------------------
# normal available: 294
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2011_002558.jpg', '2008_000151.jpg', '2010_002956.jpg', '2008_005978.jpg', '2009_003686.jpg']
# probes_per_block : ['2011_002558.jpg', '2008_000151.jpg', '2010_002956.jpg', '2008_005978.jpg', '2009_003686.jpg', '2008_006452.jpg', '2009_000716.jpg', '2011_002911.jpg', '2011_003145.jpg']
# probes:  [['2009_000523.jpg', '2008_008331.jpg', '2010_004753.jpg', '2008_005123.jpg', '2009_001975.jpg', '2011_001624.jpg', '2008_008263.jpg', '2008_002372.jpg', '2010_005785.jpg'], ['2010_003943.jpg', '2008_002725.jpg', '2009_003351.jpg', '2010_002742.jpg', '2010_003861.jpg', '2008_007388.jpg', '2008_007664.jpg', '2011_002509.jpg', '2008_003180.jpg'], ['2011_002558.jpg', '2008_000151.jpg', '2010_002956.jpg', '2008_005978.jpg', '2009_003686.jpg', '2008_006452.jpg', '2009_000716.jpg', '2011_002911.jpg', '2011_003145.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 18.135096838925413, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 20.821731630747827, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' car', ' person', nan, nan, nan, 20.695714607410885, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [0, 4, 10, 16, 21, 23, 25, 30, 32, 39, 45, 51] 12
# gap_check:  [4, 16, 32]
# 12
# (0, 'Target Absent')
# (4, 'Critical')
# (10, 'Target Present')
# (16, 'Critical')
# (21, 'Target Present')
# (23, 'Target Present')
# (25, 'Target Present')
# (30, 'Target Absent')
# (32, 'Critical')
# (39, 'Target Absent')
# (45, 'Target Absent')
# (51, 'Target Present')
# [(0, 'Target Absent'), (4, 'Critical'), (10, 'Target Present'), (16, 'Critical'), (21, 'Target Present'), (23, 'Target Present'), (25, 'Target Present'), (30, 'Target Absent'), (32, 'Critical'), (39, 'Target Absent'), (45, 'Target Absent'), (51, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 4 Critical
# image 10 Target Present
# image 16 Critical
# image 21 Target Present
# image 23 Target Present
# image 25 Target Present
# image 30 Target Absent
# image 32 Critical
# image 39 Target Absent
# image 45 Target Absent
# image 51 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 10, 21, 23, 25, 30, 39, 45, 51]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [2, 0]
# critical present set:  ['2008_007208.jpg', '2010_002603.jpg']
# critical absent set:  ['2009_003232.jpg', '2010_002393.jpg', '2008_005750.jpg', '2008_000274.jpg']
# ---------------------------------------------------
# normal available: 246
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_006481.jpg', '2011_001800.jpg', '2008_008628.jpg', '2009_004364.jpg', '2009_005118.jpg']
# probes_per_block : ['2008_006481.jpg', '2011_001800.jpg', '2008_008628.jpg', '2009_004364.jpg', '2009_005118.jpg', '2008_000704.jpg', '2011_000628.jpg', '2010_001118.jpg', '2008_000916.jpg']
# probes:  [['2009_000523.jpg', '2008_008331.jpg', '2010_004753.jpg', '2008_005123.jpg', '2009_001975.jpg', '2011_001624.jpg', '2008_008263.jpg', '2008_002372.jpg', '2010_005785.jpg'], ['2010_003943.jpg', '2008_002725.jpg', '2009_003351.jpg', '2010_002742.jpg', '2010_003861.jpg', '2008_007388.jpg', '2008_007664.jpg', '2011_002509.jpg', '2008_003180.jpg'], ['2011_002558.jpg', '2008_000151.jpg', '2010_002956.jpg', '2008_005978.jpg', '2009_003686.jpg', '2008_006452.jpg', '2009_000716.jpg', '2011_002911.jpg', '2011_003145.jpg'], ['2008_006481.jpg', '2011_001800.jpg', '2008_008628.jpg', '2009_004364.jpg', '2009_005118.jpg', '2008_000704.jpg', '2011_000628.jpg', '2010_001118.jpg', '2008_000916.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bus', ' boat', ' car', nan, nan, 34.403914620094966, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' sofa', ' bottle', ' person', nan, 29.608026491553932, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 29.9571992215138, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 4 Critical
# image 10 Target Present
# image 16 Critical
# image 21 Target Present
# image 23 Target Present
# image 25 Target Present
# image 30 Target Absent
# image 32 Critical
# image 39 Target Absent
# image 45 Target Absent
# image 51 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 10, 21, 23, 25, 30, 39, 45, 51]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 1
# absent_crit 2
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2008_007208.jpg', '2010_002603.jpg']
# critical absent set:  ['2009_003232.jpg', '2010_002393.jpg', '2008_005750.jpg', '2008_000274.jpg']
# ---------------------------------------------------
# normal available: 198
# present_critical_per_block: ['2008_007208.jpg']
# absent_critical_per_block: ['2010_002393.jpg', '2009_003232.jpg']
# critical_present:  [['2008_007208.jpg']]
# critical_absent:  [['2010_002393.jpg', '2009_003232.jpg']]
# critical_probes_used:  ['2008_007208.jpg', '2010_002393.jpg', '2009_003232.jpg']
# probes_per_block : ['2008_000734.jpg', '2008_002899.jpg', '2008_005903.jpg']
# probes_per_block : ['2008_000734.jpg', '2008_002899.jpg', '2008_005903.jpg', '2008_004893.jpg', '2009_004984.jpg', '2008_000952.jpg']
# probes:  [['2009_000523.jpg', '2008_008331.jpg', '2010_004753.jpg', '2008_005123.jpg', '2009_001975.jpg', '2011_001624.jpg', '2008_008263.jpg', '2008_002372.jpg', '2010_005785.jpg'], ['2010_003943.jpg', '2008_002725.jpg', '2009_003351.jpg', '2010_002742.jpg', '2010_003861.jpg', '2008_007388.jpg', '2008_007664.jpg', '2011_002509.jpg', '2008_003180.jpg'], ['2011_002558.jpg', '2008_000151.jpg', '2010_002956.jpg', '2008_005978.jpg', '2009_003686.jpg', '2008_006452.jpg', '2009_000716.jpg', '2011_002911.jpg', '2011_003145.jpg'], ['2008_006481.jpg', '2011_001800.jpg', '2008_008628.jpg', '2009_004364.jpg', '2009_005118.jpg', '2008_000704.jpg', '2011_000628.jpg', '2010_001118.jpg', '2008_000916.jpg'], ['2008_000734.jpg', '2008_002899.jpg', '2008_005903.jpg', '2008_004893.jpg', '2009_004984.jpg', '2008_000952.jpg']]
# Present Used in block:  3
# Absent Used in block 3
# Critical probes counter:  3
# Present Critical:  1
# Absent Critical:  2
# List of critical trials without probe:
# normal in this block:  51
# normal used overall:  243
# critical_probes_used ['2008_007208.jpg', '2010_002393.jpg', '2009_003232.jpg']
# sequence final does not exist
# x 3
# present_critical_per_block 1
# absent_critical_per_block 2
# ciao2 0
# ciao2 0
# ciao2 0
# ciao2 0
# ciao2 0
# ------------------
# [3, 6, 9, 18, 27, 29, 37, 45, 51] 9
# gap_check:  [6, 29, 45]
# 9
# (3, 'Target Present')
# (6, 'Critical Absent')
# (9, 'Target Absent')
# (18, 'Target Present')
# (27, 'Target Present')
# (29, 'Critical Present')
# (37, 'Target Absent')
# (45, 'Critical Absent')
# (51, 'Target Absent')
# [(3, 'Target Present'), (6, 'Critical Absent'), (9, 'Target Absent'), (18, 'Target Present'), (27, 'Target Present'), (29, 'Critical Present'), (37, 'Target Absent'), (45, 'Critical Absent'), (51, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 6 Critical Absent
# image 9 Target Absent
# image 18 Target Present
# image 27 Target Present
# image 29 Critical Present
# image 37 Target Absent
# image 45 Critical Absent
# image 51 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 6, 9, 18, 27, 29, 37, 45, 51]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 1
# absent_crit 2
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2008_007208.jpg', '2010_002603.jpg']
# critical absent set:  ['2009_003232.jpg', '2010_002393.jpg', '2008_005750.jpg', '2008_000274.jpg']
# ---------------------------------------------------
# normal available: 147
# present_critical_per_block: ['2010_002603.jpg']
# absent_critical_per_block: ['2008_000274.jpg', '2008_005750.jpg']
# critical_present:  [['2008_007208.jpg'], ['2010_002603.jpg']]
# critical_absent:  [['2010_002393.jpg', '2009_003232.jpg'], ['2008_000274.jpg', '2008_005750.jpg']]
# critical_probes_used:  ['2008_007208.jpg', '2010_002393.jpg', '2009_003232.jpg', '2010_002603.jpg', '2008_000274.jpg', '2008_005750.jpg']
# probes_per_block : ['2011_001382.jpg', '2008_004858.jpg', '2009_002750.jpg']
# probes_per_block : ['2011_001382.jpg', '2008_004858.jpg', '2009_002750.jpg', '2008_007970.jpg', '2008_003378.jpg', '2008_005472.jpg']
# probes:  [['2009_000523.jpg', '2008_008331.jpg', '2010_004753.jpg', '2008_005123.jpg', '2009_001975.jpg', '2011_001624.jpg', '2008_008263.jpg', '2008_002372.jpg', '2010_005785.jpg'], ['2010_003943.jpg', '2008_002725.jpg', '2009_003351.jpg', '2010_002742.jpg', '2010_003861.jpg', '2008_007388.jpg', '2008_007664.jpg', '2011_002509.jpg', '2008_003180.jpg'], ['2011_002558.jpg', '2008_000151.jpg', '2010_002956.jpg', '2008_005978.jpg', '2009_003686.jpg', '2008_006452.jpg', '2009_000716.jpg', '2011_002911.jpg', '2011_003145.jpg'], ['2008_006481.jpg', '2011_001800.jpg', '2008_008628.jpg', '2009_004364.jpg', '2009_005118.jpg', '2008_000704.jpg', '2011_000628.jpg', '2010_001118.jpg', '2008_000916.jpg'], ['2008_000734.jpg', '2008_002899.jpg', '2008_005903.jpg', '2008_004893.jpg', '2009_004984.jpg', '2008_000952.jpg'], ['2011_001382.jpg', '2008_004858.jpg', '2009_002750.jpg', '2008_007970.jpg', '2008_003378.jpg', '2008_005472.jpg']]
# Present Used in block:  3
# Absent Used in block 3
# Critical probes counter:  3
# Present Critical:  1
# Absent Critical:  2
# List of critical trials without probe:
# normal in this block:  51
# normal used overall:  294
# critical_probes_used ['2008_007208.jpg', '2010_002393.jpg', '2009_003232.jpg', '2010_002603.jpg', '2008_000274.jpg', '2008_005750.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 6 Critical Absent
# image 9 Target Absent
# image 18 Target Present
# image 27 Target Present
# image 29 Critical Present
# image 37 Target Absent
# image 45 Critical Absent
# image 51 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 6, 9, 18, 27, 29, 37, 45, 51]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2008_007208.jpg', '2010_002603.jpg']
# critical absent set:  ['2009_003232.jpg', '2010_002393.jpg', '2008_005750.jpg', '2008_000274.jpg']
# ---------------------------------------------------
# normal available: 96
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2008_007208.jpg'], ['2010_002603.jpg']]
# critical_absent:  [['2010_002393.jpg', '2009_003232.jpg'], ['2008_000274.jpg', '2008_005750.jpg']]
# critical_probes_used:  ['2008_007208.jpg', '2010_002393.jpg', '2009_003232.jpg', '2010_002603.jpg', '2008_000274.jpg', '2008_005750.jpg']
jpg', '2008_007664.jpg', '2011_002509.jpg', '2008_003180.jpg'], ['2011_002558.jpg', '2008_000151.jpg', '2010_002956.jpg', '2008_005978.jpg', '2009_003686.jpg', '2008_006452.jpg', '2009_000716.jpg', '2011_002911.jpg', '2011_003145.jpg'], ['2008_006481.jpg', '2011_001800.jpg', '2008_008628.jpg', '2009_004364.jpg', '2009_005118.jpg', '2008_000704.jpg', '2011_000628.jpg', '2010_001118.jpg', '2008_000916.jpg'], ['2008_000734.jpg', '2008_002899.jpg', '2008_005903.jpg', '2008_004893.jpg', '2009_004984.jpg', '2008_000952.jpg'], ['2011_001382.jpg', '2008_004858.jpg', '2009_002750.jpg', '2008_007970.jpg', '2008_003378.jpg', '2008_005472.jpg'], ['2008_002062.jpg', '2008_006998.jpg', '2008_004269.jpg', '2011_001613.jpg', '2010_003280.jpg', '2011_001959.jpg', '2008_001098.jpg', '2008_006072.jpg', '2010_001691.jpg'], ['2009_000539.jpg', '2010_005894.jpg', '2008_008229.jpg', '2008_006844.jpg', '2008_001333.jpg', '2008_002736.jpg', '2008_000196.jpg', '2008_002084.jpg', '2010_005542.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' dog', nan, nan, nan, 32.14242713491097, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 29.547306113597852, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' diningtable', ' bottle', nan, nan, 38.97264238893902, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  390
# critical_probes_used ['2008_007208.jpg', '2010_002393.jpg', '2009_003232.jpg', '2010_002603.jpg', '2008_000274.jpg', '2008_005750.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 4 Target Absent
# image 9 Target Present
# image 13 Critical
# image 16 Target Present
# image 20 Target Absent
# image 21 Target Present
# image 29 Target Present
# image 32 Target Absent
# image 36 Critical
# image 41 Critical
# image 50 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 4, 9, 16, 20, 21, 29, 32, 50]
# 60 60
# len(trials):  1920

# %%
print len(normal_no_probe_before)
print len(normal_used)
print len(normal_no_probe_before) == len(set(normal_used))
print len(target_present_before)
print len(present_used)
print len(target_present_before) == len(set(present_used))
print len(target_absent_before)
print len(absent_used)
print len(target_absent_before) == len(set(absent_used))

#the following is not a good check
print len(set(critical_trials_before)) == len(set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes))

print set(critical_trials_before) == set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes)

print len(low_four)
print len(low_one) == len(low_two) == len(low_three) == len(low_four) == len(high_one) == len(high_two) == len(high_three) == len(high_four)
print len(set(low_one) & set(low_two) & set(low_three) & set(low_four) & set(high_one) & set(high_two) & set(high_three) & set(high_four))
# Out:
# 390
# 390
# True
# 36
# 34
# False
# 36
# 32
# False
# True
# True
# 60
# True
# 0

# %%
for i in range(len(trials.keys())):
    trials[i+1].append(i/60+1)

import pickle
with open('../config/randomization.pik', 'wb') as of:
    pickle.dump(trials,of)

# %%
sorted_dict =sorted(trials.iteritems())
print sorted_dict[0][1]
# Out:
# [' bird', nan, nan, nan, nan, 9.57686770873812, 'low', ' bird', 'NA', 'No Target', 'Normal', '2011_001959.jpg', 1]

# %%
tone_Hz1, sound_onset1 = tone_properties()
tone_Hz2, sound_onset2 = tone_properties()
tone_Hz3, sound_onset3 = tone_properties()
tone_Hz4, sound_onset4 = tone_properties()
tone_Hz = tone_Hz1+tone_Hz2+tone_Hz3+tone_Hz4
sound_onset = sound_onset1 + sound_onset2 + sound_onset3 + sound_onset4
# Out:
# ['tone1', 'tone2', 'tone1']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone1']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone1']
# ['tone2', 'tone2', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone2', 'tone2', 'tone2']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# ['tone1', 'tone2', 'tone1']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# ['tone2', 'tone1', 'tone2']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone2']
# ['tone2', 'tone1', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone2']
# ['tone2', 'tone1', 'tone1']
# ----------------------
# ['tone1', 'tone1', 'tone1']
# ['tone2', 'tone2', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6

# %%
print len(tone_Hz)
# Out:
# 96

# %%
# %pdb
prova = []
tone_counter = 0
for i in sorted(trials.keys()):
    if 'Critical' in trials[i]:
        trials[i].append(tone_Hz[tone_counter])
        trials[i].append(sound_onset[tone_counter])
        tone_counter = tone_counter + 1
    else:
        trials[i].append('No tone')
        trials[i].append(-999)
# Out:
# Automatic pdb calling has been turned ON

# %%
df = pd.DataFrame.from_dict(trials)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','image_name','block']
df.TS = df.TS.astype('float')
df.to_csv(mypath + '../Config/randomization_1.csv')

# %%
df[df['trial_type']=='Critical']
# Out:
#              Cat.1         Cat.2         Cat.3         Cat.4    Cat.5  \
# 7        aeroplane           NaN           NaN           NaN      NaN
# 38          person           NaN           NaN           NaN      NaN
# 52     pottedplant          sofa         chair           NaN      NaN
# 70          person     aeroplane           NaN           NaN      NaN
# 76          person          bird          boat           NaN      NaN
# 90          person         horse           NaN           NaN      NaN
# 127           sofa        bottle   pottedplant     tvmonitor    chair
# 158         person         chair        bottle     tvmonitor      NaN
# 172            car          boat        person           NaN      NaN
# 190    pottedplant           NaN           NaN           NaN      NaN
# 196          chair           cat           NaN           NaN      NaN
# 210            dog           NaN           NaN           NaN      NaN
# 250         person         chair           cat           NaN      NaN
# 258            cat           NaN           NaN           NaN      NaN
# 278            car        person           bus           NaN      NaN
# 346          horse           NaN           NaN           NaN      NaN
# 351           bird           NaN           NaN           NaN      NaN
# 357           sofa           dog           NaN           NaN      NaN
# 370            car           NaN           NaN           NaN      NaN
# 378         bottle           NaN           NaN           NaN      NaN
# 398           boat           NaN           NaN           NaN      NaN
# 466           sofa         chair        person           NaN      NaN
# 471    pottedplant        person           dog           NaN      NaN
# 477           bird           NaN           NaN           NaN      NaN
# 495           boat           NaN           NaN           NaN      NaN
# 505           sofa         chair           NaN           NaN      NaN
# 530         person           NaN           NaN           NaN      NaN
# 550            dog        bottle           NaN           NaN      NaN
# 567         person         horse           dog           NaN      NaN
# 598    pottedplant        person         chair     motorbike     boat
# 615            car     motorbike        person           NaN      NaN
# 625           bird           NaN           NaN           NaN      NaN
# 650      aeroplane          boat           NaN           NaN      NaN
# 670    pottedplant           NaN           NaN           NaN      NaN
# 687            car           NaN           NaN           NaN      NaN
# 718         bottle           NaN           NaN           NaN      NaN
# 731      tvmonitor          sofa        bottle        person      NaN
# 737         person         train           car           NaN      NaN
# 753    pottedplant          sofa         chair     tvmonitor      NaN
# 809    pottedplant          sofa           NaN           NaN      NaN
# 824         person           cat           NaN           NaN      NaN
# 836      aeroplane           NaN           NaN           NaN      NaN
# 851            dog           NaN           NaN           NaN      NaN
# 857           bird           NaN           NaN           NaN      NaN
# 873          horse           NaN           NaN           NaN      NaN
# 929      tvmonitor   diningtable           cat           NaN      NaN
# 944    pottedplant           car         chair       bicycle   person
# 956         person          boat           NaN           NaN      NaN
# 989    pottedplant           NaN           NaN           NaN      NaN
# 996            car        person           NaN           NaN      NaN
# 1020        person          boat           NaN           NaN      NaN
# 1021         horse           NaN           NaN           NaN      NaN
# 1031   pottedplant        person         chair     motorbike     boat
# 1039           cat           NaN           NaN           NaN      NaN
# 1109        person           car           NaN           NaN      NaN
# 1116           car           dog        person           NaN      NaN
# 1140        person         chair          bird           NaN      NaN
# 1141        bottle           NaN           NaN           NaN      NaN
# 1151        person        bottle           NaN           NaN      NaN
# 1159        person           cat           NaN           NaN      NaN
# 1223        person        bottle           NaN           NaN      NaN
# 1231          boat           NaN           NaN           NaN      NaN
# 1235          sofa        person     tvmonitor           NaN      NaN
# 1272           dog           NaN           NaN           NaN      NaN
# 1277          bird           NaN           NaN           NaN      NaN
# 1302          sofa         chair           NaN           NaN      NaN
# 1343         horse           NaN           NaN           NaN      NaN
# 1351     aeroplane           NaN           NaN           NaN      NaN
# 1355        person         chair           NaN           NaN      NaN
# 1392        person          sofa           NaN           NaN      NaN
# 1397   pottedplant        person         chair   diningtable     boat
# 1422           car     aeroplane           NaN           NaN      NaN
# 1456           car        person           NaN           NaN      NaN
# 1477     aeroplane           NaN           NaN           NaN      NaN
# 1494         chair   diningtable        bottle           NaN      NaN
# 1505          boat           NaN           NaN           NaN      NaN
# 1517           bus          boat           car           NaN      NaN
# 1533     tvmonitor          sofa        bottle        person      NaN
# 1576   pottedplant          sofa           NaN           NaN      NaN
# 1597          bird           NaN           NaN           NaN      NaN
# 1614         horse           NaN           NaN           NaN      NaN
# 1625          bird           NaN           NaN           NaN      NaN
# 1637           cat           NaN           NaN           NaN      NaN
# 1653           car        person           NaN           NaN      NaN
# 1687     aeroplane           NaN           NaN           NaN      NaN
# 1710        person         chair           NaN           NaN      NaN
# 1726   pottedplant         chair           NaN           NaN      NaN
# 1754   pottedplant           NaN           NaN           NaN      NaN
# 1777          sofa           NaN           NaN           NaN      NaN
# 1782         chair   diningtable           NaN           NaN      NaN
# 1807          boat           NaN           NaN           NaN      NaN
# 1830           dog           NaN           NaN           NaN      NaN
# 1846         horse           NaN           NaN           NaN      NaN
# 1874        person   diningtable        bottle           NaN      NaN
# 1897        person     aeroplane           NaN           NaN      NaN
# 1902        person           dog           NaN           NaN      NaN
#
#              TS  Load      exemplar    question  present_absent trial_type  \
# 7     14.341895   low     aeroplane          NA       No Target   Critical
# 38    20.358449   low        person          NA       No Target   Critical
# 52    18.511888   low   pottedplant          NA       No Target   Critical
# 70    31.885878  high     aeroplane          NA       No Target   Critical
# 76    31.913410  high          bird          NA       No Target   Critical
# 90    35.669132  high         horse          NA       No Target   Critical
# 127   33.937776  high   pottedplant          NA       No Target   Critical
# 158   34.633056  high        bottle          NA       No Target   Critical
# 172   32.759267  high          boat          NA       No Target   Critical
# 190   20.395430   low   pottedplant          NA       No Target   Critical
# 196   19.797171   low           cat          NA       No Target   Critical
# 210   18.045036   low           dog          NA       No Target   Critical
# 250   30.878848  high           cat          NA       No Target   Critical
# 258   31.541664  high           cat         cat  Target Present   Critical
# 278   35.069419  high           car          NA       No Target   Critical
# 346   19.789006   low         horse          NA       No Target   Critical
# 351   17.497070   low          bird          NA       No Target   Critical
# 357   19.188834   low          sofa          NA       No Target   Critical
# 370   18.787451   low           car          NA       No Target   Critical
# 378   14.593337   low        bottle      bottle  Target Present   Critical
# 398   19.685752   low          boat          NA       No Target   Critical
# 466   36.443792  high          sofa          NA       No Target   Critical
# 471   30.007374  high           dog          NA       No Target   Critical
# 477   32.065096  high          bird          NA       No Target   Critical
# 495   19.264338   low          boat          NA       No Target   Critical
# 505   19.836492   low          sofa        sofa  Target Present   Critical
# 530   21.235360   low        person          NA       No Target   Critical
# 550   41.997145  high           dog          NA       No Target   Critical
# 567   31.372460  high         horse          NA       No Target   Critical
# 598   31.580490  high          boat          NA       No Target   Critical
# 615   31.408722  high           car          NA       No Target   Critical
# 625   29.272655  high          bird        bird  Target Present   Critical
# 650   29.287349  high     aeroplane          NA       No Target   Critical
# 670   21.255888   low   pottedplant          NA       No Target   Critical
# 687   18.597982   low           car          NA       No Target   Critical
# 718   17.883135   low        bottle          NA       No Target   Critical
# 731   29.608026  high        bottle          NA       No Target   Critical
# 737   31.026857  high           car          NA       No Target   Critical
# 753   29.464580  high   pottedplant          NA       No Target   Critical
# 809   18.967723   low   pottedplant          NA       No Target   Critical
# 824   20.139878   low        person          NA       No Target   Critical
# 836   20.272205   low     aeroplane          NA       No Target   Critical
# 851   16.693373   low           dog          NA       No Target   Critical
# 857   14.343347   low          bird          NA       No Target   Critical
# 873   13.879634   low         horse          NA       No Target   Critical
# 929   29.842923  high           cat          NA       No Target   Critical
# 944   30.133244  high   pottedplant          NA       No Target   Critical
# 956   31.261038  high          boat          NA       No Target   Critical
# 989   20.584163   low   pottedplant          NA       No Target   Critical
# 996   21.052977   low           car          NA       No Target   Critical
# 1020  17.698167   low          boat          NA       No Target   Critical
# 1021  31.514886  high         horse      person   Target Absent   Critical
# 1031  31.580490  high          boat        boat  Target Present   Critical
# 1039  32.660664  high           cat          NA       No Target   Critical
# 1109  28.839742  high        person          NA       No Target   Critical
# 1116  29.763552  high        person          NA       No Target   Critical
# 1140  29.630121  high          bird          NA       No Target   Critical
# 1141  20.832522   low        bottle         dog   Target Absent   Critical
# 1151  19.869099   low        bottle      bottle  Target Present   Critical
# 1159  20.139878   low        person          NA       No Target   Critical
# 1223  30.936879  high        person          NA       No Target   Critical
# 1231  34.708650  high          boat          NA       No Target   Critical
# 1235  31.149256  high          sofa          NA       No Target   Critical
# 1272  18.981598   low           dog          NA       No Target   Critical
# 1277  13.908448   low          bird          NA       No Target   Critical
# 1302  19.836492   low          sofa          NA       No Target   Critical
# 1343  18.720729   low         horse          NA       No Target   Critical
# 1351  20.559862   low     aeroplane          NA       No Target   Critical
# 1355  20.224140   low        person          NA       No Target   Critical
# 1392  29.639010  high        person          NA       No Target   Critical
# 1397  35.383634  high   pottedplant          NA       No Target   Critical
# 1422  32.224521  high     aeroplane          NA       No Target   Critical
# 1456  17.856306   low           car          NA       No Target   Critical
# 1477  18.000362   low     aeroplane          NA       No Target   Critical
# 1494  20.038120   low        bottle          NA       No Target   Critical
# 1505  29.957199  high          boat          NA       No Target   Critical
