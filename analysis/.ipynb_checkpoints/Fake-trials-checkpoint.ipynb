# %%
import pickle

# %%
import pickle

with open('../config/randomization.pik', 'r') as of:
    trials_raw = pickle.load(of)

trials = {}

cols = ['cat_1','cat_2','cat_3','cat_4','cat_5','TS','load','exemplar','question','present_absent','trial_type','tone_hz','tone_onset','image_name','block']

for k in trials_raw.keys():
    l = trials_raw[k]
    trial_dict = {}
    for i in range(len(l)):
        trial_dict[cols[i]] = l[i]
    trials[k] = trial_dict

# %%
trials
# Out:
# {1: {'TS': 20.850125265290927,
#   'block': 1,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2010_002645.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  2: {'TS': 14.127469618562607,
#   'block': 1,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2008_002899.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  3: {'TS': 15.731962722166625,
#   'block': 1,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2008_003369.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  4: {'TS': 18.23776823647068,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' bicycle',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_005978.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'Target Present',
#   'question': ' person',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  5: {'TS': 16.197035825449316,
#   'block': 1,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2010_005785.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  6: {'TS': 20.470663952413528,
#   'block': 1,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2008_002504.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  7: {'TS': 19.901616892338367,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' boat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2009_001406.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  8: {'TS': 19.194815950035924,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' boat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2010_001036.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'Target Absent',
#   'question': ' dog',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  9: {'TS': 21.05297682386103,
#   'block': 1,
#   'cat_1': ' car',
#   'cat_2': ' person',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2010_001993.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  10: {'TS': 20.561279009327844,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' chair',
#   'cat_3': ' diningtable',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2010_001907.jpg',
#   'load': 'low',
#   'onset': 500,
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 500,
#   'trial_type': 'Critical'},
#  11: {'TS': 20.15804441055767,
#   'block': 1,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2008_007096.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  12: {'TS': 20.139877805151375,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' cat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2009_002439.jpg',
#   'load': 'low',
#   'present_absent': 'Target Absent',
#   'question': ' horse',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  13: {'TS': 19.86909924741182,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' bottle',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_004814.jpg',
#   'load': 'low',
#   'present_absent': 'Target Present',
#   'question': ' bottle',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  14: {'TS': 18.981598230274844,
#   'block': 1,
#   'cat_1': ' dog',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2009_003209.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  15: {'TS': 17.856305662122608,
#   'block': 1,
#   'cat_1': ' car',
#   'cat_2': ' person',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2009_002711.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  16: {'TS': 20.58416256718508,
#   'block': 1,
#   'cat_1': ' pottedplant',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2008_004171.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  17: {'TS': 19.598131175056185,
#   'block': 1,
#   'cat_1': ' horse',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_000219.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  18: {'TS': 18.000361854332464,
#   'block': 1,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2009_002888.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  19: {'TS': 20.194433628678283,
#   'block': 1,
#   'cat_1': ' dog',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2009_002803.jpg',
#   'load': 'low',
#   'present_absent': 'Target Present',
#   'question': ' dog',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  20: {'TS': 21.22948510797022,
#   'block': 1,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2008_001495.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  21: {'TS': 16.98544233464372,
#   'block': 1,
#   'cat_1': ' chair',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2009_004737.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  22: {'TS': 9.156390286160866,
#   'block': 1,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2011_000293.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  23: {'TS': 8.062836492776528,
#   'block': 1,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2008_004893.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  24: {'TS': 8.17124474061747,
#   'block': 1,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2008_000151.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  25: {'TS': 18.288477341906038,
#   'block': 1,
#   'cat_1': ' sofa',
#   'cat_2': ' cat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2010_004425.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  26: {'TS': 20.21626352293297,
#   'block': 1,
#   'cat_1': ' tvmonitor',
#   'cat_2': ' sofa',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2010_005054.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  27: {'TS': 19.264337675075122,
#   'block': 1,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2009_001723.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 132,
#   'trial_type': 'Critical'},
#  28: {'TS': 16.86296621161062,
#   'block': 1,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2010_001691.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  29: {'TS': 19.75925599841011,
#   'block': 1,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2008_000952.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  30: {'TS': 20.712898768714968,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' dog',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2008_005046.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  31: {'TS': 20.166020393270408,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' dog',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_002116.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone2',
#   'tone_onset': 365,
#   'trial_type': 'Critical'},
#  32: {'TS': 17.316646037114566,
#   'block': 1,
#   'cat_1': ' sofa',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2011_000224.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  33: {'TS': 16.456101242175052,
#   'block': 1,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2008_000839.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  34: {'TS': 10.236635760901883,
#   'block': 1,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2010_004175.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  35: {'TS': 20.413253715842107,
#   'block': 1,
#   'cat_1': ' chair',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2008_004412.jpg',
#   'load': 'low',
#   'present_absent': 'Target Absent',
#   'question': ' horse',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  36: {'TS': 20.465741194973702,
#   'block': 1,
#   'cat_1': ' bottle',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_004607.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  37: {'TS': 16.137458117206307,
#   'block': 1,
#   'cat_1': ' dog',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2008_006452.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  38: {'TS': 19.836491630222174,
#   'block': 1,
#   'cat_1': ' sofa',
#   'cat_2': ' chair',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2009_002325.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  39: {'TS': 17.49302399164143,
#   'block': 1,
#   'cat_1': ' pottedplant',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2009_001975.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  40: {'TS': 17.0559093734335,
#   'block': 1,
#   'cat_1': ' sofa',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_006784.jpg',
#   'load': 'low',
#   'present_absent': 'Target Present',
#   'question': ' sofa',
#   'tone_hz': 'tone1',
#   'tone_onset': 441,
#   'trial_type': 'Critical'},
#  41: {'TS': 20.155193047230767,
#   'block': 1,
#   'cat_1': ' tvmonitor',
#   'cat_2': ' chair',
#   'cat_3': ' person',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2010_003287.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  42: {'TS': 14.343346792518373,
#   'block': 1,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2010_001159.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  43: {'TS': 19.675826944132364,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_001205.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  44: {'TS': 14.300464691841311,
#   'block': 1,
#   'cat_1': ' horse',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2010_001451.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  45: {'TS': 18.708497724634334,
#   'block': 1,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2008_000163.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  46: {'TS': 17.350665469404078,
#   'block': 1,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2008_008263.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  47: {'TS': 16.146154777978307,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' boat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2011_002558.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  48: {'TS': 20.48716672648194,
#   'block': 1,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2010_005437.jpg',
#   'load': 'low',
#   'present_absent': 'Target Absent',
#   'question': ' cat',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  49: {'TS': 20.8325215532547,
#   'block': 1,
#   'cat_1': ' bottle',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2009_002521.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  50: {'TS': 18.259900940752694,
#   'block': 1,
#   'cat_1': ' bottle',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_006072.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  51: {'TS': 19.24976137409617,
#   'block': 1,
#   'cat_1': ' pottedplant',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2011_002453.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  52: {'TS': 15.574047189150072,
#   'block': 1,
#   'cat_1': ' sofa',
#   'cat_2': ' tvmonitor',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2009_003373.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  53: {'TS': 19.735592352687934,
#   'block': 1,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2011_001432.jpg',
#   'load': 'low',
#   'present_absent': 'Target Absent',
#   'question': ' sofa',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  54: {'TS': 19.107696549923208,
#   'block': 1,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2009_001894.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  55: {'TS': 20.120761243201123,
#   'block': 1,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2010_004791.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  56: {'TS': 19.91230101528729,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_008395.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  57: {'TS': 18.135096838925413,
#   'block': 1,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2010_000616.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  58: {'TS': 18.96772267222304,
#   'block': 1,
#   'cat_1': ' pottedplant',
#   'cat_2': ' sofa',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2011_001005.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  59: {'TS': 16.65124246053083,
#   'block': 1,
#   'cat_1': ' person',
#   'cat_2': ' boat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2009_004888.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  60: {'TS': 15.830708942989276,
#   'block': 1,
#   'cat_1': ' chair',
#   'cat_2': ' diningtable',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2010_004231.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  61: {'TS': 32.75926741884376,
#   'block': 2,
#   'cat_1': ' car',
#   'cat_2': ' boat',
#   'cat_3': ' person',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2008_000833.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone2',
#   'tone_onset': 926,
#   'trial_type': 'Critical'},
#  62: {'TS': 29.201869461183065,
#   'block': 2,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2008_005750.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  63: {'TS': 31.62452384083404,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' sofa',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2011_001440.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  64: {'TS': 29.806819625699735,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' sofa',
#   'cat_3': ' chair',
#   'cat_4': ' diningtable',
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2011_000530.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  65: {'TS': 33.46218479046818,
#   'block': 2,
#   'cat_1': ' car',
#   'cat_2': ' cat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2008_000619.jpg',
#   'load': 'high',
#   'present_absent': 'Target Present',
#   'question': ' cat',
#   'tone_hz': 'tone2',
#   'tone_onset': 5,
#   'trial_type': 'Critical'},
#  66: {'TS': 32.97739588330027,
#   'block': 2,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2010_006033.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  67: {'TS': 35.70470893485066,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' boat',
#   'cat_3': ' car',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2010_002702.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  68: {'TS': 30.51535276170641,
#   'block': 2,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2008_004690.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  69: {'TS': 31.65115644279944,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' train',
#   'cat_3': ' sofa',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2010_001586.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  70: {'TS': 28.91651536968804,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' bottle',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_004991.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  71: {'TS': 30.39404844580157,
#   'block': 2,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2008_002672.jpg',
#   'load': 'high',
#   'present_absent': 'Target Absent',
#   'question': ' cat',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  72: {'TS': 29.314233597971626,
#   'block': 2,
#   'cat_1': ' bird',
#   'cat_2': ' boat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2008_006481.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  73: {'TS': 30.95304328989037,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' aeroplane',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2011_001800.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  74: {'TS': 31.26103763923315,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' boat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2008_005526.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  75: {'TS': 30.133244112833108,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' car',
#   'cat_3': ' chair',
#   'cat_4': ' bicycle',
#   'cat_5': ' person',
#   'exemplar': ' pottedplant',
#   'image_name': '2010_003729.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  76: {'TS': 37.22381580448725,
#   'block': 2,
#   'cat_1': ' tvmonitor',
#   'cat_2': ' chair',
#   'cat_3': ' sofa',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2011_001304.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  77: {'TS': 29.00835901633089,
#   'block': 2,
#   'cat_1': ' car',
#   'cat_2': ' person',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2009_000021.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  78: {'TS': 28.968465057520145,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' sofa',
#   'cat_3': ' chair',
#   'cat_4': ' diningtable',
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2009_002571.jpg',
#   'load': 'high',
#   'present_absent': 'Target Absent',
#   'question': ' person',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  79: {'TS': 30.20884285223731,
#   'block': 2,
#   'cat_1': ' car',
#   'cat_2': ' train',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2008_008681.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  80: {'TS': 30.530489775112553,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2009_000565.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  81: {'TS': 31.7742392698987,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' chair',
#   'cat_3': ' motorbike',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2009_004849.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  82: {'TS': 35.38363353726925,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' person',
#   'cat_3': ' chair',
#   'cat_4': ' diningtable',
#   'cat_5': ' boat',
#   'exemplar': ' pottedplant',
#   'image_name': '2011_001221.jpg',
#   'load': 'high',
#   'present_absent': 'Target Absent',
#   'question': ' car',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  83: {'TS': 39.79411022613925,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_003193.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  84: {'TS': 30.182885716527558,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' aeroplane',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2011_002193.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  85: {'TS': 29.77854418273715,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' cat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2011_001116.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  86: {'TS': 29.176311484999022,
#   'block': 2,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2008_000192.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  87: {'TS': 29.26546246503357,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2011_002555.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  88: {'TS': 28.936239221739456,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_006912.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  89: {'TS': 33.702921971939176,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_008229.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  90: {'TS': 37.710719022258736,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' person',
#   'cat_3': ' chair',
#   'cat_4': ' diningtable',
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2008_000041.jpg',
#   'load': 'high',
#   'present_absent': 'Target Present',
#   'question': ' pottedplant',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  91: {'TS': 32.179769175040214,
#   'block': 2,
#   'cat_1': ' tvmonitor',
#   'cat_2': ' chair',
#   'cat_3': ' bottle',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_000495.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  92: {'TS': 35.696632302033265,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_002725.jpg',
#   'load': 'high',
#   'present_absent': 'Target Absent',
#   'question': ' bottle',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  93: {'TS': 29.875362071673013,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_003805.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  94: {'TS': 34.96752773409758,
#   'block': 2,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2010_002620.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  95: {'TS': 35.13485651284549,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' chair',
#   'cat_3': ' bottle',
#   'cat_4': ' diningtable',
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2011_000282.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  96: {'TS': 30.954010715704413,
#   'block': 2,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2009_000466.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  97: {'TS': 34.17783424769062,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' chair',
#   'cat_3': ' diningtable',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2009_000760.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  98: {'TS': 35.92557187315038,
#   'block': 2,
#   'cat_1': ' sofa',
#   'cat_2': ' person',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_000321.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  99: {'TS': 34.31905160776113,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' bicycle',
#   'cat_3': ' boat',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2008_000191.jpg',
#   'load': 'high',
#   'present_absent': 'Target Present',
#   'question': ' boat',
#   'tone_hz': 'tone2',
#   'tone_onset': 727,
#   'trial_type': 'Critical'},
#  100: {'TS': 29.10600637597598,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' person',
#   'cat_3': ' train',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2010_005996.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  101: {'TS': 31.124437166631626,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' sofa',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_004459.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  102: {'TS': 30.80608913442844,
#   'block': 2,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2009_000120.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  103: {'TS': 29.65940712433473,
#   'block': 2,
#   'cat_1': ' boat',
#   'cat_2': ' cow',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2008_002709.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  104: {'TS': 31.142308501142768,
#   'block': 2,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2008_007629.jpg',
#   'load': 'high',
#   'present_absent': 'Target Present',
#   'question': ' aeroplane',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  105: {'TS': 34.04714690528091,
#   'block': 2,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2011_001991.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  106: {'TS': 29.247483266365705,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' sofa',
#   'cat_3': ' chair',
#   'cat_4': ' diningtable',
#   'cat_5': ' tvmonitor',
#   'exemplar': ' pottedplant',
#   'image_name': '2008_004661.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  107: {'TS': 31.79472940313895,
#   'block': 2,
#   'cat_1': ' tvmonitor',
#   'cat_2': ' chair',
#   'cat_3': ' person',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_001576.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  108: {'TS': 29.608002755298447,
#   'block': 2,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2009_002897.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  109: {'TS': 30.42487388731773,
#   'block': 2,
#   'cat_1': ' chair',
#   'cat_2': ' bottle',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2008_005347.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  110: {'TS': 36.443791926636216,
#   'block': 2,
#   'cat_1': ' sofa',
#   'cat_2': ' chair',
#   'cat_3': ' person',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2011_002971.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  111: {'TS': 34.54414482156191,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' aeroplane',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2009_002001.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  112: {'TS': 31.05804957013649,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' person',
#   'cat_3': ' chair',
#   'cat_4': ' dog',
#   'cat_5': ' bottle',
#   'exemplar': ' dog',
#   'image_name': '2008_001862.jpg',
#   'load': 'high',
#   'present_absent': 'Target Present',
#   'question': ' dog',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  113: {'TS': 34.96662806576853,
#   'block': 2,
#   'cat_1': ' pottedplant',
#   'cat_2': ' chair',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2009_000198.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  114: {'TS': 30.657341600370845,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' dog',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2008_006870.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  115: {'TS': 32.480531856762035,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_001278.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  116: {'TS': 29.798629151951733,
#   'block': 2,
#   'cat_1': ' chair',
#   'cat_2': ' cat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2010_003579.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  117: {'TS': 33.478750472719696,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' chair',
#   'cat_3': ' diningtable',
#   'cat_4': ' bottle',
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2010_001682.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  118: {'TS': 36.156012963588545,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' diningtable',
#   'cat_3': ' bottle',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_003635.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  119: {'TS': 32.2651090829965,
#   'block': 2,
#   'cat_1': ' person',
#   'cat_2': ' cat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2008_007913.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  120: {'TS': 29.993781428251964,
#   'block': 2,
#   'cat_1': ' tvmonitor',
#   'cat_2': ' bottle',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_006062.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  121: {'TS': 31.54166437440535,
#   'block': 3,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2010_000536.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  122: {'TS': 40.773121275105424,
#   'block': 3,
#   'cat_1': ' dog',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2008_007057.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  123: {'TS': 29.63929631121964,
#   'block': 3,
#   'cat_1': ' person',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2009_000067.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  124: {'TS': 31.40872195535423,
#   'block': 3,
#   'cat_1': ' car',
#   'cat_2': ' motorbike',
#   'cat_3': ' person',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2008_003844.jpg',
#   'load': 'high',
#   'present_absent': 'Target Present',
#   'question': ' car',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  125: {'TS': 31.397027824172856,
#   'block': 3,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2008_004042.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  126: {'TS': 30.93687927856223,
#   'block': 3,
#   'cat_1': ' person',
#   'cat_2': ' bottle',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2011_002482.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  127: {'TS': 30.035339131770247,
#   'block': 3,
#   'cat_1': ' sofa',
#   'cat_2': ' chair',
#   'cat_3': ' person',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_006841.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  128: {'TS': 31.463677231105994,
#   'block': 3,
#   'cat_1': ' sofa',
#   'cat_2': ' person',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2009_000995.jpg',
#   'load': 'high',
#   'present_absent': 'Target Absent',
#   'question': ' dog',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  129: {'TS': 33.38111538349955,
#   'block': 3,
#   'cat_1': ' person',
#   'cat_2': ' chair',
#   'cat_3': ' bottle',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2011_002641.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  130: {'TS': 29.36175572031889,
#   'block': 3,
#   'cat_1': ' chair',
#   'cat_2': ' bird',
#   'cat_3': ' diningtable',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2011_001139.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  131: {'TS': 36.207394560965135,
#   'block': 3,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2008_000457.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  132: {'TS': 29.775484131000805,
#   'block': 3,
#   'cat_1': ' person',
#   'cat_2': ' bottle',
#   'cat_3': ' diningtable',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_006663.jpg',
#   'load': 'high',
#   'present_absent': 'Target Absent',
#   'question': ' sofa',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  133: {'TS': 34.072917550349175,
#   'block': 3,
#   'cat_1': ' person',
#   'cat_2': ' bottle',
#   'cat_3': ' diningtable',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2009_000058.jpg',
#   'load': 'high',
#   'present_absent': 'Target Present',
#   'question': ' bottle',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  134: {'TS': 30.24293720929956,
#   'block': 3,
#   'cat_1': ' person',
#   'cat_2': ' aeroplane',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2010_005106.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  135: {'TS': 37.706201599515055,
#   'block': 3,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2011_000631.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  136: {'TS': 35.97296008400705,
#   'block': 3,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2009_004414.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  137: {'TS': 28.939513311425664,
#   'block': 3,
#   'cat_1': ' pottedplant',
#   'cat_2': ' person',
#   'cat_3': ' diningtable',
#   'cat_4': ' bottle',
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2011_001382.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  138: {'TS': 33.27958235579427,
#   'block': 3,
#   'cat_1': ' sofa',
#   'cat_2': ' person',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_007043.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  139: {'TS': 33.64739800555661,
#   'block': 3,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2008_007423.jpg',
#   'load': 'high',
#   'present_absent': 'Target Present',
#   'question': ' bird',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  140: {'TS': 31.31059992348976,
#   'block': 3,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2011_000628.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  141: {'TS': 33.31207272800427,
#   'block': 3,
#   'cat_1': ' person',
#   'cat_2': ' chair',
#   'cat_3': nan,
# ...
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  954: {'TS': 29.514189787401428,
#   'block': 16,
#   'cat_1': ' person',
#   'cat_2': ' sofa',
#   'cat_3': ' cat',
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2010_005606.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  955: {'TS': 37.05291171015417,
#   'block': 16,
#   'cat_1': ' person',
#   'cat_2': ' chair',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2010_002603.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  956: {'TS': 30.141763061562205,
#   'block': 16,
#   'cat_1': ' person',
#   'cat_2': ' horse',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2009_002750.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  957: {'TS': 35.92557187315038,
#   'block': 16,
#   'cat_1': ' sofa',
#   'cat_2': ' person',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_000321.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  958: {'TS': 29.657389969329227,
#   'block': 16,
#   'cat_1': ' person',
#   'cat_2': ' bird',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2010_003724.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  959: {'TS': 33.937775623898794,
#   'block': 16,
#   'cat_1': ' sofa',
#   'cat_2': ' bottle',
#   'cat_3': ' pottedplant',
#   'cat_4': ' tvmonitor',
#   'cat_5': ' chair',
#   'exemplar': ' pottedplant',
#   'image_name': '2011_002814.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  960: {'TS': 35.87217940794205,
#   'block': 16,
#   'cat_1': ' car',
#   'cat_2': ' aeroplane',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2008_000251.jpg',
#   'load': 'high',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  961: {'TS': 20.22413954449369,
#   'block': 17,
#   'cat_1': ' person',
#   'cat_2': ' chair',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_001617.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  962: {'TS': 13.879634097368903,
#   'block': 17,
#   'cat_1': ' horse',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_004624.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  963: {'TS': 20.707877775353552,
#   'block': 17,
#   'cat_1': ' person',
#   'cat_2': ' sofa',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_000972.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  964: {'TS': 16.86296621161062,
#   'block': 17,
#   'cat_1': ' boat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2010_001691.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  965: {'TS': 13.644417789905445,
#   'block': 17,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2009_002604.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  966: {'TS': 18.720728543179284,
#   'block': 17,
#   'cat_1': ' horse',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2009_003686.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone2',
#   'tone_onset': 321,
#   'trial_type': 'Critical'},
#  967: {'TS': 19.09625234571384,
#   'block': 17,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2009_004779.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  968: {'TS': 13.350033322032775,
#   'block': 17,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2010_005101.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  969: {'TS': 16.456101242175052,
#   'block': 17,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2008_000839.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  970: {'TS': 18.41425575439328,
#   'block': 17,
#   'cat_1': ' horse',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_001542.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  971: {'TS': 19.156547420300022,
#   'block': 17,
#   'cat_1': ' horse',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2011_001656.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  972: {'TS': 17.0559093734335,
#   'block': 17,
#   'cat_1': ' sofa',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_006784.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  973: {'TS': 19.7971714164348,
#   'block': 17,
#   'cat_1': ' chair',
#   'cat_2': ' cat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2011_000661.jpg',
#   'load': 'low',
#   'present_absent': 'Target Absent',
#   'question': ' horse',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  974: {'TS': 17.16755806031274,
#   'block': 17,
#   'cat_1': ' bird',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bird',
#   'image_name': '2008_003170.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  975: {'TS': 15.574047189150072,
#   'block': 17,
#   'cat_1': ' sofa',
#   'cat_2': ' tvmonitor',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2009_003373.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  976: {'TS': 16.142562620916582,
#   'block': 17,
#   'cat_1': ' sofa',
#   'cat_2': ' dog',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2009_001774.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  977: {'TS': 16.396955524186414,
#   'block': 17,
#   'cat_1': ' horse',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' horse',
#   'image_name': '2008_000177.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  978: {'TS': 17.350665469404078,
#   'block': 17,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2008_008263.jpg',
#   'load': 'low',
#   'present_absent': 'Target Present',
#   'question': ' aeroplane',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  979: {'TS': 20.423795473772003,
#   'block': 17,
#   'cat_1': ' person',
#   'cat_2': ' bottle',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2008_000398.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  980: {'TS': 20.07468613183729,
#   'block': 17,
#   'cat_1': ' dog',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2010_005885.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  981: {'TS': 13.68599364669666,
#   'block': 17,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2008_005735.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'tone1',
#   'tone_onset': 406,
#   'trial_type': 'Critical'},
#  982: {'TS': 21.005917005737068,
#   'block': 17,
#   'cat_1': ' chair',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2008_006470.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  983: {'TS': 16.656599770121232,
#   'block': 17,
#   'cat_1': ' cat',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' cat',
#   'image_name': '2009_004598.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  984: {'TS': 17.102590259239356,
#   'block': 17,
#   'cat_1': ' dog',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' dog',
#   'image_name': '2009_001568.jpg',
#   'load': 'low',
#   'present_absent': 'Target Absent',
#   'question': ' car',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  985: {'TS': 16.811685000593723,
#   'block': 17,
#   'cat_1': ' car',
#   'cat_2': ' aeroplane',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2009_005036.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  986: {'TS': 20.185339334432726,
#   'block': 17,
#   'cat_1': ' person',
#   'cat_2': ' sofa',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2008_000734.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  987: {'TS': 16.98544233464372,
#   'block': 17,
#   'cat_1': ' chair',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2009_004737.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  988: {'TS': 17.770158360863313,
#   'block': 17,
#   'cat_1': ' pottedplant',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2009_005008.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  989: {'TS': 21.051373291159546,
#   'block': 17,
#   'cat_1': ' person',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_002700.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  990: {'TS': 18.11780279510061,
#   'block': 17,
#   'cat_1': ' chair',
#   'cat_2': ' diningtable',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' chair',
#   'image_name': '2011_002241.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  991: {'TS': 18.13905315137702,
#   'block': 17,
#   'cat_1': ' person',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_001221.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  992: {'TS': 18.29867809750948,
#   'block': 17,
#   'cat_1': ' car',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' car',
#   'image_name': '2008_000501.jpg',
#   'load': 'low',
#   'present_absent': 'Target Absent',
#   'question': ' chair',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  993: {'TS': 21.217669901647128,
#   'block': 17,
#   'cat_1': ' pottedplant',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' pottedplant',
#   'image_name': '2008_005214.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  994: {'TS': 20.358449022039405,
#   'block': 17,
#   'cat_1': ' person',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' person',
#   'image_name': '2008_001367.jpg',
#   'load': 'low',
#   'present_absent': 'Target Absent',
#   'question': ' pottedplant',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  995: {'TS': 16.598874860824477,
#   'block': 17,
#   'cat_1': ' bottle',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2010_002956.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  996: {'TS': 17.316646037114566,
#   'block': 17,
#   'cat_1': ' sofa',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2011_000224.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  997: {'TS': 20.21626352293297,
#   'block': 17,
#   'cat_1': ' tvmonitor',
#   'cat_2': ' sofa',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' sofa',
#   'image_name': '2010_005054.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  998: {'TS': 16.65124246053083,
#   'block': 17,
#   'cat_1': ' person',
#   'cat_2': ' boat',
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' boat',
#   'image_name': '2009_004888.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  999: {'TS': 18.000361854332464,
#   'block': 17,
#   'cat_1': ' aeroplane',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' aeroplane',
#   'image_name': '2009_002888.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  1000: {'TS': 20.96364307633711,
#   'block': 17,
#   'cat_1': ' bottle',
#   'cat_2': nan,
#   'cat_3': nan,
#   'cat_4': nan,
#   'cat_5': nan,
#   'exemplar': ' bottle',
#   'image_name': '2009_002749.jpg',
#   'load': 'low',
#   'present_absent': 'No Target',
#   'question': 'NA',
#   'tone_hz': 'No tone',
#   'tone_onset': -999,
#   'trial_type': 'Normal'},
#  ...}

# %%
10 % 3
# Out:
# 1

# %%
for i in range(10):
    j = i+1
    if j % 3 == 1:
        trials[j]['trial_type'] = 'Critical'
        trials[j]['tone_hz'] = 'tone1'
        trials[j]['tone_onset'] = 500

# %%
trials[1].keys()
# Out:
# ['cat_4',
#  'cat_5',
#  'tone_hz',
#  'cat_1',
#  'cat_2',
#  'cat_3',
#  'question',
#  'TS',
#  'load',
#  'image_name',
#  'exemplar',
#  'tone_onset',
#  'trial_type',
#  'present_absent',
#  'block']

# %%
for k in trials.keys():
    print trials[k]['tone_onset']
# Out:
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 132
# -999
# -999
# -999
# 365
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 441
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 926
# -999
# -999
# -999
# 5
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 727
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 880
# -999
# -999
# -999
# 912
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 977
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 909
# -999
# -999
# -999
# 315
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 370
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 337
# -999
# -999
# 695
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 615
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 786
# -999
# -999
# -999
# 842
# -999
# -999
# -999
# -999
# -999
# 810
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 413
# -999
# -999
# 783
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 607
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 328
# -999
# -999
# -999
# 155
# -999
# -999
# -999
# -999
# -999
# 983
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 366
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 805
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 735
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 214
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 251
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 125
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 191
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 636
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 345
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 625
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 893
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 622
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 64
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 824
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 878
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 869
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 251
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 630
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 863
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 738
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 775
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 534
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 458
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 73
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 321
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 406
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 893
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 875
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 531
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 401
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 676
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 794
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 756
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 974
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 647
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 120
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 141
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 374
# -999
# -999
# -999
# 804
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 0
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 719
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 485
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 973
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 840
# -999
# -999
# -999
# 358
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 476
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 292
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 250
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 629
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 443
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 292
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 193
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 603
# -999
# -999
# -999
# -999
# -999
# 828
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 374
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 649
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 226
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 357
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 892
# -999
# -999
# -999
# -999
# -999
# 277
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 780
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 820
# -999
# -999
# -999
# 514
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 186
# -999
# -999
# -999
# -999
# -999
# 510
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 740
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 784
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 271
# -999
# -999
# -999
# 498
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 801
# -999
# -999
# -999
# -999
# -999
# 579
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# 385
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999
# -999

# %%
with open('../config/test_1.pik', 'wb') as of:
    pickle.dump(trials, of)
