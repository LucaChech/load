# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pickle
from copy import deepcopy
#%pdb
mypath = ('')
trials = {}
categories = [' bottle', ' horse', ' pottedplant', ' dog',
                  ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]
p_load = ['low','high']

# %%
def present_absent_trials(input_1, input_2):
    global target_present, lista, categories, p_load, odd, even
    # DEFINING TARGET-PRESENT PROBES
    
    #target_present = []
    intermediate = []
    
#next two lines are to check that the images picked as target present and target absent trials
                    #are different from the ones chosen in previous iterations
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_1:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break
    #print len(target_present)
    for n in target_present:
        possible_images_dict[n].append('Target Present')

    #target_present = [n for n in lista if 'Target Present' in possible_images_dict[n]]


    # DEFINING TARGET-ABSENT PROBES
    #target_absent = []
    intermediate = []
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_2:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)

                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for each in target_absent:
        possible_images_dict[each].append('Target Absent')
        

    # DEFINING NO-TARGET IMAGES
    for image in lista:
        if image not in target_present and image not in target_absent:
            possible_images_dict[image].append('NA')
            possible_images_dict[image].append('No Target')
    
    return target_present, target_absent

# %%
# DEFINING CRITICAL TRIALS
#Criteria:
# - images of set load level
# - images containing a certain category
# - image is not already in the list of critical trials for this level of load
#- image is not aready in the list of critical trials (regardless of level of load)

def pre_select_critical_trial(load_level):
    global categories, critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and 'Critical' not in possible_images_dict[intermediate]: # this is just a sanity check
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)      
        temp =[]

# %%
def appending_critical_trials():
    global critical_low_present_probes, critical_low_absent_probes, critical_high_present_probes, critical_high_absent_probes
    global critical_trials
    cycles = 1
    while True:

        #picking critical trials
        pre_select_critical_trial('low')
        pre_select_critical_trial('high')      

        # counting critical probes
        crit_p = 0
        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1


        critical_low_counter = 0
        critical_high_counter = 0
        crit_p = 0

        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1
            if 'No Target' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_counter = critical_low_counter + 1
            if 'No Target' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_counter = critical_high_counter +1
            if 'Target Present' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_absent_probes.append(n)
            if 'Target Present' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_absent_probes.append(n)
        #print crit_p
        #print critical_low_counter
        #print critical_high_counter
        #print critical_low_present_probes
        #print critical_low_absent_probes
        #print critical_high_present_probes
        #print critical_high_absent_probes

        #######################################################
        if crit_p == 0 or len(critical_low_present_probes) == len(critical_high_present_probes) and len(critical_low_absent_probes) == \
        len(critical_high_absent_probes): #check if there is an even number of critical probes
            break
            print 'cycles : ',cycles
        else:
            cycles = cycles + 1
            critical_low_present_probes = []
            critical_low_absent_probes = []
            critical_high_present_probes = []
            critical_high_absent_probes = []
            #print len(critical_low_present_probes)
            #print len(critical_high_present_probes)
            #print len(critical_low_absent_probes)
            #print len(critical_high_absent_probes)
            #print '#######################'

            #why did I reset target_present and target_absent???

            #target_present = []
            #target_absent = []
            critical_trials = []

    # appendinf words 'critical' and 'normal' to dict
    for each in critical_trials:
        possible_images_dict[each].append('Critical')
    for each in possible_images_dict:
        if 'Critical' not in possible_images_dict[each]:
            possible_images_dict[each].append('Normal')

    #######################################################
    #print 'Probe trials: ', len(probe_trials_1)
    print 'Target Present Probes: ', len(target_present)
    print 'Target Absent probes: ', len(target_absent)
    print 'Critical trials:', len(critical_trials)
    print 'Critical, low: ' , critical_low_counter
    print 'Critical, high: ' , critical_high_counter
    print 'Are all critical trials unique? ', len(critical_trials) == len(set(critical_trials))
    #######################################################
    print 'Number of critical probes: ' , crit_p
    print 'critical_low_present_probes: ' , len(critical_low_present_probes)
    print 'critical_high_present_probes: ' , len(critical_high_present_probes)
    print 'critical_low_absent_probes: ' , len(critical_low_absent_probes)
    print 'critical_high_absent_probes: ', len(critical_high_absent_probes)
    print 'cycles : ',cycles
    
    return

# %%
def critical_probes_distribution(starting):
    global critical_low_present_probes, critical_low_absent_probes
    while True:
        p_left = len(starting)
        p_max = p_left
        distribution = []
        for i in range(4):
            if p_left > 0:
                x = random.randint(0,p_left)
                distribution.append(x)
                p_left = p_left - x
            else:
                distribution.append(0)
        if sum(distribution) == p_max:
            break
    random.shuffle(distribution)
    return distribution

# %%
def block_pair(present_n,absent_n):
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block
    global present_crit_distribution, absent_crit_distribution
    global present_critical_per_block, absent_critical_per_block, critical_probes_used, critical_probes_set
    global present_per_block, absent_per_block
    
    present_crit = present_crit_distribution.pop(0)
    absent_crit = absent_crit_distribution.pop(0)
    block = []
    
    for load in p_load:
        #PRINTING STUFF
        print 'present_crit_distribution_original: ',present_crit_distribution_original
        print 'absent_crit_distribution_original: ', absent_crit_distribution_original
        print 'present_crit', present_crit
        print 'absent_crit', absent_crit
        print 'present_crit_distribution: ', present_crit_distribution
        print 'absent_crit_distribution: ', absent_crit_distribution
        print 'critical present set: ', critical_present_set
        print 'critical absent set: ', critical_absent_set
        print'---------------------------------------------------'
        normal_availble = [n for n in normal if n not in normal_used]
        print 'normal available:', len(normal_availble)
    # PICKING CRITICAL PROBES    
    #------------------------------------------------------------------------------
        if present_crit != 0:
            present_critical_per_block = []
            while len(present_critical_per_block) < present_crit:
                crit_probe = str(np.random.choice(critical_present_set,1,replace = False))[2:-2]
                if crit_probe not in present_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Present' in possible_images_dict[crit_probe]:

                    present_critical_per_block.append(crit_probe)
            critical_present.append(present_critical_per_block)
                    
        print 'present_critical_per_block:', present_critical_per_block
        
        if absent_crit != 0:
            absent_critical_per_block = []
            while len(absent_critical_per_block) < absent_crit:
                crit_probe = str(np.random.choice(critical_absent_set,1,replace = False))[2:-2]
                if crit_probe not in absent_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Absent' in possible_images_dict[crit_probe]:

                    absent_critical_per_block.append(crit_probe)
            critical_absent.append(absent_critical_per_block)
            
        print 'absent_critical_per_block:', absent_critical_per_block  
        print 'critical_present: ',critical_present
        print 'critical_absent: ',critical_absent
        
        for n in present_critical_per_block + absent_critical_per_block:
            critical_probes_used.append(n)
            
        print 'critical_probes_used: ', critical_probes_used
    #------------------------------------------------------------------------------
    # PICKING PRESENT AND ABSENT PROBES
        total = present_n + absent_n
        while len(probes_per_block) < (present_n - present_crit):
            probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in present_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        while (present_n - present_crit) <= len(probes_per_block) < total - present_crit - absent_crit:
            probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in absent_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        for n in probes_per_block:
            if 'Target Present' in possible_images_dict[n]:
                present_used.append(n)
            elif 'Target Absent' in possible_images_dict[n]:
                absent_used.append(n)

        probes.append(probes_per_block)
        
        print 'probes: ', probes
        present_per_block = [n for n in probes_per_block if 'Target Present' in possible_images_dict[n]]
        absent_per_block = [n for n in probes_per_block if 'Target Absent' in possible_images_dict[n]]
        print 'Present Used in block: ',len(present_per_block)
        print 'Absent Used in block',len(absent_per_block)
    #------------------------------------------------------------------------------    
    #Counting critical probes    
        critical_probes_counter = len(present_critical_per_block + absent_critical_per_block)
        print 'Critical probes counter: ',critical_probes_counter
        print 'Present Critical: ', len(present_critical_per_block)
        print 'Absent Critical: ', len(absent_critical_per_block)

        modifier.append(critical_probes_counter)
    #------------------------------------------------------------------------------
    #Picking critical trials
        while len(critical_per_block) < (3-critical_probes_counter):
            image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
            if image not in critical_per_block and image not in critical_used \
                and 'No Target' in possible_images_dict[image] and load in possible_images_dict[image]:
                critical_per_block.append(image) 
        print 'List of critical trials without probe: '
        for n in critical_per_block:
            critical_used.append(n)
            print possible_images_dict[n]
        #temp = []

        critical.append(critical_per_block)

    #------------------------------------------------------------------------------
    #Picking normal trials
        while len(normal_per_block) < 51 - (3 - critical_probes_counter):
            image = str(np.random.choice(normal,1,replace = False))[2:-2]
            if image not in normal_per_block and image not in normal_used and load in possible_images_dict[image]:
                normal_per_block.append(image)
        for n in normal_per_block:
            normal_used.append(n)
        print 'normal in this block: ', len(normal_per_block)
        print 'normal used overall: ',len(normal_used)

        normal_builder.append(normal_per_block)
    #----------------------------------------------------------------------------
        
        print 'critical_probes_used', critical_probes_used 
        
        
        
        if 'sequence_final' in locals():
            print 'sequence_final exists'
        else:
            print 'sequence final does not exist'
            sequence_final = position_finder()
            print sequence_final
        print'---------------------------------------------------'
        print 'END OF BLOCK PROCESSING'
        print'---------------------------------------------------'
        print 'BUILDING THE BLOCK'
        first_element = [x[0] for x in sequence_final]
        second_element = [x[1] for x in sequence_final]
        second_element_counter = 0
        probes_position = []
        for image in range(60):
            #print [x[1] for x in sequence_final if x[0] ==image][0]
            if image in first_element:
                
                print 'image', image, second_element[second_element_counter]
        
                if second_element[second_element_counter] == 'Target Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break       
                elif second_element[second_element_counter] == 'Target Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical':
                    while True:
                        element = str(np.random.choice(critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break     
                elif second_element[second_element_counter] == 'Critical Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break  
            else:
                while True:
                    element = str(np.random.choice(normal_per_block,1,replace = False))[2:-2]
                    if element not in block:
                        block.append(element)
                        break
                
        print 'block:', len(block)   
        print'---------------------------------------------------'
        print 'probes_position: ', probes_position
    #-----------------------------------------------------------------------------
        normal_per_block = []
        probes_per_block = []
        critical_per_block = []
        present_critical_per_block = []
        absent_critical_per_block = []
    #-----------------------------------------------------------------------------
    return block

# %%
def position_finder():
    global present_critical_per_block, absent_critical_per_block, present_per_block, absent_per_block, critical_per_block
    x = len(present_critical_per_block + absent_critical_per_block)
    print 'x', x
    print 'present_critical_per_block', len(present_critical_per_block)
    print 'absent_critical_per_block', len(absent_critical_per_block)
    while True:    
        while True:
            a = [random.randint(1,10) for r in xrange(12-x)]
            if sum(a) <= 60:
                break

        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]

        if len(present_critical_per_block) == 0 and len(absent_critical_per_block) == 0:
            print 'ciao', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block) + ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        if len(present_critical_per_block) != 0 or len(absent_critical_per_block) != 0:
            print 'ciao2', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block)  +\
            ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block) +\
            ['Critical Present'] * len(present_critical_per_block) +\
            ['Critical Absent'] * len(absent_critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        sequence_final = zip(new_list_1, sequence)
        #print sequence_final
        #print len(sequence_final)
        gap_check = [n[0] for n in sequence_final if 'Critical' in n[1]] 
        #print gap_check
        container = []
        for i in gap_check:
            elements = [i+1, i+2]
            for element in elements:
                if element in new_list_1:
                    container.append(element)
        #print 'container', len(container),container
        if len(container) == 0:
            break
        else:
            sequence_final = []

    print '------------------'
    print new_list_1, len(new_list_1)
    print 'gap_check: ', gap_check
    print len(sequence_final)

    for i in sequence_final:
        print i
    return sequence_final

# %%
def block_unpacker(splitting_index,present,absent):
    block = block_pair(present,absent) #, probes_position
    low_block = []
    high_block = []
    for i in range(len(block)):
        if i < (len(block)/2):
            low_block.append(block[i])
        else:
            high_block.append(block[i])
    #print probes_position
    print len(low_block), len(high_block)
    return low_block, high_block #, probes_position

# %%
def tone_properties():
    while True:
        possible_tones = ['tone1','tone2']
        low_one_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_two_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_three_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_four_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        high_one_tones = []
        high_two_tones = []
        high_three_tones = []
        high_four_tones = []
        for each in low_one_tones:
            if each == 'tone1':
                high_one_tones.append('tone2')
            elif each == 'tone2':
                high_one_tones.append('tone1')
        for each in low_two_tones:
            if each == 'tone1':
                high_two_tones.append('tone2')
            elif each == 'tone2':
                high_two_tones.append('tone1')
        for each in low_three_tones:
            if each == 'tone1':
                high_three_tones.append('tone2')
            elif each == 'tone2':
                high_three_tones.append('tone1')
        for each in low_four_tones:
            if each == 'tone1':
                high_four_tones.append('tone2')
            elif each == 'tone2':
                high_four_tones.append('tone1')
        sound_Hz = low_one_tones + low_two_tones + low_three_tones + low_four_tones + high_one_tones + high_two_tones +\
        high_three_tones + high_four_tones

        tone1_counter = 0
        tone2_counter = 0
        for each in sound_Hz:
            if each == 'tone1':
                tone1_counter = tone1_counter + 1
            elif each == 'tone2':
                tone2_counter = tone2_counter + 1

        low_load_tones = [n for n in sound_Hz[0:12]]
        high_load_tones = [n for n in sound_Hz[12:25]]
        low_load_tone1s = [n for n in low_load_tones if n == 'tone1']
        low_load_tone2s = [n for n in low_load_tones if n == 'tone2']
        high_load_tone1s = [n for n in high_load_tones if n == 'tone1']
        high_load_tone2s = [n for n in high_load_tones if n =='tone2']

        if len(low_load_tone1s) == len(low_load_tone2s) and len(high_load_tone1s) == len(high_load_tone2s):
            print low_one_tones
            print high_one_tones
            print '----------------------'
            print low_two_tones
            print high_two_tones
            print '----------------------'
            print low_three_tones
            print high_three_tones
            print '----------------------'
            print low_four_tones
            print high_four_tones
            print '----------------------'
            print 'total n of tones: ', len(sound_Hz)
            print '----------------------'
            print 'total n of 1500 Hz tones: ', tone1_counter
            print 'total n of 2000 Hz tones: ', tone2_counter
            print '----------------------'
            print len(low_load_tone1s) == len(low_load_tone2s)
            print len(low_load_tone1s)
            print len(low_load_tone2s)
            print len(high_load_tone1s) == len(high_load_tone2s)
            print len(high_load_tone1s)
            print len(high_load_tone2s)
            break
    sound_onset = []
    for i in range(48):
        a = random.uniform(0, 0.999)
        a = int(str(a)[2:5])
        #print a
        sound_onset.append(a)

    #------------------------------------------------------------------------------
    # APPEND TO DICT
    sound_index = 0
    for each in possible_images_dict:
        if 'Critical' in possible_images_dict[each]:
            possible_images_dict[each].append(sound_Hz[sound_index])
            possible_images_dict[each].append(sound_onset[sound_index])
            sound_index = sound_index + 1
        elif 'Normal' in possible_images_dict[each]:
            possible_images_dict[each].append('No tone')
            possible_images_dict[each].append(-999)

# %%
def appending_to_dict(trial_n):
    global blocks
    for b in range(8):
        this_block_images = blocks[b]
        for im in this_block_images:
            trials[trial_n] = possible_images_dict[im]
            trials[trial_n].append(im)
            trial_n += 1
    print 'len(trials): ', len(trials)

# %%
######################
### FIRST ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  8
# Critical, high:  8
# Are all critical trials unique?  True
# Number of critical probes:  8
# critical_low_present_probes:  3
# critical_high_present_probes:  3
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  12
# present_crit_distribution_original:  [1, 2, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [2, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  ['2008_005214.jpg', '2008_006784.jpg', '2010_000299.jpg', '2010_003490.jpg', '2008_000191.jpg', '2008_000619.jpg']
# critical absent set:  ['2011_002582.jpg', '2009_000488.jpg']
# ---------------------------------------------------
# normal available: 392
# present_critical_per_block: ['2008_006784.jpg']
# absent_critical_per_block: []
# critical_present:  [['2008_006784.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2008_006784.jpg']
# probes_per_block : ['2008_004814.jpg', '2009_002803.jpg', '2008_005978.jpg']
# probes_per_block : ['2008_004814.jpg', '2009_002803.jpg', '2008_005978.jpg', '2010_005437.jpg', '2011_001432.jpg', '2008_004412.jpg', '2010_001036.jpg', '2009_002439.jpg']
# probes:  [['2008_004814.jpg', '2009_002803.jpg', '2008_005978.jpg', '2010_005437.jpg', '2011_001432.jpg', '2008_004412.jpg', '2010_001036.jpg', '2009_002439.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' dog', nan, nan, nan, 20.166020393270408, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 19.264337675075122, 'low', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  49
# critical_probes_used ['2008_006784.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 1
# absent_critical_per_block 0
# ciao2 2
# ------------------
# [3, 7, 11, 12, 18, 26, 30, 34, 39, 47, 52] 11
# gap_check:  [26, 30, 39]
# 11
# (3, 'Target Present')
# (7, 'Target Absent')
# (11, 'Target Absent')
# (12, 'Target Present')
# (18, 'Target Present')
# (26, 'Critical')
# (30, 'Critical')
# (34, 'Target Absent')
# (39, 'Critical Present')
# (47, 'Target Absent')
# (52, 'Target Absent')
# [(3, 'Target Present'), (7, 'Target Absent'), (11, 'Target Absent'), (12, 'Target Present'), (18, 'Target Present'), (26, 'Critical'), (30, 'Critical'), (34, 'Target Absent'), (39, 'Critical Present'), (47, 'Target Absent'), (52, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 7 Target Absent
# image 11 Target Absent
# image 12 Target Present
# image 18 Target Present
# image 26 Critical
# image 30 Critical
# image 34 Target Absent
# image 39 Critical Present
# image 47 Target Absent
# image 52 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 7, 11, 12, 18, 34, 39, 47, 52]
# present_crit_distribution_original:  [1, 2, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [2, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  ['2008_005214.jpg', '2008_006784.jpg', '2010_000299.jpg', '2010_003490.jpg', '2008_000191.jpg', '2008_000619.jpg']
# critical absent set:  ['2011_002582.jpg', '2009_000488.jpg']
# ---------------------------------------------------
# normal available: 343
# present_critical_per_block: ['2010_003490.jpg']
# absent_critical_per_block: []
# critical_present:  [['2008_006784.jpg'], ['2010_003490.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2008_006784.jpg', '2010_003490.jpg']
# probes_per_block : ['2008_007423.jpg', '2009_000058.jpg', '2008_003844.jpg']
# probes_per_block : ['2008_007423.jpg', '2009_000058.jpg', '2008_003844.jpg', '2010_002278.jpg', '2008_006663.jpg', '2009_000995.jpg', '2010_003943.jpg', '2010_004683.jpg']
# probes:  [['2008_004814.jpg', '2009_002803.jpg', '2008_005978.jpg', '2010_005437.jpg', '2011_001432.jpg', '2008_004412.jpg', '2010_001036.jpg', '2009_002439.jpg'], ['2008_007423.jpg', '2009_000058.jpg', '2008_003844.jpg', '2010_002278.jpg', '2008_006663.jpg', '2009_000995.jpg', '2010_003943.jpg', '2010_004683.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' bottle', nan, nan, nan, 30.958055456079503, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 31.676385713707838, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  98
# critical_probes_used ['2008_006784.jpg', '2010_003490.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Present
# image 7 Target Absent
# image 11 Target Absent
# image 12 Target Present
# image 18 Target Present
# image 26 Critical
# image 30 Critical
# image 34 Target Absent
# image 39 Critical Present
# image 47 Target Absent
# image 52 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 7, 11, 12, 18, 34, 39, 47, 52]
# 60 60
# present_crit_distribution_original:  [1, 2, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 2
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  ['2008_005214.jpg', '2008_006784.jpg', '2010_000299.jpg', '2010_003490.jpg', '2008_000191.jpg', '2008_000619.jpg']
# critical absent set:  ['2011_002582.jpg', '2009_000488.jpg']
# ---------------------------------------------------
# normal available: 294
# present_critical_per_block: ['2008_005214.jpg', '2010_000299.jpg']
# absent_critical_per_block: []
# critical_present:  [['2008_006784.jpg'], ['2010_003490.jpg'], ['2008_005214.jpg', '2010_000299.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2008_006784.jpg', '2010_003490.jpg', '2008_005214.jpg', '2010_000299.jpg']
# probes_per_block : ['2010_005101.jpg', '2008_005903.jpg', '2010_003101.jpg']
# probes_per_block : ['2010_005101.jpg', '2008_005903.jpg', '2010_003101.jpg', '2008_005673.jpg', '2008_000112.jpg', '2008_005869.jpg', '2010_001731.jpg']
# probes:  [['2008_004814.jpg', '2009_002803.jpg', '2008_005978.jpg', '2010_005437.jpg', '2011_001432.jpg', '2008_004412.jpg', '2010_001036.jpg', '2009_002439.jpg'], ['2008_007423.jpg', '2009_000058.jpg', '2008_003844.jpg', '2010_002278.jpg', '2008_006663.jpg', '2009_000995.jpg', '2010_003943.jpg', '2010_004683.jpg'], ['2010_005101.jpg', '2008_005903.jpg', '2010_003101.jpg', '2008_005673.jpg', '2008_000112.jpg', '2008_005869.jpg', '2010_001731.jpg']]
# Present Used in block:  3
# Absent Used in block 4
# Critical probes counter:  2
# Present Critical:  2
# Absent Critical:  0
# List of critical trials without probe:
# [' person', nan, nan, nan, nan, 21.01071271736431, 'low', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  148
# critical_probes_used ['2008_006784.jpg', '2010_003490.jpg', '2008_005214.jpg', '2010_000299.jpg']
# sequence final does not exist
# x 2
# present_critical_per_block 2
# absent_critical_per_block 0
# ciao2 1
# ciao2 1
# ciao2 1
# ciao2 1
# ciao2 1
# ------------------
# [0, 4, 10, 17, 21, 29, 31, 38, 43, 51] 10
# gap_check:  [0, 4, 38]
# 10
# (0, 'Critical')
# (4, 'Critical Present')
# (10, 'Target Absent')
# (17, 'Target Absent')
# (21, 'Target Absent')
# (29, 'Target Present')
# (31, 'Target Absent')
# (38, 'Critical Present')
# (43, 'Target Present')
# (51, 'Target Present')
# [(0, 'Critical'), (4, 'Critical Present'), (10, 'Target Absent'), (17, 'Target Absent'), (21, 'Target Absent'), (29, 'Target Present'), (31, 'Target Absent'), (38, 'Critical Present'), (43, 'Target Present'), (51, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Critical
# image 4 Critical Present
# image 10 Target Absent
# image 17 Target Absent
# image 21 Target Absent
# image 29 Target Present
# image 31 Target Absent
# image 38 Critical Present
# image 43 Target Present
# image 51 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [4, 10, 17, 21, 29, 31, 38, 43, 51]
# present_crit_distribution_original:  [1, 2, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 2
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  ['2008_005214.jpg', '2008_006784.jpg', '2010_000299.jpg', '2010_003490.jpg', '2008_000191.jpg', '2008_000619.jpg']
# critical absent set:  ['2011_002582.jpg', '2009_000488.jpg']
# ---------------------------------------------------
# normal available: 244
# present_critical_per_block: ['2008_000191.jpg', '2008_000619.jpg']
# absent_critical_per_block: []
# critical_present:  [['2008_006784.jpg'], ['2010_003490.jpg'], ['2008_005214.jpg', '2010_000299.jpg'], ['2008_000191.jpg', '2008_000619.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2008_006784.jpg', '2010_003490.jpg', '2008_005214.jpg', '2010_000299.jpg', '2008_000191.jpg', '2008_000619.jpg']
# probes_per_block : ['2008_001862.jpg', '2008_000041.jpg', '2008_007629.jpg']
# probes_per_block : ['2008_001862.jpg', '2008_000041.jpg', '2008_007629.jpg', '2009_002571.jpg', '2008_002672.jpg', '2011_001221.jpg', '2008_002725.jpg']
# probes:  [['2008_004814.jpg', '2009_002803.jpg', '2008_005978.jpg', '2010_005437.jpg', '2011_001432.jpg', '2008_004412.jpg', '2010_001036.jpg', '2009_002439.jpg'], ['2008_007423.jpg', '2009_000058.jpg', '2008_003844.jpg', '2010_002278.jpg', '2008_006663.jpg', '2009_000995.jpg', '2010_003943.jpg', '2010_004683.jpg'], ['2010_005101.jpg', '2008_005903.jpg', '2010_003101.jpg', '2008_005673.jpg', '2008_000112.jpg', '2008_005869.jpg', '2010_001731.jpg'], ['2008_001862.jpg', '2008_000041.jpg', '2008_007629.jpg', '2009_002571.jpg', '2008_002672.jpg', '2011_001221.jpg', '2008_002725.jpg']]
# Present Used in block:  3
# Absent Used in block 4
# Critical probes counter:  2
# Present Critical:  2
# Absent Critical:  0
# List of critical trials without probe:
# [' car', ' boat', ' person', nan, nan, 32.75926741884376, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  198
# critical_probes_used ['2008_006784.jpg', '2010_003490.jpg', '2008_005214.jpg', '2010_000299.jpg', '2008_000191.jpg', '2008_000619.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Critical
# image 4 Critical Present
# image 10 Target Absent
# image 17 Target Absent
# image 21 Target Absent
# image 29 Target Present
# image 31 Target Absent
# image 38 Critical Present
# image 43 Target Present
# image 51 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [4, 10, 17, 21, 29, 31, 38, 43, 51]
# 60 60
# present_crit_distribution_original:  [1, 2, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2008_005214.jpg', '2008_006784.jpg', '2010_000299.jpg', '2010_003490.jpg', '2008_000191.jpg', '2008_000619.jpg']
# critical absent set:  ['2011_002582.jpg', '2009_000488.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: ['2011_002582.jpg']
# critical_present:  [['2008_006784.jpg'], ['2010_003490.jpg'], ['2008_005214.jpg', '2010_000299.jpg'], ['2008_000191.jpg', '2008_000619.jpg']]
# critical_absent:  [['2011_002582.jpg']]
# critical_probes_used:  ['2008_006784.jpg', '2010_003490.jpg', '2008_005214.jpg', '2010_000299.jpg', '2008_000191.jpg', '2008_000619.jpg', '2011_002582.jpg']
# probes_per_block : ['2010_000109.jpg', '2008_008359.jpg', '2011_003074.jpg', '2008_002704.jpg']
# probes_per_block : ['2010_000109.jpg', '2008_008359.jpg', '2011_003074.jpg', '2008_002704.jpg', '2009_004262.jpg', '2008_002062.jpg', '2009_000087.jpg', '2009_001774.jpg']
# probes:  [['2008_004814.jpg', '2009_002803.jpg', '2008_005978.jpg', '2010_005437.jpg', '2011_001432.jpg', '2008_004412.jpg', '2010_001036.jpg', '2009_002439.jpg'], ['2008_007423.jpg', '2009_000058.jpg', '2008_003844.jpg', '2010_002278.jpg', '2008_006663.jpg', '2009_000995.jpg', '2010_003943.jpg', '2010_004683.jpg'], ['2010_005101.jpg', '2008_005903.jpg', '2010_003101.jpg', '2008_005673.jpg', '2008_000112.jpg', '2008_005869.jpg', '2010_001731.jpg'], ['2008_001862.jpg', '2008_000041.jpg', '2008_007629.jpg', '2009_002571.jpg', '2008_002672.jpg', '2011_001221.jpg', '2008_002725.jpg'], ['2010_000109.jpg', '2008_008359.jpg', '2011_003074.jpg', '2008_002704.jpg', '2009_004262.jpg', '2008_002062.jpg', '2009_000087.jpg', '2009_001774.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 20.041574567240037, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 15.759492066531687, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  247
# critical_probes_used ['2008_006784.jpg', '2010_003490.jpg', '2008_005214.jpg', '2010_000299.jpg', '2008_000191.jpg', '2008_000619.jpg', '2011_002582.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ------------------
# [7, 10, 19, 28, 38, 40, 41, 44, 47, 48, 51] 11
# gap_check:  [7, 10, 48]
# 11
# (7, 'Critical')
# (10, 'Critical Absent')
# (19, 'Target Absent')
# (28, 'Target Present')
# (38, 'Target Present')
# (40, 'Target Absent')
# (41, 'Target Present')
# (44, 'Target Absent')
# (47, 'Target Present')
# (48, 'Critical')
# (51, 'Target Absent')
# [(7, 'Critical'), (10, 'Critical Absent'), (19, 'Target Absent'), (28, 'Target Present'), (38, 'Target Present'), (40, 'Target Absent'), (41, 'Target Present'), (44, 'Target Absent'), (47, 'Target Present'), (48, 'Critical'), (51, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 

# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  8
# Critical, high:  8
# Are all critical trials unique?  True
# Number of critical probes:  8
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  3
# critical_high_absent_probes:  3
# cycles :  1
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [1, 0, 2]
# critical present set:  ['2010_001829.jpg', '2008_008500.jpg']
# critical absent set:  ['2008_001708.jpg', '2008_000119.jpg', '2008_000398.jpg', '2008_000833.jpg', '2011_002098.jpg', '2008_002709.jpg']
# ---------------------------------------------------
# normal available: 392
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_005123.jpg', '2010_003911.jpg', '2010_000132.jpg', '2009_002521.jpg']
# probes_per_block : ['2008_005123.jpg', '2010_003911.jpg', '2010_000132.jpg', '2009_002521.jpg', '2009_002803.jpg', '2008_005490.jpg', '2011_000070.jpg', '2010_003453.jpg', '2011_001611.jpg']
# probes:  [['2008_005123.jpg', '2010_003911.jpg', '2010_000132.jpg', '2009_002521.jpg', '2009_002803.jpg', '2008_005490.jpg', '2011_000070.jpg', '2010_003453.jpg', '2011_001611.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', nan, nan, nan, nan, 20.95630728619632, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 12.53657278412077, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 17.497069987457937, 'low', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [2, 8, 9, 15, 21, 28, 29, 32, 39, 41, 49, 52] 12
# gap_check:  [21, 29, 41]
# 12
# (2, 'Target Absent')
# (8, 'Target Present')
# (9, 'Target Present')
# (15, 'Target Absent')
# (21, 'Critical')
# (28, 'Target Absent')
# (29, 'Critical')
# (32, 'Target Present')
# (39, 'Target Absent')
# (41, 'Critical')
# (49, 'Target Present')
# (52, 'Target Absent')
# [(2, 'Target Absent'), (8, 'Target Present'), (9, 'Target Present'), (15, 'Target Absent'), (21, 'Critical'), (28, 'Target Absent'), (29, 'Critical'), (32, 'Target Present'), (39, 'Target Absent'), (41, 'Critical'), (49, 'Target Present'), (52, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Absent
# image 8 Target Present
# image 9 Target Present
# image 15 Target Absent
# image 21 Critical
# image 28 Target Absent
# image 29 Critical
# image 32 Target Present
# image 39 Target Absent
# image 41 Critical
# image 49 Target Present
# image 52 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [2, 8, 9, 15, 28, 32, 39, 49, 52]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [1, 0, 2]
# critical present set:  ['2010_001829.jpg', '2008_008500.jpg']
# critical absent set:  ['2008_001708.jpg', '2008_000119.jpg', '2008_000398.jpg', '2008_000833.jpg', '2011_002098.jpg', '2008_002709.jpg']
# ---------------------------------------------------
# normal available: 344
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_003378.jpg', '2008_002897.jpg', '2011_002509.jpg', '2008_006841.jpg']
# probes_per_block : ['2008_003378.jpg', '2008_002897.jpg', '2011_002509.jpg', '2008_006841.jpg', '2010_001682.jpg', '2010_000865.jpg', '2008_002887.jpg', '2008_005600.jpg', '2008_008097.jpg']
# probes:  [['2008_005123.jpg', '2010_003911.jpg', '2010_000132.jpg', '2009_002521.jpg', '2009_002803.jpg', '2008_005490.jpg', '2011_000070.jpg', '2010_003453.jpg', '2011_001611.jpg'], ['2008_003378.jpg', '2008_002897.jpg', '2011_002509.jpg', '2008_006841.jpg', '2010_001682.jpg', '2010_000865.jpg', '2008_002887.jpg', '2008_005600.jpg', '2008_008097.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' person', ' chair', ' dog', ' bottle', 31.05804957013649, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' dog', ' car', nan, nan, 33.09488500291814, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 32.959390221443385, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Absent
# image 8 Target Present
# image 9 Target Present
# image 15 Target Absent
# image 21 Critical
# image 28 Target Absent
# image 29 Critical
# image 32 Target Present
# image 39 Target Absent
# image 41 Critical
# image 49 Target Present
# image 52 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [2, 8, 9, 15, 28, 32, 39, 49, 52]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 2]
# present_crit 1
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 2]
# critical present set:  ['2010_001829.jpg', '2008_008500.jpg']
# critical absent set:  ['2008_001708.jpg', '2008_000119.jpg', '2008_000398.jpg', '2008_000833.jpg', '2011_002098.jpg', '2008_002709.jpg']
# ---------------------------------------------------
# normal available: 296
# present_critical_per_block: ['2010_001829.jpg']
# absent_critical_per_block: ['2008_000398.jpg']
# critical_present:  [['2010_001829.jpg']]
# critical_absent:  [['2008_000398.jpg']]
# critical_probes_used:  ['2010_001829.jpg', '2008_000398.jpg']
# probes_per_block : ['2009_004779.jpg', '2010_001988.jpg', '2008_005978.jpg', '2010_001907.jpg']
# probes_per_block : ['2009_004779.jpg', '2010_001988.jpg', '2008_005978.jpg', '2010_001907.jpg', '2011_002911.jpg', '2008_000912.jpg', '2011_001591.jpg']
# probes:  [['2008_005123.jpg', '2010_003911.jpg', '2010_000132.jpg', '2009_002521.jpg', '2009_002803.jpg', '2008_005490.jpg', '2011_000070.jpg', '2010_003453.jpg', '2011_001611.jpg'], ['2008_003378.jpg', '2008_002897.jpg', '2011_002509.jpg', '2008_006841.jpg', '2010_001682.jpg', '2010_000865.jpg', '2008_002887.jpg', '2008_005600.jpg', '2008_008097.jpg'], ['2009_004779.jpg', '2010_001988.jpg', '2008_005978.jpg', '2010_001907.jpg', '2011_002911.jpg', '2008_000912.jpg', '2011_001591.jpg']]
# Present Used in block:  4
# Absent Used in block 3
# Critical probes counter:  2
# Present Critical:  1
# Absent Critical:  1
# List of critical trials without probe:
# [' bottle', nan, nan, nan, nan, 18.603518928106915, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  146
# critical_probes_used ['2010_001829.jpg', '2008_000398.jpg']
# sequence final does not exist
# x 2
# present_critical_per_block 1
# absent_critical_per_block 1
# ciao2 1
# ------------------
# [5, 13, 18, 26, 36, 37, 43, 44, 51, 52] 10
# gap_check:  [5, 26, 44]
# 10
# (5, 'Critical Present')
# (13, 'Target Present')
# (18, 'Target Absent')
# (26, 'Critical Absent')
# (36, 'Target Present')
# (37, 'Target Present')
# (43, 'Target Present')
# (44, 'Critical')
# (51, 'Target Absent')
# (52, 'Target Absent')
# [(5, 'Critical Present'), (13, 'Target Present'), (18, 'Target Absent'), (26, 'Critical Absent'), (36, 'Target Present'), (37, 'Target Present'), (43, 'Target Present'), (44, 'Critical'), (51, 'Target Absent'), (52, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical Present
# image 13 Target Present
# image 18 Target Absent
# image 26 Critical Absent
# image 36 Target Present
# image 37 Target Present
# image 43 Target Present
# image 44 Critical
# image 51 Target Absent
# image 52 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 13, 18, 26, 36, 37, 43, 51, 52]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 2]
# present_crit 1
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 2]
# critical present set:  ['2010_001829.jpg', '2008_008500.jpg']
# critical absent set:  ['2008_001708.jpg', '2008_000119.jpg', '2008_000398.jpg', '2008_000833.jpg', '2011_002098.jpg', '2008_002709.jpg']
# ---------------------------------------------------
# normal available: 246
# present_critical_per_block: ['2008_008500.jpg']
# absent_critical_per_block: ['2011_002098.jpg']
# critical_present:  [['2010_001829.jpg'], ['2008_008500.jpg']]
# critical_absent:  [['2008_000398.jpg'], ['2011_002098.jpg']]
# critical_probes_used:  ['2010_001829.jpg', '2008_000398.jpg', '2008_008500.jpg', '2011_002098.jpg']
# probes_per_block : ['2008_006481.jpg', '2009_003705.jpg', '2010_000815.jpg', '2008_002774.jpg']
# probes_per_block : ['2008_006481.jpg', '2009_003705.jpg', '2010_000815.jpg', '2008_002774.jpg', '2010_002127.jpg', '2008_007378.jpg', '2008_007664.jpg']
# probes:  [['2008_005123.jpg', '2010_003911.jpg', '2010_000132.jpg', '2009_002521.jpg', '2009_002803.jpg', '2008_005490.jpg', '2011_000070.jpg', '2010_003453.jpg', '2011_001611.jpg'], ['2008_003378.jpg', '2008_002897.jpg', '2011_002509.jpg', '2008_006841.jpg', '2010_001682.jpg', '2010_000865.jpg', '2008_002887.jpg', '2008_005600.jpg', '2008_008097.jpg'], ['2009_004779.jpg', '2010_001988.jpg', '2008_005978.jpg', '2010_001907.jpg', '2011_002911.jpg', '2008_000912.jpg', '2011_001591.jpg'], ['2008_006481.jpg', '2009_003705.jpg', '2010_000815.jpg', '2008_002774.jpg', '2010_002127.jpg', '2008_007378.jpg', '2008_007664.jpg']]
# Present Used in block:  4
# Absent Used in block 3
# Critical probes counter:  2
# Present Critical:  1
# Absent Critical:  1
# List of critical trials without probe:
# [' pottedplant', ' person', ' bottle', ' diningtable', nan, 36.665582819269645, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  196
# critical_probes_used ['2010_001829.jpg', '2008_000398.jpg', '2008_008500.jpg', '2011_002098.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical Present
# image 13 Target Present
# image 18 Target Absent
# image 26 Critical Absent
# image 36 Target Present
# image 37 Target Present
# image 43 Target Present
# image 44 Critical
# image 51 Target Absent
# image 52 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 13, 18, 26, 36, 37, 43, 51, 52]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [2]
# critical present set:  ['2010_001829.jpg', '2008_008500.jpg']
# critical absent set:  ['2008_001708.jpg', '2008_000119.jpg', '2008_000398.jpg', '2008_000833.jpg', '2011_002098.jpg', '2008_002709.jpg']
# ---------------------------------------------------
# normal available: 196
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2010_001829.jpg'], ['2008_008500.jpg']]
# critical_absent:  [['2008_000398.jpg'], ['2011_002098.jpg']]
# critical_probes_used:  ['2010_001829.jpg', '2008_000398.jpg', '2008_008500.jpg', '2011_002098.jpg']
# probes_per_block : ['2008_001238.jpg', '2009_000919.jpg', '2010_001451.jpg', '2008_000740.jpg']
# probes_per_block : ['2008_001238.jpg', '2009_000919.jpg', '2010_001451.jpg', '2008_000740.jpg', '2010_004425.jpg', '2008_007842.jpg', '2011_001613.jpg', '2011_002050.jpg', '2011_001959.jpg']
# probes:  [['2008_005123.jpg', '2010_003911.jpg', '2010_000132.jpg', '2009_002521.jpg', '2009_002803.jpg', '2008_005490.jpg', '2011_000070.jpg', '2010_003453.jpg', '2011_001611.jpg'], ['2008_003378.jpg', '2008_002897.jpg', '2011_002509.jpg', '2008_006841.jpg', '2010_001682.jpg', '2010_000865.jpg', '2008_002887.jpg', '2008_005600.jpg', '2008_008097.jpg'], ['2009_004779.jpg', '2010_001988.jpg', '2008_005978.jpg', '2010_001907.jpg', '2011_002911.jpg', '2008_000912.jpg', '2011_001591.jpg'], ['2008_006481.jpg', '2009_003705.jpg', '2010_000815.jpg', '2008_002774.jpg', '2010_002127.jpg', '2008_007378.jpg', '2008_007664.jpg'], ['2008_001238.jpg', '2009_000919.jpg', '2010_001451.jpg', '2008_000740.jpg', '2010_004425.jpg', '2008_007842.jpg', '2011_001613.jpg', '2011_002050.jpg', '2011_001959.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 19.4399393845732, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 9.955368400707393, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 20.39542994429513, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  244
# critical_probes_used ['2010_001829.jpg', '2008_000398.jpg', '2008_008500.jpg', '2011_002098.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [2, 10, 12, 19, 20, 27, 31, 33, 40, 43, 46, 49] 12
# gap_check:  [12, 20, 46]
# 12
# (2, 'Target Present')
# (10, 'Target Absent')
# (12, 'Critical')
# (19, 'Target Absent')
# (20, 'Critical')
# (27, 'Target Absent')
# (31, 'Target Present')
# (33, 'Target Present')
# (40, 'Target Absent')
# (43, 'Target Absent')
# (46, 'Critical')
# (49, 'Target Present')
# [(2, 'Target Present'), (10, 'Target Absent'), (12, 'Critical'), (19, 'Target Absent'), (20, 'Critical'), (27, 'Target Absent'), (31, 'Target Present'), (33, 'Target Present'), (40, 'Target Absent'), (43, 'Target Absent'), (46, 'Critical'), (49, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Present
# image 10 Target Absent
# image 12 Critical
# image 19 Target Absent
# image 20 Critical
# image 27 Target Absent
# image 31 Target Present
# image 33 Target Present
# image 40 Target Absent
# image 43 Target Absent
# image 46 Critical
# image 49 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [2, 10, 19, 27, 31, 33, 40, 43, 49]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 2]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [2]
# critical present set:  ['2010_001829.jpg', '2008_008500.jpg']
# critical absent set:  ['2008_001708.jpg', '2008_000119.jpg', '2008_000398.jpg', '2008_000833.jpg', '2011_002098.jpg', '2008_002709.jpg']
# ---------------------------------------------------
# normal available: 148
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2010_001829.jpg'], ['2008_008500.jpg']]
# critical_absent:  [['2008_000398.jpg'], ['2011_002098.jpg']]
# critical_probes_used:  ['2010_001829.jpg', '2008_000398.jpg', '2008_008500.jpg', '2011_002098.jpg']
# probes_per_block : ['2008_004188.jpg', '2008_001278.jpg', '2009_000120.jpg', '2008_007091.jpg']
# probes_per_block : ['2008_004188.jpg', '2008_001278.jpg', '2009_000120.jpg', '2008_007091.jpg', '2008_004482.jpg', '2010_005894.jpg', '2008_004459.jpg', '2011_001880.jpg', '2008_007913.jpg']
# probes:  [['2008_005123.jpg', '2010_003911.jpg', '2010_000132.jpg', '2009_002521.jpg', '2009_002803.jpg', '2008_005490.jpg', '2011_000070.jpg', '2010_003453.jpg', '2011_001611.jpg'], ['2008_003378.jpg', '2008_002897.jpg', '2011_002509.jpg', '2008_006841.jpg', '2010_001682.jpg', '2010_000865.jpg', '2008_002887.jpg', '2008_005600.jpg', '2008_008097.jpg'], ['2009_004779.jpg', '2010_001988.jpg', '2008_005978.jpg', '2010_001907.jpg', '2011_002911.jpg', '2008_000912.jpg', '2011_001591.jpg'], ['2008_006481.jpg', '2009_003705.jpg', '2010_000815.jpg', '2008_002774.jpg', '2010_002127.jpg', '2008_007378.jpg', '2008_007664.jpg'], ['2008_001238.jpg', '2009_000919.jpg', '2010_001451.jpg', '2008_000740.jpg', '2010_004425.jpg', '2008_007842.jpg', '2011_001613.jpg', '2011_002050.jpg', '2011_001959.jpg'], ['2008_004188.jpg', '2008_001278.jpg', '2009_000120.jpg', '2008_007091.jpg', '2008_004482.jpg', '2010_005894.jpg', '2008_004459.jpg', '2011_001880.jpg', '2008_007913.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' aeroplane', nan, nan, nan, 31.07062434195711, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 30.24293720929956, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 28.968465057520145, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  292
# critical_probes_used ['2010_001829.jpg', '2008_000398.jpg', '2008_008500.jpg', '2011_002098.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Present
# image 10 Target Absent
# image 12 Critical
# image 19 Target Absent
# image 20 Critical
# image 27 Target Absent
# image 31 Target Present
# image 33 Target Present
# image 40 Target Absent
# image 43 Target Absent
# image 46 Critical
# image 49 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [2,
present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical
# image 12 Target Absent
# image 17 Target Present
# image 20 Critical
# image 23 Target Absent
# image 31 Target Absent
# image 33 Target Absent
# image 43 Target Present
# image 48 Target Absent
# image 53 Target Present
# image 56 Critical Present
# block: 60
# ---------------------------------------------------
# probes_position:  [12, 17, 23, 31, 33, 43, 48, 53, 56]
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [1, 0, 0]
# critical present set:  ['2009_002521.jpg', '2008_000541.jpg']
# critical absent set:  ['2009_001782.jpg', '2009_002001.jpg']
# ---------------------------------------------------
# normal available: 339
# present_critical_per_block: ['2008_000541.jpg']
# absent_critical_per_block: []
# critical_present:  [['2009_002521.jpg'], ['2008_000541.jpg']]
# critical_absent:  []
# critical_probes_used:  ['2009_002521.jpg', '2008_000541.jpg']
# probes_per_block : ['2008_007057.jpg', '2010_002127.jpg', '2010_003419.jpg']
# probes_per_block : ['2008_007057.jpg', '2010_002127.jpg', '2010_003419.jpg', '2009_000995.jpg', '2011_001991.jpg', '2010_001118.jpg', '2008_002119.jpg', '2010_005996.jpg']
# probes:  [['2008_008263.jpg', '2011_001834.jpg', '2008_006452.jpg', '2011_000661.jpg', '2009_001568.jpg', '2008_001367.jpg', '2008_000501.jpg', '2010_003287.jpg'], ['2008_007057.jpg', '2010_002127.jpg', '2010_003419.jpg', '2009_000995.jpg', '2011_001991.jpg', '2010_001118.jpg', '2008_002119.jpg', '2010_005996.jpg']]
# Present Used in block:  3
# Absent Used in block 5
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 32.480531856762035, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' cat', nan, nan, nan, 30.22651637937125, 'high', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  98
# critical_probes_used ['2009_002521.jpg', '2008_000541.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical
# image 12 Target Absent
# image 17 Target Present
# image 20 Critical
# image 23 Target Absent
# image 31 Target Absent
# image 33 Target Absent
# image 43 Target Present
# image 48 Target Absent
# image 53 Target Present
# image 56 Critical Present
# block: 120
# ---------------------------------------------------
# probes_position:  [12, 17, 23, 31, 33, 43, 48, 53, 56]
# 60 60
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_002521.jpg', '2008_000541.jpg']
# critical absent set:  ['2009_001782.jpg', '2009_002001.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: ['2009_001782.jpg']
# critical_present:  [['2009_002521.jpg'], ['2008_000541.jpg']]
# critical_absent:  [['2009_001782.jpg']]
# critical_probes_used:  ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg']
# probes_per_block : ['2008_003045.jpg', '2008_004270.jpg', '2010_004753.jpg', '2009_000716.jpg', '2009_000619.jpg']
# probes_per_block : ['2008_003045.jpg', '2008_004270.jpg', '2010_004753.jpg', '2009_000716.jpg', '2009_000619.jpg', '2011_001591.jpg', '2008_000112.jpg', '2009_001305.jpg']
# probes:  [['2008_008263.jpg', '2011_001834.jpg', '2008_006452.jpg', '2011_000661.jpg', '2009_001568.jpg', '2008_001367.jpg', '2008_000501.jpg', '2010_003287.jpg'], ['2008_007057.jpg', '2010_002127.jpg', '2010_003419.jpg', '2009_000995.jpg', '2011_001991.jpg', '2010_001118.jpg', '2008_002119.jpg', '2010_005996.jpg'], ['2008_003045.jpg', '2008_004270.jpg', '2010_004753.jpg', '2009_000716.jpg', '2009_000619.jpg', '2011_001591.jpg', '2008_000112.jpg', '2009_001305.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 21.22948510797022, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 21.001227278103954, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  147
# critical_probes_used ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ciao2 2
# ciao2 2
# ------------------
# [1, 6, 9, 17, 20, 25, 31, 34, 44, 48, 55] 11
# gap_check:  [9, 31, 44]
# 11
# (1, 'Target Present')
# (6, 'Target Absent')
# (9, 'Critical Absent')
# (17, 'Target Present')
# (20, 'Target Present')
# (25, 'Target Present')
# (31, 'Critical')
# (34, 'Target Present')
# (44, 'Critical')
# (48, 'Target Absent')
# (55, 'Target Absent')
# [(1, 'Target Present'), (6, 'Target Absent'), (9, 'Critical Absent'), (17, 'Target Present'), (20, 'Target Present'), (25, 'Target Present'), (31, 'Critical'), (34, 'Target Present'), (44, 'Critical'), (48, 'Target Absent'), (55, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 6 Target Absent
# image 9 Critical Absent
# image 17 Target Present
# image 20 Target Present
# image 25 Target Present
# image 31 Critical
# image 34 Target Present
# image 44 Critical
# image 48 Target Absent
# image 55 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 6, 9, 17, 20, 25, 34, 48, 55]
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_002521.jpg', '2008_000541.jpg']
# critical absent set:  ['2009_001782.jpg', '2009_002001.jpg']
# ---------------------------------------------------
# normal available: 241
# present_critical_per_block: []
# absent_critical_per_block: ['2009_002001.jpg']
# critical_present:  [['2009_002521.jpg'], ['2008_000541.jpg']]
# critical_absent:  [['2009_001782.jpg'], ['2009_002001.jpg']]
# critical_probes_used:  ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# probes_per_block : ['2008_008229.jpg', '2008_004487.jpg', '2010_004423.jpg', '2009_004849.jpg', '2011_001221.jpg']
# probes_per_block : ['2008_008229.jpg', '2008_004487.jpg', '2010_004423.jpg', '2009_004849.jpg', '2011_001221.jpg', '2008_006216.jpg', '2008_005347.jpg', '2009_000067.jpg']
# probes:  [['2008_008263.jpg', '2011_001834.jpg', '2008_006452.jpg', '2011_000661.jpg', '2009_001568.jpg', '2008_001367.jpg', '2008_000501.jpg', '2010_003287.jpg'], ['2008_007057.jpg', '2010_002127.jpg', '2010_003419.jpg', '2009_000995.jpg', '2011_001991.jpg', '2010_001118.jpg', '2008_002119.jpg', '2010_005996.jpg'], ['2008_003045.jpg', '2008_004270.jpg', '2010_004753.jpg', '2009_000716.jpg', '2009_000619.jpg', '2011_001591.jpg', '2008_000112.jpg', '2009_001305.jpg'], ['2008_008229.jpg', '2008_004487.jpg', '2010_004423.jpg', '2009_004849.jpg', '2011_001221.jpg', '2008_006216.jpg', '2008_005347.jpg', '2009_000067.jpg']]
# Present Used in block:  5
# Absent Used in block 3
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' car', ' aeroplane', nan, nan, nan, 32.224520766602424, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' bottle', ' diningtable', nan, 35.13485651284549, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  196
# critical_probes_used ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 6 Target Absent
# image 9 Critical Absent
# image 17 Target Present
# image 20 Target Present
# image 25 Target Present
# image 31 Critical
# image 34 Target Present
# image 44 Critical
# image 48 Target Absent
# image 55 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 6, 9, 17, 20, 25, 34, 48, 55]
# 60 60
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_002521.jpg', '2008_000541.jpg']
# critical absent set:  ['2009_001782.jpg', '2009_002001.jpg']
# ---------------------------------------------------
# normal available: 192
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002521.jpg'], ['2008_000541.jpg']]
# critical_absent:  [['2009_001782.jpg'], ['2009_002001.jpg']]
# critical_probes_used:  ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# probes_per_block : ['2008_001205.jpg', '2008_002704.jpg', '2008_000912.jpg', '2009_005075.jpg']
# probes_per_block : ['2008_001205.jpg', '2008_002704.jpg', '2008_000912.jpg', '2009_005075.jpg', '2008_008533.jpg', '2011_002558.jpg', '2009_002137.jpg', '2008_008506.jpg', '2008_002379.jpg']
# probes:  [['2008_008263.jpg', '2011_001834.jpg', '2008_006452.jpg', '2011_000661.jpg', '2009_001568.jpg', '2008_001367.jpg', '2008_000501.jpg', '2010_003287.jpg'], ['2008_007057.jpg', '2010_002127.jpg', '2010_003419.jpg', '2009_000995.jpg', '2011_001991.jpg', '2010_001118.jpg', '2008_002119.jpg', '2010_005996.jpg'], ['2008_003045.jpg', '2008_004270.jpg', '2010_004753.jpg', '2009_000716.jpg', '2009_000619.jpg', '2011_001591.jpg', '2008_000112.jpg', '2009_001305.jpg'], ['2008_008229.jpg', '2008_004487.jpg', '2010_004423.jpg', '2009_004849.jpg', '2011_001221.jpg', '2008_006216.jpg', '2008_005347.jpg', '2009_000067.jpg'], ['2008_001205.jpg', '2008_002704.jpg', '2008_000912.jpg', '2009_005075.jpg', '2008_008533.jpg', '2011_002558.jpg', '2009_002137.jpg', '2008_008506.jpg', '2008_002379.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', nan, nan, nan, nan, 19.25273490800736, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 17.33155808066949, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' chair', nan, nan, nan, 14.420942277552813, 'low', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  244
# critical_probes_used ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [2, 8, 14, 17, 18, 22, 28, 34, 40, 44, 50, 56] 12
# gap_check:  [2, 18, 22]
# 12
# (2, 'Critical')
# (8, 'Target Absent')
# (14, 'Target Absent')
# (17, 'Target Absent')
# (18, 'Critical')
# (22, 'Critical')
# (28, 'Target Present')
# (34, 'Target Present')
# (40, 'Target Absent')
# (44, 'Target Present')
# (50, 'Target Absent')
# (56, 'Target Present')
# [(2, 'Critical'), (8, 'Target Absent'), (14, 'Target Absent'), (17, 'Target Absent'), (18, 'Critical'), (22, 'Critical'), (28, 'Target Present'), (34, 'Target Present'), (40, 'Target Absent'), (44, 'Target Present'), (50, 'Target Absent'), (56, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Critical
# image 8 Target Absent
# image 14 Target Absent
# image 17 Target Absent
# image 18 Critical
# image 22 Critical
# image 28 Target Present
# image 34 Target Present
# image 40 Target Absent
# image 44 Target Present
# image 50 Target Absent
# image 56 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [8, 14, 17, 28, 34, 40, 44, 50, 56]
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_002521.jpg', '2008_000541.jpg']
# critical absent set:  ['2009_001782.jpg', '2009_002001.jpg']
# ---------------------------------------------------
# normal available: 144
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002521.jpg'], ['2008_000541.jpg']]
# critical_absent:  [['2009_001782.jpg'], ['2009_002001.jpg']]
# critical_probes_used:  ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# probes_per_block : ['2009_002571.jpg', '2010_005606.jpg', '2010_002742.jpg', '2009_000760.jpg']
# probes_per_block : ['2009_002571.jpg', '2010_005606.jpg', '2010_002742.jpg', '2009_000760.jpg', '2008_000270.jpg', '2008_005878.jpg', '2009_002306.jpg', '2010_006033.jpg', '2011_001649.jpg']
# probes:  [['2008_008263.jpg', '2011_001834.jpg', '2008_006452.jpg', '2011_000661.jpg', '2009_001568.jpg', '2008_001367.jpg', '2008_000501.jpg', '2010_003287.jpg'], ['2008_007057.jpg', '2010_002127.jpg', '2010_003419.jpg', '2009_000995.jpg', '2011_001991.jpg', '2010_001118.jpg', '2008_002119.jpg', '2010_005996.jpg'], ['2008_003045.jpg', '2008_004270.jpg', '2010_004753.jpg', '2009_000716.jpg', '2009_000619.jpg', '2011_001591.jpg', '2008_000112.jpg', '2009_001305.jpg'], ['2008_008229.jpg', '2008_004487.jpg', '2010_004423.jpg', '2009_004849.jpg', '2011_001221.jpg', '2008_006216.jpg', '2008_005347.jpg', '2009_000067.jpg'], ['2008_001205.jpg', '2008_002704.jpg', '2008_000912.jpg', '2009_005075.jpg', '2008_008533.jpg', '2011_002558.jpg', '2009_002137.jpg', '2008_008506.jpg', '2008_002379.jpg'], ['2009_002571.jpg', '2010_005606.jpg', '2010_002742.jpg', '2009_000760.jpg', '2008_000270.jpg', '2008_005878.jpg', '2009_002306.jpg', '2010_006033.jpg', '2011_001649.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' person', ' diningtable', ' bottle', nan, 28.939513311425664, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' dog', nan, 34.099790178372324, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 29.806819625699735, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  292
# critical_probes_used ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Critical
# image 8 Target Absent
# image 14 Target Absent
# image 17 Target Absent
# image 18 Critical
# image 22 Critical
# image 28 Target Present
# image 34 Target Present
# image 40 Target Absent
# image 44 Target Present
# image 50 Target Absent
# image 56 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [8, 14, 17, 28, 34, 40, 44, 50, 56]
# 60 60
# present_crit_distribution_original:  [1, 0, 0, 0]
# absent_crit_distribution_original:  [0, 1, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2009_002521.jpg', '2008_000541.jpg']
# critical absent set:  ['2009_001782.jpg', '2009_002001.jpg']
# ---------------------------------------------------
# normal available: 96
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002521.jpg'], ['2008_000541.jpg']]
# critical_absent:  [['2009_001782.jpg'], ['2009_002001.jpg']]
# critical_probes_used:  ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# probes_per_block : ['2010_005780.jpg', '2009_005308.jpg', '2010_000132.jpg', '2008_004171.jpg', '2008_001185.jpg']
# probes_per_block : ['2010_005780.jpg', '2009_005308.jpg', '2010_000132.jpg', '2008_004171.jpg', '2008_001185.jpg', '2010_004145.jpg', '2010_001907.jpg', '2011_000293.jpg', '2008_005345.jpg']
# probes:  [['2008_008263.jpg', '2011_001834.jpg', '2008_006452.jpg', '2011_000661.jpg', '2009_001568.jpg', '2008_001367.jpg', '2008_000501.jpg', '2010_003287.jpg'], ['2008_007057.jpg', '2010_002127.jpg', '2010_003419.jpg', '2009_000995.jpg', '2011_001991.jpg', '2010_001118.jpg', '2008_002119.jpg', '2010_005996.jpg'], ['2008_003045.jpg', '2008_004270.jpg', '2010_004753.jpg', '2009_000716.jpg', '2009_000619.jpg', '2011_001591.jpg', '2008_000112.jpg', '2009_001305.jpg'], ['2008_008229.jpg', '2008_004487.jpg', '2010_004423.jpg', '2009_004849.jpg', '2011_001221.jpg', '2008_006216.jpg', '2008_005347.jpg', '2009_000067.jpg'], ['2008_001205.jpg', '2008_002704.jpg', '2008_000912.jpg', '2009_005075.jpg', '2008_008533.jpg', '2011_002558.jpg', '2009_002137.jpg', '2008_008506.jpg', '2008_002379.jpg'], ['2009_002571.jpg', '2010_005606.jpg', '2010_002742.jpg', '2009_000760.jpg', '2008_000270.jpg', '2008_005878.jpg', '2009_002306.jpg', '2010_006033.jpg', '2011_001649.jpg'], ['2010_005780.jpg', '2009_005308.jpg', '2010_000132.jpg', '2008_004171.jpg', '2008_001185.jpg', '2010_004145.jpg', '2010_001907.jpg', '2011_000293.jpg', '2008_005345.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', nan, nan, nan, nan, 15.77924938689554, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 15.759492066531687, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' chair', ' diningtable', nan, nan, nan, 15.830708942989276, 'low', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  340
# critical_probes_used ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
#
jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' car', ' chair', ' bicycle', ' person', 30.133244112833108, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' bird', ' boat', nan, nan, 31.913409738647122, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 31.26103763923315, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  388
# critical_probes_used ['2009_002521.jpg', '2008_000541.jpg', '2009_001782.jpg', '2009_002001.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 7 Target Present
# image 17 Critical
# image 22 Target Present
# image 25 Critical
# image 33 Target Absent
# image 37 Critical
# image 43 Target Present
# image 46 Target Absent
# image 52 Target Present
# image 54 Target Present
# image 55 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 7, 22, 33, 43, 46, 52, 54, 55]
# 60 60
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# len(trials):  1440

# %%
######################
### FOURTH ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1441)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  9
# Critical, high:  9
# Are all critical trials unique?  True
# Number of critical probes:  6
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  2
# critical_high_absent_probes:  2
# cycles :  6
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  ['2010_003911.jpg', '2010_002775.jpg']
# critical absent set:  ['2009_000919.jpg', '2009_001470.jpg', '2008_002084.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 390
# present_critical_per_block: []
# absent_critical_per_block: ['2009_001470.jpg']
# critical_present:  []
# critical_absent:  [['2009_001470.jpg']]
# critical_probes_used:  ['2009_001470.jpg']
# probes_per_block : ['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg']
# probes_per_block : ['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg']
# probes:  [['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 16.396955524186414, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' chair', nan, nan, nan, 14.420942277552813, 'low', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  49
# critical_probes_used ['2009_001470.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [5, 14, 21, 26, 30, 36, 37, 43, 44, 47, 48] 11
# gap_check:  [5, 14, 44]
# 11
# (5, 'Critical')
# (14, 'Critical Absent')
# (21, 'Target Absent')
# (26, 'Target Present')
# (30, 'Target Present')
# (36, 'Target Present')
# (37, 'Target Absent')
# (43, 'Target Present')
# (44, 'Critical')
# (47, 'Target Absent')
# (48, 'Target Absent')
# [(5, 'Critical'), (14, 'Critical Absent'), (21, 'Target Absent'), (26, 'Target Present'), (30, 'Target Present'), (36, 'Target Present'), (37, 'Target Absent'), (43, 'Target Present'), (44, 'Critical'), (47, 'Target Absent'), (48, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical
# image 14 Critical Absent
# image 21 Target Absent
# image 26 Target Present
# image 30 Target Present
# image 36 Target Present
# image 37 Target Absent
# image 43 Target Present
# image 44 Critical
# image 47 Target Absent
# image 48 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [14, 21, 26, 30, 36, 37, 43, 47, 48]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  ['2010_003911.jpg', '2010_002775.jpg']
# critical absent set:  ['2009_000919.jpg', '2009_001470.jpg', '2008_002084.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 341
# present_critical_per_block: []
# absent_critical_per_block: ['2009_003802.jpg']
# critical_present:  []
# critical_absent:  [['2009_001470.jpg'], ['2009_003802.jpg']]
# critical_probes_used:  ['2009_001470.jpg', '2009_003802.jpg']
# probes_per_block : ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg']
# probes_per_block : ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg', '2009_000067.jpg', '2008_000619.jpg', '2010_002183.jpg', '2010_004778.jpg']
# probes:  [['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg'], ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg', '2009_000067.jpg', '2008_000619.jpg', '2010_002183.jpg', '2010_004778.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' car', ' aeroplane', nan, nan, nan, 32.224520766602424, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 37.706201599515055, 'high', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  98
# critical_probes_used ['2009_001470.jpg', '2009_003802.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Critical
# image 14 Critical Absent
# image 21 Target Absent
# image 26 Target Present
# image 30 Target Present
# image 36 Target Present
# image 37 Target Absent
# image 43 Target Present
# image 44 Critical
# image 47 Target Absent
# image 48 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [14, 21, 26, 30, 36, 37, 43, 47, 48]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 1, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  ['2010_003911.jpg', '2010_002775.jpg']
# critical absent set:  ['2009_000919.jpg', '2009_001470.jpg', '2008_002084.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 292
# present_critical_per_block: ['2010_003911.jpg']
# absent_critical_per_block: []
# critical_present:  [['2010_003911.jpg']]
# critical_absent:  [['2009_001470.jpg'], ['2009_003802.jpg']]
# critical_probes_used:  ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg']
# probes_per_block : ['2011_001591.jpg', '2009_005044.jpg', '2009_001894.jpg', '2009_003686.jpg']
# probes_per_block : ['2011_001591.jpg', '2009_005044.jpg', '2009_001894.jpg', '2009_003686.jpg', '2011_001198.jpg', '2010_003400.jpg', '2010_003890.jpg', '2008_006072.jpg']
# probes:  [['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg'], ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg', '2009_000067.jpg', '2008_000619.jpg', '2010_002183.jpg', '2010_004778.jpg'], ['2011_001591.jpg', '2009_005044.jpg', '2009_001894.jpg', '2009_003686.jpg', '2011_001198.jpg', '2010_003400.jpg', '2010_003890.jpg', '2008_006072.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' bottle', ' dog', ' diningtable', nan, nan, 21.034646910874567, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 19.735592352687934, 'low', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  147
# critical_probes_used ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 1
# absent_critical_per_block 0
# ciao2 2
# ciao2 2
# ------------------
# [0, 1, 11, 20, 22, 32, 35, 38, 44, 53, 56] 11
# gap_check:  [11, 38, 44]
# 11
# (0, 'Target Absent')
# (1, 'Target Absent')
# (11, 'Critical Present')
# (20, 'Target Present')
# (22, 'Target Present')
# (32, 'Target Absent')
# (35, 'Target Present')
# (38, 'Critical')
# (44, 'Critical')
# (53, 'Target Present')
# (56, 'Target Absent')
# [(0, 'Target Absent'), (1, 'Target Absent'), (11, 'Critical Present'), (20, 'Target Present'), (22, 'Target Present'), (32, 'Target Absent'), (35, 'Target Present'), (38, 'Critical'), (44, 'Critical'), (53, 'Target Present'), (56, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 1 Target Absent
# image 11 Critical Present
# image 20 Target Present
# image 22 Target Present
# image 32 Target Absent
# image 35 Target Present
# image 38 Critical
# image 44 Critical
# image 53 Target Present
# image 56 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 1, 11, 20, 22, 32, 35, 53, 56]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 1, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  ['2010_003911.jpg', '2010_002775.jpg']
# critical absent set:  ['2009_000919.jpg', '2009_001470.jpg', '2008_002084.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 243
# present_critical_per_block: ['2010_002775.jpg']
# absent_critical_per_block: []
# critical_present:  [['2010_003911.jpg'], ['2010_002775.jpg']]
# critical_absent:  [['2009_001470.jpg'], ['2009_003802.jpg']]
# critical_probes_used:  ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg']
# probes_per_block : ['2008_004459.jpg', '2011_002641.jpg', '2008_007629.jpg', '2008_003193.jpg']
# probes_per_block : ['2008_004459.jpg', '2011_002641.jpg', '2008_007629.jpg', '2008_003193.jpg', '2008_001862.jpg', '2008_005090.jpg', '2008_007423.jpg', '2008_005702.jpg']
# probes:  [['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg'], ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg', '2009_000067.jpg', '2008_000619.jpg', '2010_002183.jpg', '2010_004778.jpg'], ['2011_001591.jpg', '2009_005044.jpg', '2009_001894.jpg', '2009_003686.jpg', '2011_001198.jpg', '2010_003400.jpg', '2010_003890.jpg', '2008_006072.jpg'], ['2008_004459.jpg', '2011_002641.jpg', '2008_007629.jpg', '2008_003193.jpg', '2008_001862.jpg', '2008_005090.jpg', '2008_007423.jpg', '2008_005702.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' bottle', ' diningtable', nan, nan, 34.072917550349175, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 29.875362071673013, 'high', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  196
# critical_probes_used ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Absent
# image 1 Target Absent
# image 11 Critical Present
# image 20 Target Present
# image 22 Target Present
# image 32 Target Absent
# image 35 Target Present
# image 38 Critical
# image 44 Critical
# image 53 Target Present
# image 56 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 1, 11, 20, 22, 32, 35, 53, 56]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2010_003911.jpg', '2010_002775.jpg']
# critical absent set:  ['2009_000919.jpg', '2009_001470.jpg', '2008_002084.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: ['2009_000919.jpg']
# critical_present:  [['2010_003911.jpg'], ['2010_002775.jpg']]
# critical_absent:  [['2009_001470.jpg'], ['2009_003802.jpg'], ['2009_000919.jpg']]
# critical_probes_used:  ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg', '2009_000919.jpg']
# probes_per_block : ['2008_001098.jpg', '2008_001542.jpg', '2010_000090.jpg', '2008_007096.jpg']
# probes_per_block : ['2008_001098.jpg', '2008_001542.jpg', '2010_000090.jpg', '2008_007096.jpg', '2011_000481.jpg', '2009_001406.jpg', '2008_000112.jpg', '2011_003145.jpg']
# probes:  [['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg'], ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg', '2009_000067.jpg', '2008_000619.jpg', '2010_002183.jpg', '2010_004778.jpg'], ['2011_001591.jpg', '2009_005044.jpg', '2009_001894.jpg', '2009_003686.jpg', '2011_001198.jpg', '2010_003400.jpg', '2010_003890.jpg', '2008_006072.jpg'], ['2008_004459.jpg', '2011_002641.jpg', '2008_007629.jpg', '2008_003193.jpg', '2008_001862.jpg', '2008_005090.jpg', '2008_007423.jpg', '2008_005702.jpg'], ['2008_001098.jpg', '2008_001542.jpg', '2010_000090.jpg', '2008_007096.jpg', '2011_000481.jpg', '2009_001406.jpg', '2008_000112.jpg', '2011_003145.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' car', nan, nan, nan, nan, 18.78745072135656, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' bicycle', ' bottle', nan, nan, nan, 18.893798014446215, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  245
# critical_probes_used ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg', '2009_000919.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [0, 7, 15, 16, 19, 22, 26, 28, 38, 42, 45] 11
# gap_check:  [22, 38, 42]
# 11
# (0, 'Target Present')
# (7, 'Target Absent')
# (15, 'Target Present')
# (16, 'Target Absent')
# (19, 'Target Present')
# (22, 'Critical')
# (26, 'Target Present')
# (28, 'Target Absent')
# (38, 'Critical Absent')
# (42, 'Critical')
# (45, 'Target Absent')
# [(0, 'Target Present'), (7, 'Target Absent'), (15, 'Target Present'), (16, 'Target Absent'), (19, 'Target Present'), (22, 'Critical'), (26, 'Target Present'), (28, 'Target Absent'), (38, 'Critical Absent'), (42, 'Critical'), (45, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Present
# image 7 Target Absent
# image 15 Target Present
# image 16 Target Absent
# image 19 Target Present
# image 22 Critical
# image 26 Target Present
# image 28 Target Absent
# image 38 Critical Absent
# image 42 Critical
# image 45 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 7, 15, 16, 19, 26, 28, 38, 45]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2010_003911.jpg', '2010_002775.jpg']
# critical absent set:  ['2009_000919.jpg', '2009_001470.jpg', '2008_002084.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 145
# present_critical_per_block: []
# absent_critical_per_block: ['2008_002084.jpg']
# critical_present:  [['2010_003911.jpg'], ['2010_002775.jpg']]
# critical_absent:  [['2009_001470.jpg'], ['2009_003802.jpg'], ['2009_000919.jpg'], ['2008_002084.jpg']]
# critical_probes_used:  ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg', '2009_000919.jpg', '2008_002084.jpg']
# probes_per_block : ['2008_005526.jpg', '2008_000984.jpg', '2010_003729.jpg', '2010_005170.jpg']
# probes_per_block : ['2008_005526.jpg', '2008_000984.jpg', '2010_003729.jpg', '2010_005170.jpg', '2008_008097.jpg', '2008_003081.jpg', '2010_000536.jpg', '2008_000704.jpg']
# probes:  [['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg'], ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg', '2009_000067.jpg', '2008_000619.jpg', '2010_002183.jpg', '2010_004778.jpg'], ['2011_001591.jpg', '2009_005044.jpg', '2009_001894.jpg', '2009_003686.jpg', '2011_001198.jpg', '2010_003400.jpg', '2010_003890.jpg', '2008_006072.jpg'], ['2008_004459.jpg', '2011_002641.jpg', '2008_007629.jpg', '2008_003193.jpg', '2008_001862.jpg', '2008_005090.jpg', '2008_007423.jpg', '2008_005702.jpg'], ['2008_001098.jpg', '2008_001542.jpg', '2010_000090.jpg', '2008_007096.jpg', '2011_000481.jpg', '2009_001406.jpg', '2008_000112.jpg', '2011_003145.jpg'], ['2008_005526.jpg', '2008_000984.jpg', '2010_003729.jpg', '2010_005170.jpg', '2008_008097.jpg', '2008_003081.jpg', '2010_000536.jpg', '2008_000704.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 31.676385713707838, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' person', ' dog', ' sofa', nan, nan, 29.935618386927253, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  294
# critical_probes_used ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg', '2009_000919.jpg', '2008_002084.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Present
# image 7 Target Absent
# image 15 Target Present
# image 16 Target Absent
# image 19 Target Present
# image 22 Critical
# image 26 Target Present
# image 28 Target Absent
# image 38 Critical Absent
# image 42 Critical
# image 45 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [0, 7, 15, 16, 19, 26, 28, 38, 45]
# 60 60
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2010_003911.jpg', '2010_002775.jpg']
# critical absent set:  ['2009_000919.jpg', '2009_001470.jpg', '2008_002084.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 96
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2010_003911.jpg'], ['2010_002775.jpg']]
# critical_absent:  [['2009_001470.jpg'], ['2009_003802.jpg'], ['2009_000919.jpg'], ['2008_002084.jpg']]
# critical_probes_used:  ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg', '2009_000919.jpg', '2008_002084.jpg']
# probes_per_block : ['2008_000183.jpg', '2010_004014.jpg', '2008_000189.jpg', '2008_003709.jpg', '2010_004425.jpg']
# probes_per_block : ['2008_000183.jpg', '2010_004014.jpg', '2008_000189.jpg', '2008_003709.jpg', '2010_004425.jpg', '2008_008331.jpg', '2009_002594.jpg', '2008_000940.jpg', '2010_000229.jpg']
# probes:  [['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg'], ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg', '2009_000067.jpg', '2008_000619.jpg', '2010_002183.jpg', '2010_004778.jpg'], ['2011_001591.jpg', '2009_005044.jpg', '2009_001894.jpg', '2009_003686.jpg', '2011_001198.jpg', '2010_003400.jpg', '2010_003890.jpg', '2008_006072.jpg'], ['2008_004459.jpg', '2011_002641.jpg', '2008_007629.jpg', '2008_003193.jpg', '2008_001862.jpg', '2008_005090.jpg', '2008_007423.jpg', '2008_005702.jpg'], ['2008_001098.jpg', '2008_001542.jpg', '2010_000090.jpg', '2008_007096.jpg', '2011_000481.jpg', '2009_001406.jpg', '2008_000112.jpg', '2011_003145.jpg'], ['2008_005526.jpg', '2008_000984.jpg', '2010_003729.jpg', '2010_005170.jpg', '2008_008097.jpg', '2008_003081.jpg', '2010_000536.jpg', '2008_000704.jpg'], ['2008_000183.jpg', '2010_004014.jpg', '2008_000189.jpg', '2008_003709.jpg', '2010_004425.jpg', '2008_008331.jpg', '2009_002594.jpg', '2008_000940.jpg', '2010_000229.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', ' dog', ' person', nan, nan, 21.020159211351668, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 19.54050687002545, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 16.417039192791336, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  342
# critical_probes_used ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg', '2009_000919.jpg', '2008_002084.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [2, 7, 8, 13, 16, 22, 31, 41, 47, 50, 53, 54] 12
# gap_check:  [16, 22, 47]
# 12
# (2, 'Target Absent')
# (7, 'Target Present')
# (8, 'Target Absent')
# (13, 'Target Present')
# (16, 'Critical')
# (22, 'Critical')
# (31, 'Target Absent')
# (41, 'Target Present')
# (47, 'Critical')
# (50, 'Target Present')
# (53, 'Target Present')
# (54, 'Target Absent')
# [(2, 'Target Absent'), (7, 'Target Present'), (8, 'Target Absent'), (13, 'Target Present'), (16, 'Critical'), (22, 'Critical'), (31, 'Target Absent'), (41, 'Target Present'), (47, 'Critical'), (50, 'Target Present'), (53, 'Target Present'), (54, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Absent
# image 7 Target Present
# image 8 Target Absent
# image 13 Target Present
# image 16 Critical
# image 22 Critical
# image 31 Target Absent
# image 41 Target Present
# image 47 Critical
# image 50 Target Present
# image 53 Target Present
# image 54 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [2, 7, 8, 13, 31, 41, 50, 53, 54]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2010_003911.jpg', '2010_002775.jpg']
# critical absent set:  ['2009_000919.jpg', '2009_001470.jpg', '2008_002084.jpg', '2009_003802.jpg']
# ---------------------------------------------------
# normal available: 48
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2010_003911.jpg'], ['2010_002775.jpg']]
# critical_absent:  [['2009_001470.jpg'], ['2009_003802.jpg'], ['2009_000919.jpg'], ['2008_002084.jpg']]
# critical_probes_used:  ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg', '2009_000919.jpg', '2008_002084.jpg']
# probes_per_block : ['2008_000860.jpg', '2008_002350.jpg', '2009_002897.jpg', '2010_000865.jpg', '2008_006870.jpg']
# probes_per_block : ['2008_000860.jpg', '2008_002350.jpg', '2009_002897.jpg', '2010_000865.jpg', '2008_006870.jpg', '2008_001673.jpg', '2008_007970.jpg', '2008_000202.jpg', '2008_003844.jpg']
# probes:  [['2008_003767.jpg', '2010_001988.jpg', '2008_002145.jpg', '2008_005046.jpg', '2008_004814.jpg', '2010_004662.jpg', '2009_004737.jpg', '2008_006998.jpg'], ['2009_003338.jpg', '2008_000705.jpg', '2008_000982.jpg', '2011_002555.jpg', '2009_000067.jpg', '2008_000619.jpg', '2010_002183.jpg', '2010_004778.jpg'], ['2011_001591.jpg', '2009_005044.jpg', '2009_001894.jpg', '2009_003686.jpg', '2011_001198.jpg', '2010_003400.jpg', '2010_003890.jpg', '2008_006072.jpg'], ['2008_004459.jpg', '2011_002641.jpg', '2008_007629.jpg', '2008_003193.jpg', '2008_001862.jpg', '2008_005090.jpg', '2008_007423.jpg', '2008_005702.jpg'], ['2008_001098.jpg', '2008_001542.jpg', '2010_000090.jpg', '2008_007096.jpg', '2011_000481.jpg', '2009_001406.jpg', '2008_000112.jpg', '2011_003145.jpg'], ['2008_005526.jpg', '2008_000984.jpg', '2010_003729.jpg', '2010_005170.jpg', '2008_008097.jpg', '2008_003081.jpg', '2010_000536.jpg', '2008_000704.jpg'], ['2008_000183.jpg', '2010_004014.jpg', '2008_000189.jpg', '2008_003709.jpg', '2010_004425.jpg', '2008_008331.jpg', '2009_002594.jpg', '2008_000940.jpg', '2010_000229.jpg'], ['2008_000860.jpg', '2008_002350.jpg', '2009_002897.jpg', '2010_000865.jpg', '2008_006870.jpg', '2008_001673.jpg', '2008_007970.jpg', '2008_000202.jpg', '2008_003844.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' chair', nan, nan, nan, 34.96662806576853, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 32.06509585553637, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 31.19357078875772, 'high', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  390
# critical_probes_used ['2009_001470.jpg', '2009_003802.jpg', '2010_003911.jpg', '2010_002775.jpg', '2009_000919.jpg', '2008_002084.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 2 Target Absent
# image 7 Target Present
# image 8 Target Absent
# image 13 Target Present
# image 16 Critical
# image 22 Critical
# image 31 Target Absent
# image 41 Target Present
# image 47 Critical
# image 50 Target Present
# image 53 Target Present
# image 54 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [2, 7, 8, 13, 31, 41, 50, 53, 54]
# 60 60
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone1']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone1', 'tone1']
# ['tone1', 'tone2', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone1']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# len(trials):  1920

# %%
print len(normal_no_probe_before)
print len(normal_used)
print len(normal_no_probe_before) == len(set(normal_used))
print len(target_present_before)
print len(present_used)
print len(target_present_before) == len(set(present_used))
print len(target_absent_before)
print len(absent_used)
print len(target_absent_before) == len(set(absent_used))

#the following is not a good check
print len(set(critical_trials_before)) == len(set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes))

print set(critical_trials_before) == set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes)

print len(low_four)
print len(low_one) == len(low_two) == len(low_three) == len(low_four) == len(high_one) == len(high_two) == len(high_three) == len(high_four)
print len(set(low_one) & set(low_two) & set(low_three) & set(low_four) & set(high_one) & set(high_two) & set(high_three) & set(high_four))
# Out:
# 390
# 390
# True
# 36
# 34
# False
# 36
# 32
# False
# True
# True
# 60
# True
# 0

# %%
for i in range(len(trials.keys())):
    trials[i+1].append(i/60+1)

import pickle
with open('../config/randomization.pik', 'wb') as of:
    pickle.dump(trials,of)

# %%
df = pd.DataFrame.from_dict(trials)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','image_name','block']
df.TS = df.TS.astype('float')
df.to_csv(mypath + '../Config/randomization_1.csv')

# %%
df
# Out:
#              Cat.1       Cat.2         Cat.3       Cat.4 Cat.5         TS  \
# 1              cat         NaN           NaN         NaN   NaN  20.850125
# 2              cat         NaN           NaN         NaN   NaN  14.127470
# 3        aeroplane         NaN           NaN         NaN   NaN  15.731963
# 4           person     bicycle           NaN         NaN   NaN  18.237768
# 5              car         NaN           NaN         NaN   NaN  16.197036
# 6             boat         NaN           NaN         NaN   NaN  20.470664
# 7           person        boat           NaN         NaN   NaN  19.901617
# 8           person        boat           NaN         NaN   NaN  19.194816
# 9              car      person           NaN         NaN   NaN  21.052977
# 10          person       chair   diningtable         NaN   NaN  20.561279
# 11       aeroplane         NaN           NaN         NaN   NaN  20.158044
# 12          person         cat           NaN         NaN   NaN  20.139878
# 13          person      bottle           NaN         NaN   NaN  19.869099
# 14             dog         NaN           NaN         NaN   NaN  18.981598
# 15             car      person           NaN         NaN   NaN  17.856306
# 16     pottedplant         NaN           NaN         NaN   NaN  20.584163
# 17           horse         NaN           NaN         NaN   NaN  19.598131
# 18       aeroplane         NaN           NaN         NaN   NaN  18.000362
# 19             dog         NaN           NaN         NaN   NaN  20.194434
# 20            bird         NaN           NaN         NaN   NaN  21.229485
# 21           chair         NaN           NaN         NaN   NaN  16.985442
# 22             car         NaN           NaN         NaN   NaN   9.156390
# 23            bird         NaN           NaN         NaN   NaN   8.062836
# 24       aeroplane         NaN           NaN         NaN   NaN   8.171245
# 25            sofa         cat           NaN         NaN   NaN  18.288477
# 26       tvmonitor        sofa           NaN         NaN   NaN  20.216264
# 27            boat         NaN           NaN         NaN   NaN  19.264338
# 28            boat         NaN           NaN         NaN   NaN  16.862966
# 29             car         NaN           NaN         NaN   NaN  19.759256
# 30          person         dog           NaN         NaN   NaN  20.712899
# ...            ...         ...           ...         ...   ...        ...
# 1891           car     bicycle        person         NaN   NaN  30.476929
# 1892        person       chair        bottle   tvmonitor   NaN  34.633056
# 1893           car     bicycle        person         NaN   NaN  28.874416
# 1894        person        sofa           cat         NaN   NaN  29.514190
# 1895           cat         NaN           NaN         NaN   NaN  31.779859
# 1896          bird         NaN           NaN         NaN   NaN  28.667065
# 1897     tvmonitor      bottle           NaN         NaN   NaN  29.993781
# 1898        person         cat           NaN         NaN   NaN  32.265109
# 1899        person   aeroplane           NaN         NaN   NaN  34.544145
# 1900        person       horse           NaN         NaN   NaN  30.927210
# 1901        person         cat           NaN         NaN   NaN  29.778544
# 1902           cat         NaN           NaN         NaN   NaN  29.401451
# 1903        person   aeroplane           NaN         NaN   NaN  31.885878
# 1904          sofa      person           NaN         NaN   NaN  31.051868
# 1905           car   aeroplane           NaN         NaN   NaN  35.872179
# 1906        person   motorbike           NaN         NaN   NaN  31.076858
# 1907     tvmonitor       chair          sofa         NaN   NaN  29.822033
# 1908   pottedplant       chair           NaN         NaN   NaN  34.966628
# 1909           dog         NaN           NaN         NaN   NaN  28.961817
# 1910           car        boat        person         NaN   NaN  32.759267
