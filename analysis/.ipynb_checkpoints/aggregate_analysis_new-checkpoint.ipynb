# %%
from random import random
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pdb
#%pdb
#mypath = 'E:/OneDrive - University College London/load/pilot_6_data/'
#mypath = 'C:/Users/KeK/OneDrive - University College London/load/pilot_6_data/'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from process_new import *
#from test import *
from tables import *

pd.set_option('display.max_rows', 9000)
pd.set_option('display.max_columns', 9000)

# %%
f = '../output/new_participants/participant_4.pik'
import pickle
with open(f,'r') as of:
    D = pickle.load(of)
df = pd.DataFrame.from_dict(D['experiment_details'],orient='index')

# %% [markdown]
# f = '../output/new_participants/participant_4.pik'
# import pickle
# with open(f,'r') as of:
#     D = pickle.load(of)
# df = pd.DataFrame.from_dict(D['experiment_details'],orient='index')
#
# new_df, notes = process(df)
# print notes

# %%
#Where do negative values come from?
df_negative = df[(df['RT_VS'] < 0)]
df_negative.shape
# Out:
# (0, 24)

# %%
df_criticals_only = df[(df['trial_type']=='Critical')]
df_criticals_only.shape
df_criticals_only
# Out:
#       load  block_number  moved_space_in_this_trial  present_absent  \
# 22     low             1                      False       No Target
# 38     low             1                      False       No Target
# 44     low             1                      False       No Target
# 66    high             2                      False       No Target
# 80    high             2                      False       No Target
# 118   high             2                      False       No Target
# 142   high             3                      False       No Target
# 158   high             3                      False       No Target
# 164   high             3                      False       No Target
# 186    low             4                      False       No Target
# 200    low             4                      False       No Target
# 238    low             4                      False       No Target
# 257   high             5                      False       No Target
# 272   high             5                      False       No Target
# 284   high             5                      False   Target Absent
# 315    low             6                      False       No Target
# 344    low             6                      False       No Target
# 354    low             6                      False       No Target
# 377    low             7                      False       No Target
# 392    low             7                      False       No Target
# 404    low             7                      False   Target Absent
# 435   high             8                      False       No Target
# 464   high             8                      False       No Target
# 474   high             8                      False       No Target
# 489    low             9                      False   Target Absent
# 498    low             9                      False       No Target
# 516    low             9                      False  Target Present
# 546   high            10                      False       No Target
# 561   high            10                      False       No Target
# 564   high            10                      False       No Target
# 609   high            11                      False   Target Absent
# 618   high            11                      False       No Target
# 636   high            11                      False  Target Present
# 666    low            12                      False       No Target
# 681    low            12                      False       No Target
# 684    low            12                      False       No Target
# 724   high            13                      False   Target Absent
# 736   high            13                      False       No Target
# 766   high            13                      False       No Target
# 807    low            14                      False       No Target
# 828    low            14                      False       No Target
# 831    low            14                      False       No Target
# 844    low            15                      False   Target Absent
# 856    low            15                      False       No Target
# 886    low            15                      False       No Target
# 927   high            16                      False       No Target
# 948   high            16                      False       No Target
# 951   high            16                      False       No Target
# 982    low            17                      False       No Target
# 986    low            17                      False   Target Absent
# 1009   low            17                      False       No Target
# 1064  high            18                      False   Target Absent
# 1067  high            18                      False       No Target
# 1078  high            18                      False       No Target
# 1102  high            19                      False       No Target
# 1106  high            19                      False   Target Absent
# 1129  high            19                      False       No Target
# 1184   low            20                      False   Target Absent
# 1187   low            20                      False       No Target
# 1198   low            20                      False       No Target
# 1217  high            21                      False       No Target
# 1238  high            21                      False  Target Present
# 1249  high            21                      False       No Target
# 1279   low            22                      False       No Target
# 1284   low            22                      False       No Target
# 1315   low            22                      False       No Target
# 1337   low            23                      False       No Target
# 1358   low            23                      False  Target Present
# 1369   low            23                      False       No Target
# 1399  high            24                      False       No Target
# 1404  high            24                      False       No Target
# 1435  high            24                      False       No Target
# 1463   low            25                      False       No Target
# 1477   low            25                      False       No Target
# 1494   low            25                      False       No Target
# 1501  high            26                      False       No Target
# 1511  high            26                      False       No Target
# 1542  high            26                      False       No Target
# 1583  high            27                      False       No Target
# 1597  high            27                      False       No Target
# 1614  high            27                      False       No Target
# 1621   low            28                      False       No Target
# 1631   low            28                      False       No Target
# 1662   low            28                      False       No Target
# 1688  high            29                      False       No Target
# 1698  high            29                      False       No Target
# 1733  high            29                      False       No Target
# 1745   low            30                      False   Target Absent
# 1750   low            30                      False   Target Absent
# 1774   low            30                      False       No Target
# 1808   low            31                      False       No Target
# 1818   low            31                      False       No Target
# 1853   low            31                      False       No Target
# 1865  high            32                      False   Target Absent
# 1870  high            32                      False   Target Absent
# 1894  high            32                      False       No Target
#
#              cat_4       cat_5 tone_hz         cat_1         cat_2  \
# 22             NaN         NaN   tone1   pottedplant           NaN
# 38             NaN         NaN   tone1         horse           NaN
# 44             NaN         NaN   tone1        person           car
# 66             NaN         NaN   tone1        person     aeroplane
# 80             NaN         NaN   tone1           bus          boat
# 118      tvmonitor         NaN   tone2   pottedplant          sofa
# 142            NaN         NaN   tone2   pottedplant     tvmonitor
# 158            NaN         NaN   tone2        person         chair
# 164            NaN         NaN   tone1          bird           NaN
# 186            NaN         NaN   tone2        person         horse
# 200            NaN         NaN   tone1         chair           NaN
# 238            NaN         NaN   tone2        bottle           NaN
# 257            NaN         NaN   tone2        person        bottle
# 272            NaN         NaN   tone1   pottedplant          sofa
# 284            NaN         NaN   tone2        person           dog
# 315            NaN         NaN   tone2          sofa           NaN
# 344            NaN         NaN   tone1        person           dog
# 354            NaN         NaN   tone2          boat           NaN
# 377            NaN         NaN   tone2           cat           NaN
# 392            NaN         NaN   tone2          bird           NaN
# 404            NaN         NaN   tone1     aeroplane           NaN
# 435            NaN         NaN   tone1          sofa         chair
# 464            NaN         NaN   tone1           car        person
# 474            NaN         NaN   tone2        person         horse
# 489            NaN         NaN   tone1          boat           NaN
# 498            NaN         NaN   tone1   pottedplant          sofa
# 516            NaN         NaN   tone1          sofa           dog
# 546    diningtable         NaN   tone1   pottedplant        person
# 561            NaN         NaN   tone2         horse           NaN
# 564            NaN         NaN   tone2        person           dog
# 609            NaN         NaN   tone1          bird          boat
# 618            NaN         NaN   tone1     aeroplane           NaN
# 636            NaN         NaN   tone1   pottedplant          sofa
# 666            NaN         NaN   tone2     aeroplane           NaN
# 681            NaN         NaN   tone1           car           NaN
# 684            NaN         NaN   tone1        person          boat
# 724    diningtable   tvmonitor   tone2   pottedplant          sofa
# 736            NaN         NaN   tone2     tvmonitor         chair
# 766            NaN         NaN   tone2        person   diningtable
# 807            NaN         NaN   tone1        person           dog
# 828            NaN         NaN   tone2           cat           NaN
# 831            NaN         NaN   tone2     tvmonitor          sofa
# 844            NaN         NaN   tone2        person        bottle
# 856            NaN         NaN   tone2         chair   diningtable
# 886            NaN         NaN   tone1          bird           NaN
# 927            NaN         NaN   tone1           cat           NaN
# 948            NaN         NaN   tone2        person          boat
# 951            NaN         NaN   tone2           car           NaN
# 982            NaN         NaN   tone1        person          sofa
# 986            NaN         NaN   tone1        person          sofa
# 1009           NaN         NaN   tone1        bottle           NaN
# 1064           NaN         NaN   tone2   pottedplant           car
# 1067           NaN         NaN   tone2        person     aeroplane
# 1078           NaN         NaN   tone1          boat           NaN
# 1102           NaN         NaN   tone1          bird           NaN
# 1106           NaN         NaN   tone2        person           cat
# 1129           NaN         NaN   tone2        person         chair
# 1184           NaN         NaN   tone1          boat           NaN
# 1187           NaN         NaN   tone1           car           NaN
# 1198           NaN         NaN   tone1           dog           NaN
# 1217           NaN         NaN   tone2        person        bottle
# 1238        person         NaN   tone2     tvmonitor          sofa
# 1249           NaN         NaN   tone1        person         horse
# 1279           NaN         NaN   tone1        person          boat
# 1284           NaN         NaN   tone2         chair   diningtable
# 1315           NaN         NaN   tone1          bird           NaN
# 1337           NaN         NaN   tone2        person         horse
# 1358           NaN         NaN   tone2           cat           NaN
# 1369           NaN         NaN   tone2   pottedplant          sofa
# 1399           NaN         NaN   tone1        person         chair
# 1404           NaN         NaN   tone2         chair        bottle
# 1435           NaN         NaN   tone2   pottedplant     tvmonitor
# 1463           NaN         NaN   tone1        person          boat
# 1477           NaN         NaN   tone1     aeroplane           NaN
# 1494           NaN         NaN   tone2   pottedplant           NaN
# 1501           NaN         NaN   tone2     aeroplane           NaN
# 1511           NaN         NaN   tone1         chair          bird
# 1542           NaN         NaN   tone1        person         horse
# 1583           NaN         NaN   tone2          boat           NaN
# 1597           NaN         NaN   tone1   pottedplant     tvmonitor
# 1614     tvmonitor       chair   tone2        person        bottle
# 1621           NaN         NaN   tone1         chair           dog
# 1631           NaN         NaN   tone1           dog           NaN
# 1662           NaN         NaN   tone2          boat           NaN
# 1688           NaN         NaN   tone1        person   diningtable
# 1698           dog      bottle   tone1   diningtable        person
# 1733           NaN         NaN   tone2     tvmonitor         chair
# 1745           NaN         NaN   tone2           cat           NaN
# 1750           NaN         NaN   tone1         chair           NaN
# 1774           NaN         NaN   tone2          bird           NaN
# 1808           NaN         NaN   tone2        bottle           NaN
# 1818           NaN         NaN   tone2         horse           NaN
# 1853           NaN         NaN   tone1          sofa           dog
# 1865           NaN         NaN   tone1          sofa         chair
# 1870           NaN         NaN   tone2   pottedplant         chair
# 1894           NaN         NaN   tone2           car       bicycle
#
#              cat_3      question         TS useless tone_sdt     RT_TO  \
# 22             NaN            NA  20.584163    None     None       NaN
# 38             NaN            NA  19.207956    None       HI  0.849605
# 44             NaN            NA  18.390878    None       HI  0.749609
# 66             NaN            NA  32.014974    None       HI  0.866114
# 80             car            NA  34.403915    None       HI  0.882880
# 118          chair            NA  29.464580    None       HI  1.049748
# 142            cat            NA  31.670447    None       HI  0.882909
# 158            cat            NA  30.878848    None       HI  0.882795
# 164            NaN            NA  33.647398    None     None       NaN
# 186            NaN            NA  19.912301    None       HI  0.882579
# 200            NaN            NA  19.646066    None     None       NaN
# 238            NaN            NA  20.465741    None       HI  1.298749
# 257    diningtable            NA  29.775484    None       HI  0.682582
# 272            NaN            NA  29.042489    None       HI  0.699249
# 284           sofa           car  29.935618    None       HI  0.516269
# 315            NaN            NA  19.892390    None       HI  0.499424
# 344            NaN            NA  20.712899    None       HI  0.699461
# 354            NaN            NA  19.253520    None       HI  1.732050
# 377            NaN            NA  20.850125    None       HI  0.615979
# 392            NaN            NA  19.239146    None       HI  0.899239
# 404            NaN   pottedplant  20.272205    None       HI  0.751990
# 435         person            NA  30.035339    None     None       NaN
# 464            NaN            NA  29.008359    None       HI  1.032894
# 474            NaN            NA  30.141763    None       HI  0.849485
# 489            NaN         horse  21.198620    None       HI  0.933012
# 498          chair            NA  18.511888    None       HI  0.833074
# 516            NaN           dog  16.142563    None       HI  0.732937
# 546          chair            NA  31.520688    None       HI  0.549315
# 561            NaN            NA  29.084159    None       HI  0.599299
# 564            NaN            NA  37.006387    None       HI  0.599607
# 609            NaN           car  29.314234    None       HI  0.666767
# 618            NaN            NA  32.020690    None       HI  0.799528
# 636            NaN   pottedplant  31.624524    None       HI  0.685258
# 666            NaN            NA  13.350033    None       HI  0.716552
# 681            NaN            NA  18.298678    None       HI  0.682961
# 684            NaN            NA  16.146155    None       HI  0.766183
# 724          chair           cat  29.247483    None       HI  0.516287
# 736            NaN            NA  32.384814    None       HI  0.799488
# 766         bottle            NA  38.972642    None       HI  0.766332
# 807            NaN            NA  20.166020    None       HI  0.966239
# 828            NaN            NA  13.685994    None       HI  0.832776
# 831            NaN            NA  20.216264    None       HI  0.666104
# 844            NaN     aeroplane  19.869099    None       HI  0.582856
# 856            NaN            NA  18.117803    None       HI  0.767708
# 886            NaN            NA  15.253871    None       HI  0.783249
# 927            NaN            NA  29.401451    None       HI  1.082934
# 948            NaN            NA  31.261038    None       HI  0.849857
# 951            NaN            NA  29.270465    None       HI  0.566330
# 982            NaN            NA  20.185339    None       HI  0.832679
# 986            NaN          boat  19.244036    None       HI  0.549341
# 1009           NaN            NA  20.963643    None       HI  0.599360
# 1064           NaN        person  30.612693    None     None       NaN
# 1067           NaN            NA  31.885878    None       HI  0.549251
# 1078           NaN            NA  30.065266    None       HI  0.765913
# 1102           NaN            NA  29.814920    None       HI  0.882937
# 1106           NaN           dog  29.778544    None       HI  0.782837
# 1129           cat            NA  30.878848    None       HI  0.749138
# 1184           NaN     aeroplane  20.074716    None       HI  0.901355
# 1187           NaN            NA  19.759256    None       HI  0.783205
# 1198           NaN            NA  19.890089    None       HI  0.831178
# 1217           NaN            NA  30.936879    None       HI  0.849600
# 1238        bottle        bottle  29.608026    None     None       NaN
# 1249           NaN            NA  33.334972    None       HI  0.749606
# 1279           NaN            NA  16.651242    None       HI  0.782837
# 1284           NaN            NA  20.017308    None       HI  0.649546
# 1315           NaN            NA  11.957700    None       HI  0.866248
# 1337           NaN            NA  19.912301    None       HI  0.731177
# 1358           NaN           cat  20.537354    None       HI  0.813542
# 1369           NaN            NA  18.967723    None       HI  0.649106
# 1399        bottle            NA  33.381115    None       HI  0.766399
# 1404           NaN            NA  35.925065    None       HI  0.632909
# 1435           cat            NA  31.670447    None       HI  1.728661
# 1463           NaN            NA  17.516941    None       HI  1.049507
# 1477           NaN            NA  14.341895    None       HI  0.832999
# 1494           NaN            NA  21.255888    None       HI  0.699627
# 1501           NaN            NA  32.020690    None       HI  0.732867
# 1511   diningtable            NA  29.361756    None       HI  0.766345
# 1542           NaN            NA  32.480532    None       HI  1.333297
# 1583           NaN            NA  37.706202    None       HI  0.799459
# 377    Critical           cat           377      7
# 392    Critical          bird           392      7
# 404    Critical     aeroplane           404      7
# 435    Critical          sofa           435      8
# 464    Critical           car           464      8
# 474    Critical         horse           474      8
# 489    Critical          boat           489      9
# 498    Critical   pottedplant           498      9
# 516    Critical           dog           516      9
# 546    Critical   pottedplant           546     10
# 561    Critical         horse           561     10
# 564    Critical           dog           564     10
# 609    Critical          bird           609     11
# 618    Critical     aeroplane           618     11
# 636    Critical   pottedplant           636     11
# 666    Critical     aeroplane           666     12
# 681    Critical           car           681     12
# 684    Critical          boat           684     12
# 724    Critical   pottedplant           724     13
# 736    Critical         chair           736     13
# 766    Critical        bottle           766     13
# 807    Critical        person           807     14
# 828    Critical           cat           828     14
# 831    Critical          sofa           831     14
# 844    Critical        bottle           844     15
# 856    Critical         chair           856     15
# 886    Critical          bird           886     15
# 927    Critical           cat           927     16
# 948    Critical          boat           948     16
# 951    Critical           car           951     16
# 982    Critical          sofa           982     17
# 986    Critical          sofa           986     17
# 1009   Critical        bottle          1009     17
# 1064   Critical           car          1064     18
# 1067   Critical     aeroplane          1067     18
# 1078   Critical          boat          1078     18
# 1102   Critical          bird          1102     19
# 1106   Critical           cat          1106     19
# 1129   Critical           cat          1129     19
# 1184   Critical          boat          1184     20
# 1187   Critical           car          1187     20
# 1198   Critical           dog          1198     20
# 1217   Critical        person          1217     21
# 1238   Critical        bottle          1238     21
# 1249   Critical         horse          1249     21
# 1279   Critical          boat          1279     22
# 1284   Critical         chair          1284     22
# 1315   Critical          bird          1315     22
# 1337   Critical         horse          1337     23
# 1358   Critical           cat          1358     23
# 1369   Critical   pottedplant          1369     23
# 1399   Critical         chair          1399     24
# 1404   Critical         chair          1404     24
# 1435   Critical           cat          1435     24
# 1463   Critical          boat          1463     25
# 1477   Critical     aeroplane          1477     25
# 1494   Critical   pottedplant          1494     25
# 1501   Critical     aeroplane          1501     26
# 1511   Critical          bird          1511     26
# 1542   Critical         horse          1542     26
# 1583   Critical          boat          1583     27
# 1597   Critical           cat          1597     27
# 1614   Critical        bottle          1614     27
# 1621   Critical         chair          1621     28
# 1631   Critical           dog          1631     28
# 1662   Critical          boat          1662     28
# 1688   Critical        bottle          1688     29
# 1698   Critical        bottle          1698     29
# 1733   Critical        bottle          1733     29
# 1745   Critical           cat          1745     30
# 1750   Critical         chair          1750     30
# 1774   Critical          bird          1774     30
# 1808   Critical        bottle          1808     31
# 1818   Critical         horse          1818     31
# 1853   Critical          sofa          1853     31
# 1865   Critical          sofa          1865     32
# 1870   Critical         chair          1870     32
# 1894   Critical           car          1894     32

# %%
df_criticals_low = df[(df['trial_type'] == 'Critical')&(df["load"] == 'low')]
print df_criticals_low.shape
df_criticals_low_hit = df[(df['trial_type'] == 'Critical')&(df["load"] == 'low')&(df['RT_TO']>0)]
print df_criticals_low_hit.shape
# Out:
# (48, 24)
# (45, 24)

# %%
df_criticals_high = df[(df['trial_type'] == 'Critical')&(df["load"] == 'high')]
print df_criticals_high.shape
df_criticals_high_hit = df[(df['trial_type'] == 'Critical')&(df["load"] == 'high')&(df['RT_TO']>0)]
print df_criticals_high_hit.shape
# Out:
# (48, 24)
# (42, 24)

# %%
df_low = df[(df["RT_TO"] > 0) & (df["load"] == 'low') & (df['trial_type'] == 'Critical')]

# %%
df_high = df[(df["RT_TO"] > 0) & (df["load"] == 'high') & (df['trial_type'] == 'Critical') & ]
#df_high = df[(df["load"] == 'high') & (df['trial_type'] == 'Critical')]

print df_high.shape
df_high['RT_TO'].mean()

# %%
participants = ['1','2','3','4','5','7','8','9','10','11','12','14','15','17']
participant_names = participants

# %%
results = {}
for p in participants:
    df_out,notes = process_observer(p)
    results[p] = notes

# %%
results

# %%
# Preparing table for visual-search task
visual_search_task_data=np.zeros((14,3))

for i,p in enumerate(participants):
    visual_search_task_data[i,0] = results[p]['vs_accuracy_high']*100
    visual_search_task_data[i,1] = results[p]['vs_accuracy_low']*100
    visual_search_task_data[i,2] = results[p]['vs_accuracy_diff']*100

    
visual_search_task_data = np.round(visual_search_task_data,1)

# %%
# Preparing table for tone-detection task
detection_task_data=np.zeros((14,3))

for i,p in enumerate(participants):
    detection_task_data[i,0] = results[p]['tone_detection_accuracy_high']*100
    detection_task_data[i,1] = results[p]['tone_detection_accuracy_low']*100
    detection_task_data[i,2] = results[p]['tone_detection_accuracy_diff']*100

    
detection_task_data = np.round(detection_task_data,1)

# %%
# Preparing table for false alarms
false_alarms_data=np.zeros((14,2))

for i,p in enumerate(participants):
    false_alarms_data[i,0] = int(results[p]['false_alarms_low'])
    false_alarms_data[i,1] = results[p]['false_alarms_high']

# %%
len(participants)

# %%
participants = np.arange(1,len(participants)+1)

# %%
f = open('reports/my_table_3.html','wb')
f.write('<html><body>')
f.write("<link rel='stylesheet' type='text/css' href='main.css'>")
#Table for Visual-search task
make_table('Visual Search Task: only trials without tones and without false alarms to tones (spacebar responses)',['Participant','Accuracy: high','Accuracy: low','Accuracy: low - high'],participants,visual_search_task_data,f)
#Table for Tone-detection task
make_table('Tone Detection Task',['Participant','Accuracy: high','Accuracy: low','Accuracy: low - high'],participants,detection_task_data,f)
#Table for false alarms (in tone detection)
make_table('Tone Detection Task: absolute number of false alarms',['Participant','False alarms: low','False alarms: high'],participants,false_alarms_data,f)
f.write('</body></html>')
f.close()

# %%
detection_task_data

# %%
np.mean(detection_task_data[:,2])

# %%
np.mean(detection_task_data[:,1] - detection_task_data[:,0])

# %%
stats.ttest_rel(detection_task_data[:,1], detection_task_data[:,0])

# %%
from scipy import stats as stats

# %%
plt.scatter(detection_task_data[:,1], detection_task_data[:,2])

# %%
import matplotlib.pyplot as plt

# %%
stats.pearsonr(detection_task_data[:,1], detection_task_data[:,2])

# %% [markdown]
# # By block

# %%
results = {}
for p in participant_names:
    df,notes = process_observer(p)
    results[p] = notes
    print 'PARTICIPANT NAME: '+str(p)
    a=df.groupby(['block_number','sdt'])['sdt'].count()  
    print type(a)
    print a

# %%
f = '../output/participant_8.pik'
import pickle
with open(f,'r') as of:
    D = pickle.load(of)
df = pd.DataFrame.from_dict(D['experiment_details'],orient='index')
new_df, notes = process(df)
print notes
a=df.groupby(['block_number','sdt'])['sdt'].count()
print a

# %%
a

# %%
len(p)

# %%
new_df, notes = process(df)
print notes

# %%
df[['RT_TO']].min()

# %%
f = '../output/participant_8.pik'
import pickle
with open(f,'r') as of:
    D = pickle.load(of)
df = pd.DataFrame.from_dict(D['experiment_details'],orient='index')

# %%
l=df['RT_TO'].tolist()
