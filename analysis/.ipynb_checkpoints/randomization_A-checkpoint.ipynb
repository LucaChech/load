# %%
import pandas as pd
import numpy as np
import random
import csv
#%pdb
#mypath = ('E:/OneDrive - University College London/Random_probes_last/Luca/')
mypath = 'C:/Users/nilli lab/Desktop/load/analysis/'

# %%
import random
probe_series = []
critical_series = []

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
print len(target_present)

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
print len(target_present)
for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
probe_trials_1 = target_present_counter + target_absent_counter
critical_trials_1 = critical_trials
print len(probe_trials_1)
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# 24
# 36
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  12
# len(critical_trials):  24
# 72

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 388
# -------------------

# %%
def block_low_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
    
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_low_2():
# Pick 5 present probes and 4 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_1():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 4:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 4 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
def block_high_2():
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 5:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 5 <= len(probes_per_block) < 9:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    
    for n in probes_per_block:
        print possible_images_dict[n]
        if 'Target Present' in possible_images_dict[n]:
            present_used.append(n)
        elif 'Target Absent' in possible_images_dict[n]:
            absent_used.append(n)
    
    probes.append(probes_per_block)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
    
    modifier.append(critical_probes_counter)
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (3-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    print 'List of critical trials without probe: '
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
    
    critical.append(critical_per_block)

#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 51 - (3 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
    
    normal.append(normal_per_block)

#-----------------------------------------------------------------------------
   
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return

# %%
block_low_1()
print critical_used
block_high_1()
print critical_used
block_high_2()
print critical_used
block_low_2()
print critical_used
block_high_1()
print critical_used
block_low_1()
print critical_used
block_low_2()
print critical_used
block_high_2()
print critical_used
# Out:
# [' horse', nan, nan, nan, nan, 13.879634097368903, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' bottle', nan, nan, nan, nan, 17.883134744539575, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 18.523024266211753, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 21.198620417532712, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 20.131411086471946, 'low', ' boat', ' person', 'Target Absent', 'Normal']
# [' bottle', ' cat', nan, nan, nan, 21.259829756421425, 'low', ' bottle', ' chair', 'Target Absent', 'Normal']
# [' person', ' cat', nan, nan, nan, 20.139877805151375, 'low', ' person', ' horse', 'Target Absent', 'Normal']
# [' chair', ' diningtable', nan, nan, nan, 18.11780279510061, 'low', ' chair', ' bird', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 14.127469618562607, 'low', ' cat', ' horse', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  0
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 20.272204751551552, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 18.045035650575528, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 16.69849859536183, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  48
# Normal used: 48
# ---------------------------------------------------
# ['2009_005075.jpg', '2010_000811.jpg', '2011_001198.jpg']
# [' cat', nan, nan, nan, nan, 31.54166437440535, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' car', ' bicycle', nan, nan, nan, 28.730946256992283, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' person', ' bottle', ' sofa', nan, nan, 33.561185784733894, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 35.696632302033265, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 28.710284354349575, 'high', ' boat', ' cat', 'Target Absent', 'Normal']
# [' chair', ' cat', nan, nan, nan, 29.798629151951733, 'high', ' cat', ' horse', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 30.30670761720366, 'high', ' cat', ' car', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' chair', ' diningtable', nan, 37.710719022258736, 'high', ' pottedplant', ' person', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 31.142308501142768, 'high', ' aeroplane', ' boat', 'Target Absent', 'Normal']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  0
# List of critical trials without probe:
# [' pottedplant', ' bicycle', ' bottle', ' cat', nan, 35.35378442994306, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' dog', nan, nan, nan, 28.66363347517436, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' bottle', nan, nan, 32.179769175040214, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  96
# Normal used: 96
# ---------------------------------------------------
# ['2009_005075.jpg', '2010_000811.jpg', '2011_001198.jpg', '2008_000196.jpg', '2010_004683.jpg', '2008_000495.jpg']
# [' person', ' horse', nan, nan, nan, 30.92721034000856, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' person', ' chair', nan, nan, nan, 34.70717080948356, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 35.97296008400705, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Critical']
# [' pottedplant', ' sofa', ' chair', ' tvmonitor', nan, 29.464580095555625, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 31.19357078875772, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 29.9571992215138, 'high', ' boat', ' dog', 'Target Absent', 'Normal']
# [' diningtable', ' person', ' chair', ' dog', ' bottle', 36.04012142826974, 'high', ' bottle', ' chair', 'Target Absent', 'Normal']
# [' bus', ' boat', ' car', nan, nan, 34.403914620094966, 'high', ' boat', ' horse', 'Target Absent', 'Normal']
# [' sofa', ' person', nan, nan, nan, 31.463677231105994, 'high', ' sofa', ' bird', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  1
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 29.26546246503357, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' boat', ' car', nan, nan, 35.70470893485066, 'high', ' boat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  145
# Normal used: 145
# ---------------------------------------------------
# ['2009_005075.jpg', '2010_000811.jpg', '2011_001198.jpg', '2008_000196.jpg', '2010_004683.jpg', '2008_000495.jpg', '2011_002555.jpg', '2010_002702.jpg']
# [' pottedplant', nan, nan, nan, nan, 19.25273490800736, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 19.239146135217897, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 19.993102773679155, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 20.48716672648194, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 9.955368400707393, 'low', ' chair', ' chair', 'Target Present', 'Critical']
# [' person', ' dog', nan, nan, nan, 18.281400610092522, 'low', ' dog', ' car', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 9.156390286160866, 'low', ' car', ' aeroplane', 'Target Absent', 'Normal']
# [' person', ' dog', nan, nan, nan, 20.166020393270408, 'low', ' person', ' bottle', 'Target Absent', 'Normal']
# [' bottle', ' dog', ' diningtable', nan, nan, 21.034646910874567, 'low', ' bottle', ' pottedplant', 'Target Absent', 'Critical']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  2
# List of critical trials without probe:
# [' person', ' car', nan, nan, nan, 18.390878339274188, 'low', ' car', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  195
# Normal used: 195
# ---------------------------------------------------
# ['2009_005075.jpg', '2010_000811.jpg', '2011_001198.jpg', '2008_000196.jpg', '2010_004683.jpg', '2008_000495.jpg', '2011_002555.jpg', '2010_002702.jpg', '2008_000189.jpg']
# [' person', ' bottle', ' diningtable', nan, nan, 29.775484131000805, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' person', ' chair', ' motorbike', nan, nan, 31.7742392698987, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' bicycle', ' car', nan, 33.367152749801264, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 29.176311484999022, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 32.97739588330027, 'high', ' car', ' bottle', 'Target Absent', 'Normal']
# [' pottedplant', ' sofa', ' chair', ' diningtable', ' tvmonitor', 29.247483266365705, 'high', ' pottedplant', ' sofa', 'Target Absent', 'Normal']
# [' tvmonitor', ' chair', ' person', nan, nan, 31.79472940313895, 'high', ' person', ' sofa', 'Target Absent', 'Normal']
# [' person', ' bird', ' boat', nan, nan, 31.913409738647122, 'high', ' bird', ' pottedplant', 'Target Absent', 'Critical']
# [' sofa', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 33.937775623898794, 'high', ' pottedplant', ' aeroplane', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  1
# List of critical trials without probe:
# [' sofa', ' chair', ' person', nan, nan, 34.56160823603891, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' sofa', ' cat', 29.72712959729897, 'high', ' cat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  244
# Normal used: 244
# ---------------------------------------------------
# ['2009_005075.jpg', '2010_000811.jpg', '2011_001198.jpg', '2008_000196.jpg', '2010_004683.jpg', '2008_000495.jpg', '2011_002555.jpg', '2010_002702.jpg', '2008_000189.jpg', '2008_000704.jpg', '2010_003861.jpg']
# [' aeroplane', nan, nan, nan, nan, 19.095995737676468, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 17.13857605003491, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 20.088435845702712, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 20.463883689453848, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' sofa', nan, nan, nan, nan, 19.892389695505386, 'low', ' sofa', ' dog', 'Target Absent', 'Normal']
# [' person', ' motorbike', nan, nan, nan, 19.44615668764516, 'low', ' person', ' boat', 'Target Absent', 'Normal']
# [' chair', nan, nan, nan, nan, 20.508881463934923, 'low', ' chair', ' boat', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 19.264337675075122, 'low', ' boat', ' sofa', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 18.686905104738816, 'low', ' cat', ' person', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  0
# List of critical trials without probe:
# [' boat', nan, nan, nan, nan, 20.21004370358339, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 19.194815950035924, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 19.156547420300022, 'low', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  292
# Normal used: 292
# ---------------------------------------------------
# ['2009_005075.jpg', '2010_000811.jpg', '2011_001198.jpg', '2008_000196.jpg', '2010_004683.jpg', '2008_000495.jpg', '2011_002555.jpg', '2010_002702.jpg', '2008_000189.jpg', '2008_000704.jpg', '2010_003861.jpg', '2008_001040.jpg', '2010_001036.jpg', '2011_001656.jpg']
# [' person', nan, nan, nan, nan, 15.903696109038165, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' chair', nan, nan, nan, nan, 21.005917005737068, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' sofa', nan, nan, nan, 19.244035875135978, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' bottle', nan, nan, nan, nan, 18.603518928106915, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 12.7290334446634, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 20.821731630747827, 'low', ' bird', ' cat', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 19.685752299806754, 'low', ' boat', ' dog', 'Target Absent', 'Normal']
# [' chair', ' cat', nan, nan, nan, 19.7971714164348, 'low', ' cat', ' car', 'Target Absent', 'Normal']
# [' car', nan, nan, nan, nan, 18.708497724634334, 'low', ' car', ' sofa', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  0
# List of critical trials without probe:
# [' pottedplant', ' sofa', nan, nan, nan, 18.96772267222304, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 20.757885363436266, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 16.456101242175052, 'low', ' cat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  340
# Normal used: 340
# ---------------------------------------------------
# ['2009_005075.jpg', '2010_000811.jpg', '2011_001198.jpg', '2008_000196.jpg', '2010_004683.jpg', '2008_000495.jpg', '2011_002555.jpg', '2010_002702.jpg', '2008_000189.jpg', '2008_000704.jpg', '2010_003861.jpg', '2008_001040.jpg', '2010_001036.jpg', '2011_001656.jpg', '2011_001005.jpg', '2009_003993.jpg', '2008_000839.jpg']
# [' aeroplane', nan, nan, nan, nan, 29.201869461183065, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' person', ' dog', nan, nan, nan, 28.838956354168435, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' chair', ' bird', nan, nan, 29.63012122697995, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 37.22381580448725, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 34.96752773409758, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' pottedplant', ' sofa', nan, nan, nan, 31.62452384083404, 'high', ' pottedplant', ' car', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 32.20276402074853, 'high', ' aeroplane', ' dog', 'Target Absent', 'Normal']
# [' person', ' cat', nan, nan, nan, 32.2651090829965, 'high', ' cat', ' boat', 'Target Absent', 'Normal']
# [' chair', ' diningtable', nan, nan, nan, 28.72863626121521, 'high', ' chair', ' person', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 31.892125506726913, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' motorbike', nan, nan, nan, 32.12330736234191, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' boat', nan, nan, nan, nan, 34.04714690528091, 'high', ' boat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  388
# Normal used: 388
# ---------------------------------------------------
# ['2009_005075.jpg', '2010_000811.jpg', '2011_001198.jpg', '2008_000196.jpg', '2010_004683.jpg', '2008_000495.jpg', '2011_002555.jpg', '2010_002702.jpg', '2008_000189.jpg', '2008_000704.jpg', '2010_003861.jpg', '2008_001040.jpg', '2010_001036.jpg', '2011_001656.jpg', '2011_001005.jpg', '2009_003993.jpg', '2008_000839.jpg', '2008_007250.jpg', '2008_002774.jpg', '2011_001991.jpg']

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
print probes[0]
# Out:
# ['2008_004624.jpg', '2010_000426.jpg', '2008_001185.jpg', '2010_004662.jpg', '2010_002393.jpg', '2008_000112.jpg', '2009_002439.jpg', '2011_002241.jpg', '2008_002899.jpg']

# %%
probe_series = []
critical_series = []

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
def building_the_church(w):
    while True:    
        while True:
            a = [random.randint(1,60) for r in xrange(9)]
            if sum(a) <= 60:
                break
        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]
        print 'new_list_1: ',new_list_1
        #print sum(a)

        while True:
            while True:
                a = [random.randint(1,60) for r in xrange(3-w)]
                if sum(a) <= 60: 
                    break
            print sum(a)
            new_list_2 = []
            acc = 0
            for i in a:
                acc = acc + i
                new_list_2.append(acc)
            print new_list_2
            two_gap = []
            for i in range(2-w): # add "-w"
                two_gap.append(new_list_2[i+1] - new_list_2[i])
                print two_gap
            if 1 not in two_gap and 2 not in two_gap:
                break
        print new_list_2

        container = []
        for i in new_list_2:
            sequence = [i, i+1, i+2]
            #print sequence
            for element in sequence:
                if element in new_list_1:
                    container.append(element)
        #print len(container)
        print new_list_2
        if len(container) == 0:
            break
    print '---------------------------'
    probe_series.append(new_list_1)
    critical_series.append(new_list_2)
    print new_list_1
    print new_list_2
    return

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [0, 14, 16, 30, 38, 46, 47, 50, 53]
# 52
# [26, 47, 52]
# [21]
# [21, 5]
# [26, 47, 52]
# [26, 47, 52]
# new_list_1:  [0, 2, 5, 11, 16, 43, 45, 50, 56]
# 54
# [25, 29, 54]
# [4]
# [4, 25]
# [25, 29, 54]
# [25, 29, 54]
# new_list_1:  [0, 16, 38, 44, 49, 50, 51, 53, 59]
# 42
# [20, 35, 42]
# [15]
# [15, 7]
# [20, 35, 42]
# [20, 35, 42]
# new_list_1:  [3, 6, 8, 15, 21, 35, 44, 47, 55]
# 46
# [20, 28, 46]
# [8]
# [8, 18]
# [20, 28, 46]
# [20, 28, 46]
# new_list_1:  [1, 32, 33, 37, 47, 50, 53, 54, 58]
# 8
# [2, 6, 8]
# [4]
# [4, 2]
# 59
# [3, 22, 59]
# [19]
# [19, 37]
# [3, 22, 59]
# [3, 22, 59]
# ---------------------------
# [1, 32, 33, 37, 47, 50, 53, 54, 58]
# [3, 22, 59]
# new_list_1:  [14, 21, 25, 32, 36, 39, 40, 41, 45]
# 46
# [14, 16, 46]
# [2]
# [2, 30]
# 43
# [3, 21, 43]
# [18]
# [18, 22]
# [3, 21, 43]
# [3, 21, 43]
# new_list_1:  [3, 10, 23, 40, 45, 50, 52, 53, 57]
# 58
# [2, 11, 58]
# [9]
# [9, 47]
# [2, 11, 58]
# [2, 11, 58]
# new_list_1:  [23, 25, 27, 30, 33, 40, 43, 47, 49]
# 28
# [3, 16, 28]
# [13]
# [13, 12]
# [3, 16, 28]
# [3, 16, 28]
# new_list_1:  [5, 8, 10, 17, 35, 36, 43, 45, 51]
# 27
# [3, 5, 27]
# [2]
# [2, 22]
# 38
# [7, 18, 38]
# [11]
# [11, 20]
# [7, 18, 38]
# [7, 18, 38]
# new_list_1:  [15, 16, 18, 27, 36, 44, 46, 51, 52]
# 31
# [3, 7, 31]
# [4]
# [4, 24]
# [3, 7, 31]
# [3, 7, 31]
# ---------------------------
# [15, 16, 18, 27, 36, 44, 46, 51, 52]
# [3, 7, 31]
# new_list_1:  [2, 9, 12, 26, 27, 39, 43, 50, 52]
# 57
# [52, 57]
# [5]
# [52, 57]
# [52, 57]
# new_list_1:  [13, 14, 15, 23, 24, 29, 49, 54, 58]
# 55
# [18, 55]
# [37]
# [18, 55]
# [18, 55]
# ---------------------------
# [13, 14, 15, 23, 24, 29, 49, 54, 58]
# [18, 55]
# new_list_1:  [2, 5, 15, 19, 20, 27, 46, 50, 56]
# 13
# [13]
# [13]
# [13]
# new_list_1:  [7, 11, 13, 29, 39, 46, 47, 50, 59]
# 49
# [49]
# [49]
# [49]
# new_list_1:  [2, 12, 18, 36, 38, 40, 47, 52, 57]
# 40
# [40]
# [40]
# [40]
# new_list_1:  [1, 8, 15, 17, 20, 36, 37, 44, 49]
# 27
# [27]
# [27]
# [27]
# ---------------------------
# [1, 8, 15, 17, 20, 36, 37, 44, 49]
# [27]
# new_list_1:  [0, 13, 20, 22, 23, 32, 38, 52, 56]
# 45
# [27, 45]
# [18]
# [27, 45]
# [27, 45]
# ---------------------------
# [0, 13, 20, 22, 23, 32, 38, 52, 56]
# [27, 45]
# new_list_1:  [11, 23, 28, 29, 31, 39, 41, 47, 48]
# 60
# [20, 45, 60]
# [25]
# [25, 15]
# [20, 45, 60]
# [20, 45, 60]
# new_list_1:  [12, 23, 28, 30, 34, 43, 51, 52, 53]
# 38
# [7, 32, 38]
# [25]
# [25, 6]
# [7, 32, 38]
# [7, 32, 38]
# new_list_1:  [1, 2, 4, 7, 33, 42, 56, 57, 58]
# 55
# [8, 54, 55]
# [46]
# [46, 1]
# 47
# [31, 45, 47]
# [14]
# [14, 2]
# 59
# [8, 39, 59]
# [31]
# [31, 20]
# [8, 39, 59]
# [8, 39, 59]
# ---------------------------
# [1, 2, 4, 7, 33, 42, 56, 57, 58]
# [8, 39, 59]
# new_list_1:  [3, 14, 16, 20, 30, 32, 37, 41, 58]
# 31
# [6, 30, 31]
# [24]
# [24, 1]
# 19
# [14, 17, 19]
# [3]
# [3, 2]
# 29
# [6, 13, 29]
# [7]
# [7, 16]
# [6, 13, 29]
# [6, 13, 29]
# new_list_1:  [2, 4, 5, 7, 9, 12, 27, 29, 33]
# 51
# [11, 26, 51]
# [15]
# [15, 25]
# [11, 26, 51]
# [11, 26, 51]
# new_list_1:  [11, 14, 19, 26, 28, 29, 36, 43, 52]
# 44
# [3, 28, 44]
# [25]
# [25, 16]
# [3, 28, 44]
# [3, 28, 44]
# new_list_1:  [3, 5, 16, 17, 19, 25, 39, 50, 53]
# 37
# [26, 31, 37]
# [5]
# [5, 6]
# [26, 31, 37]
# [26, 31, 37]
# new_list_1:  [0, 2, 8, 20, 27, 40, 46, 52, 53]
# 53
# [13, 20, 53]
# [7]
# [7, 33]
# [13, 20, 53]
# [13, 20, 53]
# new_list_1:  [8, 13, 15, 22, 38, 40, 41, 44, 49]
# 31
# [3, 17, 31]
# [14]
# [14, 14]
# [3, 17, 31]
# [3, 17, 31]
# ---------------------------
# [8, 13, 15, 22, 38, 40, 41, 44, 49]
# [3, 17, 31]
# new_list_1:  [12, 23, 26, 35, 38, 49, 54, 57, 58]
# 40
# [23, 38, 40]
# [15]
# [15, 2]
# 49
# [18, 48, 49]
# [30]
# [30, 1]
# 45
# [31, 36, 45]
# [5]
# [5, 9]
# [31, 36, 45]
# [31, 36, 45]
# new_list_1:  [1, 3, 14, 29, 45, 46, 47, 48, 52]
# 51
# [31, 46, 51]
# [15]
# [15, 5]
# [31, 46, 51]
# [31, 46, 51]
# new_list_1:  [11, 15, 17, 19, 21, 31, 44, 52, 56]
# 57
# [9, 24, 57]
# [15]
# [15, 33]
# [9, 24, 57]
# [9, 24, 57]
# new_list_1:  [4, 12, 13, 28, 29, 30, 43, 53, 58]
# 58
# [23, 26, 58]
# [3]
# [3, 32]
# [23, 26, 58]
# [23, 26, 58]
# new_list_1:  [4, 16, 19, 30, 32, 35, 43, 56, 57]
# 52
# [4, 8, 52]
# [4]
# [4, 44]
# [4, 8, 52]
# [4, 8, 52]
# new_list_1:  [18, 22, 25, 37, 42, 45, 50, 51, 56]
# 47
# [21, 27, 47]
# [6]
# [6, 20]
# [21, 27, 47]
# [21, 27, 47]
# new_list_1:  [10, 11, 21, 22, 40, 42, 48, 52, 57]
# 49
# [1, 11, 49]
# [10]
# [10, 38]
# [1, 11, 49]
# [1, 11, 49]
# new_list_1:  [5, 11, 16, 20, 38, 44, 48, 55, 57]
# 21
# [4, 5, 21]
# [1]
# [1, 16]
# 50
# [37, 42, 50]
# [5]
# [5, 8]
# [37, 42, 50]
# [37, 42, 50]
# new_list_1:  [1, 20, 22, 23, 28, 32, 35, 39, 47]
# 60
# [14, 22, 60]
# [8]
# [8, 38]
# [14, 22, 60]
# [14, 22, 60]
# new_list_1:  [4, 6, 10, 11, 17, 26, 43, 45, 47]
# 41
# [5, 37, 41]
# [32]
# [32, 4]
# [5, 37, 41]
# [5, 37, 41]
# new_list_1:  [8, 16, 22, 24, 31, 33, 41, 43, 48]
# 58
# [13, 37, 58]
# [24]
# [24, 21]
# [13, 37, 58]
# [13, 37, 58]
# ---------------------------
# [8, 16, 22, 24, 31, 33, 41, 43, 48]
# [13, 37, 58]

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])
# Out:
# 0
# 0 1 60
# 1
# 1 2 60
# 2
# 2 3 60
# 3
# 3 4 60
# 4
# 4 5 60
# 5
# 5 6 60
# 6
# 6 7 60
# 7
# 7 8 60

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 388
# 388
# True
# 36
# 36
# True
# 36
# 36
# True
# 24
# 20
# 4

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)
# Out:
# ['tone1', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone2', 'tone2', 'tone2', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone1', 'tone1']

# %%
df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df.TS = df.TS.astype('float')
df.to_csv(mypath + '../Config/randomization_1.csv')
block_1_half = block
probe_series_1_half = probe_series

# %%
##################
# SECOND ITERATION#
##################

# %%
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# %%
# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]

print categories
print odd
print even
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in even:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
    
target_present_counter = [n for n in lista if 'Target Present' in possible_images_dict[n]]
print 'len(target_present_counter): ', len(target_present_counter)

# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present \
                and trial not in probe_trials_1:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for category in odd:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present \
                and trial not in probe_trials_1:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break
                
for each in target_absent:
    possible_images_dict[each].append('Target Absent')

target_absent_counter = [n for n in lista if 'Target Absent' in possible_images_dict[n]]
print 'len(target_absent_counter): ', len(target_absent_counter)



    
# DEFINING NO-TARGET IMAGES

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and intermediate not in critical_trials_1 \
                and intermediate not in probe_trials_1:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print 'len(critical_trials): ', len(critical_trials)
         
critical_trial('low')
critical_trial('high')
# Out:
# [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
# [' bottle', ' pottedplant', ' cat', ' aeroplane', ' chair', ' bird']
# [' horse', ' dog', ' person', ' car', ' sofa', ' boat']
# len(target_present_counter):  36
# len(target_absent_counter):  36
# len(critical_trials):  12
# len(critical_trials):  24

# %%
print 'len(critical_trials) == len(set(critical_trials)):',len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')
# Out:
# len(critical_trials) == len(set(critical_trials)): True

# %%
#Defininfg blocks 
probes_per_block = []
normal_probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
critical_probes_counter = 0
print len(normal_no_probe)
print '-------------------'
probes = []
critical = []
normal = []
modifier = []
#%pdb
# Out:
# 386
# -------------------

# %%
block_low_1()
block_high_1()
block_high_2()
block_low_2()
block_high_1()
block_low_1()
block_low_2()
block_high_2()
# Out:
# [' dog', ' cat', nan, nan, nan, 21.247629460380587, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' bottle', ' cat', nan, nan, nan, 21.259829756421425, 'low', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' sofa', ' dog', nan, nan, nan, 21.001227278103954, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 17.33155808066949, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' sofa', ' cat', nan, nan, nan, 18.288477341906038, 'low', ' sofa', ' person', 'Target Absent', 'Normal']
# [' chair', nan, nan, nan, nan, 11.459232377151848, 'low', ' chair', ' horse', 'Target Absent', 'Normal']
# [' sofa', nan, nan, nan, nan, 17.316646037114566, 'low', ' sofa', ' aeroplane', 'Target Absent', 'Normal']
# [' pottedplant', ' sofa', nan, nan, nan, 18.96772267222304, 'low', ' pottedplant', ' bottle', 'Target Absent', 'Normal']
# [' bird', nan, nan, nan, nan, 9.57686770873812, 'low', ' bird', ' pottedplant', 'Target Absent', 'Normal']
# Present Used:  4
# Absent Used  5
# Critical probes counter:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 14.343346792518373, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 17.69816713203682, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 20.8325215532547, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  48
# Normal used: 48
# ---------------------------------------------------
# [' person', ' dog', nan, nan, nan, 30.657341600370845, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 33.96835298009745, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' person', ' diningtable', ' bottle', nan, nan, 38.97264238893902, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 31.54166437440535, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' pottedplant', ' tvmonitor', ' cat', nan, nan, 31.67044719842205, 'high', ' cat', ' sofa', 'Target Absent', 'Normal']
# [' chair', ' bottle', nan, nan, nan, 30.42487388731773, 'high', ' chair', ' cat', 'Target Absent', 'Normal']
# [' sofa', ' chair', ' bottle', ' person', nan, 29.05176679498621, 'high', ' sofa', ' boat', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 30.130898028557787, 'high', ' horse', ' pottedplant', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 35.66913245555085, 'high', ' horse', ' chair', 'Target Absent', 'Normal']
# Present Used:  8
# Absent Used  10
# Critical probes counter:  0
# List of critical trials without probe:
# [' person', ' diningtable', ' bottle', nan, nan, 36.156012963588545, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' sofa', ' person', nan, nan, nan, 35.92557187315038, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' horse', ' dog', nan, nan, 31.37245999871385, 'high', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  96
# Normal used: 96
# ---------------------------------------------------
# [' chair', ' diningtable', nan, nan, nan, 29.119691130314802, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 30.996977820829354, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 33.64739800555661, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' person', ' chair', ' diningtable', ' sofa', nan, 30.916466766406522, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' car', ' aeroplane', nan, nan, nan, 35.87217940794205, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' pottedplant', ' sofa', ' chair', ' diningtable', nan, 29.806819625699735, 'high', ' sofa', ' chair', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 29.547306113597852, 'high', ' aeroplane', ' bird', 'Target Absent', 'Normal']
# [' person', ' bottle', ' diningtable', nan, nan, 34.072917550349175, 'high', ' bottle', ' aeroplane', 'Target Absent', 'Normal']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 29.8220330038045, 'high', ' sofa', ' bottle', 'Target Absent', 'Normal']
# Present Used:  13
# Absent Used  14
# Critical probes counter:  0
# List of critical trials without probe:
# [' chair', ' bird', ' diningtable', nan, nan, 29.36175572031889, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 31.26103763923315, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' aeroplane', ' boat', nan, nan, nan, 29.28734944464957, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  144
# Normal used: 144
# ---------------------------------------------------
# [' horse', nan, nan, nan, nan, 19.234401336670953, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' person', ' sofa', nan, nan, nan, 20.185339334432726, 'low', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' chair', ' diningtable', nan, nan, nan, 18.11780279510061, 'low', ' chair', ' chair', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 18.59798168174263, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' person', ' dog', nan, nan, nan, 18.281400610092522, 'low', ' dog', ' dog', 'Target Present', 'Normal']
# [' horse', nan, nan, nan, nan, 18.590456430582357, 'low', ' horse', ' dog', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 18.879557532788805, 'low', ' person', ' pottedplant', 'Target Absent', 'Normal']
# [' horse', nan, nan, nan, nan, 18.41425575439328, 'low', ' horse', ' boat', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 16.580374337830555, 'low', ' boat', ' bird', 'Target Absent', 'Normal']
# Present Used:  18
# Absent Used  18
# Critical probes counter:  0
# List of critical trials without probe:
# [' person', ' boat', nan, nan, nan, 17.997748470093857, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' car', ' person', nan, nan, nan, 17.856305662122608, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 19.188834185415878, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  192
# Normal used: 192
# ---------------------------------------------------
# [' sofa', ' person', ' tvmonitor', nan, nan, 31.14925641648057, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 30.80608913442844, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' horse', nan, nan, nan, 28.936239221739456, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' bus', ' car', nan, nan, nan, 39.116317372229396, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 28.99541660743073, 'high', ' aeroplane', ' cat', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' diningtable', ' bottle', nan, 28.939513311425664, 'high', ' pottedplant', ' bottle', 'Target Absent', 'Normal']
# [' tvmonitor', ' chair', nan, nan, nan, 32.38481414164753, 'high', ' chair', ' bird', 'Target Absent', 'Critical']
# [' person', ' diningtable', ' bottle', nan, nan, 33.461904083445745, 'high', ' person', ' pottedplant', 'Target Absent', 'Normal']
# [' chair', nan, nan, nan, nan, 29.027958359084288, 'high', ' chair', ' horse', 'Target Absent', 'Normal']
# Present Used:  22
# Absent Used  23
# Critical probes counter:  1
# List of critical trials without probe:
# [' dog', nan, nan, nan, nan, 29.77784058169977, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' cat', nan, nan, nan, 29.867994035114002, 'high', ' cat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  241
# Normal used: 241
# ---------------------------------------------------
# [' horse', nan, nan, nan, nan, 19.803898838362514, 'low', ' horse', ' horse', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 18.874156232375913, 'low', ' car', ' car', 'Target Present', 'Normal']
# [' chair', ' cat', nan, nan, nan, 19.7971714164348, 'low', ' cat', ' cat', 'Target Present', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 15.759492066531687, 'low', ' aeroplane', ' aeroplane', 'Target Present', 'Normal']
# [' car', nan, nan, nan, nan, 18.78745072135656, 'low', ' car', ' aeroplane', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 18.68471821171516, 'low', ' cat', ' bird', 'Target Absent', 'Normal']
# [' bicycle', ' bottle', nan, nan, nan, 18.893798014446215, 'low', ' bottle', ' cat', 'Target Absent', 'Normal']
# [' cat', nan, nan, nan, nan, 16.656599770121232, 'low', ' cat', ' chair', 'Target Absent', 'Normal']
# [' chair', nan, nan, nan, nan, 16.98544233464372, 'low', ' chair', ' sofa', 'Target Absent', 'Normal']
# Present Used:  26
# Absent Used  28
# Critical probes counter:  0
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 18.720728543179284, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 19.755286187157022, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' chair', ' diningtable', nan, nan, nan, 20.017308322976007, 'low', ' chair', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  289
# Normal used: 289
# ---------------------------------------------------
# [' boat', nan, nan, nan, nan, 16.846336579249186, 'low', ' boat', ' boat', 'Target Present', 'Normal']
# [' pottedplant', ' person', nan, nan, nan, 13.786733463571188, 'low', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' person', ' chair', nan, nan, nan, 20.22413954449369, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 20.757885363436266, 'low', ' bird', ' bird', 'Target Present', 'Normal']
# [' person', nan, nan, nan, nan, 20.18915033705368, 'low', ' person', ' person', 'Target Present', 'Normal']
# [' person', ' sofa', nan, nan, nan, 20.707877775353552, 'low', ' sofa', ' cat', 'Target Absent', 'Critical']
# [' horse', nan, nan, nan, nan, 19.156547420300022, 'low', ' horse', ' bottle', 'Target Absent', 'Normal']
# [' dog', nan, nan, nan, nan, 19.570662256086155, 'low', ' dog', ' chair', 'Target Absent', 'Normal']
# [' pottedplant', nan, nan, nan, nan, 18.03153744936175, 'low', ' pottedplant', ' car', 'Target Absent', 'Normal']
# Present Used:  31
# Absent Used  32
# Critical probes counter:  1
# List of critical trials without probe:
# [' pottedplant', nan, nan, nan, nan, 20.393526602090205, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' car', ' aeroplane', nan, nan, nan, 16.811685000593723, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  338
# Normal used: 338
# ---------------------------------------------------
# [' person', ' boat', ' car', nan, nan, 35.70470893485066, 'high', ' boat', ' boat', 'Target Present', 'Normal']
# [' person', ' dog', nan, nan, nan, 30.20203583105944, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 30.182885716527558, 'high', ' person', ' person', 'Target Present', 'Normal']
# [' pottedplant', ' car', nan, nan, nan, 30.612693177580176, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' sofa', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 33.937775623898794, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' pottedplant', ' person', ' motorbike', nan, nan, 34.41600543331538, 'high', ' pottedplant', ' aeroplane', 'Target Absent', 'Normal']
# [' bus', ' person', ' car', nan, nan, 31.167936969796557, 'high', ' car', ' dog', 'Target Absent', 'Normal']
# [' car', ' bicycle', ' person', nan, nan, 28.874416244148048, 'high', ' person', ' car', 'Target Absent', 'Normal']
# [' aeroplane', nan, nan, nan, nan, 32.020689907436754, 'high', ' aeroplane', ' person', 'Target Absent', 'Normal']
# Present Used:  36
# Absent Used  36
# Critical probes counter:  0
# List of critical trials without probe:
# [' sofa', ' chair', ' person', nan, nan, 30.035339131770247, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' bicycle', ' car', nan, nan, 31.577906396402632, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', nan, nan, 31.427287995992387, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  386
# Normal used: 386
# ---------------------------------------------------

# %%
print len(modifier) 
print len(normal) 
print len(critical)
print len(probes)
# Out:
# 8
# 8
# 8
# 8

# %%
probe_series = []
critical_series = []

# %%
building_the_church(modifier[0])
building_the_church(modifier[1])
building_the_church(modifier[2])
building_the_church(modifier[3])
building_the_church(modifier[4])
building_the_church(modifier[5])
building_the_church(modifier[6])
building_the_church(modifier[7])
# Out:
# new_list_1:  [0, 6, 9, 18, 24, 35, 53, 56, 59]
# 57
# [16, 51, 57]
# [35]
# [35, 6]
# [16, 51, 57]
# [16, 51, 57]
# new_list_1:  [6, 19, 33, 34, 35, 36, 42, 57, 59]
# 42
# [14, 37, 42]
# [23]
# [23, 5]
# [14, 37, 42]
# [14, 37, 42]
# new_list_1:  [1, 10, 16, 39, 41, 44, 52, 56, 57]
# 55
# [14, 19, 55]
# [5]
# [5, 36]
# [14, 19, 55]
# [14, 19, 55]
# new_list_1:  [6, 14, 16, 18, 33, 36, 40, 47, 48]
# 59
# [9, 23, 59]
# [14]
# [14, 36]
# [9, 23, 59]
# [9, 23, 59]
# ---------------------------
# [6, 14, 16, 18, 33, 36, 40, 47, 48]
# [9, 23, 59]
# new_list_1:  [1, 4, 5, 12, 16, 18, 38, 50, 59]
# 30
# [18, 22, 30]
# [4]
# [4, 8]
# [18, 22, 30]
# [18, 22, 30]
# new_list_1:  [0, 11, 15, 18, 19, 38, 46, 49, 57]
# 59
# [10, 32, 59]
# [22]
# [22, 27]
# [10, 32, 59]
# [10, 32, 59]
# new_list_1:  [0, 5, 8, 14, 15, 17, 21, 39, 46]
# 48
# [13, 44, 48]
# [31]
# [31, 4]
# [13, 44, 48]
# [13, 44, 48]
# new_list_1:  [3, 7, 10, 19, 20, 22, 33, 47, 57]
# 45
# [10, 14, 45]
# [4]
# [4, 31]
# [10, 14, 45]
# [10, 14, 45]
# new_list_1:  [7, 17, 25, 29, 32, 35, 37, 54, 56]
# 29
# [23, 27, 29]
# [4]
# [4, 2]
# 44
# [8, 37, 44]
# [29]
# [29, 7]
# [8, 37, 44]
# [8, 37, 44]
# new_list_1:  [2, 3, 10, 18, 33, 37, 45, 47, 56]
# 58
# [46, 47, 58]
# [1]
# [1, 11]
# 59
# [26, 42, 59]
# [16]
# [16, 17]
# [26, 42, 59]
# [26, 42, 59]
# ---------------------------
# [2, 3, 10, 18, 33, 37, 45, 47, 56]
# [26, 42, 59]
# new_list_1:  [3, 4, 11, 16, 25, 27, 31, 41, 53]
# 53
# [8, 17, 53]
# [9]
# [9, 36]
# [8, 17, 53]
# [8, 17, 53]
# new_list_1:  [9, 23, 30, 33, 40, 45, 52, 58, 59]
# 60
# [32, 40, 60]
# [8]
# [8, 20]
# [32, 40, 60]
# [32, 40, 60]
# new_list_1:  [1, 7, 20, 24, 30, 37, 41, 47, 52]
# 53
# [45, 48, 53]
# [3]
# [3, 5]
# [45, 48, 53]
# [45, 48, 53]
# new_list_1:  [0, 1, 9, 13, 20, 29, 32, 33, 48]
# 60
# [2, 3, 60]
# [1]
# [1, 57]
# 25
# [8, 10, 25]
# [2]
# [2, 15]
# 47
# [23, 34, 47]
# [11]
# [11, 13]
# [23, 34, 47]
# [23, 34, 47]
# new_list_1:  [9, 10, 13, 18, 20, 31, 35, 47, 49]
# 33
# [16, 20, 33]
# [4]
# [4, 13]
# [16, 20, 33]
# [16, 20, 33]
# new_list_1:  [4, 8, 11, 17, 27, 30, 38, 55, 56]
# 53
# [38, 40, 53]
# [2]
# [2, 13]
# 44
# [16, 39, 44]
# [23]
# [23, 5]
# [16, 39, 44]
# [16, 39, 44]
# new_list_1:  [3, 10, 11, 20, 33, 41, 51, 53, 55]
# 48
# [21, 36, 48]
# [15]
# [15, 12]
# [21, 36, 48]
# [21, 36, 48]
# ---------------------------
# [3, 10, 11, 20, 33, 41, 51, 53, 55]
# [21, 36, 48]
# new_list_1:  [6, 22, 23, 27, 28, 38, 54, 56, 57]
# 42
# [7, 35, 42]
# [28]
# [28, 7]
# [7, 35, 42]
# [7, 35, 42]
# ---------------------------
# [6, 22, 23, 27, 28, 38, 54, 56, 57]
# [7, 35, 42]
# new_list_1:  [1, 2, 4, 5, 17, 21, 35, 46, 54]
# 59
# [14, 59]
# [45]
# [14, 59]
# [14, 59]
# ---------------------------
# [1, 2, 4, 5, 17, 21, 35, 46, 54]
# [14, 59]
# new_list_1:  [8, 26, 31, 35, 37, 44, 47, 52, 55]
# 35
# [19, 22, 35]
# [3]
# [3, 13]
# [19, 22, 35]
# [19, 22, 35]
# new_list_1:  [10, 17, 22, 26, 29, 30, 43, 55, 56]
# 56
# [19, 51, 56]
# [32]
# [32, 5]
# [19, 51, 56]
# [19, 51, 56]
# new_list_1:  [0, 6, 12, 14, 15, 21, 26, 36, 47]
# 41
# [8, 38, 41]
# [30]
# [30, 3]
# [8, 38, 41]
# [8, 38, 41]
# ---------------------------
# [0, 6, 12, 14, 15, 21, 26, 36, 47]
# [8, 38, 41]
# new_list_1:  [7, 10, 23, 30, 32, 39, 45, 46, 55]
# 48
# [13, 48]
# [35]
# [13, 48]
# [13, 48]
# ---------------------------
# [7, 10, 23, 30, 32, 39, 45, 46, 55]
# [13, 48]
# new_list_1:  [7, 15, 25, 26, 30, 36, 41, 50, 54]
# 52
# [27, 42, 52]
# [15]
# [15, 10]
# [27, 42, 52]
# [27, 42, 52]
# new_list_1:  [2, 7, 20, 39, 44, 47, 48, 54, 55]
# 52
# [21, 42, 52]
# [21]
# [21, 10]
# [21, 42, 52]
# [21, 42, 52]
# new_list_1:  [15, 27, 30, 33, 37, 39, 45, 47, 55]
# 60
# [12, 33, 60]
# [21]
# [21, 27]
# [12, 33, 60]
# [12, 33, 60]
# new_list_1:  [17, 24, 30, 34, 42, 47, 51, 58, 59]
# 55
# [15, 48, 55]
# [33]
# [33, 7]
# [15, 48, 55]
# [15, 48, 55]
# new_list_1:  [7, 8, 15, 17, 20, 23, 27, 33, 34]
# 42
# [38, 41, 42]
# [3]
# [3, 1]
# 37
# [25, 33, 37]
# [8]
# [8, 4]
# [25, 33, 37]
# [25, 33, 37]
# new_list_1:  [0, 8, 14, 25, 26, 46, 52, 54, 56]
# 51
# [22, 24, 51]
# [2]
# [2, 27]
# 42
# [34, 40, 42]
# [6]
# [6, 2]
# 43
# [23, 42, 43]
# [19]
# [19, 1]
# 53
# [39, 52, 53]
# [13]
# [13, 1]
# 47
# [26, 39, 47]
# [13]
# [13, 8]
# [26, 39, 47]
# [26, 39, 47]
# new_list_1:  [6, 16, 28, 31, 34, 42, 52, 53, 56]
# 47
# [32, 45, 47]
# [13]
# [13, 2]
# 52
# [4, 18, 52]
# [14]
# [14, 34]
# [4, 18, 52]
# [4, 18, 52]
# new_list_1:  [6, 8, 12, 19, 22, 27, 33, 36, 50]
# 29
# [6, 18, 29]
# [12]
# [12, 11]
# [6, 18, 29]
# [6, 18, 29]
# new_list_1:  [1, 19, 23, 28, 30, 33, 39, 41, 43]
# 53
# [7, 41, 53]
# [34]
# [34, 12]
# [7, 41, 53]
# [7, 41, 53]
# new_list_1:  [5, 6, 13, 14, 17, 37, 39, 43, 55]
# 51
# [7, 36, 51]
# [29]
# [29, 15]
# [7, 36, 51]
# [7, 36, 51]
# new_list_1:  [6, 12, 22, 28, 31, 35, 40, 41, 58]
# 8
# [1, 5, 8]
# [4]
# [4, 3]
# [1, 5, 8]
# [1, 5, 8]
# new_list_1:  [6, 10, 11, 15, 19, 23, 26, 39, 51]
# 59
# [41, 51, 59]
# [10]
# [10, 8]
# [41, 51, 59]
# [41, 51, 59]
# new_list_1:  [4, 7, 23, 27, 42, 46, 51, 52, 55]
# 52
# [12, 17, 52]
# [5]
# [5, 35]
# [12, 17, 52]
# [12, 17, 52]
# new_list_1:  [5, 7, 11, 24, 30, 44, 45, 50, 58]
# 53
# [8, 15, 53]
# [7]
# [7, 38]
# [8, 15, 53]
# [8, 15, 53]
# ---------------------------
# [5, 7, 11, 24, 30, 44, 45, 50, 58]
# [8, 15, 53]

# %%
for probe in probes:
    random.shuffle(probe)

# %%
block = []
interim = []
for counter in range(8):
    probe_c = 0
    critical_c = 0
    normal_c = 0
    interim = []
    print counter
    for i in range(60):
        #print i
        if i in probe_series[counter]:
            interim.append(probes[counter][probe_c])
            probe_c = probe_c + 1
        elif i in critical_series[counter]:
            interim.append(critical[counter][critical_c])
            critical_c = critical_c + 1
        else:
            interim.append(normal[counter][normal_c])
            normal_c = normal_c + 1
    block.append(interim)
    print counter, len(block), len(block[counter])
# Out:
# 0
# 0 1 60
# 1
# 1 2 60
# 2
# 2 3 60
# 3
# 3 4 60
# 4
# 4 5 60
# 5
# 5 6 60
# 6
# 6 7 60
# 7
# 7 8 60

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 386
# 386
# True
# 36
# 36
# True
# 36
# 36
# True
# 24
# 22
# 2

# %%
sound_onset = []
for i in range(48):
    a = random.uniform(0, 0.999)
    a = int(str(a)[2:5])
    #print a
    sound_onset.append(a)

sound_Hz = ['tone1'] * 12 + ['tone2'] * 12 
sound_Hz = random.sample(sound_Hz, len(sound_Hz))
print sound_Hz
#------------------------------------------------------------------------------
sound_index = 0
for each in possible_images_dict:
    if 'Critical' in possible_images_dict[each]:
        possible_images_dict[each].append(sound_Hz[sound_index])
        possible_images_dict[each].append(sound_onset[sound_index])
        sound_index = sound_index + 1
    elif 'Normal' in possible_images_dict[each]:
        possible_images_dict[each].append('No tone')
        possible_images_dict[each].append(-999)
# Out:
# ['tone2', 'tone1', 'tone1', 'tone2', 'tone2', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone2', 'tone2', 'tone1', 'tone1', 'tone1', 'tone1', 'tone1', 'tone2', 'tone1', 'tone2', 'tone2', 'tone1', 'tone2']

# %%
df_2 = pd.DataFrame.from_dict(possible_images_dict)
df_2= df_2.T
df_2.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset']
df_2.TS = df_2.TS.astype('float')
df_2.to_csv(mypath + '../Config/randomization_2.csv')
block_2_half = block
probe_series_2_half = probe_series

# %%
probe_series = probe_series_1_half + probe_series_2_half
block = block_1_half + block_2_half

# %%
with open('../Config/images.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(block[i])
        #wr.writerow(blocks_sequences_list[i])

with open('../Config/probes.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    
    for i in range(16):
        wr.writerow(probe_series[i])
