# %%
import pandas as pd
import numpy as np
import random
import csv
from pdb import set_trace
import pickle
from copy import deepcopy
#%pdb
mypath = ('')
trials = {}
categories = [' bottle', ' horse', ' pottedplant', ' dog',
                  ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
odd = categories[::2]
even = categories[1::2]
p_load = ['low','high']

# %%
def present_absent_trials(input_1, input_2):
    global target_present, lista, categories, p_load, odd, even
    # DEFINING TARGET-PRESENT PROBES
    
    #target_present = []
    intermediate = []
    
#next two lines are to check that the images picked as target present and target absent trials
                    #are different from the ones chosen in previous iterations
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_1:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_present.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break
    #print len(target_present)
    for n in target_present:
        possible_images_dict[n].append('Target Present')

    #target_present = [n for n in lista if 'Target Present' in possible_images_dict[n]]


    # DEFINING TARGET-ABSENT PROBES
    #target_absent = []
    intermediate = []
    for category in categories:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)
                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for category in input_2:
        for load in p_load:
            while True:
                trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
                if category not in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                    and trial not in intermediate and trial not in target_absent and trial not in target_present\
                    and 'Target Present' not in possible_images_dict[trial]\
                    and 'Target Absent' not in possible_images_dict[trial]:
                    intermediate.append(trial)
                if len(intermediate) == 1:
                    for each in intermediate:
                        target_absent.append(each)

                        possible_images_dict[each].append(category)
                    intermediate = []
                    break

    for each in target_absent:
        possible_images_dict[each].append('Target Absent')
        

    # DEFINING NO-TARGET IMAGES
    for image in lista:
        if image not in target_present and image not in target_absent:
            possible_images_dict[image].append('NA')
            possible_images_dict[image].append('No Target')
    
    return target_present, target_absent

# %%
# DEFINING CRITICAL TRIALS
#Criteria:
# - images of set load level
# - images containing a certain category
# - image is not already in the list of critical trials for this level of load
#- image is not aready in the list of critical trials (regardless of level of load)

def pre_select_critical_trial(load_level):
    global categories, critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <1 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials \
                and 'Critical' not in possible_images_dict[intermediate]: # this is just a sanity check
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)      
        temp =[]

# %%
def appending_critical_trials():
    global critical_low_present_probes, critical_low_absent_probes, critical_high_present_probes, critical_high_absent_probes
    global critical_trials
    cycles = 1
    while True:

        #picking critical trials
        pre_select_critical_trial('low')
        pre_select_critical_trial('high')      

        # counting critical probes
        crit_p = 0
        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1


        critical_low_counter = 0
        critical_high_counter = 0
        crit_p = 0

        for n in critical_trials:
            if 'No Target' not in possible_images_dict[n]:
                crit_p = crit_p +1
            if 'No Target' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_counter = critical_low_counter + 1
            if 'No Target' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_counter = critical_high_counter +1
            if 'Target Present' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'low' in possible_images_dict[n]:
                critical_low_absent_probes.append(n)
            if 'Target Present' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_present_probes.append(n)
            if 'Target Absent' in possible_images_dict[n] and 'high' in possible_images_dict[n]:
                critical_high_absent_probes.append(n)
        #print crit_p
        #print critical_low_counter
        #print critical_high_counter
        #print critical_low_present_probes
        #print critical_low_absent_probes
        #print critical_high_present_probes
        #print critical_high_absent_probes

        #######################################################
        if crit_p == 0 or len(critical_low_present_probes) == len(critical_high_present_probes) and len(critical_low_absent_probes) == \
        len(critical_high_absent_probes): #check if there is an even number of critical probes
            break
            print 'cycles : ',cycles
        else:
            cycles = cycles + 1
            critical_low_present_probes = []
            critical_low_absent_probes = []
            critical_high_present_probes = []
            critical_high_absent_probes = []
            #print len(critical_low_present_probes)
            #print len(critical_high_present_probes)
            #print len(critical_low_absent_probes)
            #print len(critical_high_absent_probes)
            #print '#######################'

            #why did I reset target_present and target_absent???

            #target_present = []
            #target_absent = []
            critical_trials = []

    # appendinf words 'critical' and 'normal' to dict
    for each in critical_trials:
        possible_images_dict[each].append('Critical')
    for each in possible_images_dict:
        if 'Critical' not in possible_images_dict[each]:
            possible_images_dict[each].append('Normal')

    #######################################################
    #print 'Probe trials: ', len(probe_trials_1)
    print 'Target Present Probes: ', len(target_present)
    print 'Target Absent probes: ', len(target_absent)
    print 'Critical trials:', len(critical_trials)
    print 'Critical, low: ' , critical_low_counter
    print 'Critical, high: ' , critical_high_counter
    print 'Are all critical trials unique? ', len(critical_trials) == len(set(critical_trials))
    #######################################################
    print 'Number of critical probes: ' , crit_p
    print 'critical_low_present_probes: ' , len(critical_low_present_probes)
    print 'critical_high_present_probes: ' , len(critical_high_present_probes)
    print 'critical_low_absent_probes: ' , len(critical_low_absent_probes)
    print 'critical_high_absent_probes: ', len(critical_high_absent_probes)
    print 'cycles : ',cycles
    
    return

# %%
def critical_probes_distribution(starting):
    global critical_low_present_probes, critical_low_absent_probes
    while True:
        p_left = len(starting)
        p_max = p_left
        distribution = []
        for i in range(4):
            if p_left > 0:
                x = random.randint(0,p_left)
                distribution.append(x)
                p_left = p_left - x
            else:
                distribution.append(0)
        if sum(distribution) == p_max:
            break
    random.shuffle(distribution)
    return distribution

# %%
def block_pair(present_n,absent_n):
# Pick 4 present probes and 5 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block
    global present_crit_distribution, absent_crit_distribution
    global present_critical_per_block, absent_critical_per_block, critical_probes_used, critical_probes_set
    global present_per_block, absent_per_block
    
    present_crit = present_crit_distribution.pop(0)
    absent_crit = absent_crit_distribution.pop(0)
    block = []
    
    for load in p_load:
        #PRINTING STUFF
        print 'present_crit_distribution_original: ',present_crit_distribution_original
        print 'absent_crit_distribution_original: ', absent_crit_distribution_original
        print 'present_crit', present_crit
        print 'absent_crit', absent_crit
        print 'present_crit_distribution: ', present_crit_distribution
        print 'absent_crit_distribution: ', absent_crit_distribution
        print 'critical present set: ', critical_present_set
        print 'critical absent set: ', critical_absent_set
        print'---------------------------------------------------'
        normal_availble = [n for n in normal if n not in normal_used]
        print 'normal available:', len(normal_availble)
    # PICKING CRITICAL PROBES    
    #------------------------------------------------------------------------------
        if present_crit != 0:
            present_critical_per_block = []
            while len(present_critical_per_block) < present_crit:
                crit_probe = str(np.random.choice(critical_present_set,1,replace = False))[2:-2]
                if crit_probe not in present_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Present' in possible_images_dict[crit_probe]:

                    present_critical_per_block.append(crit_probe)
            critical_present.append(present_critical_per_block)
                    
        print 'present_critical_per_block:', present_critical_per_block
        
        if absent_crit != 0:
            absent_critical_per_block = []
            while len(absent_critical_per_block) < absent_crit:
                crit_probe = str(np.random.choice(critical_absent_set,1,replace = False))[2:-2]
                if crit_probe not in absent_critical_per_block and \
                crit_probe not in critical_probes_used and load in possible_images_dict[crit_probe] and \
                'Target Absent' in possible_images_dict[crit_probe]:

                    absent_critical_per_block.append(crit_probe)
            critical_absent.append(absent_critical_per_block)
            
        print 'absent_critical_per_block:', absent_critical_per_block  
        print 'critical_present: ',critical_present
        print 'critical_absent: ',critical_absent
        
        for n in present_critical_per_block + absent_critical_per_block:
            critical_probes_used.append(n)
            
        print 'critical_probes_used: ', critical_probes_used
    #------------------------------------------------------------------------------
    # PICKING PRESENT AND ABSENT PROBES
        total = present_n + absent_n
        while len(probes_per_block) < (present_n - present_crit):
            probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in present_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        while (present_n - present_crit) <= len(probes_per_block) < total - present_crit - absent_crit:
            probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
            if probe not in probes_per_block and probe not in absent_used and load in possible_images_dict[probe] \
            and 'Critical' not in possible_images_dict[probe]:
                probes_per_block.append(probe)
                
        print 'probes_per_block :', probes_per_block
        
        for n in probes_per_block:
            if 'Target Present' in possible_images_dict[n]:
                present_used.append(n)
            elif 'Target Absent' in possible_images_dict[n]:
                absent_used.append(n)

        probes.append(probes_per_block)
        
        print 'probes: ', probes
        present_per_block = [n for n in probes_per_block if 'Target Present' in possible_images_dict[n]]
        absent_per_block = [n for n in probes_per_block if 'Target Absent' in possible_images_dict[n]]
        print 'Present Used in block: ',len(present_per_block)
        print 'Absent Used in block',len(absent_per_block)
    #------------------------------------------------------------------------------    
    #Counting critical probes    
        critical_probes_counter = len(present_critical_per_block + absent_critical_per_block)
        print 'Critical probes counter: ',critical_probes_counter
        print 'Present Critical: ', len(present_critical_per_block)
        print 'Absent Critical: ', len(absent_critical_per_block)

        modifier.append(critical_probes_counter)
    #------------------------------------------------------------------------------
    #Picking critical trials
        while len(critical_per_block) < (3-critical_probes_counter):
            image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
            if image not in critical_per_block and image not in critical_used \
                and 'No Target' in possible_images_dict[image] and load in possible_images_dict[image]:
                critical_per_block.append(image) 
        print 'List of critical trials without probe: '
        for n in critical_per_block:
            critical_used.append(n)
            print possible_images_dict[n]
        #temp = []

        critical.append(critical_per_block)

    #------------------------------------------------------------------------------
    #Picking normal trials
        while len(normal_per_block) < 51 - (3 - critical_probes_counter):
            image = str(np.random.choice(normal,1,replace = False))[2:-2]
            if image not in normal_per_block and image not in normal_used and load in possible_images_dict[image]:
                normal_per_block.append(image)
        for n in normal_per_block:
            normal_used.append(n)
        print 'normal in this block: ', len(normal_per_block)
        print 'normal used overall: ',len(normal_used)

        normal_builder.append(normal_per_block)
    #----------------------------------------------------------------------------
        
        print 'critical_probes_used', critical_probes_used 
        
        
        
        if 'sequence_final' in locals():
            print 'sequence_final exists'
        else:
            print 'sequence final does not exist'
            sequence_final = position_finder()
            print sequence_final
        print'---------------------------------------------------'
        print 'END OF BLOCK PROCESSING'
        print'---------------------------------------------------'
        print 'BUILDING THE BLOCK'
        first_element = [x[0] for x in sequence_final]
        second_element = [x[1] for x in sequence_final]
        second_element_counter = 0
        probes_position = []
        for image in range(60):
            #print [x[1] for x in sequence_final if x[0] ==image][0]
            if image in first_element:
                
                print 'image', image, second_element[second_element_counter]
        
                if second_element[second_element_counter] == 'Target Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break       
                elif second_element[second_element_counter] == 'Target Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical':
                    while True:
                        element = str(np.random.choice(critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break     
                elif second_element[second_element_counter] == 'Critical Present':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(present_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break   
                elif second_element[second_element_counter] == 'Critical Absent':
                    probes_position.append(image)
                    while True:
                        element = str(np.random.choice(absent_critical_per_block,1,replace = False))[2:-2]
                        if element not in block:
                            block.append(element)
                            second_element_counter = second_element_counter +1
                            break  
            else:
                while True:
                    element = str(np.random.choice(normal_per_block,1,replace = False))[2:-2]
                    if element not in block:
                        block.append(element)
                        break
                
        print 'block:', len(block)   
        print'---------------------------------------------------'
        print 'probes_position: ', probes_position
    #-----------------------------------------------------------------------------
        normal_per_block = []
        probes_per_block = []
        critical_per_block = []
        present_critical_per_block = []
        absent_critical_per_block = []
    #-----------------------------------------------------------------------------
    return block

# %%
def position_finder():
    global present_critical_per_block, absent_critical_per_block, present_per_block, absent_per_block, critical_per_block
    x = len(present_critical_per_block + absent_critical_per_block)
    print 'x', x
    print 'present_critical_per_block', len(present_critical_per_block)
    print 'absent_critical_per_block', len(absent_critical_per_block)
    while True:    
        while True:
            a = [random.randint(1,10) for r in xrange(12-x)]
            if sum(a) <= 60:
                break

        new_list_1 = []
        acc = 0
        for i in a:
            acc = acc + i
            new_list_1.append(acc)
        new_list_1 = [n - 1 for n in new_list_1]

        if len(present_critical_per_block) == 0 and len(absent_critical_per_block) == 0:
            print 'ciao', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block) + ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        if len(present_critical_per_block) != 0 or len(absent_critical_per_block) != 0:
            print 'ciao2', len(critical_per_block)

            sequence = ['Target Present'] * len(present_per_block)  +\
            ['Target Absent'] * len(absent_per_block) +\
            ['Critical'] * len(critical_per_block) +\
            ['Critical Present'] * len(present_critical_per_block) +\
            ['Critical Absent'] * len(absent_critical_per_block)
            sequence = random.sample(sequence, len(sequence))

        sequence_final = zip(new_list_1, sequence)
        #print sequence_final
        #print len(sequence_final)
        gap_check = [n[0] for n in sequence_final if 'Critical' in n[1]] 
        #print gap_check
        container = []
        for i in gap_check:
            elements = [i+1, i+2]
            for element in elements:
                if element in new_list_1:
                    container.append(element)
        #print 'container', len(container),container
        if len(container) == 0:
            break
        else:
            sequence_final = []

    print '------------------'
    print new_list_1, len(new_list_1)
    print 'gap_check: ', gap_check
    print len(sequence_final)

    for i in sequence_final:
        print i
    return sequence_final

# %%
def block_unpacker(splitting_index,present,absent):
    block = block_pair(present,absent) #, probes_position
    low_block = []
    high_block = []
    for i in range(len(block)):
        if i < (len(block)/2):
            low_block.append(block[i])
        else:
            high_block.append(block[i])
    #print probes_position
    print len(low_block), len(high_block)
    return low_block, high_block #, probes_position

# %%
def tone_properties():
    while True:
        possible_tones = ['tone1','tone2']
        low_one_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_two_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_three_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        low_four_tones = [np.random.choice(possible_tones) for r in xrange(3)]
        high_one_tones = []
        high_two_tones = []
        high_three_tones = []
        high_four_tones = []
        for each in low_one_tones:
            if each == 'tone1':
                high_one_tones.append('tone2')
            elif each == 'tone2':
                high_one_tones.append('tone1')
        for each in low_two_tones:
            if each == 'tone1':
                high_two_tones.append('tone2')
            elif each == 'tone2':
                high_two_tones.append('tone1')
        for each in low_three_tones:
            if each == 'tone1':
                high_three_tones.append('tone2')
            elif each == 'tone2':
                high_three_tones.append('tone1')
        for each in low_four_tones:
            if each == 'tone1':
                high_four_tones.append('tone2')
            elif each == 'tone2':
                high_four_tones.append('tone1')
        sound_Hz = low_one_tones + low_two_tones + low_three_tones + low_four_tones + high_one_tones + high_two_tones +\
        high_three_tones + high_four_tones

        tone1_counter = 0
        tone2_counter = 0
        for each in sound_Hz:
            if each == 'tone1':
                tone1_counter = tone1_counter + 1
            elif each == 'tone2':
                tone2_counter = tone2_counter + 1

        low_load_tones = [n for n in sound_Hz[0:12]]
        high_load_tones = [n for n in sound_Hz[12:25]]
        low_load_tone1s = [n for n in low_load_tones if n == 'tone1']
        low_load_tone2s = [n for n in low_load_tones if n == 'tone2']
        high_load_tone1s = [n for n in high_load_tones if n == 'tone1']
        high_load_tone2s = [n for n in high_load_tones if n =='tone2']

        if len(low_load_tone1s) == len(low_load_tone2s) and len(high_load_tone1s) == len(high_load_tone2s):
            print low_one_tones
            print high_one_tones
            print '----------------------'
            print low_two_tones
            print high_two_tones
            print '----------------------'
            print low_three_tones
            print high_three_tones
            print '----------------------'
            print low_four_tones
            print high_four_tones
            print '----------------------'
            print 'total n of tones: ', len(sound_Hz)
            print '----------------------'
            print 'total n of 1500 Hz tones: ', tone1_counter
            print 'total n of 2000 Hz tones: ', tone2_counter
            print '----------------------'
            print len(low_load_tone1s) == len(low_load_tone2s)
            print len(low_load_tone1s)
            print len(low_load_tone2s)
            print len(high_load_tone1s) == len(high_load_tone2s)
            print len(high_load_tone1s)
            print len(high_load_tone2s)
            break
    sound_onset = []
    for i in range(48):
        a = random.uniform(0, 0.999)
        a = int(str(a)[2:5])
        #print a
        sound_onset.append(a)

    #------------------------------------------------------------------------------
    # APPEND TO DICT
    sound_index = 0
    for each in possible_images_dict:
        if 'Critical' in possible_images_dict[each]:
            possible_images_dict[each].append(sound_Hz[sound_index])
            possible_images_dict[each].append(sound_onset[sound_index])
            sound_index = sound_index + 1
        elif 'Normal' in possible_images_dict[each]:
            possible_images_dict[each].append('No tone')
            possible_images_dict[each].append(-999)

# %%
def appending_to_dict(trial_n):
    global blocks
    for b in range(8):
        this_block_images = blocks[b]
        for im in this_block_images:
            trials[trial_n] = possible_images_dict[im]
            trials[trial_n].append(im)
            trial_n += 1
    print 'len(trials): ', len(trials)

# %%
######################
### FIRST ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  10
# Critical, high:  10
# Are all critical trials unique?  True
# Number of critical probes:  4
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  6
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 1, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  ['2008_001495.jpg', '2008_007970.jpg']
# critical absent set:  ['2008_005046.jpg', '2008_007629.jpg']
# ---------------------------------------------------
# normal available: 388
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_005978.jpg', '2008_000151.jpg', '2010_002645.jpg', '2010_004662.jpg']
# probes_per_block : ['2008_005978.jpg', '2008_000151.jpg', '2010_002645.jpg', '2010_004662.jpg', '2008_004624.jpg', '2009_003530.jpg', '2008_002700.jpg', '2008_006998.jpg', '2009_002325.jpg']
# probes:  [['2008_005978.jpg', '2008_000151.jpg', '2010_002645.jpg', '2010_004662.jpg', '2008_004624.jpg', '2009_003530.jpg', '2008_002700.jpg', '2008_006998.jpg', '2009_002325.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', nan, nan, nan, nan, 17.316646037114566, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 15.731962722166625, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 19.25273490800736, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [1, 9, 12, 15, 20, 28, 38, 39, 49, 54, 57, 58] 12
# gap_check:  [28, 39, 54]
# 12
# (1, 'Target Absent')
# (9, 'Target Present')
# (12, 'Target Absent')
# (15, 'Target Present')
# (20, 'Target Absent')
# (28, 'Critical')
# (38, 'Target Absent')
# (39, 'Critical')
# (49, 'Target Absent')
# (54, 'Critical')
# (57, 'Target Present')
# (58, 'Target Present')
# [(1, 'Target Absent'), (9, 'Target Present'), (12, 'Target Absent'), (15, 'Target Present'), (20, 'Target Absent'), (28, 'Critical'), (38, 'Target Absent'), (39, 'Critical'), (49, 'Target Absent'), (54, 'Critical'), (57, 'Target Present'), (58, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 9 Target Present
# image 12 Target Absent
# image 15 Target Present
# image 20 Target Absent
# image 28 Critical
# image 38 Target Absent
# image 39 Critical
# image 49 Target Absent
# image 54 Critical
# image 57 Target Present
# image 58 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 9, 12, 15, 20, 38, 49, 57, 58]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 1, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  ['2008_001495.jpg', '2008_007970.jpg']
# critical absent set:  ['2008_005046.jpg', '2008_007629.jpg']
# ---------------------------------------------------
# normal available: 340
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_003884.jpg', '2011_000824.jpg', '2008_001283.jpg', '2008_006841.jpg']
# probes_per_block : ['2009_003884.jpg', '2011_000824.jpg', '2008_001283.jpg', '2008_006841.jpg', '2011_001991.jpg', '2008_004858.jpg', '2008_007388.jpg', '2008_002736.jpg', '2011_001304.jpg']
# probes:  [['2008_005978.jpg', '2008_000151.jpg', '2010_002645.jpg', '2010_004662.jpg', '2008_004624.jpg', '2009_003530.jpg', '2008_002700.jpg', '2008_006998.jpg', '2009_002325.jpg'], ['2009_003884.jpg', '2011_000824.jpg', '2008_001283.jpg', '2008_006841.jpg', '2011_001991.jpg', '2008_004858.jpg', '2008_007388.jpg', '2008_002736.jpg', '2011_001304.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' cat', nan, nan, nan, nan, 31.54166437440535, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' diningtable', ' boat', 35.38363353726925, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' bottle', nan, nan, 32.179769175040214, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Absent
# image 9 Target Present
# image 12 Target Absent
# image 15 Target Present
# image 20 Target Absent
# image 28 Critical
# image 38 Target Absent
# image 39 Critical
# image 49 Target Absent
# image 54 Critical
# image 57 Target Present
# image 58 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 9, 12, 15, 20, 38, 49, 57, 58]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  ['2008_001495.jpg', '2008_007970.jpg']
# critical absent set:  ['2008_005046.jpg', '2008_007629.jpg']
# ---------------------------------------------------
# normal available: 292
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_003767.jpg', '2008_001238.jpg', '2010_003287.jpg', '2008_005123.jpg', '2009_001894.jpg']
# probes_per_block : ['2008_003767.jpg', '2008_001238.jpg', '2010_003287.jpg', '2008_005123.jpg', '2009_001894.jpg', '2011_002303.jpg', '2010_000750.jpg', '2009_003679.jpg', '2008_007274.jpg']
# probes:  [['2008_005978.jpg', '2008_000151.jpg', '2010_002645.jpg', '2010_004662.jpg', '2008_004624.jpg', '2009_003530.jpg', '2008_002700.jpg', '2008_006998.jpg', '2009_002325.jpg'], ['2009_003884.jpg', '2011_000824.jpg', '2008_001283.jpg', '2008_006841.jpg', '2011_001991.jpg', '2008_004858.jpg', '2008_007388.jpg', '2008_002736.jpg', '2011_001304.jpg'], ['2008_003767.jpg', '2008_001238.jpg', '2010_003287.jpg', '2008_005123.jpg', '2009_001894.jpg', '2011_002303.jpg', '2010_000750.jpg', '2009_003679.jpg', '2008_007274.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' horse', nan, nan, nan, nan, 19.76483640822989, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 18.68471821171516, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 18.603518928106915, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [1, 8, 15, 18, 28, 29, 34, 39, 44, 49, 55, 56] 12
# gap_check:  [8, 34, 39]
# 12
# (1, 'Target Present')
# (8, 'Critical')
# (15, 'Target Absent')
# (18, 'Target Present')
# (28, 'Target Present')
# (29, 'Target Absent')
# (34, 'Critical')
# (39, 'Critical')
# (44, 'Target Present')
# (49, 'Target Absent')
# (55, 'Target Present')
# (56, 'Target Absent')
# [(1, 'Target Present'), (8, 'Critical'), (15, 'Target Absent'), (18, 'Target Present'), (28, 'Target Present'), (29, 'Target Absent'), (34, 'Critical'), (39, 'Critical'), (44, 'Target Present'), (49, 'Target Absent'), (55, 'Target Present'), (56, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 8 Critical
# image 15 Target Absent
# image 18 Target Present
# image 28 Target Present
# image 29 Target Absent
# image 34 Critical
# image 39 Critical
# image 44 Target Present
# image 49 Target Absent
# image 55 Target Present
# image 56 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 15, 18, 28, 29, 44, 49, 55, 56]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [1, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  ['2008_001495.jpg', '2008_007970.jpg']
# critical absent set:  ['2008_005046.jpg', '2008_007629.jpg']
# ---------------------------------------------------
# normal available: 244
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_002887.jpg', '2010_001682.jpg', '2011_001605.jpg', '2008_000541.jpg', '2010_003579.jpg']
# probes_per_block : ['2008_002887.jpg', '2010_001682.jpg', '2011_001605.jpg', '2008_000541.jpg', '2010_003579.jpg', '2009_005118.jpg', '2008_008681.jpg', '2009_000629.jpg', '2010_002742.jpg']
# probes:  [['2008_005978.jpg', '2008_000151.jpg', '2010_002645.jpg', '2010_004662.jpg', '2008_004624.jpg', '2009_003530.jpg', '2008_002700.jpg', '2008_006998.jpg', '2009_002325.jpg'], ['2009_003884.jpg', '2011_000824.jpg', '2008_001283.jpg', '2008_006841.jpg', '2011_001991.jpg', '2008_004858.jpg', '2008_007388.jpg', '2008_002736.jpg', '2011_001304.jpg'], ['2008_003767.jpg', '2008_001238.jpg', '2010_003287.jpg', '2008_005123.jpg', '2009_001894.jpg', '2011_002303.jpg', '2010_000750.jpg', '2009_003679.jpg', '2008_007274.jpg'], ['2008_002887.jpg', '2010_001682.jpg', '2011_001605.jpg', '2008_000541.jpg', '2010_003579.jpg', '2009_005118.jpg', '2008_008681.jpg', '2009_000629.jpg', '2010_002742.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' car', ' dog', ' person', nan, nan, 29.763552134631723, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' dog', ' bottle', 31.05804957013649, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 28.66706520443793, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 8 Critical
# image 15 Target Absent
# image 18 Target Present
# image 28 Target Present
# image 29 Target Absent
# image 34 Critical
# image 39 Critical
# image 44 Target Present
# image 49 Target Absent
# image 55 Target Present
# image 56 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 15, 18, 28, 29, 44, 49, 55, 56]
# 60 60
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 1
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2008_001495.jpg', '2008_007970.jpg']
# critical absent set:  ['2008_005046.jpg', '2008_007629.jpg']
# ---------------------------------------------------
# normal available: 196
# present_critical_per_block: ['2008_001495.jpg']
# absent_critical_per_block: ['2008_005046.jpg']
# critical_present:  [['2008_001495.jpg']]
# critical_absent:  [['2008_005046.jpg']]
# critical_probes_used:  ['2008_001495.jpg', '2008_005046.jpg']
# probes_per_block : ['2010_004014.jpg', '2009_002697.jpg', '2009_002817.jpg']
# probes_per_block : ['2010_004014.jpg', '2009_002697.jpg', '2009_002817.jpg', '2009_002803.jpg', '2009_001723.jpg', '2009_000087.jpg', '2010_005054.jpg']
# probes:  [['2008_005978.jpg', '2008_000151.jpg', '2010_002645.jpg', '2010_004662.jpg', '2008_004624.jpg', '2009_003530.jpg', '2008_002700.jpg', '2008_006998.jpg', '2009_002325.jpg'], ['2009_003884.jpg', '2011_000824.jpg', '2008_001283.jpg', '2008_006841.jpg', '2011_001991.jpg', '2008_004858.jpg', '2008_007388.jpg', '2008_002736.jpg', '2011_001304.jpg'], ['2008_003767.jpg', '2008_001238.jpg', '2010_003287.jpg', '2008_005123.jpg', '2009_001894.jpg', '2011_002303.jpg', '2010_000750.jpg', '2009_003679.jpg', '2008_007274.jpg'], ['2008_002887.jpg', '2010_001682.jpg', '2011_001605.jpg', '2008_000541.jpg', '2010_003579.jpg', '2009_005118.jpg', '2008_008681.jpg', '2009_000629.jpg', '2010_002742.jpg'], ['2010_004014.jpg', '2009_002697.jpg', '2009_002817.jpg', '2009_002803.jpg', '2009_001723.jpg', '2009_000087.jpg', '2010_005054.jpg']]
# Present Used in block:  3
# Absent Used in block 4
# Critical probes counter:  2
# Present Critical:  1
# Absent Critical:  1
# List of critical trials without probe:
# [' chair', ' diningtable', nan, nan, nan, 20.017308322976007, 'low', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  50
# normal used overall:  242
# critical_probes_used ['2008_001495.jpg', '2008_005046.jpg']
# sequence final does not exist
# x 2
# present_critical_per_block 1
# absent_critical_per_block 1
# ciao2 1
# ciao2 1
# ------------------
# [8, 16, 20, 30, 36, 38, 40, 43, 52, 59] 10
# gap_check:  [16, 40, 43]
# 10
# (8, 'Target Absent')
# (16, 'Critical')
# (20, 'Target Absent')
# (30, 'Target Present')
# (36, 'Target Present')
# (38, 'Target Absent')
# (40, 'Critical Absent')
# (43, 'Critical Present')
# (52, 'Target Present')
# (59, 'Target Absent')
# [(8, 'Target Absent'), (16, 'Critical'), (20, 'Target Absent'), (30, 'Target Present'), (36, 'Target Present'), (38, 'Target Absent'), (40, 'Critical Absent'), (43, 'Critical Present'), (52, 'Target Present'), (59, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 8 Target Absent
# image 16 Critical
# image 20 Target Absent
# image 30 Target Present
# image 36 Target Present
# image 38 Target Absent
# image 40 Critical Absent
# image 43 Critical Present
# image 52 Target Present
# image 59 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [8, 20, 30, 36, 38, 40, 43, 52, 59]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 1
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2008_001495.jpg', '2008_007970.jpg']
# critical absent set:  ['2008_005046.jpg', '2008_007629.jpg']
# ---------------------------------------------------
# normal available: 146
# present_critical_per_block: ['2008_007970.jpg']
# absent_critical_per_block: ['2008_007629.jpg']
# critical_present:  [['2008_001495.jpg'], ['2008_007970.jpg']]
# critical_absent:  [['2008_005046.jpg'], ['2008_007629.jpg']]
# critical_probes_used:  ['2008_001495.jpg', '2008_005046.jpg', '2008_007970.jpg', '2008_007629.jpg']
# probes_per_block : ['2010_000792.jpg', '2008_007423.jpg', '2008_007745.jpg']
# probes_per_block : ['2010_000792.jpg', '2008_007423.jpg', '2008_007745.jpg', '2008_008210.jpg', '2008_008628.jpg', '2008_006062.jpg', '2008_001673.jpg']
# probes:  [['2008_005978.jpg', '2008_000151.jpg', '2010_002645.jpg', '2010_004662.jpg', '2008_004624.jpg', '2009_003530.jpg', '2008_002700.jpg', '2008_006998.jpg', '2009_002325.jpg'], ['2009_003884.jpg', '2011_000824.jpg', '2008_001283.jpg', '2008_006841.jpg', '2011_001991.jpg', '2008_004858.jpg', '2008_007388.jpg', '2008_002736.jpg', '2011_001304.jpg'], ['2008_003767.jpg', '2008_001238.jpg', '2010_003287.jpg', '2008_005123.jpg', '2009_001894.jpg', '2011_002303.jpg', '2010_000750.jpg', '2009_003679.jpg', '2008_007274.jpg'], ['2008_002887.jpg', '2010_001682.jpg', '2011_001605.jpg', '2008_000541.jpg', '2010_003579.jpg', '2009_005118.jpg', '
009_001723.jpg', '2009_000087.jpg', '2010_005054.jpg'], ['2010_000792.jpg', '2008_007423.jpg', '2008_007745.jpg', '2008_008210.jpg', '2008_008628.jpg', '2008_006062.jpg', '2008_001673.jpg'], ['2009_003309.jpg', '2008_007704.jpg', '2008_004893.jpg', '2009_000059.jpg', '2008_002372.jpg', '2011_000514.jpg', '2009_004984.jpg', '2008_000952.jpg', '2010_000109.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', ' car', nan, nan, 20.934599857700228, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 15.553393150912814, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 16.65124246053083, 'low', ' boat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  340
# critical_probes_used ['2008_001495.jpg', '2008_005046.jpg', '2008_007970.jpg', '2008_007629.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [1, 7, 9, 16, 19, 25, 26, 34, 38, 43, 49, 51] 12
# gap_check:  [26, 34, 51]
# 12
# (1, 'Target Present')
# (7, 'Target Absent')
# (9, 'Target Absent')
# (16, 'Target Absent')
# (19, 'Target Present')
# (25, 'Target Present')
# (26, 'Critical')
# (34, 'Critical')
# (38, 'Target Present')
# (43, 'Target Absent')
# (49, 'Target Present')
# (51, 'Critical')
# [(1, 'Target Present'), (7, 'Target Absent'), (9, 'Target Absent'), (16, 'Target Absent'), (19, 'Target Present'), (25, 'Target Present'), (26, 'Critical'), (34, 'Critical'), (38, 'Target Present'), (43, 'Target Absent'), (49, 'Target Present'), (51, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 7 Target Absent
# image 9 Target Absent
# image 16 Target Absent
# image 19 Target Present
# image 25 Target Present
# image 26 Critical
# image 34 Critical
# image 38 Target Present
# image 43 Target Absent
# image 49 Target Present
# image 51 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [1, 7, 9, 16, 19, 25, 38, 43, 49]
# present_crit_distribution_original:  [0, 0, 1, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  []
# absent_crit_distribution:  []
# critical present set:  ['2008_001495.jpg', '2008_007970.jpg']
# critical absent set:  ['2008_005046.jpg', '2008_007629.jpg']
# ---------------------------------------------------
# normal available: 48
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2008_001495.jpg'], ['2008_007970.jpg']]
# critical_absent:  [['2008_005046.jpg'], ['2008_007629.jpg']]
# critical_probes_used:  ['2008_001495.jpg', '2008_005046.jpg', '2008_007970.jpg', '2008_007629.jpg']
# probes_per_block : ['2008_001278.jpg', '2008_007527.jpg', '2010_006033.jpg', '2008_008607.jpg', '2011_001025.jpg']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# len(trials):  480

# %%
######################
### SECOND ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(481)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  10
# Critical, high:  10
# Are all critical trials unique?  True
# Number of critical probes:  4
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  9
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2009_002325.jpg', '2008_001451.jpg']
# critical absent set:  ['2008_000105.jpg', '2008_004670.jpg']
# ---------------------------------------------------
# normal available: 388
# present_critical_per_block: []
# absent_critical_per_block: ['2008_000105.jpg']
# critical_present:  []
# critical_absent:  [['2008_000105.jpg']]
# critical_probes_used:  ['2008_000105.jpg']
# probes_per_block : ['2008_008395.jpg', '2009_001470.jpg', '2009_002711.jpg', '2008_000151.jpg']
# probes_per_block : ['2008_008395.jpg', '2009_001470.jpg', '2009_002711.jpg', '2008_000151.jpg', '2008_000112.jpg', '2008_004607.jpg', '2008_006703.jpg', '2010_004339.jpg']
# probes:  [['2008_008395.jpg', '2009_001470.jpg', '2009_002711.jpg', '2008_000151.jpg', '2008_000112.jpg', '2008_004607.jpg', '2008_006703.jpg', '2010_004339.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' bottle', nan, nan, nan, nan, 17.883134744539575, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 20.088435845702712, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  49
# critical_probes_used ['2008_000105.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ciao2 2
# ------------------
# [0, 4, 11, 16, 24, 29, 35, 38, 42, 48, 56] 11
# gap_check:  [35, 42, 56]
# 11
# (0, 'Target Present')
# (4, 'Target Present')
# (11, 'Target Absent')
# (16, 'Target Absent')
# (24, 'Target Absent')
# (29, 'Target Present')
# (35, 'Critical')
# (38, 'Target Present')
# (42, 'Critical Absent')
# (48, 'Target Absent')
# (56, 'Critical')
# [(0, 'Target Present'), (4, 'Target Present'), (11, 'Target Absent'), (16, 'Target Absent'), (24, 'Target Absent'), (29, 'Target Present'), (35, 'Critical'), (38, 'Target Present'), (42, 'Critical Absent'), (48, 'Target Absent'), (56, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 0 Target Present
# image 4 Target Present
# image 11 Target Absent
# image 16 Target Absent
# image 24 Target Absent
# image 29 Target Present
# image 35 Critical
# image 38 Target Present
# image 42 Critical Absent
# image 48 Target Absent
# image 56 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [0, 4, 11, 16, 24, 29, 38, 42, 48]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 0, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [1, 0, 0]
# absent_crit_distribution:  [0, 0, 0]
# critical present set:  ['2009_002325.jpg', '2008_001451.jpg']
# critical absent set:  ['2008_000105.jpg', '2008_004670.jpg']
# ---------------------------------------------------
# normal available: 339
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' sofa', ' dog', nan, nan, nan, 20.934059682149233, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 19.24976137409617, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  147
# critical_probes_used ['2008_000105.jpg', '2008_004670.jpg', '2009_002325.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 1
# absent_critical_per_block 0
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ciao2 2
# ------------------
# [9, 13, 20, 25, 28, 35, 38, 42, 45, 50, 55] 11
# gap_check:  [20, 28, 38]
# 11
# (9, 'Target Present')
# (13, 'Target Present')
# (20, 'Critical Present')
# (25, 'Target Absent')
# (28, 'Critical')
# (35, 'Target Present')
# (38, 'Critical')
# (42, 'Target Absent')
# (45, 'Target Absent')
# (50, 'Target Present')
# (55, 'Target Absent')
# [(9, 'Target Present'), (13, 'Target Present'), (20, 'Critical Present'), (25, 'Target Absent'), (28, 'Critical'), (35, 'Target Present'), (38, 'Critical'), (42, 'Target Absent'), (45, 'Target Absent'), (50, 'Target Present'), (55, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 9 Target Present
# image 13 Target Present
# image 20 Critical Present
# image 25 Target Absent
# image 28 Critical
# image 35 Target Present
# image 38 Critical
# image 42 Target Absent
# image 45 Target Absent
# image 50 Target Present
# image 55 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [9, 13, 20, 25, 35, 42, 45, 50, 55]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 0, 0]
# present_crit 1
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [0, 0]
# critical present set:  ['2009_002325.jpg', '2008_001451.jpg']
# critical absent set:  ['2008_000105.jpg', '2008_004670.jpg']
# ---------------------------------------------------
# normal available: 241
# present_critical_per_block: ['2008_001451.jpg']
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg'], ['2008_001451.jpg']]
# critical_absent:  [['2008_000105.jpg'], ['2008_004670.jpg']]
# critical_probes_used:  ['2008_000105.jpg', '2008_004670.jpg', '2009_002325.jpg', '2008_001451.jpg']
# probes_per_block : ['2010_002620.jpg', '2011_000628.jpg', '2010_005718.jpg', '2008_006841.jpg']
# probes_per_block : ['2010_002620.jpg', '2011_000628.jpg', '2010_005718.jpg', '2008_006841.jpg', '2008_002195.jpg', '2008_005818.jpg', '2008_006844.jpg', '2011_001304.jpg']
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' boat', nan, nan, nan, nan, 19.264337675075122, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' person', ' car', nan, nan, nan, 18.390878339274188, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 14.127469618562607, 'low', ' cat', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  244
# critical_probes_used ['2008_000105.jpg', '2008_004670.jpg', '2009_002325.jpg', '2008_001451.jpg']
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [5, 11, 17, 18, 23, 26, 31, 32, 37, 47, 54, 58] 12
# gap_check:  [11, 18, 23]
# 12
# (5, 'Target Absent')
# (11, 'Critical')
# (17, 'Target Present')
# (18, 'Critical')
# (23, 'Critical')
# (26, 'Target Absent')
# (31, 'Target Present')
# (32, 'Target Absent')
# (37, 'Target Absent')
# (47, 'Target Present')
# (54, 'Target Absent')
# (58, 'Target Present')
# [(5, 'Target Absent'), (11, 'Critical'), (17, 'Target Present'), (18, 'Critical'), (23, 'Critical'), (26, 'Target Absent'), (31, 'Target Present'), (32, 'Target Absent'), (37, 'Target Absent'), (47, 'Target Present'), (54, 'Target Absent'), (58, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Absent
# image 11 Critical
# image 17 Target Present
# image 18 Critical
# image 23 Critical
# image 26 Target Absent
# image 31 Target Present
# image 32 Target Absent
# image 37 Target Absent
# image 47 Target Present
# image 54 Target Absent
# image 58 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 17, 26, 31, 32, 37, 47, 54, 58]
# present_crit_distribution_original:  [0, 1, 0, 0]
# absent_crit_distribution_original:  [1, 0, 0, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  ['2009_002325.jpg', '2008_001451.jpg']
# critical absent set:  ['2008_000105.jpg', '2008_004670.jpg']
# ---------------------------------------------------
# normal available: 144
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  [['2009_002325.jpg'], ['2008_001451.jpg']]
# critical_absent:  [['2008_000105.jpg'], ['2008_004670.jpg']]
# critical_probes_used:  ['2008_000105.jpg', '2008_004670.jpg', '2009_002325.jpg', '2008_001451.jpg']
# probes_per_block : ['2008_006663.jpg', '2010_005628.jpg', '2009_003520.jpg', '2010_001586.jpg']
# probes_per_block : ['2008_006663.jpg', '2010_005628.jpg', '2009_003520.jpg', '2010_001586.jpg', '2010_005270.jpg', '2010_002742.jpg', '2008_006121.jpg', '2008_004991.jpg', '2010_005606.jpg']
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 5 Target Absent
# image 13 Critical
# image 17 Critical
# image 20 Target Present
# image 22 Target Absent
# image 23 Target Present
# image 28 Critical
# image 36 Target Present
# image 41 Target Absent
# image 50 Target Present
# image 52 Target Absent
# image 53 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 20, 22, 23, 36, 41, 50, 52, 53]
# 60 60
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone2', 'tone1']
# ['tone2', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone1', 'tone2']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# len(trials):  960

# %%
######################
### THIRD ITERATION
######################

#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(odd, even)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(961)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  9
# Critical, high:  9
# Are all critical trials unique?  True
# Number of critical probes:  6
# critical_low_present_probes:  1
# critical_high_present_probes:  1
# critical_low_absent_probes:  2
# critical_high_absent_probes:  2
# cycles :  1
# present_crit_distribution_original:  [0, 0, 0, 1]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 1]
# absent_crit_distribution:  [0, 2, 0]
# critical present set:  ['2010_000616.jpg', '2010_001586.jpg']
# critical absent set:  ['2008_001694.jpg', '2008_008395.jpg', '2011_002555.jpg', '2008_002084.jpg']
# ---------------------------------------------------
# normal available: 390
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_005075.jpg', '2008_002145.jpg', '2008_004171.jpg', '2010_000090.jpg']
# probes_per_block : ['2009_005075.jpg', '2008_002145.jpg', '2008_004171.jpg', '2010_000090.jpg', '2009_004598.jpg', '2008_000189.jpg', '2009_001137.jpg', '2008_001367.jpg', '2009_005044.jpg']
# probes:  [['2009_005075.jpg', '2008_002145.jpg', '2008_004171.jpg', '2010_000090.jpg', '2009_004598.jpg', '2008_000189.jpg', '2009_001137.jpg', '2008_001367.jpg', '2009_005044.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' boat', nan, nan, nan, nan, 19.25351959992476, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' sofa', ' person', nan, nan, nan, 20.983298059388602, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 19.793376112600363, 'low', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ------------------
# [3, 6, 10, 16, 21, 28, 29, 33, 36, 40, 48, 50] 12
# gap_check:  [10, 16, 21]
# 12
# (3, 'Target Absent')
# (6, 'Target Absent')
# (10, 'Critical')
# (16, 'Critical')
# (21, 'Critical')
# (28, 'Target Absent')
# (29, 'Target Absent')
# (33, 'Target Present')
# (36, 'Target Present')
# (40, 'Target Absent')
# (48, 'Target Present')
# (50, 'Target Present')
# [(3, 'Target Absent'), (6, 'Target Absent'), (10, 'Critical'), (16, 'Critical'), (21, 'Critical'), (28, 'Target Absent'), (29, 'Target Absent'), (33, 'Target Present'), (36, 'Target Present'), (40, 'Target Absent'), (48, 'Target Present'), (50, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Absent
# image 6 Target Absent
# image 10 Critical
# image 16 Critical
# image 21 Critical
# image 28 Target Absent
# image 29 Target Absent
# image 33 Target Present
# image 36 Target Present
# image 40 Target Absent
# image 48 Target Present
# image 50 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [3, 6, 28, 29, 33, 36, 40, 48, 50]
# present_crit_distribution_original:  [0, 0, 0, 1]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 1]
# absent_crit_distribution:  [0, 2, 0]
# critical present set:  ['2010_000616.jpg', '2010_001586.jpg']
# critical absent set:  ['2008_001694.jpg', '2008_008395.jpg', '2011_002555.jpg', '2008_002084.jpg']
# ---------------------------------------------------
# normal available: 342
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_003802.jpg', '2011_001139.jpg', '2008_003805.jpg', '2010_000074.jpg']
# probes_per_block : ['2009_003802.jpg', '2011_001139.jpg', '2008_003805.jpg', '2010_000074.jpg', '2011_000530.jpg', '2011_002193.jpg', '2009_000629.jpg', '2008_005600.jpg', '2011_002260.jpg']
# probes:  [['2009_005075.jpg', '2008_002145.jpg', '2008_004171.jpg', '2010_000090.jpg', '2009_004598.jpg', '2008_000189.jpg', '2009_001137.jpg', '2008_001367.jpg', '2009_005044.jpg'], ['2009_003802.jpg', '2011_001139.jpg', '2008_003805.jpg', '2010_000074.jpg', '2011_000530.jpg', '2011_002193.jpg', '2009_000629.jpg', '2008_005600.jpg', '2011_002260.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' aeroplane', nan, nan, nan, nan, 29.739677956098852, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 30.30670761720366, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' dog', ' car', nan, nan, 33.09488500291814, 'high', ' dog', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 3 Target Absent
# image 6 Target Absent
# image 10 Critical
# image 16 Critical
# image 21 Critical
# image 28 Target Absent
# image 29 Target Absent
# image 33 Target Present
# image 36 Target Present
# image 40 Target Absent
# image 48 Target Present
# image 50 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [3, 6, 28, 29, 33, 36, 40, 48, 50]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 1]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 1]
# absent_crit_distribution:  [2, 0]
# critical present set:  ['2010_000616.jpg', '2010_001586.jpg']
# critical absent set:  ['2008_001694.jpg', '2008_008395.jpg', '2011_002555.jpg', '2008_002084.jpg']
# ---------------------------------------------------
# normal available: 294
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_000219.jpg', '2010_000109.jpg', '2010_001993.jpg', '2008_002372.jpg', '2009_000619.jpg']
# probes_per_block : ['2008_000219.jpg', '2010_000109.jpg', '2010_001993.jpg', '2008_002372.jpg', '2009_000619.jpg', '2010_000750.jpg', '2010_005054.jpg', '2008_000952.jpg', '2008_001040.jpg']
# probes:  [['2009_005075.jpg', '2008_002145.jpg', '2008_004171.jpg', '2010_000090.jpg', '2009_004598.jpg', '2008_000189.jpg', '2009_001137.jpg', '2008_001367.jpg', '2009_005044.jpg'], ['2009_003802.jpg', '2011_001139.jpg', '2008_003805.jpg', '2010_000074.jpg', '2011_000530.jpg', '2011_002193.jpg', '2009_000629.jpg', '2008_005600.jpg', '2011_002260.jpg'], ['2008_000219.jpg', '2010_000109.jpg', '2010_001993.jpg', '2008_002372.jpg', '2009_000619.jpg', '2010_000750.jpg', '2010_005054.jpg', '2008_000952.jpg', '2008_001040.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' chair', nan, nan, nan, nan, 21.005917005737068, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', nan, nan, 20.561279009327844, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 18.874156232375913, 'low', ' car', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [1, 5, 15, 16, 20, 21, 25, 34, 41, 47, 50, 53] 12
# gap_check:  [1, 16, 50]
# 12
# (1, 'Critical')
# (5, 'Target Present')
# (15, 'Target Absent')
# (16, 'Critical')
# (20, 'Target Present')
# (21, 'Target Absent')
# (25, 'Target Present')
# (34, 'Target Absent')
# (41, 'Target Absent')
# (47, 'Target Present')
# (50, 'Critical')
# (53, 'Target Present')
# [(1, 'Critical'), (5, 'Target Present'), (15, 'Target Absent'), (16, 'Critical'), (20, 'Target Present'), (21, 'Target Absent'), (25, 'Target Present'), (34, 'Target Absent'), (41, 'Target Absent'), (47, 'Target Present'), (50, 'Critical'), (53, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical
# image 5 Target Present
# image 15 Target Absent
# image 16 Critical
# image 20 Target Present
# image 21 Target Absent
# image 25 Target Present
# image 34 Target Absent
# image 41 Target Absent
# image 47 Target Present
# image 50 Critical
# image 53 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [5, 15, 20, 21, 25, 34, 41, 47, 53]
# present_crit_distribution_original:  [0, 0, 0, 1]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 1]
# absent_crit_distribution:  [2, 0]
# critical present set:  ['2010_000616.jpg', '2010_001586.jpg']
# critical absent set:  ['2008_001694.jpg', '2008_008395.jpg', '2011_002555.jpg', '2008_002084.jpg']
# ---------------------------------------------------
# normal available: 246
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_005608.jpg', '2008_000381.jpg', '2008_007970.jpg', '2008_000833.jpg', '2010_003729.jpg']
# probes_per_block : ['2010_005608.jpg', '2008_000381.jpg', '2008_007970.jpg', '2008_000833.jpg', '2010_003729.jpg', '2010_005170.jpg', '2011_002810.jpg', '2009_002306.jpg', '2008_002709.jpg']
# probes:  [['2009_005075.jpg', '2008_002145.jpg', '2008_004171.jpg', '2010_000090.jpg', '2009_004598.jpg', '2008_000189.jpg', '2009_001137.jpg', '2008_001367.jpg', '2009_005044.jpg'], ['2009_003802.jpg', '2011_001139.jpg', '2008_003805.jpg', '2010_000074.jpg', '2011_000530.jpg', '2011_002193.jpg', '2009_000629.jpg', '2008_005600.jpg', '2011_002260.jpg'], ['2008_000219.jpg', '2010_000109.jpg', '2010_001993.jpg', '2008_002372.jpg', '2009_000619.jpg', '2010_000750.jpg', '2010_005054.jpg', '2008_000952.jpg', '2008_001040.jpg'], ['2010_005608.jpg', '2008_000381.jpg', '2008_007970.jpg', '2008_000833.jpg', '2010_003729.jpg', '2010_005170.jpg', '2011_002810.jpg', '2009_002306.jpg', '2008_002709.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' pottedplant', ' person', ' chair', ' dog', nan, 34.099790178372324, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' chair', nan, nan, nan, 34.96662806576853, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' diningtable', ' bottle', nan, 29.62291427984228, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical
# image 5 Target Present
# image 15 Target Absent
# image 16 Critical
# image 20 Target Present
# image 21 Target Absent
# image 25 Target Present
# image 34 Target Absent
# image 41 Target Absent
# image 47 Target Present
# image 50 Critical
# image 53 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [5, 15, 20, 21, 25, 34, 41, 47, 53]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 1]
# absent_crit_distribution_original:  [0, 0, 2, 0]
# present_crit 0
# absent_crit 2
# present_crit_distribution:  [1]
# absent_crit_distribution:  [0]
# critical present set:  ['2010_000616.jpg', '2010_001586.jpg']
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  1
# Absent Critical:  0
# List of critical trials without probe:
# [' bird', nan, nan, nan, nan, 29.594597886254714, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' aeroplane', ' boat', nan, nan, nan, 29.28734944464957, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  390
# critical_probes_used ['2008_008395.jpg', '2008_001694.jpg', '2011_002555.jpg', '2008_002084.jpg', '2010_000616.jpg', '2010_001586.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Target Present
# image 3 Target Absent
# image 9 Critical Present
# image 15 Target Present
# image 21 Target Present
# image 25 Critical
# image 32 Target Present
# image 35 Target Absent
# image 40 Target Absent
# image 42 Target Absent
# image 48 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [1, 3, 9, 15, 21, 32, 35, 40, 42]
# 60 60
# ['tone2', 'tone1', 'tone2']
# ['tone1', 'tone2', 'tone1']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone2', 'tone1']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# len(trials):  1440

# %%
######################
### FOURTH ITERATION
######################


#GLOBALS

############
critical_low_present_probes = []
critical_low_absent_probes = []
critical_high_present_probes = []
critical_high_absent_probes = []
############
target_present = []
target_absent = []
critical_trials = []
############
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')
df.reset_index(drop=False)
image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}
lista = possible_images_dict.keys()
############

target_present, target_absent= present_absent_trials(even, odd)
appending_critical_trials()
#-----------------------------------------------------
normal_no_probe_before = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
target_present_before = deepcopy(target_present)
target_absent_before = deepcopy(target_absent)
critical_trials_before = deepcopy(critical_trials)
critical_low_present_probes_before = deepcopy(critical_low_present_probes)
critical_low_absent_probes_before = deepcopy(critical_low_absent_probes)
critical_high_present_probes_before = deepcopy(critical_high_present_probes)
critical_high_absent_probes_before = deepcopy(critical_high_absent_probes)
#-----------------------------------------------------

present_crit_distribution = critical_probes_distribution(critical_low_present_probes)
absent_crit_distribution = critical_probes_distribution(critical_low_absent_probes)

present_crit_distribution_original = deepcopy(present_crit_distribution)
absent_crit_distribution_original = deepcopy(absent_crit_distribution)
#-----------------------------------------------------

#Defininfg blocks 
normal_per_block = []
probes_per_block = []
present_per_block = []
absent_per_block = []
normal_probes_per_block = []
critical_per_block = []
present_critical_per_block = []
absent_critical_per_block = []

###############################
normal_used = []
present_used = []
absent_used = []
critical_used = []
critical_probes_used = []
normal = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
###############################
block = []
critical_probes_counter = 0 #useless???
critical_probes_set = critical_low_present_probes + critical_low_absent_probes + critical_high_present_probes + critical_high_absent_probes
critical_present_set = [n for n in critical_probes_set if 'Target Present' in possible_images_dict[n]]
critical_absent_set = [n for n in critical_probes_set if 'Target Absent' in possible_images_dict[n]]
###############################
normal_builder = []
probes = []
critical = []
critical_present = []
critical_absent = []
###############################
modifier = []
low_one, high_two = block_unpacker(60,4,5) 
low_two, high_one = block_unpacker(60,5,4) 
low_four, high_three = block_unpacker(60,4,5)
low_three, high_four = block_unpacker(60,5,4) 

tone_properties()

blocks = low_one , high_one , high_two , low_two , high_three , low_three , low_four , high_four
    
appending_to_dict(1441)
# Out:
# Target Present Probes:  36
# Target Absent probes:  36
# Critical trials: 24
# Critical, low:  11
# Critical, high:  11
# Are all critical trials unique?  True
# Number of critical probes:  2
# critical_low_present_probes:  0
# critical_high_present_probes:  0
# critical_low_absent_probes:  1
# critical_high_absent_probes:  1
# cycles :  1
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2008_006954.jpg', '2011_001382.jpg']
# ---------------------------------------------------
# normal available: 386
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2009_001894.jpg', '2008_006998.jpg', '2009_004888.jpg', '2009_000260.jpg']
# probes_per_block : ['2009_001894.jpg', '2008_006998.jpg', '2009_004888.jpg', '2009_000260.jpg', '2008_002504.jpg', '2008_006470.jpg', '2010_000616.jpg', '2010_005217.jpg', '2010_003911.jpg']
# probes:  [['2009_001894.jpg', '2008_006998.jpg', '2009_004888.jpg', '2009_000260.jpg', '2008_002504.jpg', '2008_006470.jpg', '2010_000616.jpg', '2010_005217.jpg', '2010_003911.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' bottle', nan, nan, nan, nan, 17.883134744539575, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 16.417039192791336, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 20.885583923700768, 'low', ' horse', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  48
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ciao 3
# ------------------
# [1, 10, 14, 16, 26, 31, 38, 47, 51, 53, 57, 59] 12
# gap_check:  [1, 26, 31]
# 12
# (1, 'Critical')
# (10, 'Target Present')
# (14, 'Target Absent')
# (16, 'Target Absent')
# (26, 'Critical')
# (31, 'Critical')
# (38, 'Target Present')
# (47, 'Target Absent')
# (51, 'Target Absent')
# (53, 'Target Present')
# (57, 'Target Present')
# (59, 'Target Absent')
# [(1, 'Critical'), (10, 'Target Present'), (14, 'Target Absent'), (16, 'Target Absent'), (26, 'Critical'), (31, 'Critical'), (38, 'Target Present'), (47, 'Target Absent'), (51, 'Target Absent'), (53, 'Target Present'), (57, 'Target Present'), (59, 'Target Absent')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical
# image 10 Target Present
# image 14 Target Absent
# image 16 Target Absent
# image 26 Critical
# image 31 Critical
# image 38 Target Present
# image 47 Target Absent
# image 51 Target Absent
# image 53 Target Present
# image 57 Target Present
# image 59 Target Absent
# block: 60
# ---------------------------------------------------
# probes_position:  [10, 14, 16, 38, 47, 51, 53, 57, 59]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0, 0]
# absent_crit_distribution:  [0, 1, 0]
# critical present set:  []
# critical absent set:  ['2008_006954.jpg', '2011_001382.jpg']
# ---------------------------------------------------
# normal available: 338
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_003283.jpg', '2008_005845.jpg', '2009_000539.jpg', '2011_000824.jpg']
# probes_per_block : ['2008_003283.jpg', '2008_005845.jpg', '2009_000539.jpg', '2011_000824.jpg', '2010_005628.jpg', '2008_002773.jpg', '2010_005606.jpg', '2008_004991.jpg', '2009_000198.jpg']
# probes:  [['2009_001894.jpg', '2008_006998.jpg', '2009_004888.jpg', '2009_000260.jpg', '2008_002504.jpg', '2008_006470.jpg', '2010_000616.jpg', '2010_005217.jpg', '2010_003911.jpg'], ['2008_003283.jpg', '2008_005845.jpg', '2009_000539.jpg', '2011_000824.jpg', '2010_005628.jpg', '2008_002773.jpg', '2010_005606.jpg', '2008_004991.jpg', '2009_000198.jpg']]
# Present Used in block:  4
# Absent Used in block 5
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' horse', nan, nan, nan, 30.92721034000856, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', ' chair', nan, nan, 31.427287995992387, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', ' dog', ' person', nan, nan, 29.763552134631723, 'high', ' person', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  96
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 1 Critical
# image 10 Target Present
# image 14 Target Absent
# image 16 Target Absent
# image 26 Critical
# image 31 Critical
# image 38 Target Present
# image 47 Target Absent
# image 51 Target Absent
# image 53 Target Present
# image 57 Target Present
# image 59 Target Absent
# block: 120
# ---------------------------------------------------
# probes_position:  [10, 14, 16, 38, 47, 51, 53, 57, 59]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2008_006954.jpg', '2011_001382.jpg']
# ---------------------------------------------------
# normal available: 290
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2010_005885.jpg', '2008_007208.jpg', '2009_002749.jpg', '2010_001829.jpg', '2011_001967.jpg']
# probes_per_block : ['2010_005885.jpg', '2008_007208.jpg', '2009_002749.jpg', '2010_001829.jpg', '2011_001967.jpg', '2008_000952.jpg', '2009_004262.jpg', '2009_000716.jpg', '2009_005075.jpg']
# probes:  [['2009_001894.jpg', '2008_006998.jpg', '2009_004888.jpg', '2009_000260.jpg', '2008_002504.jpg', '2008_006470.jpg', '2010_000616.jpg', '2010_005217.jpg', '2010_003911.jpg'], ['2008_003283.jpg', '2008_005845.jpg', '2009_000539.jpg', '2011_000824.jpg', '2010_005628.jpg', '2008_002773.jpg', '2010_005606.jpg', '2008_004991.jpg', '2009_000198.jpg'], ['2010_005885.jpg', '2008_007208.jpg', '2009_002749.jpg', '2010_001829.jpg', '2011_001967.jpg', '2008_000952.jpg', '2009_004262.jpg', '2009_000716.jpg', '2009_005075.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', nan, nan, nan, nan, 15.903696109038165, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 21.001227278103954, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' aeroplane', nan, nan, nan, nan, 12.53657278412077, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  144
# critical_probes_used []
# sequence final does not exist
# x 0
# present_critical_per_block 0
# absent_critical_per_block 0
# ciao 3
# ciao 3
# ------------------
# [7, 13, 20, 22, 24, 31, 39, 42, 43, 52, 56, 58] 12
# gap_check:  [13, 31, 58]
# 12
# (7, 'Target Present')
# (13, 'Critical')
# (20, 'Target Absent')
# (22, 'Target Present')
# (24, 'Target Absent')
# (31, 'Critical')
# (39, 'Target Present')
# (42, 'Target Present')
# (43, 'Target Absent')
# (52, 'Target Absent')
# (56, 'Target Present')
# (58, 'Critical')
# [(7, 'Target Present'), (13, 'Critical'), (20, 'Target Absent'), (22, 'Target Present'), (24, 'Target Absent'), (31, 'Critical'), (39, 'Target Present'), (42, 'Target Present'), (43, 'Target Absent'), (52, 'Target Absent'), (56, 'Target Present'), (58, 'Critical')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 13 Critical
# image 20 Target Absent
# image 22 Target Present
# image 24 Target Absent
# image 31 Critical
# image 39 Target Present
# image 42 Target Present
# image 43 Target Absent
# image 52 Target Absent
# image 56 Target Present
# image 58 Critical
# block: 60
# ---------------------------------------------------
# probes_position:  [7, 20, 22, 24, 39, 42, 43, 52, 56]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 0
# present_crit_distribution:  [0, 0]
# absent_crit_distribution:  [1, 0]
# critical present set:  []
# critical absent set:  ['2008_006954.jpg', '2011_001382.jpg']
# ---------------------------------------------------
# normal available: 242
# present_critical_per_block: []
# absent_critical_per_block: []
# critical_present:  []
# critical_absent:  []
# critical_probes_used:  []
# probes_per_block : ['2008_005526.jpg', '2008_000982.jpg', '2008_008607.jpg', '2008_004482.jpg', '2011_001221.jpg']
# probes_per_block : ['2008_005526.jpg', '2008_000982.jpg', '2008_008607.jpg', '2008_004482.jpg', '2011_001221.jpg', '2009_004414.jpg', '2009_002414.jpg', '2008_000196.jpg', '2010_002472.jpg']
# probes:  [['2009_001894.jpg', '2008_006998.jpg', '2009_004888.jpg', '2009_000260.jpg', '2008_002504.jpg', '2008_006470.jpg', '2010_000616.jpg', '2010_005217.jpg', '2010_003911.jpg'], ['2008_003283.jpg', '2008_005845.jpg', '2009_000539.jpg', '2011_000824.jpg', '2010_005628.jpg', '2008_002773.jpg', '2010_005606.jpg', '2008_004991.jpg', '2009_000198.jpg'], ['2010_005885.jpg', '2008_007208.jpg', '2009_002749.jpg', '2010_001829.jpg', '2011_001967.jpg', '2008_000952.jpg', '2009_004262.jpg', '2009_000716.jpg', '2009_005075.jpg'], ['2008_005526.jpg', '2008_000982.jpg', '2008_008607.jpg', '2008_004482.jpg', '2011_001221.jpg', '2009_004414.jpg', '2009_002414.jpg', '2008_000196.jpg', '2010_002472.jpg']]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' aeroplane', nan, nan, nan, 30.182885716527558, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', nan, nan, nan, 30.958055456079503, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 29.8220330038045, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  192
# critical_probes_used []
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Target Present
# image 13 Critical
# image 20 Target Absent
# image 22 Target Present
# image 24 Target Absent
# image 31 Critical
# image 39 Target Present
# image 42 Target Present
# image 43 Target Absent
# image 52 Target Absent
# image 56 Target Present
# image 58 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [7, 20, 22, 24, 39, 42, 43, 52, 56]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2008_006954.jpg', '2011_001382.jpg']
# ---------------------------------------------------
# normal available: 194
# present_critical_per_block: []
# absent_critical_per_block: ['2008_006954.jpg']
# critical_present:  []
# critical_absent:  [['2008_006954.jpg']]
# critical_probes_used:  ['2008_006954.jpg']
# probes_per_block : ['2011_001886.jpg', '2010_001731.jpg', '2010_002379.jpg', '2009_000087.jpg']
# probes_per_block : ['2011_001886.jpg', '2010_001731.jpg', '2010_002379.jpg', '2009_000087.jpg', '2010_000132.jpg', '2010_003287.jpg', '2008_000177.jpg', '2008_005345.jpg']
# probes:  [['2009_001894.jpg', '2008_006998.jpg', '2009_004888.jpg', '2009_000260.jpg', '2008_002504.jpg', '2008_006470.jpg', '2010_000616.jpg', '2010_005217.jpg', '2010_003911.jpg'], ['2008_003283.jpg', '2008_005845.jpg', '2009_000539.jpg', '2011_000824.jpg', '2010_005628.jpg', '2008_002773.jpg', '2010_005606.jpg', '2008_004991.jpg', '2009_000198.jpg'], ['2010_005885.jpg', '2008_007208.jpg', '2009_002749.jpg', '2010_001829.jpg', '2011_001967.jpg', '2008_000952.jpg', '2009_004262.jpg', '2009_000716.jpg', '2009_005075.jpg'], ['2008_005526.jpg', '2008_000982.jpg', '2008_008607.jpg', '2008_004482.jpg', '2011_001221.jpg', '2009_004414.jpg', '2009_002414.jpg', '2008_000196.jpg', '2010_002472.jpg'], ['2011_001886.jpg', '2010_001731.jpg', '2010_002379.jpg', '2009_000087.jpg', '2010_000132.jpg', '2010_003287.jpg', '2008_000177.jpg', '2008_005345.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' dog', nan, nan, nan, 19.793376112600363, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' chair', nan, nan, nan, nan, 16.98544233464372, 'low', ' chair', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  241
# critical_probes_used ['2008_006954.jpg']
# sequence final does not exist
# x 1
# present_critical_per_block 0
# absent_critical_per_block 1
# ciao2 2
# ------------------
# [7, 13, 15, 17, 22, 29, 33, 43, 44, 49, 55] 11
# gap_check:  [7, 17, 22]
# 11
# (7, 'Critical Absent')
# (13, 'Target Absent')
# (15, 'Target Present')
# (17, 'Critical')
# (22, 'Critical')
# (29, 'Target Absent')
# (33, 'Target Present')
# (43, 'Target Absent')
# (44, 'Target Present')
# (49, 'Target Absent')
# (55, 'Target Present')
# [(7, 'Critical Absent'), (13, 'Target Absent'), (15, 'Target Present'), (17, 'Critical'), (22, 'Critical'), (29, 'Target Absent'), (33, 'Target Present'), (43, 'Target Absent'), (44, 'Target Present'), (49, 'Target Absent'), (55, 'Target Present')]
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Critical Absent
# image 13 Target Absent
# image 15 Target Present
# image 17 Critical
# image 22 Critical
# image 29 Target Absent
# image 33 Target Present
# image 43 Target Absent
# image 44 Target Present
# image 49 Target Absent
# image 55 Target Present
# block: 60
# ---------------------------------------------------
# probes_position:  [7, 13, 15, 29, 33, 43, 44, 49, 55]
# present_crit_distribution_original:  [0, 0, 0, 0]
# absent_crit_distribution_original:  [0, 0, 1, 0]
# present_crit 0
# absent_crit 1
# present_crit_distribution:  [0]
# absent_crit_distribution:  [0]
# critical present set:  []
# critical absent set:  ['2008_006954.jpg', '2011_001382.jpg']
# ---------------------------------------------------
# normal available: 145
# present_critical_per_block: []
# absent_critical_per_block: ['2011_001382.jpg']
# critical_present:  []
# critical_absent:  [['2008_006954.jpg'], ['2011_001382.jpg']]
# critical_probes_used:  ['2008_006954.jpg', '2011_001382.jpg']
# probes_per_block : ['2011_000530.jpg', '2008_007250.jpg', '2011_001649.jpg', '2011_002555.jpg']
# probes_per_block : ['2011_000530.jpg', '2008_007250.jpg', '2011_001649.jpg', '2011_002555.jpg', '2008_001210.jpg', '2011_001116.jpg', '2008_002672.jpg', '2008_003805.jpg']
# probes:  [['2009_001894.jpg', '2008_006998.jpg', '2009_004888.jpg', '2009_000260.jpg', '2008_002504.jpg', '2008_006470.jpg', '2010_000616.jpg', '2010_005217.jpg', '2010_003911.jpg'], ['2008_003283.jpg', '2008_005845.jpg', '2009_000539.jpg', '2011_000824.jpg', '2010_005628.jpg', '2008_002773.jpg', '2010_005606.jpg', '2008_004991.jpg', '2009_000198.jpg'], ['2010_005885.jpg', '2008_007208.jpg', '2009_002749.jpg', '2010_001829.jpg', '2011_001967.jpg', '2008_000952.jpg', '2009_004262.jpg', '2009_000716.jpg', '2009_005075.jpg'], ['2008_005526.jpg', '2008_000982.jpg', '2008_008607.jpg', '2008_004482.jpg', '2011_001221.jpg', '2009_004414.jpg', '2009_002414.jpg', '2008_000196.jpg', '2010_002472.jpg'], ['2011_001886.jpg', '2010_001731.jpg', '2010_002379.jpg', '2009_000087.jpg', '2010_000132.jpg', '2010_003287.jpg', '2008_000177.jpg', '2008_005345.jpg'], ['2011_000530.jpg', '2008_007250.jpg', '2011_001649.jpg', '2011_002555.jpg', '2008_001210.jpg', '2011_001116.jpg', '2008_002672.jpg', '2008_003805.jpg']]
# Present Used in block:  4
# Absent Used in block 4
# Critical probes counter:  1
# Present Critical:  0
# Absent Critical:  1
# List of critical trials without probe:
# [' person', ' boat', nan, nan, nan, 29.006457456633935, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' person', ' bird', ' boat', nan, nan, 31.913409738647122, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  49
# normal used overall:  290
# critical_probes_used ['2008_006954.jpg', '2011_001382.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 7 Critical Absent
# image 13 Target Absent
# image 15 Target Present
# image 17 Critical
# image 22 Critical
# image 29 Target Absent
# image 33 Target Present
# image 43 Target Absent
# image 44 Target Present
# image 49 Target Absent
# image 55 Target Present
# block: 120
# ---------------------------------------------------
# probes_position:  [7, 13, 15, 29, 33, 43, 44, 49, 55]
# 60 60
# present_crit_distribution_original:  [0, 0, 0, 0]
# Present Used in block:  5
# Absent Used in block 4
# Critical probes counter:  0
# Present Critical:  0
# Absent Critical:  0
# List of critical trials without probe:
# [' person', ' dog', nan, nan, nan, 32.959390221443385, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' person', ' cat', nan, nan, nan, 32.2651090829965, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 29.27265460253791, 'high', ' bird', 'NA', 'No Target', 'Critical']
# normal in this block:  48
# normal used overall:  386
# critical_probes_used ['2008_006954.jpg', '2011_001382.jpg']
# sequence_final exists
# ---------------------------------------------------
# END OF BLOCK PROCESSING
# ---------------------------------------------------
# BUILDING THE BLOCK
# image 6 Critical
# image 11 Critical
# image 17 Target Present
# image 19 Target Present
# image 23 Target Absent
# image 25 Target Present
# image 32 Target Present
# image 38 Target Absent
# image 47 Target Absent
# image 50 Target Absent
# image 54 Target Present
# image 57 Critical
# block: 120
# ---------------------------------------------------
# probes_position:  [17, 19, 23, 25, 32, 38, 47, 50, 54]
# 60 60
# ['tone1', 'tone1', 'tone1']
# ['tone2', 'tone2', 'tone2']
# ----------------------
# ['tone1', 'tone1', 'tone2']
# ['tone2', 'tone2', 'tone1']
# ----------------------
# ['tone2', 'tone2', 'tone1']
# ['tone1', 'tone1', 'tone2']
# ----------------------
# ['tone2', 'tone2', 'tone2']
# ['tone1', 'tone1', 'tone1']
# ----------------------
# total n of tones:  24
# ----------------------
# total n of 1500 Hz tones:  12
# total n of 2000 Hz tones:  12
# ----------------------
# True
# 6
# 6
# True
# 6
# 6
# len(trials):  1920

# %%
print len(normal_no_probe_before)
print len(normal_used)
print len(normal_no_probe_before) == len(set(normal_used))
print len(target_present_before)
print len(present_used)
print len(target_present_before) == len(set(present_used))
print len(target_absent_before)
print len(absent_used)
print len(target_absent_before) == len(set(absent_used))

#the following is not a good check
print len(set(critical_trials_before)) == len(set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes))

print set(critical_trials_before) == set(critical_used + critical_low_present_probes + critical_low_absent_probes +
                                             critical_high_present_probes + critical_high_absent_probes)

print len(low_four)
print len(low_one) == len(low_two) == len(low_three) == len(low_four) == len(high_one) == len(high_two) == len(high_three) == len(high_four)
print len(set(low_one) & set(low_two) & set(low_three) & set(low_four) & set(high_one) & set(high_two) & set(high_three) & set(high_four))
# Out:
# 386
# 386
# True
# 36
# 36
# True
# 36
# 34
# False
# True
# True
# 60
# True
# 0

# %%
for i in range(len(trials.keys())):
    trials[i+1].append(i/60+1)

import pickle
with open('../config/randomization.pik', 'wb') as of:
    pickle.dump(trials,of)

# %%
df = pd.DataFrame.from_dict(trials)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type','tone_Hz','tone_onset','image_name','block']
df.TS = df.TS.astype('float')
df.to_csv(mypath + '../Config/randomization_1.csv')

# %%
df
# Out:
#              Cat.1         Cat.2         Cat.3       Cat.4    Cat.5  \
# 1              car           NaN           NaN         NaN      NaN
# 2           person           NaN           NaN         NaN      NaN
# 3           person        bottle           NaN         NaN      NaN
# 4              dog           NaN           NaN         NaN      NaN
# 5           bottle           NaN           NaN         NaN      NaN
# 6            chair           NaN           NaN         NaN      NaN
# 7           person         chair           NaN         NaN      NaN
# 8            horse           NaN           NaN         NaN      NaN
# 9           person           NaN           NaN         NaN      NaN
# 10             cat           NaN           NaN         NaN      NaN
# 11            bird           NaN           NaN         NaN      NaN
# 12     pottedplant           NaN           NaN         NaN      NaN
# 13           horse           NaN           NaN         NaN      NaN
# 14             car           NaN           NaN         NaN      NaN
# 15          person           dog           NaN         NaN      NaN
# 16       aeroplane           NaN           NaN         NaN      NaN
# 17          person          boat           NaN         NaN      NaN
# 18            boat           NaN           NaN         NaN      NaN
# 19             car           NaN           NaN         NaN      NaN
# 20       aeroplane           NaN           NaN         NaN      NaN
# 21            sofa         chair           NaN         NaN      NaN
# 22       aeroplane           NaN           NaN         NaN      NaN
# 23          person         chair   diningtable         NaN      NaN
# 24             dog           NaN           NaN         NaN      NaN
# 25           chair           cat           NaN         NaN      NaN
# 26             car           NaN           NaN         NaN      NaN
# 27             dog           NaN           NaN         NaN      NaN
# 28     pottedplant           NaN           NaN         NaN      NaN
# 29       aeroplane           NaN           NaN         NaN      NaN
# 30             cat           NaN           NaN         NaN      NaN
# ...            ...           ...           ...         ...      ...
# 1891        person           NaN           NaN         NaN      NaN
# 1892          sofa         chair           NaN         NaN      NaN
# 1893        person       bicycle          boat         NaN      NaN
# 1894        person         chair           NaN         NaN      NaN
# 1895         horse           NaN           NaN         NaN      NaN
# 1896        person         horse           NaN         NaN      NaN
# 1897        person         horse           NaN         NaN      NaN
# 1898           bus          boat           car         NaN      NaN
# 1899          boat           NaN           NaN         NaN      NaN
# 1900           dog           NaN           NaN         NaN      NaN
# 1901        person         chair   diningtable      bottle      NaN
# 1902           cat           NaN           NaN         NaN      NaN
# 1903        person   diningtable        bottle         NaN      NaN
# 1904        person         train          sofa         NaN      NaN
# 1905           cat           NaN           NaN         NaN      NaN
# 1906        person           dog           NaN         NaN      NaN
# 1907        person         horse           NaN         NaN      NaN
# 1908          sofa         chair        person         NaN      NaN
# 1909        person     aeroplane           NaN         NaN      NaN
# 1910           dog           NaN           NaN         NaN      NaN
# 1911        person         horse           NaN         NaN      NaN
# 1912           cat           NaN           NaN         NaN      NaN
# 1913     tvmonitor          sofa        bottle      person      NaN
# 1914   pottedplant          sofa         chair   tvmonitor      NaN
# 1915           car           NaN           NaN         NaN      NaN
# 1916          sofa        person           NaN         NaN      NaN
# 1917           car       bicycle     motorbike         bus   person
# 1918          bird           NaN           NaN         NaN      NaN
# 1919          bird           NaN           NaN         NaN      NaN
# 1920          sofa        person           NaN         NaN      NaN
#
#              TS  Load      exemplar    question  present_absent trial_type  \
# 1     18.787451   low           car          NA       No Target     Normal
# 2     18.716529   low        person        boat   Target Absent     Normal
# 3     19.869099   low        bottle          NA       No Target     Normal
# 4     19.803149   low           dog          NA       No Target     Normal
# 5     19.096237   low        bottle          NA       No Target     Normal
# 6     21.005917   low         chair          NA       No Target     Normal
# 7     16.606807   low        person          NA       No Target     Normal
# 8     19.234401   low         horse          NA       No Target     Normal
# 9     21.010713   low        person          NA       No Target     Normal
# 10    20.850125   low           cat         cat  Target Present     Normal
# 11    17.167558   low          bird          NA       No Target     Normal
# 12    19.895720   low   pottedplant          NA       No Target     Normal
# 13    13.879634   low         horse      bottle   Target Absent     Normal
# 14    19.030178   low           car          NA       No Target     Normal
# 15    19.793376   low        person          NA       No Target     Normal
# 16     8.171245   low     aeroplane   aeroplane  Target Present     Normal
# 17    17.997748   low          boat          NA       No Target     Normal
# 18    20.210044   low          boat          NA       No Target     Normal
# 19    16.197036   low           car          NA       No Target     Normal
# 20    20.885437   low     aeroplane          NA       No Target     Normal
# 21    19.836492   low          sofa         car   Target Absent     Normal
# 22    14.341895   low     aeroplane          NA       No Target     Normal
# 23    20.561279   low         chair          NA       No Target     Normal
# 24    18.045036   low           dog          NA       No Target     Normal
# 25    19.797171   low           cat          NA       No Target     Normal
# 26    20.487167   low           car          NA       No Target     Normal
# 27    19.890089   low           dog          NA       No Target     Normal
# 28    17.493024   low   pottedplant          NA       No Target     Normal
# 29    15.731963   low     aeroplane          NA       No Target   Critical
# 30    18.686905   low           cat          NA       No Target     Normal
# ...         ...   ...           ...         ...             ...        ...
# 1891  29.639296  high        person          NA       No Target     Normal
# 1892  32.351474  high         chair          NA       No Target     Normal
# 1893  34.319052  high          boat        boat  Target Present     Normal
# 1894  29.779907  high         chair          NA       No Target     Normal
# 1895  29.281238  high         horse          NA       No Target     Normal
# 1896  33.334972  high         horse          NA       No Target     Normal
# 1897  28.936239  high         horse          NA       No Target     Normal
# 1898  34.403915  high          boat          NA       No Target     Normal
# 1899  34.967528  high          boat       chair   Target Absent     Normal
# 1900  31.728170  high           dog          NA       No Target     Normal
# 1901  33.823550  high         chair          NA       No Target     Normal
# 1902  29.401451  high           cat          NA       No Target     Normal
# 1903  33.461904  high        person          NA       No Target     Normal
# 1904  31.651156  high          sofa          NA       No Target     Normal
# 1905  30.306708  high           cat          NA       No Target     Normal
# 1906  32.142427  high           dog          NA       No Target     Normal
# 1907  30.530490  high         horse          NA       No Target     Normal
# 1908  36.443792  high          sofa   aeroplane   Target Absent     Normal
# 1909  34.544145  high     aeroplane          NA       No Target     Normal
# 1910  31.537857  high           dog          NA       No Target     Normal
# 1911  34.557577  high         horse         cat   Target Absent     Normal
# 1912  30.954011  high           cat          NA       No Target     Normal
# 1913  29.608026  high        bottle          NA       No Target     Normal
# 1914  29.464580  high   pottedplant          NA       No Target     Normal
# 1915  36.207395  high           car         car  Target Present     Normal
# 1916  31.463677  high          sofa          NA       No Target     Normal
# 1917  30.263449  high           car          NA       No Target     Normal
