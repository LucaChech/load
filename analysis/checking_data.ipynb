# %%
import pandas as pd
import pickle

# %%
f = '../output/participant_1.pik'
with open(f,'r') as of:
    D = pickle.load(of)
new_df = pd.DataFrame.from_dict(D['experiment_details'],orient='index')

# %%
pd.set_option('display.max_rows', 9000)

# %%
new_df
# Out:
#             cat_4       cat_5  tone_hz  tone_onset         cat_1  \
# 1             NaN         NaN  No tone        -999          bird
# 2             NaN         NaN  No tone        -999   pottedplant
# 3             NaN         NaN  No tone        -999           car
# 4             NaN         NaN  No tone        -999   pottedplant
# 5             NaN         NaN  No tone        -999   pottedplant
# 6             NaN         NaN  No tone        -999          boat
# 7             NaN         NaN  No tone        -999        person
# 8             NaN         NaN  No tone        -999         horse
# 9             NaN         NaN  No tone        -999          sofa
# 10            NaN         NaN    tone1          32           car
# 11            NaN         NaN    tone2         790          bird
# 12            NaN         NaN  No tone        -999        person
# 13            NaN         NaN  No tone        -999     aeroplane
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 999999):
    print(new_df)
# Out:
#             cat_4       cat_5  tone_hz  tone_onset         cat_1  \
# 1             NaN         NaN  No tone        -999           cat
# 2             NaN         NaN  No tone        -999         horse
# 3             NaN         NaN  No tone        -999        person
# 4             NaN         NaN  No tone        -999           car
# 5             NaN         NaN  No tone        -999           dog
# 6             NaN         NaN  No tone        -999          boat
# 7             NaN         NaN  No tone        -999          boat
# 8             NaN         NaN  No tone        -999          boat
# 9             NaN         NaN  No tone        -999        bottle
# 10            NaN         NaN  No tone        -999           dog
# 11            NaN         NaN  No tone        -999        person
# 12            NaN         NaN  No tone        -999           cat
# 13            NaN         NaN  No tone        -999           car
# ...

# %%
import numpy as np
import pandas as pd
raw_data = {'first_name': ['Jason', 'Molly', np.nan, np.nan, np.nan], 
        'nationality': ['USA', 'USA', 'France', 'UK', 'UK'], 
        'aage': [42, 52, 36, 24, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'nationality', 'age'])
df
# Out:
#   first_name nationality  age
# 0      Jason         USA   42
# 1      Molly         USA   52
# 2        NaN      France   36
# 3        NaN          UK   24
# 4        NaN          UK   70

# %%
import random
while True:

    while True:
        a = [random.randint(1,60) for r in xrange(3)]
        if sum(a) <= 60: 
            break
    print sum(a)
    new_list_2 = []
    acc = 0
    for i in a:
        acc = acc + i
        new_list_2.append(acc)
    print new_list_2
    two_gap = []
    for i in range(2): # add "-w"
        two_gap.append(new_list_2[i+1] - new_list_2[i])
        print two_gap
    if 1 and 2 not in two_gap:
        break
print new_list_2
# Out:
# 56
# [45, 55, 56]
# [10]
# [10, 1]
# [45, 55, 56]

# %%
# Out:
# [6, 28, 30]
# [22]
# [22, 2]

# %%
import random
while True:
    a = [random.randint(1,60) for r in xrange(3)]
    if sum(a) <= 60: 
        break
    new_list_2 = []
    acc = 0
    for i in a:
        acc = acc + i
        new_list_2.append(acc)
    new_list_2 = [n - 1 for n in new_list_2]
print sum(a)
print 'new_list_2: ', new_list_2
# Out:
# 55
# new_list_2:  [24, 74, 125]
