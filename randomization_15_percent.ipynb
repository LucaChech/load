# %%
### CREATING RANDOMIZATION.CSV
import pandas as pd
import numpy as np
import random
import csv
mypath = ('C:/Users/luca.chech.16/Desktop/Random_probes_last/Luca/')
df = pd.DataFrame.from_csv(mypath+'all_images_2.csv')


df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
exemplar = df['7'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load,exemplar)}

# DEFINING TARGET-PRESENT PROBES
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog',
              ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(category)
                intermediate = []
                break

for n in target_present:
    possible_images_dict[n].append('Target Present')
# DEFINING TARGET-ABSENT PROBES
target_absent = []
intermediate = []
for category in categories:
    for load in p_load:
        while True:
            trial = str(np.random.choice(lista, 1, replace= False))[2:-2]
            if category in possible_images_dict[trial][7] and load in possible_images_dict[trial] \
                and trial not in intermediate and trial not in target_absent and trial not in target_present:
                intermediate.append(trial)
            if len(intermediate) == 1:
                for each in intermediate:
                    target_absent.append(each)
                intermediate = []
                break
for each in target_absent:
    absent_list = [category for category in categories if category not in possible_images_dict[each]]
    absent_question = str(np.random.choice(absent_list, 1, replace= False))[2:-2]
    possible_images_dict[each].append(absent_question)
    possible_images_dict[each].append('Target Absent')
    print possible_images_dict[each]

for image in lista:
    if image not in target_present and image not in target_absent:
        possible_images_dict[image].append('NA')
        possible_images_dict[image].append('No Target')

# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level):
    global critical_trials
    temp = []
    container = []
    for element in lista:
        if load_level in possible_images_dict[element]:
            container.append(element)
    for category in categories:
        while len(temp) <3 :
            intermediate = str(np.random.choice(container, 1, replace= False))[2:-2]
            if category in possible_images_dict[intermediate] \
                and intermediate not in temp and intermediate not in critical_trials:
                temp.append(intermediate)
        for each in temp:
            critical_trials.append(each)
        temp =[]
    print len(critical_trials)
         
critical_trial('low')
critical_trial('high')

print len(critical_trials) == len(set(critical_trials))
for each in critical_trials:
    possible_images_dict[each].append('Critical')
for each in possible_images_dict:
    if 'Critical' not in possible_images_dict[each]:
        possible_images_dict[each].append('Normal')

df = pd.DataFrame.from_dict(possible_images_dict)
df= df.T
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','exemplar','question','present_absent','trial_type']
df.TS = df.TS.astype('float')
df.to_csv(mypath + 'randomization_15.csv')
# Out:
# [' bottle', nan, nan, nan, nan, 16.598874860824477, 'low', ' bottle', ' chair', 'Target Absent']
# [' bicycle', ' bottle', nan, nan, nan, 35.238149580823567, 'high', ' bottle', ' bird', 'Target Absent']
# [' horse', nan, nan, nan, nan, 18.590456430582357, 'low', ' horse', ' sofa', 'Target Absent']
# [' person', ' horse', nan, nan, nan, 35.669132455550859, 'high', ' horse', ' chair', 'Target Absent']
# [' pottedplant', nan, nan, nan, nan, 19.906276626032106, 'low', ' pottedplant', ' chair', 'Target Absent']
# [' pottedplant', ' person', ' motorbike', ' car', ' bus', 30.65978031477821, 'high', ' pottedplant', ' chair', 'Target Absent']
# [' sofa', ' dog', nan, nan, nan, 19.188834185415878, 'low', ' dog', ' chair', 'Target Absent']
# [' dog', nan, nan, nan, nan, 40.773121275105424, 'high', ' dog', ' aeroplane', 'Target Absent']
# [' cat', nan, nan, nan, nan, 16.417039192791336, 'low', ' cat', ' aeroplane', 'Target Absent']
# [' tvmonitor', ' cat', nan, nan, nan, 33.319550308764342, 'high', ' cat', ' pottedplant', 'Target Absent']
# [' person', nan, nan, nan, nan, 18.879557532788805, 'low', ' person', ' bottle', 'Target Absent']
# [' person', nan, nan, nan, nan, 38.902832805256907, 'high', ' person', ' cat', 'Target Absent']
# [' aeroplane', nan, nan, nan, nan, 19.095995737676468, 'low', ' aeroplane', ' bird', 'Target Absent']
# [' person', ' aeroplane', nan, nan, nan, 30.48036175658957, 'high', ' aeroplane', ' pottedplant', 'Target Absent']
# [' person', ' chair', ' dog', ' car', nan, 19.939826301105867, 'low', ' car', ' cat', 'Target Absent']
# [' car', ' motorbike', nan, nan, nan, 30.349000415280557, 'high', ' car', ' boat', 'Target Absent']
# [' chair', nan, nan, nan, nan, 20.138559565527519, 'low', ' chair', ' dog', 'Target Absent']
# [' person', ' chair', nan, nan, nan, 30.016324329275829, 'high', ' chair', ' aeroplane', 'Target Absent']
# [' sofa', ' person', nan, nan, nan, 20.382684879012675, 'low', ' sofa', ' car', 'Target Absent']
# [' sofa', ' dog', ' person', nan, nan, 29.283091574921396, 'high', ' sofa', ' aeroplane', 'Target Absent']
# [' bird', nan, nan, nan, nan, 18.231088875750352, 'low', ' bird', ' bottle', 'Target Absent']
# [' bird', nan, nan, nan, nan, 29.272654602537909, 'high', ' bird', ' chair', 'Target Absent']
# [' boat', nan, nan, nan, nan, 17.331558080669492, 'low', ' boat', ' pottedplant', 'Target Absent']
# [' boat', nan, nan, nan, nan, 35.94715000296663, 'high', ' boat', ' chair', 'Target Absent']
# 36
# 72
# True

# %%
#Defininfg blocks 
probes_per_block = []
critical_per_block = []
normal_per_block = []
present_used = []
absent_used = []
critical_used = []
normal_no_probe = [n for n in lista if 'Normal' in possible_images_dict[n] and 'No Target' in possible_images_dict[n]]
normal_no_probe_used = []
block = []
to_insert = []
print len(normal_no_probe)
# Out:
# 372

# %%
#%pdb

# %%
def block_low():
# Pick 3 present probes and 3 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 3:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 3 <= len(probes_per_block) < 6:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'low' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    for n in probes_per_block[0:3]:
        present_used.append(n)
    for n in probes_per_block[3:]:
        absent_used.append(n)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (9-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'low' in possible_images_dict[image]:
            critical_per_block.append(image) 
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 54 - (9 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'low' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(14):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                return  block, new_list
                break
#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(15,60)
    print 'len(block): ',len(block)
#print new_list
#for n in range(len(new_list)):
#    print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list

# %%
def block_high():
# Pick 3 present probes and 3 absent probes
    global critical_per_block,probes_per_block, present_used, absent_used, critical_used, normal_per_block, to_insert
    while len(probes_per_block) < 3:
        probe = str(np.random.choice(target_present,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in present_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    while 3 <= len(probes_per_block) < 6:
        probe = str(np.random.choice(target_absent,1,replace = False))[2:-2]
        if probe not in probes_per_block and probe not in absent_used and 'high' in possible_images_dict[probe]:
            probes_per_block.append(probe)
    for n in probes_per_block[0:3]:
        present_used.append(n)
    for n in probes_per_block[3:]:
        absent_used.append(n)
#------------------------------------------------------------------------------    
#Counting critical probes    
    critical_probes_counter = 0
    for n in probes_per_block:
        if 'Critical' in possible_images_dict[n]:
            critical_probes_counter = critical_probes_counter + 1
    #for n in probes_per_block:
    #    print possible_images_dict[n]
    print 'Present Used: ',len(present_used)
    print 'Absent Used ',len(absent_used)
    print 'Critical probes counter: ',critical_probes_counter
#------------------------------------------------------------------------------
#Picking critical trials
    while len(critical_per_block) < (9-critical_probes_counter):
        image = str(np.random.choice(critical_trials,1,replace = False))[2:-2]
        if image not in critical_per_block and image not in critical_used \
            and 'No Target' in possible_images_dict[image] and 'high' in possible_images_dict[image]:
            critical_per_block.append(image) 
    for n in critical_per_block:
        critical_used.append(n)
        print possible_images_dict[n]
    #temp = []
#------------------------------------------------------------------------------
#Picking normal trials
    while len(normal_per_block) < 54 - (9 - critical_probes_counter):
        image = str(np.random.choice(normal_no_probe,1,replace = False))[2:-2]
        if image not in normal_per_block and image not in normal_no_probe_used and 'high' in possible_images_dict[image]:
            normal_per_block.append(image)
    for n in normal_per_block:
        normal_no_probe_used.append(n)
    print 'len(normal_no_probe_used): ',len(normal_no_probe_used)
#-----------------------------------------------------------------------------
    to_insert = probes_per_block + critical_per_block
    print 'len(to_insert): ',len(to_insert)

    #Adding critical (no probe) trials to the block
    def constrained_sum_sample_pos_adding_criticals(n, total):
        """Return a randomly chosen list of n positive integers summing to total.
        Each such list is equally likely to occur."""
        global block, critical_per_block, new_list, diff, to_insert
        liste_scartate = 0
        while True:
            global sequences_length
            dividers = sorted(random.sample(xrange(1, total), n - 1))
            sequences_length = [a - b for a, b in zip(dividers + [total], [0] + dividers)]
            acc = 0
            new_list = []
            for i in sequences_length:
                acc = acc + i
                new_list.append(acc - 1)
            diff = []
            for i in range(14):
                diff.append(new_list[i+1] - new_list[i])
            liste_scartate = liste_scartate + 1
            if 1 not in diff and 2 not in diff:
                print 'Liste scartate: ',liste_scartate
                print 'New List: ', new_list
                block = normal_per_block
                #print len(block)
                random.shuffle(to_insert)
                for i in range(len(to_insert)):
                    block.insert(new_list[i], to_insert[i])
                return  block, new_list
                break
#-----------------------------------------------------------------------------    
    print 'len(block): ',len(block)
    constrained_sum_sample_pos_adding_criticals(15,60)
    print 'len(block): ',len(block)
#print new_list
#for n in range(len(new_list)):
#    print new_list[n], possible_images_dict[block[new_list[n]]]
#print diff
    probes_per_block = []
    critical_per_block = []
    normal_per_block = []
    to_insert = []
    print 'Normal used:',len(normal_no_probe_used)
    print'---------------------------------------------------'
    return block, new_list

# %%
low_one, lista_low_one = block_low()
low_two, lista_low_two = block_low()
low_three, lista_low_three = block_low()
low_four, lista_low_four = block_low()
high_one, lista_high_one = block_high()
high_two, lista_high_two = block_high()
high_three, lista_high_three = block_high()
high_four, lista_high_four = block_high()
# Out:
# Present Used:  3
# Absent Used  3
# Critical probes counter:  2
# [' bottle', ' cat', nan, nan, nan, 21.259829756421428, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 21.116301747151233, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' sofa', ' cat', nan, nan, nan, 21.054250295020399, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' chair', ' dog', ' diningtable', nan, nan, 18.206263900870965, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' sofa', ' person', nan, nan, nan, 20.983298059388602, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', nan, nan, nan, 19.664476147826182, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 17.32743512662066, 'low', ' cat', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  47
# len(to_insert):  13
# len(block):  0
# Liste scartate:  7231
# New List:  [0, 4, 8, 15, 18, 23, 26, 29, 32, 35, 41, 45, 50, 55, 59]
# len(block):  60
# Normal used: 47
# ---------------------------------------------------
# Present Used:  6
# Absent Used  6
# Critical probes counter:  2
# [' tvmonitor', ' bird', nan, nan, nan, 15.427788040321774, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 17.997748470093857, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' sofa', ' cat', nan, nan, nan, 18.288477341906038, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', ' person', nan, nan, nan, 17.856305662122608, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 9.5768677087381189, 'low', ' bird', 'NA', 'No Target', 'Critical']
# [' bottle', nan, nan, nan, nan, 20.465741194973702, 'low', ' bottle', 'NA', 'No Target', 'Critical']
# [' horse', nan, nan, nan, nan, 19.234401336670953, 'low', ' horse', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  94
# len(to_insert):  13
# len(block):  60
# Liste scartate:  32111
# New List:  [1, 4, 7, 10, 14, 17, 21, 24, 32, 35, 41, 46, 49, 53, 59]
# len(block):  60
# Normal used: 94
# ---------------------------------------------------
# Present Used:  9
# Absent Used  9
# Critical probes counter:  2
# [' aeroplane', nan, nan, nan, nan, 11.346413138559113, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' chair', ' diningtable', nan, nan, nan, 15.830708942989276, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', nan, nan, nan, 20.515117634611254, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' chair', ' cat', nan, nan, nan, 18.189876425015743, 'low', ' chair', 'NA', 'No Target', 'Critical']
# [' dog', nan, nan, nan, nan, 16.137458117206307, 'low', ' dog', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 15.633666738732224, 'low', ' cat', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 21.020838805689188, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  141
# len(to_insert):  13
# len(block):  60
# Liste scartate:  20409
# New List:  [1, 4, 7, 12, 15, 18, 26, 30, 39, 42, 46, 49, 52, 56, 59]
# len(block):  60
# Normal used: 141
# ---------------------------------------------------
# Present Used:  12
# Absent Used  12
# Critical probes counter:  2
# [' aeroplane', nan, nan, nan, nan, 19.885750448101746, 'low', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' car', nan, nan, nan, nan, 19.892352124442521, 'low', ' car', 'NA', 'No Target', 'Critical']
# [' person', ' bicycle', nan, nan, nan, 21.238698300852345, 'low', ' person', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 18.608778484059602, 'low', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 16.651242460530831, 'low', ' boat', 'NA', 'No Target', 'Critical']
# [' sofa', ' dog', nan, nan, nan, 16.69849859536183, 'low', ' sofa', 'NA', 'No Target', 'Critical']
# [' pottedplant', nan, nan, nan, nan, 20.730711859845602, 'low', ' pottedplant', 'NA', 'No Target', 'Critical']
# len(normal_no_probe_used):  188
# len(to_insert):  13
# len(block):  60
# Liste scartate:  54601
# New List:  [1, 4, 9, 12, 17, 23, 26, 30, 33, 37, 41, 45, 52, 56, 59]
# len(block):  60
# Normal used: 188
# ---------------------------------------------------
# [' chair', ' diningtable', nan, nan, nan, 38.092559700736814, 'high', ' chair', ' chair', 'Target Present', 'Normal']
# [' person', ' bicycle', ' car', nan, nan, 30.190593034538828, 'high', ' person', ' person', 'Target Present', 'Critical']
# [' pottedplant', ' chair', nan, nan, nan, 30.345415875169319, 'high', ' pottedplant', ' pottedplant', 'Target Present', 'Normal']
# [' dog', nan, nan, nan, nan, 40.773121275105424, 'high', ' dog', ' aeroplane', 'Target Absent', 'Normal']
# [' sofa', ' dog', ' person', nan, nan, 29.283091574921396, 'high', ' sofa', ' aeroplane', 'Target Absent', 'Normal']
# [' person', nan, nan, nan, nan, 38.902832805256907, 'high', ' person', ' cat', 'Target Absent', 'Normal']
# Present Used :  15
# Absent Used:  15
# 1
# [' cat', nan, nan, nan, nan, 29.246976174425782, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' boat', nan, nan, nan, 28.945528007542443, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' bird', nan, nan, nan, nan, 29.971879878734466, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' chair', ' bottle', nan, nan, 30.214295396186017, 'high', ' chair', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', nan, nan, nan, 31.19071287356914, 'high', ' person', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' car', ' chair', ' bicycle', ' person', 30.133244112833108, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', nan, nan, 30.606059813585301, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' bottle', ' diningtable', nan, nan, 33.022066804988405, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# 234
# len(block):  54
# len(block):  60
# Normal used: 234
# [' person', ' bicycle', ' car', nan, nan, 31.810247903263157, 'high', ' car', ' car', 'Target Present', 'Normal']
# [' cat', nan, nan, nan, nan, 29.37680987232249, 'high', ' cat', ' cat', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 29.176311484999022, 'high', ' bird', ' bird', 'Target Present', 'Normal']
# [' bird', nan, nan, nan, nan, 29.272654602537909, 'high', ' bird', ' chair', 'Target Absent', 'Normal']
# [' person', ' horse', nan, nan, nan, 35.669132455550859, 'high', ' horse', ' chair', 'Target Absent', 'Normal']
# [' person', ' aeroplane', nan, nan, nan, 30.48036175658957, 'high', ' aeroplane', ' pottedplant', 'Target Absent', 'Critical']
# Present Used :  18
# Absent Used:  18
# 1
# [' bird', ' boat', nan, nan, nan, 29.314233597971626, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' sofa', ' bottle', ' pottedplant', ' tvmonitor', ' chair', 33.937775623898794, 'high', ' bottle', 'NA', 'No Target', 'Critical']
# [' car', ' horse', ' person', nan, nan, 32.996121172096558, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' sofa', ' tvmonitor', nan, nan, nan, 29.902737207122268, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 31.319653473122486, 'high', ' dog', 'NA', 'No Target', 'Critical']
# [' tvmonitor', ' chair', ' sofa', nan, nan, 29.822033003804499, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' sofa', ' bottle', ' person', nan, nan, 29.479716970441856, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' car', ' aeroplane', nan, nan, nan, 32.224520766602424, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# 280
# len(block):  54
# len(block):  60
# Normal used: 280
# [' dog', nan, nan, nan, nan, 33.960677529937648, 'high', ' dog', ' dog', 'Target Present', 'Normal']
# [' boat', nan, nan, nan, nan, 30.07547411972709, 'high', ' boat', ' boat', 'Target Present', 'Critical']
# [' person', ' diningtable', ' bottle', nan, nan, 40.553399499714772, 'high', ' bottle', ' bottle', 'Target Present', 'Normal']
# [' bicycle', ' bottle', nan, nan, nan, 35.238149580823567, 'high', ' bottle', ' bird', 'Target Absent', 'Normal']
# [' pottedplant', ' person', ' motorbike', ' car', ' bus', 30.65978031477821, 'high', ' pottedplant', ' chair', 'Target Absent', 'Normal']
# [' car', ' motorbike', nan, nan, nan, 30.349000415280557, 'high', ' car', ' boat', 'Target Absent', 'Normal']
# Present Used :  21
# Absent Used:  21
# 1
# [' bird', nan, nan, nan, nan, 28.997604876343772, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 33.854821153874802, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' chair', ' diningtable', nan, nan, 29.968561457592411, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' cat', nan, nan, nan, nan, 31.779858819461175, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' sofa', ' diningtable', ' person', nan, nan, 40.507103369084113, 'high', ' sofa', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 31.046352086599544, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' sofa', nan, nan, nan, 28.81434208709868, 'high', ' pottedplant', 'NA', 'No Target', 'Critical']
# [' person', ' cat', nan, nan, nan, 30.226516379371251, 'high', ' cat', 'NA', 'No Target', 'Critical']
# 326
# len(block):  54
# len(block):  60
# Normal used: 326
# [' pottedplant', ' sofa', ' person', nan, nan, 29.723255523994041, 'high', ' sofa', ' sofa', 'Target Present', 'Normal']
# [' car', ' aeroplane', nan, nan, nan, 37.93755165753997, 'high', ' aeroplane', ' aeroplane', 'Target Present', 'Critical']
# [' person', ' horse', nan, nan, nan, 34.557577168628228, 'high', ' horse', ' horse', 'Target Present', 'Normal']
# [' tvmonitor', ' cat', nan, nan, nan, 33.319550308764342, 'high', ' cat', ' pottedplant', 'Target Absent', 'Normal']
# [' boat', nan, nan, nan, nan, 35.94715000296663, 'high', ' boat', ' chair', 'Target Absent', 'Normal']
# [' person', ' chair', nan, nan, nan, 30.016324329275829, 'high', ' chair', ' aeroplane', 'Target Absent', 'Normal']
# Present Used :  24
# Absent Used:  24
# 1
# [' bird', nan, nan, nan, nan, 32.06509585553637, 'high', ' bird', 'NA', 'No Target', 'Critical']
# [' bus', ' person', ' car', nan, nan, 29.160026173656238, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' motorbike', ' boat', 31.580489902106891, 'high', ' boat', 'NA', 'No Target', 'Critical']
# [' pottedplant', ' person', ' chair', ' sofa', ' cat', 29.727129597298969, 'high', ' cat', 'NA', 'No Target', 'Critical']
# [' person', ' horse', nan, nan, nan, 29.86612410055109, 'high', ' horse', 'NA', 'No Target', 'Critical']
# [' person', ' aeroplane', nan, nan, nan, 30.073041628958684, 'high', ' aeroplane', 'NA', 'No Target', 'Critical']
# [' car', ' dog', nan, nan, nan, 31.13697327795364, 'high', ' car', 'NA', 'No Target', 'Critical']
# [' person', ' dog', nan, nan, nan, 29.0787327362723, 'high', ' dog', 'NA', 'No Target', 'Critical']
# 372
# len(block):  54
# len(block):  60
# Normal used: 372

# %%
print len(normal_no_probe)
print len(normal_no_probe_used)
print len(normal_no_probe) == len(set(normal_no_probe_used))
print len(target_present)
print len(present_used)
print len(target_present) == len(set(present_used))
print len(target_absent)
print len(absent_used)
print len(target_absent) == len(set(absent_used))
print len(critical_trials)
print len(critical_used)
critical_probes_counter = 0
probes = target_absent + target_present
for probe in probes:
    if 'Target Present' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    if 'Target Absent' in possible_images_dict[probe] and 'Critical' in possible_images_dict[probe]:
        critical_probes_counter = critical_probes_counter +1
    
print critical_probes_counter
# Out:
# 372
# 372
# True
# 24
# 24
# True
# 24
# 24
# True
# 72
# 60
# 12

# %%
block_dict = {}
block_dict['low_one'] = low_one
block_dict['low_two'] = low_two
block_dict['low_three'] = low_three
block_dict['low_four'] = low_four
block_dict['high_one'] = high_one
block_dict['high_two'] = high_two
block_dict['high_three'] = high_three
block_dict['high_four'] = high_four

# %%
block_dict['low_one']
print len(block_dict['low_one'])
# Out:
# 60
